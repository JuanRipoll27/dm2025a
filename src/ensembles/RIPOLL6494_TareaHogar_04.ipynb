# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# Esta Tarea para el Hogar 02 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el viernes 01-agosto

# %% [markdown]
# ##  1. Cazatalentos

# %% [markdown]
# En la Clase 03 nos hemos enfrentado a  "La Maldicion del Ganandor",  elegir el modelo con el mejor puntaje simple no suele ser la mejor estrategia.
# <br> Lea y ejecute el notebook  **src/CazaTalentos/CazaTalentos.ipynb**
# <br> en caso de interesarle, participe del Desafío Ordenamiento  que vence el sábado 02 de agosto a las 19:00

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dm"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dm" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/itba2025-8d0a/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Wed Jul 23 00:32:03 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  656930 35.1 1439368    76.9 1431359  76.5
# Vcells 1224847  9.4 8388608    64.0 1924958  14.7

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 4945
PARAM$semilla_primigenia <- 100887

# %%
PARAM$kaggle$competencia <- "data-mining-analista-sr-2025-a"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_iterations", lower = 800L, upper = 1600L),         
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.03),           
  makeNumericParam("feature_fraction", lower = 0.45, upper = 0.65),         
  makeIntegerParam("num_leaves", lower = 20L, upper = 60L),                 
  makeIntegerParam("min_data_in_leaf", lower = 400L, upper = 900L)          
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 100 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83368
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Wed Jul 23 00:40:32 2025 AUC 0.929688944386515
#
# Wed Jul 23 00:41:37 2025 AUC 0.930337702975287
#
# Wed Jul 23 00:42:41 2025 AUC 0.931086181031023
#
# Wed Jul 23 00:43:30 2025 AUC 0.929631874932042
#
# Wed Jul 23 00:44:05 2025 AUC 0.93091892685863
#
# Wed Jul 23 00:44:53 2025 AUC 0.930262712505026
#
# Wed Jul 23 00:45:38 2025 AUC 0.930817707784623
#
# Wed Jul 23 00:46:47 2025 AUC 0.931693033972585
#
# Wed Jul 23 00:47:24 2025 AUC 0.930363945913007
#
# Wed Jul 23 00:48:25 2025 AUC 0.930425018876952
#
# Wed Jul 23 00:49:19 2025 AUC 0.931120686999816
#
# Wed Jul 23 00:50:34 2025 AUC 0.930021722113397
#
# Wed Jul 23 00:51:34 2025 AUC 0.930421510182539
#
# Wed Jul 23 00:52:18 2025 AUC 0.930519651881573
#
# Wed Jul 23 00:53:08 2025 AUC 0.93037770423979
#
# Wed Jul 23 00:54:17 2025 AUC 0.929794160987677
#
# Wed Jul 23 00:55:17 2025 AUC 0.931688295375924
#
# Wed Jul 23 00:55:54 2025 AUC 0.930753053838045
#
# Wed Jul 23 00:57:20 2025 AUC 0.930163050980517
#
# Wed Jul 23 00:58:09 2025 AUC 0.931079582303841
#
# [mbo] 0: num_iterations=1085; learning_rate=0.0227; feature_fraction=0.585; num_leaves=35; min_data_in_leaf=830 : y = 0.93 : 45.3 secs : initdesign
#
# [mbo] 0: num_iterations=1382; learning_rate=0.0185; feature_fraction=0.565; num_leaves=45; min_data_in_leaf=475 : y = 0.93 : 64.7 secs : initdesign
#
# [mbo] 0: num_iterations=1277; learning_rate=0.0146; feature_fraction=0.525; num_leaves=48; min_data_in_leaf=513 : y = 0.931 : 64.5 secs : initdesign
#
# [mbo] 0: num_iterations=991; learning_rate=0.0125; feature_fraction=0.621; num_leaves=50; min_data_in_leaf=863 : y = 0.93 : 48.8 secs : initdesign
#
# [mbo] 0: num_iterations=853; learning_rate=0.02; feature_fraction=0.518; num_leaves=27; min_data_in_leaf=661 : y = 0.931 : 35.3 secs : initdesign
#
# [mbo] 0: num_iterations=1233; learning_rate=0.0118; feature_fraction=0.571; num_leaves=24; min_data_in_leaf=576 : y = 0.93 : 47.4 secs : initdesign
#
# [mbo] 0: num_iterations=805; learning_rate=0.00682; feature_fraction=0.499; num_leaves=57; min_data_in_leaf=710 : y = 0.931 : 45.5 secs : initdesign
#
# [mbo] 0: num_iterations=1508; learning_rate=0.0159; feature_fraction=0.503; num_leaves=37; min_data_in_leaf=457 : y = 0.932 : 69.1 secs : initdesign
#
# [mbo] 0: num_iterations=934; learning_rate=0.0244; feature_fraction=0.611; num_leaves=31; min_data_in_leaf=623 : y = 0.93 : 37.2 secs : initdesign
#
# [mbo] 0: num_iterations=1440; learning_rate=0.0255; feature_fraction=0.489; num_leaves=28; min_data_in_leaf=770 : y = 0.93 : 61.0 secs : initdesign
#
# [mbo] 0: num_iterations=1060; learning_rate=0.0271; feature_fraction=0.545; num_leaves=42; min_data_in_leaf=779 : y = 0.931 : 53.4 secs : initdesign
#
# [mbo] 0: num_iterations=1356; learning_rate=0.0299; feature_fraction=0.458; num_leaves=59; min_data_in_leaf=629 : y = 0.93 : 75.0 secs : initdesign
#
# [mbo] 0: num_iterations=1569; learning_rate=0.0107; feature_fraction=0.462; num_leaves=21; min_data_in_leaf=682 : y = 0.93 : 60.2 secs : initdesign
#
# [mbo] 0: num_iterations=901; learning_rate=0.00935; feature_fraction=0.557; num_leaves=39; min_data_in_leaf=439 : y = 0.931 : 43.8 secs : initdesign
#
# [mbo] 0: num_iterations=1124; learning_rate=0.0215; feature_fraction=0.648; num_leaves=51; min_data_in_leaf=574 : y = 0.93 : 50.5 secs : initdesign
#
# [mbo] 0: num_iterations=1290; learning_rate=0.00849; feature_fraction=0.535; num_leaves=54; min_data_in_leaf=741 : y = 0.93 : 68.2 secs : initdesign
#
# [mbo] 0: num_iterations=1466; learning_rate=0.00594; feature_fraction=0.6; num_leaves=33; min_data_in_leaf=409 : y = 0.932 : 60.9 secs : initdesign
#
# [mbo] 0: num_iterations=1180; learning_rate=0.0167; feature_fraction=0.639; num_leaves=23; min_data_in_leaf=823 : y = 0.931 : 36.9 secs : initdesign
#
# [mbo] 0: num_iterations=1556; learning_rate=0.0285; feature_fraction=0.593; num_leaves=56; min_data_in_leaf=891 : y = 0.93 : 85.9 secs : initdesign
#
# [mbo] 0: num_iterations=1017; learning_rate=0.0196; feature_fraction=0.474; num_leaves=40; min_data_in_leaf=536 : y = 0.931 : 49.1 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Wed Jul 23 00:59:26 2025 AUC 0.930842407746264
#
# [mbo] 1: num_iterations=1421; learning_rate=0.0155; feature_fraction=0.502; num_leaves=39; min_data_in_leaf=513 : y = 0.931 : 71.5 secs : infill_ei
#
# Wed Jul 23 01:00:30 2025 AUC 0.930830923141377
#
# [mbo] 2: num_iterations=1369; learning_rate=0.00606; feature_fraction=0.6; num_leaves=33; min_data_in_leaf=446 : y = 0.931 : 63.0 secs : infill_ei
#
# Wed Jul 23 01:01:38 2025 AUC 0.930690157872858
#
# [mbo] 3: num_iterations=1362; learning_rate=0.0146; feature_fraction=0.648; num_leaves=47; min_data_in_leaf=780 : y = 0.931 : 67.9 secs : infill_ei
#
# Wed Jul 23 01:02:26 2025 AUC 0.93070975790579
#
# [mbo] 4: num_iterations=1112; learning_rate=0.00906; feature_fraction=0.603; num_leaves=35; min_data_in_leaf=555 : y = 0.931 : 47.7 secs : infill_ei
#
# Wed Jul 23 01:03:32 2025 AUC 0.931034582254079
#
# [mbo] 5: num_iterations=1430; learning_rate=0.00977; feature_fraction=0.559; num_leaves=34; min_data_in_leaf=456 : y = 0.931 : 65.6 secs : infill_ei
#
# Wed Jul 23 01:04:44 2025 AUC 0.930010293299256
#
# [mbo] 6: num_iterations=1506; learning_rate=0.0121; feature_fraction=0.526; num_leaves=34; min_data_in_leaf=432 : y = 0.93 : 71.1 secs : infill_ei
#
# Wed Jul 23 01:06:01 2025 AUC 0.930793290470002
#
# [mbo] 7: num_iterations=1485; learning_rate=0.0158; feature_fraction=0.518; num_leaves=40; min_data_in_leaf=452 : y = 0.931 : 77.1 secs : infill_ei
#
# Wed Jul 23 01:07:26 2025 AUC 0.929677613022677
#
# [mbo] 8: num_iterations=1509; learning_rate=0.0256; feature_fraction=0.489; num_leaves=59; min_data_in_leaf=427 : y = 0.93 : 84.5 secs : infill_ei
#
# Wed Jul 23 01:08:26 2025 AUC 0.930908416522245
#
# [mbo] 9: num_iterations=1591; learning_rate=0.0118; feature_fraction=0.455; num_leaves=21; min_data_in_leaf=634 : y = 0.931 : 59.3 secs : infill_ei
#
# Saved the current state after iteration 10 in the file bayesiana.RDATA.
#
# Wed Jul 23 01:09:28 2025 AUC 0.930119330089529
#
# [mbo] 10: num_iterations=1332; learning_rate=0.0177; feature_fraction=0.593; num_leaves=37; min_data_in_leaf=778 : y = 0.93 : 58.3 secs : infill_ei
#
# Wed Jul 23 01:10:40 2025 AUC 0.931155970838354
#
# [mbo] 11: num_iterations=1513; learning_rate=0.0157; feature_fraction=0.503; num_leaves=42; min_data_in_leaf=420 : y = 0.931 : 71.1 secs : infill_ei
#
# Wed Jul 23 01:11:40 2025 AUC 0.93095030087984
#
# [mbo] 12: num_iterations=1531; learning_rate=0.0059; feature_fraction=0.602; num_leaves=34; min_data_in_leaf=415 : y = 0.931 : 59.7 secs : infill_ei
#
# Wed Jul 23 01:12:48 2025 AUC 0.930711497456582
#
# [mbo] 13: num_iterations=1467; learning_rate=0.00799; feature_fraction=0.531; num_leaves=38; min_data_in_leaf=868 : y = 0.931 : 67.7 secs : infill_ei
#
# Wed Jul 23 01:13:47 2025 AUC 0.930364349165661
#
# [mbo] 14: num_iterations=1442; learning_rate=0.0252; feature_fraction=0.45; num_leaves=31; min_data_in_leaf=790 : y = 0.93 : 58.8 secs : infill_ei
#
# Wed Jul 23 01:14:56 2025 AUC 0.930111467742434
#
# [mbo] 15: num_iterations=1362; learning_rate=0.0124; feature_fraction=0.594; num_leaves=56; min_data_in_leaf=825 : y = 0.93 : 68.8 secs : infill_ei
#
# Wed Jul 23 01:16:15 2025 AUC 0.930957037133571
#
# [mbo] 16: num_iterations=1476; learning_rate=0.0149; feature_fraction=0.53; num_leaves=54; min_data_in_leaf=554 : y = 0.931 : 77.4 secs : infill_ei
#
# Wed Jul 23 01:16:56 2025 AUC 0.92982638349597
#
# [mbo] 17: num_iterations=1064; learning_rate=0.026; feature_fraction=0.574; num_leaves=33; min_data_in_leaf=410 : y = 0.93 : 41.3 secs : infill_ei
#
# Wed Jul 23 01:18:02 2025 AUC 0.930300070598681
#
# [mbo] 18: num_iterations=1489; learning_rate=0.0238; feature_fraction=0.523; num_leaves=33; min_data_in_leaf=834 : y = 0.93 : 65.4 secs : infill_ei
#
# Wed Jul 23 01:18:40 2025 AUC 0.930930269547595
#
# [mbo] 19: num_iterations=946; learning_rate=0.00874; feature_fraction=0.456; num_leaves=24; min_data_in_leaf=539 : y = 0.931 : 37.1 secs : infill_ei
#
# Saved the current state after iteration 20 in the file bayesiana.RDATA.
#
# Wed Jul 23 01:19:33 2025 AUC 0.930086333123722
#
# [mbo] 20: num_iterations=1289; learning_rate=0.00865; feature_fraction=0.648; num_leaves=38; min_data_in_leaf=841 : y = 0.93 : 50.7 secs : infill_ei
#
# Wed Jul 23 01:20:36 2025 AUC 0.930214838965757
#
# [mbo] 21: num_iterations=1324; learning_rate=0.0183; feature_fraction=0.474; num_leaves=41; min_data_in_leaf=863 : y = 0.93 : 62.4 secs : infill_ei
#
# Wed Jul 23 01:21:24 2025 AUC 0.930565996421172
#
# [mbo] 22: num_iterations=932; learning_rate=0.0161; feature_fraction=0.457; num_leaves=49; min_data_in_leaf=411 : y = 0.931 : 46.8 secs : infill_ei
#
# Wed Jul 23 01:22:19 2025 AUC 0.931278035476367
#
# [mbo] 23: num_iterations=1414; learning_rate=0.00509; feature_fraction=0.452; num_leaves=25; min_data_in_leaf=537 : y = 0.931 : 55.3 secs : infill_ei
#
# Wed Jul 23 01:23:16 2025 AUC 0.930666056583112
#
# [mbo] 24: num_iterations=1346; learning_rate=0.0191; feature_fraction=0.597; num_leaves=37; min_data_in_leaf=642 : y = 0.931 : 56.0 secs : infill_ei
#
# Wed Jul 23 01:23:51 2025 AUC 0.930655559191884
#
# [mbo] 25: num_iterations=928; learning_rate=0.0071; feature_fraction=0.631; num_leaves=32; min_data_in_leaf=637 : y = 0.931 : 34.4 secs : infill_ei
#
# Wed Jul 23 01:24:50 2025 AUC 0.930797969080812
#
# [mbo] 26: num_iterations=1281; learning_rate=0.0238; feature_fraction=0.468; num_leaves=42; min_data_in_leaf=595 : y = 0.931 : 59.5 secs : infill_ei
#
# Wed Jul 23 01:25:37 2025 AUC 0.930869353240307
#
# [mbo] 27: num_iterations=1406; learning_rate=0.0197; feature_fraction=0.594; num_leaves=23; min_data_in_leaf=446 : y = 0.931 : 46.4 secs : infill_ei
#
# Wed Jul 23 01:26:36 2025 AUC 0.930510896068605
#
# [mbo] 28: num_iterations=1324; learning_rate=0.0135; feature_fraction=0.573; num_leaves=37; min_data_in_leaf=784 : y = 0.931 : 57.9 secs : infill_ei
#
# Wed Jul 23 01:27:07 2025 AUC 0.929927087243633
#
# [mbo] 29: num_iterations=929; learning_rate=0.0261; feature_fraction=0.581; num_leaves=21; min_data_in_leaf=789 : y = 0.93 : 31.0 secs : infill_ei
#
# Wed Jul 23 01:28:02 2025 AUC 0.930861144849858
#
# [mbo] 30: num_iterations=1412; learning_rate=0.0223; feature_fraction=0.64; num_leaves=40; min_data_in_leaf=474 : y = 0.931 : 54.1 secs : infill_ei
#
# Wed Jul 23 01:29:06 2025 AUC 0.92988848654055
#
# [mbo] 31: num_iterations=1328; learning_rate=0.0258; feature_fraction=0.494; num_leaves=45; min_data_in_leaf=774 : y = 0.93 : 63.7 secs : infill_ei
#
# Saved the current state after iteration 32 in the file bayesiana.RDATA.
#
# Wed Jul 23 01:30:03 2025 AUC 0.931195622655504
#
# [mbo] 32: num_iterations=1391; learning_rate=0.0257; feature_fraction=0.562; num_leaves=28; min_data_in_leaf=440 : y = 0.931 : 52.9 secs : infill_ei
#
# Wed Jul 23 01:30:59 2025 AUC 0.930782115461314
#
# [mbo] 33: num_iterations=1474; learning_rate=0.028; feature_fraction=0.624; num_leaves=36; min_data_in_leaf=530 : y = 0.931 : 56.2 secs : infill_ei
#
# Wed Jul 23 01:31:37 2025 AUC 0.930172725987542
#
# [mbo] 34: num_iterations=1323; learning_rate=0.0299; feature_fraction=0.64; num_leaves=24; min_data_in_leaf=534 : y = 0.93 : 37.9 secs : infill_ei
#
# Wed Jul 23 01:32:41 2025 AUC 0.930974798714945
#
# [mbo] 35: num_iterations=1301; learning_rate=0.0145; feature_fraction=0.648; num_leaves=56; min_data_in_leaf=750 : y = 0.931 : 63.4 secs : infill_ei
#
# Wed Jul 23 01:33:48 2025 AUC 0.930696533049858
#
# [mbo] 36: num_iterations=1546; learning_rate=0.00745; feature_fraction=0.604; num_leaves=43; min_data_in_leaf=409 : y = 0.931 : 66.7 secs : infill_ei
#
# Wed Jul 23 01:34:56 2025 AUC 0.930986861651135
#
# [mbo] 37: num_iterations=1350; learning_rate=0.0179; feature_fraction=0.569; num_leaves=53; min_data_in_leaf=422 : y = 0.931 : 67.2 secs : infill_ei
#
# Wed Jul 23 01:35:38 2025 AUC 0.930449816751261
#
# [mbo] 38: num_iterations=1470; learning_rate=0.0259; feature_fraction=0.624; num_leaves=21; min_data_in_leaf=547 : y = 0.93 : 41.0 secs : infill_ei
#
# Wed Jul 23 01:36:24 2025 AUC 0.931165354577184
#
# [mbo] 39: num_iterations=1172; learning_rate=0.00643; feature_fraction=0.546; num_leaves=26; min_data_in_leaf=856 : y = 0.931 : 46.4 secs : infill_ei
#
# Wed Jul 23 01:37:03 2025 AUC 0.930076162153946
#
# [mbo] 40: num_iterations=811; learning_rate=0.0224; feature_fraction=0.529; num_leaves=45; min_data_in_leaf=413 : y = 0.93 : 37.7 secs : infill_ei
#
# Wed Jul 23 01:38:02 2025 AUC 0.929990767119368
#
# [mbo] 41: num_iterations=1340; learning_rate=0.0175; feature_fraction=0.631; num_leaves=47; min_data_in_leaf=748 : y = 0.93 : 58.6 secs : infill_ei
#
# Wed Jul 23 01:38:57 2025 AUC 0.931241846918293
#
# [mbo] 42: num_iterations=1462; learning_rate=0.0132; feature_fraction=0.6; num_leaves=32; min_data_in_leaf=554 : y = 0.931 : 54.7 secs : infill_ei
#
# Wed Jul 23 01:40:01 2025 AUC 0.929951098591997
#
# [mbo] 43: num_iterations=1480; learning_rate=0.0216; feature_fraction=0.503; num_leaves=37; min_data_in_leaf=584 : y = 0.93 : 63.5 secs : infill_ei
#
# Saved the current state after iteration 44 in the file bayesiana.RDATA.
#
# Wed Jul 23 01:40:49 2025 AUC 0.929470479868393
#
# [mbo] 44: num_iterations=930; learning_rate=0.0264; feature_fraction=0.613; num_leaves=56; min_data_in_leaf=506 : y = 0.929 : 44.8 secs : infill_ei
#
# Wed Jul 23 01:41:57 2025 AUC 0.930786959453817
#
# [mbo] 45: num_iterations=1293; learning_rate=0.0271; feature_fraction=0.498; num_leaves=55; min_data_in_leaf=740 : y = 0.931 : 67.3 secs : infill_ei
#
# Wed Jul 23 01:43:13 2025 AUC 0.93055279373287
#
# [mbo] 46: num_iterations=1397; learning_rate=0.00823; feature_fraction=0.557; num_leaves=60; min_data_in_leaf=483 : y = 0.931 : 75.6 secs : infill_ei
#
# Wed Jul 23 01:44:07 2025 AUC 0.930214494685135
#
# [mbo] 47: num_iterations=1311; learning_rate=0.0146; feature_fraction=0.605; num_leaves=40; min_data_in_leaf=836 : y = 0.93 : 53.3 secs : infill_ei
#
# Wed Jul 23 01:44:48 2025 AUC 0.931434358438617
#
# [mbo] 48: num_iterations=1105; learning_rate=0.0128; feature_fraction=0.607; num_leaves=36; min_data_in_leaf=538 : y = 0.931 : 41.1 secs : infill_ei
#
# Wed Jul 23 01:45:46 2025 AUC 0.930291104263963
#
# [mbo] 49: num_iterations=1506; learning_rate=0.0161; feature_fraction=0.586; num_leaves=33; min_data_in_leaf=482 : y = 0.93 : 57.5 secs : infill_ei
#
# Wed Jul 23 01:46:38 2025 AUC 0.930197656330427
#
# [mbo] 50: num_iterations=1380; learning_rate=0.00505; feature_fraction=0.58; num_leaves=30; min_data_in_leaf=409 : y = 0.93 : 51.4 secs : infill_ei
#
# Wed Jul 23 01:47:32 2025 AUC 0.929737948109266
#
# [mbo] 51: num_iterations=1033; learning_rate=0.0212; feature_fraction=0.552; num_leaves=51; min_data_in_leaf=756 : y = 0.93 : 53.3 secs : infill_ei
#
# Wed Jul 23 01:48:35 2025 AUC 0.930714554740336
#
# [mbo] 52: num_iterations=1462; learning_rate=0.0177; feature_fraction=0.504; num_leaves=37; min_data_in_leaf=463 : y = 0.931 : 62.5 secs : infill_ei
#
# Wed Jul 23 01:49:36 2025 AUC 0.930314571529064
#
# [mbo] 53: num_iterations=1281; learning_rate=0.017; feature_fraction=0.508; num_leaves=45; min_data_in_leaf=721 : y = 0.93 : 60.5 secs : infill_ei
#
# Wed Jul 23 01:50:26 2025 AUC 0.930472874725607
#
# [mbo] 54: num_iterations=1164; learning_rate=0.0162; feature_fraction=0.456; num_leaves=36; min_data_in_leaf=813 : y = 0.93 : 49.6 secs : infill_ei
#
# Saved the current state after iteration 55 in the file bayesiana.RDATA.
#
# Wed Jul 23 01:51:14 2025 AUC 0.931874885404391
#
# [mbo] 55: num_iterations=873; learning_rate=0.0141; feature_fraction=0.498; num_leaves=52; min_data_in_leaf=481 : y = 0.932 : 43.7 secs : infill_ei
#
# Wed Jul 23 01:51:55 2025 AUC 0.929771976836268
#
# [mbo] 56: num_iterations=953; learning_rate=0.0243; feature_fraction=0.548; num_leaves=38; min_data_in_leaf=426 : y = 0.93 : 40.5 secs : infill_ei
#
# Wed Jul 23 01:52:48 2025 AUC 0.931076874085103
#
# [mbo] 57: num_iterations=1330; learning_rate=0.00952; feature_fraction=0.585; num_leaves=36; min_data_in_leaf=797 : y = 0.931 : 53.2 secs : infill_ei
#
# Wed Jul 23 01:53:56 2025 AUC 0.930270931681153
#
# [mbo] 58: num_iterations=1568; learning_rate=0.0134; feature_fraction=0.564; num_leaves=41; min_data_in_leaf=468 : y = 0.93 : 67.0 secs : infill_ei
#
# Wed Jul 23 01:54:50 2025 AUC 0.930306309500737
#
# [mbo] 59: num_iterations=1224; learning_rate=0.0166; feature_fraction=0.554; num_leaves=43; min_data_in_leaf=639 : y = 0.93 : 54.1 secs : infill_ei
#
# Wed Jul 23 01:55:55 2025 AUC 0.93099295944484
#
# [mbo] 60: num_iterations=1548; learning_rate=0.0152; feature_fraction=0.462; num_leaves=39; min_data_in_leaf=471 : y = 0.931 : 64.1 secs : infill_ei
#
# Wed Jul 23 01:57:02 2025 AUC 0.93038294380206
#
# [mbo] 61: num_iterations=1449; learning_rate=0.00793; feature_fraction=0.495; num_leaves=49; min_data_in_leaf=476 : y = 0.93 : 66.9 secs : infill_ei
#
# Wed Jul 23 01:57:48 2025 AUC 0.930497183005255
#
# [mbo] 62: num_iterations=1331; learning_rate=0.0226; feature_fraction=0.613; num_leaves=32; min_data_in_leaf=761 : y = 0.93 : 45.4 secs : infill_ei
#
# Wed Jul 23 01:58:50 2025 AUC 0.930001758227463
#
# [mbo] 63: num_iterations=1378; learning_rate=0.00748; feature_fraction=0.456; num_leaves=43; min_data_in_leaf=826 : y = 0.93 : 61.1 secs : infill_ei
#
# Wed Jul 23 02:00:05 2025 AUC 0.930295125484441
#
# [mbo] 64: num_iterations=1505; learning_rate=0.0109; feature_fraction=0.504; num_leaves=56; min_data_in_leaf=659 : y = 0.93 : 74.4 secs : infill_ei
#
# Wed Jul 23 02:01:06 2025 AUC 0.930201683577193
#
# [mbo] 65: num_iterations=1549; learning_rate=0.0264; feature_fraction=0.483; num_leaves=30; min_data_in_leaf=877 : y = 0.93 : 60.5 secs : infill_ei
#
# Saved the current state after iteration 66 in the file bayesiana.RDATA.
#
# Wed Jul 23 02:02:18 2025 AUC 0.93000739248709
#
# [mbo] 66: num_iterations=1515; learning_rate=0.0257; feature_fraction=0.451; num_leaves=43; min_data_in_leaf=741 : y = 0.93 : 66.5 secs : infill_ei
#
# Wed Jul 23 02:03:08 2025 AUC 0.93080105885356
#
# [mbo] 67: num_iterations=1358; learning_rate=0.0137; feature_fraction=0.524; num_leaves=26; min_data_in_leaf=806 : y = 0.931 : 49.8 secs : infill_ei
#
# Wed Jul 23 02:03:55 2025 AUC 0.93066839821205
#
# [mbo] 68: num_iterations=1042; learning_rate=0.0103; feature_fraction=0.483; num_leaves=45; min_data_in_leaf=884 : y = 0.931 : 46.4 secs : infill_ei
#
# Wed Jul 23 02:04:40 2025 AUC 0.930537690006134
#
# [mbo] 69: num_iterations=1132; learning_rate=0.0126; feature_fraction=0.502; num_leaves=29; min_data_in_leaf=806 : y = 0.931 : 44.2 secs : infill_ei
#
# Wed Jul 23 02:05:08 2025 AUC 0.93117555743048
#
# [mbo] 70: num_iterations=868; learning_rate=0.00857; feature_fraction=0.646; num_leaves=30; min_data_in_leaf=584 : y = 0.931 : 27.8 secs : infill_ei
#
# Wed Jul 23 02:06:01 2025 AUC 0.929499926209613
#
# [mbo] 71: num_iterations=1563; learning_rate=0.0268; feature_fraction=0.546; num_leaves=21; min_data_in_leaf=648 : y = 0.929 : 52.6 secs : infill_ei
#
# Wed Jul 23 02:06:40 2025 AUC 0.930031482307915
#
# [mbo] 72: num_iterations=838; learning_rate=0.0131; feature_fraction=0.57; num_leaves=45; min_data_in_leaf=803 : y = 0.93 : 38.1 secs : infill_ei
#
# Wed Jul 23 02:07:11 2025 AUC 0.929834375550334
#
# [mbo] 73: num_iterations=1075; learning_rate=0.0183; feature_fraction=0.609; num_leaves=22; min_data_in_leaf=490 : y = 0.93 : 30.5 secs : infill_ei
#
# Wed Jul 23 02:08:13 2025 AUC 0.929670710449143
#
# [mbo] 74: num_iterations=1508; learning_rate=0.0269; feature_fraction=0.474; num_leaves=37; min_data_in_leaf=678 : y = 0.93 : 61.9 secs : infill_ei
#
# Wed Jul 23 02:08:53 2025 AUC 0.930679000584201
#
# [mbo] 75: num_iterations=876; learning_rate=0.012; feature_fraction=0.469; num_leaves=42; min_data_in_leaf=481 : y = 0.931 : 38.9 secs : infill_ei
#
# Wed Jul 23 02:09:47 2025 AUC 0.931071717153218
#
# [mbo] 76: num_iterations=1258; learning_rate=0.00615; feature_fraction=0.483; num_leaves=37; min_data_in_leaf=567 : y = 0.931 : 53.0 secs : infill_ei
#
# Wed Jul 23 02:10:48 2025 AUC 0.930439836895677
#
# [mbo] 77: num_iterations=1371; learning_rate=0.0252; feature_fraction=0.597; num_leaves=51; min_data_in_leaf=525 : y = 0.93 : 60.8 secs : infill_ei
#
# Wed Jul 23 02:11:32 2025 AUC 0.930505345135401
#
# [mbo] 78: num_iterations=1070; learning_rate=0.0262; feature_fraction=0.533; num_leaves=33; min_data_in_leaf=861 : y = 0.931 : 43.1 secs : infill_ei
#
# Saved the current state after iteration 79 in the file bayesiana.RDATA.
#
# Wed Jul 23 02:12:32 2025 AUC 0.931205198942369
#
# [mbo] 79: num_iterations=1161; learning_rate=0.00926; feature_fraction=0.49; num_leaves=55; min_data_in_leaf=658 : y = 0.931 : 56.4 secs : infill_ei
#
# Wed Jul 23 02:13:33 2025 AUC 0.930100021963735
#
# [mbo] 80: num_iterations=1275; learning_rate=0.0261; feature_fraction=0.536; num_leaves=54; min_data_in_leaf=453 : y = 0.93 : 60.5 secs : infill_ei
#
# Wed Jul 23 02:14:16 2025 AUC 0.93035744279785
#
# [mbo] 81: num_iterations=878; learning_rate=0.0141; feature_fraction=0.491; num_leaves=52; min_data_in_leaf=467 : y = 0.93 : 42.9 secs : infill_ei
#
# Wed Jul 23 02:15:16 2025 AUC 0.9308154122677
#
# [mbo] 82: num_iterations=1251; learning_rate=0.00654; feature_fraction=0.457; num_leaves=51; min_data_in_leaf=675 : y = 0.931 : 59.6 secs : infill_ei
#
# Wed Jul 23 02:16:08 2025 AUC 0.930838635463122
#
# [mbo] 83: num_iterations=1460; learning_rate=0.0214; feature_fraction=0.462; num_leaves=22; min_data_in_leaf=642 : y = 0.931 : 50.9 secs : infill_ei
#
# Wed Jul 23 02:16:54 2025 AUC 0.930424475653846
#
# [mbo] 84: num_iterations=1237; learning_rate=0.00664; feature_fraction=0.613; num_leaves=35; min_data_in_leaf=724 : y = 0.93 : 45.2 secs : infill_ei
#
# Wed Jul 23 02:17:56 2025 AUC 0.930377204804646
#
# [mbo] 85: num_iterations=1212; learning_rate=0.0143; feature_fraction=0.466; num_leaves=59; min_data_in_leaf=656 : y = 0.93 : 61.8 secs : infill_ei
#
# Wed Jul 23 02:19:04 2025 AUC 0.92906509716165
#
# [mbo] 86: num_iterations=1403; learning_rate=0.028; feature_fraction=0.556; num_leaves=54; min_data_in_leaf=691 : y = 0.929 : 67.9 secs : infill_ei
#
# Wed Jul 23 02:20:04 2025 AUC 0.930707327766156
#
# [mbo] 87: num_iterations=1247; learning_rate=0.0258; feature_fraction=0.492; num_leaves=50; min_data_in_leaf=717 : y = 0.931 : 59.5 secs : infill_ei
#
# Wed Jul 23 02:20:45 2025 AUC 0.930007586540655
#
# [mbo] 88: num_iterations=1048; learning_rate=0.01; feature_fraction=0.573; num_leaves=35; min_data_in_leaf=762 : y = 0.93 : 39.9 secs : infill_ei
#
# Wed Jul 23 02:21:27 2025 AUC 0.929876445487563
#
# [mbo] 89: num_iterations=1192; learning_rate=0.0124; feature_fraction=0.497; num_leaves=20; min_data_in_leaf=694 : y = 0.93 : 41.6 secs : infill_ei
#
# Wed Jul 23 02:22:14 2025 AUC 0.931163096445446
#
# [mbo] 90: num_iterations=1371; learning_rate=0.021; feature_fraction=0.577; num_leaves=26; min_data_in_leaf=875 : y = 0.931 : 46.8 secs : infill_ei
#
# Saved the current state after iteration 91 in the file bayesiana.RDATA.
#
# Wed Jul 23 02:22:55 2025 AUC 0.929774187667328
#
# [mbo] 91: num_iterations=843; learning_rate=0.0178; feature_fraction=0.565; num_leaves=42; min_data_in_leaf=695 : y = 0.93 : 36.2 secs : infill_ei
#
# Wed Jul 23 02:23:45 2025 AUC 0.930296434816998
#
# [mbo] 92: num_iterations=1114; learning_rate=0.0282; feature_fraction=0.483; num_leaves=45; min_data_in_leaf=635 : y = 0.93 : 49.7 secs : infill_ei
#
# Wed Jul 23 02:24:50 2025 AUC 0.93050623300524
#
# [mbo] 93: num_iterations=1315; learning_rate=0.0184; feature_fraction=0.503; num_leaves=55; min_data_in_leaf=694 : y = 0.931 : 64.6 secs : infill_ei
#
# Wed Jul 23 02:25:37 2025 AUC 0.930534840527053
#
# [mbo] 94: num_iterations=1289; learning_rate=0.0208; feature_fraction=0.455; num_leaves=26; min_data_in_leaf=525 : y = 0.931 : 46.3 secs : infill_ei
#
# Wed Jul 23 02:26:34 2025 AUC 0.931532199351796
#
# [mbo] 95: num_iterations=1554; learning_rate=0.0178; feature_fraction=0.499; num_leaves=25; min_data_in_leaf=481 : y = 0.932 : 56.4 secs : infill_ei
#
# Wed Jul 23 02:27:40 2025 AUC 0.931076513594147
#
# [mbo] 96: num_iterations=1516; learning_rate=0.00708; feature_fraction=0.535; num_leaves=39; min_data_in_leaf=694 : y = 0.931 : 65.2 secs : infill_ei
#
# Wed Jul 23 02:28:53 2025 AUC 0.930271989436844
#
# [mbo] 97: num_iterations=1423; learning_rate=0.0194; feature_fraction=0.543; num_leaves=60; min_data_in_leaf=476 : y = 0.93 : 71.8 secs : infill_ei
#
# Wed Jul 23 02:29:33 2025 AUC 0.930066156775544
#
# [mbo] 98: num_iterations=1030; learning_rate=0.0245; feature_fraction=0.558; num_leaves=34; min_data_in_leaf=762 : y = 0.93 : 39.8 secs : infill_ei
#
# Wed Jul 23 02:30:05 2025 AUC 0.929579815307995
#
# [mbo] 99: num_iterations=895; learning_rate=0.0261; feature_fraction=0.622; num_leaves=35; min_data_in_leaf=847 : y = 0.93 : 31.4 secs : infill_ei
#
# Wed Jul 23 02:31:01 2025 AUC 0.930574864670639
#
# [mbo] 100: num_iterations=1337; learning_rate=0.00938; feature_fraction=0.524; num_leaves=34; min_data_in_leaf=702 : y = 0.931 : 55.2 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "num_iterations"   "learning_rate"    "feature_fraction" "num_leaves"
#  [5] "min_data_in_leaf" "y"                "dob"              "eol"
#  [9] "error.message"    "exec.time"        "ei"               "error.model"
# [13] "train.time"       "prop.type"        "propose.time"     "se"
# [17] "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    num_iterations learning_rate feature_fraction num_leaves min_data_in_leaf
#             <int>         <num>            <num>      <int>            <int>
# 1:            873    0.01410464        0.4978797         52              481
# [1] 0.9318749

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 100887
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 0
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 1
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 873
#
# $learning_rate
# [1] 0.01410464
#
# $feature_fraction
# [1] 0.4978797
#
# $num_leaves
# [1] 52
#
# $min_data_in_leaf
# [1] 481

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Wed Jul 23 02:39:08 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
