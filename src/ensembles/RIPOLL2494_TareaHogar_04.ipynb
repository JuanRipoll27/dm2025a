# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# Esta Tarea para el Hogar 02 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el viernes 01-agosto

# %% [markdown]
# ##  1. Cazatalentos

# %% [markdown]
# En la Clase 03 nos hemos enfrentado a  "La Maldicion del Ganandor",  elegir el modelo con el mejor puntaje simple no suele ser la mejor estrategia.
# <br> Lea y ejecute el notebook  **src/CazaTalentos/CazaTalentos.ipynb**
# <br> en caso de interesarle, participe del Desafío Ordenamiento  que vence el sábado 02 de agosto a las 19:00

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dm"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dm" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/itba2025-8d0a/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Jul 21 13:41:49 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  656930 35.1 1439371    76.9 1431354  76.5
# Vcells 1224847  9.4 8388608    64.0 1924958  14.7

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 4941
PARAM$semilla_primigenia <- 100887

# %%
PARAM$kaggle$competencia <- "data-mining-analista-sr-2025-a"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_iterations", lower = 500L, upper = 2000L),
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.05),
  makeNumericParam("feature_fraction", lower = 0.4, upper = 0.9),
  makeNumericParam("bagging_fraction", lower = 0.6, upper = 1.0),
  makeIntegerParam("num_leaves", lower = 20L, upper = 150L),
  makeIntegerParam("min_data_in_leaf", lower = 50L, upper = 1000L),
  makeIntegerParam("max_depth", lower = 3L, upper = 15L),
  makeNumericParam("lambda_l1", lower = 0.0, upper = 5.0),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 5.0)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 90 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83368
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Mon Jul 21 13:50:58 2025 AUC 0.930316154069721
#
# Mon Jul 21 13:51:42 2025 AUC 0.930815609492209
#
# Mon Jul 21 13:52:55 2025 AUC 0.929942058762945
#
# Mon Jul 21 13:53:30 2025 AUC 0.929927211039042
#
# Mon Jul 21 13:53:49 2025 AUC 0.929324335419659
#
# Mon Jul 21 13:55:28 2025 AUC 0.930122168557713
#
# Mon Jul 21 13:56:14 2025 AUC 0.928703965436851
#
# Mon Jul 21 13:57:40 2025 AUC 0.929546863211134
#
# Mon Jul 21 13:59:18 2025 AUC 0.930751188603327
#
# Mon Jul 21 14:00:27 2025 AUC 0.92954497321759
#
# Mon Jul 21 14:01:19 2025 AUC 0.92930598677789
#
# Mon Jul 21 14:02:20 2025 AUC 0.930111559228519
#
# Mon Jul 21 14:02:58 2025 AUC 0.929341978009959
#
# Mon Jul 21 14:03:22 2025 AUC 0.929607833006622
#
# Mon Jul 21 14:04:23 2025 AUC 0.928415198899796
#
# Mon Jul 21 14:05:12 2025 AUC 0.93089461706354
#
# Mon Jul 21 14:06:48 2025 AUC 0.931552439876898
#
# Mon Jul 21 14:07:39 2025 AUC 0.930669931168965
#
# Mon Jul 21 14:08:09 2025 AUC 0.929837385265531
#
# Mon Jul 21 14:09:15 2025 AUC 0.928913691225663
#
# Mon Jul 21 14:10:00 2025 AUC 0.929792922998568
#
# Mon Jul 21 14:12:09 2025 AUC 0.929222200011922
#
# Mon Jul 21 14:13:20 2025 AUC 0.929301364267818
#
# Mon Jul 21 14:13:50 2025 AUC 0.929193390614392
#
# Mon Jul 21 14:14:39 2025 AUC 0.930451806804564
#
# Mon Jul 21 14:15:18 2025 AUC 0.929024590280446
#
# Mon Jul 21 14:16:48 2025 AUC 0.930654354338776
#
# Mon Jul 21 14:18:31 2025 AUC 0.930920612840752
#
# Mon Jul 21 14:18:46 2025 AUC 0.930414528221608
#
# Mon Jul 21 14:19:35 2025 AUC 0.929230994052057
#
# Mon Jul 21 14:20:49 2025 AUC 0.930169241335148
#
# Mon Jul 21 14:21:22 2025 AUC 0.926724931651731
#
# Mon Jul 21 14:22:49 2025 AUC 0.930431900645945
#
# Mon Jul 21 14:23:18 2025 AUC 0.922897793310535
#
# Mon Jul 21 14:24:10 2025 AUC 0.930439217680107
#
# Mon Jul 21 14:25:12 2025 AUC 0.929861769067825
#
# [mbo] 0: num_iterations=947; learning_rate=0.0263; feature_fraction=0.601; bagging_fraction=0.741; num_leaves=107; min_data_in_leaf=717; max_depth=10; lambda_l1=3.33; lambda_l2=3.5 : y = 0.93 : 51.5 secs : initdesign
#
# [mbo] 0: num_iterations=826; learning_rate=0.0186; feature_fraction=0.681; bagging_fraction=0.682; num_leaves=58; min_data_in_leaf=235; max_depth=10; lambda_l1=3.77; lambda_l2=4.02 : y = 0.931 : 43.5 secs : initdesign
#
# [mbo] 0: num_iterations=1816; learning_rate=0.0225; feature_fraction=0.775; bagging_fraction=0.671; num_leaves=73; min_data_in_leaf=336; max_depth=7; lambda_l1=2.4; lambda_l2=2.95 : y = 0.93 : 73.7 secs : initdesign
#
# [mbo] 0: num_iterations=565; learning_rate=0.0318; feature_fraction=0.509; bagging_fraction=0.708; num_leaves=103; min_data_in_leaf=394; max_depth=8; lambda_l1=1.28; lambda_l2=1.26 : y = 0.93 : 34.5 secs : initdesign
#
# [mbo] 0: num_iterations=729; learning_rate=0.0199; feature_fraction=0.663; bagging_fraction=0.823; num_leaves=129; min_data_in_leaf=59; max_depth=4; lambda_l1=0.591; lambda_l2=0.644 : y = 0.929 : 19.1 secs : initdesign
#
# [mbo] 0: num_iterations=1456; learning_rate=0.0341; feature_fraction=0.545; bagging_fraction=0.86; num_leaves=95; min_data_in_leaf=658; max_depth=12; lambda_l1=2.06; lambda_l2=2.46 : y = 0.93 : 98.9 secs : initdesign
#
# [mbo] 0: num_iterations=1077; learning_rate=0.0328; feature_fraction=0.825; bagging_fraction=0.75; num_leaves=76; min_data_in_leaf=369; max_depth=8; lambda_l1=1.2; lambda_l2=3.17 : y = 0.929 : 46.5 secs : initdesign
#
# [mbo] 0: num_iterations=1194; learning_rate=0.0373; feature_fraction=0.618; bagging_fraction=0.758; num_leaves=136; min_data_in_leaf=158; max_depth=11; lambda_l1=0.499; lambda_l2=2 : y = 0.93 : 86.2 secs : initdesign
#
# [mbo] 0: num_iterations=1760; learning_rate=0.0411; feature_fraction=0.529; bagging_fraction=0.922; num_leaves=70; min_data_in_leaf=819; max_depth=7; lambda_l1=4.46; lambda_l2=1.65 : y = 0.931 : 97.7 secs : initdesign
#
# [mbo] 0: num_iterations=1878; learning_rate=0.038; feature_fraction=0.71; bagging_fraction=0.721; num_leaves=98; min_data_in_leaf=306; max_depth=11; lambda_l1=4.42; lambda_l2=4.08 : y = 0.93 : 68.6 secs : initdesign
#
# [mbo] 0: num_iterations=1119; learning_rate=0.028; feature_fraction=0.859; bagging_fraction=0.89; num_leaves=138; min_data_in_leaf=503; max_depth=9; lambda_l1=2.82; lambda_l2=0.955 : y = 0.929 : 52.1 secs : initdesign
#
# [mbo] 0: num_iterations=1242; learning_rate=0.0471; feature_fraction=0.437; bagging_fraction=0.951; num_leaves=113; min_data_in_leaf=548; max_depth=5; lambda_l1=0.884; lambda_l2=2.23 : y = 0.93 : 61.1 secs : initdesign
#
# [mbo] 0: num_iterations=646; learning_rate=0.00912; feature_fraction=0.408; bagging_fraction=0.878; num_leaves=36; min_data_in_leaf=344; max_depth=9; lambda_l1=2.67; lambda_l2=4.21 : y = 0.929 : 37.8 secs : initdesign
#
# [mbo] 0: num_iterations=998; learning_rate=0.0238; feature_fraction=0.7; bagging_fraction=0.807; num_leaves=92; min_data_in_leaf=641; max_depth=4; lambda_l1=4; lambda_l2=3.23 : y = 0.93 : 24.1 secs : initdesign
#
# [mbo] 0: num_iterations=1327; learning_rate=0.0356; feature_fraction=0.497; bagging_fraction=0.658; num_leaves=116; min_data_in_leaf=917; max_depth=3; lambda_l1=2.21; lambda_l2=4.59 : y = 0.928 : 61.4 secs : initdesign
#
# [mbo] 0: num_iterations=773; learning_rate=0.0311; feature_fraction=0.566; bagging_fraction=0.843; num_leaves=88; min_data_in_leaf=265; max_depth=8; lambda_l1=4.24; lambda_l2=0.241 : y = 0.931 : 48.8 secs : initdesign
#
# [mbo] 0: num_iterations=1949; learning_rate=0.043; feature_fraction=0.575; bagging_fraction=0.782; num_leaves=23; min_data_in_leaf=567; max_depth=15; lambda_l1=1.43; lambda_l2=1.9 : y = 0.932 : 95.6 secs : initdesign
#
# [mbo] 0: num_iterations=1868; learning_rate=0.0125; feature_fraction=0.751; bagging_fraction=0.937; num_leaves=142; min_data_in_leaf=629; max_depth=5; lambda_l1=3.65; lambda_l2=1.5 : y = 0.931 : 51.7 secs : initdesign
#
# [mbo] 0: num_iterations=679; learning_rate=0.015; feature_fraction=0.779; bagging_fraction=0.792; num_leaves=33; min_data_in_leaf=586; max_depth=15; lambda_l1=4.8; lambda_l2=3.34 : y = 0.93 : 30.1 secs : initdesign
#
# [mbo] 0: num_iterations=1976; learning_rate=0.0456; feature_fraction=0.889; bagging_fraction=0.963; num_leaves=82; min_data_in_leaf=480; max_depth=12; lambda_l1=3.12; lambda_l2=0.413 : y = 0.929 : 65.9 secs : initdesign
#
# [mbo] 0: num_iterations=844; learning_rate=0.021; feature_fraction=0.673; bagging_fraction=0.649; num_leaves=60; min_data_in_leaf=750; max_depth=14; lambda_l1=1.05; lambda_l2=0.734 : y = 0.93 : 44.4 secs : initdesign
#
# [mbo] 0: num_iterations=1612; learning_rate=0.00712; feature_fraction=0.589; bagging_fraction=0.868; num_leaves=106; min_data_in_leaf=143; max_depth=14; lambda_l1=1.58; lambda_l2=0.517 : y = 0.929 : 129.6 secs : initdesign
#
# [mbo] 0: num_iterations=1552; learning_rate=0.04; feature_fraction=0.624; bagging_fraction=0.771; num_leaves=124; min_data_in_leaf=793; max_depth=9; lambda_l1=0.117; lambda_l2=1.21 : y = 0.929 : 70.9 secs : initdesign
#
# [mbo] 0: num_iterations=1472; learning_rate=0.0482; feature_fraction=0.737; bagging_fraction=0.852; num_leaves=45; min_data_in_leaf=221; max_depth=3; lambda_l1=2.32; lambda_l2=4.51 : y = 0.929 : 29.8 secs : initdesign
#
# [mbo] 0: num_iterations=1150; learning_rate=0.0228; feature_fraction=0.637; bagging_fraction=0.61; num_leaves=126; min_data_in_leaf=206; max_depth=7; lambda_l1=1.92; lambda_l2=3.73 : y = 0.93 : 48.9 secs : initdesign
#
# [mbo] 0: num_iterations=1029; learning_rate=0.0491; feature_fraction=0.838; bagging_fraction=0.726; num_leaves=28; min_data_in_leaf=457; max_depth=14; lambda_l1=2.57; lambda_l2=4.88 : y = 0.929 : 39.4 secs : initdesign
#
# [mbo] 0: num_iterations=1379; learning_rate=0.0127; feature_fraction=0.446; bagging_fraction=0.616; num_leaves=144; min_data_in_leaf=955; max_depth=13; lambda_l1=1.79; lambda_l2=2.84 : y = 0.931 : 89.6 secs : initdesign
#
# [mbo] 0: num_iterations=1632; learning_rate=0.00818; feature_fraction=0.48; bagging_fraction=0.928; num_leaves=51; min_data_in_leaf=889; max_depth=13; lambda_l1=4.16; lambda_l2=1.67 : y = 0.931 : 103.1 secs : initdesign
#
# [mbo] 0: num_iterations=611; learning_rate=0.0256; feature_fraction=0.799; bagging_fraction=0.98; num_leaves=43; min_data_in_leaf=694; max_depth=4; lambda_l1=0.353; lambda_l2=2.65 : y = 0.93 : 14.6 secs : initdesign
#
# [mbo] 0: num_iterations=1365; learning_rate=0.0158; feature_fraction=0.806; bagging_fraction=0.978; num_leaves=41; min_data_in_leaf=125; max_depth=6; lambda_l1=3.52; lambda_l2=0.0513 : y = 0.929 : 49.1 secs : initdesign
#
# [mbo] 0: num_iterations=1255; learning_rate=0.0416; feature_fraction=0.421; bagging_fraction=0.902; num_leaves=118; min_data_in_leaf=424; max_depth=11; lambda_l1=5; lambda_l2=3.8 : y = 0.93 : 73.8 secs : initdesign
#
# [mbo] 0: num_iterations=1668; learning_rate=0.0101; feature_fraction=0.727; bagging_fraction=0.634; num_leaves=20; min_data_in_leaf=928; max_depth=3; lambda_l1=0.735; lambda_l2=4.73 : y = 0.927 : 33.4 secs : initdesign
#
# [mbo] 0: num_iterations=1712; learning_rate=0.0171; feature_fraction=0.854; bagging_fraction=0.996; num_leaves=149; min_data_in_leaf=781; max_depth=15; lambda_l1=2.96; lambda_l2=4.43 : y = 0.93 : 87.2 secs : initdesign
#
# [mbo] 0: num_iterations=528; learning_rate=0.00554; feature_fraction=0.518; bagging_fraction=0.699; num_leaves=79; min_data_in_leaf=990; max_depth=6; lambda_l1=4.67; lambda_l2=2.2 : y = 0.923 : 29.1 secs : initdesign
#
# [mbo] 0: num_iterations=1516; learning_rate=0.0449; feature_fraction=0.873; bagging_fraction=0.624; num_leaves=64; min_data_in_leaf=861; max_depth=6; lambda_l1=3.36; lambda_l2=1.11 : y = 0.93 : 51.4 secs : initdesign
#
# [mbo] 0: num_iterations=913; learning_rate=0.0295; feature_fraction=0.463; bagging_fraction=0.812; num_leaves=53; min_data_in_leaf=99; max_depth=12; lambda_l1=0.249; lambda_l2=2.58 : y = 0.93 : 62.0 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Mon Jul 21 14:26:58 2025 AUC 0.931069197542317
#
# [mbo] 1: num_iterations=2000; learning_rate=0.0426; feature_fraction=0.431; bagging_fraction=0.784; num_leaves=43; min_data_in_leaf=591; max_depth=15; lambda_l1=4.77; lambda_l2=0.87 : y = 0.931 : 100.6 secs : infill_ei
#
# Mon Jul 21 14:28:56 2025 AUC 0.931270839781327
#
# [mbo] 2: num_iterations=1992; learning_rate=0.0263; feature_fraction=0.464; bagging_fraction=0.819; num_leaves=28; min_data_in_leaf=716; max_depth=15; lambda_l1=2.35; lambda_l2=3.45 : y = 0.931 : 117.1 secs : infill_ei
#
# Mon Jul 21 14:31:03 2025 AUC 0.931499531639737
#
# [mbo] 3: num_iterations=1924; learning_rate=0.0144; feature_fraction=0.448; bagging_fraction=0.787; num_leaves=120; min_data_in_leaf=747; max_depth=13; lambda_l1=4.26; lambda_l2=1.55 : y = 0.931 : 125.4 secs : infill_ei
#
# Mon Jul 21 14:33:11 2025 AUC 0.931032604234904
#
# [mbo] 4: num_iterations=1971; learning_rate=0.0171; feature_fraction=0.427; bagging_fraction=0.726; num_leaves=100; min_data_in_leaf=844; max_depth=14; lambda_l1=3.85; lambda_l2=2.31 : y = 0.931 : 127.6 secs : infill_ei
#
# Mon Jul 21 14:34:56 2025 AUC 0.928697069834862
#
# [mbo] 5: num_iterations=1993; learning_rate=0.0388; feature_fraction=0.761; bagging_fraction=0.85; num_leaves=54; min_data_in_leaf=761; max_depth=15; lambda_l1=0.687; lambda_l2=3.28 : y = 0.929 : 103.4 secs : infill_ei
#
# Mon Jul 21 14:36:59 2025 AUC 0.93078058051526
#
# [mbo] 6: num_iterations=1936; learning_rate=0.0127; feature_fraction=0.407; bagging_fraction=0.949; num_leaves=117; min_data_in_leaf=815; max_depth=15; lambda_l1=2.93; lambda_l2=3.06 : y = 0.931 : 121.6 secs : infill_ei
#
# Saved the current state after iteration 7 in the file bayesiana.RDATA.
#
# Mon Jul 21 14:38:56 2025 AUC 0.930880371765803
#
# [mbo] 7: num_iterations=1887; learning_rate=0.0217; feature_fraction=0.515; bagging_fraction=0.725; num_leaves=29; min_data_in_leaf=561; max_depth=14; lambda_l1=3.78; lambda_l2=1.27 : y = 0.931 : 113.1 secs : infill_ei
#
# Mon Jul 21 14:40:56 2025 AUC 0.931234366789599
#
# [mbo] 8: num_iterations=1777; learning_rate=0.0172; feature_fraction=0.486; bagging_fraction=0.935; num_leaves=133; min_data_in_leaf=653; max_depth=11; lambda_l1=4.01; lambda_l2=3.71 : y = 0.931 : 118.4 secs : infill_ei
#
# Mon Jul 21 14:42:44 2025 AUC 0.932187053700125
#
# [mbo] 9: num_iterations=1959; learning_rate=0.0461; feature_fraction=0.494; bagging_fraction=0.737; num_leaves=20; min_data_in_leaf=546; max_depth=14; lambda_l1=2.86; lambda_l2=3.99 : y = 0.932 : 107.1 secs : infill_ei
#
# Mon Jul 21 14:44:33 2025 AUC 0.93165671577315
#
# [mbo] 10: num_iterations=1998; learning_rate=0.0429; feature_fraction=0.401; bagging_fraction=0.673; num_leaves=24; min_data_in_leaf=567; max_depth=8; lambda_l1=2.18; lambda_l2=3.64 : y = 0.932 : 107.0 secs : infill_ei
#
# Mon Jul 21 14:46:18 2025 AUC 0.930778988550186
#
# [mbo] 11: num_iterations=1922; learning_rate=0.0487; feature_fraction=0.469; bagging_fraction=0.864; num_leaves=20; min_data_in_leaf=525; max_depth=11; lambda_l1=1.68; lambda_l2=3.38 : y = 0.931 : 103.6 secs : infill_ei
#
# Mon Jul 21 14:47:55 2025 AUC 0.930658576010891
#
# [mbo] 12: num_iterations=1738; learning_rate=0.0453; feature_fraction=0.502; bagging_fraction=0.628; num_leaves=20; min_data_in_leaf=664; max_depth=15; lambda_l1=3.55; lambda_l2=2.79 : y = 0.931 : 96.6 secs : infill_ei
#
# Saved the current state after iteration 13 in the file bayesiana.RDATA.
#
# Mon Jul 21 14:49:45 2025 AUC 0.930994440275346
#
# [mbo] 13: num_iterations=1993; learning_rate=0.0434; feature_fraction=0.415; bagging_fraction=0.74; num_leaves=20; min_data_in_leaf=480; max_depth=14; lambda_l1=0.708; lambda_l2=4.63 : y = 0.931 : 104.9 secs : infill_ei
#
# Mon Jul 21 14:51:35 2025 AUC 0.93136773674971
#
# [mbo] 14: num_iterations=1998; learning_rate=0.037; feature_fraction=0.445; bagging_fraction=0.7; num_leaves=23; min_data_in_leaf=583; max_depth=11; lambda_l1=4.45; lambda_l2=4.86 : y = 0.931 : 108.2 secs : infill_ei
#
# Mon Jul 21 14:53:30 2025 AUC 0.931072718139386
#
# [mbo] 15: num_iterations=2000; learning_rate=0.0449; feature_fraction=0.517; bagging_fraction=0.674; num_leaves=45; min_data_in_leaf=617; max_depth=8; lambda_l1=3.06; lambda_l2=2.25 : y = 0.931 : 113.7 secs : infill_ei
#
# Mon Jul 21 14:54:59 2025 AUC 0.930113770720651
#
# [mbo] 16: num_iterations=1315; learning_rate=0.0204; feature_fraction=0.408; bagging_fraction=0.832; num_leaves=54; min_data_in_leaf=246; max_depth=15; lambda_l1=3.87; lambda_l2=4.98 : y = 0.93 : 87.6 secs : infill_ei
#
# Mon Jul 21 14:56:40 2025 AUC 0.930900901404612
#
# [mbo] 17: num_iterations=1997; learning_rate=0.0462; feature_fraction=0.547; bagging_fraction=0.945; num_leaves=26; min_data_in_leaf=542; max_depth=14; lambda_l1=4.31; lambda_l2=2.85 : y = 0.931 : 99.4 secs : infill_ei
#
# Mon Jul 21 14:58:56 2025 AUC 0.930578795662803
#
# [mbo] 18: num_iterations=1998; learning_rate=0.027; feature_fraction=0.405; bagging_fraction=0.717; num_leaves=108; min_data_in_leaf=569; max_depth=15; lambda_l1=2.33; lambda_l2=4.14 : y = 0.931 : 134.8 secs : infill_ei
#
# Saved the current state after iteration 19 in the file bayesiana.RDATA.
#
# Mon Jul 21 15:00:48 2025 AUC 0.930066568384435
#
# [mbo] 19: num_iterations=1988; learning_rate=0.0173; feature_fraction=0.42; bagging_fraction=0.994; num_leaves=20; min_data_in_leaf=732; max_depth=12; lambda_l1=3.62; lambda_l2=2.19 : y = 0.93 : 107.1 secs : infill_ei
#
# Mon Jul 21 15:02:20 2025 AUC 0.931382376834191
#
# [mbo] 20: num_iterations=1332; learning_rate=0.0119; feature_fraction=0.515; bagging_fraction=0.805; num_leaves=150; min_data_in_leaf=716; max_depth=13; lambda_l1=2.94; lambda_l2=4.04 : y = 0.931 : 90.6 secs : infill_ei
#
# Mon Jul 21 15:04:12 2025 AUC 0.931172845823847
#
# [mbo] 21: num_iterations=1615; learning_rate=0.0169; feature_fraction=0.486; bagging_fraction=0.708; num_leaves=148; min_data_in_leaf=683; max_depth=15; lambda_l1=3.61; lambda_l2=1.63 : y = 0.931 : 110.9 secs : infill_ei
#
# Mon Jul 21 15:06:01 2025 AUC 0.929660294926387
#
# [mbo] 22: num_iterations=1734; learning_rate=0.0118; feature_fraction=0.553; bagging_fraction=0.892; num_leaves=138; min_data_in_leaf=954; max_depth=13; lambda_l1=4.97; lambda_l2=0.419 : y = 0.93 : 107.7 secs : infill_ei
#
# Mon Jul 21 15:07:47 2025 AUC 0.929962046972333
#
# [mbo] 23: num_iterations=1655; learning_rate=0.00618; feature_fraction=0.447; bagging_fraction=0.793; num_leaves=134; min_data_in_leaf=703; max_depth=13; lambda_l1=3.68; lambda_l2=4.82 : y = 0.93 : 104.3 secs : infill_ei
#
# Mon Jul 21 15:09:29 2025 AUC 0.930928761023441
#
# [mbo] 24: num_iterations=1927; learning_rate=0.043; feature_fraction=0.47; bagging_fraction=0.756; num_leaves=20; min_data_in_leaf=362; max_depth=9; lambda_l1=4.62; lambda_l2=3.79 : y = 0.931 : 100.4 secs : infill_ei
#
# Saved the current state after iteration 25 in the file bayesiana.RDATA.
#
# Mon Jul 21 15:11:07 2025 AUC 0.930800918090605
#
# [mbo] 25: num_iterations=1424; learning_rate=0.0167; feature_fraction=0.465; bagging_fraction=0.868; num_leaves=125; min_data_in_leaf=770; max_depth=13; lambda_l1=2.68; lambda_l2=1.24 : y = 0.931 : 93.8 secs : infill_ei
#
# Mon Jul 21 15:12:55 2025 AUC 0.930971251607146
#
# [mbo] 26: num_iterations=2000; learning_rate=0.047; feature_fraction=0.564; bagging_fraction=0.724; num_leaves=34; min_data_in_leaf=538; max_depth=15; lambda_l1=2.88; lambda_l2=4.1 : y = 0.931 : 106.3 secs : infill_ei
#
# Mon Jul 21 15:15:01 2025 AUC 0.930408567496187
#
# [mbo] 27: num_iterations=1948; learning_rate=0.0154; feature_fraction=0.565; bagging_fraction=0.699; num_leaves=149; min_data_in_leaf=702; max_depth=12; lambda_l1=0.708; lambda_l2=3.72 : y = 0.93 : 125.3 secs : infill_ei
#
# Mon Jul 21 15:16:41 2025 AUC 0.930341386826956
#
# [mbo] 28: num_iterations=1591; learning_rate=0.0278; feature_fraction=0.468; bagging_fraction=0.951; num_leaves=62; min_data_in_leaf=739; max_depth=13; lambda_l1=4.78; lambda_l2=2.8 : y = 0.93 : 98.2 secs : infill_ei
#
# Mon Jul 21 15:18:29 2025 AUC 0.930684859878486
#
# [mbo] 29: num_iterations=1989; learning_rate=0.0415; feature_fraction=0.466; bagging_fraction=0.79; num_leaves=20; min_data_in_leaf=473; max_depth=14; lambda_l1=2.78; lambda_l2=1.99 : y = 0.931 : 106.6 secs : infill_ei
#
# Mon Jul 21 15:19:44 2025 AUC 0.930067763331769
#
# [mbo] 30: num_iterations=1332; learning_rate=0.0455; feature_fraction=0.479; bagging_fraction=0.76; num_leaves=20; min_data_in_leaf=628; max_depth=10; lambda_l1=3.1; lambda_l2=3.9 : y = 0.93 : 73.3 secs : infill_ei
#
# Saved the current state after iteration 31 in the file bayesiana.RDATA.
#
# Mon Jul 21 15:21:37 2025 AUC 0.930780163297893
#
# [mbo] 31: num_iterations=1954; learning_rate=0.0443; feature_fraction=0.43; bagging_fraction=0.637; num_leaves=24; min_data_in_leaf=767; max_depth=15; lambda_l1=3.48; lambda_l2=4.13 : y = 0.931 : 108.2 secs : infill_ei
#
# Mon Jul 21 15:23:31 2025 AUC 0.929883011593431
#
# [mbo] 32: num_iterations=1993; learning_rate=0.0463; feature_fraction=0.5; bagging_fraction=0.775; num_leaves=21; min_data_in_leaf=782; max_depth=14; lambda_l1=1.45; lambda_l2=1.56 : y = 0.93 : 111.7 secs : infill_ei
#
# Mon Jul 21 15:25:34 2025 AUC 0.931029001495069
#
# [mbo] 33: num_iterations=1973; learning_rate=0.0385; feature_fraction=0.493; bagging_fraction=0.687; num_leaves=69; min_data_in_leaf=523; max_depth=13; lambda_l1=3.43; lambda_l2=4.11 : y = 0.931 : 121.6 secs : infill_ei
#
# Mon Jul 21 15:27:18 2025 AUC 0.931293997786157
#
# [mbo] 34: num_iterations=1658; learning_rate=0.0132; feature_fraction=0.488; bagging_fraction=0.802; num_leaves=33; min_data_in_leaf=699; max_depth=14; lambda_l1=3.47; lambda_l2=4.9 : y = 0.931 : 102.7 secs : infill_ei
#
# Mon Jul 21 15:28:37 2025 AUC 0.930526592321691
#
# [mbo] 35: num_iterations=1121; learning_rate=0.0145; feature_fraction=0.498; bagging_fraction=0.727; num_leaves=88; min_data_in_leaf=624; max_depth=14; lambda_l1=4.65; lambda_l2=3.48 : y = 0.931 : 77.2 secs : infill_ei
#
# Mon Jul 21 15:30:22 2025 AUC 0.931887935926264
#
# [mbo] 36: num_iterations=1959; learning_rate=0.0404; feature_fraction=0.488; bagging_fraction=0.809; num_leaves=21; min_data_in_leaf=554; max_depth=6; lambda_l1=4.43; lambda_l2=1.7 : y = 0.932 : 103.6 secs : infill_ei
#
# Saved the current state after iteration 37 in the file bayesiana.RDATA.
#
# Mon Jul 21 15:32:09 2025 AUC 0.930536331147048
#
# [mbo] 37: num_iterations=1933; learning_rate=0.0162; feature_fraction=0.5; bagging_fraction=0.831; num_leaves=20; min_data_in_leaf=611; max_depth=5; lambda_l1=4.26; lambda_l2=3.89 : y = 0.931 : 99.6 secs : infill_ei
#
# Mon Jul 21 15:33:56 2025 AUC 0.930879288616812
#
# [mbo] 38: num_iterations=1946; learning_rate=0.036; feature_fraction=0.503; bagging_fraction=0.815; num_leaves=20; min_data_in_leaf=422; max_depth=14; lambda_l1=0.737; lambda_l2=4.47 : y = 0.931 : 106.3 secs : infill_ei
#
# Mon Jul 21 15:36:03 2025 AUC 0.931124981816601
#
# [mbo] 39: num_iterations=1853; learning_rate=0.0228; feature_fraction=0.492; bagging_fraction=0.792; num_leaves=97; min_data_in_leaf=735; max_depth=13; lambda_l1=3.94; lambda_l2=3.83 : y = 0.931 : 125.0 secs : infill_ei
#
# Mon Jul 21 15:37:46 2025 AUC 0.930166572949927
#
# [mbo] 40: num_iterations=1995; learning_rate=0.037; feature_fraction=0.43; bagging_fraction=0.649; num_leaves=21; min_data_in_leaf=555; max_depth=7; lambda_l1=4.81; lambda_l2=0.346 : y = 0.93 : 101.8 secs : infill_ei
#
# Mon Jul 21 15:39:34 2025 AUC 0.93146926511406
#
# [mbo] 41: num_iterations=1897; learning_rate=0.0423; feature_fraction=0.509; bagging_fraction=0.761; num_leaves=20; min_data_in_leaf=572; max_depth=14; lambda_l1=2.46; lambda_l2=4.74 : y = 0.931 : 105.7 secs : infill_ei
#
# Mon Jul 21 15:41:19 2025 AUC 0.931388924240471
#
# [mbo] 42: num_iterations=1968; learning_rate=0.043; feature_fraction=0.473; bagging_fraction=0.93; num_leaves=111; min_data_in_leaf=564; max_depth=5; lambda_l1=4.11; lambda_l2=1.61 : y = 0.931 : 102.9 secs : infill_ei
#
# Saved the current state after iteration 43 in the file bayesiana.RDATA.
#
# Mon Jul 21 15:42:54 2025 AUC 0.929382428855845
#
# [mbo] 43: num_iterations=1958; learning_rate=0.0444; feature_fraction=0.486; bagging_fraction=0.844; num_leaves=41; min_data_in_leaf=578; max_depth=3; lambda_l1=4.91; lambda_l2=3.76 : y = 0.929 : 90.1 secs : infill_ei
#
# Mon Jul 21 15:44:40 2025 AUC 0.930226896893546
#
# [mbo] 44: num_iterations=1841; learning_rate=0.0294; feature_fraction=0.487; bagging_fraction=0.884; num_leaves=21; min_data_in_leaf=364; max_depth=15; lambda_l1=2.71; lambda_l2=3.94 : y = 0.93 : 104.1 secs : infill_ei
#
# Mon Jul 21 15:46:37 2025 AUC 0.930570958989497
#
# [mbo] 45: num_iterations=1903; learning_rate=0.0397; feature_fraction=0.496; bagging_fraction=0.925; num_leaves=73; min_data_in_leaf=540; max_depth=7; lambda_l1=2.32; lambda_l2=2.66 : y = 0.931 : 114.9 secs : infill_ei
#
# Mon Jul 21 15:47:40 2025 AUC 0.929958322927025
#
# [mbo] 46: num_iterations=1952; learning_rate=0.0362; feature_fraction=0.642; bagging_fraction=0.697; num_leaves=58; min_data_in_leaf=628; max_depth=5; lambda_l1=4.25; lambda_l2=1.54 : y = 0.93 : 61.9 secs : infill_ei
#
# Mon Jul 21 15:49:35 2025 AUC 0.930506161468165
#
# [mbo] 47: num_iterations=1996; learning_rate=0.0432; feature_fraction=0.505; bagging_fraction=0.912; num_leaves=31; min_data_in_leaf=187; max_depth=6; lambda_l1=2.84; lambda_l2=1.33 : y = 0.931 : 112.6 secs : infill_ei
#
# Mon Jul 21 15:51:50 2025 AUC 0.93007411941465
#
# [mbo] 48: num_iterations=1964; learning_rate=0.0109; feature_fraction=0.526; bagging_fraction=0.828; num_leaves=74; min_data_in_leaf=734; max_depth=15; lambda_l1=4.7; lambda_l2=1.8 : y = 0.93 : 133.7 secs : infill_ei
#
# Saved the current state after iteration 49 in the file bayesiana.RDATA.
#
# Mon Jul 21 15:53:29 2025 AUC 0.931607304968762
#
# [mbo] 49: num_iterations=1392; learning_rate=0.0138; feature_fraction=0.505; bagging_fraction=0.937; num_leaves=44; min_data_in_leaf=863; max_depth=13; lambda_l1=2.47; lambda_l2=4.41 : y = 0.932 : 90.9 secs : infill_ei
#
# Mon Jul 21 15:55:27 2025 AUC 0.930899447728881
#
# [mbo] 50: num_iterations=1993; learning_rate=0.0183; feature_fraction=0.466; bagging_fraction=0.9; num_leaves=41; min_data_in_leaf=595; max_depth=7; lambda_l1=4.95; lambda_l2=1.67 : y = 0.931 : 116.4 secs : infill_ei
#
# Mon Jul 21 15:57:32 2025 AUC 0.930817850960066
#
# [mbo] 51: num_iterations=2000; learning_rate=0.0393; feature_fraction=0.445; bagging_fraction=0.702; num_leaves=26; min_data_in_leaf=597; max_depth=6; lambda_l1=2.75; lambda_l2=2.1 : y = 0.931 : 122.9 secs : infill_ei
#
# Mon Jul 21 15:58:56 2025 AUC 0.930045379337507
#
# [mbo] 52: num_iterations=1364; learning_rate=0.0159; feature_fraction=0.409; bagging_fraction=0.79; num_leaves=27; min_data_in_leaf=812; max_depth=14; lambda_l1=1.44; lambda_l2=4.06 : y = 0.93 : 82.2 secs : infill_ei
#
# Mon Jul 21 16:01:00 2025 AUC 0.930852987407845
#
# [mbo] 53: num_iterations=1938; learning_rate=0.015; feature_fraction=0.51; bagging_fraction=0.978; num_leaves=31; min_data_in_leaf=693; max_depth=14; lambda_l1=0.75; lambda_l2=4.28 : y = 0.931 : 121.9 secs : infill_ei
#
# Mon Jul 21 16:02:57 2025 AUC 0.930975685195103
#
# [mbo] 54: num_iterations=1984; learning_rate=0.0322; feature_fraction=0.488; bagging_fraction=0.678; num_leaves=132; min_data_in_leaf=743; max_depth=7; lambda_l1=4.5; lambda_l2=1.59 : y = 0.931 : 114.3 secs : infill_ei
#
# Saved the current state after iteration 55 in the file bayesiana.RDATA.
#
# Mon Jul 21 16:04:47 2025 AUC 0.930573519977247
#
# [mbo] 55: num_iterations=2000; learning_rate=0.0341; feature_fraction=0.532; bagging_fraction=0.826; num_leaves=25; min_data_in_leaf=519; max_depth=7; lambda_l1=4.95; lambda_l2=1.43 : y = 0.931 : 104.7 secs : infill_ei
#
# Mon Jul 21 16:06:34 2025 AUC 0.931366111250255
#
# [mbo] 56: num_iterations=1998; learning_rate=0.0492; feature_fraction=0.485; bagging_fraction=0.859; num_leaves=25; min_data_in_leaf=548; max_depth=15; lambda_l1=4.19; lambda_l2=4.37 : y = 0.931 : 105.1 secs : infill_ei
#
# Mon Jul 21 16:08:24 2025 AUC 0.930501834255293
#
# [mbo] 57: num_iterations=1657; learning_rate=0.0221; feature_fraction=0.494; bagging_fraction=0.946; num_leaves=100; min_data_in_leaf=888; max_depth=15; lambda_l1=4.43; lambda_l2=4.26 : y = 0.931 : 108.1 secs : infill_ei
#
# Mon Jul 21 16:09:51 2025 AUC 0.93114675400527
#
# [mbo] 58: num_iterations=1487; learning_rate=0.0158; feature_fraction=0.518; bagging_fraction=0.731; num_leaves=23; min_data_in_leaf=573; max_depth=11; lambda_l1=3.98; lambda_l2=4.66 : y = 0.931 : 84.9 secs : infill_ei
#
# Mon Jul 21 16:11:56 2025 AUC 0.930206760242718
#
# [mbo] 59: num_iterations=1987; learning_rate=0.0241; feature_fraction=0.462; bagging_fraction=0.637; num_leaves=43; min_data_in_leaf=581; max_depth=9; lambda_l1=1.27; lambda_l2=4.57 : y = 0.93 : 123.2 secs : infill_ei
#
# Mon Jul 21 16:13:38 2025 AUC 0.930827584224246
#
# [mbo] 60: num_iterations=1993; learning_rate=0.046; feature_fraction=0.479; bagging_fraction=0.685; num_leaves=65; min_data_in_leaf=571; max_depth=7; lambda_l1=4.95; lambda_l2=1.56 : y = 0.931 : 100.3 secs : infill_ei
#
# Saved the current state after iteration 61 in the file bayesiana.RDATA.
#
# Mon Jul 21 16:15:26 2025 AUC 0.931390270673068
#
# [mbo] 61: num_iterations=1901; learning_rate=0.0459; feature_fraction=0.485; bagging_fraction=0.859; num_leaves=28; min_data_in_leaf=567; max_depth=9; lambda_l1=4.2; lambda_l2=1.7 : y = 0.931 : 100.3 secs : infill_ei
#
# Mon Jul 21 16:17:40 2025 AUC 0.930371972163966
#
# [mbo] 62: num_iterations=1993; learning_rate=0.0231; feature_fraction=0.447; bagging_fraction=0.786; num_leaves=114; min_data_in_leaf=320; max_depth=15; lambda_l1=3.94; lambda_l2=1.49 : y = 0.93 : 132.0 secs : infill_ei
#
# Mon Jul 21 16:19:45 2025 AUC 0.930756702266525
#
# [mbo] 63: num_iterations=1810; learning_rate=0.0198; feature_fraction=0.557; bagging_fraction=0.809; num_leaves=104; min_data_in_leaf=400; max_depth=10; lambda_l1=4.46; lambda_l2=4.45 : y = 0.931 : 123.4 secs : infill_ei
#
# Mon Jul 21 16:21:53 2025 AUC 0.93162933101308
#
# [mbo] 64: num_iterations=1964; learning_rate=0.0168; feature_fraction=0.478; bagging_fraction=0.954; num_leaves=150; min_data_in_leaf=824; max_depth=10; lambda_l1=4.09; lambda_l2=1.84 : y = 0.932 : 126.3 secs : infill_ei
#
# Mon Jul 21 16:23:54 2025 AUC 0.930445045557249
#
# [mbo] 65: num_iterations=1988; learning_rate=0.03; feature_fraction=0.449; bagging_fraction=0.898; num_leaves=150; min_data_in_leaf=684; max_depth=9; lambda_l1=3.94; lambda_l2=1.53 : y = 0.93 : 118.0 secs : infill_ei
#
# Saved the current state after iteration 66 in the file bayesiana.RDATA.
#
# Mon Jul 21 16:26:01 2025 AUC 0.930357579640027
#
# [mbo] 66: num_iterations=1879; learning_rate=0.0152; feature_fraction=0.489; bagging_fraction=0.709; num_leaves=89; min_data_in_leaf=959; max_depth=14; lambda_l1=2.54; lambda_l2=3.18 : y = 0.93 : 120.7 secs : infill_ei
#
# Mon Jul 21 16:27:39 2025 AUC 0.93106309692982
#
# [mbo] 67: num_iterations=1344; learning_rate=0.0145; feature_fraction=0.551; bagging_fraction=0.933; num_leaves=90; min_data_in_leaf=515; max_depth=14; lambda_l1=2.11; lambda_l2=4.39 : y = 0.931 : 97.1 secs : infill_ei
#
# Mon Jul 21 16:29:25 2025 AUC 0.930933640758505
#
# [mbo] 68: num_iterations=1564; learning_rate=0.0131; feature_fraction=0.513; bagging_fraction=0.962; num_leaves=134; min_data_in_leaf=835; max_depth=12; lambda_l1=3.65; lambda_l2=3.86 : y = 0.931 : 103.4 secs : infill_ei
#
# Mon Jul 21 16:30:53 2025 AUC 0.930598898301746
#
# [mbo] 69: num_iterations=1248; learning_rate=0.0142; feature_fraction=0.502; bagging_fraction=0.867; num_leaves=103; min_data_in_leaf=706; max_depth=13; lambda_l1=0.382; lambda_l2=4.98 : y = 0.931 : 85.7 secs : infill_ei
#
# Mon Jul 21 16:32:28 2025 AUC 0.930378270355258
#
# [mbo] 70: num_iterations=1786; learning_rate=0.0191; feature_fraction=0.491; bagging_fraction=0.755; num_leaves=23; min_data_in_leaf=493; max_depth=5; lambda_l1=4.74; lambda_l2=1.67 : y = 0.93 : 93.1 secs : infill_ei
#
# Mon Jul 21 16:34:02 2025 AUC 0.931461570464327
#
# [mbo] 71: num_iterations=1685; learning_rate=0.0397; feature_fraction=0.48; bagging_fraction=0.883; num_leaves=20; min_data_in_leaf=553; max_depth=8; lambda_l1=5; lambda_l2=1.77 : y = 0.931 : 91.6 secs : infill_ei
#
# Saved the current state after iteration 72 in the file bayesiana.RDATA.
#
# Mon Jul 21 16:35:47 2025 AUC 0.931416577593049
#
# [mbo] 72: num_iterations=1862; learning_rate=0.0421; feature_fraction=0.554; bagging_fraction=0.842; num_leaves=21; min_data_in_leaf=546; max_depth=15; lambda_l1=3.46; lambda_l2=0.561 : y = 0.931 : 98.1 secs : infill_ei
#
# Mon Jul 21 16:37:05 2025 AUC 0.930754417944196
#
# [mbo] 73: num_iterations=1072; learning_rate=0.0201; feature_fraction=0.572; bagging_fraction=0.757; num_leaves=150; min_data_in_leaf=478; max_depth=14; lambda_l1=3.32; lambda_l2=4.28 : y = 0.931 : 75.9 secs : infill_ei
#
# Mon Jul 21 16:39:18 2025 AUC 0.930708616022083
#
# [mbo] 74: num_iterations=1901; learning_rate=0.0154; feature_fraction=0.479; bagging_fraction=0.717; num_leaves=149; min_data_in_leaf=588; max_depth=10; lambda_l1=4.15; lambda_l2=1.93 : y = 0.931 : 130.8 secs : infill_ei
#
# Mon Jul 21 16:40:08 2025 AUC 0.930834399228166
#
# [mbo] 75: num_iterations=906; learning_rate=0.0386; feature_fraction=0.566; bagging_fraction=0.631; num_leaves=23; min_data_in_leaf=300; max_depth=15; lambda_l1=3.68; lambda_l2=0.308 : y = 0.931 : 48.0 secs : infill_ei
#
# Mon Jul 21 16:42:35 2025 AUC 0.930275122983499
#
# [mbo] 76: num_iterations=1991; learning_rate=0.0481; feature_fraction=0.504; bagging_fraction=0.713; num_leaves=128; min_data_in_leaf=578; max_depth=15; lambda_l1=1.33; lambda_l2=3.87 : y = 0.93 : 143.8 secs : infill_ei
#
# Mon Jul 21 16:43:53 2025 AUC 0.930904957654629
#
# [mbo] 77: num_iterations=1514; learning_rate=0.0154; feature_fraction=0.58; bagging_fraction=0.848; num_leaves=20; min_data_in_leaf=674; max_depth=13; lambda_l1=3.39; lambda_l2=4.44 : y = 0.931 : 75.6 secs : infill_ei
#
# Mon Jul 21 16:45:30 2025 AUC 0.93075791111512
#
# [mbo] 78: num_iterations=1789; learning_rate=0.0417; feature_fraction=0.502; bagging_fraction=0.948; num_leaves=29; min_data_in_leaf=572; max_depth=5; lambda_l1=2.41; lambda_l2=0.431 : y = 0.931 : 94.5 secs : infill_ei
#
# Saved the current state after iteration 79 in the file bayesiana.RDATA.
#
# Mon Jul 21 16:47:04 2025 AUC 0.930559047891051
#
# [mbo] 79: num_iterations=1836; learning_rate=0.043; feature_fraction=0.577; bagging_fraction=0.685; num_leaves=21; min_data_in_leaf=460; max_depth=13; lambda_l1=4; lambda_l2=1.66 : y = 0.931 : 86.5 secs : infill_ei
#
# Mon Jul 21 16:48:41 2025 AUC 0.929539936105541
#
# [mbo] 80: num_iterations=1991; learning_rate=0.0387; feature_fraction=0.575; bagging_fraction=0.76; num_leaves=23; min_data_in_leaf=536; max_depth=15; lambda_l1=0.887; lambda_l2=0.158 : y = 0.93 : 95.4 secs : infill_ei
#
# Mon Jul 21 16:50:43 2025 AUC 0.929680665587215
#
# [mbo] 81: num_iterations=1787; learning_rate=0.013; feature_fraction=0.472; bagging_fraction=0.974; num_leaves=118; min_data_in_leaf=883; max_depth=13; lambda_l1=1.67; lambda_l2=1.73 : y = 0.93 : 119.7 secs : infill_ei
#
# Mon Jul 21 16:52:30 2025 AUC 0.930375017230064
#
# [mbo] 82: num_iterations=1460; learning_rate=0.0169; feature_fraction=0.503; bagging_fraction=0.725; num_leaves=61; min_data_in_leaf=695; max_depth=15; lambda_l1=2.53; lambda_l2=4.08 : y = 0.93 : 103.6 secs : infill_ei
#
# Mon Jul 21 16:54:14 2025 AUC 0.93080847673088
#
# [mbo] 83: num_iterations=1842; learning_rate=0.0341; feature_fraction=0.449; bagging_fraction=0.767; num_leaves=20; min_data_in_leaf=565; max_depth=14; lambda_l1=4.24; lambda_l2=3.51 : y = 0.931 : 101.4 secs : infill_ei
#
# Mon Jul 21 16:55:32 2025 AUC 0.931621664630354
#
# [mbo] 84: num_iterations=1416; learning_rate=0.0398; feature_fraction=0.41; bagging_fraction=0.691; num_leaves=20; min_data_in_leaf=544; max_depth=8; lambda_l1=2.85; lambda_l2=4.92 : y = 0.932 : 75.0 secs : infill_ei
#
# Mon Jul 21 16:57:15 2025 AUC 0.930585587125913
#
# [mbo] 85: num_iterations=1640; learning_rate=0.0331; feature_fraction=0.486; bagging_fraction=0.745; num_leaves=38; min_data_in_leaf=608; max_depth=8; lambda_l1=3.56; lambda_l2=1.42 : y = 0.931 : 100.4 secs : infill_ei
#
# Saved the current state after iteration 86 in the file bayesiana.RDATA.
#
# Mon Jul 21 16:59:11 2025 AUC 0.930185004571269
#
# [mbo] 86: num_iterations=1714; learning_rate=0.0155; feature_fraction=0.411; bagging_fraction=0.815; num_leaves=150; min_data_in_leaf=783; max_depth=12; lambda_l1=4.37; lambda_l2=3.82 : y = 0.93 : 107.6 secs : infill_ei
#
# Mon Jul 21 17:01:01 2025 AUC 0.930508649606835
#
# [mbo] 87: num_iterations=1890; learning_rate=0.0464; feature_fraction=0.491; bagging_fraction=0.736; num_leaves=21; min_data_in_leaf=323; max_depth=15; lambda_l1=2.56; lambda_l2=4.05 : y = 0.931 : 106.8 secs : infill_ei
#
# Mon Jul 21 17:02:55 2025 AUC 0.930595000445238
#
# [mbo] 88: num_iterations=1997; learning_rate=0.0413; feature_fraction=0.401; bagging_fraction=0.816; num_leaves=27; min_data_in_leaf=286; max_depth=8; lambda_l1=3.08; lambda_l2=4.73 : y = 0.931 : 111.5 secs : infill_ei
#
# Mon Jul 21 17:04:32 2025 AUC 0.930372499573952
#
# [mbo] 89: num_iterations=1765; learning_rate=0.0439; feature_fraction=0.423; bagging_fraction=0.736; num_leaves=21; min_data_in_leaf=589; max_depth=8; lambda_l1=4.15; lambda_l2=3.27 : y = 0.93 : 94.8 secs : infill_ei
#
# Mon Jul 21 17:06:30 2025 AUC 0.929703665234853
#
# [mbo] 90: num_iterations=1902; learning_rate=0.0458; feature_fraction=0.411; bagging_fraction=0.658; num_leaves=65; min_data_in_leaf=544; max_depth=14; lambda_l1=2.84; lambda_l2=4.79 : y = 0.93 : 115.0 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "num_iterations"   "learning_rate"    "feature_fraction" "bagging_fraction"
#  [5] "num_leaves"       "min_data_in_leaf" "max_depth"        "lambda_l1"
#  [9] "lambda_l2"        "y"                "dob"              "eol"
# [13] "error.message"    "exec.time"        "ei"               "error.model"
# [17] "train.time"       "prop.type"        "propose.time"     "se"
# [21] "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    num_iterations learning_rate feature_fraction bagging_fraction num_leaves
#             <int>         <num>            <num>            <num>      <int>
# 1:           1959    0.04610846        0.4942253        0.7370137         20
#    min_data_in_leaf max_depth lambda_l1 lambda_l2
#               <int>     <int>     <num>     <num>
# 1:              546        14  2.862272  3.985881
# [1] 0.9321871

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 100887
#
# $max_depth
# [1] 14
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 2.862272
#
# $lambda_l2
# [1] 3.985881
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 0.7370137
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1959
#
# $learning_rate
# [1] 0.04610846
#
# $feature_fraction
# [1] 0.4942253
#
# $num_leaves
# [1] 20
#
# $min_data_in_leaf
# [1] 546

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Jul 21 17:19:53 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
