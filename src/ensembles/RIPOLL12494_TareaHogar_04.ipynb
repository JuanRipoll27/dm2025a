# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# Esta Tarea para el Hogar 02 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el viernes 01-agosto

# %% [markdown]
# ##  1. Cazatalentos

# %% [markdown]
# En la Clase 03 nos hemos enfrentado a  "La Maldicion del Ganandor",  elegir el modelo con el mejor puntaje simple no suele ser la mejor estrategia.
# <br> Lea y ejecute el notebook  **src/CazaTalentos/CazaTalentos.ipynb**
# <br> en caso de interesarle, participe del Desafío Ordenamiento  que vence el sábado 02 de agosto a las 19:00

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dm"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dm" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/itba2025-8d0a/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Jul 24 16:03:56 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  656930 35.1 1439371    76.9 1431354  76.5
# Vcells 1224847  9.4 8388608    64.0 1924958  14.7

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 4951
PARAM$semilla_primigenia <- 100887

# %%
PARAM$kaggle$competencia <- "data-mining-analista-sr-2025-a"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
makeNumericParam("learning_rate", lower = 0.01, upper = 0.015),
makeNumericParam("feature_fraction", lower = 0.30, upper = 0.37),
makeNumericParam("bagging_fraction", lower = 0.75, upper = 0.85),
makeIntegerParam("num_leaves", lower = 20L, upper = 35L),
makeIntegerParam("min_data_in_leaf", lower = 700L, upper = 760L),
makeNumericParam("lambda_l2", lower = 0.0, upper = 5.0)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 80 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83368
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Thu Jul 24 16:07:19 2025 AUC 0.930898851520791
#
# Thu Jul 24 16:08:21 2025 AUC 0.930710270179325
#
# Thu Jul 24 16:09:19 2025 AUC 0.930999129573791
#
# Thu Jul 24 16:10:21 2025 AUC 0.931087716911893
#
# Thu Jul 24 16:11:21 2025 AUC 0.930173119105493
#
# Thu Jul 24 16:12:25 2025 AUC 0.931120062321872
#
# Thu Jul 24 16:13:30 2025 AUC 0.931596155425725
#
# Thu Jul 24 16:14:33 2025 AUC 0.930910767581916
#
# Thu Jul 24 16:15:34 2025 AUC 0.930584153790085
#
# Thu Jul 24 16:16:35 2025 AUC 0.9302948218223
#
# Thu Jul 24 16:17:34 2025 AUC 0.931562951862552
#
# Thu Jul 24 16:18:39 2025 AUC 0.930253417470052
#
# Thu Jul 24 16:19:38 2025 AUC 0.930848657972203
#
# Thu Jul 24 16:20:40 2025 AUC 0.93043810416653
#
# Thu Jul 24 16:21:38 2025 AUC 0.930580749132731
#
# Thu Jul 24 16:22:39 2025 AUC 0.931251293036288
#
# Thu Jul 24 16:23:45 2025 AUC 0.9314424565925
#
# Thu Jul 24 16:24:46 2025 AUC 0.931141913548401
#
# Thu Jul 24 16:25:49 2025 AUC 0.930486941748223
#
# Thu Jul 24 16:26:52 2025 AUC 0.930929026260985
#
# Thu Jul 24 16:27:49 2025 AUC 0.930621840793404
#
# Thu Jul 24 16:28:54 2025 AUC 0.930699813920641
#
# Thu Jul 24 16:29:54 2025 AUC 0.930229137618654
#
# Thu Jul 24 16:30:57 2025 AUC 0.93091558278812
#
# [mbo] 0: learning_rate=0.0133; feature_fraction=0.342; bagging_fraction=0.811; num_leaves=24; min_data_in_leaf=710; lambda_l2=1.42 : y = 0.931 : 59.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0122; feature_fraction=0.349; bagging_fraction=0.84; num_leaves=26; min_data_in_leaf=747; lambda_l2=2.87 : y = 0.931 : 61.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0116; feature_fraction=0.345; bagging_fraction=0.794; num_leaves=20; min_data_in_leaf=735; lambda_l2=0.881 : y = 0.931 : 58.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0105; feature_fraction=0.314; bagging_fraction=0.787; num_leaves=32; min_data_in_leaf=755; lambda_l2=3.18 : y = 0.931 : 61.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0139; feature_fraction=0.337; bagging_fraction=0.774; num_leaves=28; min_data_in_leaf=722; lambda_l2=4.13 : y = 0.93 : 59.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0136; feature_fraction=0.321; bagging_fraction=0.818; num_leaves=33; min_data_in_leaf=730; lambda_l2=2.17 : y = 0.931 : 64.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0123; feature_fraction=0.307; bagging_fraction=0.797; num_leaves=34; min_data_in_leaf=734; lambda_l2=0.738 : y = 0.932 : 64.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0129; feature_fraction=0.364; bagging_fraction=0.781; num_leaves=23; min_data_in_leaf=727; lambda_l2=3.89 : y = 0.931 : 62.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0142; feature_fraction=0.32; bagging_fraction=0.769; num_leaves=25; min_data_in_leaf=715; lambda_l2=0.441 : y = 0.931 : 60.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0132; feature_fraction=0.309; bagging_fraction=0.792; num_leaves=30; min_data_in_leaf=744; lambda_l2=3.37 : y = 0.93 : 61.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.01; feature_fraction=0.323; bagging_fraction=0.814; num_leaves=24; min_data_in_leaf=702; lambda_l2=1.68 : y = 0.932 : 59.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0108; feature_fraction=0.354; bagging_fraction=0.75; num_leaves=33; min_data_in_leaf=730; lambda_l2=3.11 : y = 0.93 : 64.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0117; feature_fraction=0.369; bagging_fraction=0.824; num_leaves=20; min_data_in_leaf=705; lambda_l2=3.64 : y = 0.931 : 59.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0126; feature_fraction=0.366; bagging_fraction=0.803; num_leaves=27; min_data_in_leaf=755; lambda_l2=2.04 : y = 0.93 : 61.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0112; feature_fraction=0.302; bagging_fraction=0.755; num_leaves=23; min_data_in_leaf=718; lambda_l2=4.33 : y = 0.931 : 58.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.011; feature_fraction=0.33; bagging_fraction=0.835; num_leaves=26; min_data_in_leaf=749; lambda_l2=0.00152 : y = 0.931 : 60.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0148; feature_fraction=0.361; bagging_fraction=0.762; num_leaves=35; min_data_in_leaf=739; lambda_l2=1.1 : y = 0.931 : 65.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.013; feature_fraction=0.304; bagging_fraction=0.805; num_leaves=30; min_data_in_leaf=701; lambda_l2=1.47 : y = 0.931 : 60.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0145; feature_fraction=0.357; bagging_fraction=0.846; num_leaves=31; min_data_in_leaf=752; lambda_l2=4.67 : y = 0.93 : 63.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0141; feature_fraction=0.352; bagging_fraction=0.847; num_leaves=29; min_data_in_leaf=709; lambda_l2=2.55 : y = 0.931 : 62.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0146; feature_fraction=0.328; bagging_fraction=0.777; num_leaves=21; min_data_in_leaf=741; lambda_l2=2.43 : y = 0.931 : 57.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0103; feature_fraction=0.317; bagging_fraction=0.831; num_leaves=34; min_data_in_leaf=722; lambda_l2=4.41 : y = 0.931 : 65.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0119; feature_fraction=0.333; bagging_fraction=0.828; num_leaves=22; min_data_in_leaf=759; lambda_l2=4.93 : y = 0.93 : 60.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0115; feature_fraction=0.34; bagging_fraction=0.764; num_leaves=28; min_data_in_leaf=715; lambda_l2=0.29 : y = 0.931 : 62.4 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Thu Jul 24 16:32:02 2025 AUC 0.930971378381508
#
# [mbo] 1: learning_rate=0.0109; feature_fraction=0.312; bagging_fraction=0.828; num_leaves=33; min_data_in_leaf=735; lambda_l2=1.12 : y = 0.931 : 61.7 secs : infill_ei
#
# Thu Jul 24 16:33:05 2025 AUC 0.930747897559131
#
# [mbo] 2: learning_rate=0.0133; feature_fraction=0.314; bagging_fraction=0.791; num_leaves=35; min_data_in_leaf=735; lambda_l2=0.695 : y = 0.931 : 62.4 secs : infill_ei
#
# Thu Jul 24 16:34:07 2025 AUC 0.931032673488737
#
# [mbo] 3: learning_rate=0.0113; feature_fraction=0.33; bagging_fraction=0.824; num_leaves=26; min_data_in_leaf=743; lambda_l2=4.81 : y = 0.931 : 61.2 secs : infill_ei
#
# Thu Jul 24 16:35:04 2025 AUC 0.931440904068951
#
# [mbo] 4: learning_rate=0.0149; feature_fraction=0.333; bagging_fraction=0.783; num_leaves=21; min_data_in_leaf=735; lambda_l2=0.983 : y = 0.931 : 56.0 secs : infill_ei
#
# Thu Jul 24 16:36:07 2025 AUC 0.930768642971644
#
# [mbo] 5: learning_rate=0.0123; feature_fraction=0.306; bagging_fraction=0.789; num_leaves=35; min_data_in_leaf=723; lambda_l2=0.528 : y = 0.931 : 62.6 secs : infill_ei
#
# Thu Jul 24 16:37:07 2025 AUC 0.930986532078675
#
# [mbo] 6: learning_rate=0.0113; feature_fraction=0.348; bagging_fraction=0.751; num_leaves=22; min_data_in_leaf=750; lambda_l2=3.55 : y = 0.931 : 58.6 secs : infill_ei
#
# Thu Jul 24 16:38:07 2025 AUC 0.930851819714596
#
# [mbo] 7: learning_rate=0.0125; feature_fraction=0.324; bagging_fraction=0.776; num_leaves=29; min_data_in_leaf=702; lambda_l2=4.77 : y = 0.931 : 59.6 secs : infill_ei
#
# Thu Jul 24 16:39:07 2025 AUC 0.931107185497973
#
# [mbo] 8: learning_rate=0.0148; feature_fraction=0.336; bagging_fraction=0.752; num_leaves=27; min_data_in_leaf=745; lambda_l2=0.964 : y = 0.931 : 59.8 secs : infill_ei
#
# Thu Jul 24 16:40:10 2025 AUC 0.931029419679674
#
# [mbo] 9: learning_rate=0.011; feature_fraction=0.341; bagging_fraction=0.84; num_leaves=28; min_data_in_leaf=759; lambda_l2=1.8 : y = 0.931 : 61.5 secs : infill_ei
#
# Thu Jul 24 16:41:15 2025 AUC 0.931106953448671
#
# [mbo] 10: learning_rate=0.0124; feature_fraction=0.352; bagging_fraction=0.792; num_leaves=33; min_data_in_leaf=732; lambda_l2=0.748 : y = 0.931 : 64.5 secs : infill_ei
#
# Saved the current state after iteration 11 in the file bayesiana.RDATA.
#
# Thu Jul 24 16:42:16 2025 AUC 0.931418300854692
#
# [mbo] 11: learning_rate=0.0149; feature_fraction=0.318; bagging_fraction=0.827; num_leaves=22; min_data_in_leaf=712; lambda_l2=0.779 : y = 0.931 : 57.4 secs : infill_ei
#
# Thu Jul 24 16:43:16 2025 AUC 0.930525321907912
#
# [mbo] 12: learning_rate=0.0147; feature_fraction=0.312; bagging_fraction=0.827; num_leaves=23; min_data_in_leaf=750; lambda_l2=3.59 : y = 0.931 : 58.4 secs : infill_ei
#
# Thu Jul 24 16:44:20 2025 AUC 0.931285651709987
#
# [mbo] 13: learning_rate=0.0102; feature_fraction=0.359; bagging_fraction=0.776; num_leaves=31; min_data_in_leaf=745; lambda_l2=4.78 : y = 0.931 : 64.0 secs : infill_ei
#
# Thu Jul 24 16:45:23 2025 AUC 0.931269879759833
#
# [mbo] 14: learning_rate=0.0131; feature_fraction=0.303; bagging_fraction=0.794; num_leaves=32; min_data_in_leaf=712; lambda_l2=2.82 : y = 0.931 : 61.9 secs : infill_ei
#
# Thu Jul 24 16:46:27 2025 AUC 0.930798343338352
#
# [mbo] 15: learning_rate=0.0134; feature_fraction=0.346; bagging_fraction=0.798; num_leaves=29; min_data_in_leaf=726; lambda_l2=4.89 : y = 0.931 : 63.1 secs : infill_ei
#
# Thu Jul 24 16:47:30 2025 AUC 0.930936298342979
#
# [mbo] 16: learning_rate=0.0105; feature_fraction=0.346; bagging_fraction=0.802; num_leaves=30; min_data_in_leaf=756; lambda_l2=4.73 : y = 0.931 : 62.8 secs : infill_ei
#
# Thu Jul 24 16:48:34 2025 AUC 0.931682607948596
#
# [mbo] 17: learning_rate=0.0114; feature_fraction=0.342; bagging_fraction=0.841; num_leaves=29; min_data_in_leaf=747; lambda_l2=3.72 : y = 0.932 : 62.6 secs : infill_ei
#
# Thu Jul 24 16:49:36 2025 AUC 0.931477594763686
#
# [mbo] 18: learning_rate=0.0109; feature_fraction=0.345; bagging_fraction=0.843; num_leaves=29; min_data_in_leaf=756; lambda_l2=3.68 : y = 0.931 : 61.9 secs : infill_ei
#
# Thu Jul 24 16:50:42 2025 AUC 0.931225629236216
#
# [mbo] 19: learning_rate=0.0122; feature_fraction=0.369; bagging_fraction=0.807; num_leaves=35; min_data_in_leaf=704; lambda_l2=1.79 : y = 0.931 : 65.4 secs : infill_ei
#
# Thu Jul 24 16:51:46 2025 AUC 0.931543500129507
#
# [mbo] 20: learning_rate=0.01; feature_fraction=0.312; bagging_fraction=0.824; num_leaves=35; min_data_in_leaf=710; lambda_l2=4.16 : y = 0.932 : 62.6 secs : infill_ei
#
# Saved the current state after iteration 21 in the file bayesiana.RDATA.
#
# Thu Jul 24 16:52:54 2025 AUC 0.931101229426715
#
# [mbo] 21: learning_rate=0.0139; feature_fraction=0.366; bagging_fraction=0.814; num_leaves=34; min_data_in_leaf=726; lambda_l2=4.64 : y = 0.931 : 64.1 secs : infill_ei
#
# Thu Jul 24 16:53:54 2025 AUC 0.93067077283939
#
# [mbo] 22: learning_rate=0.0122; feature_fraction=0.336; bagging_fraction=0.775; num_leaves=24; min_data_in_leaf=758; lambda_l2=0.754 : y = 0.931 : 58.9 secs : infill_ei
#
# Thu Jul 24 16:54:56 2025 AUC 0.930765162362904
#
# [mbo] 23: learning_rate=0.0133; feature_fraction=0.309; bagging_fraction=0.826; num_leaves=31; min_data_in_leaf=759; lambda_l2=4.45 : y = 0.931 : 61.6 secs : infill_ei
#
# Thu Jul 24 16:56:01 2025 AUC 0.931210726207273
#
# [mbo] 24: learning_rate=0.0143; feature_fraction=0.323; bagging_fraction=0.8; num_leaves=30; min_data_in_leaf=702; lambda_l2=1.27 : y = 0.931 : 64.1 secs : infill_ei
#
# Thu Jul 24 16:57:03 2025 AUC 0.930803961992615
#
# [mbo] 25: learning_rate=0.0101; feature_fraction=0.315; bagging_fraction=0.775; num_leaves=25; min_data_in_leaf=736; lambda_l2=1.27 : y = 0.931 : 61.0 secs : infill_ei
#
# Thu Jul 24 16:58:03 2025 AUC 0.930704510571652
#
# [mbo] 26: learning_rate=0.0145; feature_fraction=0.335; bagging_fraction=0.831; num_leaves=26; min_data_in_leaf=738; lambda_l2=1.13 : y = 0.931 : 59.6 secs : infill_ei
#
# Thu Jul 24 16:59:08 2025 AUC 0.931481998486037
#
# [mbo] 27: learning_rate=0.0103; feature_fraction=0.342; bagging_fraction=0.828; num_leaves=29; min_data_in_leaf=725; lambda_l2=3.83 : y = 0.931 : 63.6 secs : infill_ei
#
# Thu Jul 24 17:00:09 2025 AUC 0.931561009053346
#
# [mbo] 28: learning_rate=0.0108; feature_fraction=0.362; bagging_fraction=0.803; num_leaves=21; min_data_in_leaf=733; lambda_l2=0.532 : y = 0.932 : 60.5 secs : infill_ei
#
# Thu Jul 24 17:01:12 2025 AUC 0.931169311792408
#
# [mbo] 29: learning_rate=0.0108; feature_fraction=0.345; bagging_fraction=0.761; num_leaves=29; min_data_in_leaf=704; lambda_l2=0.729 : y = 0.931 : 62.1 secs : infill_ei
#
# Thu Jul 24 17:02:16 2025 AUC 0.93028767611202
#
# [mbo] 30: learning_rate=0.0119; feature_fraction=0.336; bagging_fraction=0.847; num_leaves=29; min_data_in_leaf=731; lambda_l2=3.79 : y = 0.93 : 62.8 secs : infill_ei
#
# Saved the current state after iteration 31 in the file bayesiana.RDATA.
#
# Thu Jul 24 17:03:21 2025 AUC 0.931524897193925
#
# [mbo] 31: learning_rate=0.0111; feature_fraction=0.328; bagging_fraction=0.773; num_leaves=27; min_data_in_leaf=747; lambda_l2=1.72 : y = 0.932 : 61.1 secs : infill_ei
#
# Thu Jul 24 17:04:23 2025 AUC 0.930599108389917
#
# [mbo] 32: learning_rate=0.0144; feature_fraction=0.312; bagging_fraction=0.801; num_leaves=28; min_data_in_leaf=735; lambda_l2=0.799 : y = 0.931 : 60.6 secs : infill_ei
#
# Thu Jul 24 17:05:22 2025 AUC 0.930384275265674
#
# [mbo] 33: learning_rate=0.0108; feature_fraction=0.346; bagging_fraction=0.795; num_leaves=22; min_data_in_leaf=722; lambda_l2=0.0654 : y = 0.93 : 58.4 secs : infill_ei
#
# Thu Jul 24 17:06:21 2025 AUC 0.931012605072048
#
# [mbo] 34: learning_rate=0.0102; feature_fraction=0.345; bagging_fraction=0.792; num_leaves=22; min_data_in_leaf=702; lambda_l2=1.03 : y = 0.931 : 58.5 secs : infill_ei
#
# Thu Jul 24 17:07:23 2025 AUC 0.930831171032692
#
# [mbo] 35: learning_rate=0.013; feature_fraction=0.327; bagging_fraction=0.849; num_leaves=30; min_data_in_leaf=706; lambda_l2=1.18 : y = 0.931 : 61.0 secs : infill_ei
#
# Thu Jul 24 17:08:26 2025 AUC 0.93109510123996
#
# [mbo] 36: learning_rate=0.0122; feature_fraction=0.341; bagging_fraction=0.842; num_leaves=29; min_data_in_leaf=749; lambda_l2=3.7 : y = 0.931 : 62.3 secs : infill_ei
#
# Thu Jul 24 17:09:27 2025 AUC 0.930596703949538
#
# [mbo] 37: learning_rate=0.0134; feature_fraction=0.35; bagging_fraction=0.816; num_leaves=27; min_data_in_leaf=703; lambda_l2=3.62 : y = 0.931 : 59.9 secs : infill_ei
#
# Thu Jul 24 17:10:28 2025 AUC 0.930742224086397
#
# [mbo] 38: learning_rate=0.015; feature_fraction=0.333; bagging_fraction=0.775; num_leaves=28; min_data_in_leaf=729; lambda_l2=0.892 : y = 0.931 : 60.6 secs : infill_ei
#
# Thu Jul 24 17:11:32 2025 AUC 0.931077076916732
#
# [mbo] 39: learning_rate=0.0117; feature_fraction=0.369; bagging_fraction=0.83; num_leaves=28; min_data_in_leaf=738; lambda_l2=0.148 : y = 0.931 : 62.8 secs : infill_ei
#
# Thu Jul 24 17:12:29 2025 AUC 0.930849844060478
#
# [mbo] 40: learning_rate=0.0124; feature_fraction=0.308; bagging_fraction=0.833; num_leaves=20; min_data_in_leaf=727; lambda_l2=0.156 : y = 0.931 : 56.7 secs : infill_ei
#
# Saved the current state after iteration 41 in the file bayesiana.RDATA.
#
# Thu Jul 24 17:13:36 2025 AUC 0.931599811215431
#
# [mbo] 41: learning_rate=0.0148; feature_fraction=0.322; bagging_fraction=0.773; num_leaves=33; min_data_in_leaf=737; lambda_l2=0.355 : y = 0.932 : 62.2 secs : infill_ei
#
# Thu Jul 24 17:14:33 2025 AUC 0.93150345161982
#
# [mbo] 42: learning_rate=0.0101; feature_fraction=0.324; bagging_fraction=0.762; num_leaves=21; min_data_in_leaf=705; lambda_l2=3.47 : y = 0.932 : 56.5 secs : infill_ei
#
# Thu Jul 24 17:15:31 2025 AUC 0.931498755800742
#
# [mbo] 43: learning_rate=0.0141; feature_fraction=0.352; bagging_fraction=0.776; num_leaves=21; min_data_in_leaf=704; lambda_l2=1.26 : y = 0.931 : 57.5 secs : infill_ei
#
# Thu Jul 24 17:16:36 2025 AUC 0.931509036686295
#
# [mbo] 44: learning_rate=0.0107; feature_fraction=0.341; bagging_fraction=0.841; num_leaves=30; min_data_in_leaf=748; lambda_l2=4.19 : y = 0.932 : 63.2 secs : infill_ei
#
# Thu Jul 24 17:17:36 2025 AUC 0.930674082516112
#
# [mbo] 45: learning_rate=0.0132; feature_fraction=0.369; bagging_fraction=0.798; num_leaves=21; min_data_in_leaf=755; lambda_l2=2.73 : y = 0.931 : 59.6 secs : infill_ei
#
# Thu Jul 24 17:18:40 2025 AUC 0.93106892470389
#
# [mbo] 46: learning_rate=0.0107; feature_fraction=0.342; bagging_fraction=0.832; num_leaves=28; min_data_in_leaf=743; lambda_l2=4.06 : y = 0.931 : 63.0 secs : infill_ei
#
# Thu Jul 24 17:19:46 2025 AUC 0.931727935488415
#
# [mbo] 47: learning_rate=0.0116; feature_fraction=0.354; bagging_fraction=0.809; num_leaves=34; min_data_in_leaf=726; lambda_l2=4.3 : y = 0.932 : 65.4 secs : infill_ei
#
# Thu Jul 24 17:20:49 2025 AUC 0.930703242227037
#
# [mbo] 48: learning_rate=0.0118; feature_fraction=0.304; bagging_fraction=0.781; num_leaves=32; min_data_in_leaf=758; lambda_l2=2.4 : y = 0.931 : 62.0 secs : infill_ei
#
# Thu Jul 24 17:21:49 2025 AUC 0.930442276241994
#
# [mbo] 49: learning_rate=0.0134; feature_fraction=0.309; bagging_fraction=0.799; num_leaves=25; min_data_in_leaf=741; lambda_l2=4.99 : y = 0.93 : 58.9 secs : infill_ei
#
# Thu Jul 24 17:22:50 2025 AUC 0.930835940807042
#
# [mbo] 50: learning_rate=0.0134; feature_fraction=0.33; bagging_fraction=0.841; num_leaves=29; min_data_in_leaf=748; lambda_l2=3.86 : y = 0.931 : 60.3 secs : infill_ei
#
# Saved the current state after iteration 51 in the file bayesiana.RDATA.
#
# Thu Jul 24 17:23:53 2025 AUC 0.931778219230994
#
# [mbo] 51: learning_rate=0.0144; feature_fraction=0.357; bagging_fraction=0.832; num_leaves=21; min_data_in_leaf=754; lambda_l2=0.739 : y = 0.932 : 57.8 secs : infill_ei
#
# Thu Jul 24 17:24:53 2025 AUC 0.93111759798955
#
# [mbo] 52: learning_rate=0.0147; feature_fraction=0.369; bagging_fraction=0.818; num_leaves=23; min_data_in_leaf=715; lambda_l2=2.5 : y = 0.931 : 60.1 secs : infill_ei
#
# Thu Jul 24 17:25:58 2025 AUC 0.930888538077919
#
# [mbo] 53: learning_rate=0.0109; feature_fraction=0.36; bagging_fraction=0.841; num_leaves=29; min_data_in_leaf=752; lambda_l2=3.84 : y = 0.931 : 63.6 secs : infill_ei
#
# Thu Jul 24 17:27:03 2025 AUC 0.930540479086816
#
# [mbo] 54: learning_rate=0.0121; feature_fraction=0.327; bagging_fraction=0.799; num_leaves=35; min_data_in_leaf=751; lambda_l2=3.24 : y = 0.931 : 63.9 secs : infill_ei
#
# Thu Jul 24 17:28:04 2025 AUC 0.930886606432074
#
# [mbo] 55: learning_rate=0.0104; feature_fraction=0.34; bagging_fraction=0.818; num_leaves=25; min_data_in_leaf=759; lambda_l2=2.46 : y = 0.931 : 60.2 secs : infill_ei
#
# Thu Jul 24 17:29:06 2025 AUC 0.931234633009578
#
# [mbo] 56: learning_rate=0.0131; feature_fraction=0.312; bagging_fraction=0.817; num_leaves=34; min_data_in_leaf=723; lambda_l2=0.0718 : y = 0.931 : 61.6 secs : infill_ei
#
# Thu Jul 24 17:30:09 2025 AUC 0.931130570843423
#
# [mbo] 57: learning_rate=0.012; feature_fraction=0.345; bagging_fraction=0.839; num_leaves=28; min_data_in_leaf=716; lambda_l2=2.51 : y = 0.931 : 62.3 secs : infill_ei
#
# Thu Jul 24 17:31:11 2025 AUC 0.931287991513018
#
# [mbo] 58: learning_rate=0.0118; feature_fraction=0.325; bagging_fraction=0.827; num_leaves=28; min_data_in_leaf=707; lambda_l2=2.56 : y = 0.931 : 60.3 secs : infill_ei
#
# Thu Jul 24 17:32:11 2025 AUC 0.930277998915775
#
# [mbo] 59: learning_rate=0.0117; feature_fraction=0.355; bagging_fraction=0.753; num_leaves=22; min_data_in_leaf=754; lambda_l2=3.24 : y = 0.93 : 59.3 secs : infill_ei
#
# Thu Jul 24 17:33:14 2025 AUC 0.931411173230554
#
# [mbo] 60: learning_rate=0.0137; feature_fraction=0.333; bagging_fraction=0.822; num_leaves=30; min_data_in_leaf=749; lambda_l2=4.87 : y = 0.931 : 62.6 secs : infill_ei
#
# Saved the current state after iteration 61 in the file bayesiana.RDATA.
#
# Thu Jul 24 17:34:22 2025 AUC 0.930858363384949
#
# [mbo] 61: learning_rate=0.0104; feature_fraction=0.302; bagging_fraction=0.831; num_leaves=35; min_data_in_leaf=713; lambda_l2=3.82 : y = 0.931 : 63.2 secs : infill_ei
#
# Thu Jul 24 17:35:27 2025 AUC 0.93093089678738
#
# [mbo] 62: learning_rate=0.0112; feature_fraction=0.35; bagging_fraction=0.781; num_leaves=29; min_data_in_leaf=749; lambda_l2=3.71 : y = 0.931 : 64.1 secs : infill_ei
#
# Thu Jul 24 17:36:29 2025 AUC 0.93028002178813
#
# [mbo] 63: learning_rate=0.0126; feature_fraction=0.333; bagging_fraction=0.848; num_leaves=27; min_data_in_leaf=706; lambda_l2=4.13 : y = 0.93 : 61.5 secs : infill_ei
#
# Thu Jul 24 17:37:30 2025 AUC 0.930904489980611
#
# [mbo] 64: learning_rate=0.0116; feature_fraction=0.337; bagging_fraction=0.751; num_leaves=24; min_data_in_leaf=751; lambda_l2=4.8 : y = 0.931 : 59.7 secs : infill_ei
#
# Thu Jul 24 17:38:37 2025 AUC 0.930914792918567
#
# [mbo] 65: learning_rate=0.0102; feature_fraction=0.37; bagging_fraction=0.782; num_leaves=33; min_data_in_leaf=738; lambda_l2=4.56 : y = 0.931 : 65.8 secs : infill_ei
#
# Thu Jul 24 17:39:37 2025 AUC 0.931591948682175
#
# [mbo] 66: learning_rate=0.0123; feature_fraction=0.322; bagging_fraction=0.845; num_leaves=25; min_data_in_leaf=701; lambda_l2=0.127 : y = 0.932 : 59.1 secs : infill_ei
#
# Thu Jul 24 17:40:37 2025 AUC 0.931364182558257
#
# [mbo] 67: learning_rate=0.0146; feature_fraction=0.367; bagging_fraction=0.839; num_leaves=20; min_data_in_leaf=744; lambda_l2=4.31 : y = 0.931 : 59.3 secs : infill_ei
#
# Thu Jul 24 17:41:34 2025 AUC 0.930557852453831
#
# [mbo] 68: learning_rate=0.0119; feature_fraction=0.309; bagging_fraction=0.759; num_leaves=20; min_data_in_leaf=708; lambda_l2=2.59 : y = 0.931 : 55.8 secs : infill_ei
#
# Thu Jul 24 17:42:32 2025 AUC 0.929773851544462
#
# [mbo] 69: learning_rate=0.0147; feature_fraction=0.325; bagging_fraction=0.784; num_leaves=20; min_data_in_leaf=742; lambda_l2=4.1 : y = 0.93 : 57.5 secs : infill_ei
#
# Thu Jul 24 17:43:32 2025 AUC 0.931218488726364
#
# [mbo] 70: learning_rate=0.0133; feature_fraction=0.332; bagging_fraction=0.78; num_leaves=23; min_data_in_leaf=710; lambda_l2=1.42 : y = 0.931 : 58.8 secs : infill_ei
#
# Saved the current state after iteration 71 in the file bayesiana.RDATA.
#
# Thu Jul 24 17:44:39 2025 AUC 0.931671460579376
#
# [mbo] 71: learning_rate=0.0138; feature_fraction=0.355; bagging_fraction=0.82; num_leaves=22; min_data_in_leaf=742; lambda_l2=1.31 : y = 0.932 : 59.7 secs : infill_ei
#
# Thu Jul 24 17:45:45 2025 AUC 0.931103610964204
#
# [mbo] 72: learning_rate=0.0141; feature_fraction=0.361; bagging_fraction=0.765; num_leaves=34; min_data_in_leaf=740; lambda_l2=1.39 : y = 0.931 : 65.8 secs : infill_ei
#
# Thu Jul 24 17:46:50 2025 AUC 0.930531122288709
#
# [mbo] 73: learning_rate=0.0144; feature_fraction=0.363; bagging_fraction=0.833; num_leaves=31; min_data_in_leaf=731; lambda_l2=2.48 : y = 0.931 : 63.8 secs : infill_ei
#
# Thu Jul 24 17:47:49 2025 AUC 0.930493322699829
#
# [mbo] 74: learning_rate=0.0123; feature_fraction=0.323; bagging_fraction=0.833; num_leaves=24; min_data_in_leaf=702; lambda_l2=1.39 : y = 0.93 : 57.8 secs : infill_ei
#
# Thu Jul 24 17:48:52 2025 AUC 0.930919554053566
#
# [mbo] 75: learning_rate=0.0138; feature_fraction=0.349; bagging_fraction=0.792; num_leaves=30; min_data_in_leaf=712; lambda_l2=1.02 : y = 0.931 : 62.2 secs : infill_ei
#
# Thu Jul 24 17:49:50 2025 AUC 0.931317987749313
#
# [mbo] 76: learning_rate=0.0128; feature_fraction=0.309; bagging_fraction=0.832; num_leaves=23; min_data_in_leaf=716; lambda_l2=1.54 : y = 0.931 : 57.0 secs : infill_ei
#
# Thu Jul 24 17:50:51 2025 AUC 0.930662859233584
#
# [mbo] 77: learning_rate=0.0141; feature_fraction=0.364; bagging_fraction=0.825; num_leaves=22; min_data_in_leaf=704; lambda_l2=1.18 : y = 0.931 : 59.5 secs : infill_ei
#
# Thu Jul 24 17:51:50 2025 AUC 0.930870843062311
#
# [mbo] 78: learning_rate=0.0142; feature_fraction=0.347; bagging_fraction=0.832; num_leaves=22; min_data_in_leaf=754; lambda_l2=0.047 : y = 0.931 : 57.7 secs : infill_ei
#
# Thu Jul 24 17:52:51 2025 AUC 0.930769755274591
#
# [mbo] 79: learning_rate=0.0102; feature_fraction=0.352; bagging_fraction=0.841; num_leaves=28; min_data_in_leaf=727; lambda_l2=0.357 : y = 0.931 : 60.7 secs : infill_ei
#
# Thu Jul 24 17:53:58 2025 AUC 0.931093902307352
#
# [mbo] 80: learning_rate=0.0106; feature_fraction=0.317; bagging_fraction=0.763; num_leaves=33; min_data_in_leaf=733; lambda_l2=1.69 : y = 0.931 : 65.8 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "learning_rate"    "feature_fraction" "bagging_fraction" "num_leaves"
#  [5] "min_data_in_leaf" "lambda_l2"        "y"                "dob"
#  [9] "eol"              "error.message"    "exec.time"        "ei"
# [13] "error.model"      "train.time"       "prop.type"        "propose.time"
# [17] "se"               "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    learning_rate feature_fraction bagging_fraction num_leaves min_data_in_leaf
#            <num>            <num>            <num>      <int>            <int>
# 1:    0.01437303        0.3570167        0.8321729         21              754
#    lambda_l2
#        <num>
# 1:   0.73874
# [1] 0.9317782

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 100887
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 0.73874
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 0.8321729
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1200
#
# $learning_rate
# [1] 0.01437303
#
# $feature_fraction
# [1] 0.3570167
#
# $num_leaves
# [1] 21
#
# $min_data_in_leaf
# [1] 754

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Jul 24 18:01:35 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
