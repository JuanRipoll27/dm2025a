# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# Esta Tarea para el Hogar 02 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el viernes 01-agosto

# %% [markdown]
# ##  1. Cazatalentos

# %% [markdown]
# En la Clase 03 nos hemos enfrentado a  "La Maldicion del Ganandor",  elegir el modelo con el mejor puntaje simple no suele ser la mejor estrategia.
# <br> Lea y ejecute el notebook  **src/CazaTalentos/CazaTalentos.ipynb**
# <br> en caso de interesarle, participe del Desafío Ordenamiento  que vence el sábado 02 de agosto a las 19:00

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dm"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dm" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/itba2025-8d0a/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Jul 29 04:39:10 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used     (Mb)  gc trigger (Mb)  max used  (Mb)
# Ncells  2326632 124.3   3891185  207.9   3891185 207.9
# Vcells 17083955 130.4 111748032  852.6 104497719 797.3

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 4964
PARAM$semilla_primigenia <- 333757

# %%
PARAM$kaggle$competencia <- "data-mining-analista-sr-2025-a"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1500,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeNumericParam("learning_rate", lower = 0.001, upper = 0.9),
  makeNumericParam("feature_fraction", lower = 0.1, upper = 0.9),
  makeNumericParam("bagging_fraction", lower = 0.1, upper = 1.0),
  makeIntegerParam("num_leaves", lower = 15L, upper = 2048L),
  makeIntegerParam("min_data_in_leaf", lower = 20L, upper = 2000L),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 10.0),
  makeNumericParam("lambda_l1", lower = 0.0, upper = 5.0),
  makeIntegerParam("max_depth", lower = 3L, upper = 15L),
  makeNumericParam("min_gain_to_split", lower = 0.0, upper = 2.0),
  makeNumericParam("min_sum_hessian_in_leaf", lower = 0.001, upper = 100),
  makeNumericParam("scale_pos_weight", lower = 0.5, upper = 10.0),
  makeNumericParam("path_smooth", lower = 0, upper = 100),
  makeIntegerParam("top_k", lower = 1L, upper = 50L)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 600 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83552
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Tue Jul 29 04:41:31 2025 AUC 0.923438238989652
#
# Tue Jul 29 04:42:04 2025 AUC 0.911660079718935
#
# Tue Jul 29 04:42:40 2025 AUC 0.923760621812702
#
# Tue Jul 29 04:43:12 2025 AUC 0.919847801463974
#
# Tue Jul 29 04:43:41 2025 AUC 0.876990780999318
#
# Tue Jul 29 04:44:10 2025 AUC 0.898738014887661
#
# Tue Jul 29 04:44:28 2025 AUC 0.924509357406354
#
# Tue Jul 29 04:45:02 2025 AUC 0.907647195560732
#
# Tue Jul 29 04:45:37 2025 AUC 0.919827085633617
#
# Tue Jul 29 04:46:09 2025 AUC 0.871888407989707
#
# Tue Jul 29 04:46:43 2025 AUC 0.879161643636746
#
# Tue Jul 29 04:46:59 2025 AUC 0.900791220587658
#
# Tue Jul 29 04:47:23 2025 AUC 0.928696143534229
#
# Tue Jul 29 04:47:57 2025 AUC 0.913354899584786
#
# Tue Jul 29 04:48:12 2025 AUC 0.923667793306699
#
# Tue Jul 29 04:48:34 2025 AUC 0.895364571809875
#
# Tue Jul 29 04:48:50 2025 AUC 0.906904753990497
#
# Tue Jul 29 04:49:25 2025 AUC 0.917354660481527
#
# Tue Jul 29 04:49:41 2025 AUC 0.879275540438656
#
# Tue Jul 29 04:50:21 2025 AUC 0.930352353467265
#
# Tue Jul 29 04:50:38 2025 AUC 0.873147463076004
#
# Tue Jul 29 04:51:12 2025 AUC 0.863156739149242
#
# Tue Jul 29 04:51:33 2025 AUC 0.920758216262032
#
# Tue Jul 29 04:52:04 2025 AUC 0.911254823347417
#
# Tue Jul 29 04:52:40 2025 AUC 0.925888124695787
#
# Tue Jul 29 04:53:09 2025 AUC 0.905493159444485
#
# Tue Jul 29 04:53:39 2025 AUC 0.924433570190766
#
# Tue Jul 29 04:54:18 2025 AUC 0.918960711239899
#
# Tue Jul 29 04:54:52 2025 AUC 0.927192536052674
#
# Tue Jul 29 04:55:24 2025 AUC 0.900449585183436
#
# Tue Jul 29 04:55:57 2025 AUC 0.892819830511914
#
# Tue Jul 29 04:56:15 2025 AUC 0.90138841517571
#
# Tue Jul 29 04:56:29 2025 AUC 0.911359690545721
#
# Tue Jul 29 04:56:57 2025 AUC 0.916148688471112
#
# Tue Jul 29 04:57:18 2025 AUC 0.874912769319275
#
# Tue Jul 29 04:57:33 2025 AUC 0.875958830916343
#
# Tue Jul 29 04:57:53 2025 AUC 0.873587739237902
#
# Tue Jul 29 04:58:53 2025 AUC 0.928969281875443
#
# Tue Jul 29 04:59:14 2025 AUC 0.925499700556139
#
# Tue Jul 29 04:59:44 2025 AUC 0.878865509811475
#
# Tue Jul 29 05:00:10 2025 AUC 0.925706240348048
#
# Tue Jul 29 05:00:25 2025 AUC 0.925395141096648
#
# Tue Jul 29 05:00:59 2025 AUC 0.876470706244686
#
# Tue Jul 29 05:01:16 2025 AUC 0.868335349472566
#
# Tue Jul 29 05:01:47 2025 AUC 0.897208543873125
#
# Tue Jul 29 05:02:19 2025 AUC 0.927444427061654
#
# Tue Jul 29 05:02:49 2025 AUC 0.893350627280345
#
# Tue Jul 29 05:03:30 2025 AUC 0.924559233731656
#
# Tue Jul 29 05:04:09 2025 AUC 0.882058319098034
#
# Tue Jul 29 05:04:40 2025 AUC 0.906613135298154
#
# Tue Jul 29 05:05:16 2025 AUC 0.869853206708476
#
# Tue Jul 29 05:05:32 2025 AUC 0.9238070032768
#
# [mbo] 0: learning_rate=0.227; feature_fraction=0.517; bagging_fraction=0.353; num_leaves=1432; min_data_in_leaf=794; lambda_l2=7.64; lambda_l1=1.44; max_depth=8; min_gain_to_split=1.34; min_sum_hessian_in_leaf=89.3; scale_pos_weight=7.4; path_smooth=72.5; top_k=21 : y = 0.923 : 36.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.529; feature_fraction=0.352; bagging_fraction=0.822; num_leaves=1015; min_data_in_leaf=542; lambda_l2=5.51; lambda_l1=1.56; max_depth=3; min_gain_to_split=0.563; min_sum_hessian_in_leaf=84.3; scale_pos_weight=4.39; path_smooth=31.1; top_k=15 : y = 0.912 : 33.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.163; feature_fraction=0.48; bagging_fraction=0.533; num_leaves=784; min_data_in_leaf=1467; lambda_l2=6.08; lambda_l1=2.89; max_depth=12; min_gain_to_split=0.863; min_sum_hessian_in_leaf=45.2; scale_pos_weight=4.94; path_smooth=55.6; top_k=36 : y = 0.924 : 36.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.304; feature_fraction=0.322; bagging_fraction=0.48; num_leaves=1269; min_data_in_leaf=961; lambda_l2=3.48; lambda_l1=4.1; max_depth=9; min_gain_to_split=1.54; min_sum_hessian_in_leaf=59.5; scale_pos_weight=3.3; path_smooth=73.7; top_k=14 : y = 0.92 : 32.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.697; feature_fraction=0.575; bagging_fraction=0.418; num_leaves=861; min_data_in_leaf=1255; lambda_l2=7.47; lambda_l1=2.81; max_depth=10; min_gain_to_split=1.48; min_sum_hessian_in_leaf=59.8; scale_pos_weight=5.33; path_smooth=39; top_k=17 : y = 0.877 : 28.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.565; feature_fraction=0.127; bagging_fraction=0.434; num_leaves=1541; min_data_in_leaf=991; lambda_l2=3.77; lambda_l1=3.39; max_depth=7; min_gain_to_split=1.02; min_sum_hessian_in_leaf=80.1; scale_pos_weight=3.47; path_smooth=46.7; top_k=47 : y = 0.899 : 29.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.108; feature_fraction=0.783; bagging_fraction=0.543; num_leaves=241; min_data_in_leaf=1609; lambda_l2=5.61; lambda_l1=3.05; max_depth=6; min_gain_to_split=1.2; min_sum_hessian_in_leaf=23.2; scale_pos_weight=7.56; path_smooth=33.8; top_k=11 : y = 0.925 : 17.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.551; feature_fraction=0.444; bagging_fraction=0.33; num_leaves=332; min_data_in_leaf=184; lambda_l2=4.93; lambda_l1=0.954; max_depth=15; min_gain_to_split=0.702; min_sum_hessian_in_leaf=33.1; scale_pos_weight=1.46; path_smooth=61.3; top_k=40 : y = 0.908 : 34.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.363; feature_fraction=0.4; bagging_fraction=0.273; num_leaves=1344; min_data_in_leaf=1021; lambda_l2=6.85; lambda_l1=3.12; max_depth=3; min_gain_to_split=0.748; min_sum_hessian_in_leaf=76.1; scale_pos_weight=5.98; path_smooth=68; top_k=29 : y = 0.92 : 34.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.486; feature_fraction=0.268; bagging_fraction=0.649; num_leaves=891; min_data_in_leaf=727; lambda_l2=6.3; lambda_l1=1.49; max_depth=9; min_gain_to_split=0.968; min_sum_hessian_in_leaf=26.7; scale_pos_weight=8.42; path_smooth=41; top_k=45 : y = 0.872 : 32.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.505; feature_fraction=0.3; bagging_fraction=0.672; num_leaves=1725; min_data_in_leaf=1767; lambda_l2=2; lambda_l1=1.16; max_depth=13; min_gain_to_split=0.59; min_sum_hessian_in_leaf=57.5; scale_pos_weight=8.05; path_smooth=59; top_k=25 : y = 0.879 : 33.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.433; feature_fraction=0.753; bagging_fraction=0.943; num_leaves=816; min_data_in_leaf=779; lambda_l2=3.9; lambda_l1=2.61; max_depth=12; min_gain_to_split=0.665; min_sum_hessian_in_leaf=51.1; scale_pos_weight=6.8; path_smooth=77.6; top_k=32 : y = 0.901 : 16.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0656; feature_fraction=0.632; bagging_fraction=0.369; num_leaves=79; min_data_in_leaf=653; lambda_l2=7.81; lambda_l1=1.92; max_depth=8; min_gain_to_split=1.13; min_sum_hessian_in_leaf=53.7; scale_pos_weight=6.9; path_smooth=43.4; top_k=44 : y = 0.929 : 23.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.385; feature_fraction=0.378; bagging_fraction=0.12; num_leaves=686; min_data_in_leaf=1777; lambda_l2=4.68; lambda_l1=0.0117; max_depth=14; min_gain_to_split=0.391; min_sum_hessian_in_leaf=70.1; scale_pos_weight=3.81; path_smooth=38.5; top_k=15 : y = 0.913 : 34.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.26; feature_fraction=0.725; bagging_fraction=0.17; num_leaves=1403; min_data_in_leaf=1654; lambda_l2=2.28; lambda_l1=3.48; max_depth=10; min_gain_to_split=1.63; min_sum_hessian_in_leaf=48.9; scale_pos_weight=1.61; path_smooth=8.03; top_k=4 : y = 0.924 : 15.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.685; feature_fraction=0.774; bagging_fraction=0.888; num_leaves=1512; min_data_in_leaf=1665; lambda_l2=3.1; lambda_l1=3.22; max_depth=6; min_gain_to_split=0.292; min_sum_hessian_in_leaf=11.7; scale_pos_weight=7.84; path_smooth=10.2; top_k=27 : y = 0.895 : 22.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.649; feature_fraction=0.65; bagging_fraction=0.454; num_leaves=1950; min_data_in_leaf=1574; lambda_l2=9.59; lambda_l1=4.35; max_depth=5; min_gain_to_split=1.98; min_sum_hessian_in_leaf=31.7; scale_pos_weight=2.34; path_smooth=22.9; top_k=28 : y = 0.907 : 16.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.288; feature_fraction=0.437; bagging_fraction=0.63; num_leaves=382; min_data_in_leaf=1717; lambda_l2=7.1; lambda_l1=3.64; max_depth=14; min_gain_to_split=0.781; min_sum_hessian_in_leaf=8.05; scale_pos_weight=8.79; path_smooth=16.7; top_k=26 : y = 0.917 : 34.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.731; feature_fraction=0.681; bagging_fraction=0.612; num_leaves=1985; min_data_in_leaf=1359; lambda_l2=8.38; lambda_l1=1.13; max_depth=12; min_gain_to_split=1.91; min_sum_hessian_in_leaf=40.6; scale_pos_weight=4.56; path_smooth=70.2; top_k=16 : y = 0.879 : 15.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0478; feature_fraction=0.409; bagging_fraction=0.484; num_leaves=1106; min_data_in_leaf=564; lambda_l2=8.18; lambda_l1=2.18; max_depth=11; min_gain_to_split=1.25; min_sum_hessian_in_leaf=39.6; scale_pos_weight=6.16; path_smooth=79.5; top_k=7 : y = 0.93 : 40.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.775; feature_fraction=0.703; bagging_fraction=0.719; num_leaves=568; min_data_in_leaf=337; lambda_l2=6.68; lambda_l1=2.25; max_depth=5; min_gain_to_split=0.808; min_sum_hessian_in_leaf=43.7; scale_pos_weight=5.79; path_smooth=3.38; top_k=4 : y = 0.873 : 16.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.786; feature_fraction=0.278; bagging_fraction=0.731; num_leaves=505; min_data_in_leaf=831; lambda_l2=4.23; lambda_l1=0.271; max_depth=11; min_gain_to_split=0.496; min_sum_hessian_in_leaf=71.9; scale_pos_weight=5.61; path_smooth=96.1; top_k=12 : y = 0.863 : 34.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.331; feature_fraction=0.602; bagging_fraction=0.69; num_leaves=1169; min_data_in_leaf=891; lambda_l2=8.62; lambda_l1=4.48; max_depth=7; min_gain_to_split=1.28; min_sum_hessian_in_leaf=97.3; scale_pos_weight=0.784; path_smooth=14.9; top_k=7 : y = 0.921 : 21.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.402; feature_fraction=0.219; bagging_fraction=0.797; num_leaves=1053; min_data_in_leaf=27; lambda_l2=2.36; lambda_l1=2.51; max_depth=8; min_gain_to_split=1.66; min_sum_hessian_in_leaf=64.2; scale_pos_weight=4.27; path_smooth=97.6; top_k=37 : y = 0.911 : 30.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.138; feature_fraction=0.506; bagging_fraction=0.206; num_leaves=1352; min_data_in_leaf=921; lambda_l2=3.42; lambda_l1=0.123; max_depth=12; min_gain_to_split=1.19; min_sum_hessian_in_leaf=87.3; scale_pos_weight=4.08; path_smooth=92.8; top_k=40 : y = 0.926 : 36.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.582; feature_fraction=0.195; bagging_fraction=0.229; num_leaves=677; min_data_in_leaf=371; lambda_l2=1.62; lambda_l1=3.31; max_depth=11; min_gain_to_split=1.84; min_sum_hessian_in_leaf=10.4; scale_pos_weight=1.13; path_smooth=1.56; top_k=35 : y = 0.905 : 29.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.188; feature_fraction=0.184; bagging_fraction=0.514; num_leaves=287; min_data_in_leaf=1281; lambda_l2=2.78; lambda_l1=4.14; max_depth=9; min_gain_to_split=0.65; min_sum_hessian_in_leaf=68.2; scale_pos_weight=2.31; path_smooth=53.1; top_k=43 : y = 0.924 : 29.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.465; feature_fraction=0.375; bagging_fraction=0.406; num_leaves=1614; min_data_in_leaf=319; lambda_l2=5.95; lambda_l1=1.28; max_depth=3; min_gain_to_split=0.023; min_sum_hessian_in_leaf=28.7; scale_pos_weight=2.93; path_smooth=48.3; top_k=50 : y = 0.919 : 39.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.14; feature_fraction=0.556; bagging_fraction=0.575; num_leaves=1256; min_data_in_leaf=1528; lambda_l2=8.97; lambda_l1=0.987; max_depth=9; min_gain_to_split=0.377; min_sum_hessian_in_leaf=36.9; scale_pos_weight=1.83; path_smooth=24.9; top_k=20 : y = 0.927 : 34.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.599; feature_fraction=0.154; bagging_fraction=0.306; num_leaves=1142; min_data_in_leaf=222; lambda_l2=4.44; lambda_l1=0.417; max_depth=15; min_gain_to_split=0.117; min_sum_hessian_in_leaf=85; scale_pos_weight=3.61; path_smooth=20.6; top_k=46 : y = 0.9 : 32.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.84; feature_fraction=0.169; bagging_fraction=0.137; num_leaves=1224; min_data_in_leaf=493; lambda_l2=0.7; lambda_l1=1.93; max_depth=8; min_gain_to_split=1.09; min_sum_hessian_in_leaf=6.54; scale_pos_weight=7.74; path_smooth=6.59; top_k=3 : y = 0.893 : 32.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.661; feature_fraction=0.821; bagging_fraction=0.322; num_leaves=137; min_data_in_leaf=702; lambda_l2=0.272; lambda_l1=4.63; max_depth=14; min_gain_to_split=1.6; min_sum_hessian_in_leaf=1.88; scale_pos_weight=2.85; path_smooth=89.2; top_k=18 : y = 0.901 : 17.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.366; feature_fraction=0.866; bagging_fraction=0.25; num_leaves=938; min_data_in_leaf=1192; lambda_l2=2.9; lambda_l1=4.8; max_depth=4; min_gain_to_split=1.44; min_sum_hessian_in_leaf=46.3; scale_pos_weight=7.19; path_smooth=50.4; top_k=42 : y = 0.911 : 14.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.329; feature_fraction=0.109; bagging_fraction=0.783; num_leaves=428; min_data_in_leaf=1816; lambda_l2=5.27; lambda_l1=2.07; max_depth=4; min_gain_to_split=1.86; min_sum_hessian_in_leaf=14.5; scale_pos_weight=6.16; path_smooth=64.2; top_k=23 : y = 0.916 : 27.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.632; feature_fraction=0.693; bagging_fraction=0.384; num_leaves=1489; min_data_in_leaf=138; lambda_l2=4.41; lambda_l1=0.326; max_depth=13; min_gain_to_split=0.199; min_sum_hessian_in_leaf=4.12; scale_pos_weight=4.85; path_smooth=66.7; top_k=9 : y = 0.875 : 21.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.747; feature_fraction=0.852; bagging_fraction=0.839; num_leaves=474; min_data_in_leaf=62; lambda_l2=6.41; lambda_l1=2.73; max_depth=3; min_gain_to_split=0.911; min_sum_hessian_in_leaf=20.7; scale_pos_weight=3.18; path_smooth=100; top_k=24 : y = 0.876 : 14.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.851; feature_fraction=0.656; bagging_fraction=0.971; num_leaves=300; min_data_in_leaf=1504; lambda_l2=8.79; lambda_l1=4.28; max_depth=7; min_gain_to_split=0.0729; min_sum_hessian_in_leaf=91.1; scale_pos_weight=5.23; path_smooth=36; top_k=19 : y = 0.874 : 19.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0131; feature_fraction=0.492; bagging_fraction=0.658; num_leaves=1818; min_data_in_leaf=1208; lambda_l2=0.79; lambda_l1=3.66; max_depth=11; min_gain_to_split=0.937; min_sum_hessian_in_leaf=73.5; scale_pos_weight=9.46; path_smooth=26.4; top_k=10 : y = 0.929 : 60.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.199; feature_fraction=0.619; bagging_fraction=0.912; num_leaves=1912; min_data_in_leaf=1350; lambda_l2=1.52; lambda_l1=3.9; max_depth=15; min_gain_to_split=0.44; min_sum_hessian_in_leaf=30.2; scale_pos_weight=0.629; path_smooth=62.9; top_k=49 : y = 0.925 : 20.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.884; feature_fraction=0.581; bagging_fraction=0.765; num_leaves=104; min_data_in_leaf=1137; lambda_l2=9.08; lambda_l1=0.623; max_depth=14; min_gain_to_split=1.51; min_sum_hessian_in_leaf=35.6; scale_pos_weight=8.58; path_smooth=76.4; top_k=31 : y = 0.879 : 30.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0863; feature_fraction=0.886; bagging_fraction=0.565; num_leaves=1628; min_data_in_leaf=1872; lambda_l2=9.34; lambda_l1=0.567; max_depth=4; min_gain_to_split=0.526; min_sum_hessian_in_leaf=98.1; scale_pos_weight=9.36; path_smooth=85.4; top_k=31 : y = 0.926 : 25.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.223; feature_fraction=0.837; bagging_fraction=0.599; num_leaves=1773; min_data_in_leaf=257; lambda_l2=1.83; lambda_l1=0.736; max_depth=7; min_gain_to_split=1.76; min_sum_hessian_in_leaf=18.1; scale_pos_weight=2.63; path_smooth=17.3; top_k=34 : y = 0.925 : 15.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.806; feature_fraction=0.535; bagging_fraction=0.112; num_leaves=191; min_data_in_leaf=414; lambda_l2=9.94; lambda_l1=4.99; max_depth=10; min_gain_to_split=0.314; min_sum_hessian_in_leaf=23; scale_pos_weight=0.961; path_smooth=44.8; top_k=22 : y = 0.876 : 34.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.712; feature_fraction=0.745; bagging_fraction=0.952; num_leaves=2040; min_data_in_leaf=1071; lambda_l2=0.0832; lambda_l1=4.89; max_depth=4; min_gain_to_split=1.38; min_sum_hessian_in_leaf=55.3; scale_pos_weight=6.49; path_smooth=81.7; top_k=12 : y = 0.868 : 16.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.468; feature_fraction=0.243; bagging_fraction=0.156; num_leaves=990; min_data_in_leaf=1959; lambda_l2=5.17; lambda_l1=2.36; max_depth=15; min_gain_to_split=1.7; min_sum_hessian_in_leaf=77.2; scale_pos_weight=8.27; path_smooth=30.3; top_k=37 : y = 0.897 : 31.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0192; feature_fraction=0.884; bagging_fraction=0.926; num_leaves=1678; min_data_in_leaf=604; lambda_l2=8.04; lambda_l1=3.78; max_depth=13; min_gain_to_split=1.79; min_sum_hessian_in_leaf=95.8; scale_pos_weight=6.66; path_smooth=84.1; top_k=41 : y = 0.927 : 31.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.611; feature_fraction=0.146; bagging_fraction=0.279; num_leaves=755; min_data_in_leaf=469; lambda_l2=1.23; lambda_l1=2.46; max_depth=6; min_gain_to_split=0.101; min_sum_hessian_in_leaf=65.4; scale_pos_weight=9.22; path_smooth=91; top_k=39 : y = 0.893 : 30.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0878; feature_fraction=0.233; bagging_fraction=0.987; num_leaves=34; min_data_in_leaf=1986; lambda_l2=0.575; lambda_l1=0.816; max_depth=10; min_gain_to_split=0.243; min_sum_hessian_in_leaf=93.7; scale_pos_weight=9.7; path_smooth=27; top_k=6 : y = 0.925 : 41.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.42; feature_fraction=0.461; bagging_fraction=0.854; num_leaves=1791; min_data_in_leaf=1092; lambda_l2=9.65; lambda_l1=4; max_depth=13; min_gain_to_split=0.182; min_sum_hessian_in_leaf=15.8; scale_pos_weight=8.91; path_smooth=57.7; top_k=1 : y = 0.882 : 38.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.818; feature_fraction=0.341; bagging_fraction=0.757; num_leaves=1887; min_data_in_leaf=1904; lambda_l2=7.13; lambda_l1=1.71; max_depth=5; min_gain_to_split=1.07; min_sum_hessian_in_leaf=81.6; scale_pos_weight=1.31; path_smooth=4.47; top_k=48 : y = 0.907 : 31.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.87; feature_fraction=0.31; bagging_fraction=0.864; num_leaves=610; min_data_in_leaf=99; lambda_l2=0.982; lambda_l1=4.54; max_depth=5; min_gain_to_split=1.96; min_sum_hessian_in_leaf=3.83; scale_pos_weight=9.9; path_smooth=12.2; top_k=29 : y = 0.87 : 35.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.275; feature_fraction=0.799; bagging_fraction=0.195; num_leaves=549; min_data_in_leaf=1411; lambda_l2=2.67; lambda_l1=1.74; max_depth=6; min_gain_to_split=1.39; min_sum_hessian_in_leaf=62.4; scale_pos_weight=2.06; path_smooth=87.4; top_k=2 : y = 0.924 : 15.3 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Tue Jul 29 05:06:16 2025 AUC 0.92777866523267
#
# [mbo] 1: learning_rate=0.0617; feature_fraction=0.556; bagging_fraction=0.63; num_leaves=1342; min_data_in_leaf=576; lambda_l2=4.07; lambda_l1=2.22; max_depth=6; min_gain_to_split=0.572; min_sum_hessian_in_leaf=88.3; scale_pos_weight=4.52; path_smooth=55.6; top_k=22 : y = 0.928 : 38.0 secs : infill_ei
#
# Tue Jul 29 05:06:43 2025 AUC 0.928345712605207
#
# [mbo] 2: learning_rate=0.0256; feature_fraction=0.719; bagging_fraction=0.341; num_leaves=1475; min_data_in_leaf=1136; lambda_l2=7.31; lambda_l1=1.41; max_depth=10; min_gain_to_split=1.78; min_sum_hessian_in_leaf=71.1; scale_pos_weight=6.5; path_smooth=28.8; top_k=22 : y = 0.928 : 26.2 secs : infill_ei
#
# Tue Jul 29 05:06:59 2025 AUC 0.924112746860953
#
# [mbo] 3: learning_rate=0.246; feature_fraction=0.857; bagging_fraction=0.878; num_leaves=379; min_data_in_leaf=482; lambda_l2=1.13; lambda_l1=3.34; max_depth=15; min_gain_to_split=0.63; min_sum_hessian_in_leaf=69.6; scale_pos_weight=1.63; path_smooth=61.2; top_k=31 : y = 0.924 : 15.2 secs : infill_ei
#
# Tue Jul 29 05:07:17 2025 AUC 0.925376778684215
#
# [mbo] 4: learning_rate=0.178; feature_fraction=0.666; bagging_fraction=0.354; num_leaves=1622; min_data_in_leaf=1120; lambda_l2=6.56; lambda_l1=2.41; max_depth=3; min_gain_to_split=0.72; min_sum_hessian_in_leaf=43.6; scale_pos_weight=2.11; path_smooth=66.7; top_k=30 : y = 0.925 : 16.2 secs : infill_ei
#
# Tue Jul 29 05:08:05 2025 AUC 0.931336620094194
#
# [mbo] 5: learning_rate=0.0246; feature_fraction=0.565; bagging_fraction=0.723; num_leaves=626; min_data_in_leaf=797; lambda_l2=4.19; lambda_l1=1.66; max_depth=11; min_gain_to_split=0.859; min_sum_hessian_in_leaf=76.5; scale_pos_weight=8.15; path_smooth=87.5; top_k=18 : y = 0.931 : 47.8 secs : infill_ei
#
# Tue Jul 29 05:08:46 2025 AUC 0.925322291240775
#
# [mbo] 6: learning_rate=0.298; feature_fraction=0.48; bagging_fraction=0.779; num_leaves=598; min_data_in_leaf=609; lambda_l2=3.11; lambda_l1=1.05; max_depth=3; min_gain_to_split=0.068; min_sum_hessian_in_leaf=77; scale_pos_weight=1.73; path_smooth=13.9; top_k=30 : y = 0.925 : 39.2 secs : infill_ei
#
# Tue Jul 29 05:09:44 2025 AUC 0.927346280311732
#
# [mbo] 7: learning_rate=0.0157; feature_fraction=0.544; bagging_fraction=0.746; num_leaves=1116; min_data_in_leaf=1568; lambda_l2=1.96; lambda_l1=2.23; max_depth=12; min_gain_to_split=1.12; min_sum_hessian_in_leaf=89.1; scale_pos_weight=6.85; path_smooth=84.9; top_k=17 : y = 0.927 : 57.3 secs : infill_ei
#
# Tue Jul 29 05:10:07 2025 AUC 0.92932224358553
#
# [mbo] 8: learning_rate=0.0516; feature_fraction=0.761; bagging_fraction=0.259; num_leaves=927; min_data_in_leaf=592; lambda_l2=1.95; lambda_l1=3.92; max_depth=11; min_gain_to_split=1.16; min_sum_hessian_in_leaf=69.2; scale_pos_weight=7.84; path_smooth=77.4; top_k=20 : y = 0.929 : 22.3 secs : infill_ei
#
# Tue Jul 29 05:10:53 2025 AUC 0.928280536212246
#
# [mbo] 9: learning_rate=0.0461; feature_fraction=0.468; bagging_fraction=0.649; num_leaves=331; min_data_in_leaf=548; lambda_l2=6.9; lambda_l1=2.82; max_depth=12; min_gain_to_split=1.17; min_sum_hessian_in_leaf=87; scale_pos_weight=7.47; path_smooth=31.8; top_k=9 : y = 0.928 : 44.1 secs : infill_ei
#
# Tue Jul 29 05:11:20 2025 AUC 0.929655211082665
#
# [mbo] 10: learning_rate=0.0454; feature_fraction=0.801; bagging_fraction=0.811; num_leaves=1552; min_data_in_leaf=584; lambda_l2=3.59; lambda_l1=0.93; max_depth=10; min_gain_to_split=0.972; min_sum_hessian_in_leaf=46.8; scale_pos_weight=7.1; path_smooth=69.3; top_k=27 : y = 0.93 : 25.8 secs : infill_ei
#
# Tue Jul 29 05:12:00 2025 AUC 0.930087301639805
#
# [mbo] 11: learning_rate=0.0466; feature_fraction=0.458; bagging_fraction=0.362; num_leaves=312; min_data_in_leaf=277; lambda_l2=7.02; lambda_l1=1.2; max_depth=8; min_gain_to_split=1.53; min_sum_hessian_in_leaf=72.3; scale_pos_weight=7.03; path_smooth=98.5; top_k=20 : y = 0.93 : 39.8 secs : infill_ei
#
# Tue Jul 29 05:12:48 2025 AUC 0.929628349892522
#
# [mbo] 12: learning_rate=0.0266; feature_fraction=0.402; bagging_fraction=0.531; num_leaves=1281; min_data_in_leaf=702; lambda_l2=7.94; lambda_l1=2.35; max_depth=8; min_gain_to_split=1.27; min_sum_hessian_in_leaf=70.7; scale_pos_weight=8.77; path_smooth=81.3; top_k=31 : y = 0.93 : 46.0 secs : infill_ei
#
# Tue Jul 29 05:13:14 2025 AUC 0.929129987195235
#
# [mbo] 13: learning_rate=0.0352; feature_fraction=0.673; bagging_fraction=0.63; num_leaves=605; min_data_in_leaf=294; lambda_l2=7.93; lambda_l1=2.43; max_depth=10; min_gain_to_split=0.839; min_sum_hessian_in_leaf=40.5; scale_pos_weight=2.56; path_smooth=97.8; top_k=36 : y = 0.929 : 24.9 secs : infill_ei
#
# Tue Jul 29 05:14:01 2025 AUC 0.928582151801673
#
# [mbo] 14: learning_rate=0.0219; feature_fraction=0.794; bagging_fraction=0.616; num_leaves=631; min_data_in_leaf=842; lambda_l2=9.56; lambda_l1=3.07; max_depth=9; min_gain_to_split=0.268; min_sum_hessian_in_leaf=74.3; scale_pos_weight=8.09; path_smooth=98.1; top_k=10 : y = 0.929 : 46.0 secs : infill_ei
#
# Tue Jul 29 05:15:18 2025 AUC 0.929829204361774
#
# [mbo] 15: learning_rate=0.0043; feature_fraction=0.593; bagging_fraction=0.359; num_leaves=1076; min_data_in_leaf=135; lambda_l2=5.16; lambda_l1=1.69; max_depth=14; min_gain_to_split=0.526; min_sum_hessian_in_leaf=60.7; scale_pos_weight=9.08; path_smooth=84; top_k=36 : y = 0.93 : 76.0 secs : infill_ei
#
# Tue Jul 29 05:16:27 2025 AUC 0.930547861801157
#
# [mbo] 16: learning_rate=0.00441; feature_fraction=0.475; bagging_fraction=0.415; num_leaves=342; min_data_in_leaf=867; lambda_l2=1.82; lambda_l1=1.53; max_depth=12; min_gain_to_split=0.478; min_sum_hessian_in_leaf=10.8; scale_pos_weight=9.09; path_smooth=23.2; top_k=20 : y = 0.931 : 67.8 secs : infill_ei
#
# Saved the current state after iteration 17 in the file bayesiana.RDATA.
#
# Tue Jul 29 05:17:43 2025 AUC 0.924993835283003
#
# [mbo] 17: learning_rate=0.0011; feature_fraction=0.388; bagging_fraction=0.444; num_leaves=917; min_data_in_leaf=179; lambda_l2=1.05; lambda_l1=1.81; max_depth=10; min_gain_to_split=0.614; min_sum_hessian_in_leaf=48.9; scale_pos_weight=7.34; path_smooth=18.6; top_k=16 : y = 0.925 : 71.4 secs : infill_ei
#
# Tue Jul 29 05:18:44 2025 AUC 0.929454685646403
#
# [mbo] 18: learning_rate=0.0207; feature_fraction=0.465; bagging_fraction=0.104; num_leaves=339; min_data_in_leaf=830; lambda_l2=7.95; lambda_l1=0.463; max_depth=13; min_gain_to_split=0.65; min_sum_hessian_in_leaf=64.1; scale_pos_weight=9.54; path_smooth=80.7; top_k=20 : y = 0.929 : 59.2 secs : infill_ei
#
# Tue Jul 29 05:19:13 2025 AUC 0.929642978420338
#
# [mbo] 19: learning_rate=0.0338; feature_fraction=0.672; bagging_fraction=0.53; num_leaves=243; min_data_in_leaf=734; lambda_l2=2.8; lambda_l1=1.89; max_depth=14; min_gain_to_split=1.08; min_sum_hessian_in_leaf=25.6; scale_pos_weight=9.26; path_smooth=87.5; top_k=27 : y = 0.93 : 27.7 secs : infill_ei
#
# Tue Jul 29 05:20:02 2025 AUC 0.927673704322412
#
# [mbo] 20: learning_rate=0.0223; feature_fraction=0.705; bagging_fraction=0.564; num_leaves=705; min_data_in_leaf=1652; lambda_l2=5.45; lambda_l1=3.85; max_depth=14; min_gain_to_split=0.38; min_sum_hessian_in_leaf=30.1; scale_pos_weight=9.99; path_smooth=8.81; top_k=27 : y = 0.928 : 48.4 secs : infill_ei
#
# Tue Jul 29 05:20:40 2025 AUC 0.929506218580281
#
# [mbo] 21: learning_rate=0.0323; feature_fraction=0.684; bagging_fraction=0.403; num_leaves=475; min_data_in_leaf=421; lambda_l2=7.13; lambda_l1=1.42; max_depth=11; min_gain_to_split=0.612; min_sum_hessian_in_leaf=8.82; scale_pos_weight=9.06; path_smooth=81; top_k=21 : y = 0.93 : 37.0 secs : infill_ei
#
# Tue Jul 29 05:21:17 2025 AUC 0.929823118040879
#
# [mbo] 22: learning_rate=0.0377; feature_fraction=0.592; bagging_fraction=0.432; num_leaves=1838; min_data_in_leaf=803; lambda_l2=4.78; lambda_l1=2.17; max_depth=14; min_gain_to_split=0.594; min_sum_hessian_in_leaf=25.6; scale_pos_weight=2.01; path_smooth=40.5; top_k=26 : y = 0.93 : 35.6 secs : infill_ei
#
# Tue Jul 29 05:21:49 2025 AUC 0.92725421321061
#
# [mbo] 23: learning_rate=0.0666; feature_fraction=0.575; bagging_fraction=0.686; num_leaves=1839; min_data_in_leaf=316; lambda_l2=9.09; lambda_l1=1.85; max_depth=11; min_gain_to_split=1.21; min_sum_hessian_in_leaf=63.8; scale_pos_weight=2.52; path_smooth=79.1; top_k=21 : y = 0.927 : 30.6 secs : infill_ei
#
# Tue Jul 29 05:22:27 2025 AUC 0.927887617233285
#
# [mbo] 24: learning_rate=0.0575; feature_fraction=0.489; bagging_fraction=0.36; num_leaves=1363; min_data_in_leaf=984; lambda_l2=3.57; lambda_l1=0.418; max_depth=9; min_gain_to_split=1.59; min_sum_hessian_in_leaf=0.145; scale_pos_weight=1.12; path_smooth=56.1; top_k=22 : y = 0.928 : 36.4 secs : infill_ei
#
# Tue Jul 29 05:23:40 2025 AUC 0.926895242509382
#
# [mbo] 25: learning_rate=0.0017; feature_fraction=0.565; bagging_fraction=0.249; num_leaves=1801; min_data_in_leaf=790; lambda_l2=4.01; lambda_l1=3.39; max_depth=13; min_gain_to_split=1.14; min_sum_hessian_in_leaf=12.3; scale_pos_weight=7.43; path_smooth=79.8; top_k=37 : y = 0.927 : 71.8 secs : infill_ei
#
# Tue Jul 29 05:24:18 2025 AUC 0.92828473177254
#
# [mbo] 26: learning_rate=0.0855; feature_fraction=0.478; bagging_fraction=0.331; num_leaves=39; min_data_in_leaf=1178; lambda_l2=3.98; lambda_l1=1.44; max_depth=15; min_gain_to_split=0.388; min_sum_hessian_in_leaf=3.18; scale_pos_weight=1.17; path_smooth=15.8; top_k=26 : y = 0.928 : 37.5 secs : infill_ei
#
# Tue Jul 29 05:25:08 2025 AUC 0.929254681054373
#
# [mbo] 27: learning_rate=0.0389; feature_fraction=0.742; bagging_fraction=0.418; num_leaves=1244; min_data_in_leaf=922; lambda_l2=2.22; lambda_l1=0.836; max_depth=11; min_gain_to_split=0.101; min_sum_hessian_in_leaf=85.7; scale_pos_weight=9.79; path_smooth=81.9; top_k=46 : y = 0.929 : 47.9 secs : infill_ei
#
# Tue Jul 29 05:25:40 2025 AUC 0.929814324290806
#
# [mbo] 28: learning_rate=0.0329; feature_fraction=0.75; bagging_fraction=0.423; num_leaves=1389; min_data_in_leaf=503; lambda_l2=5.43; lambda_l1=1.38; max_depth=12; min_gain_to_split=1.19; min_sum_hessian_in_leaf=75.7; scale_pos_weight=9.74; path_smooth=91.4; top_k=4 : y = 0.93 : 31.4 secs : infill_ei
#
# Tue Jul 29 05:26:28 2025 AUC 0.929911793732149
#
# [mbo] 29: learning_rate=0.0357; feature_fraction=0.591; bagging_fraction=0.389; num_leaves=231; min_data_in_leaf=970; lambda_l2=4.52; lambda_l1=1.22; max_depth=11; min_gain_to_split=0.215; min_sum_hessian_in_leaf=34.7; scale_pos_weight=2.59; path_smooth=52.1; top_k=11 : y = 0.93 : 46.6 secs : infill_ei
#
# Tue Jul 29 05:27:03 2025 AUC 0.924445065817013
#
# [mbo] 30: learning_rate=0.354; feature_fraction=0.374; bagging_fraction=0.182; num_leaves=1418; min_data_in_leaf=254; lambda_l2=5.02; lambda_l1=0.538; max_depth=3; min_gain_to_split=0.265; min_sum_hessian_in_leaf=93.2; scale_pos_weight=0.771; path_smooth=51.7; top_k=37 : y = 0.924 : 33.5 secs : infill_ei
#
# Saved the current state after iteration 31 in the file bayesiana.RDATA.
#
# Tue Jul 29 05:27:48 2025 AUC 0.928940174323053
#
# [mbo] 31: learning_rate=0.0601; feature_fraction=0.592; bagging_fraction=0.357; num_leaves=425; min_data_in_leaf=740; lambda_l2=2.67; lambda_l1=1.51; max_depth=12; min_gain_to_split=0.288; min_sum_hessian_in_leaf=68.7; scale_pos_weight=6.31; path_smooth=73.5; top_k=29 : y = 0.929 : 38.8 secs : infill_ei
#
# Tue Jul 29 05:28:46 2025 AUC 0.927386423217295
#
# [mbo] 32: learning_rate=0.00233; feature_fraction=0.345; bagging_fraction=0.581; num_leaves=142; min_data_in_leaf=1069; lambda_l2=5.96; lambda_l1=1.26; max_depth=11; min_gain_to_split=1.61; min_sum_hessian_in_leaf=19; scale_pos_weight=4.01; path_smooth=60.3; top_k=36 : y = 0.927 : 56.8 secs : infill_ei
#
# Tue Jul 29 05:29:50 2025 AUC 0.929758971172375
#
# [mbo] 33: learning_rate=0.00391; feature_fraction=0.578; bagging_fraction=0.699; num_leaves=1076; min_data_in_leaf=1283; lambda_l2=3.36; lambda_l1=0.125; max_depth=14; min_gain_to_split=0.601; min_sum_hessian_in_leaf=38.3; scale_pos_weight=8.81; path_smooth=23.1; top_k=16 : y = 0.93 : 61.8 secs : infill_ei
#
# Tue Jul 29 05:30:25 2025 AUC 0.928811908491222
#
# [mbo] 34: learning_rate=0.0408; feature_fraction=0.674; bagging_fraction=0.934; num_leaves=1722; min_data_in_leaf=765; lambda_l2=3.32; lambda_l1=1.98; max_depth=15; min_gain_to_split=0.675; min_sum_hessian_in_leaf=90.2; scale_pos_weight=9.73; path_smooth=42.5; top_k=41 : y = 0.929 : 33.9 secs : infill_ei
#
# Tue Jul 29 05:30:45 2025 AUC 0.926427940282473
#
# [mbo] 35: learning_rate=0.067; feature_fraction=0.732; bagging_fraction=0.705; num_leaves=1635; min_data_in_leaf=1407; lambda_l2=0.543; lambda_l1=3.78; max_depth=14; min_gain_to_split=0.866; min_sum_hessian_in_leaf=36.9; scale_pos_weight=1.86; path_smooth=13.2; top_k=33 : y = 0.926 : 18.7 secs : infill_ei
#
# Tue Jul 29 05:31:16 2025 AUC 0.929277836873862
#
# [mbo] 36: learning_rate=0.0285; feature_fraction=0.641; bagging_fraction=0.314; num_leaves=639; min_data_in_leaf=710; lambda_l2=8.33; lambda_l1=0.511; max_depth=14; min_gain_to_split=1.24; min_sum_hessian_in_leaf=13; scale_pos_weight=3.08; path_smooth=12.4; top_k=17 : y = 0.929 : 29.9 secs : infill_ei
#
# Tue Jul 29 05:32:00 2025 AUC 0.928410816734436
#
# [mbo] 37: learning_rate=0.0186; feature_fraction=0.899; bagging_fraction=0.384; num_leaves=1123; min_data_in_leaf=931; lambda_l2=6.79; lambda_l1=0.986; max_depth=11; min_gain_to_split=1.01; min_sum_hessian_in_leaf=40.9; scale_pos_weight=8.8; path_smooth=86.8; top_k=15 : y = 0.928 : 42.2 secs : infill_ei
#
# Tue Jul 29 05:33:07 2025 AUC 0.928982117236984
#
# [mbo] 38: learning_rate=0.0176; feature_fraction=0.343; bagging_fraction=0.903; num_leaves=603; min_data_in_leaf=969; lambda_l2=4.74; lambda_l1=3.72; max_depth=15; min_gain_to_split=0.121; min_sum_hessian_in_leaf=12.9; scale_pos_weight=5.52; path_smooth=43.4; top_k=13 : y = 0.929 : 65.1 secs : infill_ei
#
# Tue Jul 29 05:33:49 2025 AUC 0.929518406698196
#
# [mbo] 39: learning_rate=0.0417; feature_fraction=0.464; bagging_fraction=0.831; num_leaves=341; min_data_in_leaf=859; lambda_l2=7.38; lambda_l1=1.72; max_depth=9; min_gain_to_split=0.668; min_sum_hessian_in_leaf=3.02; scale_pos_weight=2.38; path_smooth=27.1; top_k=2 : y = 0.93 : 41.0 secs : infill_ei
#
# Tue Jul 29 05:34:27 2025 AUC 0.928578923544088
#
# [mbo] 40: learning_rate=0.0318; feature_fraction=0.147; bagging_fraction=0.338; num_leaves=858; min_data_in_leaf=1066; lambda_l2=4.91; lambda_l1=2.89; max_depth=13; min_gain_to_split=0.732; min_sum_hessian_in_leaf=21; scale_pos_weight=2.01; path_smooth=24.2; top_k=3 : y = 0.929 : 36.0 secs : infill_ei
#
# Tue Jul 29 05:34:59 2025 AUC 0.928370631388792
#
# [mbo] 41: learning_rate=0.0669; feature_fraction=0.583; bagging_fraction=0.941; num_leaves=1469; min_data_in_leaf=689; lambda_l2=3.31; lambda_l1=2.49; max_depth=9; min_gain_to_split=1.83; min_sum_hessian_in_leaf=88.5; scale_pos_weight=9.75; path_smooth=89; top_k=17 : y = 0.928 : 31.2 secs : infill_ei
#
# Tue Jul 29 05:35:44 2025 AUC 0.929587647223093
#
# [mbo] 42: learning_rate=0.0408; feature_fraction=0.596; bagging_fraction=0.922; num_leaves=1375; min_data_in_leaf=657; lambda_l2=4.84; lambda_l1=1.02; max_depth=14; min_gain_to_split=0.268; min_sum_hessian_in_leaf=4.17; scale_pos_weight=2.97; path_smooth=83.7; top_k=19 : y = 0.93 : 42.6 secs : infill_ei
#
# Tue Jul 29 05:36:25 2025 AUC 0.92864005888104
#
# [mbo] 43: learning_rate=0.0353; feature_fraction=0.516; bagging_fraction=0.692; num_leaves=1186; min_data_in_leaf=580; lambda_l2=4.95; lambda_l1=2.06; max_depth=15; min_gain_to_split=1.78; min_sum_hessian_in_leaf=51.3; scale_pos_weight=3.3; path_smooth=76.1; top_k=19 : y = 0.929 : 40.3 secs : infill_ei
#
# Tue Jul 29 05:36:51 2025 AUC 0.929931591064636
#
# [mbo] 44: learning_rate=0.0411; feature_fraction=0.702; bagging_fraction=0.701; num_leaves=1113; min_data_in_leaf=874; lambda_l2=5.65; lambda_l1=2.35; max_depth=11; min_gain_to_split=0.465; min_sum_hessian_in_leaf=6.5; scale_pos_weight=1.88; path_smooth=12.8; top_k=19 : y = 0.93 : 24.0 secs : infill_ei
#
# Tue Jul 29 05:37:53 2025 AUC 0.928236571039065
#
# [mbo] 45: learning_rate=0.0375; feature_fraction=0.5; bagging_fraction=0.538; num_leaves=1478; min_data_in_leaf=1154; lambda_l2=6.11; lambda_l1=3.49; max_depth=12; min_gain_to_split=0.144; min_sum_hessian_in_leaf=81.6; scale_pos_weight=9.61; path_smooth=81.4; top_k=21 : y = 0.928 : 60.5 secs : infill_ei
#
# Saved the current state after iteration 46 in the file bayesiana.RDATA.
#
# Tue Jul 29 05:38:50 2025 AUC 0.928327430140212
#
# [mbo] 46: learning_rate=0.034; feature_fraction=0.494; bagging_fraction=0.341; num_leaves=684; min_data_in_leaf=1255; lambda_l2=2.74; lambda_l1=1.12; max_depth=7; min_gain_to_split=0.621; min_sum_hessian_in_leaf=86.1; scale_pos_weight=9.99; path_smooth=29; top_k=14 : y = 0.928 : 50.7 secs : infill_ei
#
# Tue Jul 29 05:39:35 2025 AUC 0.92819952181859
#
# [mbo] 47: learning_rate=0.0352; feature_fraction=0.651; bagging_fraction=0.971; num_leaves=1863; min_data_in_leaf=1484; lambda_l2=6.85; lambda_l1=0.554; max_depth=8; min_gain_to_split=0.0612; min_sum_hessian_in_leaf=21.5; scale_pos_weight=3.57; path_smooth=18.3; top_k=44 : y = 0.928 : 43.5 secs : infill_ei
#
# Tue Jul 29 05:40:25 2025 AUC 0.930157146921147
#
# [mbo] 48: learning_rate=0.0264; feature_fraction=0.425; bagging_fraction=0.296; num_leaves=677; min_data_in_leaf=660; lambda_l2=8.07; lambda_l1=1.91; max_depth=15; min_gain_to_split=0.51; min_sum_hessian_in_leaf=4.18; scale_pos_weight=2.08; path_smooth=91.7; top_k=1 : y = 0.93 : 48.5 secs : infill_ei
#
# Tue Jul 29 05:40:51 2025 AUC 0.927457084832715
#
# [mbo] 49: learning_rate=0.0297; feature_fraction=0.679; bagging_fraction=0.966; num_leaves=1014; min_data_in_leaf=842; lambda_l2=5.16; lambda_l1=0.679; max_depth=14; min_gain_to_split=0.491; min_sum_hessian_in_leaf=34.7; scale_pos_weight=0.867; path_smooth=36.1; top_k=49 : y = 0.927 : 24.8 secs : infill_ei
#
# Tue Jul 29 05:41:55 2025 AUC 0.929601545827524
#
# [mbo] 50: learning_rate=0.00608; feature_fraction=0.546; bagging_fraction=0.546; num_leaves=359; min_data_in_leaf=491; lambda_l2=7.88; lambda_l1=1.55; max_depth=10; min_gain_to_split=0.621; min_sum_hessian_in_leaf=81.6; scale_pos_weight=8.97; path_smooth=98.3; top_k=43 : y = 0.93 : 61.8 secs : infill_ei
#
# Tue Jul 29 05:43:03 2025 AUC 0.9291149226111
#
# [mbo] 51: learning_rate=0.0272; feature_fraction=0.489; bagging_fraction=0.962; num_leaves=1042; min_data_in_leaf=1306; lambda_l2=2.2; lambda_l1=1.65; max_depth=11; min_gain_to_split=0.188; min_sum_hessian_in_leaf=4.89; scale_pos_weight=9.82; path_smooth=34.3; top_k=7 : y = 0.929 : 66.6 secs : infill_ei
#
# Tue Jul 29 05:43:51 2025 AUC 0.929391800112491
#
# [mbo] 52: learning_rate=0.0332; feature_fraction=0.377; bagging_fraction=0.299; num_leaves=327; min_data_in_leaf=943; lambda_l2=4.97; lambda_l1=2.6; max_depth=10; min_gain_to_split=0.655; min_sum_hessian_in_leaf=41.7; scale_pos_weight=8.59; path_smooth=93.4; top_k=2 : y = 0.929 : 46.3 secs : infill_ei
#
# Tue Jul 29 05:44:32 2025 AUC 0.930493209284083
#
# [mbo] 53: learning_rate=0.0476; feature_fraction=0.433; bagging_fraction=0.291; num_leaves=121; min_data_in_leaf=630; lambda_l2=9.34; lambda_l1=3.3; max_depth=12; min_gain_to_split=0.87; min_sum_hessian_in_leaf=12.1; scale_pos_weight=2.3; path_smooth=74.4; top_k=16 : y = 0.93 : 38.9 secs : infill_ei
#
# Tue Jul 29 05:44:57 2025 AUC 0.928969331593656
#
# [mbo] 54: learning_rate=0.0597; feature_fraction=0.725; bagging_fraction=0.578; num_leaves=1845; min_data_in_leaf=708; lambda_l2=4.18; lambda_l1=2.26; max_depth=9; min_gain_to_split=0.954; min_sum_hessian_in_leaf=79.5; scale_pos_weight=8.39; path_smooth=31.5; top_k=48 : y = 0.929 : 23.5 secs : infill_ei
#
# Tue Jul 29 05:45:44 2025 AUC 0.929999699891948
#
# [mbo] 55: learning_rate=0.0362; feature_fraction=0.429; bagging_fraction=0.171; num_leaves=616; min_data_in_leaf=671; lambda_l2=6.89; lambda_l1=1.88; max_depth=10; min_gain_to_split=0.505; min_sum_hessian_in_leaf=6.6; scale_pos_weight=3.29; path_smooth=51; top_k=21 : y = 0.93 : 45.7 secs : infill_ei
#
# Tue Jul 29 05:46:19 2025 AUC 0.928460572973671
#
# [mbo] 56: learning_rate=0.0473; feature_fraction=0.607; bagging_fraction=0.997; num_leaves=505; min_data_in_leaf=897; lambda_l2=7.27; lambda_l1=0.432; max_depth=7; min_gain_to_split=0.796; min_sum_hessian_in_leaf=73.1; scale_pos_weight=6.82; path_smooth=94; top_k=32 : y = 0.928 : 32.9 secs : infill_ei
#
# Tue Jul 29 05:46:59 2025 AUC 0.92922272736415
#
# [mbo] 57: learning_rate=0.0294; feature_fraction=0.56; bagging_fraction=0.549; num_leaves=435; min_data_in_leaf=611; lambda_l2=4.34; lambda_l1=4.91; max_depth=12; min_gain_to_split=1.03; min_sum_hessian_in_leaf=0.747; scale_pos_weight=3.12; path_smooth=76.3; top_k=2 : y = 0.929 : 38.4 secs : infill_ei
#
# Tue Jul 29 05:47:41 2025 AUC 0.928860877760368
#
# [mbo] 58: learning_rate=0.0627; feature_fraction=0.428; bagging_fraction=0.52; num_leaves=288; min_data_in_leaf=622; lambda_l2=6.38; lambda_l1=1.15; max_depth=13; min_gain_to_split=0.786; min_sum_hessian_in_leaf=15.4; scale_pos_weight=3.49; path_smooth=88.6; top_k=12 : y = 0.929 : 38.9 secs : infill_ei
#
# Tue Jul 29 05:48:41 2025 AUC 0.927466870417564
#
# [mbo] 59: learning_rate=0.0325; feature_fraction=0.483; bagging_fraction=0.608; num_leaves=1603; min_data_in_leaf=1909; lambda_l2=3.04; lambda_l1=1.18; max_depth=10; min_gain_to_split=0.157; min_sum_hessian_in_leaf=18; scale_pos_weight=6.5; path_smooth=9.82; top_k=14 : y = 0.927 : 58.8 secs : infill_ei
#
# Saved the current state after iteration 60 in the file bayesiana.RDATA.
#
# Tue Jul 29 05:49:56 2025 AUC 0.928815135153091
#
# [mbo] 60: learning_rate=0.00232; feature_fraction=0.43; bagging_fraction=0.326; num_leaves=576; min_data_in_leaf=540; lambda_l2=9.41; lambda_l1=3.78; max_depth=13; min_gain_to_split=1.66; min_sum_hessian_in_leaf=49.1; scale_pos_weight=8.43; path_smooth=72.9; top_k=9 : y = 0.929 : 68.5 secs : infill_ei
#
# Tue Jul 29 05:51:07 2025 AUC 0.92929227754891
#
# [mbo] 61: learning_rate=0.0127; feature_fraction=0.509; bagging_fraction=0.444; num_leaves=95; min_data_in_leaf=1092; lambda_l2=7.86; lambda_l1=2.35; max_depth=13; min_gain_to_split=0.285; min_sum_hessian_in_leaf=5.55; scale_pos_weight=7.95; path_smooth=25.3; top_k=18 : y = 0.929 : 69.4 secs : infill_ei
#
# Tue Jul 29 05:51:40 2025 AUC 0.924513667200077
#
# [mbo] 62: learning_rate=0.266; feature_fraction=0.576; bagging_fraction=0.744; num_leaves=1214; min_data_in_leaf=1954; lambda_l2=4.71; lambda_l1=3.02; max_depth=3; min_gain_to_split=0.225; min_sum_hessian_in_leaf=85.1; scale_pos_weight=2.91; path_smooth=9.61; top_k=31 : y = 0.925 : 31.3 secs : infill_ei
#
# Tue Jul 29 05:52:02 2025 AUC 0.929725346281692
#
# [mbo] 63: learning_rate=0.0393; feature_fraction=0.686; bagging_fraction=0.289; num_leaves=1157; min_data_in_leaf=589; lambda_l2=9.32; lambda_l1=3.34; max_depth=14; min_gain_to_split=0.632; min_sum_hessian_in_leaf=6.54; scale_pos_weight=0.897; path_smooth=61.9; top_k=21 : y = 0.93 : 19.4 secs : infill_ei
#
# Tue Jul 29 05:52:34 2025 AUC 0.921801870218479
#
# [mbo] 64: learning_rate=0.271; feature_fraction=0.563; bagging_fraction=0.144; num_leaves=56; min_data_in_leaf=474; lambda_l2=7.21; lambda_l1=2.37; max_depth=15; min_gain_to_split=1.72; min_sum_hessian_in_leaf=29.6; scale_pos_weight=0.519; path_smooth=87.2; top_k=37 : y = 0.922 : 30.0 secs : infill_ei
#
# Tue Jul 29 05:53:12 2025 AUC 0.926785661602314
#
# [mbo] 65: learning_rate=0.0462; feature_fraction=0.505; bagging_fraction=0.235; num_leaves=374; min_data_in_leaf=814; lambda_l2=9.54; lambda_l1=2.2; max_depth=7; min_gain_to_split=1.74; min_sum_hessian_in_leaf=65.3; scale_pos_weight=2.17; path_smooth=74.7; top_k=12 : y = 0.927 : 36.3 secs : infill_ei
#
# Tue Jul 29 05:54:07 2025 AUC 0.929076501779427
#
# [mbo] 66: learning_rate=0.0134; feature_fraction=0.638; bagging_fraction=0.982; num_leaves=288; min_data_in_leaf=872; lambda_l2=3.5; lambda_l1=2.63; max_depth=12; min_gain_to_split=0.836; min_sum_hessian_in_leaf=26.3; scale_pos_weight=9.71; path_smooth=32.2; top_k=20 : y = 0.929 : 53.6 secs : infill_ei
#
# Tue Jul 29 05:55:25 2025 AUC 0.92891418996358
#
# [mbo] 67: learning_rate=0.0316; feature_fraction=0.545; bagging_fraction=0.427; num_leaves=1377; min_data_in_leaf=837; lambda_l2=8.78; lambda_l1=1.7; max_depth=15; min_gain_to_split=0.0625; min_sum_hessian_in_leaf=3.61; scale_pos_weight=3.14; path_smooth=28.8; top_k=42 : y = 0.929 : 75.6 secs : infill_ei
#
# Tue Jul 29 05:56:10 2025 AUC 0.929872788840848
#
# [mbo] 68: learning_rate=0.0372; feature_fraction=0.447; bagging_fraction=0.397; num_leaves=682; min_data_in_leaf=526; lambda_l2=3.47; lambda_l1=0.211; max_depth=11; min_gain_to_split=1.42; min_sum_hessian_in_leaf=81.2; scale_pos_weight=9.76; path_smooth=77.3; top_k=31 : y = 0.93 : 43.0 secs : infill_ei
#
# Tue Jul 29 05:56:36 2025 AUC 0.927136727032144
#
# [mbo] 69: learning_rate=0.182; feature_fraction=0.863; bagging_fraction=0.931; num_leaves=1775; min_data_in_leaf=1252; lambda_l2=0.949; lambda_l1=0.669; max_depth=7; min_gain_to_split=0.0269; min_sum_hessian_in_leaf=0.202; scale_pos_weight=0.621; path_smooth=17.8; top_k=43 : y = 0.927 : 23.9 secs : infill_ei
#
# Tue Jul 29 05:57:18 2025 AUC 0.930101340746305
#
# [mbo] 70: learning_rate=0.0318; feature_fraction=0.593; bagging_fraction=0.296; num_leaves=1055; min_data_in_leaf=477; lambda_l2=6.94; lambda_l1=2.4; max_depth=14; min_gain_to_split=1.09; min_sum_hessian_in_leaf=99.2; scale_pos_weight=7.63; path_smooth=99.7; top_k=25 : y = 0.93 : 40.4 secs : infill_ei
#
# Tue Jul 29 05:58:15 2025 AUC 0.929213425250147
#
# [mbo] 71: learning_rate=0.027; feature_fraction=0.549; bagging_fraction=0.833; num_leaves=1821; min_data_in_leaf=1013; lambda_l2=4.47; lambda_l1=0.168; max_depth=9; min_gain_to_split=0.559; min_sum_hessian_in_leaf=70.1; scale_pos_weight=8.15; path_smooth=34.2; top_k=6 : y = 0.929 : 54.6 secs : infill_ei
#
# Tue Jul 29 05:58:32 2025 AUC 0.922535171519048
#
# [mbo] 72: learning_rate=0.4; feature_fraction=0.81; bagging_fraction=0.839; num_leaves=1539; min_data_in_leaf=321; lambda_l2=2.19; lambda_l1=2.72; max_depth=3; min_gain_to_split=0.249; min_sum_hessian_in_leaf=89.5; scale_pos_weight=0.523; path_smooth=97.4; top_k=35 : y = 0.923 : 15.1 secs : infill_ei
#
# Tue Jul 29 05:59:10 2025 AUC 0.925539758839811
#
# [mbo] 73: learning_rate=0.217; feature_fraction=0.533; bagging_fraction=0.264; num_leaves=144; min_data_in_leaf=1853; lambda_l2=0.313; lambda_l1=2.85; max_depth=9; min_gain_to_split=0.128; min_sum_hessian_in_leaf=0.695; scale_pos_weight=1.84; path_smooth=19.2; top_k=19 : y = 0.926 : 35.7 secs : infill_ei
#
# Saved the current state after iteration 74 in the file bayesiana.RDATA.
#
# Tue Jul 29 05:59:58 2025 AUC 0.930144637414491
#
# [mbo] 74: learning_rate=0.026; feature_fraction=0.603; bagging_fraction=0.304; num_leaves=814; min_data_in_leaf=892; lambda_l2=2.25; lambda_l1=2.61; max_depth=15; min_gain_to_split=0.398; min_sum_hessian_in_leaf=2.13; scale_pos_weight=3.27; path_smooth=29.4; top_k=8 : y = 0.93 : 40.6 secs : infill_ei
#
# Tue Jul 29 06:00:58 2025 AUC 0.92940192734816
#
# [mbo] 75: learning_rate=0.0151; feature_fraction=0.662; bagging_fraction=0.303; num_leaves=169; min_data_in_leaf=741; lambda_l2=3.55; lambda_l1=1.68; max_depth=15; min_gain_to_split=0.583; min_sum_hessian_in_leaf=76.6; scale_pos_weight=9.83; path_smooth=48.7; top_k=17 : y = 0.929 : 57.9 secs : infill_ei
#
# Tue Jul 29 06:01:38 2025 AUC 0.929106188081878
#
# [mbo] 76: learning_rate=0.038; feature_fraction=0.603; bagging_fraction=0.73; num_leaves=27; min_data_in_leaf=451; lambda_l2=1.2; lambda_l1=2.74; max_depth=8; min_gain_to_split=0.894; min_sum_hessian_in_leaf=79.8; scale_pos_weight=9.67; path_smooth=98.7; top_k=22 : y = 0.929 : 37.3 secs : infill_ei
#
# Tue Jul 29 06:02:43 2025 AUC 0.920306743186029
#
# [mbo] 77: learning_rate=0.00116; feature_fraction=0.513; bagging_fraction=0.824; num_leaves=686; min_data_in_leaf=957; lambda_l2=4.37; lambda_l1=2.01; max_depth=12; min_gain_to_split=0.373; min_sum_hessian_in_leaf=0.266; scale_pos_weight=1.53; path_smooth=64.1; top_k=12 : y = 0.92 : 62.6 secs : infill_ei
#
# Tue Jul 29 06:03:17 2025 AUC 0.929298982668126
#
# [mbo] 78: learning_rate=0.0465; feature_fraction=0.699; bagging_fraction=0.29; num_leaves=380; min_data_in_leaf=662; lambda_l2=8.85; lambda_l1=4.62; max_depth=15; min_gain_to_split=0.225; min_sum_hessian_in_leaf=18.1; scale_pos_weight=2.94; path_smooth=34.1; top_k=8 : y = 0.929 : 31.3 secs : infill_ei
#
# Tue Jul 29 06:04:03 2025 AUC 0.92984655721627
#
# [mbo] 79: learning_rate=0.0422; feature_fraction=0.537; bagging_fraction=0.402; num_leaves=1261; min_data_in_leaf=550; lambda_l2=6.12; lambda_l1=3.95; max_depth=14; min_gain_to_split=0.808; min_sum_hessian_in_leaf=8.29; scale_pos_weight=4.63; path_smooth=45.1; top_k=3 : y = 0.93 : 44.2 secs : infill_ei
#
# Tue Jul 29 06:05:03 2025 AUC 0.928287744540441
#
# [mbo] 80: learning_rate=0.0283; feature_fraction=0.203; bagging_fraction=0.376; num_leaves=257; min_data_in_leaf=816; lambda_l2=3.67; lambda_l1=0.675; max_depth=15; min_gain_to_split=0.357; min_sum_hessian_in_leaf=0.914; scale_pos_weight=8.95; path_smooth=24.4; top_k=31 : y = 0.928 : 57.3 secs : infill_ei
#
# Tue Jul 29 06:05:45 2025 AUC 0.929848535787386
#
# [mbo] 81: learning_rate=0.0421; feature_fraction=0.494; bagging_fraction=0.248; num_leaves=121; min_data_in_leaf=681; lambda_l2=4.96; lambda_l1=4.06; max_depth=9; min_gain_to_split=0.939; min_sum_hessian_in_leaf=10.5; scale_pos_weight=3.1; path_smooth=18.7; top_k=27 : y = 0.93 : 40.5 secs : infill_ei
#
# Tue Jul 29 06:06:16 2025 AUC 0.928767002018636
#
# [mbo] 82: learning_rate=0.061; feature_fraction=0.768; bagging_fraction=0.162; num_leaves=1492; min_data_in_leaf=771; lambda_l2=4.85; lambda_l1=0.628; max_depth=12; min_gain_to_split=0.284; min_sum_hessian_in_leaf=1.71; scale_pos_weight=2.35; path_smooth=24.5; top_k=1 : y = 0.929 : 28.7 secs : infill_ei
#
# Tue Jul 29 06:06:55 2025 AUC 0.929435676795192
#
# ...
#
# Tue Jul 29 12:53:51 2025 AUC 0.930235529871467
#
# [mbo] 557: learning_rate=0.0254; feature_fraction=0.477; bagging_fraction=0.133; num_leaves=1451; min_data_in_leaf=554; lambda_l2=5.41; lambda_l1=2.76; max_depth=15; min_gain_to_split=0.914; min_sum_hessian_in_leaf=26.2; scale_pos_weight=9.36; path_smooth=70.8; top_k=6 : y = 0.93 : 55.4 secs : infill_ei
#
# Tue Jul 29 12:54:43 2025 AUC 0.926683773122601
#
# [mbo] 558: learning_rate=0.181; feature_fraction=0.255; bagging_fraction=0.588; num_leaves=1482; min_data_in_leaf=245; lambda_l2=8.74; lambda_l1=1.57; max_depth=6; min_gain_to_split=0.0654; min_sum_hessian_in_leaf=21.9; scale_pos_weight=0.522; path_smooth=1.14; top_k=4 : y = 0.927 : 34.7 secs : infill_ei
#
# Tue Jul 29 12:55:56 2025 AUC 0.927797188454605
#
# [mbo] 559: learning_rate=0.0662; feature_fraction=0.618; bagging_fraction=0.925; num_leaves=1062; min_data_in_leaf=830; lambda_l2=5.61; lambda_l1=4.47; max_depth=10; min_gain_to_split=0.00208; min_sum_hessian_in_leaf=73.4; scale_pos_weight=6.06; path_smooth=32.4; top_k=18 : y = 0.928 : 56.4 secs : infill_ei
#
# Tue Jul 29 12:57:17 2025 AUC 0.930520952840923
#
# [mbo] 560: learning_rate=0.0203; feature_fraction=0.804; bagging_fraction=0.588; num_leaves=1934; min_data_in_leaf=720; lambda_l2=0.944; lambda_l1=4.88; max_depth=11; min_gain_to_split=0.354; min_sum_hessian_in_leaf=47.5; scale_pos_weight=9.89; path_smooth=17.9; top_k=5 : y = 0.931 : 55.3 secs : infill_ei
#
# Tue Jul 29 12:58:14 2025 AUC 0.929660522013936
#
# [mbo] 561: learning_rate=0.0245; feature_fraction=0.694; bagging_fraction=0.328; num_leaves=504; min_data_in_leaf=794; lambda_l2=0.887; lambda_l1=2.12; max_depth=15; min_gain_to_split=0.502; min_sum_hessian_in_leaf=8.51; scale_pos_weight=8.38; path_smooth=50.3; top_k=20 : y = 0.93 : 43.6 secs : infill_ei
#
# Tue Jul 29 12:59:28 2025 AUC 0.930861973491331
#
# [mbo] 562: learning_rate=0.0252; feature_fraction=0.584; bagging_fraction=0.963; num_leaves=1555; min_data_in_leaf=93; lambda_l2=6.59; lambda_l1=4.77; max_depth=12; min_gain_to_split=0.541; min_sum_hessian_in_leaf=22.8; scale_pos_weight=6.71; path_smooth=89.3; top_k=44 : y = 0.931 : 51.4 secs : infill_ei
#
# Saved the current state after iteration 563 in the file bayesiana.RDATA.
#
# Tue Jul 29 13:00:14 2025 AUC 0.926948679189711
#
# [mbo] 563: learning_rate=0.216; feature_fraction=0.747; bagging_fraction=0.829; num_leaves=411; min_data_in_leaf=781; lambda_l2=2.85; lambda_l1=4.56; max_depth=4; min_gain_to_split=0.112; min_sum_hessian_in_leaf=15.5; scale_pos_weight=0.729; path_smooth=91; top_k=45 : y = 0.927 : 18.0 secs : infill_ei
#
# Tue Jul 29 13:00:54 2025 AUC 0.922406142982313
#
# [mbo] 564: learning_rate=0.218; feature_fraction=0.67; bagging_fraction=0.293; num_leaves=51; min_data_in_leaf=1993; lambda_l2=7.04; lambda_l1=3.49; max_depth=7; min_gain_to_split=0.21; min_sum_hessian_in_leaf=98.1; scale_pos_weight=9.02; path_smooth=63.5; top_k=26 : y = 0.922 : 24.8 secs : infill_ei
#
# Tue Jul 29 13:02:07 2025 AUC 0.926405369884531
#
# [mbo] 565: learning_rate=0.0469; feature_fraction=0.866; bagging_fraction=0.969; num_leaves=737; min_data_in_leaf=809; lambda_l2=0.241; lambda_l1=1.36; max_depth=15; min_gain_to_split=0.001; min_sum_hessian_in_leaf=62; scale_pos_weight=3; path_smooth=82; top_k=40 : y = 0.926 : 51.7 secs : infill_ei
#
# Tue Jul 29 13:03:09 2025 AUC 0.928631996720577
#
# [mbo] 566: learning_rate=0.028; feature_fraction=0.801; bagging_fraction=0.281; num_leaves=596; min_data_in_leaf=560; lambda_l2=1.78; lambda_l1=4.95; max_depth=14; min_gain_to_split=0.319; min_sum_hessian_in_leaf=90.7; scale_pos_weight=9.91; path_smooth=67.1; top_k=10 : y = 0.929 : 48.4 secs : infill_ei
#
# Tue Jul 29 13:03:58 2025 AUC 0.926834770804408
#
# [mbo] 567: learning_rate=0.205; feature_fraction=0.322; bagging_fraction=0.257; num_leaves=38; min_data_in_leaf=35; lambda_l2=7.27; lambda_l1=3.46; max_depth=5; min_gain_to_split=1.48; min_sum_hessian_in_leaf=70.6; scale_pos_weight=5.17; path_smooth=13.3; top_k=40 : y = 0.927 : 33.9 secs : infill_ei
#
# Tue Jul 29 13:05:01 2025 AUC 0.928893400379069
#
# [mbo] 568: learning_rate=0.024; feature_fraction=0.258; bagging_fraction=0.41; num_leaves=151; min_data_in_leaf=606; lambda_l2=7.49; lambda_l1=3.51; max_depth=15; min_gain_to_split=1.65; min_sum_hessian_in_leaf=16.4; scale_pos_weight=5.75; path_smooth=68; top_k=44 : y = 0.929 : 43.1 secs : infill_ei
#
# Tue Jul 29 13:05:58 2025 AUC 0.930748849026266
#
# [mbo] 569: learning_rate=0.0332; feature_fraction=0.724; bagging_fraction=0.865; num_leaves=1948; min_data_in_leaf=1317; lambda_l2=2.51; lambda_l1=0.578; max_depth=11; min_gain_to_split=0.58; min_sum_hessian_in_leaf=58.5; scale_pos_weight=9.93; path_smooth=19.8; top_k=22 : y = 0.931 : 41.8 secs : infill_ei
#
# Tue Jul 29 13:07:05 2025 AUC 0.929939441613639
#
# [mbo] 570: learning_rate=0.1; feature_fraction=0.541; bagging_fraction=0.335; num_leaves=1412; min_data_in_leaf=585; lambda_l2=9.01; lambda_l1=1.93; max_depth=5; min_gain_to_split=0.135; min_sum_hessian_in_leaf=32.9; scale_pos_weight=4.48; path_smooth=83; top_k=2 : y = 0.93 : 45.4 secs : infill_ei
#
# Tue Jul 29 13:07:45 2025 AUC 0.925961804380376
#
# [mbo] 571: learning_rate=0.278; feature_fraction=0.711; bagging_fraction=0.962; num_leaves=203; min_data_in_leaf=790; lambda_l2=0.243; lambda_l1=4.13; max_depth=3; min_gain_to_split=1.62; min_sum_hessian_in_leaf=0.749; scale_pos_weight=1.07; path_smooth=41.1; top_k=19 : y = 0.926 : 14.7 secs : infill_ei
#
# Tue Jul 29 13:08:42 2025 AUC 0.931043256334868
#
# [mbo] 572: learning_rate=0.0273; feature_fraction=0.576; bagging_fraction=0.136; num_leaves=1889; min_data_in_leaf=21; lambda_l2=7.32; lambda_l1=4.72; max_depth=8; min_gain_to_split=1.72; min_sum_hessian_in_leaf=49.4; scale_pos_weight=6.63; path_smooth=29.4; top_k=30 : y = 0.931 : 40.0 secs : infill_ei
#
# Tue Jul 29 13:09:53 2025 AUC 0.929685750454915
#
# [mbo] 573: learning_rate=0.0305; feature_fraction=0.362; bagging_fraction=0.193; num_leaves=1407; min_data_in_leaf=102; lambda_l2=8.25; lambda_l1=4.56; max_depth=11; min_gain_to_split=1.26; min_sum_hessian_in_leaf=32.5; scale_pos_weight=4.92; path_smooth=81; top_k=5 : y = 0.93 : 45.1 secs : infill_ei
#
# Saved the current state after iteration 574 in the file bayesiana.RDATA.
#
# Tue Jul 29 13:11:26 2025 AUC 0.928158074439935
#
# [mbo] 574: learning_rate=0.0152; feature_fraction=0.215; bagging_fraction=0.683; num_leaves=279; min_data_in_leaf=1038; lambda_l2=1.62; lambda_l1=2.51; max_depth=12; min_gain_to_split=0.631; min_sum_hessian_in_leaf=17.9; scale_pos_weight=9.84; path_smooth=15.9; top_k=10 : y = 0.928 : 59.6 secs : infill_ei
#
# Tue Jul 29 13:12:32 2025 AUC 0.929719113000695
#
# [mbo] 575: learning_rate=0.0477; feature_fraction=0.467; bagging_fraction=0.283; num_leaves=1792; min_data_in_leaf=106; lambda_l2=7.26; lambda_l1=4.09; max_depth=5; min_gain_to_split=1.75; min_sum_hessian_in_leaf=48.1; scale_pos_weight=5.55; path_smooth=81.9; top_k=40 : y = 0.93 : 41.0 secs : infill_ei
#
# Tue Jul 29 13:13:31 2025 AUC 0.928004772458262
#
# [mbo] 576: learning_rate=0.0494; feature_fraction=0.485; bagging_fraction=0.375; num_leaves=23; min_data_in_leaf=515; lambda_l2=3.99; lambda_l1=2.5; max_depth=4; min_gain_to_split=1.92; min_sum_hessian_in_leaf=81.7; scale_pos_weight=8.82; path_smooth=65.3; top_k=24 : y = 0.928 : 43.8 secs : infill_ei
#
# Tue Jul 29 13:14:48 2025 AUC 0.930395890171045
#
# [mbo] 577: learning_rate=0.0294; feature_fraction=0.461; bagging_fraction=0.898; num_leaves=223; min_data_in_leaf=618; lambda_l2=0.658; lambda_l1=4.95; max_depth=11; min_gain_to_split=0.904; min_sum_hessian_in_leaf=32; scale_pos_weight=7.6; path_smooth=98; top_k=4 : y = 0.93 : 49.8 secs : infill_ei
#
# Tue Jul 29 13:16:00 2025 AUC 0.930267959392096
#
# [mbo] 578: learning_rate=0.0288; feature_fraction=0.64; bagging_fraction=0.883; num_leaves=1888; min_data_in_leaf=20; lambda_l2=5.95; lambda_l1=3.9; max_depth=10; min_gain_to_split=0.389; min_sum_hessian_in_leaf=38.9; scale_pos_weight=7.17; path_smooth=69.3; top_k=13 : y = 0.93 : 48.1 secs : infill_ei
#
# Tue Jul 29 13:17:08 2025 AUC 0.925743150332427
#
# [mbo] 579: learning_rate=0.116; feature_fraction=0.13; bagging_fraction=0.965; num_leaves=1670; min_data_in_leaf=1837; lambda_l2=1.26; lambda_l1=0.371; max_depth=11; min_gain_to_split=0.0216; min_sum_hessian_in_leaf=92.8; scale_pos_weight=3.05; path_smooth=77.7; top_k=38 : y = 0.926 : 44.4 secs : infill_ei
#
# Tue Jul 29 13:18:47 2025 AUC 0.931070093139256
#
# [mbo] 580: learning_rate=0.00629; feature_fraction=0.473; bagging_fraction=0.746; num_leaves=1699; min_data_in_leaf=559; lambda_l2=0.974; lambda_l1=1.57; max_depth=11; min_gain_to_split=1.61; min_sum_hessian_in_leaf=39.5; scale_pos_weight=10; path_smooth=84.4; top_k=50 : y = 0.931 : 73.9 secs : infill_ei
#
# Tue Jul 29 13:20:08 2025 AUC 0.927772104009314
#
# [mbo] 581: learning_rate=0.0431; feature_fraction=0.57; bagging_fraction=0.413; num_leaves=742; min_data_in_leaf=693; lambda_l2=8.07; lambda_l1=1.68; max_depth=12; min_gain_to_split=0.181; min_sum_hessian_in_leaf=83.9; scale_pos_weight=7.21; path_smooth=66.9; top_k=44 : y = 0.928 : 60.5 secs : infill_ei
#
# Saved the current state after iteration 582 in the file bayesiana.RDATA.
#
# Tue Jul 29 13:21:22 2025 AUC 0.928353098311727
#
# [mbo] 582: learning_rate=0.0336; feature_fraction=0.629; bagging_fraction=0.816; num_leaves=1871; min_data_in_leaf=1819; lambda_l2=1.48; lambda_l1=0.138; max_depth=11; min_gain_to_split=1.06; min_sum_hessian_in_leaf=57.5; scale_pos_weight=9.91; path_smooth=84.8; top_k=38 : y = 0.928 : 38.8 secs : infill_ei
#
# Tue Jul 29 13:22:55 2025 AUC 0.930842714963604
#
# [mbo] 583: learning_rate=0.0299; feature_fraction=0.694; bagging_fraction=0.955; num_leaves=2005; min_data_in_leaf=30; lambda_l2=7.83; lambda_l1=4.65; max_depth=13; min_gain_to_split=0.0702; min_sum_hessian_in_leaf=44.1; scale_pos_weight=8.94; path_smooth=36; top_k=25 : y = 0.931 : 68.9 secs : infill_ei
#
# Tue Jul 29 13:23:57 2025 AUC 0.924551038859606
#
# [mbo] 584: learning_rate=0.217; feature_fraction=0.471; bagging_fraction=0.972; num_leaves=1359; min_data_in_leaf=350; lambda_l2=0.428; lambda_l1=1.8; max_depth=3; min_gain_to_split=0.212; min_sum_hessian_in_leaf=50.5; scale_pos_weight=4.96; path_smooth=40.5; top_k=48 : y = 0.925 : 40.6 secs : infill_ei
#
# Tue Jul 29 13:25:08 2025 AUC 0.929352436559716
#
# [mbo] 585: learning_rate=0.0321; feature_fraction=0.503; bagging_fraction=0.278; num_leaves=1603; min_data_in_leaf=667; lambda_l2=3.13; lambda_l1=3.83; max_depth=15; min_gain_to_split=0.397; min_sum_hessian_in_leaf=39.3; scale_pos_weight=3.77; path_smooth=72; top_k=12 : y = 0.929 : 52.6 secs : infill_ei
#
# Tue Jul 29 13:26:22 2025 AUC 0.928377529718794
#
# [mbo] 586: learning_rate=0.0353; feature_fraction=0.851; bagging_fraction=0.369; num_leaves=42; min_data_in_leaf=1147; lambda_l2=7.95; lambda_l1=4.38; max_depth=8; min_gain_to_split=0.00208; min_sum_hessian_in_leaf=12.8; scale_pos_weight=2.62; path_smooth=84.7; top_k=5 : y = 0.928 : 50.3 secs : infill_ei
#
# Tue Jul 29 13:27:50 2025 AUC 0.929075179142725
#
# [mbo] 587: learning_rate=0.0254; feature_fraction=0.315; bagging_fraction=0.92; num_leaves=762; min_data_in_leaf=840; lambda_l2=7.61; lambda_l1=4.57; max_depth=12; min_gain_to_split=0.0216; min_sum_hessian_in_leaf=7.26; scale_pos_weight=6.46; path_smooth=91.5; top_k=50 : y = 0.929 : 68.2 secs : infill_ei
#
# Tue Jul 29 13:28:50 2025 AUC 0.929636760564545
#
# [mbo] 588: learning_rate=0.0316; feature_fraction=0.47; bagging_fraction=0.746; num_leaves=1422; min_data_in_leaf=540; lambda_l2=7.99; lambda_l1=1.46; max_depth=11; min_gain_to_split=1.4; min_sum_hessian_in_leaf=18.2; scale_pos_weight=2.94; path_smooth=77.5; top_k=42 : y = 0.93 : 42.5 secs : infill_ei
#
# Tue Jul 29 13:29:48 2025 AUC 0.929355677157969
#
# [mbo] 589: learning_rate=0.0247; feature_fraction=0.438; bagging_fraction=0.136; num_leaves=1813; min_data_in_leaf=23; lambda_l2=7.16; lambda_l1=3.62; max_depth=12; min_gain_to_split=1.82; min_sum_hessian_in_leaf=47.1; scale_pos_weight=2.87; path_smooth=30.5; top_k=31 : y = 0.929 : 42.4 secs : infill_ei
#
# Tue Jul 29 13:31:11 2025 AUC 0.929304481784011
#
# [mbo] 590: learning_rate=0.0528; feature_fraction=0.566; bagging_fraction=0.998; num_leaves=1097; min_data_in_leaf=404; lambda_l2=7.17; lambda_l1=2.58; max_depth=6; min_gain_to_split=0.0454; min_sum_hessian_in_leaf=21.5; scale_pos_weight=4.61; path_smooth=68; top_k=25 : y = 0.929 : 57.5 secs : infill_ei
#
# Saved the current state after iteration 591 in the file bayesiana.RDATA.
#
# Tue Jul 29 13:32:36 2025 AUC 0.929884294391937
#
# [mbo] 591: learning_rate=0.0179; feature_fraction=0.348; bagging_fraction=0.442; num_leaves=1749; min_data_in_leaf=508; lambda_l2=1.75; lambda_l1=4.42; max_depth=11; min_gain_to_split=1.55; min_sum_hessian_in_leaf=30.2; scale_pos_weight=9.89; path_smooth=39.4; top_k=4 : y = 0.93 : 51.4 secs : infill_ei
#
# Tue Jul 29 13:33:31 2025 AUC 0.930604133929618
#
# [mbo] 592: learning_rate=0.0316; feature_fraction=0.598; bagging_fraction=0.368; num_leaves=157; min_data_in_leaf=879; lambda_l2=6.99; lambda_l1=3.46; max_depth=11; min_gain_to_split=0.389; min_sum_hessian_in_leaf=13.1; scale_pos_weight=2.91; path_smooth=43.5; top_k=26 : y = 0.931 : 40.2 secs : infill_ei
#
# Tue Jul 29 13:34:13 2025 AUC 0.926579930326362
#
# [mbo] 593: learning_rate=0.1; feature_fraction=0.874; bagging_fraction=0.986; num_leaves=1902; min_data_in_leaf=1839; lambda_l2=7.7; lambda_l1=1.47; max_depth=9; min_gain_to_split=0.213; min_sum_hessian_in_leaf=21.1; scale_pos_weight=0.633; path_smooth=46.2; top_k=12 : y = 0.927 : 19.6 secs : infill_ei
#
# Tue Jul 29 13:35:11 2025 AUC 0.929267491736499
#
# [mbo] 594: learning_rate=0.126; feature_fraction=0.499; bagging_fraction=0.619; num_leaves=1631; min_data_in_leaf=23; lambda_l2=8.32; lambda_l1=1.64; max_depth=6; min_gain_to_split=0.0998; min_sum_hessian_in_leaf=0.441; scale_pos_weight=1.32; path_smooth=19.9; top_k=37 : y = 0.929 : 44.4 secs : infill_ei
#
# Tue Jul 29 13:35:52 2025 AUC 0.926547429149036
#
# [mbo] 595: learning_rate=0.0596; feature_fraction=0.643; bagging_fraction=0.263; num_leaves=26; min_data_in_leaf=681; lambda_l2=1.98; lambda_l1=4.75; max_depth=5; min_gain_to_split=1.26; min_sum_hessian_in_leaf=99.9; scale_pos_weight=3.12; path_smooth=80.6; top_k=43 : y = 0.927 : 21.8 secs : infill_ei
#
# Tue Jul 29 13:36:48 2025 AUC 0.926835579193076
#
# [mbo] 596: learning_rate=0.103; feature_fraction=0.191; bagging_fraction=0.337; num_leaves=602; min_data_in_leaf=25; lambda_l2=7.46; lambda_l1=0.356; max_depth=8; min_gain_to_split=1.76; min_sum_hessian_in_leaf=1.34; scale_pos_weight=0.63; path_smooth=0.306; top_k=27 : y = 0.927 : 30.7 secs : infill_ei
#
# Tue Jul 29 13:37:50 2025 AUC 0.930251927815547
#
# [mbo] 597: learning_rate=0.0321; feature_fraction=0.495; bagging_fraction=0.313; num_leaves=1965; min_data_in_leaf=23; lambda_l2=7.87; lambda_l1=3.54; max_depth=9; min_gain_to_split=1.64; min_sum_hessian_in_leaf=41.3; scale_pos_weight=6.52; path_smooth=29.8; top_k=24 : y = 0.93 : 43.8 secs : infill_ei
#
# Tue Jul 29 13:39:15 2025 AUC 0.928981016895381
#
# [mbo] 598: learning_rate=0.00375; feature_fraction=0.584; bagging_fraction=0.665; num_leaves=1885; min_data_in_leaf=23; lambda_l2=4.53; lambda_l1=4.55; max_depth=10; min_gain_to_split=1.6; min_sum_hessian_in_leaf=81.7; scale_pos_weight=9.91; path_smooth=21.7; top_k=45 : y = 0.929 : 69.3 secs : infill_ei
#
# Tue Jul 29 13:40:19 2025 AUC 0.93004889270415
#
# [mbo] 599: learning_rate=0.0283; feature_fraction=0.487; bagging_fraction=0.183; num_leaves=1896; min_data_in_leaf=578; lambda_l2=0.474; lambda_l1=3.51; max_depth=8; min_gain_to_split=1.85; min_sum_hessian_in_leaf=22.2; scale_pos_weight=3.73; path_smooth=68.5; top_k=27 : y = 0.93 : 43.9 secs : infill_ei
#
# Tue Jul 29 13:41:29 2025 AUC 0.930396361113768
#
# [mbo] 600: learning_rate=0.0495; feature_fraction=0.515; bagging_fraction=0.151; num_leaves=189; min_data_in_leaf=20; lambda_l2=7.6; lambda_l1=4.91; max_depth=6; min_gain_to_split=1.13; min_sum_hessian_in_leaf=29.1; scale_pos_weight=6.27; path_smooth=92.5; top_k=24 : y = 0.93 : 42.8 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "learning_rate"           "feature_fraction"
#  [3] "bagging_fraction"        "num_leaves"
#  [5] "min_data_in_leaf"        "lambda_l2"
#  [7] "lambda_l1"               "max_depth"
#  [9] "min_gain_to_split"       "min_sum_hessian_in_leaf"
# [11] "scale_pos_weight"        "path_smooth"
# [13] "top_k"                   "y"
# [15] "dob"                     "eol"
# [17] "error.message"           "exec.time"
# [19] "ei"                      "error.model"
# [21] "train.time"              "prop.type"
# [23] "propose.time"            "se"
# [25] "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    learning_rate feature_fraction bagging_fraction num_leaves min_data_in_leaf
#            <num>            <num>            <num>      <int>            <int>
# 1:    0.02725448        0.5133067        0.1009976       1441              511
#    lambda_l2 lambda_l1 max_depth min_gain_to_split min_sum_hessian_in_leaf
#        <num>     <num>     <int>             <num>                   <num>
# 1:  9.723684  1.596121        15          1.037311                49.28688
#    scale_pos_weight path_smooth top_k
#               <num>       <num> <int>
# 1:          8.56682      87.952    16
# [1] 0.9316025

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 333757
#
# $max_depth
# [1] 15
#
# $min_gain_to_split
# [1] 1.037311
#
# $min_sum_hessian_in_leaf
# [1] 49.28688
#
# $lambda_l1
# [1] 1.596121
#
# $lambda_l2
# [1] 9.723684
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 0.1009976
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 8.56682
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1500
#
# $learning_rate
# [1] 0.02725448
#
# $feature_fraction
# [1] 0.5133067
#
# $num_leaves
# [1] 1441
#
# $min_data_in_leaf
# [1] 511
#
# $path_smooth
# [1] 87.952
#
# $top_k
# [1] 16

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Jul 29 13:47:40 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
