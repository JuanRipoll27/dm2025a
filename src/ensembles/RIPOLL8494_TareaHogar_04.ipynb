# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# Esta Tarea para el Hogar 02 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el viernes 01-agosto

# %% [markdown]
# ##  1. Cazatalentos

# %% [markdown]
# En la Clase 03 nos hemos enfrentado a  "La Maldicion del Ganandor",  elegir el modelo con el mejor puntaje simple no suele ser la mejor estrategia.
# <br> Lea y ejecute el notebook  **src/CazaTalentos/CazaTalentos.ipynb**
# <br> en caso de interesarle, participe del Desafío Ordenamiento  que vence el sábado 02 de agosto a las 19:00

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dm"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dm" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/itba2025-8d0a/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Wed Jul 23 11:45:42 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  656930 35.1 1439371    76.9 1431359  76.5
# Vcells 1224847  9.4 8388608    64.0 1924958  14.7

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 4947
PARAM$semilla_primigenia <- 100887

# %%
PARAM$kaggle$competencia <- "data-mining-analista-sr-2025-a"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "dart", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.03),
  makeNumericParam("feature_fraction", lower = 0.45, upper = 0.6),
  makeNumericParam("bagging_fraction", lower = 0.8, upper = 1.0),
  makeIntegerParam("num_leaves", lower = 20L, upper = 50L),
  makeIntegerParam("min_data_in_leaf", lower = 600L, upper = 800L),
  makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.5)

)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 150 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83368
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Wed Jul 23 11:53:44 2025 AUC 0.928738081289573
#
# Wed Jul 23 11:59:37 2025 AUC 0.924957329963476
#
# Wed Jul 23 12:04:10 2025 AUC 0.922146721100584
#
# Wed Jul 23 12:09:58 2025 AUC 0.9197977251086
#
# Wed Jul 23 12:16:21 2025 AUC 0.928704088517501
#
# Wed Jul 23 12:23:28 2025 AUC 0.929085378434923
#
# Wed Jul 23 12:31:15 2025 AUC 0.927070461675203
#
# Wed Jul 23 12:36:35 2025 AUC 0.927464558205944
#
# Wed Jul 23 12:42:26 2025 AUC 0.929625629453509
#
# Wed Jul 23 12:49:09 2025 AUC 0.927748498596844
#
# Wed Jul 23 12:54:49 2025 AUC 0.919260893918783
#
# Wed Jul 23 13:01:02 2025 AUC 0.920682597301853
#
# Wed Jul 23 13:05:20 2025 AUC 0.92304569010912
#
# Wed Jul 23 13:11:42 2025 AUC 0.926814716538134
#
# Wed Jul 23 13:16:48 2025 AUC 0.921640525756507
#
# Wed Jul 23 13:23:02 2025 AUC 0.921282208741886
#
# Wed Jul 23 13:31:12 2025 AUC 0.929491128900744
#
# Wed Jul 23 13:37:57 2025 AUC 0.928032887725547
#
# Wed Jul 23 13:44:43 2025 AUC 0.928775122814274
#
# Wed Jul 23 13:51:24 2025 AUC 0.928794489052833
#
# Wed Jul 23 13:56:30 2025 AUC 0.928906561981109
#
# Wed Jul 23 14:02:22 2025 AUC 0.919430798689819
#
# Wed Jul 23 14:07:29 2025 AUC 0.923337425520698
#
# Wed Jul 23 14:13:53 2025 AUC 0.923394753821167
#
# [mbo] 0: learning_rate=0.0217; feature_fraction=0.54; bagging_fraction=0.922; num_leaves=28; min_data_in_leaf=635; min_gain_to_split=0.142 : y = 0.929 : 332.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0158; feature_fraction=0.555; bagging_fraction=0.98; num_leaves=31; min_data_in_leaf=755; min_gain_to_split=0.287 : y = 0.925 : 353.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.013; feature_fraction=0.545; bagging_fraction=0.888; num_leaves=20; min_data_in_leaf=717; min_gain_to_split=0.0881 : y = 0.922 : 272.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.00741; feature_fraction=0.479; bagging_fraction=0.874; num_leaves=44; min_data_in_leaf=784; min_gain_to_split=0.318 : y = 0.92 : 348.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0247; feature_fraction=0.53; bagging_fraction=0.848; num_leaves=37; min_data_in_leaf=672; min_gain_to_split=0.413 : y = 0.929 : 383.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0231; feature_fraction=0.494; bagging_fraction=0.936; num_leaves=45; min_data_in_leaf=699; min_gain_to_split=0.217 : y = 0.929 : 426.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0167; feature_fraction=0.466; bagging_fraction=0.895; num_leaves=48; min_data_in_leaf=714; min_gain_to_split=0.0738 : y = 0.927 : 466.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0194; feature_fraction=0.586; bagging_fraction=0.863; num_leaves=26; min_data_in_leaf=690; min_gain_to_split=0.389 : y = 0.927 : 320.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0259; feature_fraction=0.492; bagging_fraction=0.838; num_leaves=30; min_data_in_leaf=649; min_gain_to_split=0.0441 : y = 0.93 : 350.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0212; feature_fraction=0.469; bagging_fraction=0.883; num_leaves=40; min_data_in_leaf=747; min_gain_to_split=0.337 : y = 0.928 : 403.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.00523; feature_fraction=0.5; bagging_fraction=0.928; num_leaves=29; min_data_in_leaf=608; min_gain_to_split=0.168 : y = 0.919 : 339.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.00908; feature_fraction=0.566; bagging_fraction=0.801; num_leaves=46; min_data_in_leaf=701; min_gain_to_split=0.311 : y = 0.921 : 372.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0136; feature_fraction=0.598; bagging_fraction=0.948; num_leaves=21; min_data_in_leaf=616; min_gain_to_split=0.364 : y = 0.923 : 258.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0178; feature_fraction=0.591; bagging_fraction=0.907; num_leaves=35; min_data_in_leaf=781; min_gain_to_split=0.204 : y = 0.927 : 382.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0112; feature_fraction=0.454; bagging_fraction=0.811; num_leaves=25; min_data_in_leaf=661; min_gain_to_split=0.433 : y = 0.922 : 305.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.00998; feature_fraction=0.514; bagging_fraction=0.97; num_leaves=33; min_data_in_leaf=763; min_gain_to_split=0.000152 : y = 0.921 : 374.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0292; feature_fraction=0.58; bagging_fraction=0.824; num_leaves=50; min_data_in_leaf=730; min_gain_to_split=0.11 : y = 0.929 : 489.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0201; feature_fraction=0.459; bagging_fraction=0.91; num_leaves=40; min_data_in_leaf=604; min_gain_to_split=0.147 : y = 0.928 : 405.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0274; feature_fraction=0.573; bagging_fraction=0.991; num_leaves=42; min_data_in_leaf=771; min_gain_to_split=0.467 : y = 0.929 : 405.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0253; feature_fraction=0.562; bagging_fraction=0.993; num_leaves=39; min_data_in_leaf=631; min_gain_to_split=0.255 : y = 0.929 : 401.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0282; feature_fraction=0.51; bagging_fraction=0.854; num_leaves=22; min_data_in_leaf=737; min_gain_to_split=0.243 : y = 0.929 : 305.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.00651; feature_fraction=0.486; bagging_fraction=0.963; num_leaves=47; min_data_in_leaf=675; min_gain_to_split=0.441 : y = 0.919 : 351.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0147; feature_fraction=0.522; bagging_fraction=0.955; num_leaves=23; min_data_in_leaf=794; min_gain_to_split=0.493 : y = 0.923 : 307.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0123; feature_fraction=0.535; bagging_fraction=0.828; num_leaves=36; min_data_in_leaf=652; min_gain_to_split=0.029 : y = 0.923 : 384.2 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Wed Jul 23 14:21:42 2025 AUC 0.928929796062367
#
# [mbo] 1: learning_rate=0.0264; feature_fraction=0.552; bagging_fraction=0.884; num_leaves=44; min_data_in_leaf=700; min_gain_to_split=0.000617 : y = 0.929 : 465.2 secs : infill_ei
#
# Wed Jul 23 14:28:07 2025 AUC 0.929654540957503
#
# [mbo] 2: learning_rate=0.03; feature_fraction=0.491; bagging_fraction=0.826; num_leaves=34; min_data_in_leaf=649; min_gain_to_split=0.117 : y = 0.93 : 383.7 secs : infill_ei
#
# Saved the current state after iteration 3 in the file bayesiana.RDATA.
#
# Wed Jul 23 14:33:50 2025 AUC 0.92955877439289
#
# [mbo] 3: learning_rate=0.029; feature_fraction=0.6; bagging_fraction=0.8; num_leaves=29; min_data_in_leaf=652; min_gain_to_split=0.149 : y = 0.93 : 335.1 secs : infill_ei
#
# Wed Jul 23 14:41:47 2025 AUC 0.928955153998917
#
# [mbo] 4: learning_rate=0.0283; feature_fraction=0.503; bagging_fraction=0.801; num_leaves=49; min_data_in_leaf=651; min_gain_to_split=0.14 : y = 0.929 : 476.4 secs : infill_ei
#
# Saved the current state after iteration 5 in the file bayesiana.RDATA.
#
# Wed Jul 23 14:48:08 2025 AUC 0.929543048728345
#
# [mbo] 5: learning_rate=0.03; feature_fraction=0.599; bagging_fraction=0.926; num_leaves=34; min_data_in_leaf=711; min_gain_to_split=0.197 : y = 0.93 : 375.2 secs : infill_ei
#
# Wed Jul 23 14:54:03 2025 AUC 0.929392484170952
#
# [mbo] 6: learning_rate=0.0288; feature_fraction=0.482; bagging_fraction=0.94; num_leaves=29; min_data_in_leaf=660; min_gain_to_split=0.116 : y = 0.929 : 354.4 secs : infill_ei
#
# Saved the current state after iteration 7 in the file bayesiana.RDATA.
#
# Wed Jul 23 15:00:32 2025 AUC 0.929403758409464
#
# [mbo] 7: learning_rate=0.03; feature_fraction=0.57; bagging_fraction=0.812; num_leaves=33; min_data_in_leaf=745; min_gain_to_split=0.108 : y = 0.929 : 384.8 secs : infill_ei
#
# Wed Jul 23 15:06:40 2025 AUC 0.929861930369852
#
# [mbo] 8: learning_rate=0.0292; feature_fraction=0.525; bagging_fraction=0.833; num_leaves=31; min_data_in_leaf=675; min_gain_to_split=0.15 : y = 0.93 : 367.2 secs : infill_ei
#
# Saved the current state after iteration 9 in the file bayesiana.RDATA.
#
# Wed Jul 23 15:12:13 2025 AUC 0.929831184332828
#
# [mbo] 9: learning_rate=0.0299; feature_fraction=0.529; bagging_fraction=0.839; num_leaves=25; min_data_in_leaf=636; min_gain_to_split=0.0977 : y = 0.93 : 327.9 secs : infill_ei
#
# Wed Jul 23 15:18:23 2025 AUC 0.929340076615241
#
# [mbo] 10: learning_rate=0.03; feature_fraction=0.555; bagging_fraction=0.848; num_leaves=31; min_data_in_leaf=655; min_gain_to_split=0.179 : y = 0.929 : 369.8 secs : infill_ei
#
# Saved the current state after iteration 11 in the file bayesiana.RDATA.
#
# Wed Jul 23 15:23:43 2025 AUC 0.929641452840758
#
# [mbo] 11: learning_rate=0.0293; feature_fraction=0.507; bagging_fraction=0.807; num_leaves=23; min_data_in_leaf=668; min_gain_to_split=0.00778 : y = 0.93 : 313.2 secs : infill_ei
#
# Wed Jul 23 15:29:06 2025 AUC 0.930434295448254
#
# [mbo] 12: learning_rate=0.0285; feature_fraction=0.503; bagging_fraction=0.802; num_leaves=25; min_data_in_leaf=617; min_gain_to_split=0.107 : y = 0.93 : 322.6 secs : infill_ei
#
# Saved the current state after iteration 13 in the file bayesiana.RDATA.
#
# Wed Jul 23 15:34:27 2025 AUC 0.930254208370771
#
# [mbo] 13: learning_rate=0.0285; feature_fraction=0.507; bagging_fraction=0.8; num_leaves=24; min_data_in_leaf=600; min_gain_to_split=0.106 : y = 0.93 : 315.7 secs : infill_ei
#
# Wed Jul 23 15:39:38 2025 AUC 0.930543505309927
#
# [mbo] 14: learning_rate=0.0284; feature_fraction=0.451; bagging_fraction=0.8; num_leaves=23; min_data_in_leaf=620; min_gain_to_split=0.135 : y = 0.931 : 310.3 secs : infill_ei
#
# Saved the current state after iteration 15 in the file bayesiana.RDATA.
#
# Wed Jul 23 15:44:31 2025 AUC 0.929733702365729
#
# [mbo] 15: learning_rate=0.0281; feature_fraction=0.469; bagging_fraction=0.824; num_leaves=20; min_data_in_leaf=618; min_gain_to_split=0.183 : y = 0.93 : 286.8 secs : infill_ei
#
# Wed Jul 23 15:50:08 2025 AUC 0.929027919856339
#
# [mbo] 16: learning_rate=0.0288; feature_fraction=0.45; bagging_fraction=0.801; num_leaves=27; min_data_in_leaf=618; min_gain_to_split=0.0848 : y = 0.929 : 336.5 secs : infill_ei
#
# Saved the current state after iteration 17 in the file bayesiana.RDATA.
#
# Wed Jul 23 15:55:25 2025 AUC 0.929296617988434
#
# [mbo] 17: learning_rate=0.0263; feature_fraction=0.492; bagging_fraction=0.8; num_leaves=24; min_data_in_leaf=655; min_gain_to_split=0.138 : y = 0.929 : 310.6 secs : infill_ei
#
# Wed Jul 23 16:02:01 2025 AUC 0.929251914875204
#
# [mbo] 18: learning_rate=0.0277; feature_fraction=0.532; bagging_fraction=0.889; num_leaves=34; min_data_in_leaf=659; min_gain_to_split=0.114 : y = 0.929 : 395.1 secs : infill_ei
#
# Saved the current state after iteration 19 in the file bayesiana.RDATA.
#
# Wed Jul 23 16:06:57 2025 AUC 0.928947029922821
#
# [mbo] 19: learning_rate=0.0288; feature_fraction=0.496; bagging_fraction=0.8; num_leaves=20; min_data_in_leaf=650; min_gain_to_split=0.127 : y = 0.929 : 290.0 secs : infill_ei
#
# Wed Jul 23 16:12:07 2025 AUC 0.929816274806986
#
# [mbo] 20: learning_rate=0.0283; feature_fraction=0.496; bagging_fraction=0.887; num_leaves=23; min_data_in_leaf=620; min_gain_to_split=0.323 : y = 0.93 : 309.5 secs : infill_ei
#
# Saved the current state after iteration 21 in the file bayesiana.RDATA.
#
# Wed Jul 23 16:17:24 2025 AUC 0.930144533122293
#
# [mbo] 21: learning_rate=0.03; feature_fraction=0.465; bagging_fraction=0.811; num_leaves=23; min_data_in_leaf=617; min_gain_to_split=0.281 : y = 0.93 : 310.9 secs : infill_ei
#
# Wed Jul 23 16:24:34 2025 AUC 0.929001614842537
#
# [mbo] 22: learning_rate=0.03; feature_fraction=0.6; bagging_fraction=0.807; num_leaves=42; min_data_in_leaf=707; min_gain_to_split=0.281 : y = 0.929 : 429.3 secs : infill_ei
#
# Saved the current state after iteration 23 in the file bayesiana.RDATA.
#
# Wed Jul 23 16:32:33 2025 AUC 0.929931136170628
#
# [mbo] 23: learning_rate=0.03; feature_fraction=0.483; bagging_fraction=0.97; num_leaves=47; min_data_in_leaf=724; min_gain_to_split=0.204 : y = 0.93 : 474.5 secs : infill_ei
#
# Wed Jul 23 16:40:52 2025 AUC 0.930779667040931
#
# [mbo] 24: learning_rate=0.03; feature_fraction=0.598; bagging_fraction=1; num_leaves=48; min_data_in_leaf=739; min_gain_to_split=0.0874 : y = 0.931 : 497.4 secs : infill_ei
#
# Saved the current state after iteration 25 in the file bayesiana.RDATA.
#
# Wed Jul 23 16:48:38 2025 AUC 0.929810993216281
#
# [mbo] 25: learning_rate=0.03; feature_fraction=0.591; bagging_fraction=1; num_leaves=50; min_data_in_leaf=683; min_gain_to_split=0.227 : y = 0.93 : 460.3 secs : infill_ei
#
# Wed Jul 23 16:54:28 2025 AUC 0.930025287575523
#
# [mbo] 26: learning_rate=0.0293; feature_fraction=0.517; bagging_fraction=0.819; num_leaves=28; min_data_in_leaf=612; min_gain_to_split=0.145 : y = 0.93 : 349.2 secs : infill_ei
#
# Saved the current state after iteration 27 in the file bayesiana.RDATA.
#
# Wed Jul 23 17:02:53 2025 AUC 0.929249112069634
#
# [mbo] 27: learning_rate=0.03; feature_fraction=0.587; bagging_fraction=0.996; num_leaves=47; min_data_in_leaf=794; min_gain_to_split=0.0309 : y = 0.929 : 499.3 secs : infill_ei
#
# Wed Jul 23 17:10:36 2025 AUC 0.928468975452179
#
# [mbo] 28: learning_rate=0.0285; feature_fraction=0.6; bagging_fraction=1; num_leaves=50; min_data_in_leaf=738; min_gain_to_split=0.222 : y = 0.928 : 461.9 secs : infill_ei
#
# Saved the current state after iteration 29 in the file bayesiana.RDATA.
#
# Wed Jul 23 17:18:39 2025 AUC 0.929585899086204
#
# [mbo] 29: learning_rate=0.03; feature_fraction=0.599; bagging_fraction=0.897; num_leaves=47; min_data_in_leaf=640; min_gain_to_split=0.0461 : y = 0.93 : 477.4 secs : infill_ei
#
# Wed Jul 23 17:26:03 2025 AUC 0.929579342768427
#
# [mbo] 30: learning_rate=0.03; feature_fraction=0.516; bagging_fraction=0.996; num_leaves=41; min_data_in_leaf=706; min_gain_to_split=0.248 : y = 0.93 : 442.8 secs : infill_ei
#
# Saved the current state after iteration 31 in the file bayesiana.RDATA.
#
# Wed Jul 23 17:34:07 2025 AUC 0.928854210549572
#
# [mbo] 31: learning_rate=0.03; feature_fraction=0.566; bagging_fraction=0.936; num_leaves=47; min_data_in_leaf=718; min_gain_to_split=0.0631 : y = 0.929 : 479.8 secs : infill_ei
#
# Wed Jul 23 17:41:03 2025 AUC 0.930803379826861
#
# [mbo] 32: learning_rate=0.03; feature_fraction=0.486; bagging_fraction=1; num_leaves=36; min_data_in_leaf=759; min_gain_to_split=0.166 : y = 0.931 : 414.5 secs : infill_ei
#
# Saved the current state after iteration 33 in the file bayesiana.RDATA.
#
# Wed Jul 23 17:47:11 2025 AUC 0.929585422488775
#
# [mbo] 33: learning_rate=0.0276; feature_fraction=0.45; bagging_fraction=0.856; num_leaves=32; min_data_in_leaf=619; min_gain_to_split=0.285 : y = 0.93 : 363.0 secs : infill_ei
#
# Wed Jul 23 17:53:52 2025 AUC 0.930036327754977
#
# [mbo] 34: learning_rate=0.0299; feature_fraction=0.477; bagging_fraction=1; num_leaves=36; min_data_in_leaf=753; min_gain_to_split=0.457 : y = 0.93 : 399.4 secs : infill_ei
#
# Saved the current state after iteration 35 in the file bayesiana.RDATA.
#
# Wed Jul 23 18:00:58 2025 AUC 0.928724468214993
#
# [mbo] 35: learning_rate=0.0268; feature_fraction=0.478; bagging_fraction=1; num_leaves=39; min_data_in_leaf=758; min_gain_to_split=0.125 : y = 0.929 : 421.0 secs : infill_ei
#
# Wed Jul 23 18:07:20 2025 AUC 0.929254009436494
#
# [mbo] 36: learning_rate=0.03; feature_fraction=0.503; bagging_fraction=0.993; num_leaves=32; min_data_in_leaf=766; min_gain_to_split=0.195 : y = 0.929 : 381.1 secs : infill_ei
#
# Saved the current state after iteration 37 in the file bayesiana.RDATA.
#
# Wed Jul 23 18:14:28 2025 AUC 0.929324778299407
#
# [mbo] 37: learning_rate=0.03; feature_fraction=0.464; bagging_fraction=0.999; num_leaves=38; min_data_in_leaf=741; min_gain_to_split=0.151 : y = 0.929 : 420.9 secs : infill_ei
#
# Wed Jul 23 18:19:14 2025 AUC 0.929737791487844
#
# [mbo] 38: learning_rate=0.028; feature_fraction=0.45; bagging_fraction=0.854; num_leaves=21; min_data_in_leaf=617; min_gain_to_split=0.407 : y = 0.93 : 284.4 secs : infill_ei
#
# Saved the current state after iteration 39 in the file bayesiana.RDATA.
#
# Wed Jul 23 18:26:09 2025 AUC 0.929565068766532
#
# [mbo] 39: learning_rate=0.0299; feature_fraction=0.497; bagging_fraction=0.863; num_leaves=36; min_data_in_leaf=798; min_gain_to_split=0.241 : y = 0.93 : 409.7 secs : infill_ei
#
# Wed Jul 23 18:33:31 2025 AUC 0.929025191945818
#
# [mbo] 40: learning_rate=0.0234; feature_fraction=0.598; bagging_fraction=0.811; num_leaves=43; min_data_in_leaf=742; min_gain_to_split=0.00134 : y = 0.929 : 441.1 secs : infill_ei
#
# Saved the current state after iteration 41 in the file bayesiana.RDATA.
#
# Wed Jul 23 18:40:18 2025 AUC 0.929466964612466
#
# [mbo] 41: learning_rate=0.03; feature_fraction=0.485; bagging_fraction=0.984; num_leaves=37; min_data_in_leaf=712; min_gain_to_split=0.301 : y = 0.929 : 401.3 secs : infill_ei
#
# Wed Jul 23 18:47:30 2025 AUC 0.928663230758569
#
# [mbo] 42: learning_rate=0.0224; feature_fraction=0.523; bagging_fraction=0.841; num_leaves=44; min_data_in_leaf=617; min_gain_to_split=0.00283 : y = 0.929 : 430.9 secs : infill_ei
#
# Saved the current state after iteration 43 in the file bayesiana.RDATA.
#
# Wed Jul 23 18:53:20 2025 AUC 0.929146823398188
#
# [mbo] 43: learning_rate=0.027; feature_fraction=0.523; bagging_fraction=0.804; num_leaves=30; min_data_in_leaf=608; min_gain_to_split=0.499 : y = 0.929 : 343.2 secs : infill_ei
#
# Wed Jul 23 19:00:11 2025 AUC 0.929348628103972
#
# [mbo] 44: learning_rate=0.03; feature_fraction=0.513; bagging_fraction=0.867; num_leaves=44; min_data_in_leaf=744; min_gain_to_split=0.497 : y = 0.929 : 409.8 secs : infill_ei
#
# Saved the current state after iteration 45 in the file bayesiana.RDATA.
#
# Wed Jul 23 19:07:40 2025 AUC 0.9285920909444
#
# [mbo] 45: learning_rate=0.03; feature_fraction=0.6; bagging_fraction=1; num_leaves=43; min_data_in_leaf=743; min_gain_to_split=0.0807 : y = 0.929 : 442.2 secs : infill_ei
#
# Wed Jul 23 19:14:54 2025 AUC 0.928767934155811
#
# [mbo] 46: learning_rate=0.03; feature_fraction=0.471; bagging_fraction=1; num_leaves=48; min_data_in_leaf=603; min_gain_to_split=0.412 : y = 0.929 : 433.0 secs : infill_ei
#
# Saved the current state after iteration 47 in the file bayesiana.RDATA.
#
# Wed Jul 23 19:21:56 2025 AUC 0.929317870922186
#
# [mbo] 47: learning_rate=0.0258; feature_fraction=0.452; bagging_fraction=0.802; num_leaves=43; min_data_in_leaf=679; min_gain_to_split=0.246 : y = 0.929 : 415.9 secs : infill_ei
#
# Wed Jul 23 19:28:57 2025 AUC 0.929035129394413
#
# [mbo] 48: learning_rate=0.03; feature_fraction=0.6; bagging_fraction=0.801; num_leaves=48; min_data_in_leaf=674; min_gain_to_split=0.456 : y = 0.929 : 419.4 secs : infill_ei
#
# Saved the current state after iteration 49 in the file bayesiana.RDATA.
#
# Wed Jul 23 19:35:44 2025 AUC 0.929166106856751
#
# [mbo] 49: learning_rate=0.0299; feature_fraction=0.58; bagging_fraction=1; num_leaves=36; min_data_in_leaf=767; min_gain_to_split=0.147 : y = 0.929 : 400.9 secs : infill_ei
#
# Wed Jul 23 19:42:20 2025 AUC 0.930224276279423
#
# [mbo] 50: learning_rate=0.0299; feature_fraction=0.476; bagging_fraction=1; num_leaves=35; min_data_in_leaf=753; min_gain_to_split=0.0872 : y = 0.93 : 394.0 secs : infill_ei
#
# Saved the current state after iteration 51 in the file bayesiana.RDATA.
#
# Wed Jul 23 19:48:15 2025 AUC 0.929088901902877
#
# [mbo] 51: learning_rate=0.024; feature_fraction=0.6; bagging_fraction=0.81; num_leaves=33; min_data_in_leaf=673; min_gain_to_split=0.218 : y = 0.929 : 348.8 secs : infill_ei
#
# Wed Jul 23 19:54:44 2025 AUC 0.928343169223942
#
# [mbo] 52: learning_rate=0.025; feature_fraction=0.6; bagging_fraction=0.84; num_leaves=42; min_data_in_leaf=601; min_gain_to_split=0.459 : y = 0.928 : 387.6 secs : infill_ei
#
# Saved the current state after iteration 53 in the file bayesiana.RDATA.
#
# Wed Jul 23 19:59:44 2025 AUC 0.930420634307111
#
# [mbo] 53: learning_rate=0.0287; feature_fraction=0.451; bagging_fraction=0.989; num_leaves=22; min_data_in_leaf=607; min_gain_to_split=0.0981 : y = 0.93 : 292.7 secs : infill_ei
#
# Wed Jul 23 20:07:45 2025 AUC 0.930077851337451
#
# [mbo] 54: learning_rate=0.03; feature_fraction=0.489; bagging_fraction=1; num_leaves=49; min_data_in_leaf=778; min_gain_to_split=0.132 : y = 0.93 : 479.7 secs : infill_ei
#
# Saved the current state after iteration 55 in the file bayesiana.RDATA.
#
# Wed Jul 23 20:13:47 2025 AUC 0.929385053162293
#
# [mbo] 55: learning_rate=0.0242; feature_fraction=0.484; bagging_fraction=0.983; num_leaves=33; min_data_in_leaf=600; min_gain_to_split=0.206 : y = 0.929 : 355.8 secs : infill_ei
#
# Wed Jul 23 20:21:23 2025 AUC 0.928942033401375
#
# [mbo] 56: learning_rate=0.03; feature_fraction=0.451; bagging_fraction=0.809; num_leaves=48; min_data_in_leaf=775; min_gain_to_split=0.19 : y = 0.929 : 454.4 secs : infill_ei
#
# Saved the current state after iteration 57 in the file bayesiana.RDATA.
#
# Wed Jul 23 20:28:36 2025 AUC 0.928042900725753
#
# [mbo] 57: learning_rate=0.0254; feature_fraction=0.513; bagging_fraction=0.815; num_leaves=43; min_data_in_leaf=758; min_gain_to_split=0.213 : y = 0.928 : 426.7 secs : infill_ei
#
# Wed Jul 23 20:35:27 2025 AUC 0.929204258310231
#
# [mbo] 58: learning_rate=0.03; feature_fraction=0.456; bagging_fraction=1; num_leaves=44; min_data_in_leaf=781; min_gain_to_split=0.483 : y = 0.929 : 409.6 secs : infill_ei
#
# Saved the current state after iteration 59 in the file bayesiana.RDATA.
#
# Wed Jul 23 20:40:36 2025 AUC 0.929251573760659
#
# [mbo] 59: learning_rate=0.0286; feature_fraction=0.45; bagging_fraction=0.886; num_leaves=23; min_data_in_leaf=615; min_gain_to_split=0.173 : y = 0.929 : 302.3 secs : infill_ei
#
# Wed Jul 23 20:45:50 2025 AUC 0.930276503964942
#
# [mbo] 60: learning_rate=0.028; feature_fraction=0.505; bagging_fraction=1; num_leaves=25; min_data_in_leaf=600; min_gain_to_split=0.332 : y = 0.93 : 312.1 secs : infill_ei
#
# Saved the current state after iteration 61 in the file bayesiana.RDATA.
#
# Wed Jul 23 20:50:47 2025 AUC 0.928694463313401
#
# [mbo] 61: learning_rate=0.0276; feature_fraction=0.477; bagging_fraction=1; num_leaves=22; min_data_in_leaf=627; min_gain_to_split=0.262 : y = 0.929 : 290.9 secs : infill_ei
#
# Wed Jul 23 20:56:07 2025 AUC 0.929087551519509
#
# [mbo] 62: learning_rate=0.0293; feature_fraction=0.502; bagging_fraction=0.993; num_leaves=25; min_data_in_leaf=600; min_gain_to_split=0.0154 : y = 0.929 : 318.4 secs : infill_ei
#
# Saved the current state after iteration 63 in the file bayesiana.RDATA.
#
# Wed Jul 23 21:01:24 2025 AUC 0.929879741182929
#
# [mbo] 63: learning_rate=0.0284; feature_fraction=0.524; bagging_fraction=0.8; num_leaves=25; min_data_in_leaf=613; min_gain_to_split=0.359 : y = 0.93 : 310.8 secs : infill_ei
#
# Wed Jul 23 21:09:18 2025 AUC 0.929848154075474
#
# [mbo] 64: learning_rate=0.03; feature_fraction=0.6; bagging_fraction=0.99; num_leaves=50; min_data_in_leaf=647; min_gain_to_split=0.0604 : y = 0.93 : 473.3 secs : infill_ei
#
# Saved the current state after iteration 65 in the file bayesiana.RDATA.
#
# Wed Jul 23 21:14:34 2025 AUC 0.928236389625258
#
# [mbo] 65: learning_rate=0.0279; feature_fraction=0.586; bagging_fraction=0.949; num_leaves=27; min_data_in_leaf=610; min_gain_to_split=0.492 : y = 0.928 : 309.6 secs : infill_ei
#
# Wed Jul 23 21:21:16 2025 AUC 0.930147778745816
#
# [mbo] 66: learning_rate=0.0294; feature_fraction=0.505; bagging_fraction=1; num_leaves=36; min_data_in_leaf=800; min_gain_to_split=0.205 : y = 0.93 : 400.7 secs : infill_ei
#
# Saved the current state after iteration 67 in the file bayesiana.RDATA.
#
# Wed Jul 23 21:27:01 2025 AUC 0.930534758474561
#
# [mbo] 67: learning_rate=0.028; feature_fraction=0.494; bagging_fraction=0.845; num_leaves=29; min_data_in_leaf=621; min_gain_to_split=0.373 : y = 0.931 : 337.8 secs : infill_ei
#
# Wed Jul 23 21:32:44 2025 AUC 0.929464370282652
#
# [mbo] 68: learning_rate=0.028; feature_fraction=0.495; bagging_fraction=0.977; num_leaves=30; min_data_in_leaf=600; min_gain_to_split=0.428 : y = 0.929 : 341.4 secs : infill_ei
#
# Saved the current state after iteration 69 in the file bayesiana.RDATA.
#
# Wed Jul 23 21:38:03 2025 AUC 0.929870613400916
#
# [mbo] 69: learning_rate=0.0283; feature_fraction=0.494; bagging_fraction=0.835; num_leaves=25; min_data_in_leaf=614; min_gain_to_split=0.488 : y = 0.93 : 312.0 secs : infill_ei
#
# Wed Jul 23 21:45:01 2025 AUC 0.929725627313775
#
# [mbo] 70: learning_rate=0.0291; feature_fraction=0.492; bagging_fraction=0.856; num_leaves=42; min_data_in_leaf=631; min_gain_to_split=0.294 : y = 0.93 : 416.2 secs : infill_ei
#
# Saved the current state after iteration 71 in the file bayesiana.RDATA.
#
# Wed Jul 23 21:50:38 2025 AUC 0.930066202710044
#
# [mbo] 71: learning_rate=0.0276; feature_fraction=0.6; bagging_fraction=0.855; num_leaves=29; min_data_in_leaf=740; min_gain_to_split=0.196 : y = 0.93 : 332.3 secs : infill_ei
#
# Wed Jul 23 21:56:11 2025 AUC 0.929263024219832
#
# [mbo] 72: learning_rate=0.028; feature_fraction=0.509; bagging_fraction=0.845; num_leaves=28; min_data_in_leaf=665; min_gain_to_split=0.265 : y = 0.929 : 331.3 secs : infill_ei
#
# Saved the current state after iteration 73 in the file bayesiana.RDATA.
#
# Wed Jul 23 22:02:28 2025 AUC 0.930336350255138
#
# [mbo] 73: learning_rate=0.0283; feature_fraction=0.461; bagging_fraction=0.804; num_leaves=35; min_data_in_leaf=650; min_gain_to_split=0.454 : y = 0.93 : 370.8 secs : infill_ei
#
# Wed Jul 23 22:08:01 2025 AUC 0.928420024418196
#
# [mbo] 74: learning_rate=0.0252; feature_fraction=0.6; bagging_fraction=0.84; num_leaves=29; min_data_in_leaf=760; min_gain_to_split=0.0145 : y = 0.928 : 331.2 secs : infill_ei
#
# Saved the current state after iteration 75 in the file bayesiana.RDATA.
#
# Wed Jul 23 22:13:49 2025 AUC 0.930510621943969
#
# [mbo] 75: learning_rate=0.0266; feature_fraction=0.473; bagging_fraction=0.802; num_leaves=31; min_data_in_leaf=600; min_gain_to_split=0.379 : y = 0.931 : 342.1 secs : infill_ei
#
# Wed Jul 23 22:20:52 2025 AUC 0.928688022704735
#
# [mbo] 76: learning_rate=0.03; feature_fraction=0.483; bagging_fraction=0.983; num_leaves=45; min_data_in_leaf=681; min_gain_to_split=0.393 : y = 0.929 : 422.6 secs : infill_ei
#
# Saved the current state after iteration 77 in the file bayesiana.RDATA.
#
# Wed Jul 23 22:25:56 2025 AUC 0.929672037509336
#
# [mbo] 77: learning_rate=0.0298; feature_fraction=0.459; bagging_fraction=0.819; num_leaves=22; min_data_in_leaf=752; min_gain_to_split=0.072 : y = 0.93 : 297.6 secs : infill_ei
#
# Wed Jul 23 22:31:19 2025 AUC 0.929791359800589
#
# [mbo] 78: learning_rate=0.0285; feature_fraction=0.47; bagging_fraction=0.806; num_leaves=25; min_data_in_leaf=772; min_gain_to_split=0.391 : y = 0.93 : 321.3 secs : infill_ei
#
# Saved the current state after iteration 79 in the file bayesiana.RDATA.
#
# Wed Jul 23 22:37:45 2025 AUC 0.92941628156124
#
# [mbo] 79: learning_rate=0.0292; feature_fraction=0.474; bagging_fraction=0.821; num_leaves=35; min_data_in_leaf=800; min_gain_to_split=0.5 : y = 0.929 : 380.7 secs : infill_ei
#
# Wed Jul 23 22:43:58 2025 AUC 0.929888795157066
#
# [mbo] 80: learning_rate=0.028; feature_fraction=0.482; bagging_fraction=0.825; num_leaves=35; min_data_in_leaf=600; min_gain_to_split=0.354 : y = 0.93 : 371.2 secs : infill_ei
#
# Saved the current state after iteration 81 in the file bayesiana.RDATA.
#
# Wed Jul 23 22:49:49 2025 AUC 0.92928503917072
#
# [mbo] 81: learning_rate=0.0282; feature_fraction=0.455; bagging_fraction=0.805; num_leaves=30; min_data_in_leaf=622; min_gain_to_split=0.417 : y = 0.929 : 344.0 secs : infill_ei
#
# Wed Jul 23 22:56:27 2025 AUC 0.929477132105894
#
# [mbo] 82: learning_rate=0.0276; feature_fraction=0.454; bagging_fraction=0.831; num_leaves=41; min_data_in_leaf=651; min_gain_to_split=0.5 : y = 0.929 : 396.1 secs : infill_ei
#
# Saved the current state after iteration 83 in the file bayesiana.RDATA.
#
# Wed Jul 23 23:02:11 2025 AUC 0.930034628581707
#
# [mbo] 83: learning_rate=0.025; feature_fraction=0.494; bagging_fraction=0.832; num_leaves=29; min_data_in_leaf=611; min_gain_to_split=0.364 : y = 0.93 : 336.7 secs : infill_ei
#
# Wed Jul 23 23:06:58 2025 AUC 0.929962601890577
#
# [mbo] 84: learning_rate=0.0285; feature_fraction=0.451; bagging_fraction=0.821; num_leaves=21; min_data_in_leaf=603; min_gain_to_split=0.059 : y = 0.93 : 286.5 secs : infill_ei
#
# Saved the current state after iteration 85 in the file bayesiana.RDATA.
#
# Wed Jul 23 23:13:13 2025 AUC 0.92936047612942
#
# [mbo] 85: learning_rate=0.0268; feature_fraction=0.483; bagging_fraction=0.866; num_leaves=33; min_data_in_leaf=670; min_gain_to_split=0.388 : y = 0.929 : 368.7 secs : infill_ei
#
# Wed Jul 23 23:20:49 2025 AUC 0.929231694557474
#
# [mbo] 86: learning_rate=0.03; feature_fraction=0.594; bagging_fraction=0.969; num_leaves=48; min_data_in_leaf=643; min_gain_to_split=0.16 : y = 0.929 : 453.9 secs : infill_ei
#
# Saved the current state after iteration 87 in the file bayesiana.RDATA.
#
# Wed Jul 23 23:27:06 2025 AUC 0.929883814187816
#
# [mbo] 87: learning_rate=0.03; feature_fraction=0.597; bagging_fraction=0.856; num_leaves=36; min_data_in_leaf=744; min_gain_to_split=0.481 : y = 0.93 : 371.6 secs : infill_ei
#
# Wed Jul 23 23:32:07 2025 AUC 0.929824632020478
#
# [mbo] 88: learning_rate=0.0299; feature_fraction=0.598; bagging_fraction=0.834; num_leaves=24; min_data_in_leaf=766; min_gain_to_split=0.317 : y = 0.93 : 299.5 secs : infill_ei
#
# Saved the current state after iteration 89 in the file bayesiana.RDATA.
#
# Wed Jul 23 23:38:23 2025 AUC 0.929793144608007
#
# [mbo] 89: learning_rate=0.0249; feature_fraction=0.461; bagging_fraction=0.8; num_leaves=34; min_data_in_leaf=630; min_gain_to_split=0.22 : y = 0.93 : 367.2 secs : infill_ei
#
# Wed Jul 23 23:44:21 2025 AUC 0.929448225298436
#
# [mbo] 90: learning_rate=0.0291; feature_fraction=0.6; bagging_fraction=0.863; num_leaves=31; min_data_in_leaf=771; min_gain_to_split=0.387 : y = 0.929 : 356.4 secs : infill_ei
#
# Saved the current state after iteration 91 in the file bayesiana.RDATA.
#
# Wed Jul 23 23:51:04 2025 AUC 0.92996193679801
#
# [mbo] 91: learning_rate=0.0287; feature_fraction=0.474; bagging_fraction=0.811; num_leaves=36; min_data_in_leaf=711; min_gain_to_split=0.185 : y = 0.93 : 396.5 secs : infill_ei
#
# Wed Jul 23 23:57:37 2025 AUC 0.929602740556808
#
# [mbo] 92: learning_rate=0.0297; feature_fraction=0.538; bagging_fraction=1; num_leaves=37; min_data_in_leaf=766; min_gain_to_split=0.463 : y = 0.93 : 391.9 secs : infill_ei
#
# Saved the current state after iteration 93 in the file bayesiana.RDATA.
#
# Thu Jul 24 00:04:06 2025 AUC 0.929309510549849
#
# [mbo] 93: learning_rate=0.0274; feature_fraction=0.592; bagging_fraction=0.846; num_leaves=36; min_data_in_leaf=724; min_gain_to_split=0.172 : y = 0.929 : 383.4 secs : infill_ei
#
# Thu Jul 24 00:09:50 2025 AUC 0.929684726827417
#
# [mbo] 94: learning_rate=0.0272; feature_fraction=0.494; bagging_fraction=0.86; num_leaves=30; min_data_in_leaf=600; min_gain_to_split=0.184 : y = 0.93 : 341.5 secs : infill_ei
#
# Saved the current state after iteration 95 in the file bayesiana.RDATA.
#
# Thu Jul 24 00:16:29 2025 AUC 0.929195173465778
#
# [mbo] 95: learning_rate=0.0295; feature_fraction=0.496; bagging_fraction=0.923; num_leaves=36; min_data_in_leaf=758; min_gain_to_split=0.335 : y = 0.929 : 392.0 secs : infill_ei
#
# Thu Jul 24 00:24:25 2025 AUC 0.929230350672834
#
# [mbo] 96: learning_rate=0.0259; feature_fraction=0.6; bagging_fraction=0.829; num_leaves=48; min_data_in_leaf=689; min_gain_to_split=2.66e-05 : y = 0.929 : 473.8 secs : infill_ei
#
# Saved the current state after iteration 97 in the file bayesiana.RDATA.
#
# Thu Jul 24 00:31:03 2025 AUC 0.929919593846348
#
# [mbo] 97: learning_rate=0.03; feature_fraction=0.55; bagging_fraction=0.81; num_leaves=39; min_data_in_leaf=625; min_gain_to_split=0.489 : y = 0.93 : 389.9 secs : infill_ei
#
# Thu Jul 24 00:37:43 2025 AUC 0.930217484459791
#
# [mbo] 98: learning_rate=0.0291; feature_fraction=0.502; bagging_fraction=0.806; num_leaves=36; min_data_in_leaf=756; min_gain_to_split=7.93e-05 : y = 0.93 : 398.2 secs : infill_ei
#
# Saved the current state after iteration 99 in the file bayesiana.RDATA.
#
# Thu Jul 24 00:44:02 2025 AUC 0.929280657101381
#
# [mbo] 99: learning_rate=0.0266; feature_fraction=0.492; bagging_fraction=0.811; num_leaves=35; min_data_in_leaf=627; min_gain_to_split=0.35 : y = 0.929 : 371.7 secs : infill_ei
#
# Thu Jul 24 00:50:25 2025 AUC 0.930438049378591
#
# [mbo] 100: learning_rate=0.03; feature_fraction=0.481; bagging_fraction=0.862; num_leaves=36; min_data_in_leaf=643; min_gain_to_split=0.498 : y = 0.93 : 381.1 secs : infill_ei
#
# Saved the current state after iteration 101 in the file bayesiana.RDATA.
#
# Thu Jul 24 00:55:39 2025 AUC 0.930073436162818
#
# [mbo] 101: learning_rate=0.028; feature_fraction=0.478; bagging_fraction=0.803; num_leaves=25; min_data_in_leaf=600; min_gain_to_split=0.365 : y = 0.93 : 307.6 secs : infill_ei
#
# Thu Jul 24 01:00:32 2025 AUC 0.930287665750737
#
# [mbo] 102: learning_rate=0.03; feature_fraction=0.479; bagging_fraction=0.827; num_leaves=21; min_data_in_leaf=742; min_gain_to_split=0.46 : y = 0.93 : 291.6 secs : infill_ei
#
# Saved the current state after iteration 103 in the file bayesiana.RDATA.
#
# Thu Jul 24 01:05:51 2025 AUC 0.930476680931908
#
# [mbo] 103: learning_rate=0.03; feature_fraction=0.52; bagging_fraction=0.994; num_leaves=24; min_data_in_leaf=741; min_gain_to_split=0.398 : y = 0.93 : 310.9 secs : infill_ei
#
# Thu Jul 24 01:13:50 2025 AUC 0.928465102656712
#
# [mbo] 104: learning_rate=0.03; feature_fraction=0.496; bagging_fraction=0.999; num_leaves=50; min_data_in_leaf=773; min_gain_to_split=0.0977 : y = 0.928 : 477.2 secs : infill_ei
#
# Saved the current state after iteration 105 in the file bayesiana.RDATA.
#
# Thu Jul 24 01:19:18 2025 AUC 0.929751395306822
#
# [mbo] 105: learning_rate=0.03; feature_fraction=0.517; bagging_fraction=0.852; num_leaves=25; min_data_in_leaf=752; min_gain_to_split=0.449 : y = 0.93 : 321.7 secs : infill_ei
#
# Thu Jul 24 01:24:05 2025 AUC 0.93019833177641
#
# [mbo] 106: learning_rate=0.03; feature_fraction=0.472; bagging_fraction=0.995; num_leaves=20; min_data_in_leaf=760; min_gain_to_split=0.374 : y = 0.93 : 285.4 secs : infill_ei
#
# Saved the current state after iteration 107 in the file bayesiana.RDATA.
#
# Thu Jul 24 01:29:20 2025 AUC 0.928478062177245
#
# [mbo] 107: learning_rate=0.0285; feature_fraction=0.597; bagging_fraction=0.985; num_leaves=26; min_data_in_leaf=726; min_gain_to_split=0.337 : y = 0.928 : 309.7 secs : infill_ei
#
# Thu Jul 24 01:34:21 2025 AUC 0.930367373327688
#
# [mbo] 108: learning_rate=0.03; feature_fraction=0.499; bagging_fraction=0.999; num_leaves=23; min_data_in_leaf=600; min_gain_to_split=0.388 : y = 0.93 : 299.2 secs : infill_ei
#
# Saved the current state after iteration 109 in the file bayesiana.RDATA.
#
# Thu Jul 24 01:39:29 2025 AUC 0.92987864938271
#
# [mbo] 109: learning_rate=0.03; feature_fraction=0.494; bagging_fraction=0.895; num_leaves=22; min_data_in_leaf=799; min_gain_to_split=0.38 : y = 0.93 : 300.7 secs : infill_ei
#
# Thu Jul 24 01:46:49 2025 AUC 0.929278417609153
#
# [mbo] 110: learning_rate=0.0242; feature_fraction=0.451; bagging_fraction=0.939; num_leaves=49; min_data_in_leaf=601; min_gain_to_split=0.247 : y = 0.929 : 437.3 secs : infill_ei
#
# Saved the current state after iteration 111 in the file bayesiana.RDATA.
#
# Thu Jul 24 01:52:05 2025 AUC 0.929929301107915
#
# [mbo] 111: learning_rate=0.0297; feature_fraction=0.479; bagging_fraction=1; num_leaves=23; min_data_in_leaf=738; min_gain_to_split=0.492 : y = 0.93 : 306.9 secs : infill_ei
#
# Thu Jul 24 01:59:36 2025 AUC 0.929156048926832
#
# [mbo] 112: learning_rate=0.03; feature_fraction=0.482; bagging_fraction=0.899; num_leaves=44; min_data_in_leaf=797; min_gain_to_split=0.133 : y = 0.929 : 448.3 secs : infill_ei
#
# Saved the current state after iteration 113 in the file bayesiana.RDATA.
#
# Thu Jul 24 02:06:09 2025 AUC 0.929060241946347
#
# [mbo] 113: learning_rate=0.03; feature_fraction=0.469; bagging_fraction=0.83; num_leaves=37; min_data_in_leaf=626; min_gain_to_split=0.467 : y = 0.929 : 383.6 secs : infill_ei
#
# Thu Jul 24 02:11:12 2025 AUC 0.929935585401467
#
# [mbo] 114: learning_rate=0.03; feature_fraction=0.483; bagging_fraction=0.821; num_leaves=23; min_data_in_leaf=722; min_gain_to_split=0.379 : y = 0.93 : 301.7 secs : infill_ei
#
# Saved the current state after iteration 115 in the file bayesiana.RDATA.
#
# Thu Jul 24 02:17:23 2025 AUC 0.92892952067455
#
# [mbo] 115: learning_rate=0.0286; feature_fraction=0.481; bagging_fraction=0.99; num_leaves=35; min_data_in_leaf=644; min_gain_to_split=0.5 : y = 0.929 : 363.4 secs : infill_ei
#
# Thu Jul 24 02:25:06 2025 AUC 0.929052220143649
#
# [mbo] 116: learning_rate=0.0279; feature_fraction=0.457; bagging_fraction=1; num_leaves=48; min_data_in_leaf=756; min_gain_to_split=0.0954 : y = 0.929 : 460.4 secs : infill_ei
#
# Saved the current state after iteration 117 in the file bayesiana.RDATA.
#
# Thu Jul 24 02:31:46 2025 AUC 0.929621674670315
#
# [mbo] 117: learning_rate=0.0299; feature_fraction=0.554; bagging_fraction=0.876; num_leaves=40; min_data_in_leaf=685; min_gain_to_split=0.5 : y = 0.93 : 389.1 secs : infill_ei
#
# Thu Jul 24 02:38:02 2025 AUC 0.929276061536659
#
# [mbo] 118: learning_rate=0.03; feature_fraction=0.527; bagging_fraction=0.851; num_leaves=36; min_data_in_leaf=642; min_gain_to_split=0.5 : y = 0.929 : 373.3 secs : infill_ei
#
# Saved the current state after iteration 119 in the file bayesiana.RDATA.
#
# Thu Jul 24 02:44:55 2025 AUC 0.929593512344714
#
# [mbo] 119: learning_rate=0.0292; feature_fraction=0.537; bagging_fraction=0.8; num_leaves=39; min_data_in_leaf=705; min_gain_to_split=0.0214 : y = 0.93 : 405.2 secs : infill_ei
#
# Thu Jul 24 02:49:54 2025 AUC 0.930326698503179
#
# [mbo] 120: learning_rate=0.0292; feature_fraction=0.451; bagging_fraction=0.975; num_leaves=23; min_data_in_leaf=704; min_gain_to_split=0.0481 : y = 0.93 : 297.3 secs : infill_ei
#
# Saved the current state after iteration 121 in the file bayesiana.RDATA.
#
# Thu Jul 24 02:54:46 2025 AUC 0.92979648791419
#
# [mbo] 121: learning_rate=0.0265; feature_fraction=0.45; bagging_fraction=0.8; num_leaves=22; min_data_in_leaf=649; min_gain_to_split=0.122 : y = 0.93 : 282.5 secs : infill_ei
#
# Thu Jul 24 03:01:20 2025 AUC 0.92878852324211
#
# [mbo] 122: learning_rate=0.0248; feature_fraction=0.478; bagging_fraction=0.858; num_leaves=48; min_data_in_leaf=639; min_gain_to_split=0.496 : y = 0.929 : 393.3 secs : infill_ei
#
# Saved the current state after iteration 123 in the file bayesiana.RDATA.
#
# Thu Jul 24 03:05:57 2025 AUC 0.929382037397374
#
# [mbo] 123: learning_rate=0.0298; feature_fraction=0.577; bagging_fraction=0.867; num_leaves=20; min_data_in_leaf=724; min_gain_to_split=0.468 : y = 0.929 : 269.1 secs : infill_ei
#
# Thu Jul 24 03:10:49 2025 AUC 0.930218820647234
#
# [mbo] 124: learning_rate=0.0291; feature_fraction=0.523; bagging_fraction=1; num_leaves=23; min_data_in_leaf=611; min_gain_to_split=0.412 : y = 0.93 : 290.6 secs : infill_ei
#
# Thu Jul 24 03:15:48 2025 AUC 0.929574310317081
#
# [mbo] 125: learning_rate=0.0295; feature_fraction=0.45; bagging_fraction=1; num_leaves=22; min_data_in_leaf=786; min_gain_to_split=0.0477 : y = 0.93 : 295.6 secs : infill_ei
#
# Saved the current state after iteration 126 in the file bayesiana.RDATA.
#
# Thu Jul 24 03:20:31 2025 AUC 0.929358304774851
#
# [mbo] 126: learning_rate=0.0293; feature_fraction=0.459; bagging_fraction=0.8; num_leaves=20; min_data_in_leaf=638; min_gain_to_split=0.357 : y = 0.929 : 274.8 secs : infill_ei
#
# Thu Jul 24 03:27:37 2025 AUC 0.929684375876511
#
# [mbo] 127: learning_rate=0.0292; feature_fraction=0.481; bagging_fraction=1; num_leaves=48; min_data_in_leaf=792; min_gain_to_split=0.282 : y = 0.93 : 423.4 secs : infill_ei
#
# Saved the current state after iteration 128 in the file bayesiana.RDATA.
#
# Thu Jul 24 03:33:22 2025 AUC 0.929362980667957
#
# [mbo] 128: learning_rate=0.0288; feature_fraction=0.516; bagging_fraction=0.813; num_leaves=29; min_data_in_leaf=710; min_gain_to_split=0.00481 : y = 0.929 : 336.7 secs : infill_ei
#
# Thu Jul 24 03:38:33 2025 AUC 0.930710060762277
#
# [mbo] 129: learning_rate=0.0299; feature_fraction=0.506; bagging_fraction=0.963; num_leaves=25; min_data_in_leaf=618; min_gain_to_split=0.417 : y = 0.931 : 309.7 secs : infill_ei
#
# Saved the current state after iteration 130 in the file bayesiana.RDATA.
#
# Thu Jul 24 03:44:36 2025 AUC 0.929322605692995
#
# [mbo] 130: learning_rate=0.024; feature_fraction=0.456; bagging_fraction=0.854; num_leaves=35; min_data_in_leaf=600; min_gain_to_split=0.499 : y = 0.929 : 355.8 secs : infill_ei
#
# Thu Jul 24 03:49:17 2025 AUC 0.929643402362102
#
# [mbo] 131: learning_rate=0.03; feature_fraction=0.45; bagging_fraction=0.955; num_leaves=20; min_data_in_leaf=732; min_gain_to_split=0.396 : y = 0.93 : 279.1 secs : infill_ei
#
# Saved the current state after iteration 132 in the file bayesiana.RDATA.
#
# Thu Jul 24 03:55:32 2025 AUC 0.929352965318655
#
# [mbo] 132: learning_rate=0.0289; feature_fraction=0.478; bagging_fraction=0.8; num_leaves=35; min_data_in_leaf=681; min_gain_to_split=0.5 : y = 0.929 : 367.6 secs : infill_ei
#
# Thu Jul 24 04:01:20 2025 AUC 0.928946644579791
#
# [mbo] 133: learning_rate=0.0283; feature_fraction=0.48; bagging_fraction=0.848; num_leaves=32; min_data_in_leaf=638; min_gain_to_split=0.326 : y = 0.929 : 346.3 secs : infill_ei
#
# Saved the current state after iteration 134 in the file bayesiana.RDATA.
#
# Thu Jul 24 04:06:12 2025 AUC 0.929528044539458
#
# [mbo] 134: learning_rate=0.03; feature_fraction=0.511; bagging_fraction=0.975; num_leaves=20; min_data_in_leaf=762; min_gain_to_split=0.467 : y = 0.93 : 283.2 secs : infill_ei
#
# Thu Jul 24 04:12:13 2025 AUC 0.929878609387375
#
# [mbo] 135: learning_rate=0.0271; feature_fraction=0.452; bagging_fraction=0.857; num_leaves=35; min_data_in_leaf=609; min_gain_to_split=0.443 : y = 0.93 : 358.7 secs : infill_ei
#
# Saved the current state after iteration 136 in the file bayesiana.RDATA.
#
# Thu Jul 24 04:17:20 2025 AUC 0.929888832885401
#
# [mbo] 136: learning_rate=0.029; feature_fraction=0.575; bagging_fraction=0.819; num_leaves=24; min_data_in_leaf=777; min_gain_to_split=0.188 : y = 0.93 : 300.5 secs : infill_ei
#
# Thu Jul 24 04:22:57 2025 AUC 0.929974119315044
#
# [mbo] 137: learning_rate=0.0231; feature_fraction=0.455; bagging_fraction=0.886; num_leaves=31; min_data_in_leaf=622; min_gain_to_split=0.368 : y = 0.93 : 333.4 secs : infill_ei
#
# Saved the current state after iteration 138 in the file bayesiana.RDATA.
#
# Thu Jul 24 04:29:51 2025 AUC 0.929616213435902
#
# [mbo] 138: learning_rate=0.03; feature_fraction=0.554; bagging_fraction=0.855; num_leaves=44; min_data_in_leaf=600; min_gain_to_split=0.383 : y = 0.93 : 405.5 secs : infill_ei
#
# Thu Jul 24 04:34:51 2025 AUC 0.929800414727748
#
# [mbo] 139: learning_rate=0.03; feature_fraction=0.482; bagging_fraction=0.994; num_leaves=23; min_data_in_leaf=699; min_gain_to_split=0.0973 : y = 0.93 : 298.1 secs : infill_ei
#
# Saved the current state after iteration 140 in the file bayesiana.RDATA.
#
# Thu Jul 24 04:42:32 2025 AUC 0.930367806898838
#
# [mbo] 140: learning_rate=0.03; feature_fraction=0.465; bagging_fraction=0.889; num_leaves=48; min_data_in_leaf=717; min_gain_to_split=0.156 : y = 0.93 : 453.4 secs : infill_ei
#
# Thu Jul 24 04:48:40 2025 AUC 0.929780125639164
#
# [mbo] 141: learning_rate=0.0276; feature_fraction=0.45; bagging_fraction=0.801; num_leaves=35; min_data_in_leaf=670; min_gain_to_split=0.0471 : y = 0.93 : 365.8 secs : infill_ei
#
# Saved the current state after iteration 142 in the file bayesiana.RDATA.
#
# Thu Jul 24 04:54:18 2025 AUC 0.929505506522221
#
# [mbo] 142: learning_rate=0.0236; feature_fraction=0.45; bagging_fraction=0.967; num_leaves=31; min_data_in_leaf=605; min_gain_to_split=0.0635 : y = 0.93 : 330.1 secs : infill_ei
#
# Thu Jul 24 05:00:38 2025 AUC 0.929626395739997
#
# [mbo] 143: learning_rate=0.0299; feature_fraction=0.461; bagging_fraction=0.874; num_leaves=36; min_data_in_leaf=659; min_gain_to_split=0.251 : y = 0.93 : 378.1 secs : infill_ei
#
# Saved the current state after iteration 144 in the file bayesiana.RDATA.
#
# Thu Jul 24 05:06:40 2025 AUC 0.929065388502147
#
# [mbo] 144: learning_rate=0.0262; feature_fraction=0.454; bagging_fraction=0.806; num_leaves=32; min_data_in_leaf=786; min_gain_to_split=0.13 : y = 0.929 : 355.1 secs : infill_ei
#
# Thu Jul 24 05:11:27 2025 AUC 0.9293014983426
#
# [mbo] 145: learning_rate=0.0277; feature_fraction=0.464; bagging_fraction=0.842; num_leaves=21; min_data_in_leaf=790; min_gain_to_split=0.452 : y = 0.929 : 284.1 secs : infill_ei
#
# Saved the current state after iteration 146 in the file bayesiana.RDATA.
#
# Thu Jul 24 05:18:00 2025 AUC 0.931085296223325
#
# [mbo] 146: learning_rate=0.03; feature_fraction=0.494; bagging_fraction=0.878; num_leaves=36; min_data_in_leaf=711; min_gain_to_split=0.0602 : y = 0.931 : 385.7 secs : infill_ei
#
# Thu Jul 24 05:24:24 2025 AUC 0.929900657110083
#
# [mbo] 147: learning_rate=0.03; feature_fraction=0.497; bagging_fraction=0.893; num_leaves=36; min_data_in_leaf=710; min_gain_to_split=0.132 : y = 0.93 : 381.6 secs : infill_ei
#
# Saved the current state after iteration 148 in the file bayesiana.RDATA.
#
# Thu Jul 24 05:31:05 2025 AUC 0.929882926610211
#
# [mbo] 148: learning_rate=0.0299; feature_fraction=0.478; bagging_fraction=0.866; num_leaves=36; min_data_in_leaf=757; min_gain_to_split=0.0107 : y = 0.93 : 393.8 secs : infill_ei
#
# Thu Jul 24 05:36:22 2025 AUC 0.929533452110108
#
# [mbo] 149: learning_rate=0.0279; feature_fraction=0.525; bagging_fraction=0.886; num_leaves=27; min_data_in_leaf=600; min_gain_to_split=0.392 : y = 0.93 : 313.9 secs : infill_ei
#
# Saved the current state after iteration 150 in the file bayesiana.RDATA.
#
# Thu Jul 24 05:42:44 2025 AUC 0.929508898613592
#
# [mbo] 150: learning_rate=0.0288; feature_fraction=0.494; bagging_fraction=0.865; num_leaves=36; min_data_in_leaf=648; min_gain_to_split=0.0424 : y = 0.93 : 374.5 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "learning_rate"     "feature_fraction"  "bagging_fraction"
#  [4] "num_leaves"        "min_data_in_leaf"  "min_gain_to_split"
#  [7] "y"                 "dob"               "eol"
# [10] "error.message"     "exec.time"         "ei"
# [13] "error.model"       "train.time"        "prop.type"
# [16] "propose.time"      "se"                "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    learning_rate feature_fraction bagging_fraction num_leaves min_data_in_leaf
#            <num>            <num>            <num>      <int>            <int>
# 1:    0.02999335        0.4941378        0.8778923         36              711
#    min_gain_to_split
#                <num>
# 1:        0.06018065
# [1] 0.9310853

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "dart"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 100887
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0.06018065
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 0
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 0.8778923
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1200
#
# $learning_rate
# [1] 0.02999335
#
# $feature_fraction
# [1] 0.4941378
#
# $num_leaves
# [1] 36
#
# $min_data_in_leaf
# [1] 711

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Jul 24 05:46:48 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
