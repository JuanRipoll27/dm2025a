# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# Esta Tarea para el Hogar 02 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el viernes 01-agosto

# %% [markdown]
# ##  1. Cazatalentos

# %% [markdown]
# En la Clase 03 nos hemos enfrentado a  "La Maldicion del Ganandor",  elegir el modelo con el mejor puntaje simple no suele ser la mejor estrategia.
# <br> Lea y ejecute el notebook  **src/CazaTalentos/CazaTalentos.ipynb**
# <br> en caso de interesarle, participe del Desafío Ordenamiento  que vence el sábado 02 de agosto a las 19:00

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dm"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dm" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/itba2025-8d0a/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sat Jul 26 04:21:59 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  656930 35.1 1439380    76.9 1431357  76.5
# Vcells 1224847  9.4 8388608    64.0 1924958  14.7

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 4960
PARAM$semilla_primigenia <- 100887

# %%
PARAM$kaggle$competencia <- "data-mining-analista-sr-2025-a"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeNumericParam("learning_rate", lower = 0.0135, upper = 0.0148),
  makeNumericParam("feature_fraction", lower = 0.34, upper = 0.365),
  makeNumericParam("bagging_fraction", lower = 0.81, upper = 0.845),
  makeIntegerParam("num_leaves", lower = 26L, upper = 30L),
  makeIntegerParam("min_data_in_leaf", lower = 740L, upper = 755L),
  makeNumericParam("lambda_l2", lower = 0.7, upper = 0.78)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 300 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83368
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Sat Jul 26 04:24:19 2025 AUC 0.930791827391181
#
# Sat Jul 26 04:25:19 2025 AUC 0.930312030257072
#
# Sat Jul 26 04:26:21 2025 AUC 0.931292532447089
#
# Sat Jul 26 04:27:23 2025 AUC 0.931208285696024
#
# Sat Jul 26 04:28:25 2025 AUC 0.930026047872675
#
# Sat Jul 26 04:29:28 2025 AUC 0.930772524638539
#
# Sat Jul 26 04:30:29 2025 AUC 0.931396958168583
#
# Sat Jul 26 04:31:31 2025 AUC 0.930882562444878
#
# Sat Jul 26 04:32:32 2025 AUC 0.930759200157991
#
# Sat Jul 26 04:33:33 2025 AUC 0.930411686137051
#
# Sat Jul 26 04:34:34 2025 AUC 0.931346559256043
#
# Sat Jul 26 04:35:38 2025 AUC 0.930192066945574
#
# Sat Jul 26 04:36:39 2025 AUC 0.930454929809823
#
# Sat Jul 26 04:37:41 2025 AUC 0.930139641486878
#
# Sat Jul 26 04:38:42 2025 AUC 0.930506889594351
#
# Sat Jul 26 04:39:43 2025 AUC 0.930788647722837
#
# Sat Jul 26 04:40:46 2025 AUC 0.931494639704329
#
# Sat Jul 26 04:41:48 2025 AUC 0.930660859887593
#
# Sat Jul 26 04:42:51 2025 AUC 0.930372712288881
#
# Sat Jul 26 04:43:53 2025 AUC 0.930927615208099
#
# Sat Jul 26 04:44:54 2025 AUC 0.930452517144776
#
# Sat Jul 26 04:45:56 2025 AUC 0.930028971597117
#
# Sat Jul 26 04:46:56 2025 AUC 0.930286495025292
#
# Sat Jul 26 04:47:59 2025 AUC 0.93076472982626
#
# [mbo] 0: learning_rate=0.0144; feature_fraction=0.355; bagging_fraction=0.831; num_leaves=27; min_data_in_leaf=742; lambda_l2=0.723 : y = 0.931 : 63.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0141; feature_fraction=0.357; bagging_fraction=0.841; num_leaves=27; min_data_in_leaf=752; lambda_l2=0.746 : y = 0.93 : 60.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0139; feature_fraction=0.356; bagging_fraction=0.825; num_leaves=26; min_data_in_leaf=749; lambda_l2=0.714 : y = 0.931 : 61.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0136; feature_fraction=0.345; bagging_fraction=0.823; num_leaves=29; min_data_in_leaf=754; lambda_l2=0.751 : y = 0.931 : 62.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0145; feature_fraction=0.353; bagging_fraction=0.818; num_leaves=28; min_data_in_leaf=745; lambda_l2=0.766 : y = 0.93 : 61.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0144; feature_fraction=0.347; bagging_fraction=0.834; num_leaves=30; min_data_in_leaf=747; lambda_l2=0.735 : y = 0.931 : 62.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0141; feature_fraction=0.343; bagging_fraction=0.827; num_leaves=30; min_data_in_leaf=749; lambda_l2=0.712 : y = 0.931 : 61.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0142; feature_fraction=0.363; bagging_fraction=0.821; num_leaves=27; min_data_in_leaf=747; lambda_l2=0.762 : y = 0.931 : 62.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0146; feature_fraction=0.347; bagging_fraction=0.817; num_leaves=27; min_data_in_leaf=743; lambda_l2=0.707 : y = 0.931 : 60.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0143; feature_fraction=0.343; bagging_fraction=0.825; num_leaves=29; min_data_in_leaf=751; lambda_l2=0.754 : y = 0.93 : 61.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0135; feature_fraction=0.348; bagging_fraction=0.832; num_leaves=27; min_data_in_leaf=740; lambda_l2=0.727 : y = 0.931 : 61.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0137; feature_fraction=0.359; bagging_fraction=0.81; num_leaves=30; min_data_in_leaf=748; lambda_l2=0.75 : y = 0.93 : 63.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0139; feature_fraction=0.365; bagging_fraction=0.836; num_leaves=26; min_data_in_leaf=741; lambda_l2=0.758 : y = 0.93 : 61.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0142; feature_fraction=0.364; bagging_fraction=0.829; num_leaves=28; min_data_in_leaf=754; lambda_l2=0.733 : y = 0.93 : 62.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0138; feature_fraction=0.341; bagging_fraction=0.812; num_leaves=26; min_data_in_leaf=744; lambda_l2=0.769 : y = 0.931 : 60.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0138; feature_fraction=0.351; bagging_fraction=0.84; num_leaves=28; min_data_in_leaf=753; lambda_l2=0.7 : y = 0.931 : 60.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0148; feature_fraction=0.362; bagging_fraction=0.814; num_leaves=30; min_data_in_leaf=750; lambda_l2=0.718 : y = 0.931 : 63.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0143; feature_fraction=0.341; bagging_fraction=0.829; num_leaves=29; min_data_in_leaf=740; lambda_l2=0.724 : y = 0.931 : 61.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0147; feature_fraction=0.36; bagging_fraction=0.843; num_leaves=29; min_data_in_leaf=753; lambda_l2=0.775 : y = 0.93 : 63.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0146; feature_fraction=0.359; bagging_fraction=0.844; num_leaves=29; min_data_in_leaf=742; lambda_l2=0.741 : y = 0.931 : 62.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0147; feature_fraction=0.35; bagging_fraction=0.819; num_leaves=26; min_data_in_leaf=750; lambda_l2=0.739 : y = 0.93 : 60.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0136; feature_fraction=0.346; bagging_fraction=0.838; num_leaves=30; min_data_in_leaf=746; lambda_l2=0.771 : y = 0.93 : 62.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.014; feature_fraction=0.352; bagging_fraction=0.837; num_leaves=26; min_data_in_leaf=755; lambda_l2=0.779 : y = 0.93 : 59.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0139; feature_fraction=0.354; bagging_fraction=0.815; num_leaves=28; min_data_in_leaf=744; lambda_l2=0.705 : y = 0.931 : 62.2 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Sat Jul 26 04:49:04 2025 AUC 0.93130537144835
#
# [mbo] 1: learning_rate=0.0143; feature_fraction=0.357; bagging_fraction=0.837; num_leaves=29; min_data_in_leaf=755; lambda_l2=0.758 : y = 0.931 : 62.4 secs : infill_ei
#
# Sat Jul 26 04:50:06 2025 AUC 0.931075190525722
#
# [mbo] 2: learning_rate=0.0137; feature_fraction=0.353; bagging_fraction=0.826; num_leaves=26; min_data_in_leaf=755; lambda_l2=0.707 : y = 0.931 : 60.8 secs : infill_ei
#
# Sat Jul 26 04:51:09 2025 AUC 0.93083558008716
#
# [mbo] 3: learning_rate=0.0145; feature_fraction=0.354; bagging_fraction=0.819; num_leaves=29; min_data_in_leaf=750; lambda_l2=0.715 : y = 0.931 : 62.6 secs : infill_ei
#
# Sat Jul 26 04:52:13 2025 AUC 0.931291957049643
#
# [mbo] 4: learning_rate=0.0147; feature_fraction=0.355; bagging_fraction=0.813; num_leaves=30; min_data_in_leaf=750; lambda_l2=0.719 : y = 0.931 : 63.0 secs : infill_ei
#
# Sat Jul 26 04:53:16 2025 AUC 0.931164350742907
#
# [mbo] 5: learning_rate=0.014; feature_fraction=0.353; bagging_fraction=0.826; num_leaves=29; min_data_in_leaf=749; lambda_l2=0.71 : y = 0.931 : 62.3 secs : infill_ei
#
# Sat Jul 26 04:54:19 2025 AUC 0.929970763530577
#
# [mbo] 6: learning_rate=0.0146; feature_fraction=0.346; bagging_fraction=0.814; num_leaves=30; min_data_in_leaf=746; lambda_l2=0.748 : y = 0.93 : 62.3 secs : infill_ei
#
# Sat Jul 26 04:55:20 2025 AUC 0.931076536639525
#
# [mbo] 7: learning_rate=0.0141; feature_fraction=0.343; bagging_fraction=0.827; num_leaves=27; min_data_in_leaf=750; lambda_l2=0.713 : y = 0.931 : 59.9 secs : infill_ei
#
# Sat Jul 26 04:56:24 2025 AUC 0.930976012528728
#
# [mbo] 8: learning_rate=0.0148; feature_fraction=0.355; bagging_fraction=0.814; num_leaves=30; min_data_in_leaf=751; lambda_l2=0.715 : y = 0.931 : 62.9 secs : infill_ei
#
# Sat Jul 26 04:57:27 2025 AUC 0.931333259739374
#
# [mbo] 9: learning_rate=0.0147; feature_fraction=0.36; bagging_fraction=0.826; num_leaves=30; min_data_in_leaf=747; lambda_l2=0.718 : y = 0.931 : 63.0 secs : infill_ei
#
# Sat Jul 26 04:58:30 2025 AUC 0.931078679576634
#
# [mbo] 10: learning_rate=0.0136; feature_fraction=0.362; bagging_fraction=0.831; num_leaves=30; min_data_in_leaf=750; lambda_l2=0.718 : y = 0.931 : 62.2 secs : infill_ei
#
# Saved the current state after iteration 11 in the file bayesiana.RDATA.
#
# Sat Jul 26 04:59:38 2025 AUC 0.931491088487434
#
# [mbo] 11: learning_rate=0.0148; feature_fraction=0.365; bagging_fraction=0.813; num_leaves=30; min_data_in_leaf=749; lambda_l2=0.717 : y = 0.931 : 63.0 secs : infill_ei
#
# Sat Jul 26 05:00:40 2025 AUC 0.931201903165085
#
# [mbo] 12: learning_rate=0.0137; feature_fraction=0.343; bagging_fraction=0.834; num_leaves=30; min_data_in_leaf=746; lambda_l2=0.712 : y = 0.931 : 61.6 secs : infill_ei
#
# Sat Jul 26 05:01:44 2025 AUC 0.930773496536003
#
# [mbo] 13: learning_rate=0.0147; feature_fraction=0.365; bagging_fraction=0.81; num_leaves=30; min_data_in_leaf=750; lambda_l2=0.72 : y = 0.931 : 63.4 secs : infill_ei
#
# Sat Jul 26 05:02:48 2025 AUC 0.931183350249964
#
# [mbo] 14: learning_rate=0.0147; feature_fraction=0.344; bagging_fraction=0.811; num_leaves=30; min_data_in_leaf=751; lambda_l2=0.717 : y = 0.931 : 62.7 secs : infill_ei
#
# Sat Jul 26 05:03:52 2025 AUC 0.931588950252306
#
# [mbo] 15: learning_rate=0.0148; feature_fraction=0.363; bagging_fraction=0.821; num_leaves=28; min_data_in_leaf=749; lambda_l2=0.718 : y = 0.932 : 63.0 secs : infill_ei
#
# Sat Jul 26 05:04:54 2025 AUC 0.930787073508904
#
# [mbo] 16: learning_rate=0.0146; feature_fraction=0.36; bagging_fraction=0.812; num_leaves=27; min_data_in_leaf=747; lambda_l2=0.718 : y = 0.931 : 61.7 secs : infill_ei
#
# Sat Jul 26 05:05:58 2025 AUC 0.931243458933311
#
# [mbo] 17: learning_rate=0.0145; feature_fraction=0.354; bagging_fraction=0.825; num_leaves=30; min_data_in_leaf=749; lambda_l2=0.718 : y = 0.931 : 62.7 secs : infill_ei
#
# Sat Jul 26 05:07:01 2025 AUC 0.931025817102247
#
# [mbo] 18: learning_rate=0.0138; feature_fraction=0.347; bagging_fraction=0.826; num_leaves=30; min_data_in_leaf=748; lambda_l2=0.713 : y = 0.931 : 62.4 secs : infill_ei
#
# Sat Jul 26 05:08:05 2025 AUC 0.93114684838215
#
# [mbo] 19: learning_rate=0.0141; feature_fraction=0.362; bagging_fraction=0.812; num_leaves=29; min_data_in_leaf=749; lambda_l2=0.718 : y = 0.931 : 62.9 secs : infill_ei
#
# Sat Jul 26 05:09:09 2025 AUC 0.931894638503159
#
# [mbo] 20: learning_rate=0.0148; feature_fraction=0.364; bagging_fraction=0.821; num_leaves=29; min_data_in_leaf=747; lambda_l2=0.718 : y = 0.932 : 62.7 secs : infill_ei
#
# Saved the current state after iteration 21 in the file bayesiana.RDATA.
#
# Sat Jul 26 05:10:16 2025 AUC 0.931475266355687
#
# [mbo] 21: learning_rate=0.0148; feature_fraction=0.362; bagging_fraction=0.82; num_leaves=29; min_data_in_leaf=744; lambda_l2=0.718 : y = 0.931 : 62.9 secs : infill_ei
#
# Sat Jul 26 05:11:19 2025 AUC 0.931069101903051
#
# [mbo] 22: learning_rate=0.0148; feature_fraction=0.362; bagging_fraction=0.821; num_leaves=29; min_data_in_leaf=748; lambda_l2=0.718 : y = 0.931 : 61.7 secs : infill_ei
#
# Sat Jul 26 05:12:22 2025 AUC 0.931480832502921
#
# [mbo] 23: learning_rate=0.0147; feature_fraction=0.357; bagging_fraction=0.824; num_leaves=28; min_data_in_leaf=755; lambda_l2=0.718 : y = 0.931 : 62.1 secs : infill_ei
#
# Sat Jul 26 05:13:25 2025 AUC 0.931133524638248
#
# [mbo] 24: learning_rate=0.0148; feature_fraction=0.363; bagging_fraction=0.832; num_leaves=28; min_data_in_leaf=747; lambda_l2=0.718 : y = 0.931 : 62.2 secs : infill_ei
#
# Sat Jul 26 05:14:28 2025 AUC 0.931122118548261
#
# [mbo] 25: learning_rate=0.0146; feature_fraction=0.354; bagging_fraction=0.826; num_leaves=28; min_data_in_leaf=743; lambda_l2=0.74 : y = 0.931 : 61.5 secs : infill_ei
#
# Sat Jul 26 05:15:32 2025 AUC 0.930597503677781
#
# [mbo] 26: learning_rate=0.0147; feature_fraction=0.364; bagging_fraction=0.819; num_leaves=30; min_data_in_leaf=754; lambda_l2=0.718 : y = 0.931 : 63.2 secs : infill_ei
#
# Sat Jul 26 05:16:34 2025 AUC 0.930871720451171
#
# [mbo] 27: learning_rate=0.0146; feature_fraction=0.364; bagging_fraction=0.816; num_leaves=26; min_data_in_leaf=744; lambda_l2=0.711 : y = 0.931 : 61.4 secs : infill_ei
#
# Sat Jul 26 05:17:37 2025 AUC 0.930920431557924
#
# [mbo] 28: learning_rate=0.0142; feature_fraction=0.359; bagging_fraction=0.823; num_leaves=29; min_data_in_leaf=747; lambda_l2=0.718 : y = 0.931 : 62.4 secs : infill_ei
#
# Sat Jul 26 05:18:41 2025 AUC 0.930051042064938
#
# [mbo] 29: learning_rate=0.014; feature_fraction=0.353; bagging_fraction=0.825; num_leaves=30; min_data_in_leaf=746; lambda_l2=0.741 : y = 0.93 : 62.6 secs : infill_ei
#
# Sat Jul 26 05:19:42 2025 AUC 0.931395264980704
#
# [mbo] 30: learning_rate=0.0142; feature_fraction=0.358; bagging_fraction=0.822; num_leaves=28; min_data_in_leaf=743; lambda_l2=0.76 : y = 0.931 : 60.9 secs : infill_ei
#
# Saved the current state after iteration 31 in the file bayesiana.RDATA.
#
# Sat Jul 26 05:20:50 2025 AUC 0.930428910836621
#
# [mbo] 31: learning_rate=0.0138; feature_fraction=0.364; bagging_fraction=0.844; num_leaves=29; min_data_in_leaf=755; lambda_l2=0.763 : y = 0.93 : 63.0 secs : infill_ei
#
# Sat Jul 26 05:21:53 2025 AUC 0.931188552298054
#
# [mbo] 32: learning_rate=0.0138; feature_fraction=0.355; bagging_fraction=0.842; num_leaves=27; min_data_in_leaf=746; lambda_l2=0.765 : y = 0.931 : 61.8 secs : infill_ei
#
# Sat Jul 26 05:22:55 2025 AUC 0.930212709799129
#
# [mbo] 33: learning_rate=0.0136; feature_fraction=0.36; bagging_fraction=0.819; num_leaves=26; min_data_in_leaf=746; lambda_l2=0.736 : y = 0.93 : 61.2 secs : infill_ei
#
# Sat Jul 26 05:23:55 2025 AUC 0.930999824260254
#
# [mbo] 34: learning_rate=0.0148; feature_fraction=0.347; bagging_fraction=0.821; num_leaves=27; min_data_in_leaf=747; lambda_l2=0.717 : y = 0.931 : 59.6 secs : infill_ei
#
# Sat Jul 26 05:24:59 2025 AUC 0.931471309159206
#
# [mbo] 35: learning_rate=0.0145; feature_fraction=0.347; bagging_fraction=0.822; num_leaves=30; min_data_in_leaf=745; lambda_l2=0.762 : y = 0.931 : 62.3 secs : infill_ei
#
# Sat Jul 26 05:26:00 2025 AUC 0.929988448692749
#
# [mbo] 36: learning_rate=0.014; feature_fraction=0.352; bagging_fraction=0.84; num_leaves=26; min_data_in_leaf=754; lambda_l2=0.715 : y = 0.93 : 60.7 secs : infill_ei
#
# Sat Jul 26 05:27:03 2025 AUC 0.930310210219035
#
# [mbo] 37: learning_rate=0.0138; feature_fraction=0.347; bagging_fraction=0.838; num_leaves=28; min_data_in_leaf=752; lambda_l2=0.714 : y = 0.93 : 61.8 secs : infill_ei
#
# Sat Jul 26 05:28:06 2025 AUC 0.93145070504784
#
# [mbo] 38: learning_rate=0.0141; feature_fraction=0.342; bagging_fraction=0.828; num_leaves=30; min_data_in_leaf=745; lambda_l2=0.736 : y = 0.931 : 62.5 secs : infill_ei
#
# Sat Jul 26 05:29:10 2025 AUC 0.932221285850005
#
# [mbo] 39: learning_rate=0.0148; feature_fraction=0.359; bagging_fraction=0.818; num_leaves=29; min_data_in_leaf=748; lambda_l2=0.718 : y = 0.932 : 62.5 secs : infill_ei
#
# Sat Jul 26 05:30:13 2025 AUC 0.930750089267126
#
# [mbo] 40: learning_rate=0.0143; feature_fraction=0.36; bagging_fraction=0.841; num_leaves=27; min_data_in_leaf=751; lambda_l2=0.706 : y = 0.931 : 61.9 secs : infill_ei
#
# Saved the current state after iteration 41 in the file bayesiana.RDATA.
#
# Sat Jul 26 05:31:20 2025 AUC 0.930456419545726
#
# [mbo] 41: learning_rate=0.0148; feature_fraction=0.358; bagging_fraction=0.831; num_leaves=29; min_data_in_leaf=748; lambda_l2=0.714 : y = 0.93 : 62.4 secs : infill_ei
#
# Sat Jul 26 05:32:22 2025 AUC 0.930929620772118
#
# [mbo] 42: learning_rate=0.014; feature_fraction=0.361; bagging_fraction=0.816; num_leaves=26; min_data_in_leaf=741; lambda_l2=0.712 : y = 0.931 : 61.4 secs : infill_ei
#
# Sat Jul 26 05:33:25 2025 AUC 0.930456883677199
#
# [mbo] 43: learning_rate=0.0148; feature_fraction=0.359; bagging_fraction=0.814; num_leaves=29; min_data_in_leaf=745; lambda_l2=0.726 : y = 0.93 : 62.4 secs : infill_ei
#
# Sat Jul 26 05:34:27 2025 AUC 0.931307541032931
#
# [mbo] 44: learning_rate=0.0142; feature_fraction=0.36; bagging_fraction=0.826; num_leaves=27; min_data_in_leaf=741; lambda_l2=0.754 : y = 0.931 : 60.4 secs : infill_ei
#
# Sat Jul 26 05:35:30 2025 AUC 0.930651362504472
#
# [mbo] 45: learning_rate=0.0139; feature_fraction=0.347; bagging_fraction=0.842; num_leaves=28; min_data_in_leaf=746; lambda_l2=0.706 : y = 0.931 : 62.6 secs : infill_ei
#
# Sat Jul 26 05:36:33 2025 AUC 0.930795983456657
#
# [mbo] 46: learning_rate=0.0143; feature_fraction=0.348; bagging_fraction=0.818; num_leaves=29; min_data_in_leaf=747; lambda_l2=0.725 : y = 0.931 : 62.0 secs : infill_ei
#
# Sat Jul 26 05:37:36 2025 AUC 0.930937052554261
#
# [mbo] 47: learning_rate=0.0147; feature_fraction=0.358; bagging_fraction=0.822; num_leaves=28; min_data_in_leaf=750; lambda_l2=0.702 : y = 0.931 : 62.1 secs : infill_ei
#
# Sat Jul 26 05:38:39 2025 AUC 0.93093709298638
#
# [mbo] 48: learning_rate=0.014; feature_fraction=0.341; bagging_fraction=0.838; num_leaves=30; min_data_in_leaf=744; lambda_l2=0.741 : y = 0.931 : 62.1 secs : infill_ei
#
# Sat Jul 26 05:39:42 2025 AUC 0.931276385331785
#
# [mbo] 49: learning_rate=0.0147; feature_fraction=0.354; bagging_fraction=0.814; num_leaves=29; min_data_in_leaf=748; lambda_l2=0.718 : y = 0.931 : 62.2 secs : infill_ei
#
# Sat Jul 26 05:40:43 2025 AUC 0.931216256594377
#
# [mbo] 50: learning_rate=0.0143; feature_fraction=0.343; bagging_fraction=0.824; num_leaves=27; min_data_in_leaf=750; lambda_l2=0.749 : y = 0.931 : 60.1 secs : infill_ei
#
# Saved the current state after iteration 51 in the file bayesiana.RDATA.
#
# Sat Jul 26 05:41:49 2025 AUC 0.930770018957735
#
# [mbo] 51: learning_rate=0.0148; feature_fraction=0.359; bagging_fraction=0.818; num_leaves=29; min_data_in_leaf=748; lambda_l2=0.756 : y = 0.931 : 61.4 secs : infill_ei
#
# Sat Jul 26 05:42:53 2025 AUC 0.931445611573
#
# [mbo] 52: learning_rate=0.0136; feature_fraction=0.357; bagging_fraction=0.834; num_leaves=29; min_data_in_leaf=747; lambda_l2=0.746 : y = 0.931 : 62.9 secs : infill_ei
#
# Sat Jul 26 05:43:55 2025 AUC 0.931353394941456
#
# [mbo] 53: learning_rate=0.0136; feature_fraction=0.341; bagging_fraction=0.831; num_leaves=26; min_data_in_leaf=754; lambda_l2=0.728 : y = 0.931 : 60.7 secs : infill_ei
#
# Sat Jul 26 05:44:57 2025 AUC 0.930777183205304
#
# [mbo] 54: learning_rate=0.014; feature_fraction=0.355; bagging_fraction=0.814; num_leaves=28; min_data_in_leaf=751; lambda_l2=0.753 : y = 0.931 : 61.2 secs : infill_ei
#
# Sat Jul 26 05:46:00 2025 AUC 0.931058141874538
#
# [mbo] 55: learning_rate=0.0142; feature_fraction=0.36; bagging_fraction=0.817; num_leaves=30; min_data_in_leaf=746; lambda_l2=0.742 : y = 0.931 : 61.9 secs : infill_ei
#
# Sat Jul 26 05:47:02 2025 AUC 0.930517142718136
#
# [mbo] 56: learning_rate=0.0143; feature_fraction=0.345; bagging_fraction=0.838; num_leaves=28; min_data_in_leaf=745; lambda_l2=0.745 : y = 0.931 : 61.4 secs : infill_ei
#
# Sat Jul 26 05:48:06 2025 AUC 0.931015362597111
#
# [mbo] 57: learning_rate=0.0147; feature_fraction=0.359; bagging_fraction=0.823; num_leaves=29; min_data_in_leaf=748; lambda_l2=0.712 : y = 0.931 : 63.0 secs : infill_ei
#
# Sat Jul 26 05:49:10 2025 AUC 0.930024590176172
#
# [mbo] 58: learning_rate=0.0144; feature_fraction=0.365; bagging_fraction=0.844; num_leaves=29; min_data_in_leaf=747; lambda_l2=0.739 : y = 0.93 : 63.0 secs : infill_ei
#
# Sat Jul 26 05:50:12 2025 AUC 0.93024112227557
#
# [mbo] 59: learning_rate=0.0147; feature_fraction=0.345; bagging_fraction=0.824; num_leaves=26; min_data_in_leaf=755; lambda_l2=0.749 : y = 0.93 : 60.9 secs : infill_ei
#
# Sat Jul 26 05:51:16 2025 AUC 0.931451336620731
#
# [mbo] 60: learning_rate=0.0148; feature_fraction=0.361; bagging_fraction=0.817; num_leaves=29; min_data_in_leaf=744; lambda_l2=0.717 : y = 0.931 : 62.8 secs : infill_ei
#
# Saved the current state after iteration 61 in the file bayesiana.RDATA.
#
# Sat Jul 26 05:52:23 2025 AUC 0.930893921158187
#
# [mbo] 61: learning_rate=0.0142; feature_fraction=0.36; bagging_fraction=0.83; num_leaves=28; min_data_in_leaf=753; lambda_l2=0.77 : y = 0.931 : 62.1 secs : infill_ei
#
# Sat Jul 26 05:53:25 2025 AUC 0.930622339664758
#
# [mbo] 62: learning_rate=0.0138; feature_fraction=0.342; bagging_fraction=0.811; num_leaves=28; min_data_in_leaf=743; lambda_l2=0.714 : y = 0.931 : 61.4 secs : infill_ei
#
# Sat Jul 26 05:54:28 2025 AUC 0.930596747550212
#
# [mbo] 63: learning_rate=0.0148; feature_fraction=0.363; bagging_fraction=0.818; num_leaves=29; min_data_in_leaf=747; lambda_l2=0.718 : y = 0.931 : 61.9 secs : infill_ei
#
# Sat Jul 26 05:55:32 2025 AUC 0.931232766241427
#
# [mbo] 64: learning_rate=0.0143; feature_fraction=0.364; bagging_fraction=0.833; num_leaves=30; min_data_in_leaf=755; lambda_l2=0.718 : y = 0.931 : 62.2 secs : infill_ei
#
# Sat Jul 26 05:56:36 2025 AUC 0.930272073773593
#
# [mbo] 65: learning_rate=0.0144; feature_fraction=0.354; bagging_fraction=0.844; num_leaves=30; min_data_in_leaf=748; lambda_l2=0.755 : y = 0.93 : 63.0 secs : infill_ei
#
# Sat Jul 26 05:57:40 2025 AUC 0.930221489341306
#
# [mbo] 66: learning_rate=0.0142; feature_fraction=0.356; bagging_fraction=0.811; num_leaves=30; min_data_in_leaf=743; lambda_l2=0.746 : y = 0.93 : 63.1 secs : infill_ei
#
# Sat Jul 26 05:58:42 2025 AUC 0.930770427780525
#
# [mbo] 67: learning_rate=0.0139; feature_fraction=0.348; bagging_fraction=0.831; num_leaves=28; min_data_in_leaf=740; lambda_l2=0.772 : y = 0.931 : 61.8 secs : infill_ei
#
# Sat Jul 26 05:59:45 2025 AUC 0.930356112987802
#
# [mbo] 68: learning_rate=0.0145; feature_fraction=0.354; bagging_fraction=0.835; num_leaves=28; min_data_in_leaf=753; lambda_l2=0.723 : y = 0.93 : 61.2 secs : infill_ei
#
# Sat Jul 26 06:00:49 2025 AUC 0.93169481429606
#
# [mbo] 69: learning_rate=0.0137; feature_fraction=0.359; bagging_fraction=0.826; num_leaves=29; min_data_in_leaf=749; lambda_l2=0.718 : y = 0.932 : 63.2 secs : infill_ei
#
# Sat Jul 26 06:01:51 2025 AUC 0.9306485089788
#
# [mbo] 70: learning_rate=0.0147; feature_fraction=0.343; bagging_fraction=0.831; num_leaves=26; min_data_in_leaf=750; lambda_l2=0.735 : y = 0.931 : 61.5 secs : infill_ei
#
# Saved the current state after iteration 71 in the file bayesiana.RDATA.
#
# Sat Jul 26 06:03:00 2025 AUC 0.931119224924368
#
# [mbo] 71: learning_rate=0.0138; feature_fraction=0.344; bagging_fraction=0.818; num_leaves=27; min_data_in_leaf=753; lambda_l2=0.728 : y = 0.931 : 62.5 secs : infill_ei
#
# Sat Jul 26 06:04:02 2025 AUC 0.93061925494103
#
# [mbo] 72: learning_rate=0.014; feature_fraction=0.355; bagging_fraction=0.844; num_leaves=26; min_data_in_leaf=748; lambda_l2=0.765 : y = 0.931 : 61.4 secs : infill_ei
#
# Sat Jul 26 06:05:06 2025 AUC 0.929877172838765
#
# [mbo] 73: learning_rate=0.0146; feature_fraction=0.363; bagging_fraction=0.812; num_leaves=27; min_data_in_leaf=750; lambda_l2=0.743 : y = 0.93 : 62.5 secs : infill_ei
#
# Sat Jul 26 06:06:08 2025 AUC 0.930177991589932
#
# [mbo] 74: learning_rate=0.0137; feature_fraction=0.341; bagging_fraction=0.821; num_leaves=26; min_data_in_leaf=753; lambda_l2=0.739 : y = 0.93 : 60.6 secs : infill_ei
#
# Sat Jul 26 06:07:12 2025 AUC 0.930131568183968
#
# [mbo] 75: learning_rate=0.0137; feature_fraction=0.364; bagging_fraction=0.815; num_leaves=30; min_data_in_leaf=741; lambda_l2=0.766 : y = 0.93 : 63.4 secs : infill_ei
#
# Sat Jul 26 06:08:16 2025 AUC 0.932004888893912
#
# [mbo] 76: learning_rate=0.0146; feature_fraction=0.347; bagging_fraction=0.837; num_leaves=30; min_data_in_leaf=751; lambda_l2=0.721 : y = 0.932 : 62.9 secs : infill_ei
#
# Sat Jul 26 06:09:19 2025 AUC 0.93025204498158
#
# [mbo] 77: learning_rate=0.0138; feature_fraction=0.355; bagging_fraction=0.836; num_leaves=30; min_data_in_leaf=754; lambda_l2=0.701 : y = 0.93 : 61.8 secs : infill_ei
#
# Sat Jul 26 06:10:23 2025 AUC 0.93040947805196
#
# [mbo] 78: learning_rate=0.0144; feature_fraction=0.361; bagging_fraction=0.836; num_leaves=30; min_data_in_leaf=755; lambda_l2=0.732 : y = 0.93 : 63.4 secs : infill_ei
#
# Sat Jul 26 06:11:26 2025 AUC 0.931121930484333
#
# [mbo] 79: learning_rate=0.0144; feature_fraction=0.357; bagging_fraction=0.82; num_leaves=27; min_data_in_leaf=742; lambda_l2=0.762 : y = 0.931 : 61.4 secs : infill_ei
#
# Sat Jul 26 06:12:30 2025 AUC 0.930675971795144
#
# [mbo] 80: learning_rate=0.0142; feature_fraction=0.356; bagging_fraction=0.81; num_leaves=30; min_data_in_leaf=752; lambda_l2=0.74 : y = 0.931 : 63.2 secs : infill_ei
#
# Saved the current state after iteration 81 in the file bayesiana.RDATA.
#
# Sat Jul 26 06:13:36 2025 AUC 0.931299711015091
#
# [mbo] 81: learning_rate=0.0144; feature_fraction=0.35; bagging_fraction=0.816; num_leaves=29; min_data_in_leaf=740; lambda_l2=0.771 : y = 0.931 : 62.4 secs : infill_ei
#
# Sat Jul 26 06:14:38 2025 AUC 0.930387260339276
#
# [mbo] 82: learning_rate=0.0147; feature_fraction=0.345; bagging_fraction=0.832; num_leaves=26; min_data_in_leaf=747; lambda_l2=0.77 : y = 0.93 : 60.9 secs : infill_ei
#
# Sat Jul 26 06:15:39 2025 AUC 0.931382412796155
#
# [mbo] 83: learning_rate=0.0142; feature_fraction=0.343; bagging_fraction=0.823; num_leaves=26; min_data_in_leaf=744; lambda_l2=0.761 : y = 0.931 : 59.9 secs : infill_ei
#
# Sat Jul 26 06:16:43 2025 AUC 0.931223648947266
#
# [mbo] 84: learning_rate=0.0144; feature_fraction=0.361; bagging_fraction=0.841; num_leaves=29; min_data_in_leaf=749; lambda_l2=0.726 : y = 0.931 : 63.1 secs : infill_ei
#
# Sat Jul 26 06:17:46 2025 AUC 0.930458042476994
#
# [mbo] 85: learning_rate=0.0135; feature_fraction=0.344; bagging_fraction=0.827; num_leaves=27; min_data_in_leaf=755; lambda_l2=0.725 : y = 0.93 : 61.6 secs : infill_ei
#
# Sat Jul 26 06:18:48 2025 AUC 0.931154375560011
#
# [mbo] 86: learning_rate=0.0144; feature_fraction=0.349; bagging_fraction=0.833; num_leaves=27; min_data_in_leaf=746; lambda_l2=0.734 : y = 0.931 : 60.5 secs : infill_ei
#
# Sat Jul 26 06:19:52 2025 AUC 0.931000149695155
#
# [mbo] 87: learning_rate=0.0146; feature_fraction=0.356; bagging_fraction=0.814; num_leaves=30; min_data_in_leaf=746; lambda_l2=0.743 : y = 0.931 : 63.1 secs : infill_ei
#
# Sat Jul 26 06:20:55 2025 AUC 0.931049094136566
#
# [mbo] 88: learning_rate=0.014; feature_fraction=0.345; bagging_fraction=0.833; num_leaves=28; min_data_in_leaf=754; lambda_l2=0.737 : y = 0.931 : 61.8 secs : infill_ei
#
# Sat Jul 26 06:21:58 2025 AUC 0.931324985788056
#
# [mbo] 89: learning_rate=0.0146; feature_fraction=0.359; bagging_fraction=0.824; num_leaves=29; min_data_in_leaf=752; lambda_l2=0.705 : y = 0.931 : 62.6 secs : infill_ei
#
# Sat Jul 26 06:23:02 2025 AUC 0.930075524990193
#
# [mbo] 90: learning_rate=0.0146; feature_fraction=0.364; bagging_fraction=0.822; num_leaves=29; min_data_in_leaf=745; lambda_l2=0.756 : y = 0.93 : 62.9 secs : infill_ei
#
# Saved the current state after iteration 91 in the file bayesiana.RDATA.
#
# Sat Jul 26 06:24:09 2025 AUC 0.93082349361051
#
# [mbo] 91: learning_rate=0.0144; feature_fraction=0.355; bagging_fraction=0.839; num_leaves=28; min_data_in_leaf=748; lambda_l2=0.716 : y = 0.931 : 62.5 secs : infill_ei
#
# Sat Jul 26 06:25:15 2025 AUC 0.930429214994078
#
# [mbo] 92: learning_rate=0.0137; feature_fraction=0.349; bagging_fraction=0.836; num_leaves=27; min_data_in_leaf=741; lambda_l2=0.738 : y = 0.93 : 64.4 secs : infill_ei
#
# Sat Jul 26 06:26:17 2025 AUC 0.929881577180096
#
# [mbo] 93: learning_rate=0.0139; feature_fraction=0.345; bagging_fraction=0.829; num_leaves=30; min_data_in_leaf=751; lambda_l2=0.777 : y = 0.93 : 61.5 secs : infill_ei
#
# Sat Jul 26 06:27:20 2025 AUC 0.93134650435025
#
# [mbo] 94: learning_rate=0.014; feature_fraction=0.345; bagging_fraction=0.812; num_leaves=27; min_data_in_leaf=750; lambda_l2=0.748 : y = 0.931 : 61.1 secs : infill_ei
#
# Sat Jul 26 06:28:22 2025 AUC 0.930205800272779
#
# [mbo] 95: learning_rate=0.0136; feature_fraction=0.341; bagging_fraction=0.833; num_leaves=28; min_data_in_leaf=754; lambda_l2=0.751 : y = 0.93 : 61.7 secs : infill_ei
#
# Sat Jul 26 06:29:27 2025 AUC 0.931635109380555
#
# [mbo] 96: learning_rate=0.0141; feature_fraction=0.358; bagging_fraction=0.843; num_leaves=30; min_data_in_leaf=755; lambda_l2=0.779 : y = 0.932 : 63.1 secs : infill_ei
#
# Sat Jul 26 06:30:30 2025 AUC 0.931186474338555
#
# [mbo] 97: learning_rate=0.0139; feature_fraction=0.363; bagging_fraction=0.839; num_leaves=28; min_data_in_leaf=754; lambda_l2=0.736 : y = 0.931 : 62.6 secs : infill_ei
#
# Sat Jul 26 06:31:31 2025 AUC 0.930372048675963
#
# [mbo] 98: learning_rate=0.0141; feature_fraction=0.349; bagging_fraction=0.825; num_leaves=26; min_data_in_leaf=754; lambda_l2=0.731 : y = 0.93 : 60.0 secs : infill_ei
#
# Sat Jul 26 06:32:34 2025 AUC 0.93027346673928
#
# [mbo] 99: learning_rate=0.0136; feature_fraction=0.352; bagging_fraction=0.842; num_leaves=27; min_data_in_leaf=750; lambda_l2=0.75 : y = 0.93 : 61.8 secs : infill_ei
#
# Sat Jul 26 06:33:38 2025 AUC 0.930774181552954
#
# [mbo] 100: learning_rate=0.0141; feature_fraction=0.362; bagging_fraction=0.828; num_leaves=26; min_data_in_leaf=741; lambda_l2=0.717 : y = 0.931 : 62.3 secs : infill_ei
#
# Saved the current state after iteration 101 in the file bayesiana.RDATA.
#
# Sat Jul 26 06:34:46 2025 AUC 0.931193573173003
#
# [mbo] 101: learning_rate=0.0141; feature_fraction=0.344; bagging_fraction=0.831; num_leaves=29; min_data_in_leaf=745; lambda_l2=0.729 : y = 0.931 : 61.5 secs : infill_ei
#
# Sat Jul 26 06:35:48 2025 AUC 0.93127626368897
#
# [mbo] 102: learning_rate=0.0141; feature_fraction=0.359; bagging_fraction=0.832; num_leaves=26; min_data_in_leaf=746; lambda_l2=0.727 : y = 0.931 : 61.0 secs : infill_ei
#
# Sat Jul 26 06:36:51 2025 AUC 0.930644122652973
#
# [mbo] 103: learning_rate=0.0146; feature_fraction=0.354; bagging_fraction=0.815; num_leaves=29; min_data_in_leaf=741; lambda_l2=0.723 : y = 0.931 : 62.3 secs : infill_ei
#
# Sat Jul 26 06:37:54 2025 AUC 0.93195360134068
#
# [mbo] 104: learning_rate=0.0139; feature_fraction=0.358; bagging_fraction=0.842; num_leaves=28; min_data_in_leaf=752; lambda_l2=0.72 : y = 0.932 : 62.0 secs : infill_ei
#
# Sat Jul 26 06:38:58 2025 AUC 0.930792926950271
#
# [mbo] 105: learning_rate=0.0148; feature_fraction=0.359; bagging_fraction=0.821; num_leaves=28; min_data_in_leaf=745; lambda_l2=0.749 : y = 0.931 : 62.2 secs : infill_ei
#
# Sat Jul 26 06:40:00 2025 AUC 0.931463318841759
#
# [mbo] 106: learning_rate=0.0137; feature_fraction=0.356; bagging_fraction=0.823; num_leaves=27; min_data_in_leaf=740; lambda_l2=0.734 : y = 0.931 : 61.6 secs : infill_ei
#
# Sat Jul 26 06:41:03 2025 AUC 0.931211244356526
#
# [mbo] 107: learning_rate=0.0141; feature_fraction=0.347; bagging_fraction=0.819; num_leaves=29; min_data_in_leaf=745; lambda_l2=0.708 : y = 0.931 : 61.5 secs : infill_ei
#
# Sat Jul 26 06:42:06 2025 AUC 0.930310855141081
#
# [mbo] 108: learning_rate=0.0146; feature_fraction=0.363; bagging_fraction=0.81; num_leaves=27; min_data_in_leaf=742; lambda_l2=0.734 : y = 0.93 : 61.6 secs : infill_ei
#
# Sat Jul 26 06:43:10 2025 AUC 0.930751490655649
#
# [mbo] 109: learning_rate=0.0138; feature_fraction=0.36; bagging_fraction=0.833; num_leaves=30; min_data_in_leaf=755; lambda_l2=0.711 : y = 0.931 : 63.1 secs : infill_ei
#
# Sat Jul 26 06:44:13 2025 AUC 0.93052876788716
#
# [mbo] 110: learning_rate=0.0138; feature_fraction=0.363; bagging_fraction=0.841; num_leaves=27; min_data_in_leaf=753; lambda_l2=0.707 : y = 0.931 : 61.7 secs : infill_ei
#
# Saved the current state after iteration 111 in the file bayesiana.RDATA.
#
# Sat Jul 26 06:45:20 2025 AUC 0.931363501048412
#
# [mbo] 111: learning_rate=0.0148; feature_fraction=0.351; bagging_fraction=0.827; num_leaves=30; min_data_in_leaf=755; lambda_l2=0.773 : y = 0.931 : 63.0 secs : infill_ei
#
# Sat Jul 26 06:46:23 2025 AUC 0.930615754427356
#
# [mbo] 112: learning_rate=0.0141; feature_fraction=0.343; bagging_fraction=0.823; num_leaves=27; min_data_in_leaf=750; lambda_l2=0.754 : y = 0.931 : 61.1 secs : infill_ei
#
# Sat Jul 26 06:47:25 2025 AUC 0.930570953751924
#
# [mbo] 113: learning_rate=0.0147; feature_fraction=0.365; bagging_fraction=0.823; num_leaves=26; min_data_in_leaf=747; lambda_l2=0.761 : y = 0.931 : 61.4 secs : infill_ei
#
# Sat Jul 26 06:48:27 2025 AUC 0.930331873771382
#
# [mbo] 114: learning_rate=0.0146; feature_fraction=0.35; bagging_fraction=0.827; num_leaves=27; min_data_in_leaf=753; lambda_l2=0.737 : y = 0.93 : 60.3 secs : infill_ei
#
# Sat Jul 26 06:49:31 2025 AUC 0.93165543966258
#
# [mbo] 115: learning_rate=0.0147; feature_fraction=0.351; bagging_fraction=0.813; num_leaves=30; min_data_in_leaf=745; lambda_l2=0.739 : y = 0.932 : 62.9 secs : infill_ei
#
# Sat Jul 26 06:50:34 2025 AUC 0.93124392253307
#
# [mbo] 116: learning_rate=0.0148; feature_fraction=0.35; bagging_fraction=0.821; num_leaves=29; min_data_in_leaf=753; lambda_l2=0.766 : y = 0.931 : 62.2 secs : infill_ei
#
# Sat Jul 26 06:51:38 2025 AUC 0.930385359844991
#
# [mbo] 117: learning_rate=0.0139; feature_fraction=0.351; bagging_fraction=0.831; num_leaves=30; min_data_in_leaf=749; lambda_l2=0.702 : y = 0.93 : 62.7 secs : infill_ei
#
# Sat Jul 26 06:52:40 2025 AUC 0.931655813909948
#
# [mbo] 118: learning_rate=0.0142; feature_fraction=0.345; bagging_fraction=0.823; num_leaves=26; min_data_in_leaf=753; lambda_l2=0.702 : y = 0.932 : 60.7 secs : infill_ei
#
# Sat Jul 26 06:53:42 2025 AUC 0.93013264383317
#
# [mbo] 119: learning_rate=0.0135; feature_fraction=0.358; bagging_fraction=0.843; num_leaves=28; min_data_in_leaf=755; lambda_l2=0.757 : y = 0.93 : 61.2 secs : infill_ei
#
# Sat Jul 26 06:54:45 2025 AUC 0.930847102434461
#
# [mbo] 120: learning_rate=0.0144; feature_fraction=0.349; bagging_fraction=0.837; num_leaves=28; min_data_in_leaf=745; lambda_l2=0.779 : y = 0.931 : 62.0 secs : infill_ei
#
# Saved the current state after iteration 121 in the file bayesiana.RDATA.
#
# Sat Jul 26 06:55:53 2025 AUC 0.930341555831169
#
# [mbo] 121: learning_rate=0.0147; feature_fraction=0.355; bagging_fraction=0.824; num_leaves=29; min_data_in_leaf=748; lambda_l2=0.726 : y = 0.93 : 62.5 secs : infill_ei
#
# Sat Jul 26 06:56:55 2025 AUC 0.931032117493918
#
# [mbo] 122: learning_rate=0.0136; feature_fraction=0.347; bagging_fraction=0.834; num_leaves=26; min_data_in_leaf=742; lambda_l2=0.723 : y = 0.931 : 60.8 secs : infill_ei
#
# Sat Jul 26 06:57:58 2025 AUC 0.930835572350734
#
# [mbo] 123: learning_rate=0.0146; feature_fraction=0.361; bagging_fraction=0.841; num_leaves=28; min_data_in_leaf=742; lambda_l2=0.729 : y = 0.931 : 62.2 secs : infill_ei
#
# Sat Jul 26 06:59:01 2025 AUC 0.93094711859059
#
# [mbo] 124: learning_rate=0.0142; feature_fraction=0.355; bagging_fraction=0.829; num_leaves=30; min_data_in_leaf=743; lambda_l2=0.709 : y = 0.931 : 61.6 secs : infill_ei
#
# Sat Jul 26 07:00:04 2025 AUC 0.930957796781341
#
# [mbo] 125: learning_rate=0.0143; feature_fraction=0.341; bagging_fraction=0.838; num_leaves=29; min_data_in_leaf=746; lambda_l2=0.75 : y = 0.931 : 62.5 secs : infill_ei
#
# Sat Jul 26 07:01:09 2025 AUC 0.931159930401239
#
# [mbo] 126: learning_rate=0.0139; feature_fraction=0.361; bagging_fraction=0.838; num_leaves=30; min_data_in_leaf=745; lambda_l2=0.708 : y = 0.931 : 63.5 secs : infill_ei
#
# Sat Jul 26 07:02:13 2025 AUC 0.930649865190097
#
# [mbo] 127: learning_rate=0.0138; feature_fraction=0.346; bagging_fraction=0.843; num_leaves=29; min_data_in_leaf=742; lambda_l2=0.727 : y = 0.931 : 62.2 secs : infill_ei
#
# Sat Jul 26 07:03:16 2025 AUC 0.931741617145349
#
# [mbo] 128: learning_rate=0.0145; feature_fraction=0.362; bagging_fraction=0.814; num_leaves=28; min_data_in_leaf=746; lambda_l2=0.721 : y = 0.932 : 62.4 secs : infill_ei
#
# Sat Jul 26 07:04:20 2025 AUC 0.93068057367079
#
# [mbo] 129: learning_rate=0.0138; feature_fraction=0.354; bagging_fraction=0.817; num_leaves=29; min_data_in_leaf=745; lambda_l2=0.736 : y = 0.931 : 62.5 secs : infill_ei
#
# Sat Jul 26 07:05:25 2025 AUC 0.93078257493811
#
# [mbo] 130: learning_rate=0.0135; feature_fraction=0.358; bagging_fraction=0.817; num_leaves=30; min_data_in_leaf=754; lambda_l2=0.771 : y = 0.931 : 63.4 secs : infill_ei
#
# Saved the current state after iteration 131 in the file bayesiana.RDATA.
#
# Sat Jul 26 07:06:30 2025 AUC 0.931070998259521
#
# [mbo] 131: learning_rate=0.0143; feature_fraction=0.348; bagging_fraction=0.823; num_leaves=28; min_data_in_leaf=754; lambda_l2=0.773 : y = 0.931 : 60.6 secs : infill_ei
#
# Sat Jul 26 07:07:33 2025 AUC 0.930538692999982
#
# [mbo] 132: learning_rate=0.0137; feature_fraction=0.341; bagging_fraction=0.829; num_leaves=30; min_data_in_leaf=753; lambda_l2=0.736 : y = 0.931 : 62.1 secs : infill_ei
#
# Sat Jul 26 07:08:36 2025 AUC 0.930941143064929
#
# [mbo] 133: learning_rate=0.014; feature_fraction=0.357; bagging_fraction=0.84; num_leaves=27; min_data_in_leaf=744; lambda_l2=0.756 : y = 0.931 : 61.6 secs : infill_ei
#
# Sat Jul 26 07:09:40 2025 AUC 0.930804264091842
#
# [mbo] 134: learning_rate=0.0143; feature_fraction=0.348; bagging_fraction=0.845; num_leaves=29; min_data_in_leaf=752; lambda_l2=0.732 : y = 0.931 : 62.1 secs : infill_ei
#
# Sat Jul 26 07:10:44 2025 AUC 0.931008124872889
#
# [mbo] 135: learning_rate=0.0147; feature_fraction=0.358; bagging_fraction=0.823; num_leaves=29; min_data_in_leaf=745; lambda_l2=0.714 : y = 0.931 : 62.9 secs : infill_ei
#
# Sat Jul 26 07:11:47 2025 AUC 0.930636220707798
#
# [mbo] 136: learning_rate=0.0142; feature_fraction=0.361; bagging_fraction=0.827; num_leaves=30; min_data_in_leaf=747; lambda_l2=0.731 : y = 0.931 : 61.9 secs : infill_ei
#
# Sat Jul 26 07:12:50 2025 AUC 0.930883784985828
#
# [mbo] 137: learning_rate=0.0138; feature_fraction=0.344; bagging_fraction=0.814; num_leaves=27; min_data_in_leaf=751; lambda_l2=0.749 : y = 0.931 : 61.4 secs : infill_ei
#
# Sat Jul 26 07:13:51 2025 AUC 0.931032081608669
#
# [mbo] 138: learning_rate=0.0147; feature_fraction=0.342; bagging_fraction=0.817; num_leaves=26; min_data_in_leaf=744; lambda_l2=0.727 : y = 0.931 : 60.5 secs : infill_ei
#
# Sat Jul 26 07:14:54 2025 AUC 0.930529848827121
#
# [mbo] 139: learning_rate=0.0139; feature_fraction=0.35; bagging_fraction=0.831; num_leaves=30; min_data_in_leaf=745; lambda_l2=0.771 : y = 0.931 : 61.5 secs : infill_ei
#
# Sat Jul 26 07:15:56 2025 AUC 0.930658604229032
#
# [mbo] 140: learning_rate=0.0138; feature_fraction=0.347; bagging_fraction=0.819; num_leaves=26; min_data_in_leaf=751; lambda_l2=0.76 : y = 0.931 : 60.8 secs : infill_ei
#
# Saved the current state after iteration 141 in the file bayesiana.RDATA.
#
# Sat Jul 26 07:17:02 2025 AUC 0.931324814244957
#
# [mbo] 141: learning_rate=0.0145; feature_fraction=0.344; bagging_fraction=0.815; num_leaves=29; min_data_in_leaf=742; lambda_l2=0.742 : y = 0.931 : 61.0 secs : infill_ei
#
# Sat Jul 26 07:18:06 2025 AUC 0.931262551837617
#
# [mbo] 142: learning_rate=0.0145; feature_fraction=0.349; bagging_fraction=0.819; num_leaves=28; min_data_in_leaf=751; lambda_l2=0.746 : y = 0.931 : 62.4 secs : infill_ei
#
# Sat Jul 26 07:19:08 2025 AUC 0.930945511729065
#
# [mbo] 143: learning_rate=0.0145; feature_fraction=0.348; bagging_fraction=0.821; num_leaves=27; min_data_in_leaf=748; lambda_l2=0.719 : y = 0.931 : 61.1 secs : infill_ei
#
# Sat Jul 26 07:20:11 2025 AUC 0.931016964964522
#
# [mbo] 144: learning_rate=0.0141; feature_fraction=0.34; bagging_fraction=0.815; num_leaves=28; min_data_in_leaf=746; lambda_l2=0.747 : y = 0.931 : 61.0 secs : infill_ei
#
# Sat Jul 26 07:21:14 2025 AUC 0.931452242841997
#
# [mbo] 145: learning_rate=0.0142; feature_fraction=0.347; bagging_fraction=0.831; num_leaves=28; min_data_in_leaf=740; lambda_l2=0.778 : y = 0.931 : 61.7 secs : infill_ei
#
# Sat Jul 26 07:22:17 2025 AUC 0.930761272477976
#
# [mbo] 146: learning_rate=0.0139; feature_fraction=0.364; bagging_fraction=0.81; num_leaves=28; min_data_in_leaf=748; lambda_l2=0.725 : y = 0.931 : 62.4 secs : infill_ei
#
# Sat Jul 26 07:23:21 2025 AUC 0.931324589317165
#
# [mbo] 147: learning_rate=0.0141; feature_fraction=0.35; bagging_fraction=0.836; num_leaves=29; min_data_in_leaf=751; lambda_l2=0.723 : y = 0.931 : 62.1 secs : infill_ei
#
# Sat Jul 26 07:24:24 2025 AUC 0.930483509034871
#
# [mbo] 148: learning_rate=0.0138; feature_fraction=0.359; bagging_fraction=0.841; num_leaves=30; min_data_in_leaf=755; lambda_l2=0.706 : y = 0.93 : 62.2 secs : infill_ei
#
# Sat Jul 26 07:25:26 2025 AUC 0.931002593693656
#
# [mbo] 149: learning_rate=0.0137; feature_fraction=0.348; bagging_fraction=0.835; num_leaves=27; min_data_in_leaf=743; lambda_l2=0.714 : y = 0.931 : 60.5 secs : infill_ei
#
# Sat Jul 26 07:26:29 2025 AUC 0.930915103045836
#
# [mbo] 150: learning_rate=0.0139; feature_fraction=0.351; bagging_fraction=0.837; num_leaves=26; min_data_in_leaf=750; lambda_l2=0.743 : y = 0.931 : 61.1 secs : infill_ei
#
# Saved the current state after iteration 151 in the file bayesiana.RDATA.
#
# Sat Jul 26 07:27:34 2025 AUC 0.930990977923958
#
# [mbo] 151: learning_rate=0.0136; feature_fraction=0.34; bagging_fraction=0.835; num_leaves=27; min_data_in_leaf=746; lambda_l2=0.738 : y = 0.931 : 60.9 secs : infill_ei
#
# Sat Jul 26 07:28:37 2025 AUC 0.931162149611469
#
# [mbo] 152: learning_rate=0.0145; feature_fraction=0.356; bagging_fraction=0.835; num_leaves=26; min_data_in_leaf=746; lambda_l2=0.758 : y = 0.931 : 61.1 secs : infill_ei
#
# Sat Jul 26 07:29:38 2025 AUC 0.930193242045778
#
# [mbo] 153: learning_rate=0.0138; feature_fraction=0.343; bagging_fraction=0.828; num_leaves=26; min_data_in_leaf=741; lambda_l2=0.717 : y = 0.93 : 59.7 secs : infill_ei
#
# Sat Jul 26 07:30:41 2025 AUC 0.930932866649331
#
# [mbo] 154: learning_rate=0.0145; feature_fraction=0.353; bagging_fraction=0.827; num_leaves=29; min_data_in_leaf=755; lambda_l2=0.711 : y = 0.931 : 62.3 secs : infill_ei
#
# Sat Jul 26 07:31:45 2025 AUC 0.930847104966506
#
# [mbo] 155: learning_rate=0.0137; feature_fraction=0.358; bagging_fraction=0.828; num_leaves=28; min_data_in_leaf=747; lambda_l2=0.708 : y = 0.931 : 62.3 secs : infill_ei
#
# Sat Jul 26 07:32:47 2025 AUC 0.930368691470984
#
# [mbo] 156: learning_rate=0.0144; feature_fraction=0.352; bagging_fraction=0.822; num_leaves=26; min_data_in_leaf=740; lambda_l2=0.7 : y = 0.93 : 60.8 secs : infill_ei
#
# Sat Jul 26 07:33:52 2025 AUC 0.93098987210406
#
# [mbo] 157: learning_rate=0.0145; feature_fraction=0.351; bagging_fraction=0.823; num_leaves=30; min_data_in_leaf=745; lambda_l2=0.736 : y = 0.931 : 63.2 secs : infill_ei
#
# Sat Jul 26 07:34:56 2025 AUC 0.930287055062818
#
# [mbo] 158: learning_rate=0.0138; feature_fraction=0.362; bagging_fraction=0.816; num_leaves=29; min_data_in_leaf=753; lambda_l2=0.772 : y = 0.93 : 62.9 secs : infill_ei
#
# Sat Jul 26 07:36:00 2025 AUC 0.930465845158195
#
# [mbo] 159: learning_rate=0.0146; feature_fraction=0.355; bagging_fraction=0.831; num_leaves=28; min_data_in_leaf=745; lambda_l2=0.77 : y = 0.93 : 62.4 secs : infill_ei
#
# Sat Jul 26 07:37:03 2025 AUC 0.930887136030873
#
# [mbo] 160: learning_rate=0.0136; feature_fraction=0.352; bagging_fraction=0.835; num_leaves=28; min_data_in_leaf=754; lambda_l2=0.701 : y = 0.931 : 62.0 secs : infill_ei
#
# Saved the current state after iteration 161 in the file bayesiana.RDATA.
#
# Sat Jul 26 07:38:13 2025 AUC 0.931200384866646
#
# [mbo] 161: learning_rate=0.0136; feature_fraction=0.364; bagging_fraction=0.816; num_leaves=30; min_data_in_leaf=743; lambda_l2=0.706 : y = 0.931 : 63.3 secs : infill_ei
#
# Sat Jul 26 07:39:17 2025 AUC 0.931177207427973
#
# [mbo] 162: learning_rate=0.0142; feature_fraction=0.355; bagging_fraction=0.819; num_leaves=30; min_data_in_leaf=748; lambda_l2=0.721 : y = 0.931 : 62.4 secs : infill_ei
#
# Sat Jul 26 07:40:20 2025 AUC 0.930987107674115
#
# [mbo] 163: learning_rate=0.0147; feature_fraction=0.349; bagging_fraction=0.844; num_leaves=29; min_data_in_leaf=743; lambda_l2=0.746 : y = 0.931 : 62.6 secs : infill_ei
#
# Sat Jul 26 07:41:23 2025 AUC 0.930957641761093
#
# [mbo] 164: learning_rate=0.0137; feature_fraction=0.353; bagging_fraction=0.837; num_leaves=27; min_data_in_leaf=740; lambda_l2=0.744 : y = 0.931 : 61.5 secs : infill_ei
#
# Sat Jul 26 07:42:27 2025 AUC 0.931598183684902
#
# [mbo] 165: learning_rate=0.0143; feature_fraction=0.341; bagging_fraction=0.832; num_leaves=29; min_data_in_leaf=746; lambda_l2=0.716 : y = 0.932 : 62.1 secs : infill_ei
#
# Sat Jul 26 07:43:30 2025 AUC 0.931144588079818
#
# [mbo] 166: learning_rate=0.0141; feature_fraction=0.342; bagging_fraction=0.828; num_leaves=29; min_data_in_leaf=749; lambda_l2=0.734 : y = 0.931 : 61.9 secs : infill_ei
#
# Sat Jul 26 07:44:35 2025 AUC 0.931813791651612
#
# [mbo] 167: learning_rate=0.0139; feature_fraction=0.362; bagging_fraction=0.838; num_leaves=30; min_data_in_leaf=755; lambda_l2=0.731 : y = 0.932 : 63.3 secs : infill_ei
#
# Sat Jul 26 07:45:37 2025 AUC 0.930998862462315
#
# [mbo] 168: learning_rate=0.0142; feature_fraction=0.355; bagging_fraction=0.824; num_leaves=28; min_data_in_leaf=754; lambda_l2=0.719 : y = 0.931 : 61.3 secs : infill_ei
#
# Sat Jul 26 07:46:41 2025 AUC 0.930788069224713
#
# [mbo] 169: learning_rate=0.0143; feature_fraction=0.356; bagging_fraction=0.839; num_leaves=27; min_data_in_leaf=752; lambda_l2=0.752 : y = 0.931 : 61.8 secs : infill_ei
#
# Sat Jul 26 07:47:44 2025 AUC 0.930467310576544
#
# [mbo] 170: learning_rate=0.0147; feature_fraction=0.351; bagging_fraction=0.829; num_leaves=27; min_data_in_leaf=747; lambda_l2=0.749 : y = 0.93 : 61.5 secs : infill_ei
#
# Saved the current state after iteration 171 in the file bayesiana.RDATA.
#
# Sat Jul 26 07:48:51 2025 AUC 0.930787261370577
#
# [mbo] 171: learning_rate=0.0139; feature_fraction=0.356; bagging_fraction=0.839; num_leaves=29; min_data_in_leaf=747; lambda_l2=0.709 : y = 0.931 : 62.8 secs : infill_ei
#
# Sat Jul 26 07:49:54 2025 AUC 0.931138281751384
#
# [mbo] 172: learning_rate=0.0137; feature_fraction=0.348; bagging_fraction=0.823; num_leaves=27; min_data_in_leaf=750; lambda_l2=0.762 : y = 0.931 : 60.7 secs : infill_ei
#
# Sat Jul 26 07:50:58 2025 AUC 0.930586633858052
#
# [mbo] 173: learning_rate=0.0138; feature_fraction=0.348; bagging_fraction=0.817; num_leaves=30; min_data_in_leaf=746; lambda_l2=0.704 : y = 0.931 : 63.6 secs : infill_ei
#
# Sat Jul 26 07:52:03 2025 AUC 0.931309440133946
#
# [mbo] 174: learning_rate=0.0142; feature_fraction=0.357; bagging_fraction=0.836; num_leaves=30; min_data_in_leaf=746; lambda_l2=0.739 : y = 0.931 : 63.3 secs : infill_ei
#
# Sat Jul 26 07:53:06 2025 AUC 0.931893063811513
#
# [mbo] 175: learning_rate=0.0144; feature_fraction=0.359; bagging_fraction=0.812; num_leaves=26; min_data_in_leaf=751; lambda_l2=0.722 : y = 0.932 : 61.5 secs : infill_ei
#
# Sat Jul 26 07:54:10 2025 AUC 0.931116131843342
#
# [mbo] 176: learning_rate=0.0145; feature_fraction=0.347; bagging_fraction=0.834; num_leaves=29; min_data_in_leaf=747; lambda_l2=0.719 : y = 0.931 : 62.0 secs : infill_ei
#
# Sat Jul 26 07:55:13 2025 AUC 0.931132257929771
#
# [mbo] 177: learning_rate=0.0147; feature_fraction=0.348; bagging_fraction=0.839; num_leaves=29; min_data_in_leaf=748; lambda_l2=0.738 : y = 0.931 : 61.6 secs : infill_ei
#
# Sat Jul 26 07:56:16 2025 AUC 0.930715091462215
#
# [mbo] 178: learning_rate=0.0136; feature_fraction=0.347; bagging_fraction=0.842; num_leaves=27; min_data_in_leaf=748; lambda_l2=0.707 : y = 0.931 : 61.4 secs : infill_ei
#
# Sat Jul 26 07:57:20 2025 AUC 0.930766312443628
#
# [mbo] 179: learning_rate=0.0142; feature_fraction=0.356; bagging_fraction=0.84; num_leaves=29; min_data_in_leaf=753; lambda_l2=0.714 : y = 0.931 : 62.6 secs : infill_ei
#
# Sat Jul 26 07:58:21 2025 AUC 0.930620215334835
#
# [mbo] 180: learning_rate=0.0141; feature_fraction=0.348; bagging_fraction=0.833; num_leaves=26; min_data_in_leaf=744; lambda_l2=0.735 : y = 0.931 : 60.2 secs : infill_ei
#
# Saved the current state after iteration 181 in the file bayesiana.RDATA.
#
# Sat Jul 26 07:59:26 2025 AUC 0.930285701637615
#
# [mbo] 181: learning_rate=0.0147; feature_fraction=0.341; bagging_fraction=0.845; num_leaves=26; min_data_in_leaf=752; lambda_l2=0.719 : y = 0.93 : 59.7 secs : infill_ei
#
# Sat Jul 26 08:00:30 2025 AUC 0.931839308535696
#
# [mbo] 182: learning_rate=0.0138; feature_fraction=0.364; bagging_fraction=0.831; num_leaves=27; min_data_in_leaf=743; lambda_l2=0.705 : y = 0.932 : 62.5 secs : infill_ei
#
# Sat Jul 26 08:01:34 2025 AUC 0.93040601476805
#
# [mbo] 183: learning_rate=0.0137; feature_fraction=0.357; bagging_fraction=0.836; num_leaves=28; min_data_in_leaf=749; lambda_l2=0.718 : y = 0.93 : 62.2 secs : infill_ei
#
# Sat Jul 26 08:02:37 2025 AUC 0.929780734353021
#
# [mbo] 184: learning_rate=0.0146; feature_fraction=0.359; bagging_fraction=0.836; num_leaves=26; min_data_in_leaf=747; lambda_l2=0.73 : y = 0.93 : 61.5 secs : infill_ei
#
# Sat Jul 26 08:03:41 2025 AUC 0.931543164700523
#
# [mbo] 185: learning_rate=0.0144; feature_fraction=0.347; bagging_fraction=0.839; num_leaves=29; min_data_in_leaf=750; lambda_l2=0.709 : y = 0.932 : 62.6 secs : infill_ei
#
# Sat Jul 26 08:04:44 2025 AUC 0.930774740497486
#
# [mbo] 186: learning_rate=0.014; feature_fraction=0.345; bagging_fraction=0.832; num_leaves=28; min_data_in_leaf=747; lambda_l2=0.708 : y = 0.931 : 60.9 secs : infill_ei
#
# Sat Jul 26 08:05:47 2025 AUC 0.930671466735447
#
# [mbo] 187: learning_rate=0.0143; feature_fraction=0.349; bagging_fraction=0.837; num_leaves=26; min_data_in_leaf=748; lambda_l2=0.75 : y = 0.931 : 61.3 secs : infill_ei
#
# Sat Jul 26 08:06:50 2025 AUC 0.930759691382027
#
# [mbo] 188: learning_rate=0.0145; feature_fraction=0.355; bagging_fraction=0.817; num_leaves=28; min_data_in_leaf=747; lambda_l2=0.724 : y = 0.931 : 62.2 secs : infill_ei
#
# Sat Jul 26 08:07:53 2025 AUC 0.930629414212479
#
# [mbo] 189: learning_rate=0.0146; feature_fraction=0.349; bagging_fraction=0.816; num_leaves=26; min_data_in_leaf=748; lambda_l2=0.701 : y = 0.931 : 61.0 secs : infill_ei
#
# Sat Jul 26 08:08:56 2025 AUC 0.930708384959522
#
# ...
#
# Saved the current state after iteration 231 in the file bayesiana.RDATA.
#
# Sat Jul 26 08:52:54 2025 AUC 0.929770348405898
#
# [mbo] 231: learning_rate=0.014; feature_fraction=0.343; bagging_fraction=0.821; num_leaves=28; min_data_in_leaf=746; lambda_l2=0.766 : y = 0.93 : 61.8 secs : infill_ei
#
# Sat Jul 26 08:53:57 2025 AUC 0.930943172737569
#
# [mbo] 232: learning_rate=0.0137; feature_fraction=0.343; bagging_fraction=0.841; num_leaves=26; min_data_in_leaf=740; lambda_l2=0.721 : y = 0.931 : 61.1 secs : infill_ei
#
# Sat Jul 26 08:55:02 2025 AUC 0.931411500239807
#
# [mbo] 233: learning_rate=0.0139; feature_fraction=0.343; bagging_fraction=0.82; num_leaves=30; min_data_in_leaf=744; lambda_l2=0.759 : y = 0.931 : 63.2 secs : infill_ei
#
# Sat Jul 26 08:56:07 2025 AUC 0.930329418824765
#
# [mbo] 234: learning_rate=0.0143; feature_fraction=0.341; bagging_fraction=0.83; num_leaves=30; min_data_in_leaf=744; lambda_l2=0.712 : y = 0.93 : 62.6 secs : infill_ei
#
# Sat Jul 26 08:57:11 2025 AUC 0.930792957437043
#
# [mbo] 235: learning_rate=0.0141; feature_fraction=0.349; bagging_fraction=0.819; num_leaves=28; min_data_in_leaf=742; lambda_l2=0.726 : y = 0.931 : 62.4 secs : infill_ei
#
# Sat Jul 26 08:58:14 2025 AUC 0.930321114634972
#
# [mbo] 236: learning_rate=0.0139; feature_fraction=0.363; bagging_fraction=0.817; num_leaves=28; min_data_in_leaf=751; lambda_l2=0.708 : y = 0.93 : 61.8 secs : infill_ei
#
# Sat Jul 26 08:59:20 2025 AUC 0.931157577059993
#
# [mbo] 237: learning_rate=0.014; feature_fraction=0.361; bagging_fraction=0.821; num_leaves=29; min_data_in_leaf=742; lambda_l2=0.705 : y = 0.931 : 63.6 secs : infill_ei
#
# Sat Jul 26 09:00:24 2025 AUC 0.93138213352594
#
# [mbo] 238: learning_rate=0.0144; feature_fraction=0.352; bagging_fraction=0.812; num_leaves=28; min_data_in_leaf=747; lambda_l2=0.709 : y = 0.931 : 62.2 secs : infill_ei
#
# Sat Jul 26 09:01:27 2025 AUC 0.931416989721858
#
# [mbo] 239: learning_rate=0.0136; feature_fraction=0.341; bagging_fraction=0.841; num_leaves=26; min_data_in_leaf=755; lambda_l2=0.732 : y = 0.931 : 61.7 secs : infill_ei
#
# Sat Jul 26 09:02:31 2025 AUC 0.931262284407915
#
# [mbo] 240: learning_rate=0.0146; feature_fraction=0.356; bagging_fraction=0.813; num_leaves=26; min_data_in_leaf=755; lambda_l2=0.778 : y = 0.931 : 62.4 secs : infill_ei
#
# Saved the current state after iteration 241 in the file bayesiana.RDATA.
#
# Sat Jul 26 09:03:38 2025 AUC 0.931172871794532
#
# [mbo] 241: learning_rate=0.014; feature_fraction=0.341; bagging_fraction=0.811; num_leaves=27; min_data_in_leaf=754; lambda_l2=0.714 : y = 0.931 : 61.4 secs : infill_ei
#
# Sat Jul 26 09:04:42 2025 AUC 0.931090331076261
#
# [mbo] 242: learning_rate=0.014; feature_fraction=0.354; bagging_fraction=0.822; num_leaves=27; min_data_in_leaf=743; lambda_l2=0.701 : y = 0.931 : 61.8 secs : infill_ei
#
# Sat Jul 26 09:05:45 2025 AUC 0.930043698990223
#
# [mbo] 243: learning_rate=0.0143; feature_fraction=0.346; bagging_fraction=0.818; num_leaves=28; min_data_in_leaf=743; lambda_l2=0.759 : y = 0.93 : 61.1 secs : infill_ei
#
# Sat Jul 26 09:06:50 2025 AUC 0.930070319532636
#
# [mbo] 244: learning_rate=0.0136; feature_fraction=0.345; bagging_fraction=0.82; num_leaves=29; min_data_in_leaf=753; lambda_l2=0.739 : y = 0.93 : 62.8 secs : infill_ei
#
# Sat Jul 26 09:07:54 2025 AUC 0.930764338378053
#
# [mbo] 245: learning_rate=0.0141; feature_fraction=0.351; bagging_fraction=0.826; num_leaves=27; min_data_in_leaf=741; lambda_l2=0.724 : y = 0.931 : 62.2 secs : infill_ei
#
# Sat Jul 26 09:08:58 2025 AUC 0.930865031585633
#
# [mbo] 246: learning_rate=0.0143; feature_fraction=0.358; bagging_fraction=0.837; num_leaves=26; min_data_in_leaf=746; lambda_l2=0.709 : y = 0.931 : 62.2 secs : infill_ei
#
# Sat Jul 26 09:10:01 2025 AUC 0.931635460988878
#
# [mbo] 247: learning_rate=0.0145; feature_fraction=0.345; bagging_fraction=0.829; num_leaves=26; min_data_in_leaf=751; lambda_l2=0.722 : y = 0.932 : 61.2 secs : infill_ei
#
# Sat Jul 26 09:11:06 2025 AUC 0.930432344481078
#
# [mbo] 248: learning_rate=0.0143; feature_fraction=0.342; bagging_fraction=0.829; num_leaves=30; min_data_in_leaf=751; lambda_l2=0.77 : y = 0.93 : 62.9 secs : infill_ei
#
# Sat Jul 26 09:12:11 2025 AUC 0.929962018828459
#
# [mbo] 249: learning_rate=0.0145; feature_fraction=0.356; bagging_fraction=0.837; num_leaves=29; min_data_in_leaf=751; lambda_l2=0.774 : y = 0.93 : 63.4 secs : infill_ei
#
# Sat Jul 26 09:13:21 2025 AUC 0.930676886931074
#
# [mbo] 250: learning_rate=0.0141; feature_fraction=0.364; bagging_fraction=0.823; num_leaves=26; min_data_in_leaf=741; lambda_l2=0.732 : y = 0.931 : 68.0 secs : infill_ei
#
# Saved the current state after iteration 251 in the file bayesiana.RDATA.
#
# Sat Jul 26 09:14:35 2025 AUC 0.930607091610336
#
# [mbo] 251: learning_rate=0.0141; feature_fraction=0.351; bagging_fraction=0.841; num_leaves=29; min_data_in_leaf=744; lambda_l2=0.71 : y = 0.931 : 68.4 secs : infill_ei
#
# Sat Jul 26 09:15:40 2025 AUC 0.930738514148589
#
# [mbo] 252: learning_rate=0.014; feature_fraction=0.354; bagging_fraction=0.814; num_leaves=30; min_data_in_leaf=748; lambda_l2=0.726 : y = 0.931 : 63.2 secs : infill_ei
#
# Sat Jul 26 09:16:44 2025 AUC 0.930594751209832
#
# [mbo] 253: learning_rate=0.0144; feature_fraction=0.34; bagging_fraction=0.814; num_leaves=28; min_data_in_leaf=751; lambda_l2=0.741 : y = 0.931 : 61.7 secs : infill_ei
#
# Sat Jul 26 09:17:49 2025 AUC 0.931786394529117
#
# [mbo] 254: learning_rate=0.0143; feature_fraction=0.353; bagging_fraction=0.822; num_leaves=30; min_data_in_leaf=743; lambda_l2=0.73 : y = 0.932 : 63.5 secs : infill_ei
#
# Sat Jul 26 09:18:54 2025 AUC 0.930028044617782
#
# [mbo] 255: learning_rate=0.0142; feature_fraction=0.353; bagging_fraction=0.832; num_leaves=30; min_data_in_leaf=741; lambda_l2=0.766 : y = 0.93 : 63.2 secs : infill_ei
#
# Sat Jul 26 09:19:58 2025 AUC 0.931267477719717
#
# [mbo] 256: learning_rate=0.014; feature_fraction=0.342; bagging_fraction=0.829; num_leaves=27; min_data_in_leaf=754; lambda_l2=0.732 : y = 0.931 : 61.7 secs : infill_ei
#
# Sat Jul 26 09:21:02 2025 AUC 0.930076888043948
#
# [mbo] 257: learning_rate=0.0141; feature_fraction=0.351; bagging_fraction=0.838; num_leaves=27; min_data_in_leaf=752; lambda_l2=0.763 : y = 0.93 : 62.1 secs : infill_ei
#
# Sat Jul 26 09:22:05 2025 AUC 0.93147450659044
#
# [mbo] 258: learning_rate=0.0148; feature_fraction=0.341; bagging_fraction=0.815; num_leaves=27; min_data_in_leaf=745; lambda_l2=0.716 : y = 0.931 : 60.8 secs : infill_ei
#
# Sat Jul 26 09:23:10 2025 AUC 0.930491967324128
#
# [mbo] 259: learning_rate=0.0142; feature_fraction=0.354; bagging_fraction=0.838; num_leaves=30; min_data_in_leaf=752; lambda_l2=0.71 : y = 0.93 : 63.5 secs : infill_ei
#
# Sat Jul 26 09:24:15 2025 AUC 0.931203534473574
#
# [mbo] 260: learning_rate=0.014; feature_fraction=0.354; bagging_fraction=0.836; num_leaves=28; min_data_in_leaf=741; lambda_l2=0.76 : y = 0.931 : 62.8 secs : infill_ei
#
# Saved the current state after iteration 261 in the file bayesiana.RDATA.
#
# Sat Jul 26 09:25:26 2025 AUC 0.931363635133822
#
# [mbo] 261: learning_rate=0.0145; feature_fraction=0.353; bagging_fraction=0.814; num_leaves=30; min_data_in_leaf=755; lambda_l2=0.777 : y = 0.931 : 63.1 secs : infill_ei
#
# Sat Jul 26 09:26:30 2025 AUC 0.930968465176528
#
# [mbo] 262: learning_rate=0.0137; feature_fraction=0.364; bagging_fraction=0.82; num_leaves=27; min_data_in_leaf=753; lambda_l2=0.738 : y = 0.931 : 62.0 secs : infill_ei
#
# Sat Jul 26 09:27:34 2025 AUC 0.931453480463493
#
# [mbo] 263: learning_rate=0.0138; feature_fraction=0.342; bagging_fraction=0.817; num_leaves=26; min_data_in_leaf=752; lambda_l2=0.741 : y = 0.931 : 61.2 secs : infill_ei
#
# Sat Jul 26 09:28:37 2025 AUC 0.930909413622462
#
# [mbo] 264: learning_rate=0.0142; feature_fraction=0.355; bagging_fraction=0.827; num_leaves=29; min_data_in_leaf=751; lambda_l2=0.732 : y = 0.931 : 61.5 secs : infill_ei
#
# Sat Jul 26 09:29:42 2025 AUC 0.931322547998672
#
# [mbo] 265: learning_rate=0.0136; feature_fraction=0.35; bagging_fraction=0.83; num_leaves=30; min_data_in_leaf=741; lambda_l2=0.701 : y = 0.931 : 63.2 secs : infill_ei
#
# Sat Jul 26 09:30:46 2025 AUC 0.930367425673503
#
# [mbo] 266: learning_rate=0.0142; feature_fraction=0.357; bagging_fraction=0.844; num_leaves=27; min_data_in_leaf=744; lambda_l2=0.755 : y = 0.93 : 62.0 secs : infill_ei
#
# Sat Jul 26 09:31:52 2025 AUC 0.93045939894529
#
# [mbo] 267: learning_rate=0.0141; feature_fraction=0.362; bagging_fraction=0.821; num_leaves=30; min_data_in_leaf=743; lambda_l2=0.715 : y = 0.93 : 63.5 secs : infill_ei
#
# Sat Jul 26 09:32:56 2025 AUC 0.931202957495939
#
# [mbo] 268: learning_rate=0.0147; feature_fraction=0.346; bagging_fraction=0.811; num_leaves=28; min_data_in_leaf=747; lambda_l2=0.719 : y = 0.931 : 62.0 secs : infill_ei
#
# Sat Jul 26 09:33:58 2025 AUC 0.931024307544229
#
# [mbo] 269: learning_rate=0.0145; feature_fraction=0.344; bagging_fraction=0.842; num_leaves=26; min_data_in_leaf=752; lambda_l2=0.701 : y = 0.931 : 60.6 secs : infill_ei
#
# Sat Jul 26 09:35:02 2025 AUC 0.932070453123911
#
# [mbo] 270: learning_rate=0.014; feature_fraction=0.343; bagging_fraction=0.829; num_leaves=27; min_data_in_leaf=740; lambda_l2=0.75 : y = 0.932 : 61.2 secs : infill_ei
#
# Saved the current state after iteration 271 in the file bayesiana.RDATA.
#
# Sat Jul 26 09:36:09 2025 AUC 0.930920645417131
#
# [mbo] 271: learning_rate=0.0142; feature_fraction=0.353; bagging_fraction=0.834; num_leaves=27; min_data_in_leaf=748; lambda_l2=0.763 : y = 0.931 : 61.4 secs : infill_ei
#
# Sat Jul 26 09:37:14 2025 AUC 0.930688862723006
#
# [mbo] 272: learning_rate=0.0143; feature_fraction=0.355; bagging_fraction=0.825; num_leaves=28; min_data_in_leaf=750; lambda_l2=0.731 : y = 0.931 : 62.5 secs : infill_ei
#
# Sat Jul 26 09:38:18 2025 AUC 0.930385486014342
#
# [mbo] 273: learning_rate=0.014; feature_fraction=0.34; bagging_fraction=0.815; num_leaves=30; min_data_in_leaf=742; lambda_l2=0.735 : y = 0.93 : 62.3 secs : infill_ei
#
# Sat Jul 26 09:39:21 2025 AUC 0.931219925206379
#
# [mbo] 274: learning_rate=0.0135; feature_fraction=0.363; bagging_fraction=0.816; num_leaves=26; min_data_in_leaf=750; lambda_l2=0.716 : y = 0.931 : 60.8 secs : infill_ei
#
# Sat Jul 26 09:40:25 2025 AUC 0.931145241106746
#
# [mbo] 275: learning_rate=0.0147; feature_fraction=0.359; bagging_fraction=0.835; num_leaves=27; min_data_in_leaf=747; lambda_l2=0.758 : y = 0.931 : 62.0 secs : infill_ei
#
# Sat Jul 26 09:41:30 2025 AUC 0.93026999252778
#
# [mbo] 276: learning_rate=0.0148; feature_fraction=0.349; bagging_fraction=0.83; num_leaves=29; min_data_in_leaf=740; lambda_l2=0.754 : y = 0.93 : 62.5 secs : infill_ei
#
# Sat Jul 26 09:42:34 2025 AUC 0.930859151755523
#
# [mbo] 277: learning_rate=0.014; feature_fraction=0.351; bagging_fraction=0.818; num_leaves=28; min_data_in_leaf=747; lambda_l2=0.726 : y = 0.931 : 62.2 secs : infill_ei
#
# Sat Jul 26 09:43:38 2025 AUC 0.931638539409076
#
# [mbo] 278: learning_rate=0.0142; feature_fraction=0.351; bagging_fraction=0.827; num_leaves=28; min_data_in_leaf=750; lambda_l2=0.744 : y = 0.932 : 62.4 secs : infill_ei
#
# Sat Jul 26 09:44:42 2025 AUC 0.930773337063762
#
# [mbo] 279: learning_rate=0.0138; feature_fraction=0.349; bagging_fraction=0.814; num_leaves=30; min_data_in_leaf=742; lambda_l2=0.73 : y = 0.931 : 62.0 secs : infill_ei
#
# Sat Jul 26 09:45:47 2025 AUC 0.930614944423611
#
# [mbo] 280: learning_rate=0.014; feature_fraction=0.359; bagging_fraction=0.816; num_leaves=28; min_data_in_leaf=746; lambda_l2=0.78 : y = 0.931 : 62.7 secs : infill_ei
#
# Saved the current state after iteration 281 in the file bayesiana.RDATA.
#
# Sat Jul 26 09:46:56 2025 AUC 0.931513910172085
#
# [mbo] 281: learning_rate=0.0137; feature_fraction=0.341; bagging_fraction=0.81; num_leaves=28; min_data_in_leaf=741; lambda_l2=0.717 : y = 0.932 : 60.8 secs : infill_ei
#
# Sat Jul 26 09:48:02 2025 AUC 0.930511355219635
#
# [mbo] 282: learning_rate=0.0137; feature_fraction=0.349; bagging_fraction=0.837; num_leaves=30; min_data_in_leaf=751; lambda_l2=0.76 : y = 0.931 : 64.3 secs : infill_ei
#
# Sat Jul 26 09:49:07 2025 AUC 0.931049733152111
#
# [mbo] 283: learning_rate=0.0145; feature_fraction=0.351; bagging_fraction=0.836; num_leaves=29; min_data_in_leaf=741; lambda_l2=0.734 : y = 0.931 : 62.7 secs : infill_ei
#
# Sat Jul 26 09:50:11 2025 AUC 0.930270923242543
#
# [mbo] 284: learning_rate=0.0144; feature_fraction=0.343; bagging_fraction=0.82; num_leaves=27; min_data_in_leaf=744; lambda_l2=0.743 : y = 0.93 : 61.9 secs : infill_ei
#
# Sat Jul 26 09:51:15 2025 AUC 0.931509373056783
#
# [mbo] 285: learning_rate=0.0139; feature_fraction=0.342; bagging_fraction=0.815; num_leaves=27; min_data_in_leaf=744; lambda_l2=0.752 : y = 0.932 : 61.7 secs : infill_ei
#
# Sat Jul 26 09:52:21 2025 AUC 0.930468982013573
#
# [mbo] 286: learning_rate=0.0146; feature_fraction=0.364; bagging_fraction=0.828; num_leaves=30; min_data_in_leaf=747; lambda_l2=0.762 : y = 0.93 : 63.5 secs : infill_ei
#
# Sat Jul 26 09:53:25 2025 AUC 0.931431601934067
#
# [mbo] 287: learning_rate=0.0136; feature_fraction=0.361; bagging_fraction=0.833; num_leaves=27; min_data_in_leaf=743; lambda_l2=0.721 : y = 0.931 : 62.4 secs : infill_ei
#
# Sat Jul 26 09:54:28 2025 AUC 0.931108297756281
#
# [mbo] 288: learning_rate=0.0142; feature_fraction=0.362; bagging_fraction=0.842; num_leaves=27; min_data_in_leaf=747; lambda_l2=0.729 : y = 0.931 : 61.0 secs : infill_ei
#
# Sat Jul 26 09:55:33 2025 AUC 0.931086740298781
#
# [mbo] 289: learning_rate=0.0137; feature_fraction=0.356; bagging_fraction=0.834; num_leaves=29; min_data_in_leaf=746; lambda_l2=0.779 : y = 0.931 : 63.1 secs : infill_ei
#
# Sat Jul 26 09:56:37 2025 AUC 0.930559864327834
#
# [mbo] 290: learning_rate=0.0144; feature_fraction=0.352; bagging_fraction=0.823; num_leaves=27; min_data_in_leaf=746; lambda_l2=0.75 : y = 0.931 : 61.6 secs : infill_ei
#
# Saved the current state after iteration 291 in the file bayesiana.RDATA.
#
# Sat Jul 26 09:57:46 2025 AUC 0.930751004989089
#
# [mbo] 291: learning_rate=0.0143; feature_fraction=0.344; bagging_fraction=0.811; num_leaves=27; min_data_in_leaf=751; lambda_l2=0.758 : y = 0.931 : 61.5 secs : infill_ei
#
# Sat Jul 26 09:58:50 2025 AUC 0.930786744146145
#
# [mbo] 292: learning_rate=0.0147; feature_fraction=0.356; bagging_fraction=0.844; num_leaves=26; min_data_in_leaf=751; lambda_l2=0.751 : y = 0.931 : 61.5 secs : infill_ei
#
# Sat Jul 26 09:59:55 2025 AUC 0.930334802419231
#
# [mbo] 293: learning_rate=0.0136; feature_fraction=0.354; bagging_fraction=0.824; num_leaves=28; min_data_in_leaf=749; lambda_l2=0.73 : y = 0.93 : 62.8 secs : infill_ei
#
# Sat Jul 26 10:00:59 2025 AUC 0.930398204657903
#
# [mbo] 294: learning_rate=0.0137; feature_fraction=0.341; bagging_fraction=0.828; num_leaves=27; min_data_in_leaf=755; lambda_l2=0.71 : y = 0.93 : 61.5 secs : infill_ei
#
# Sat Jul 26 10:02:02 2025 AUC 0.930341338292568
#
# [mbo] 295: learning_rate=0.0137; feature_fraction=0.358; bagging_fraction=0.816; num_leaves=27; min_data_in_leaf=740; lambda_l2=0.742 : y = 0.93 : 60.7 secs : infill_ei
#
# Sat Jul 26 10:03:08 2025 AUC 0.930700309118269
#
# [mbo] 296: learning_rate=0.0147; feature_fraction=0.347; bagging_fraction=0.82; num_leaves=29; min_data_in_leaf=749; lambda_l2=0.763 : y = 0.931 : 62.4 secs : infill_ei
#
# Sat Jul 26 10:04:13 2025 AUC 0.930360518415567
#
# [mbo] 297: learning_rate=0.0138; feature_fraction=0.349; bagging_fraction=0.824; num_leaves=30; min_data_in_leaf=744; lambda_l2=0.709 : y = 0.93 : 63.1 secs : infill_ei
#
# Sat Jul 26 10:05:17 2025 AUC 0.930850017862889
#
# [mbo] 298: learning_rate=0.0141; feature_fraction=0.352; bagging_fraction=0.825; num_leaves=27; min_data_in_leaf=755; lambda_l2=0.748 : y = 0.931 : 61.6 secs : infill_ei
#
# Sat Jul 26 10:06:22 2025 AUC 0.931292304717728
#
# [mbo] 299: learning_rate=0.0136; feature_fraction=0.36; bagging_fraction=0.826; num_leaves=28; min_data_in_leaf=755; lambda_l2=0.737 : y = 0.931 : 62.7 secs : infill_ei
#
# Sat Jul 26 10:07:26 2025 AUC 0.930759343848747
#
# [mbo] 300: learning_rate=0.0147; feature_fraction=0.364; bagging_fraction=0.828; num_leaves=28; min_data_in_leaf=752; lambda_l2=0.703 : y = 0.931 : 61.6 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "learning_rate"    "feature_fraction" "bagging_fraction" "num_leaves"
#  [5] "min_data_in_leaf" "lambda_l2"        "y"                "dob"
#  [9] "eol"              "error.message"    "exec.time"        "ei"
# [13] "error.model"      "train.time"       "prop.type"        "propose.time"
# [17] "se"               "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    learning_rate feature_fraction bagging_fraction num_leaves min_data_in_leaf
#            <num>            <num>            <num>      <int>            <int>
# 1:    0.01476728        0.3590987        0.8179206         29              748
#    lambda_l2
#        <num>
# 1: 0.7175909
# [1] 0.9322213

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 100887
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 0.7175909
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 0.8179206
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1200
#
# $learning_rate
# [1] 0.01476728
#
# $feature_fraction
# [1] 0.3590987
#
# $num_leaves
# [1] 29
#
# $min_data_in_leaf
# [1] 748

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sat Jul 26 10:08:43 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
