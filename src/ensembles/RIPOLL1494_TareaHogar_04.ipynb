# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# Esta Tarea para el Hogar 02 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el viernes 01-agosto

# %% [markdown]
# ##  1. Cazatalentos

# %% [markdown]
# En la Clase 03 nos hemos enfrentado a  "La Maldicion del Ganandor",  elegir el modelo con el mejor puntaje simple no suele ser la mejor estrategia.
# <br> Lea y ejecute el notebook  **src/CazaTalentos/CazaTalentos.ipynb**
# <br> en caso de interesarle, participe del Desafío Ordenamiento  que vence el sábado 02 de agosto a las 19:00

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dm"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dm" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/itba2025-8d0a/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Jul 21 04:27:57 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  656930 35.1 1439380    76.9 1431364  76.5
# Vcells 1224847  9.4 8388608    64.0 1924958  14.7

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 4940
PARAM$semilla_primigenia <- 100887

# %%
PARAM$kaggle$competencia <- "data-mining-analista-sr-2025-a"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_iterations", lower= 8L, upper= 2048L),
  makeNumericParam("learning_rate", lower= 0.01, upper= 0.2),
  makeNumericParam("feature_fraction", lower= 0.5, upper= 1.0),
  makeIntegerParam("num_leaves", lower= 20L, upper= 300L),
  makeIntegerParam("min_data_in_leaf", lower= 10L, upper= 1000L)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 70 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83368
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Mon Jul 21 05:34:37 2025 AUC 0.926739868744808
#
# Mon Jul 21 07:42:50 2025 AUC 0.924058313805567
#
# Mon Jul 21 07:56:48 2025 AUC 0.927052397996773
#
# Mon Jul 21 07:57:14 2025 AUC 0.927647154112918
#
# Mon Jul 21 07:57:23 2025 AUC 0.927772846616691
#
# Mon Jul 21 07:58:16 2025 AUC 0.928405199701608
#
# Mon Jul 21 07:58:17 2025 AUC 0.917521023343387
#
# Mon Jul 21 08:00:21 2025 AUC 0.926766212280211
#
# Mon Jul 21 08:00:47 2025 AUC 0.925544268395457
#
# Mon Jul 21 08:02:19 2025 AUC 0.9266771674596
#
# Mon Jul 21 08:03:03 2025 AUC 0.926891411101461
#
# Mon Jul 21 08:04:28 2025 AUC 0.923341137920677
#
# Mon Jul 21 08:05:50 2025 AUC 0.930647205171339
#
# Mon Jul 21 08:06:16 2025 AUC 0.925683119043925
#
# Mon Jul 21 08:07:31 2025 AUC 0.925011992566316
#
# Mon Jul 21 08:08:55 2025 AUC 0.928494183143304
#
# Mon Jul 21 08:10:58 2025 AUC 0.929037097162801
#
# Mon Jul 21 08:11:40 2025 AUC 0.927284360125281
#
# Mon Jul 21 08:13:11 2025 AUC 0.924735111778404
#
# Mon Jul 21 08:14:09 2025 AUC 0.924285339462914
#
# [mbo] 0: num_iterations=736; learning_rate=0.145; feature_fraction=0.837; num_leaves=126; min_data_in_leaf=861 : y = 0.927 : 3656.1 secs : initdesign
#
# [mbo] 0: num_iterations=1492; learning_rate=0.113; feature_fraction=0.787; num_leaves=192; min_data_in_leaf=159 : y = 0.924 : 7692.7 secs : initdesign
#
# [mbo] 0: num_iterations=1223; learning_rate=0.083; feature_fraction=0.687; num_leaves=211; min_data_in_leaf=233 : y = 0.927 : 838.3 secs : initdesign
#
# [mbo] 0: num_iterations=494; learning_rate=0.067; feature_fraction=0.928; num_leaves=227; min_data_in_leaf=927 : y = 0.928 : 25.9 secs : initdesign
#
# [mbo] 0: num_iterations=143; learning_rate=0.124; feature_fraction=0.671; num_leaves=72; min_data_in_leaf=526 : y = 0.928 : 8.9 secs : initdesign
#
# [mbo] 0: num_iterations=1112; learning_rate=0.0614; feature_fraction=0.804; num_leaves=54; min_data_in_leaf=358 : y = 0.928 : 52.7 secs : initdesign
#
# [mbo] 0: num_iterations=22; learning_rate=0.0239; feature_fraction=0.622; num_leaves=275; min_data_in_leaf=624 : y = 0.918 : 1.8 secs : initdesign
#
# [mbo] 0: num_iterations=1812; learning_rate=0.0926; feature_fraction=0.633; num_leaves=141; min_data_in_leaf=124 : y = 0.927 : 123.4 secs : initdesign
#
# [mbo] 0: num_iterations=351; learning_rate=0.157; feature_fraction=0.903; num_leaves=97; min_data_in_leaf=451 : y = 0.926 : 26.6 secs : initdesign
#
# [mbo] 0: num_iterations=1639; learning_rate=0.166; feature_fraction=0.598; num_leaves=79; min_data_in_leaf=742 : y = 0.927 : 91.1 secs : initdesign
#
# [mbo] 0: num_iterations=670; learning_rate=0.178; feature_fraction=0.737; num_leaves=176; min_data_in_leaf=760 : y = 0.927 : 44.0 secs : initdesign
#
# [mbo] 0: num_iterations=1425; learning_rate=0.199; feature_fraction=0.519; num_leaves=288; min_data_in_leaf=464 : y = 0.923 : 85.0 secs : initdesign
#
# [mbo] 0: num_iterations=1969; learning_rate=0.0531; feature_fraction=0.53; num_leaves=33; min_data_in_leaf=568 : y = 0.931 : 82.7 secs : initdesign
#
# [mbo] 0: num_iterations=265; learning_rate=0.0431; feature_fraction=0.769; num_leaves=151; min_data_in_leaf=88 : y = 0.926 : 25.6 secs : initdesign
#
# [mbo] 0: num_iterations=834; learning_rate=0.136; feature_fraction=0.996; num_leaves=233; min_data_in_leaf=355 : y = 0.925 : 75.6 secs : initdesign
#
# [mbo] 0: num_iterations=1257; learning_rate=0.0365; feature_fraction=0.712; num_leaves=258; min_data_in_leaf=686 : y = 0.928 : 84.0 secs : initdesign
#
# [mbo] 0: num_iterations=1706; learning_rate=0.0172; feature_fraction=0.875; num_leaves=114; min_data_in_leaf=29 : y = 0.929 : 122.3 secs : initdesign
#
# [mbo] 0: num_iterations=978; learning_rate=0.0992; feature_fraction=0.971; num_leaves=42; min_data_in_leaf=847 : y = 0.927 : 42.2 secs : initdesign
#
# [mbo] 0: num_iterations=1935; learning_rate=0.188; feature_fraction=0.857; num_leaves=268; min_data_in_leaf=981 : y = 0.925 : 90.5 secs : initdesign
#
# [mbo] 0: num_iterations=562; learning_rate=0.121; feature_fraction=0.56; num_leaves=163; min_data_in_leaf=280 : y = 0.924 : 58.5 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Mon Jul 21 08:16:15 2025 AUC 0.928919536322923
#
# [mbo] 1: num_iterations=1871; learning_rate=0.0472; feature_fraction=0.744; num_leaves=132; min_data_in_leaf=758 : y = 0.929 : 120.2 secs : infill_ei
#
# Mon Jul 21 08:17:24 2025 AUC 0.930282328907335
#
# [mbo] 2: num_iterations=2048; learning_rate=0.0139; feature_fraction=0.567; num_leaves=20; min_data_in_leaf=375 : y = 0.93 : 67.9 secs : infill_ei
#
# Mon Jul 21 08:18:45 2025 AUC 0.930517477860413
#
# [mbo] 3: num_iterations=1890; learning_rate=0.0255; feature_fraction=0.558; num_leaves=36; min_data_in_leaf=460 : y = 0.931 : 81.2 secs : infill_ei
#
# Mon Jul 21 08:19:54 2025 AUC 0.930050737960606
#
# [mbo] 4: num_iterations=1289; learning_rate=0.0101; feature_fraction=0.511; num_leaves=91; min_data_in_leaf=997 : y = 0.93 : 68.2 secs : infill_ei
#
# Mon Jul 21 08:20:49 2025 AUC 0.929519052836567
#
# [mbo] 5: num_iterations=1541; learning_rate=0.0489; feature_fraction=0.545; num_leaves=20; min_data_in_leaf=1000 : y = 0.93 : 54.4 secs : infill_ei
#
# Mon Jul 21 08:22:44 2025 AUC 0.929428417739779
#
# [mbo] 6: num_iterations=2045; learning_rate=0.0148; feature_fraction=0.5; num_leaves=79; min_data_in_leaf=910 : y = 0.929 : 115.4 secs : infill_ei
#
# Mon Jul 21 08:23:52 2025 AUC 0.929111597638471
#
# [mbo] 7: num_iterations=2037; learning_rate=0.0422; feature_fraction=0.502; num_leaves=20; min_data_in_leaf=12 : y = 0.929 : 67.7 secs : infill_ei
#
# Mon Jul 21 08:24:47 2025 AUC 0.930589326128614
#
# [mbo] 8: num_iterations=1086; learning_rate=0.0102; feature_fraction=0.924; num_leaves=177; min_data_in_leaf=1000 : y = 0.931 : 54.3 secs : infill_ei
#
# Saved the current state after iteration 9 in the file bayesiana.RDATA.
#
# Mon Jul 21 08:25:44 2025 AUC 0.929195711194579
#
# [mbo] 9: num_iterations=1965; learning_rate=0.0252; feature_fraction=0.921; num_leaves=20; min_data_in_leaf=683 : y = 0.929 : 51.3 secs : infill_ei
#
# Mon Jul 21 08:26:44 2025 AUC 0.930205063028175
#
# [mbo] 10: num_iterations=1668; learning_rate=0.01; feature_fraction=0.536; num_leaves=20; min_data_in_leaf=557 : y = 0.93 : 59.9 secs : infill_ei
#
# Mon Jul 21 08:27:49 2025 AUC 0.930161960320917
#
# [mbo] 11: num_iterations=1285; learning_rate=0.0105; feature_fraction=0.999; num_leaves=129; min_data_in_leaf=1000 : y = 0.93 : 63.9 secs : infill_ei
#
# Mon Jul 21 08:28:55 2025 AUC 0.929881330023036
#
# [mbo] 12: num_iterations=1176; learning_rate=0.0103; feature_fraction=0.725; num_leaves=144; min_data_in_leaf=826 : y = 0.93 : 65.8 secs : infill_ei
#
# Mon Jul 21 08:29:59 2025 AUC 0.928720717310455
#
# [mbo] 13: num_iterations=1215; learning_rate=0.0353; feature_fraction=0.998; num_leaves=214; min_data_in_leaf=1000 : y = 0.929 : 63.8 secs : infill_ei
#
# Mon Jul 21 08:30:49 2025 AUC 0.928086272080415
#
# [mbo] 14: num_iterations=1006; learning_rate=0.01; feature_fraction=0.905; num_leaves=91; min_data_in_leaf=998 : y = 0.928 : 49.1 secs : infill_ei
#
# Mon Jul 21 08:31:34 2025 AUC 0.929806067934955
#
# [mbo] 15: num_iterations=917; learning_rate=0.0101; feature_fraction=0.741; num_leaves=191; min_data_in_leaf=1000 : y = 0.93 : 44.9 secs : infill_ei
#
# Mon Jul 21 08:32:46 2025 AUC 0.930880202874227
#
# [mbo] 16: num_iterations=1338; learning_rate=0.0102; feature_fraction=0.524; num_leaves=171; min_data_in_leaf=999 : y = 0.931 : 71.9 secs : infill_ei
#
# Mon Jul 21 08:34:33 2025 AUC 0.930183271642992
#
# [mbo] 17: num_iterations=1493; learning_rate=0.0101; feature_fraction=0.527; num_leaves=112; min_data_in_leaf=572 : y = 0.93 : 106.6 secs : infill_ei
#
# Mon Jul 21 08:35:44 2025 AUC 0.929615916638105
#
# [mbo] 18: num_iterations=1428; learning_rate=0.01; feature_fraction=0.841; num_leaves=233; min_data_in_leaf=1000 : y = 0.93 : 70.3 secs : infill_ei
#
# Saved the current state after iteration 19 in the file bayesiana.RDATA.
#
# Mon Jul 21 08:36:55 2025 AUC 0.929124088257402
#
# [mbo] 19: num_iterations=1877; learning_rate=0.0762; feature_fraction=0.501; num_leaves=20; min_data_in_leaf=621 : y = 0.929 : 66.7 secs : infill_ei
#
# Mon Jul 21 08:38:33 2025 AUC 0.929621091526122
#
# [mbo] 20: num_iterations=1685; learning_rate=0.0483; feature_fraction=0.508; num_leaves=63; min_data_in_leaf=502 : y = 0.93 : 97.9 secs : infill_ei
#
# Mon Jul 21 08:41:34 2025 AUC 0.929588719196491
#
# [mbo] 21: num_iterations=1967; learning_rate=0.01; feature_fraction=0.505; num_leaves=172; min_data_in_leaf=385 : y = 0.93 : 180.1 secs : infill_ei
#
# Mon Jul 21 08:43:42 2025 AUC 0.927909235171606
#
# [mbo] 22: num_iterations=1291; learning_rate=0.01; feature_fraction=0.994; num_leaves=183; min_data_in_leaf=393 : y = 0.928 : 128.2 secs : infill_ei
#
# Mon Jul 21 08:44:58 2025 AUC 0.929195840843714
#
# [mbo] 23: num_iterations=1483; learning_rate=0.01; feature_fraction=0.639; num_leaves=138; min_data_in_leaf=1000 : y = 0.929 : 75.0 secs : infill_ei
#
# Mon Jul 21 08:46:05 2025 AUC 0.930045207036948
#
# [mbo] 24: num_iterations=1258; learning_rate=0.0102; feature_fraction=0.501; num_leaves=201; min_data_in_leaf=966 : y = 0.93 : 67.0 secs : infill_ei
#
# Saved the current state after iteration 25 in the file bayesiana.RDATA.
#
# Mon Jul 21 08:46:26 2025 AUC 0.928292138550181
#
# [mbo] 25: num_iterations=373; learning_rate=0.01; feature_fraction=0.5; num_leaves=33; min_data_in_leaf=703 : y = 0.928 : 16.1 secs : infill_ei
#
# Mon Jul 21 08:48:07 2025 AUC 0.929042332669525
#
# [mbo] 26: num_iterations=2024; learning_rate=0.0101; feature_fraction=0.942; num_leaves=147; min_data_in_leaf=1000 : y = 0.929 : 100.5 secs : infill_ei
#
# Mon Jul 21 08:49:12 2025 AUC 0.930372398647221
#
# [mbo] 27: num_iterations=2044; learning_rate=0.0195; feature_fraction=0.688; num_leaves=29; min_data_in_leaf=501 : y = 0.93 : 64.3 secs : infill_ei
#
# Mon Jul 21 08:51:16 2025 AUC 0.928689422772669
#
# [mbo] 28: num_iterations=2048; learning_rate=0.0318; feature_fraction=0.5; num_leaves=238; min_data_in_leaf=815 : y = 0.929 : 123.6 secs : infill_ei
#
# Mon Jul 21 08:52:48 2025 AUC 0.930355774967642
#
# [mbo] 29: num_iterations=2045; learning_rate=0.0102; feature_fraction=0.5; num_leaves=32; min_data_in_leaf=860 : y = 0.93 : 91.5 secs : infill_ei
#
# Mon Jul 21 08:53:48 2025 AUC 0.928633708481712
#
# [mbo] 30: num_iterations=1167; learning_rate=0.0103; feature_fraction=0.715; num_leaves=171; min_data_in_leaf=999 : y = 0.929 : 59.1 secs : infill_ei
#
# Mon Jul 21 08:55:03 2025 AUC 0.93028403090805
#
# [mbo] 31: num_iterations=1338; learning_rate=0.0105; feature_fraction=0.502; num_leaves=147; min_data_in_leaf=879 : y = 0.93 : 74.8 secs : infill_ei
#
# Mon Jul 21 08:56:01 2025 AUC 0.930011765011023
#
# [mbo] 32: num_iterations=2048; learning_rate=0.0297; feature_fraction=0.651; num_leaves=21; min_data_in_leaf=887 : y = 0.93 : 57.8 secs : infill_ei
#
# Mon Jul 21 08:56:44 2025 AUC 0.92915906775428
#
# [mbo] 33: num_iterations=941; learning_rate=0.0134; feature_fraction=0.68; num_leaves=46; min_data_in_leaf=579 : y = 0.929 : 42.2 secs : infill_ei
#
# Saved the current state after iteration 34 in the file bayesiana.RDATA.
#
# Mon Jul 21 08:57:45 2025 AUC 0.929851129836255
#
# [mbo] 34: num_iterations=969; learning_rate=0.01; feature_fraction=0.827; num_leaves=198; min_data_in_leaf=800 : y = 0.93 : 55.1 secs : infill_ei
#
# Mon Jul 21 08:59:18 2025 AUC 0.929426981110903
#
# [mbo] 35: num_iterations=1704; learning_rate=0.0101; feature_fraction=0.529; num_leaves=181; min_data_in_leaf=997 : y = 0.929 : 92.4 secs : infill_ei
#
# Mon Jul 21 09:00:35 2025 AUC 0.930705984230717
#
# [mbo] 36: num_iterations=1643; learning_rate=0.0101; feature_fraction=0.748; num_leaves=49; min_data_in_leaf=614 : y = 0.931 : 76.7 secs : infill_ei
#
# Mon Jul 21 09:02:14 2025 AUC 0.929834145579627
#
# [mbo] 37: num_iterations=2032; learning_rate=0.0101; feature_fraction=0.77; num_leaves=51; min_data_in_leaf=652 : y = 0.93 : 98.2 secs : infill_ei
#
# Mon Jul 21 09:03:35 2025 AUC 0.929469198524768
#
# [mbo] 38: num_iterations=1440; learning_rate=0.0104; feature_fraction=0.921; num_leaves=144; min_data_in_leaf=843 : y = 0.929 : 81.0 secs : infill_ei
#
# Mon Jul 21 09:05:15 2025 AUC 0.930159702719881
#
# [mbo] 39: num_iterations=1404; learning_rate=0.0102; feature_fraction=0.738; num_leaves=91; min_data_in_leaf=452 : y = 0.93 : 99.4 secs : infill_ei
#
# Mon Jul 21 09:06:23 2025 AUC 0.930689045358947
#
# [mbo] 40: num_iterations=1328; learning_rate=0.0107; feature_fraction=0.613; num_leaves=51; min_data_in_leaf=652 : y = 0.931 : 67.4 secs : infill_ei
#
# Mon Jul 21 09:07:00 2025 AUC 0.929503550700686
#
# [mbo] 41: num_iterations=1366; learning_rate=0.0418; feature_fraction=0.736; num_leaves=20; min_data_in_leaf=692 : y = 0.93 : 37.2 secs : infill_ei
#
# Saved the current state after iteration 42 in the file bayesiana.RDATA.
#
# Mon Jul 21 09:08:45 2025 AUC 0.930154235592475
#
# [mbo] 42: num_iterations=2047; learning_rate=0.0103; feature_fraction=0.609; num_leaves=47; min_data_in_leaf=627 : y = 0.93 : 100.6 secs : infill_ei
#
# Mon Jul 21 09:09:50 2025 AUC 0.928451870602399
#
# [mbo] 43: num_iterations=1073; learning_rate=0.0105; feature_fraction=0.982; num_leaves=146; min_data_in_leaf=774 : y = 0.928 : 64.4 secs : infill_ei
#
# Mon Jul 21 09:10:49 2025 AUC 0.929187220113871
#
# [mbo] 44: num_iterations=1149; learning_rate=0.01; feature_fraction=0.884; num_leaves=192; min_data_in_leaf=979 : y = 0.929 : 58.7 secs : infill_ei
#
# Mon Jul 21 09:11:41 2025 AUC 0.929769403697871
#
# [mbo] 45: num_iterations=1043; learning_rate=0.01; feature_fraction=0.789; num_leaves=260; min_data_in_leaf=994 : y = 0.93 : 51.6 secs : infill_ei
#
# Mon Jul 21 09:12:57 2025 AUC 0.930255201534136
#
# [mbo] 46: num_iterations=1284; learning_rate=0.0138; feature_fraction=0.573; num_leaves=52; min_data_in_leaf=804 : y = 0.93 : 74.5 secs : infill_ei
#
# Mon Jul 21 09:13:52 2025 AUC 0.930615351667803
#
# [mbo] 47: num_iterations=1702; learning_rate=0.01; feature_fraction=0.652; num_leaves=23; min_data_in_leaf=536 : y = 0.931 : 54.5 secs : infill_ei
#
# Mon Jul 21 09:15:23 2025 AUC 0.929917058494136
#
# [mbo] 48: num_iterations=1557; learning_rate=0.0192; feature_fraction=0.661; num_leaves=59; min_data_in_leaf=660 : y = 0.93 : 90.6 secs : infill_ei
#
# Mon Jul 21 09:17:04 2025 AUC 0.930273938628911
#
# [mbo] 49: num_iterations=1265; learning_rate=0.0102; feature_fraction=0.63; num_leaves=109; min_data_in_leaf=545 : y = 0.93 : 101.1 secs : infill_ei
#
# Saved the current state after iteration 50 in the file bayesiana.RDATA.
#
# Mon Jul 21 09:17:59 2025 AUC 0.930330648324054
#
# [mbo] 50: num_iterations=1763; learning_rate=0.0101; feature_fraction=0.751; num_leaves=20; min_data_in_leaf=406 : y = 0.93 : 50.8 secs : infill_ei
#
# Mon Jul 21 09:18:56 2025 AUC 0.929396100449479
#
# [mbo] 51: num_iterations=1715; learning_rate=0.0102; feature_fraction=1; num_leaves=23; min_data_in_leaf=994 : y = 0.929 : 56.1 secs : infill_ei
#
# Mon Jul 21 09:20:21 2025 AUC 0.930928708919894
#
# [mbo] 52: num_iterations=1250; learning_rate=0.0137; feature_fraction=0.529; num_leaves=162; min_data_in_leaf=731 : y = 0.931 : 84.1 secs : infill_ei
#
# Mon Jul 21 09:21:24 2025 AUC 0.929362968975822
#
# [mbo] 53: num_iterations=1185; learning_rate=0.0101; feature_fraction=0.935; num_leaves=297; min_data_in_leaf=1000 : y = 0.929 : 62.7 secs : infill_ei
#
# Mon Jul 21 09:22:15 2025 AUC 0.930622541068217
#
# [mbo] 54: num_iterations=1419; learning_rate=0.0149; feature_fraction=0.633; num_leaves=27; min_data_in_leaf=512 : y = 0.931 : 50.1 secs : infill_ei
#
# Mon Jul 21 09:23:33 2025 AUC 0.929142709311516
#
# [mbo] 55: num_iterations=1288; learning_rate=0.0101; feature_fraction=0.782; num_leaves=122; min_data_in_leaf=830 : y = 0.929 : 77.5 secs : infill_ei
#
# Mon Jul 21 09:24:44 2025 AUC 0.929805117781038
#
# [mbo] 56: num_iterations=1200; learning_rate=0.0101; feature_fraction=0.538; num_leaves=157; min_data_in_leaf=950 : y = 0.93 : 71.2 secs : infill_ei
#
# Mon Jul 21 09:26:22 2025 AUC 0.930094851290871
#
# [mbo] 57: num_iterations=1348; learning_rate=0.01; feature_fraction=0.547; num_leaves=175; min_data_in_leaf=667 : y = 0.93 : 97.2 secs : infill_ei
#
# Mon Jul 21 09:27:45 2025 AUC 0.930408537188136
#
# [mbo] 58: num_iterations=1183; learning_rate=0.0102; feature_fraction=0.528; num_leaves=249; min_data_in_leaf=687 : y = 0.93 : 81.9 secs : infill_ei
#
# Saved the current state after iteration 59 in the file bayesiana.RDATA.
#
# Mon Jul 21 09:28:59 2025 AUC 0.930661274804348
#
# [mbo] 59: num_iterations=1067; learning_rate=0.0101; feature_fraction=0.516; num_leaves=161; min_data_in_leaf=759 : y = 0.931 : 69.9 secs : infill_ei
#
# Mon Jul 21 09:30:48 2025 AUC 0.929520911578802
#
# [mbo] 60: num_iterations=1316; learning_rate=0.0179; feature_fraction=0.52; num_leaves=178; min_data_in_leaf=522 : y = 0.93 : 108.3 secs : infill_ei
#
# Mon Jul 21 09:32:08 2025 AUC 0.930930538919912
#
# [mbo] 61: num_iterations=2045; learning_rate=0.0113; feature_fraction=0.517; num_leaves=20; min_data_in_leaf=569 : y = 0.931 : 80.0 secs : infill_ei
#
# Mon Jul 21 09:33:06 2025 AUC 0.931405394839576
#
# [mbo] 62: num_iterations=1213; learning_rate=0.0104; feature_fraction=0.517; num_leaves=30; min_data_in_leaf=693 : y = 0.931 : 56.8 secs : infill_ei
#
# Mon Jul 21 09:34:08 2025 AUC 0.930337005475006
#
# [mbo] 63: num_iterations=1253; learning_rate=0.01; feature_fraction=0.504; num_leaves=39; min_data_in_leaf=236 : y = 0.93 : 61.1 secs : infill_ei
#
# Mon Jul 21 09:35:08 2025 AUC 0.929115643270744
#
# [mbo] 64: num_iterations=2046; learning_rate=0.0103; feature_fraction=0.841; num_leaves=20; min_data_in_leaf=385 : y = 0.929 : 59.4 secs : infill_ei
#
# Mon Jul 21 09:36:31 2025 AUC 0.930767071402573
#
# [mbo] 65: num_iterations=1192; learning_rate=0.0141; feature_fraction=0.508; num_leaves=79; min_data_in_leaf=648 : y = 0.931 : 83.0 secs : infill_ei
#
# Mon Jul 21 09:38:57 2025 AUC 0.928876257781846
#
# [mbo] 66: num_iterations=1683; learning_rate=0.01; feature_fraction=0.973; num_leaves=129; min_data_in_leaf=509 : y = 0.929 : 144.8 secs : infill_ei
#
# Saved the current state after iteration 67 in the file bayesiana.RDATA.
#
# Mon Jul 21 09:40:40 2025 AUC 0.929024399661342
#
# [mbo] 67: num_iterations=1345; learning_rate=0.0101; feature_fraction=0.512; num_leaves=93; min_data_in_leaf=11 : y = 0.929 : 98.7 secs : infill_ei
#
# Mon Jul 21 09:41:30 2025 AUC 0.928471884164342
#
# [mbo] 68: num_iterations=1878; learning_rate=0.012; feature_fraction=0.937; num_leaves=20; min_data_in_leaf=10 : y = 0.928 : 48.6 secs : infill_ei
#
# Mon Jul 21 09:42:35 2025 AUC 0.930213023317296
#
# [mbo] 69: num_iterations=1343; learning_rate=0.0283; feature_fraction=0.523; num_leaves=35; min_data_in_leaf=731 : y = 0.93 : 64.4 secs : infill_ei
#
# Mon Jul 21 09:43:11 2025 AUC 0.929530838159502
#
# [mbo] 70: num_iterations=1223; learning_rate=0.01; feature_fraction=0.683; num_leaves=20; min_data_in_leaf=377 : y = 0.93 : 35.6 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
