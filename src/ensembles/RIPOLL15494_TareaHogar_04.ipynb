# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# Esta Tarea para el Hogar 02 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el viernes 01-agosto

# %% [markdown]
# ##  1. Cazatalentos

# %% [markdown]
# En la Clase 03 nos hemos enfrentado a  "La Maldicion del Ganandor",  elegir el modelo con el mejor puntaje simple no suele ser la mejor estrategia.
# <br> Lea y ejecute el notebook  **src/CazaTalentos/CazaTalentos.ipynb**
# <br> en caso de interesarle, participe del Desafío Ordenamiento  que vence el sábado 02 de agosto a las 19:00

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dm"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dm" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/itba2025-8d0a/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Jul 24 21:01:03 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  656930 35.1 1439371    76.9 1431354  76.5
# Vcells 1224847  9.4 8388608    64.0 1924958  14.7

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 4954
PARAM$semilla_primigenia <- 100887

# %%
PARAM$kaggle$competencia <- "data-mining-analista-sr-2025-a"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= TRUE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
makeNumericParam("learning_rate", lower = 0.01, upper = 0.015),
makeNumericParam("feature_fraction", lower = 0.30, upper = 0.37),
makeNumericParam("bagging_fraction", lower = 0.75, upper = 0.85),
makeIntegerParam("num_leaves", lower = 20L, upper = 35L),
makeIntegerParam("min_data_in_leaf", lower = 700L, upper = 760L),
makeNumericParam("lambda_l2", lower = 0.0, upper = 5.0)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 80 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83368
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Thu Jul 24 21:03:27 2025 AUC 0.928850527925618
#
# Thu Jul 24 21:04:30 2025 AUC 0.928933989986034
#
# Thu Jul 24 21:05:31 2025 AUC 0.929187970889998
#
# Thu Jul 24 21:06:32 2025 AUC 0.928198441660033
#
# Thu Jul 24 21:07:33 2025 AUC 0.928774912632736
#
# Thu Jul 24 21:08:34 2025 AUC 0.928833289489638
#
# Thu Jul 24 21:09:36 2025 AUC 0.929340096084564
#
# Thu Jul 24 21:10:36 2025 AUC 0.929140790273836
#
# Thu Jul 24 21:11:35 2025 AUC 0.92894861360286
#
# Thu Jul 24 21:12:35 2025 AUC 0.927896014211129
#
# Thu Jul 24 21:13:34 2025 AUC 0.928811097208028
#
# Thu Jul 24 21:14:37 2025 AUC 0.928734366615467
#
# Thu Jul 24 21:15:36 2025 AUC 0.928983726887701
#
# Thu Jul 24 21:16:39 2025 AUC 0.9288112269949
#
# Thu Jul 24 21:17:36 2025 AUC 0.927811884131383
#
# Thu Jul 24 21:18:36 2025 AUC 0.929113489743063
#
# Thu Jul 24 21:19:42 2025 AUC 0.929686376978702
#
# Thu Jul 24 21:20:44 2025 AUC 0.929029448990005
#
# Thu Jul 24 21:21:46 2025 AUC 0.92878210816945
#
# Thu Jul 24 21:22:48 2025 AUC 0.929116756986399
#
# Thu Jul 24 21:23:49 2025 AUC 0.928622509871519
#
# Thu Jul 24 21:24:54 2025 AUC 0.927615321919252
#
# Thu Jul 24 21:25:54 2025 AUC 0.928360929696882
#
# Thu Jul 24 21:26:55 2025 AUC 0.928711338576248
#
# [mbo] 0: learning_rate=0.0133; feature_fraction=0.342; bagging_fraction=0.811; num_leaves=24; min_data_in_leaf=710; lambda_l2=1.42 : y = 0.929 : 61.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0122; feature_fraction=0.349; bagging_fraction=0.84; num_leaves=26; min_data_in_leaf=747; lambda_l2=2.87 : y = 0.929 : 63.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0116; feature_fraction=0.345; bagging_fraction=0.794; num_leaves=20; min_data_in_leaf=735; lambda_l2=0.881 : y = 0.929 : 61.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0105; feature_fraction=0.314; bagging_fraction=0.787; num_leaves=32; min_data_in_leaf=755; lambda_l2=3.18 : y = 0.928 : 60.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0139; feature_fraction=0.337; bagging_fraction=0.774; num_leaves=28; min_data_in_leaf=722; lambda_l2=4.13 : y = 0.929 : 60.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0136; feature_fraction=0.321; bagging_fraction=0.818; num_leaves=33; min_data_in_leaf=730; lambda_l2=2.17 : y = 0.929 : 61.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0123; feature_fraction=0.307; bagging_fraction=0.797; num_leaves=34; min_data_in_leaf=734; lambda_l2=0.738 : y = 0.929 : 62.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0129; feature_fraction=0.364; bagging_fraction=0.781; num_leaves=23; min_data_in_leaf=727; lambda_l2=3.89 : y = 0.929 : 60.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0142; feature_fraction=0.32; bagging_fraction=0.769; num_leaves=25; min_data_in_leaf=715; lambda_l2=0.441 : y = 0.929 : 58.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0132; feature_fraction=0.309; bagging_fraction=0.792; num_leaves=30; min_data_in_leaf=744; lambda_l2=3.37 : y = 0.928 : 60.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.01; feature_fraction=0.323; bagging_fraction=0.814; num_leaves=24; min_data_in_leaf=702; lambda_l2=1.68 : y = 0.929 : 58.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0108; feature_fraction=0.354; bagging_fraction=0.75; num_leaves=33; min_data_in_leaf=730; lambda_l2=3.11 : y = 0.929 : 62.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0117; feature_fraction=0.369; bagging_fraction=0.824; num_leaves=20; min_data_in_leaf=705; lambda_l2=3.64 : y = 0.929 : 59.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0126; feature_fraction=0.366; bagging_fraction=0.803; num_leaves=27; min_data_in_leaf=755; lambda_l2=2.04 : y = 0.929 : 62.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0112; feature_fraction=0.302; bagging_fraction=0.755; num_leaves=23; min_data_in_leaf=718; lambda_l2=4.33 : y = 0.928 : 57.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.011; feature_fraction=0.33; bagging_fraction=0.835; num_leaves=26; min_data_in_leaf=749; lambda_l2=0.00152 : y = 0.929 : 59.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0148; feature_fraction=0.361; bagging_fraction=0.762; num_leaves=35; min_data_in_leaf=739; lambda_l2=1.1 : y = 0.93 : 65.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.013; feature_fraction=0.304; bagging_fraction=0.805; num_leaves=30; min_data_in_leaf=701; lambda_l2=1.47 : y = 0.929 : 62.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0145; feature_fraction=0.357; bagging_fraction=0.846; num_leaves=31; min_data_in_leaf=752; lambda_l2=4.67 : y = 0.929 : 62.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0141; feature_fraction=0.352; bagging_fraction=0.847; num_leaves=29; min_data_in_leaf=709; lambda_l2=2.55 : y = 0.929 : 62.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0146; feature_fraction=0.328; bagging_fraction=0.777; num_leaves=21; min_data_in_leaf=741; lambda_l2=2.43 : y = 0.929 : 60.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0103; feature_fraction=0.317; bagging_fraction=0.831; num_leaves=34; min_data_in_leaf=722; lambda_l2=4.41 : y = 0.928 : 65.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0119; feature_fraction=0.333; bagging_fraction=0.828; num_leaves=22; min_data_in_leaf=759; lambda_l2=4.93 : y = 0.928 : 59.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0115; feature_fraction=0.34; bagging_fraction=0.764; num_leaves=28; min_data_in_leaf=715; lambda_l2=0.29 : y = 0.929 : 61.7 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Thu Jul 24 21:28:05 2025 AUC 0.929480431642445
#
# [mbo] 1: learning_rate=0.015; feature_fraction=0.359; bagging_fraction=0.814; num_leaves=35; min_data_in_leaf=746; lambda_l2=0.889 : y = 0.929 : 66.0 secs : infill_ei
#
# Thu Jul 24 21:29:10 2025 AUC 0.928932167220367
#
# [mbo] 2: learning_rate=0.0149; feature_fraction=0.351; bagging_fraction=0.755; num_leaves=35; min_data_in_leaf=738; lambda_l2=1.01 : y = 0.929 : 64.5 secs : infill_ei
#
# Thu Jul 24 21:30:16 2025 AUC 0.929694369994894
#
# [mbo] 3: learning_rate=0.0147; feature_fraction=0.363; bagging_fraction=0.761; num_leaves=31; min_data_in_leaf=717; lambda_l2=0.974 : y = 0.93 : 64.5 secs : infill_ei
#
# Thu Jul 24 21:31:15 2025 AUC 0.930178205109548
#
# [mbo] 4: learning_rate=0.0143; feature_fraction=0.361; bagging_fraction=0.768; num_leaves=21; min_data_in_leaf=732; lambda_l2=1.06 : y = 0.93 : 59.0 secs : infill_ei
#
# Thu Jul 24 21:32:15 2025 AUC 0.929174898523192
#
# [mbo] 5: learning_rate=0.0149; feature_fraction=0.362; bagging_fraction=0.755; num_leaves=20; min_data_in_leaf=738; lambda_l2=0.921 : y = 0.929 : 59.0 secs : infill_ei
#
# Thu Jul 24 21:33:17 2025 AUC 0.928775842512804
#
# [mbo] 6: learning_rate=0.0146; feature_fraction=0.365; bagging_fraction=0.772; num_leaves=25; min_data_in_leaf=722; lambda_l2=1.11 : y = 0.929 : 60.8 secs : infill_ei
#
# Thu Jul 24 21:34:17 2025 AUC 0.929401232350962
#
# [mbo] 7: learning_rate=0.012; feature_fraction=0.36; bagging_fraction=0.766; num_leaves=22; min_data_in_leaf=732; lambda_l2=2.84 : y = 0.929 : 59.5 secs : infill_ei
#
# Thu Jul 24 21:35:21 2025 AUC 0.929476512181348
#
# [mbo] 8: learning_rate=0.0143; feature_fraction=0.361; bagging_fraction=0.815; num_leaves=29; min_data_in_leaf=717; lambda_l2=0.564 : y = 0.929 : 62.8 secs : infill_ei
#
# Thu Jul 24 21:36:22 2025 AUC 0.929243574844961
#
# [mbo] 9: learning_rate=0.0128; feature_fraction=0.361; bagging_fraction=0.773; num_leaves=22; min_data_in_leaf=726; lambda_l2=1.12 : y = 0.929 : 60.4 secs : infill_ei
#
# Thu Jul 24 21:37:24 2025 AUC 0.928892528552865
#
# [mbo] 10: learning_rate=0.0143; feature_fraction=0.362; bagging_fraction=0.801; num_leaves=26; min_data_in_leaf=732; lambda_l2=0.813 : y = 0.929 : 61.4 secs : infill_ei
#
# Saved the current state after iteration 11 in the file bayesiana.RDATA.
#
# Thu Jul 24 21:38:29 2025 AUC 0.929605590327834
#
# [mbo] 11: learning_rate=0.0143; feature_fraction=0.36; bagging_fraction=0.766; num_leaves=20; min_data_in_leaf=746; lambda_l2=0.951 : y = 0.93 : 58.8 secs : infill_ei
#
# Thu Jul 24 21:39:34 2025 AUC 0.929317112527432
#
# [mbo] 12: learning_rate=0.0129; feature_fraction=0.361; bagging_fraction=0.768; num_leaves=30; min_data_in_leaf=732; lambda_l2=0.545 : y = 0.929 : 63.8 secs : infill_ei
#
# Thu Jul 24 21:40:33 2025 AUC 0.929516802022583
#
# [mbo] 13: learning_rate=0.0147; feature_fraction=0.315; bagging_fraction=0.766; num_leaves=20; min_data_in_leaf=732; lambda_l2=1.27 : y = 0.93 : 58.7 secs : infill_ei
#
# Thu Jul 24 21:41:34 2025 AUC 0.930371392195627
#
# [mbo] 14: learning_rate=0.0141; feature_fraction=0.361; bagging_fraction=0.773; num_leaves=21; min_data_in_leaf=710; lambda_l2=2.4 : y = 0.93 : 59.6 secs : infill_ei
#
# Thu Jul 24 21:42:33 2025 AUC 0.9290717555062
#
# [mbo] 15: learning_rate=0.0141; feature_fraction=0.36; bagging_fraction=0.795; num_leaves=21; min_data_in_leaf=717; lambda_l2=1.41 : y = 0.929 : 58.9 secs : infill_ei
#
# Thu Jul 24 21:43:33 2025 AUC 0.929629343652283
#
# [mbo] 16: learning_rate=0.0141; feature_fraction=0.361; bagging_fraction=0.77; num_leaves=22; min_data_in_leaf=707; lambda_l2=2.05 : y = 0.93 : 59.2 secs : infill_ei
#
# Thu Jul 24 21:44:34 2025 AUC 0.929738069013298
#
# [mbo] 17: learning_rate=0.015; feature_fraction=0.361; bagging_fraction=0.776; num_leaves=22; min_data_in_leaf=742; lambda_l2=0.779 : y = 0.93 : 59.5 secs : infill_ei
#
# Thu Jul 24 21:45:34 2025 AUC 0.929408092547754
#
# [mbo] 18: learning_rate=0.0146; feature_fraction=0.361; bagging_fraction=0.772; num_leaves=21; min_data_in_leaf=720; lambda_l2=2.96 : y = 0.929 : 59.6 secs : infill_ei
#
# Thu Jul 24 21:46:34 2025 AUC 0.930142581279963
#
# [mbo] 19: learning_rate=0.0145; feature_fraction=0.361; bagging_fraction=0.773; num_leaves=21; min_data_in_leaf=712; lambda_l2=1.39 : y = 0.93 : 58.8 secs : infill_ei
#
# Thu Jul 24 21:47:33 2025 AUC 0.929054489462971
#
# [mbo] 20: learning_rate=0.0137; feature_fraction=0.36; bagging_fraction=0.775; num_leaves=21; min_data_in_leaf=711; lambda_l2=2.74 : y = 0.929 : 58.8 secs : infill_ei
#
# Saved the current state after iteration 21 in the file bayesiana.RDATA.
#
# Thu Jul 24 21:48:36 2025 AUC 0.929017294194634
#
# [mbo] 21: learning_rate=0.0137; feature_fraction=0.337; bagging_fraction=0.773; num_leaves=20; min_data_in_leaf=719; lambda_l2=2.84 : y = 0.929 : 58.0 secs : infill_ei
#
# Thu Jul 24 21:49:36 2025 AUC 0.929109692682561
#
# [mbo] 22: learning_rate=0.0118; feature_fraction=0.357; bagging_fraction=0.833; num_leaves=21; min_data_in_leaf=756; lambda_l2=3.63 : y = 0.929 : 59.2 secs : infill_ei
#
# Thu Jul 24 21:50:35 2025 AUC 0.929705392948032
#
# [mbo] 23: learning_rate=0.0141; feature_fraction=0.361; bagging_fraction=0.773; num_leaves=21; min_data_in_leaf=701; lambda_l2=1.52 : y = 0.93 : 58.2 secs : infill_ei
#
# Thu Jul 24 21:51:35 2025 AUC 0.928885193549625
#
# [mbo] 24: learning_rate=0.0125; feature_fraction=0.331; bagging_fraction=0.839; num_leaves=24; min_data_in_leaf=726; lambda_l2=4.68 : y = 0.929 : 59.5 secs : infill_ei
#
# Thu Jul 24 21:52:38 2025 AUC 0.929086206580962
#
# [mbo] 25: learning_rate=0.0129; feature_fraction=0.302; bagging_fraction=0.777; num_leaves=35; min_data_in_leaf=757; lambda_l2=2.27 : y = 0.929 : 62.4 secs : infill_ei
#
# Thu Jul 24 21:53:43 2025 AUC 0.9301334336625
#
# [mbo] 26: learning_rate=0.0138; feature_fraction=0.368; bagging_fraction=0.756; num_leaves=29; min_data_in_leaf=710; lambda_l2=2.41 : y = 0.93 : 63.7 secs : infill_ei
#
# Thu Jul 24 21:54:47 2025 AUC 0.92817309349373
#
# [mbo] 27: learning_rate=0.0103; feature_fraction=0.337; bagging_fraction=0.802; num_leaves=33; min_data_in_leaf=704; lambda_l2=2.69 : y = 0.928 : 63.7 secs : infill_ei
#
# Thu Jul 24 21:55:50 2025 AUC 0.928845427025612
#
# [mbo] 28: learning_rate=0.0141; feature_fraction=0.36; bagging_fraction=0.773; num_leaves=27; min_data_in_leaf=711; lambda_l2=2.48 : y = 0.929 : 62.2 secs : infill_ei
#
# Thu Jul 24 21:56:49 2025 AUC 0.929114258689978
#
# [mbo] 29: learning_rate=0.0129; feature_fraction=0.325; bagging_fraction=0.821; num_leaves=21; min_data_in_leaf=713; lambda_l2=2.24 : y = 0.929 : 57.6 secs : infill_ei
#
# Thu Jul 24 21:57:47 2025 AUC 0.929938509982118
#
# [mbo] 30: learning_rate=0.0145; feature_fraction=0.361; bagging_fraction=0.772; num_leaves=20; min_data_in_leaf=719; lambda_l2=2.36 : y = 0.93 : 57.6 secs : infill_ei
#
# Saved the current state after iteration 31 in the file bayesiana.RDATA.
#
# Thu Jul 24 21:58:54 2025 AUC 0.928930282567156
#
# [mbo] 31: learning_rate=0.0122; feature_fraction=0.356; bagging_fraction=0.831; num_leaves=30; min_data_in_leaf=752; lambda_l2=3.54 : y = 0.929 : 62.3 secs : infill_ei
#
# Thu Jul 24 21:59:56 2025 AUC 0.929752203590677
#
# [mbo] 32: learning_rate=0.0127; feature_fraction=0.363; bagging_fraction=0.768; num_leaves=26; min_data_in_leaf=709; lambda_l2=2.4 : y = 0.93 : 61.3 secs : infill_ei
#
# Thu Jul 24 22:00:56 2025 AUC 0.929077698893987
#
# [mbo] 33: learning_rate=0.0133; feature_fraction=0.361; bagging_fraction=0.767; num_leaves=20; min_data_in_leaf=710; lambda_l2=3.38 : y = 0.929 : 58.7 secs : infill_ei
#
# Thu Jul 24 22:01:58 2025 AUC 0.929301700165966
#
# [mbo] 34: learning_rate=0.0144; feature_fraction=0.355; bagging_fraction=0.774; num_leaves=26; min_data_in_leaf=713; lambda_l2=2.39 : y = 0.929 : 61.0 secs : infill_ei
#
# Thu Jul 24 22:02:58 2025 AUC 0.929434124104765
#
# [mbo] 35: learning_rate=0.0126; feature_fraction=0.345; bagging_fraction=0.845; num_leaves=24; min_data_in_leaf=743; lambda_l2=0.871 : y = 0.929 : 59.2 secs : infill_ei
#
# Thu Jul 24 22:04:02 2025 AUC 0.928770610181208
#
# [mbo] 36: learning_rate=0.0117; feature_fraction=0.368; bagging_fraction=0.782; num_leaves=30; min_data_in_leaf=718; lambda_l2=0.877 : y = 0.929 : 63.4 secs : infill_ei
#
# Thu Jul 24 22:05:07 2025 AUC 0.928798015818155
#
# [mbo] 37: learning_rate=0.0141; feature_fraction=0.36; bagging_fraction=0.773; num_leaves=20; min_data_in_leaf=711; lambda_l2=2.46 : y = 0.929 : 64.3 secs : infill_ei
#
# Thu Jul 24 22:06:11 2025 AUC 0.928857659226777
#
# [mbo] 38: learning_rate=0.0148; feature_fraction=0.32; bagging_fraction=0.817; num_leaves=23; min_data_in_leaf=756; lambda_l2=1.22 : y = 0.929 : 62.5 secs : infill_ei
#
# Thu Jul 24 22:07:12 2025 AUC 0.928153323084557
#
# [mbo] 39: learning_rate=0.0106; feature_fraction=0.302; bagging_fraction=0.826; num_leaves=22; min_data_in_leaf=732; lambda_l2=2.29 : y = 0.928 : 60.5 secs : infill_ei
#
# Thu Jul 24 22:08:14 2025 AUC 0.929000495309771
#
# [mbo] 40: learning_rate=0.0142; feature_fraction=0.334; bagging_fraction=0.824; num_leaves=23; min_data_in_leaf=732; lambda_l2=4.95 : y = 0.929 : 60.8 secs : infill_ei
#
# Saved the current state after iteration 41 in the file bayesiana.RDATA.
#
# Thu Jul 24 22:09:20 2025 AUC 0.929353167566128
#
# [mbo] 41: learning_rate=0.0133; feature_fraction=0.353; bagging_fraction=0.824; num_leaves=30; min_data_in_leaf=703; lambda_l2=1.14 : y = 0.929 : 62.2 secs : infill_ei
#
# Thu Jul 24 22:10:19 2025 AUC 0.92854474003952
#
# [mbo] 42: learning_rate=0.0105; feature_fraction=0.313; bagging_fraction=0.75; num_leaves=22; min_data_in_leaf=732; lambda_l2=4.25 : y = 0.929 : 57.8 secs : infill_ei
#
# Thu Jul 24 22:11:21 2025 AUC 0.928154066602082
#
# [mbo] 43: learning_rate=0.0108; feature_fraction=0.308; bagging_fraction=0.783; num_leaves=32; min_data_in_leaf=726; lambda_l2=3.01 : y = 0.928 : 61.2 secs : infill_ei
#
# Thu Jul 24 22:12:23 2025 AUC 0.927885063010032
#
# [mbo] 44: learning_rate=0.0106; feature_fraction=0.355; bagging_fraction=0.817; num_leaves=27; min_data_in_leaf=729; lambda_l2=4.17 : y = 0.928 : 61.6 secs : infill_ei
#
# Thu Jul 24 22:13:24 2025 AUC 0.930300390866087
#
# [mbo] 45: learning_rate=0.0138; feature_fraction=0.363; bagging_fraction=0.759; num_leaves=22; min_data_in_leaf=708; lambda_l2=2.4 : y = 0.93 : 60.1 secs : infill_ei
#
# Thu Jul 24 22:14:23 2025 AUC 0.929604919904174
#
# [mbo] 46: learning_rate=0.0137; feature_fraction=0.346; bagging_fraction=0.822; num_leaves=21; min_data_in_leaf=733; lambda_l2=1.06 : y = 0.93 : 58.0 secs : infill_ei
#
# Thu Jul 24 22:15:24 2025 AUC 0.929825505803848
#
# [mbo] 47: learning_rate=0.0138; feature_fraction=0.366; bagging_fraction=0.797; num_leaves=21; min_data_in_leaf=714; lambda_l2=1.38 : y = 0.93 : 60.2 secs : infill_ei
#
# Thu Jul 24 22:16:28 2025 AUC 0.929057197884258
#
# [mbo] 48: learning_rate=0.0109; feature_fraction=0.314; bagging_fraction=0.812; num_leaves=27; min_data_in_leaf=755; lambda_l2=0.45 : y = 0.929 : 62.6 secs : infill_ei
#
# Thu Jul 24 22:17:33 2025 AUC 0.927967181106913
#
# [mbo] 49: learning_rate=0.0128; feature_fraction=0.331; bagging_fraction=0.779; num_leaves=33; min_data_in_leaf=716; lambda_l2=4.92 : y = 0.928 : 64.4 secs : infill_ei
#
# Thu Jul 24 22:18:35 2025 AUC 0.929336624992476
#
# [mbo] 50: learning_rate=0.0145; feature_fraction=0.364; bagging_fraction=0.806; num_leaves=21; min_data_in_leaf=741; lambda_l2=2.4 : y = 0.929 : 60.9 secs : infill_ei
#
# Saved the current state after iteration 51 in the file bayesiana.RDATA.
#
# Thu Jul 24 22:19:39 2025 AUC 0.929246815960323
#
# [mbo] 51: learning_rate=0.0121; feature_fraction=0.363; bagging_fraction=0.821; num_leaves=20; min_data_in_leaf=726; lambda_l2=1.66 : y = 0.929 : 59.2 secs : infill_ei
#
# Thu Jul 24 22:20:46 2025 AUC 0.927752904872603
#
# [mbo] 52: learning_rate=0.01; feature_fraction=0.305; bagging_fraction=0.816; num_leaves=32; min_data_in_leaf=739; lambda_l2=4.67 : y = 0.928 : 66.2 secs : infill_ei
#
# Thu Jul 24 22:21:48 2025 AUC 0.929236700510037
#
# [mbo] 53: learning_rate=0.014; feature_fraction=0.365; bagging_fraction=0.752; num_leaves=20; min_data_in_leaf=715; lambda_l2=2.4 : y = 0.929 : 60.9 secs : infill_ei
#
# Thu Jul 24 22:22:49 2025 AUC 0.929061686471221
#
# [mbo] 54: learning_rate=0.0143; feature_fraction=0.333; bagging_fraction=0.757; num_leaves=27; min_data_in_leaf=703; lambda_l2=1.11 : y = 0.929 : 60.8 secs : infill_ei
#
# Thu Jul 24 22:23:49 2025 AUC 0.929591190757758
#
# [mbo] 55: learning_rate=0.0123; feature_fraction=0.343; bagging_fraction=0.827; num_leaves=20; min_data_in_leaf=730; lambda_l2=2.77 : y = 0.93 : 58.6 secs : infill_ei
#
# Thu Jul 24 22:24:50 2025 AUC 0.92904876305103
#
# [mbo] 56: learning_rate=0.0127; feature_fraction=0.345; bagging_fraction=0.755; num_leaves=25; min_data_in_leaf=758; lambda_l2=1.92 : y = 0.929 : 60.6 secs : infill_ei
#
# Thu Jul 24 22:25:48 2025 AUC 0.930038060116159
#
# [mbo] 57: learning_rate=0.014; feature_fraction=0.31; bagging_fraction=0.773; num_leaves=20; min_data_in_leaf=716; lambda_l2=2.4 : y = 0.93 : 56.8 secs : infill_ei
#
# Thu Jul 24 22:26:53 2025 AUC 0.928780901720145
#
# [mbo] 58: learning_rate=0.0115; feature_fraction=0.344; bagging_fraction=0.846; num_leaves=29; min_data_in_leaf=707; lambda_l2=1.91 : y = 0.929 : 63.7 secs : infill_ei
#
# Thu Jul 24 22:27:53 2025 AUC 0.929155405797519
#
# [mbo] 59: learning_rate=0.0131; feature_fraction=0.332; bagging_fraction=0.78; num_leaves=21; min_data_in_leaf=710; lambda_l2=4.07 : y = 0.929 : 59.3 secs : infill_ei
#
# Thu Jul 24 22:28:58 2025 AUC 0.929030019358816
#
# [mbo] 60: learning_rate=0.0129; feature_fraction=0.354; bagging_fraction=0.78; num_leaves=31; min_data_in_leaf=728; lambda_l2=4.57 : y = 0.929 : 63.9 secs : infill_ei
#
# Saved the current state after iteration 61 in the file bayesiana.RDATA.
#
# Thu Jul 24 22:30:05 2025 AUC 0.929178541341073
#
# [mbo] 61: learning_rate=0.0104; feature_fraction=0.363; bagging_fraction=0.76; num_leaves=22; min_data_in_leaf=708; lambda_l2=0.916 : y = 0.929 : 61.6 secs : infill_ei
#
# Thu Jul 24 22:31:12 2025 AUC 0.928777469353928
#
# [mbo] 62: learning_rate=0.0112; feature_fraction=0.355; bagging_fraction=0.772; num_leaves=33; min_data_in_leaf=738; lambda_l2=0.832 : y = 0.929 : 66.0 secs : infill_ei
#
# Thu Jul 24 22:32:16 2025 AUC 0.928108062500538
#
# [mbo] 63: learning_rate=0.0106; feature_fraction=0.314; bagging_fraction=0.773; num_leaves=35; min_data_in_leaf=742; lambda_l2=0.616 : y = 0.928 : 63.0 secs : infill_ei
#
# Thu Jul 24 22:33:20 2025 AUC 0.928204385530222
#
# [mbo] 64: learning_rate=0.0133; feature_fraction=0.333; bagging_fraction=0.764; num_leaves=32; min_data_in_leaf=755; lambda_l2=1.52 : y = 0.928 : 62.9 secs : infill_ei
#
# Thu Jul 24 22:34:25 2025 AUC 0.928593175668879
#
# [mbo] 65: learning_rate=0.014; feature_fraction=0.367; bagging_fraction=0.806; num_leaves=27; min_data_in_leaf=757; lambda_l2=4.22 : y = 0.929 : 64.0 secs : infill_ei
#
# Thu Jul 24 22:35:26 2025 AUC 0.929440938962053
#
# [mbo] 66: learning_rate=0.0147; feature_fraction=0.357; bagging_fraction=0.771; num_leaves=22; min_data_in_leaf=705; lambda_l2=2.4 : y = 0.929 : 59.7 secs : infill_ei
#
# Thu Jul 24 22:36:27 2025 AUC 0.929307722409186
#
# [mbo] 67: learning_rate=0.0142; feature_fraction=0.353; bagging_fraction=0.765; num_leaves=21; min_data_in_leaf=709; lambda_l2=2.4 : y = 0.929 : 59.1 secs : infill_ei
#
# Thu Jul 24 22:37:29 2025 AUC 0.929579043318893
#
# [mbo] 68: learning_rate=0.0144; feature_fraction=0.364; bagging_fraction=0.813; num_leaves=23; min_data_in_leaf=709; lambda_l2=2.4 : y = 0.93 : 60.8 secs : infill_ei
#
# Thu Jul 24 22:38:35 2025 AUC 0.928826223742591
#
# [mbo] 69: learning_rate=0.0135; feature_fraction=0.32; bagging_fraction=0.828; num_leaves=35; min_data_in_leaf=734; lambda_l2=1.37 : y = 0.929 : 64.7 secs : infill_ei
#
# Thu Jul 24 22:39:38 2025 AUC 0.928642106793225
#
# [mbo] 70: learning_rate=0.0108; feature_fraction=0.327; bagging_fraction=0.832; num_leaves=32; min_data_in_leaf=737; lambda_l2=0.481 : y = 0.929 : 62.9 secs : infill_ei
#
# Saved the current state after iteration 71 in the file bayesiana.RDATA.
#
# Thu Jul 24 22:40:46 2025 AUC 0.928670169030088
#
# [mbo] 71: learning_rate=0.0131; feature_fraction=0.341; bagging_fraction=0.804; num_leaves=29; min_data_in_leaf=709; lambda_l2=4.87 : y = 0.929 : 63.2 secs : infill_ei
#
# Thu Jul 24 22:41:50 2025 AUC 0.928870841137749
#
# [mbo] 72: learning_rate=0.0134; feature_fraction=0.332; bagging_fraction=0.805; num_leaves=34; min_data_in_leaf=735; lambda_l2=3.79 : y = 0.929 : 63.0 secs : infill_ei
#
# Thu Jul 24 22:42:50 2025 AUC 0.929901378822672
#
# [mbo] 73: learning_rate=0.0123; feature_fraction=0.336; bagging_fraction=0.834; num_leaves=24; min_data_in_leaf=715; lambda_l2=2.6 : y = 0.93 : 59.1 secs : infill_ei
#
# Thu Jul 24 22:43:53 2025 AUC 0.930016698018242
#
# [mbo] 74: learning_rate=0.014; feature_fraction=0.364; bagging_fraction=0.789; num_leaves=27; min_data_in_leaf=709; lambda_l2=2.17 : y = 0.93 : 62.5 secs : infill_ei
#
# Thu Jul 24 22:44:53 2025 AUC 0.929408540464528
#
# [mbo] 75: learning_rate=0.0141; feature_fraction=0.337; bagging_fraction=0.774; num_leaves=21; min_data_in_leaf=721; lambda_l2=2.08 : y = 0.929 : 59.0 secs : infill_ei
#
# Thu Jul 24 22:45:58 2025 AUC 0.92839065943792
#
# [mbo] 76: learning_rate=0.0105; feature_fraction=0.337; bagging_fraction=0.818; num_leaves=29; min_data_in_leaf=715; lambda_l2=0.864 : y = 0.928 : 63.0 secs : infill_ei
#
# Thu Jul 24 22:46:59 2025 AUC 0.927950099626932
#
# [mbo] 77: learning_rate=0.0102; feature_fraction=0.31; bagging_fraction=0.764; num_leaves=27; min_data_in_leaf=738; lambda_l2=4.65 : y = 0.928 : 60.8 secs : infill_ei
#
# Thu Jul 24 22:48:03 2025 AUC 0.930122519524509
#
# [mbo] 78: learning_rate=0.0143; feature_fraction=0.361; bagging_fraction=0.798; num_leaves=24; min_data_in_leaf=736; lambda_l2=0.523 : y = 0.93 : 62.2 secs : infill_ei
#
# Thu Jul 24 22:49:06 2025 AUC 0.929840381993772
#
# [mbo] 79: learning_rate=0.0142; feature_fraction=0.355; bagging_fraction=0.773; num_leaves=21; min_data_in_leaf=741; lambda_l2=1.22 : y = 0.93 : 62.1 secs : infill_ei
#
# Thu Jul 24 22:50:07 2025 AUC 0.929749664424634
#
# [mbo] 80: learning_rate=0.0143; feature_fraction=0.362; bagging_fraction=0.772; num_leaves=21; min_data_in_leaf=725; lambda_l2=2.28 : y = 0.93 : 60.0 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "learning_rate"    "feature_fraction" "bagging_fraction" "num_leaves"
#  [5] "min_data_in_leaf" "lambda_l2"        "y"                "dob"
#  [9] "eol"              "error.message"    "exec.time"        "ei"
# [13] "error.model"      "train.time"       "prop.type"        "propose.time"
# [17] "se"               "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    learning_rate feature_fraction bagging_fraction num_leaves min_data_in_leaf
#            <num>            <num>            <num>      <int>            <int>
# 1:    0.01413744        0.3607001        0.7728511         21              710
#    lambda_l2
#        <num>
# 1:  2.399509
# [1] 0.9303714

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 100887
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 2.399509
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 0.7728511
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] TRUE
#
# $num_iterations
# [1] 1200
#
# $learning_rate
# [1] 0.01413744
#
# $feature_fraction
# [1] 0.3607001
#
# $num_leaves
# [1] 21
#
# $min_data_in_leaf
# [1] 710

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Jul 24 22:51:19 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
