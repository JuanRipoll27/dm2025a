# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# Esta Tarea para el Hogar 02 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el viernes 01-agosto

# %% [markdown]
# ##  1. Cazatalentos

# %% [markdown]
# En la Clase 03 nos hemos enfrentado a  "La Maldicion del Ganandor",  elegir el modelo con el mejor puntaje simple no suele ser la mejor estrategia.
# <br> Lea y ejecute el notebook  **src/CazaTalentos/CazaTalentos.ipynb**
# <br> en caso de interesarle, participe del Desafío Ordenamiento  que vence el sábado 02 de agosto a las 19:00

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dm"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dm" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/itba2025-8d0a/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Jul 22 00:39:51 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  656930 35.1 1439374    76.9 1431349  76.5
# Vcells 1224847  9.4 8388608    64.0 1924958  14.7

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 4942
PARAM$semilla_primigenia <- 100887

# %%
PARAM$kaggle$competencia <- "data-mining-analista-sr-2025-a"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_iterations", lower = 500L, upper = 3000L),
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.08),
  makeNumericParam("feature_fraction", lower = 0.4, upper = 0.7),
  makeNumericParam("bagging_fraction", lower = 0.4, upper = 0.9),
  makeIntegerParam("num_leaves", lower = 15L, upper = 80L),
  makeIntegerParam("min_data_in_leaf", lower = 200L, upper = 800L),
  makeIntegerParam("max_depth", lower = 6L, upper = 15L),
  makeNumericParam("lambda_l1", lower = 0.0, upper = 5.0),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 5.0),
  makeNumericParam("min_gain_to_split", lower = 0.0, upper = 1.0),
  makeNumericParam("drop_rate", lower = 0.1, upper = 0.6),
  makeNumericParam("skip_drop", lower = 0.1, upper = 0.7)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 90 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83368
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Tue Jul 22 00:41:04 2025 AUC 0.930395964599059
#
# Tue Jul 22 00:41:31 2025 AUC 0.929794106870652
#
# Tue Jul 22 00:41:51 2025 AUC 0.931410899962962
#
# Tue Jul 22 00:42:31 2025 AUC 0.930611289637847
#
# Tue Jul 22 00:43:01 2025 AUC 0.929626170177216
#
# Tue Jul 22 00:43:36 2025 AUC 0.930080519551287
#
# Tue Jul 22 00:44:01 2025 AUC 0.930339471637451
#
# Tue Jul 22 00:45:07 2025 AUC 0.93094691881504
#
# Tue Jul 22 00:46:01 2025 AUC 0.929673343797592
#
# Tue Jul 22 00:46:34 2025 AUC 0.931203564010335
#
# Tue Jul 22 00:47:22 2025 AUC 0.930431515860669
#
# Tue Jul 22 00:47:58 2025 AUC 0.931420033021977
#
# Tue Jul 22 00:49:04 2025 AUC 0.930045054945728
#
# Tue Jul 22 00:49:38 2025 AUC 0.931316488941277
#
# Tue Jul 22 00:50:05 2025 AUC 0.929812649812794
#
# Tue Jul 22 00:51:07 2025 AUC 0.930481761505161
#
# Tue Jul 22 00:51:34 2025 AUC 0.929636788927252
#
# Tue Jul 22 00:52:01 2025 AUC 0.930279092968677
#
# Tue Jul 22 00:52:22 2025 AUC 0.930363441748836
#
# Tue Jul 22 00:52:49 2025 AUC 0.930282497052431
#
# Tue Jul 22 00:53:21 2025 AUC 0.92947709498366
#
# Tue Jul 22 00:54:13 2025 AUC 0.930166419882138
#
# Tue Jul 22 00:55:27 2025 AUC 0.930795961726738
#
# Tue Jul 22 00:55:43 2025 AUC 0.930096345246178
#
# Tue Jul 22 00:56:24 2025 AUC 0.931258336828777
#
# Tue Jul 22 00:56:48 2025 AUC 0.929411174997491
#
# Tue Jul 22 00:57:31 2025 AUC 0.930300261783023
#
# Tue Jul 22 00:59:04 2025 AUC 0.931346673334025
#
# Tue Jul 22 01:00:12 2025 AUC 0.930481400139706
#
# Tue Jul 22 01:00:34 2025 AUC 0.931203259967027
#
# Tue Jul 22 01:01:24 2025 AUC 0.929413161790885
#
# Tue Jul 22 01:01:38 2025 AUC 0.929578680119596
#
# Tue Jul 22 01:02:10 2025 AUC 0.930472521739489
#
# Tue Jul 22 01:02:36 2025 AUC 0.930426332274352
#
# Tue Jul 22 01:03:13 2025 AUC 0.931604060892203
#
# Tue Jul 22 01:03:39 2025 AUC 0.92972333407076
#
# Tue Jul 22 01:04:20 2025 AUC 0.930603306115497
#
# Tue Jul 22 01:05:02 2025 AUC 0.930355859503822
#
# Tue Jul 22 01:06:16 2025 AUC 0.931089806396991
#
# Tue Jul 22 01:06:40 2025 AUC 0.930243703739821
#
# Tue Jul 22 01:07:34 2025 AUC 0.928475909508055
#
# Tue Jul 22 01:08:14 2025 AUC 0.929651286821389
#
# Tue Jul 22 01:08:47 2025 AUC 0.92924695850704
#
# Tue Jul 22 01:09:05 2025 AUC 0.924057193294483
#
# Tue Jul 22 01:10:10 2025 AUC 0.929850771438708
#
# Tue Jul 22 01:11:06 2025 AUC 0.930426353328106
#
# Tue Jul 22 01:11:52 2025 AUC 0.929710464378748
#
# Tue Jul 22 01:12:22 2025 AUC 0.930344590501651
#
# [mbo] 0: num_iterations=1445; learning_rate=0.0442; feature_fraction=0.486; bagging_fraction=0.587; num_leaves=52; min_data_in_leaf=372; max_depth=10; lambda_l1=0.761; lambda_l2=1.59; min_gain_to_split=0.414; drop_rate=0.23; skip_drop=0.557 : y = 0.93 : 41.4 secs : initdesign
#
# [mbo] 0: num_iterations=876; learning_rate=0.043; feature_fraction=0.529; bagging_fraction=0.473; num_leaves=43; min_data_in_leaf=474; max_depth=11; lambda_l1=1.91; lambda_l2=2.24; min_gain_to_split=0.306; drop_rate=0.156; skip_drop=0.49 : y = 0.93 : 27.1 secs : initdesign
#
# [mbo] 0: num_iterations=1238; learning_rate=0.068; feature_fraction=0.612; bagging_fraction=0.733; num_leaves=25; min_data_in_leaf=600; max_depth=10; lambda_l1=2.29; lambda_l2=2.76; min_gain_to_split=0.577; drop_rate=0.321; skip_drop=0.575 : y = 0.931 : 19.8 secs : initdesign
#
# [mbo] 0: num_iterations=1566; learning_rate=0.0495; feature_fraction=0.429; bagging_fraction=0.715; num_leaves=35; min_data_in_leaf=530; max_depth=12; lambda_l1=2.43; lambda_l2=2.61; min_gain_to_split=0.543; drop_rate=0.367; skip_drop=0.163 : y = 0.931 : 39.7 secs : initdesign
#
# [mbo] 0: num_iterations=1304; learning_rate=0.0258; feature_fraction=0.576; bagging_fraction=0.747; num_leaves=37; min_data_in_leaf=610; max_depth=12; lambda_l1=3.94; lambda_l2=2.07; min_gain_to_split=0.663; drop_rate=0.428; skip_drop=0.431 : y = 0.93 : 30.4 secs : initdesign
#
# [mbo] 0: num_iterations=1679; learning_rate=0.0565; feature_fraction=0.57; bagging_fraction=0.69; num_leaves=41; min_data_in_leaf=693; max_depth=10; lambda_l1=2.83; lambda_l2=1.48; min_gain_to_split=0.683; drop_rate=0.211; skip_drop=0.298 : y = 0.93 : 34.5 secs : initdesign
#
# [mbo] 0: num_iterations=785; learning_rate=0.0526; feature_fraction=0.505; bagging_fraction=0.556; num_leaves=56; min_data_in_leaf=459; max_depth=12; lambda_l1=2.54; lambda_l2=3.11; min_gain_to_split=0.245; drop_rate=0.455; skip_drop=0.402 : y = 0.93 : 25.4 secs : initdesign
#
# [mbo] 0: num_iterations=2700; learning_rate=0.0249; feature_fraction=0.541; bagging_fraction=0.64; num_leaves=63; min_data_in_leaf=478; max_depth=9; lambda_l1=1.66; lambda_l2=4.37; min_gain_to_split=0.866; drop_rate=0.504; skip_drop=0.371 : y = 0.931 : 65.7 secs : initdesign
#
# [mbo] 0: num_iterations=2398; learning_rate=0.0378; feature_fraction=0.555; bagging_fraction=0.773; num_leaves=72; min_data_in_leaf=712; max_depth=7; lambda_l1=4.98; lambda_l2=0.539; min_gain_to_split=0.766; drop_rate=0.524; skip_drop=0.444 : y = 0.93 : 53.9 secs : initdesign
#
# [mbo] 0: num_iterations=1782; learning_rate=0.033; feature_fraction=0.627; bagging_fraction=0.545; num_leaves=48; min_data_in_leaf=354; max_depth=8; lambda_l1=1.18; lambda_l2=3.44; min_gain_to_split=0.352; drop_rate=0.199; skip_drop=0.194 : y = 0.931 : 33.8 secs : initdesign
#
# [mbo] 0: num_iterations=1701; learning_rate=0.0475; feature_fraction=0.467; bagging_fraction=0.701; num_leaves=46; min_data_in_leaf=582; max_depth=10; lambda_l1=0.6; lambda_l2=1.9; min_gain_to_split=0.324; drop_rate=0.379; skip_drop=0.57 : y = 0.93 : 47.1 secs : initdesign
#
# [mbo] 0: num_iterations=1351; learning_rate=0.0392; feature_fraction=0.453; bagging_fraction=0.49; num_leaves=78; min_data_in_leaf=436; max_depth=12; lambda_l1=2.97; lambda_l2=0.793; min_gain_to_split=0.485; drop_rate=0.477; skip_drop=0.614 : y = 0.931 : 36.3 secs : initdesign
#
# [mbo] 0: num_iterations=2617; learning_rate=0.0548; feature_fraction=0.511; bagging_fraction=0.46; num_leaves=54; min_data_in_leaf=643; max_depth=14; lambda_l1=3.45; lambda_l2=0.0273; min_gain_to_split=0.124; drop_rate=0.269; skip_drop=0.258 : y = 0.93 : 66.3 secs : initdesign
#
# [mbo] 0: num_iterations=996; learning_rate=0.0153; feature_fraction=0.545; bagging_fraction=0.636; num_leaves=44; min_data_in_leaf=312; max_depth=8; lambda_l1=1.06; lambda_l2=4.07; min_gain_to_split=0.806; drop_rate=0.468; skip_drop=0.455 : y = 0.931 : 34.1 secs : initdesign
#
# [mbo] 0: num_iterations=966; learning_rate=0.0219; feature_fraction=0.599; bagging_fraction=0.658; num_leaves=31; min_data_in_leaf=418; max_depth=14; lambda_l1=2.22; lambda_l2=1.03; min_gain_to_split=0.372; drop_rate=0.178; skip_drop=0.546 : y = 0.93 : 26.6 secs : initdesign
#
# [mbo] 0: num_iterations=2435; learning_rate=0.0297; feature_fraction=0.447; bagging_fraction=0.465; num_leaves=22; min_data_in_leaf=768; max_depth=8; lambda_l1=4.43; lambda_l2=2.35; min_gain_to_split=0.225; drop_rate=0.295; skip_drop=0.501 : y = 0.93 : 62.2 secs : initdesign
#
# [mbo] 0: num_iterations=2355; learning_rate=0.0505; feature_fraction=0.648; bagging_fraction=0.505; num_leaves=28; min_data_in_leaf=721; max_depth=8; lambda_l1=3.28; lambda_l2=4.94; min_gain_to_split=0.778; drop_rate=0.347; skip_drop=0.326 : y = 0.93 : 26.7 secs : initdesign
#
# [mbo] 0: num_iterations=1093; learning_rate=0.0584; feature_fraction=0.407; bagging_fraction=0.743; num_leaves=62; min_data_in_leaf=448; max_depth=7; lambda_l1=3.55; lambda_l2=2.43; min_gain_to_split=0.886; drop_rate=0.265; skip_drop=0.237 : y = 0.93 : 26.8 secs : initdesign
#
# [mbo] 0: num_iterations=1495; learning_rate=0.0698; feature_fraction=0.654; bagging_fraction=0.759; num_leaves=55; min_data_in_leaf=404; max_depth=6; lambda_l1=2.12; lambda_l2=3.86; min_gain_to_split=0.185; drop_rate=0.409; skip_drop=0.652 : y = 0.93 : 21.0 secs : initdesign
#
# [mbo] 0: num_iterations=2511; learning_rate=0.0399; feature_fraction=0.668; bagging_fraction=0.877; num_leaves=73; min_data_in_leaf=500; max_depth=13; lambda_l1=3.39; lambda_l2=4.83; min_gain_to_split=0.984; drop_rate=0.351; skip_drop=0.215 : y = 0.93 : 27.5 secs : initdesign
#
# [mbo] 0: num_iterations=2129; learning_rate=0.0412; feature_fraction=0.673; bagging_fraction=0.436; num_leaves=52; min_data_in_leaf=267; max_depth=14; lambda_l1=0.715; lambda_l2=2.98; min_gain_to_split=0.27; drop_rate=0.568; skip_drop=0.34 : y = 0.929 : 32.2 secs : initdesign
#
# [mbo] 0: num_iterations=1601; learning_rate=0.0135; feature_fraction=0.492; bagging_fraction=0.424; num_leaves=69; min_data_in_leaf=760; max_depth=12; lambda_l1=0.862; lambda_l2=1.26; min_gain_to_split=0.702; drop_rate=0.532; skip_drop=0.302 : y = 0.93 : 51.8 secs : initdesign
#
# [mbo] 0: num_iterations=2649; learning_rate=0.0172; feature_fraction=0.423; bagging_fraction=0.818; num_leaves=34; min_data_in_leaf=653; max_depth=13; lambda_l1=3.12; lambda_l2=0.131; min_gain_to_split=0.284; drop_rate=0.283; skip_drop=0.513 : y = 0.931 : 73.8 secs : initdesign
#
# [mbo] 0: num_iterations=849; learning_rate=0.0735; feature_fraction=0.606; bagging_fraction=0.886; num_leaves=26; min_data_in_leaf=736; max_depth=13; lambda_l1=1.27; lambda_l2=4.64; min_gain_to_split=0.531; drop_rate=0.31; skip_drop=0.671 : y = 0.93 : 16.2 secs : initdesign
#
# [mbo] 0: num_iterations=1879; learning_rate=0.0652; feature_fraction=0.568; bagging_fraction=0.831; num_leaves=70; min_data_in_leaf=522; max_depth=9; lambda_l1=1.01; lambda_l2=1.23; min_gain_to_split=0.462; drop_rate=0.302; skip_drop=0.142 : y = 0.931 : 40.5 secs : initdesign
#
# [mbo] 0: num_iterations=2056; learning_rate=0.0711; feature_fraction=0.685; bagging_fraction=0.676; num_leaves=65; min_data_in_leaf=575; max_depth=15; lambda_l1=0.343; lambda_l2=4.43; min_gain_to_split=0.722; drop_rate=0.125; skip_drop=0.532 : y = 0.929 : 23.9 secs : initdesign
#
# [mbo] 0: num_iterations=2776; learning_rate=0.028; feature_fraction=0.678; bagging_fraction=0.575; num_leaves=49; min_data_in_leaf=284; max_depth=11; lambda_l1=4.19; lambda_l2=0.29; min_gain_to_split=0.059; drop_rate=0.194; skip_drop=0.284 : y = 0.93 : 43.5 secs : initdesign
#
# [mbo] 0: num_iterations=2557; learning_rate=0.0126; feature_fraction=0.402; bagging_fraction=0.783; num_leaves=39; min_data_in_leaf=552; max_depth=7; lambda_l1=0.114; lambda_l2=4.2; min_gain_to_split=0.011; drop_rate=0.392; skip_drop=0.322 : y = 0.931 : 92.4 secs : initdesign
#
# [mbo] 0: num_iterations=2924; learning_rate=0.058; feature_fraction=0.434; bagging_fraction=0.788; num_leaves=60; min_data_in_leaf=344; max_depth=7; lambda_l1=0.018; lambda_l2=2.83; min_gain_to_split=0.976; drop_rate=0.597; skip_drop=0.39 : y = 0.93 : 68.6 secs : initdesign
#
# [mbo] 0: num_iterations=744; learning_rate=0.0667; feature_fraction=0.52; bagging_fraction=0.868; num_leaves=75; min_data_in_leaf=333; max_depth=15; lambda_l1=2.06; lambda_l2=0.884; min_gain_to_split=0.744; drop_rate=0.224; skip_drop=0.599 : y = 0.931 : 21.3 secs : initdesign
#
# [mbo] 0: num_iterations=2071; learning_rate=0.0764; feature_fraction=0.474; bagging_fraction=0.413; num_leaves=18; min_data_in_leaf=299; max_depth=11; lambda_l1=4.58; lambda_l2=4.51; min_gain_to_split=0.839; drop_rate=0.253; skip_drop=0.603 : y = 0.929 : 50.3 secs : initdesign
#
# [mbo] 0: num_iterations=627; learning_rate=0.0314; feature_fraction=0.64; bagging_fraction=0.601; num_leaves=34; min_data_in_leaf=389; max_depth=8; lambda_l1=4.8; lambda_l2=4.02; min_gain_to_split=0.447; drop_rate=0.54; skip_drop=0.358 : y = 0.93 : 14.0 secs : initdesign
#
# [mbo] 0: num_iterations=1040; learning_rate=0.0622; feature_fraction=0.5; bagging_fraction=0.445; num_leaves=61; min_data_in_leaf=257; max_depth=15; lambda_l1=3.73; lambda_l2=2.17; min_gain_to_split=0.0793; drop_rate=0.236; skip_drop=0.125 : y = 0.93 : 32.0 secs : initdesign
#
# [mbo] 0: num_iterations=594; learning_rate=0.0336; feature_fraction=0.562; bagging_fraction=0.813; num_leaves=41; min_data_in_leaf=216; max_depth=9; lambda_l1=1.39; lambda_l2=0.495; min_gain_to_split=0.0934; drop_rate=0.511; skip_drop=0.47 : y = 0.93 : 26.3 secs : initdesign
#
# [mbo] 0: num_iterations=2207; learning_rate=0.0357; feature_fraction=0.616; bagging_fraction=0.839; num_leaves=16; min_data_in_leaf=550; max_depth=6; lambda_l1=4.1; lambda_l2=1.85; min_gain_to_split=0.204; drop_rate=0.144; skip_drop=0.274 : y = 0.932 : 36.8 secs : initdesign
#
# [mbo] 0: num_iterations=673; learning_rate=0.023; feature_fraction=0.459; bagging_fraction=0.897; num_leaves=67; min_data_in_leaf=798; max_depth=11; lambda_l1=2.64; lambda_l2=3.35; min_gain_to_split=0.424; drop_rate=0.336; skip_drop=0.205 : y = 0.93 : 26.3 secs : initdesign
#
# [mbo] 0: num_iterations=2959; learning_rate=0.0612; feature_fraction=0.624; bagging_fraction=0.588; num_leaves=77; min_data_in_leaf=377; max_depth=6; lambda_l1=3.22; lambda_l2=4.75; min_gain_to_split=0.391; drop_rate=0.413; skip_drop=0.111 : y = 0.931 : 40.5 secs : initdesign
#
# [mbo] 0: num_iterations=2803; learning_rate=0.0199; feature_fraction=0.637; bagging_fraction=0.53; num_leaves=57; min_data_in_leaf=672; max_depth=6; lambda_l1=0.424; lambda_l2=0.332; min_gain_to_split=0.62; drop_rate=0.135; skip_drop=0.382 : y = 0.93 : 42.3 secs : initdesign
#
# [mbo] 0: num_iterations=2272; learning_rate=0.00826; feature_fraction=0.414; bagging_fraction=0.563; num_leaves=47; min_data_in_leaf=313; max_depth=7; lambda_l1=1.82; lambda_l2=3.33; min_gain_to_split=0.592; drop_rate=0.101; skip_drop=0.7 : y = 0.931 : 74.2 secs : initdesign
#
# [mbo] 0: num_iterations=1178; learning_rate=0.0632; feature_fraction=0.591; bagging_fraction=0.851; num_leaves=16; min_data_in_leaf=494; max_depth=15; lambda_l1=4.7; lambda_l2=3.84; min_gain_to_split=0.166; drop_rate=0.438; skip_drop=0.136 : y = 0.93 : 24.1 secs : initdesign
#
# [mbo] 0: num_iterations=2271; learning_rate=0.0799; feature_fraction=0.513; bagging_fraction=0.703; num_leaves=67; min_data_in_leaf=782; max_depth=15; lambda_l1=1.46; lambda_l2=3.55; min_gain_to_split=0.814; drop_rate=0.581; skip_drop=0.628 : y = 0.928 : 54.0 secs : initdesign
#
# [mbo] 0: num_iterations=1388; learning_rate=0.00754; feature_fraction=0.694; bagging_fraction=0.406; num_leaves=23; min_data_in_leaf=238; max_depth=14; lambda_l1=3.82; lambda_l2=3.14; min_gain_to_split=0.504; drop_rate=0.12; skip_drop=0.162 : y = 0.93 : 39.6 secs : initdesign
#
# [mbo] 0: num_iterations=1914; learning_rate=0.0107; feature_fraction=0.658; bagging_fraction=0.619; num_leaves=74; min_data_in_leaf=211; max_depth=9; lambda_l1=4.28; lambda_l2=1.08; min_gain_to_split=0.954; drop_rate=0.445; skip_drop=0.238 : y = 0.929 : 33.1 secs : initdesign
#
# [mbo] 0: num_iterations=530; learning_rate=0.00528; feature_fraction=0.585; bagging_fraction=0.609; num_leaves=28; min_data_in_leaf=742; max_depth=13; lambda_l1=4.67; lambda_l2=0.722; min_gain_to_split=0.916; drop_rate=0.55; skip_drop=0.477 : y = 0.924 : 17.9 secs : initdesign
#
# [mbo] 0: num_iterations=2850; learning_rate=0.0747; feature_fraction=0.536; bagging_fraction=0.524; num_leaves=19; min_data_in_leaf=615; max_depth=6; lambda_l1=2.79; lambda_l2=1.4; min_gain_to_split=0.632; drop_rate=0.571; skip_drop=0.415 : y = 0.93 : 64.6 secs : initdesign
#
# [mbo] 0: num_iterations=1964; learning_rate=0.0179; feature_fraction=0.69; bagging_fraction=0.803; num_leaves=21; min_data_in_leaf=631; max_depth=11; lambda_l1=1.73; lambda_l2=3.71; min_gain_to_split=0.0353; drop_rate=0.487; skip_drop=0.684 : y = 0.93 : 56.2 secs : initdesign
#
# [mbo] 0: num_iterations=1808; learning_rate=0.0776; feature_fraction=0.476; bagging_fraction=0.496; num_leaves=80; min_data_in_leaf=676; max_depth=10; lambda_l1=4.02; lambda_l2=1.68; min_gain_to_split=0.14; drop_rate=0.166; skip_drop=0.646 : y = 0.93 : 46.1 secs : initdesign
#
# [mbo] 0: num_iterations=1164; learning_rate=0.0469; feature_fraction=0.442; bagging_fraction=0.662; num_leaves=31; min_data_in_leaf=232; max_depth=13; lambda_l1=0.283; lambda_l2=2.5; min_gain_to_split=0.924; drop_rate=0.391; skip_drop=0.175 : y = 0.93 : 30.3 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Tue Jul 22 01:13:14 2025 AUC 0.931612221698497
#
# [mbo] 1: num_iterations=1743; learning_rate=0.0243; feature_fraction=0.521; bagging_fraction=0.876; num_leaves=74; min_data_in_leaf=405; max_depth=6; lambda_l1=1.68; lambda_l2=3.14; min_gain_to_split=0.555; drop_rate=0.4; skip_drop=0.342 : y = 0.932 : 47.8 secs : infill_ei
#
# Tue Jul 22 01:13:55 2025 AUC 0.930154957364748
#
# [mbo] 2: num_iterations=2149; learning_rate=0.0246; feature_fraction=0.605; bagging_fraction=0.781; num_leaves=46; min_data_in_leaf=358; max_depth=8; lambda_l1=1.31; lambda_l2=4.18; min_gain_to_split=0.663; drop_rate=0.294; skip_drop=0.258 : y = 0.93 : 39.9 secs : infill_ei
#
# Tue Jul 22 01:14:27 2025 AUC 0.929318473321827
#
# [mbo] 3: num_iterations=1262; learning_rate=0.0529; feature_fraction=0.541; bagging_fraction=0.787; num_leaves=73; min_data_in_leaf=459; max_depth=7; lambda_l1=2.1; lambda_l2=1.01; min_gain_to_split=0.582; drop_rate=0.358; skip_drop=0.638 : y = 0.929 : 31.8 secs : infill_ei
#
# Tue Jul 22 01:15:31 2025 AUC 0.930767427811259
#
# [mbo] 4: num_iterations=2267; learning_rate=0.0484; feature_fraction=0.478; bagging_fraction=0.83; num_leaves=31; min_data_in_leaf=574; max_depth=6; lambda_l1=1.15; lambda_l2=2.51; min_gain_to_split=0.0933; drop_rate=0.24; skip_drop=0.202 : y = 0.931 : 62.6 secs : infill_ei
#
# Tue Jul 22 01:16:23 2025 AUC 0.931208281940849
#
# [mbo] 5: num_iterations=1638; learning_rate=0.0313; feature_fraction=0.443; bagging_fraction=0.585; num_leaves=77; min_data_in_leaf=431; max_depth=8; lambda_l1=1.93; lambda_l2=2.3; min_gain_to_split=0.136; drop_rate=0.429; skip_drop=0.407 : y = 0.931 : 51.1 secs : infill_ei
#
# Tue Jul 22 01:16:56 2025 AUC 0.930309071296655
#
# [mbo] 6: num_iterations=2373; learning_rate=0.032; feature_fraction=0.641; bagging_fraction=0.805; num_leaves=34; min_data_in_leaf=542; max_depth=8; lambda_l1=1.88; lambda_l2=3.26; min_gain_to_split=0.424; drop_rate=0.138; skip_drop=0.328 : y = 0.93 : 32.2 secs : infill_ei
#
# Tue Jul 22 01:17:54 2025 AUC 0.931274587033038
#
# [mbo] 7: num_iterations=1743; learning_rate=0.0188; feature_fraction=0.406; bagging_fraction=0.758; num_leaves=48; min_data_in_leaf=423; max_depth=6; lambda_l1=1.2; lambda_l2=4.44; min_gain_to_split=0.234; drop_rate=0.174; skip_drop=0.507 : y = 0.931 : 56.8 secs : infill_ei
#
# Tue Jul 22 01:18:54 2025 AUC 0.930867619107388
#
# [mbo] 8: num_iterations=2068; learning_rate=0.0176; feature_fraction=0.512; bagging_fraction=0.537; num_leaves=71; min_data_in_leaf=358; max_depth=6; lambda_l1=0.845; lambda_l2=4.14; min_gain_to_split=0.601; drop_rate=0.441; skip_drop=0.437 : y = 0.931 : 58.9 secs : infill_ei
#
# Tue Jul 22 01:19:37 2025 AUC 0.930895915730707
#
# [mbo] 9: num_iterations=1463; learning_rate=0.0693; feature_fraction=0.489; bagging_fraction=0.731; num_leaves=18; min_data_in_leaf=489; max_depth=9; lambda_l1=1.83; lambda_l2=3.86; min_gain_to_split=0.0689; drop_rate=0.304; skip_drop=0.362 : y = 0.931 : 42.5 secs : infill_ei
#
# Tue Jul 22 01:20:59 2025 AUC 0.93056705611695
#
# [mbo] 10: num_iterations=2352; learning_rate=0.014; feature_fraction=0.436; bagging_fraction=0.715; num_leaves=44; min_data_in_leaf=397; max_depth=8; lambda_l1=0.401; lambda_l2=3.47; min_gain_to_split=0.306; drop_rate=0.287; skip_drop=0.593 : y = 0.931 : 80.5 secs : infill_ei
#
# Tue Jul 22 01:22:04 2025 AUC 0.930862823564172
#
# [mbo] 11: num_iterations=1909; learning_rate=0.0158; feature_fraction=0.425; bagging_fraction=0.845; num_leaves=65; min_data_in_leaf=411; max_depth=6; lambda_l1=1.75; lambda_l2=2.84; min_gain_to_split=0.262; drop_rate=0.457; skip_drop=0.395 : y = 0.931 : 63.9 secs : infill_ei
#
# Tue Jul 22 01:22:37 2025 AUC 0.930554079610644
#
# [mbo] 12: num_iterations=1852; learning_rate=0.0612; feature_fraction=0.605; bagging_fraction=0.578; num_leaves=52; min_data_in_leaf=561; max_depth=6; lambda_l1=1.93; lambda_l2=1.1; min_gain_to_split=0.29; drop_rate=0.189; skip_drop=0.204 : y = 0.931 : 31.9 secs : infill_ei
#
# Saved the current state after iteration 13 in the file bayesiana.RDATA.
#
# Tue Jul 22 01:23:20 2025 AUC 0.931414687892181
#
# [mbo] 13: num_iterations=1340; learning_rate=0.0225; feature_fraction=0.477; bagging_fraction=0.777; num_leaves=62; min_data_in_leaf=281; max_depth=6; lambda_l1=1.07; lambda_l2=4.15; min_gain_to_split=0.611; drop_rate=0.353; skip_drop=0.4 : y = 0.931 : 38.9 secs : infill_ei
#
# Tue Jul 22 01:24:15 2025 AUC 0.930932829378667
#
# [mbo] 14: num_iterations=2032; learning_rate=0.0363; feature_fraction=0.464; bagging_fraction=0.651; num_leaves=38; min_data_in_leaf=430; max_depth=9; lambda_l1=3.51; lambda_l2=1.74; min_gain_to_split=0.256; drop_rate=0.201; skip_drop=0.185 : y = 0.931 : 53.8 secs : infill_ei
#
# Tue Jul 22 01:24:55 2025 AUC 0.929492767854195
#
# [mbo] 15: num_iterations=1486; learning_rate=0.0268; feature_fraction=0.508; bagging_fraction=0.537; num_leaves=80; min_data_in_leaf=434; max_depth=6; lambda_l1=1.5; lambda_l2=4.09; min_gain_to_split=0.841; drop_rate=0.362; skip_drop=0.262 : y = 0.929 : 39.7 secs : infill_ei
#
# Tue Jul 22 01:25:45 2025 AUC 0.930870472808662
#
# [mbo] 16: num_iterations=1786; learning_rate=0.0306; feature_fraction=0.555; bagging_fraction=0.817; num_leaves=31; min_data_in_leaf=390; max_depth=6; lambda_l1=2.72; lambda_l2=3.13; min_gain_to_split=0.159; drop_rate=0.385; skip_drop=0.214 : y = 0.931 : 48.7 secs : infill_ei
#
# Tue Jul 22 01:26:32 2025 AUC 0.931195221703655
#
# [mbo] 17: num_iterations=1590; learning_rate=0.0231; feature_fraction=0.493; bagging_fraction=0.824; num_leaves=74; min_data_in_leaf=354; max_depth=6; lambda_l1=1.56; lambda_l2=2.96; min_gain_to_split=0.45; drop_rate=0.177; skip_drop=0.666 : y = 0.931 : 45.7 secs : infill_ei
#
# Tue Jul 22 01:27:22 2025 AUC 0.93108044150403
#
# [mbo] 18: num_iterations=1739; learning_rate=0.0346; feature_fraction=0.535; bagging_fraction=0.585; num_leaves=72; min_data_in_leaf=285; max_depth=6; lambda_l1=0.603; lambda_l2=1.17; min_gain_to_split=0.287; drop_rate=0.431; skip_drop=0.315 : y = 0.931 : 49.2 secs : infill_ei
#
# Tue Jul 22 01:28:10 2025 AUC 0.930472660508841
#
# [mbo] 19: num_iterations=1723; learning_rate=0.0307; feature_fraction=0.469; bagging_fraction=0.884; num_leaves=75; min_data_in_leaf=392; max_depth=10; lambda_l1=1.37; lambda_l2=3.78; min_gain_to_split=0.451; drop_rate=0.344; skip_drop=0.172 : y = 0.93 : 47.2 secs : infill_ei
#
# Tue Jul 22 01:29:30 2025 AUC 0.931915401583287
#
# [mbo] 20: num_iterations=2173; learning_rate=0.0248; feature_fraction=0.504; bagging_fraction=0.645; num_leaves=51; min_data_in_leaf=528; max_depth=7; lambda_l1=0.71; lambda_l2=4.29; min_gain_to_split=0.0791; drop_rate=0.129; skip_drop=0.284 : y = 0.932 : 78.9 secs : infill_ei
#
# Tue Jul 22 01:30:13 2025 AUC 0.930183004157197
#
# [mbo] 21: num_iterations=1455; learning_rate=0.0294; feature_fraction=0.443; bagging_fraction=0.862; num_leaves=75; min_data_in_leaf=296; max_depth=6; lambda_l1=0.43; lambda_l2=4.63; min_gain_to_split=0.575; drop_rate=0.23; skip_drop=0.305 : y = 0.93 : 41.3 secs : infill_ei
#
# Tue Jul 22 01:31:34 2025 AUC 0.931787845601566
#
# [mbo] 22: num_iterations=2330; learning_rate=0.0218; feature_fraction=0.407; bagging_fraction=0.656; num_leaves=65; min_data_in_leaf=508; max_depth=6; lambda_l1=0.842; lambda_l2=4.21; min_gain_to_split=0.0268; drop_rate=0.465; skip_drop=0.372 : y = 0.932 : 80.8 secs : infill_ei
#
# Tue Jul 22 01:32:55 2025 AUC 0.93090652075835
#
# [mbo] 23: num_iterations=2582; learning_rate=0.024; feature_fraction=0.491; bagging_fraction=0.845; num_leaves=64; min_data_in_leaf=323; max_depth=6; lambda_l1=0.966; lambda_l2=4.24; min_gain_to_split=0.154; drop_rate=0.393; skip_drop=0.237 : y = 0.931 : 79.8 secs : infill_ei
#
# Saved the current state after iteration 24 in the file bayesiana.RDATA.
#
# Tue Jul 22 01:34:17 2025 AUC 0.93041890853257
#
# [mbo] 24: num_iterations=1751; learning_rate=0.0238; feature_fraction=0.522; bagging_fraction=0.675; num_leaves=58; min_data_in_leaf=506; max_depth=8; lambda_l1=0.639; lambda_l2=3.23; min_gain_to_split=0.0282; drop_rate=0.478; skip_drop=0.279 : y = 0.93 : 75.1 secs : infill_ei
#
# Tue Jul 22 01:35:27 2025 AUC 0.93092047041773
#
# [mbo] 25: num_iterations=2211; learning_rate=0.0221; feature_fraction=0.527; bagging_fraction=0.622; num_leaves=42; min_data_in_leaf=475; max_depth=6; lambda_l1=2.74; lambda_l2=4.53; min_gain_to_split=0.11; drop_rate=0.114; skip_drop=0.409 : y = 0.931 : 68.9 secs : infill_ei
#
# Tue Jul 22 01:36:06 2025 AUC 0.931363045440005
#
# [mbo] 26: num_iterations=1353; learning_rate=0.0354; feature_fraction=0.498; bagging_fraction=0.727; num_leaves=48; min_data_in_leaf=290; max_depth=6; lambda_l1=1.01; lambda_l2=3.28; min_gain_to_split=0.597; drop_rate=0.29; skip_drop=0.346 : y = 0.931 : 37.6 secs : infill_ei
#
# Tue Jul 22 01:37:15 2025 AUC 0.931071066853218
#
# [mbo] 27: num_iterations=2401; learning_rate=0.0255; feature_fraction=0.523; bagging_fraction=0.625; num_leaves=41; min_data_in_leaf=332; max_depth=6; lambda_l1=0.719; lambda_l2=4.37; min_gain_to_split=0.293; drop_rate=0.402; skip_drop=0.416 : y = 0.931 : 68.3 secs : infill_ei
#
# Tue Jul 22 01:37:57 2025 AUC 0.930971703720457
#
# [mbo] 28: num_iterations=1170; learning_rate=0.014; feature_fraction=0.542; bagging_fraction=0.682; num_leaves=60; min_data_in_leaf=252; max_depth=6; lambda_l1=1.28; lambda_l2=3.43; min_gain_to_split=0.584; drop_rate=0.518; skip_drop=0.581 : y = 0.931 : 40.2 secs : infill_ei
#
# Tue Jul 22 01:39:24 2025 AUC 0.930906790907253
#
# [mbo] 29: num_iterations=2475; learning_rate=0.0226; feature_fraction=0.484; bagging_fraction=0.609; num_leaves=57; min_data_in_leaf=636; max_depth=6; lambda_l1=0.821; lambda_l2=3.78; min_gain_to_split=0.039; drop_rate=0.163; skip_drop=0.389 : y = 0.931 : 85.6 secs : infill_ei
#
# Tue Jul 22 01:40:35 2025 AUC 0.93093297251676
#
# [mbo] 30: num_iterations=1830; learning_rate=0.0365; feature_fraction=0.414; bagging_fraction=0.647; num_leaves=57; min_data_in_leaf=363; max_depth=7; lambda_l1=0.778; lambda_l2=4.35; min_gain_to_split=0.0217; drop_rate=0.399; skip_drop=0.343 : y = 0.931 : 69.7 secs : infill_ei
#
# Tue Jul 22 01:41:22 2025 AUC 0.930741532844746
#
# [mbo] 31: num_iterations=1798; learning_rate=0.0304; feature_fraction=0.449; bagging_fraction=0.812; num_leaves=69; min_data_in_leaf=367; max_depth=6; lambda_l1=1.36; lambda_l2=2.38; min_gain_to_split=0.501; drop_rate=0.273; skip_drop=0.304 : y = 0.931 : 45.8 secs : infill_ei
#
# Tue Jul 22 01:42:48 2025 AUC 0.930578720373759
#
# [mbo] 32: num_iterations=2932; learning_rate=0.0145; feature_fraction=0.496; bagging_fraction=0.664; num_leaves=58; min_data_in_leaf=534; max_depth=6; lambda_l1=0.514; lambda_l2=3.97; min_gain_to_split=0.424; drop_rate=0.232; skip_drop=0.416 : y = 0.931 : 84.5 secs : infill_ei
#
# Tue Jul 22 01:43:33 2025 AUC 0.929731280315689
#
# [mbo] 33: num_iterations=1628; learning_rate=0.0461; feature_fraction=0.46; bagging_fraction=0.724; num_leaves=80; min_data_in_leaf=358; max_depth=13; lambda_l1=1.91; lambda_l2=0.793; min_gain_to_split=0.291; drop_rate=0.524; skip_drop=0.355 : y = 0.93 : 43.8 secs : infill_ei
#
# Saved the current state after iteration 34 in the file bayesiana.RDATA.
#
# Tue Jul 22 01:44:11 2025 AUC 0.930553994042117
#
# [mbo] 34: num_iterations=1484; learning_rate=0.0659; feature_fraction=0.579; bagging_fraction=0.744; num_leaves=34; min_data_in_leaf=471; max_depth=10; lambda_l1=0.685; lambda_l2=2.34; min_gain_to_split=0.446; drop_rate=0.212; skip_drop=0.207 : y = 0.931 : 31.4 secs : infill_ei
#
# Tue Jul 22 01:45:08 2025 AUC 0.930717995132271
#
# [mbo] 35: num_iterations=2177; learning_rate=0.0347; feature_fraction=0.586; bagging_fraction=0.454; num_leaves=78; min_data_in_leaf=423; max_depth=7; lambda_l1=0.81; lambda_l2=3.59; min_gain_to_split=0.102; drop_rate=0.331; skip_drop=0.307 : y = 0.931 : 56.4 secs : infill_ei
#
# Tue Jul 22 01:46:39 2025 AUC 0.92992466948932
#
# [mbo] 36: num_iterations=2470; learning_rate=0.0242; feature_fraction=0.448; bagging_fraction=0.441; num_leaves=46; min_data_in_leaf=403; max_depth=6; lambda_l1=1.36; lambda_l2=1.45; min_gain_to_split=0.000181; drop_rate=0.101; skip_drop=0.288 : y = 0.93 : 89.0 secs : infill_ei
#
# Tue Jul 22 01:47:19 2025 AUC 0.93070771283124
#
# [mbo] 37: num_iterations=1108; learning_rate=0.008; feature_fraction=0.45; bagging_fraction=0.65; num_leaves=45; min_data_in_leaf=625; max_depth=7; lambda_l1=1.46; lambda_l2=4.85; min_gain_to_split=0.149; drop_rate=0.146; skip_drop=0.525 : y = 0.931 : 39.3 secs : infill_ei
#
# Tue Jul 22 01:48:03 2025 AUC 0.93083109230218
#
# [mbo] 38: num_iterations=1572; learning_rate=0.0358; feature_fraction=0.505; bagging_fraction=0.598; num_leaves=43; min_data_in_leaf=694; max_depth=7; lambda_l1=2.35; lambda_l2=2.43; min_gain_to_split=0.27; drop_rate=0.167; skip_drop=0.615 : y = 0.931 : 43.4 secs : infill_ei
#
# Tue Jul 22 01:48:41 2025 AUC 0.931155879758908
#
# [mbo] 39: num_iterations=1154; learning_rate=0.0239; feature_fraction=0.403; bagging_fraction=0.641; num_leaves=59; min_data_in_leaf=504; max_depth=6; lambda_l1=1.45; lambda_l2=4.57; min_gain_to_split=0.339; drop_rate=0.514; skip_drop=0.401 : y = 0.931 : 36.6 secs : infill_ei
#
# Tue Jul 22 01:49:46 2025 AUC 0.930564349553372
#
# [mbo] 40: num_iterations=1613; learning_rate=0.0211; feature_fraction=0.456; bagging_fraction=0.702; num_leaves=63; min_data_in_leaf=594; max_depth=7; lambda_l1=0.523; lambda_l2=4.36; min_gain_to_split=0.0748; drop_rate=0.559; skip_drop=0.347 : y = 0.931 : 63.8 secs : infill_ei
#
# Tue Jul 22 01:51:10 2025 AUC 0.929786517078795
#
# [mbo] 41: num_iterations=2497; learning_rate=0.0226; feature_fraction=0.532; bagging_fraction=0.63; num_leaves=19; min_data_in_leaf=548; max_depth=7; lambda_l1=0.584; lambda_l2=4.18; min_gain_to_split=0.135; drop_rate=0.14; skip_drop=0.413 : y = 0.93 : 82.5 secs : infill_ei
#
# Tue Jul 22 01:52:30 2025 AUC 0.930310826951916
#
# [mbo] 42: num_iterations=2164; learning_rate=0.0261; feature_fraction=0.555; bagging_fraction=0.737; num_leaves=46; min_data_in_leaf=615; max_depth=6; lambda_l1=2.64; lambda_l2=4.47; min_gain_to_split=0.00551; drop_rate=0.126; skip_drop=0.262 : y = 0.93 : 78.1 secs : infill_ei
#
# Tue Jul 22 01:53:03 2025 AUC 0.931427329664988
#
# [mbo] 43: num_iterations=1691; learning_rate=0.0456; feature_fraction=0.597; bagging_fraction=0.852; num_leaves=17; min_data_in_leaf=551; max_depth=8; lambda_l1=2.64; lambda_l2=1.74; min_gain_to_split=0.309; drop_rate=0.139; skip_drop=0.595 : y = 0.931 : 31.6 secs : infill_ei
#
# Tue Jul 22 01:53:46 2025 AUC 0.93105456847834
#
# [mbo] 44: num_iterations=1377; learning_rate=0.0251; feature_fraction=0.553; bagging_fraction=0.868; num_leaves=21; min_data_in_leaf=516; max_depth=6; lambda_l1=2.79; lambda_l2=1.46; min_gain_to_split=0.201; drop_rate=0.225; skip_drop=0.383 : y = 0.931 : 41.2 secs : infill_ei
#
# Saved the current state after iteration 45 in the file bayesiana.RDATA.
#
# Tue Jul 22 01:54:18 2025 AUC 0.930145369508826
#
# [mbo] 45: num_iterations=1090; learning_rate=0.0441; feature_fraction=0.563; bagging_fraction=0.764; num_leaves=26; min_data_in_leaf=387; max_depth=6; lambda_l1=1.7; lambda_l2=3.63; min_gain_to_split=0.646; drop_rate=0.168; skip_drop=0.656 : y = 0.93 : 26.6 secs : infill_ei
#
# Tue Jul 22 01:55:30 2025 AUC 0.930979463044186
#
# [mbo] 46: num_iterations=2428; learning_rate=0.0322; feature_fraction=0.464; bagging_fraction=0.514; num_leaves=71; min_data_in_leaf=313; max_depth=9; lambda_l1=2.56; lambda_l2=2.78; min_gain_to_split=0.117; drop_rate=0.59; skip_drop=0.638 : y = 0.931 : 70.5 secs : infill_ei
#
# Tue Jul 22 01:55:59 2025 AUC 0.930280443543754
#
# [mbo] 47: num_iterations=2131; learning_rate=0.0332; feature_fraction=0.661; bagging_fraction=0.874; num_leaves=67; min_data_in_leaf=441; max_depth=6; lambda_l1=2.33; lambda_l2=2.03; min_gain_to_split=0.524; drop_rate=0.269; skip_drop=0.497 : y = 0.93 : 27.1 secs : infill_ei
#
# Tue Jul 22 01:56:21 2025 AUC 0.930252463404841
#
# [mbo] 48: num_iterations=958; learning_rate=0.0248; feature_fraction=0.637; bagging_fraction=0.633; num_leaves=51; min_data_in_leaf=345; max_depth=7; lambda_l1=2.13; lambda_l2=4.28; min_gain_to_split=0.7; drop_rate=0.106; skip_drop=0.502 : y = 0.93 : 20.1 secs : infill_ei
#
# Tue Jul 22 01:57:57 2025 AUC 0.930826598907644
#
# [mbo] 49: num_iterations=2490; learning_rate=0.0214; feature_fraction=0.409; bagging_fraction=0.653; num_leaves=70; min_data_in_leaf=521; max_depth=7; lambda_l1=2.98; lambda_l2=2.26; min_gain_to_split=0.00545; drop_rate=0.153; skip_drop=0.274 : y = 0.931 : 94.9 secs : infill_ei
#
# Tue Jul 22 01:59:11 2025 AUC 0.930842390681319
#
# [mbo] 50: num_iterations=2207; learning_rate=0.00771; feature_fraction=0.411; bagging_fraction=0.567; num_leaves=67; min_data_in_leaf=505; max_depth=8; lambda_l1=3.07; lambda_l2=3.92; min_gain_to_split=0.525; drop_rate=0.511; skip_drop=0.502 : y = 0.931 : 72.7 secs : infill_ei
#
# Tue Jul 22 01:59:55 2025 AUC 0.930825863165486
#
# [mbo] 51: num_iterations=1357; learning_rate=0.0216; feature_fraction=0.478; bagging_fraction=0.642; num_leaves=49; min_data_in_leaf=296; max_depth=6; lambda_l1=0.301; lambda_l2=2.99; min_gain_to_split=0.647; drop_rate=0.171; skip_drop=0.252 : y = 0.931 : 41.9 secs : infill_ei
#
# Tue Jul 22 02:00:51 2025 AUC 0.931463943626562
#
# [mbo] 52: num_iterations=2136; learning_rate=0.0592; feature_fraction=0.451; bagging_fraction=0.848; num_leaves=17; min_data_in_leaf=494; max_depth=8; lambda_l1=3.4; lambda_l2=1.76; min_gain_to_split=0.233; drop_rate=0.143; skip_drop=0.418 : y = 0.931 : 54.4 secs : infill_ei
#
# Tue Jul 22 02:01:53 2025 AUC 0.930633982645086
#
# [mbo] 53: num_iterations=2057; learning_rate=0.0415; feature_fraction=0.464; bagging_fraction=0.641; num_leaves=58; min_data_in_leaf=278; max_depth=8; lambda_l1=0.951; lambda_l2=3.94; min_gain_to_split=0.174; drop_rate=0.12; skip_drop=0.271 : y = 0.931 : 60.9 secs : infill_ei
#
# Tue Jul 22 02:02:28 2025 AUC 0.931259292293127
#
# [mbo] 54: num_iterations=2107; learning_rate=0.0526; feature_fraction=0.624; bagging_fraction=0.779; num_leaves=18; min_data_in_leaf=624; max_depth=9; lambda_l1=3.28; lambda_l2=2.06; min_gain_to_split=0.216; drop_rate=0.279; skip_drop=0.4 : y = 0.931 : 33.1 secs : infill_ei
#
# Tue Jul 22 02:03:36 2025 AUC 0.930867826918268
#
# [mbo] 55: num_iterations=2398; learning_rate=0.0409; feature_fraction=0.491; bagging_fraction=0.835; num_leaves=18; min_data_in_leaf=433; max_depth=7; lambda_l1=3.42; lambda_l2=0.74; min_gain_to_split=0.0541; drop_rate=0.184; skip_drop=0.33 : y = 0.931 : 66.1 secs : infill_ei
#
# Tue Jul 22 02:04:53 2025 AUC 0.930235779225709
#
# [mbo] 56: num_iterations=2226; learning_rate=0.00646; feature_fraction=0.448; bagging_fraction=0.637; num_leaves=49; min_data_in_leaf=637; max_depth=6; lambda_l1=0.644; lambda_l2=4.64; min_gain_to_split=0.0106; drop_rate=0.275; skip_drop=0.484 : y = 0.93 : 76.2 secs : infill_ei
#
# Saved the current state after iteration 57 in the file bayesiana.RDATA.
#
# Tue Jul 22 02:06:07 2025 AUC 0.931197536627693
#
# [mbo] 57: num_iterations=1771; learning_rate=0.022; feature_fraction=0.44; bagging_fraction=0.636; num_leaves=52; min_data_in_leaf=494; max_depth=7; lambda_l1=0.185; lambda_l2=3.89; min_gain_to_split=0.0532; drop_rate=0.129; skip_drop=0.455 : y = 0.931 : 66.8 secs : infill_ei
#
# Tue Jul 22 02:06:50 2025 AUC 0.930523472674025
#
# [mbo] 58: num_iterations=1682; learning_rate=0.0485; feature_fraction=0.439; bagging_fraction=0.828; num_leaves=16; min_data_in_leaf=577; max_depth=8; lambda_l1=1.94; lambda_l2=2.41; min_gain_to_split=0.49; drop_rate=0.327; skip_drop=0.547 : y = 0.931 : 41.7 secs : infill_ei
#
# Tue Jul 22 02:07:40 2025 AUC 0.931218824415995
#
# [mbo] 59: num_iterations=1947; learning_rate=0.0563; feature_fraction=0.495; bagging_fraction=0.739; num_leaves=50; min_data_in_leaf=500; max_depth=8; lambda_l1=2.17; lambda_l2=4.52; min_gain_to_split=0.556; drop_rate=0.11; skip_drop=0.158 : y = 0.931 : 48.7 secs : infill_ei
#
# Tue Jul 22 02:09:02 2025 AUC 0.931401492559454
#
# [mbo] 60: num_iterations=2684; learning_rate=0.0246; feature_fraction=0.406; bagging_fraction=0.745; num_leaves=56; min_data_in_leaf=509; max_depth=7; lambda_l1=1.49; lambda_l2=4.29; min_gain_to_split=0.0913; drop_rate=0.234; skip_drop=0.162 : y = 0.931 : 80.2 secs : infill_ei
#
# Tue Jul 22 02:09:41 2025 AUC 0.930746965487578
#
# [mbo] 61: num_iterations=1871; learning_rate=0.0677; feature_fraction=0.579; bagging_fraction=0.821; num_leaves=21; min_data_in_leaf=537; max_depth=8; lambda_l1=3.7; lambda_l2=3.29; min_gain_to_split=0.226; drop_rate=0.235; skip_drop=0.539 : y = 0.931 : 37.6 secs : infill_ei
#
# Tue Jul 22 02:10:10 2025 AUC 0.930779786316254
#
# [mbo] 62: num_iterations=978; learning_rate=0.0428; feature_fraction=0.517; bagging_fraction=0.883; num_leaves=54; min_data_in_leaf=275; max_depth=7; lambda_l1=2.05; lambda_l2=3.41; min_gain_to_split=0.695; drop_rate=0.373; skip_drop=0.333 : y = 0.931 : 26.5 secs : infill_ei
#
# Tue Jul 22 02:11:07 2025 AUC 0.930906896034037
#
# [mbo] 63: num_iterations=1864; learning_rate=0.0163; feature_fraction=0.521; bagging_fraction=0.86; num_leaves=61; min_data_in_leaf=385; max_depth=9; lambda_l1=1.25; lambda_l2=3.39; min_gain_to_split=0.724; drop_rate=0.23; skip_drop=0.269 : y = 0.931 : 55.5 secs : infill_ei
#
# Tue Jul 22 02:12:23 2025 AUC 0.930627079217992
#
# [mbo] 64: num_iterations=1782; learning_rate=0.0296; feature_fraction=0.496; bagging_fraction=0.684; num_leaves=50; min_data_in_leaf=563; max_depth=12; lambda_l1=0.569; lambda_l2=4.31; min_gain_to_split=0.0551; drop_rate=0.1; skip_drop=0.371 : y = 0.931 : 74.3 secs : infill_ei
#
# Tue Jul 22 02:13:06 2025 AUC 0.93015250817496
#
# [mbo] 65: num_iterations=1960; learning_rate=0.0437; feature_fraction=0.57; bagging_fraction=0.883; num_leaves=16; min_data_in_leaf=506; max_depth=7; lambda_l1=3.92; lambda_l2=2.02; min_gain_to_split=0.269; drop_rate=0.216; skip_drop=0.167 : y = 0.93 : 41.0 secs : infill_ei
#
# Tue Jul 22 02:14:17 2025 AUC 0.931205694109172
#
# [mbo] 66: num_iterations=1905; learning_rate=0.0224; feature_fraction=0.489; bagging_fraction=0.685; num_leaves=57; min_data_in_leaf=517; max_depth=7; lambda_l1=1.55; lambda_l2=4.49; min_gain_to_split=0.0851; drop_rate=0.109; skip_drop=0.198 : y = 0.931 : 69.6 secs : infill_ei
#
# Tue Jul 22 02:15:07 2025 AUC 0.930604549190758
#
# [mbo] 67: num_iterations=1974; learning_rate=0.0765; feature_fraction=0.469; bagging_fraction=0.742; num_leaves=47; min_data_in_leaf=301; max_depth=6; lambda_l1=0.348; lambda_l2=4.78; min_gain_to_split=0.781; drop_rate=0.427; skip_drop=0.444 : y = 0.931 : 47.8 secs : infill_ei
#
# Saved the current state after iteration 68 in the file bayesiana.RDATA.
#
# Tue Jul 22 02:16:14 2025 AUC 0.930545725227679
#
# [mbo] 68: num_iterations=2127; learning_rate=0.0285; feature_fraction=0.506; bagging_fraction=0.709; num_leaves=49; min_data_in_leaf=383; max_depth=6; lambda_l1=1.38; lambda_l2=1.68; min_gain_to_split=0.249; drop_rate=0.139; skip_drop=0.332 : y = 0.931 : 60.9 secs : infill_ei
#
# Tue Jul 22 02:17:20 2025 AUC 0.92960512037644
#
# [mbo] 69: num_iterations=2197; learning_rate=0.0632; feature_fraction=0.491; bagging_fraction=0.82; num_leaves=74; min_data_in_leaf=509; max_depth=7; lambda_l1=0.579; lambda_l2=3.13; min_gain_to_split=0.0688; drop_rate=0.221; skip_drop=0.173 : y = 0.93 : 64.0 secs : infill_ei
#
# Tue Jul 22 02:18:01 2025 AUC 0.930472293188152
#
# [mbo] 70: num_iterations=2145; learning_rate=0.0352; feature_fraction=0.611; bagging_fraction=0.829; num_leaves=16; min_data_in_leaf=549; max_depth=11; lambda_l1=2.98; lambda_l2=1.66; min_gain_to_split=0.163; drop_rate=0.202; skip_drop=0.611 : y = 0.93 : 38.4 secs : infill_ei
#
# Tue Jul 22 02:19:03 2025 AUC 0.930672381427124
#
# [mbo] 71: num_iterations=2010; learning_rate=0.0291; feature_fraction=0.503; bagging_fraction=0.665; num_leaves=39; min_data_in_leaf=332; max_depth=6; lambda_l1=0.875; lambda_l2=4.79; min_gain_to_split=0.164; drop_rate=0.274; skip_drop=0.37 : y = 0.931 : 60.3 secs : infill_ei
#
# Tue Jul 22 02:20:08 2025 AUC 0.931185241963383
#
# [mbo] 72: num_iterations=2331; learning_rate=0.0254; feature_fraction=0.404; bagging_fraction=0.639; num_leaves=53; min_data_in_leaf=476; max_depth=7; lambda_l1=0.918; lambda_l2=4.35; min_gain_to_split=0.237; drop_rate=0.331; skip_drop=0.122 : y = 0.931 : 63.0 secs : infill_ei
#
# Tue Jul 22 02:21:21 2025 AUC 0.930338580476162
#
# [mbo] 73: num_iterations=2434; learning_rate=0.0111; feature_fraction=0.501; bagging_fraction=0.586; num_leaves=56; min_data_in_leaf=353; max_depth=7; lambda_l1=4.04; lambda_l2=3.86; min_gain_to_split=0.294; drop_rate=0.486; skip_drop=0.477 : y = 0.93 : 71.0 secs : infill_ei
#
# Tue Jul 22 02:22:51 2025 AUC 0.930292000828393
#
# [mbo] 74: num_iterations=2460; learning_rate=0.0173; feature_fraction=0.461; bagging_fraction=0.569; num_leaves=56; min_data_in_leaf=506; max_depth=7; lambda_l1=0.892; lambda_l2=4.28; min_gain_to_split=0.0724; drop_rate=0.448; skip_drop=0.322 : y = 0.93 : 88.0 secs : infill_ei
#
# Tue Jul 22 02:23:41 2025 AUC 0.929378272022558
#
# [mbo] 75: num_iterations=2068; learning_rate=0.0638; feature_fraction=0.505; bagging_fraction=0.65; num_leaves=45; min_data_in_leaf=367; max_depth=7; lambda_l1=1.32; lambda_l2=3.21; min_gain_to_split=0.549; drop_rate=0.247; skip_drop=0.221 : y = 0.929 : 48.1 secs : infill_ei
#
# Tue Jul 22 02:24:14 2025 AUC 0.930876938587323
#
# [mbo] 76: num_iterations=2332; learning_rate=0.0583; feature_fraction=0.62; bagging_fraction=0.841; num_leaves=26; min_data_in_leaf=573; max_depth=6; lambda_l1=2.72; lambda_l2=1.16; min_gain_to_split=0.27; drop_rate=0.304; skip_drop=0.141 : y = 0.931 : 31.7 secs : infill_ei
#
# Tue Jul 22 02:25:33 2025 AUC 0.931452764246406
#
# [mbo] 77: num_iterations=2743; learning_rate=0.0277; feature_fraction=0.533; bagging_fraction=0.796; num_leaves=46; min_data_in_leaf=626; max_depth=7; lambda_l1=2.51; lambda_l2=3.07; min_gain_to_split=0.0525; drop_rate=0.296; skip_drop=0.311 : y = 0.931 : 76.7 secs : infill_ei
#
# Saved the current state after iteration 78 in the file bayesiana.RDATA.
#
# Tue Jul 22 02:26:44 2025 AUC 0.930968805993657
#
# [mbo] 78: num_iterations=2554; learning_rate=0.0258; feature_fraction=0.523; bagging_fraction=0.835; num_leaves=69; min_data_in_leaf=534; max_depth=7; lambda_l1=2.45; lambda_l2=3.93; min_gain_to_split=0.395; drop_rate=0.219; skip_drop=0.227 : y = 0.931 : 62.8 secs : infill_ei
#
# Tue Jul 22 02:27:58 2025 AUC 0.931194110431094
#
# [mbo] 79: num_iterations=2209; learning_rate=0.0159; feature_fraction=0.488; bagging_fraction=0.811; num_leaves=45; min_data_in_leaf=573; max_depth=6; lambda_l1=2.28; lambda_l2=2.31; min_gain_to_split=0.0413; drop_rate=0.295; skip_drop=0.518 : y = 0.931 : 72.1 secs : infill_ei
#
# Tue Jul 22 02:28:56 2025 AUC 0.931820626601069
#
# [mbo] 80: num_iterations=1999; learning_rate=0.025; feature_fraction=0.507; bagging_fraction=0.644; num_leaves=68; min_data_in_leaf=405; max_depth=7; lambda_l1=1.08; lambda_l2=4.53; min_gain_to_split=0.275; drop_rate=0.366; skip_drop=0.371 : y = 0.932 : 56.0 secs : infill_ei
#
# Tue Jul 22 02:30:04 2025 AUC 0.930610235359672
#
# [mbo] 81: num_iterations=2396; learning_rate=0.0257; feature_fraction=0.468; bagging_fraction=0.649; num_leaves=68; min_data_in_leaf=442; max_depth=7; lambda_l1=4.79; lambda_l2=4.47; min_gain_to_split=0.05; drop_rate=0.246; skip_drop=0.403 : y = 0.931 : 65.8 secs : infill_ei
#
# Tue Jul 22 02:30:40 2025 AUC 0.930357654408895
#
# [mbo] 82: num_iterations=2130; learning_rate=0.0245; feature_fraction=0.651; bagging_fraction=0.632; num_leaves=66; min_data_in_leaf=512; max_depth=8; lambda_l1=0.347; lambda_l2=4.87; min_gain_to_split=0.5; drop_rate=0.211; skip_drop=0.496 : y = 0.93 : 34.2 secs : infill_ei
#
# Tue Jul 22 02:31:36 2025 AUC 0.930428266502514
#
# [mbo] 83: num_iterations=1974; learning_rate=0.027; feature_fraction=0.506; bagging_fraction=0.779; num_leaves=68; min_data_in_leaf=414; max_depth=6; lambda_l1=0.933; lambda_l2=4.47; min_gain_to_split=0.328; drop_rate=0.509; skip_drop=0.579 : y = 0.93 : 53.7 secs : infill_ei
#
# Tue Jul 22 02:32:51 2025 AUC 0.930774178269271
#
# [mbo] 84: num_iterations=2186; learning_rate=0.0256; feature_fraction=0.514; bagging_fraction=0.633; num_leaves=68; min_data_in_leaf=398; max_depth=6; lambda_l1=1.4; lambda_l2=3.18; min_gain_to_split=0.0496; drop_rate=0.238; skip_drop=0.474 : y = 0.931 : 73.1 secs : infill_ei
#
# Tue Jul 22 02:33:57 2025 AUC 0.930311071653233
#
# [mbo] 85: num_iterations=2281; learning_rate=0.0163; feature_fraction=0.51; bagging_fraction=0.643; num_leaves=78; min_data_in_leaf=312; max_depth=8; lambda_l1=0.796; lambda_l2=4.98; min_gain_to_split=0.518; drop_rate=0.545; skip_drop=0.258 : y = 0.93 : 64.0 secs : infill_ei
#
# Tue Jul 22 02:34:29 2025 AUC 0.931189244164669
#
# [mbo] 86: num_iterations=1145; learning_rate=0.0234; feature_fraction=0.427; bagging_fraction=0.742; num_leaves=57; min_data_in_leaf=248; max_depth=6; lambda_l1=1.98; lambda_l2=3.68; min_gain_to_split=0.752; drop_rate=0.241; skip_drop=0.587 : y = 0.931 : 30.2 secs : infill_ei
#
# Tue Jul 22 02:34:55 2025 AUC 0.929658930708664
#
# [mbo] 87: num_iterations=649; learning_rate=0.0253; feature_fraction=0.512; bagging_fraction=0.629; num_leaves=62; min_data_in_leaf=346; max_depth=7; lambda_l1=0.364; lambda_l2=4.3; min_gain_to_split=0.293; drop_rate=0.39; skip_drop=0.429 : y = 0.93 : 23.7 secs : infill_ei
#
# Tue Jul 22 02:36:03 2025 AUC 0.930444315699539
#
# [mbo] 88: num_iterations=2375; learning_rate=0.0248; feature_fraction=0.489; bagging_fraction=0.591; num_leaves=70; min_data_in_leaf=662; max_depth=6; lambda_l1=1.48; lambda_l2=4.39; min_gain_to_split=0.159; drop_rate=0.359; skip_drop=0.577 : y = 0.93 : 66.0 secs : infill_ei
#
# Saved the current state after iteration 89 in the file bayesiana.RDATA.
#
# Tue Jul 22 02:36:42 2025 AUC 0.930833802462061
#
# [mbo] 89: num_iterations=2126; learning_rate=0.0503; feature_fraction=0.611; bagging_fraction=0.839; num_leaves=20; min_data_in_leaf=662; max_depth=6; lambda_l1=4.75; lambda_l2=1.65; min_gain_to_split=0.195; drop_rate=0.12; skip_drop=0.37 : y = 0.931 : 31.4 secs : infill_ei
#
# Tue Jul 22 02:37:26 2025 AUC 0.930105940367563
#
# [mbo] 90: num_iterations=1734; learning_rate=0.0226; feature_fraction=0.506; bagging_fraction=0.867; num_leaves=55; min_data_in_leaf=499; max_depth=6; lambda_l1=4.38; lambda_l2=3.09; min_gain_to_split=0.959; drop_rate=0.371; skip_drop=0.396 : y = 0.93 : 41.5 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "num_iterations"    "learning_rate"     "feature_fraction"
#  [4] "bagging_fraction"  "num_leaves"        "min_data_in_leaf"
#  [7] "max_depth"         "lambda_l1"         "lambda_l2"
# [10] "min_gain_to_split" "drop_rate"         "skip_drop"
# [13] "y"                 "dob"               "eol"
# [16] "error.message"     "exec.time"         "ei"
# [19] "error.model"       "train.time"        "prop.type"
# [22] "propose.time"      "se"                "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    num_iterations learning_rate feature_fraction bagging_fraction num_leaves
#             <int>         <num>            <num>            <num>      <int>
# 1:           2173    0.02476757        0.5035242        0.6451871         51
#    min_data_in_leaf max_depth lambda_l1 lambda_l2 min_gain_to_split drop_rate
#               <int>     <int>     <num>     <num>             <num>     <num>
# 1:              528         7 0.7095149  4.287504         0.0791264 0.1291011
#    skip_drop
#        <num>
# 1: 0.2842489
# [1] 0.9319154

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 100887
#
# $max_depth
# [1] 7
#
# $min_gain_to_split
# [1] 0.0791264
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0.7095149
#
# $lambda_l2
# [1] 4.287504
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 0.6451871
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1291011
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.2842489
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 2173
#
# $learning_rate
# [1] 0.02476757
#
# $feature_fraction
# [1] 0.5035242
#
# $num_leaves
# [1] 51
#
# $min_data_in_leaf
# [1] 528

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Jul 22 02:41:04 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
