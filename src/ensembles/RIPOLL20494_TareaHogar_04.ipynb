# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# Esta Tarea para el Hogar 02 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el viernes 01-agosto

# %% [markdown]
# ##  1. Cazatalentos

# %% [markdown]
# En la Clase 03 nos hemos enfrentado a  "La Maldicion del Ganandor",  elegir el modelo con el mejor puntaje simple no suele ser la mejor estrategia.
# <br> Lea y ejecute el notebook  **src/CazaTalentos/CazaTalentos.ipynb**
# <br> en caso de interesarle, participe del Desafío Ordenamiento  que vence el sábado 02 de agosto a las 19:00

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dm"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dm" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/itba2025-8d0a/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Fri Jul 25 22:22:57 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  656930 35.1 1439374    76.9 1431360  76.5
# Vcells 1224847  9.4 8388608    64.0 1924958  14.7

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 4959
PARAM$semilla_primigenia <- 100887

# %%
PARAM$kaggle$competencia <- "data-mining-analista-sr-2025-a"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
makeNumericParam("learning_rate", lower = 0.01, upper = 0.015),
makeNumericParam("feature_fraction", lower = 0.30, upper = 0.37),
makeNumericParam("bagging_fraction", lower = 0.75, upper = 0.85),
makeIntegerParam("num_leaves", lower = 20L, upper = 35L),
makeIntegerParam("min_data_in_leaf", lower = 700L, upper = 760L),
makeNumericParam("lambda_l2", lower = 0.0, upper = 5.0)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 300 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83368
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Fri Jul 25 22:24:52 2025 AUC 0.930898851520791
#
# Fri Jul 25 22:25:55 2025 AUC 0.930710270179325
#
# Fri Jul 25 22:26:55 2025 AUC 0.930999129573791
#
# Fri Jul 25 22:27:59 2025 AUC 0.931087716911893
#
# Fri Jul 25 22:29:03 2025 AUC 0.930173119105493
#
# Fri Jul 25 22:30:07 2025 AUC 0.931120062321872
#
# Fri Jul 25 22:31:11 2025 AUC 0.931596155425725
#
# Fri Jul 25 22:32:13 2025 AUC 0.930910767581916
#
# Fri Jul 25 22:33:13 2025 AUC 0.930584153790085
#
# Fri Jul 25 22:34:15 2025 AUC 0.9302948218223
#
# Fri Jul 25 22:35:16 2025 AUC 0.931562951862552
#
# Fri Jul 25 22:36:22 2025 AUC 0.930253417470052
#
# Fri Jul 25 22:37:23 2025 AUC 0.930848657972203
#
# Fri Jul 25 22:38:28 2025 AUC 0.93043810416653
#
# Fri Jul 25 22:39:27 2025 AUC 0.930580749132731
#
# Fri Jul 25 22:40:28 2025 AUC 0.931251293036288
#
# Fri Jul 25 22:41:36 2025 AUC 0.9314424565925
#
# Fri Jul 25 22:42:38 2025 AUC 0.931141913548401
#
# Fri Jul 25 22:43:44 2025 AUC 0.930486941748223
#
# Fri Jul 25 22:44:48 2025 AUC 0.930929026260985
#
# Fri Jul 25 22:45:47 2025 AUC 0.930621840793404
#
# Fri Jul 25 22:46:51 2025 AUC 0.930699813920641
#
# Fri Jul 25 22:47:51 2025 AUC 0.930229137618654
#
# Fri Jul 25 22:48:53 2025 AUC 0.93091558278812
#
# [mbo] 0: learning_rate=0.0133; feature_fraction=0.342; bagging_fraction=0.811; num_leaves=24; min_data_in_leaf=710; lambda_l2=1.42 : y = 0.931 : 63.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0122; feature_fraction=0.349; bagging_fraction=0.84; num_leaves=26; min_data_in_leaf=747; lambda_l2=2.87 : y = 0.931 : 63.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0116; feature_fraction=0.345; bagging_fraction=0.794; num_leaves=20; min_data_in_leaf=735; lambda_l2=0.881 : y = 0.931 : 59.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0105; feature_fraction=0.314; bagging_fraction=0.787; num_leaves=32; min_data_in_leaf=755; lambda_l2=3.18 : y = 0.931 : 64.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0139; feature_fraction=0.337; bagging_fraction=0.774; num_leaves=28; min_data_in_leaf=722; lambda_l2=4.13 : y = 0.93 : 64.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0136; feature_fraction=0.321; bagging_fraction=0.818; num_leaves=33; min_data_in_leaf=730; lambda_l2=2.17 : y = 0.931 : 64.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0123; feature_fraction=0.307; bagging_fraction=0.797; num_leaves=34; min_data_in_leaf=734; lambda_l2=0.738 : y = 0.932 : 63.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0129; feature_fraction=0.364; bagging_fraction=0.781; num_leaves=23; min_data_in_leaf=727; lambda_l2=3.89 : y = 0.931 : 62.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0142; feature_fraction=0.32; bagging_fraction=0.769; num_leaves=25; min_data_in_leaf=715; lambda_l2=0.441 : y = 0.931 : 59.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0132; feature_fraction=0.309; bagging_fraction=0.792; num_leaves=30; min_data_in_leaf=744; lambda_l2=3.37 : y = 0.93 : 62.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.01; feature_fraction=0.323; bagging_fraction=0.814; num_leaves=24; min_data_in_leaf=702; lambda_l2=1.68 : y = 0.932 : 60.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0108; feature_fraction=0.354; bagging_fraction=0.75; num_leaves=33; min_data_in_leaf=730; lambda_l2=3.11 : y = 0.93 : 66.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0117; feature_fraction=0.369; bagging_fraction=0.824; num_leaves=20; min_data_in_leaf=705; lambda_l2=3.64 : y = 0.931 : 61.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0126; feature_fraction=0.366; bagging_fraction=0.803; num_leaves=27; min_data_in_leaf=755; lambda_l2=2.04 : y = 0.93 : 64.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0112; feature_fraction=0.302; bagging_fraction=0.755; num_leaves=23; min_data_in_leaf=718; lambda_l2=4.33 : y = 0.931 : 59.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.011; feature_fraction=0.33; bagging_fraction=0.835; num_leaves=26; min_data_in_leaf=749; lambda_l2=0.00152 : y = 0.931 : 60.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0148; feature_fraction=0.361; bagging_fraction=0.762; num_leaves=35; min_data_in_leaf=739; lambda_l2=1.1 : y = 0.931 : 67.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.013; feature_fraction=0.304; bagging_fraction=0.805; num_leaves=30; min_data_in_leaf=701; lambda_l2=1.47 : y = 0.931 : 62.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0145; feature_fraction=0.357; bagging_fraction=0.846; num_leaves=31; min_data_in_leaf=752; lambda_l2=4.67 : y = 0.93 : 65.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0141; feature_fraction=0.352; bagging_fraction=0.847; num_leaves=29; min_data_in_leaf=709; lambda_l2=2.55 : y = 0.931 : 64.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0146; feature_fraction=0.328; bagging_fraction=0.777; num_leaves=21; min_data_in_leaf=741; lambda_l2=2.43 : y = 0.931 : 58.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0103; feature_fraction=0.317; bagging_fraction=0.831; num_leaves=34; min_data_in_leaf=722; lambda_l2=4.41 : y = 0.931 : 63.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0119; feature_fraction=0.333; bagging_fraction=0.828; num_leaves=22; min_data_in_leaf=759; lambda_l2=4.93 : y = 0.93 : 60.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0115; feature_fraction=0.34; bagging_fraction=0.764; num_leaves=28; min_data_in_leaf=715; lambda_l2=0.29 : y = 0.931 : 62.5 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Fri Jul 25 22:50:01 2025 AUC 0.930971378381508
#
# [mbo] 1: learning_rate=0.0109; feature_fraction=0.312; bagging_fraction=0.828; num_leaves=33; min_data_in_leaf=735; lambda_l2=1.12 : y = 0.931 : 63.8 secs : infill_ei
#
# Fri Jul 25 22:51:06 2025 AUC 0.930747897559131
#
# [mbo] 2: learning_rate=0.0133; feature_fraction=0.314; bagging_fraction=0.791; num_leaves=35; min_data_in_leaf=735; lambda_l2=0.695 : y = 0.931 : 64.6 secs : infill_ei
#
# Fri Jul 25 22:52:09 2025 AUC 0.931032673488737
#
# [mbo] 3: learning_rate=0.0113; feature_fraction=0.33; bagging_fraction=0.824; num_leaves=26; min_data_in_leaf=743; lambda_l2=4.81 : y = 0.931 : 62.1 secs : infill_ei
#
# Fri Jul 25 22:53:08 2025 AUC 0.931440904068951
#
# [mbo] 4: learning_rate=0.0149; feature_fraction=0.333; bagging_fraction=0.783; num_leaves=21; min_data_in_leaf=735; lambda_l2=0.983 : y = 0.931 : 57.9 secs : infill_ei
#
# Fri Jul 25 22:54:13 2025 AUC 0.930768642971644
#
# [mbo] 5: learning_rate=0.0123; feature_fraction=0.306; bagging_fraction=0.789; num_leaves=35; min_data_in_leaf=723; lambda_l2=0.528 : y = 0.931 : 64.6 secs : infill_ei
#
# Fri Jul 25 22:55:15 2025 AUC 0.930986532078675
#
# [mbo] 6: learning_rate=0.0113; feature_fraction=0.348; bagging_fraction=0.751; num_leaves=22; min_data_in_leaf=750; lambda_l2=3.55 : y = 0.931 : 61.2 secs : infill_ei
#
# Fri Jul 25 22:56:19 2025 AUC 0.930851819714596
#
# [mbo] 7: learning_rate=0.0125; feature_fraction=0.324; bagging_fraction=0.776; num_leaves=29; min_data_in_leaf=702; lambda_l2=4.77 : y = 0.931 : 63.0 secs : infill_ei
#
# Fri Jul 25 22:57:22 2025 AUC 0.931107185497973
#
# [mbo] 8: learning_rate=0.0148; feature_fraction=0.336; bagging_fraction=0.752; num_leaves=27; min_data_in_leaf=745; lambda_l2=0.964 : y = 0.931 : 62.5 secs : infill_ei
#
# Fri Jul 25 22:58:26 2025 AUC 0.931029419679674
#
# [mbo] 9: learning_rate=0.011; feature_fraction=0.341; bagging_fraction=0.84; num_leaves=28; min_data_in_leaf=759; lambda_l2=1.8 : y = 0.931 : 63.4 secs : infill_ei
#
# Fri Jul 25 22:59:32 2025 AUC 0.931106953448671
#
# [mbo] 10: learning_rate=0.0124; feature_fraction=0.352; bagging_fraction=0.792; num_leaves=33; min_data_in_leaf=732; lambda_l2=0.748 : y = 0.931 : 65.3 secs : infill_ei
#
# Saved the current state after iteration 11 in the file bayesiana.RDATA.
#
# Fri Jul 25 23:00:36 2025 AUC 0.931418300854692
#
# [mbo] 11: learning_rate=0.0149; feature_fraction=0.318; bagging_fraction=0.827; num_leaves=22; min_data_in_leaf=712; lambda_l2=0.779 : y = 0.931 : 59.6 secs : infill_ei
#
# Fri Jul 25 23:01:37 2025 AUC 0.930525321907912
#
# [mbo] 12: learning_rate=0.0147; feature_fraction=0.312; bagging_fraction=0.827; num_leaves=23; min_data_in_leaf=750; lambda_l2=3.59 : y = 0.931 : 59.9 secs : infill_ei
#
# Fri Jul 25 23:02:44 2025 AUC 0.931285651709987
#
# [mbo] 13: learning_rate=0.0102; feature_fraction=0.359; bagging_fraction=0.776; num_leaves=31; min_data_in_leaf=745; lambda_l2=4.78 : y = 0.931 : 66.5 secs : infill_ei
#
# Fri Jul 25 23:03:48 2025 AUC 0.931269879759833
#
# [mbo] 14: learning_rate=0.0131; feature_fraction=0.303; bagging_fraction=0.794; num_leaves=32; min_data_in_leaf=712; lambda_l2=2.82 : y = 0.931 : 63.7 secs : infill_ei
#
# Fri Jul 25 23:04:53 2025 AUC 0.930798343338352
#
# [mbo] 15: learning_rate=0.0134; feature_fraction=0.346; bagging_fraction=0.798; num_leaves=29; min_data_in_leaf=726; lambda_l2=4.89 : y = 0.931 : 63.7 secs : infill_ei
#
# Fri Jul 25 23:05:59 2025 AUC 0.930936298342979
#
# [mbo] 16: learning_rate=0.0105; feature_fraction=0.346; bagging_fraction=0.802; num_leaves=30; min_data_in_leaf=756; lambda_l2=4.73 : y = 0.931 : 65.5 secs : infill_ei
#
# Fri Jul 25 23:07:05 2025 AUC 0.931682607948596
#
# [mbo] 17: learning_rate=0.0114; feature_fraction=0.342; bagging_fraction=0.841; num_leaves=29; min_data_in_leaf=747; lambda_l2=3.72 : y = 0.932 : 64.8 secs : infill_ei
#
# Fri Jul 25 23:08:10 2025 AUC 0.931477594763686
#
# [mbo] 18: learning_rate=0.0109; feature_fraction=0.345; bagging_fraction=0.843; num_leaves=29; min_data_in_leaf=756; lambda_l2=3.68 : y = 0.931 : 64.7 secs : infill_ei
#
# Fri Jul 25 23:09:21 2025 AUC 0.931225629236216
#
# [mbo] 19: learning_rate=0.0122; feature_fraction=0.369; bagging_fraction=0.807; num_leaves=35; min_data_in_leaf=704; lambda_l2=1.79 : y = 0.931 : 69.6 secs : infill_ei
#
# Fri Jul 25 23:10:29 2025 AUC 0.931543500129507
#
# [mbo] 20: learning_rate=0.01; feature_fraction=0.312; bagging_fraction=0.824; num_leaves=35; min_data_in_leaf=710; lambda_l2=4.16 : y = 0.932 : 66.9 secs : infill_ei
#
# Saved the current state after iteration 21 in the file bayesiana.RDATA.
#
# Fri Jul 25 23:11:42 2025 AUC 0.931101229426715
#
# [mbo] 21: learning_rate=0.0139; feature_fraction=0.366; bagging_fraction=0.814; num_leaves=34; min_data_in_leaf=726; lambda_l2=4.64 : y = 0.931 : 69.0 secs : infill_ei
#
# Fri Jul 25 23:12:46 2025 AUC 0.93067077283939
#
# [mbo] 22: learning_rate=0.0122; feature_fraction=0.336; bagging_fraction=0.775; num_leaves=24; min_data_in_leaf=758; lambda_l2=0.754 : y = 0.931 : 63.1 secs : infill_ei
#
# Fri Jul 25 23:13:51 2025 AUC 0.930765162362904
#
# [mbo] 23: learning_rate=0.0133; feature_fraction=0.309; bagging_fraction=0.826; num_leaves=31; min_data_in_leaf=759; lambda_l2=4.45 : y = 0.931 : 64.7 secs : infill_ei
#
# Fri Jul 25 23:14:55 2025 AUC 0.931210726207273
#
# [mbo] 24: learning_rate=0.0143; feature_fraction=0.323; bagging_fraction=0.8; num_leaves=30; min_data_in_leaf=702; lambda_l2=1.27 : y = 0.931 : 63.0 secs : infill_ei
#
# Fri Jul 25 23:15:58 2025 AUC 0.930803961992615
#
# [mbo] 25: learning_rate=0.0101; feature_fraction=0.315; bagging_fraction=0.775; num_leaves=25; min_data_in_leaf=736; lambda_l2=1.27 : y = 0.931 : 62.2 secs : infill_ei
#
# Fri Jul 25 23:17:02 2025 AUC 0.930704510571652
#
# [mbo] 26: learning_rate=0.0145; feature_fraction=0.335; bagging_fraction=0.831; num_leaves=26; min_data_in_leaf=738; lambda_l2=1.13 : y = 0.931 : 62.9 secs : infill_ei
#
# Fri Jul 25 23:18:08 2025 AUC 0.931481998486037
#
# [mbo] 27: learning_rate=0.0103; feature_fraction=0.342; bagging_fraction=0.828; num_leaves=29; min_data_in_leaf=725; lambda_l2=3.83 : y = 0.931 : 65.4 secs : infill_ei
#
# Fri Jul 25 23:19:11 2025 AUC 0.931561009053346
#
# [mbo] 28: learning_rate=0.0108; feature_fraction=0.362; bagging_fraction=0.803; num_leaves=21; min_data_in_leaf=733; lambda_l2=0.532 : y = 0.932 : 61.8 secs : infill_ei
#
# Fri Jul 25 23:20:17 2025 AUC 0.931169311792408
#
# [mbo] 29: learning_rate=0.0108; feature_fraction=0.345; bagging_fraction=0.761; num_leaves=29; min_data_in_leaf=704; lambda_l2=0.729 : y = 0.931 : 65.0 secs : infill_ei
#
# Fri Jul 25 23:21:23 2025 AUC 0.93028767611202
#
# [mbo] 30: learning_rate=0.0119; feature_fraction=0.336; bagging_fraction=0.847; num_leaves=29; min_data_in_leaf=731; lambda_l2=3.79 : y = 0.93 : 64.9 secs : infill_ei
#
# Saved the current state after iteration 31 in the file bayesiana.RDATA.
#
# Fri Jul 25 23:22:31 2025 AUC 0.931524897193925
#
# [mbo] 31: learning_rate=0.0111; feature_fraction=0.328; bagging_fraction=0.773; num_leaves=27; min_data_in_leaf=747; lambda_l2=1.72 : y = 0.932 : 63.8 secs : infill_ei
#
# Fri Jul 25 23:23:35 2025 AUC 0.930599108389917
#
# [mbo] 32: learning_rate=0.0144; feature_fraction=0.312; bagging_fraction=0.801; num_leaves=28; min_data_in_leaf=735; lambda_l2=0.799 : y = 0.931 : 63.1 secs : infill_ei
#
# Fri Jul 25 23:24:37 2025 AUC 0.930384275265674
#
# [mbo] 33: learning_rate=0.0108; feature_fraction=0.346; bagging_fraction=0.795; num_leaves=22; min_data_in_leaf=722; lambda_l2=0.0654 : y = 0.93 : 61.4 secs : infill_ei
#
# Fri Jul 25 23:25:38 2025 AUC 0.931012605072048
#
# [mbo] 34: learning_rate=0.0102; feature_fraction=0.345; bagging_fraction=0.792; num_leaves=22; min_data_in_leaf=702; lambda_l2=1.03 : y = 0.931 : 60.0 secs : infill_ei
#
# Fri Jul 25 23:26:42 2025 AUC 0.930831171032692
#
# [mbo] 35: learning_rate=0.013; feature_fraction=0.327; bagging_fraction=0.849; num_leaves=30; min_data_in_leaf=706; lambda_l2=1.18 : y = 0.931 : 63.5 secs : infill_ei
#
# Fri Jul 25 23:27:48 2025 AUC 0.93109510123996
#
# [mbo] 36: learning_rate=0.0122; feature_fraction=0.341; bagging_fraction=0.842; num_leaves=29; min_data_in_leaf=749; lambda_l2=3.7 : y = 0.931 : 64.6 secs : infill_ei
#
# Fri Jul 25 23:28:53 2025 AUC 0.930596703949538
#
# [mbo] 37: learning_rate=0.0134; feature_fraction=0.35; bagging_fraction=0.816; num_leaves=27; min_data_in_leaf=703; lambda_l2=3.62 : y = 0.931 : 63.8 secs : infill_ei
#
# Fri Jul 25 23:29:55 2025 AUC 0.930742224086397
#
# [mbo] 38: learning_rate=0.015; feature_fraction=0.333; bagging_fraction=0.775; num_leaves=28; min_data_in_leaf=729; lambda_l2=0.892 : y = 0.931 : 61.5 secs : infill_ei
#
# Fri Jul 25 23:31:01 2025 AUC 0.931077076916732
#
# [mbo] 39: learning_rate=0.0117; feature_fraction=0.369; bagging_fraction=0.83; num_leaves=28; min_data_in_leaf=738; lambda_l2=0.148 : y = 0.931 : 64.8 secs : infill_ei
#
# Fri Jul 25 23:32:00 2025 AUC 0.930849844060478
#
# [mbo] 40: learning_rate=0.0124; feature_fraction=0.308; bagging_fraction=0.833; num_leaves=20; min_data_in_leaf=727; lambda_l2=0.156 : y = 0.931 : 58.3 secs : infill_ei
#
# Saved the current state after iteration 41 in the file bayesiana.RDATA.
#
# Fri Jul 25 23:33:08 2025 AUC 0.931599811215431
#
# [mbo] 41: learning_rate=0.0148; feature_fraction=0.322; bagging_fraction=0.773; num_leaves=33; min_data_in_leaf=737; lambda_l2=0.355 : y = 0.932 : 64.5 secs : infill_ei
#
# Fri Jul 25 23:34:09 2025 AUC 0.93150345161982
#
# [mbo] 42: learning_rate=0.0101; feature_fraction=0.324; bagging_fraction=0.762; num_leaves=21; min_data_in_leaf=705; lambda_l2=3.47 : y = 0.932 : 59.6 secs : infill_ei
#
# Fri Jul 25 23:35:10 2025 AUC 0.931498755800742
#
# [mbo] 43: learning_rate=0.0141; feature_fraction=0.352; bagging_fraction=0.776; num_leaves=21; min_data_in_leaf=704; lambda_l2=1.26 : y = 0.931 : 60.3 secs : infill_ei
#
# Fri Jul 25 23:36:16 2025 AUC 0.931509036686295
#
# [mbo] 44: learning_rate=0.0107; feature_fraction=0.341; bagging_fraction=0.841; num_leaves=30; min_data_in_leaf=748; lambda_l2=4.19 : y = 0.932 : 64.4 secs : infill_ei
#
# Fri Jul 25 23:37:18 2025 AUC 0.930674082516112
#
# [mbo] 45: learning_rate=0.0132; feature_fraction=0.369; bagging_fraction=0.798; num_leaves=21; min_data_in_leaf=755; lambda_l2=2.73 : y = 0.931 : 61.6 secs : infill_ei
#
# Fri Jul 25 23:38:22 2025 AUC 0.93106892470389
#
# [mbo] 46: learning_rate=0.0107; feature_fraction=0.342; bagging_fraction=0.832; num_leaves=28; min_data_in_leaf=743; lambda_l2=4.06 : y = 0.931 : 63.0 secs : infill_ei
#
# Fri Jul 25 23:39:30 2025 AUC 0.931727935488415
#
# [mbo] 47: learning_rate=0.0116; feature_fraction=0.354; bagging_fraction=0.809; num_leaves=34; min_data_in_leaf=726; lambda_l2=4.3 : y = 0.932 : 67.2 secs : infill_ei
#
# Fri Jul 25 23:40:35 2025 AUC 0.930703242227037
#
# [mbo] 48: learning_rate=0.0118; feature_fraction=0.304; bagging_fraction=0.781; num_leaves=32; min_data_in_leaf=758; lambda_l2=2.4 : y = 0.931 : 63.7 secs : infill_ei
#
# Fri Jul 25 23:41:38 2025 AUC 0.930442276241994
#
# [mbo] 49: learning_rate=0.0134; feature_fraction=0.309; bagging_fraction=0.799; num_leaves=25; min_data_in_leaf=741; lambda_l2=4.99 : y = 0.93 : 62.0 secs : infill_ei
#
# Fri Jul 25 23:42:44 2025 AUC 0.930835940807042
#
# [mbo] 50: learning_rate=0.0134; feature_fraction=0.33; bagging_fraction=0.841; num_leaves=29; min_data_in_leaf=748; lambda_l2=3.86 : y = 0.931 : 65.0 secs : infill_ei
#
# Saved the current state after iteration 51 in the file bayesiana.RDATA.
#
# Fri Jul 25 23:43:50 2025 AUC 0.931778219230994
#
# [mbo] 51: learning_rate=0.0144; feature_fraction=0.357; bagging_fraction=0.832; num_leaves=21; min_data_in_leaf=754; lambda_l2=0.739 : y = 0.932 : 60.6 secs : infill_ei
#
# Fri Jul 25 23:44:53 2025 AUC 0.93111759798955
#
# [mbo] 52: learning_rate=0.0147; feature_fraction=0.369; bagging_fraction=0.818; num_leaves=23; min_data_in_leaf=715; lambda_l2=2.5 : y = 0.931 : 62.5 secs : infill_ei
#
# Fri Jul 25 23:45:59 2025 AUC 0.930888538077919
#
# [mbo] 53: learning_rate=0.0109; feature_fraction=0.36; bagging_fraction=0.841; num_leaves=29; min_data_in_leaf=752; lambda_l2=3.84 : y = 0.931 : 65.1 secs : infill_ei
#
# Fri Jul 25 23:47:05 2025 AUC 0.930540479086816
#
# [mbo] 54: learning_rate=0.0121; feature_fraction=0.327; bagging_fraction=0.799; num_leaves=35; min_data_in_leaf=751; lambda_l2=3.24 : y = 0.931 : 65.0 secs : infill_ei
#
# Fri Jul 25 23:48:10 2025 AUC 0.930886606432074
#
# [mbo] 55: learning_rate=0.0104; feature_fraction=0.34; bagging_fraction=0.818; num_leaves=25; min_data_in_leaf=759; lambda_l2=2.46 : y = 0.931 : 63.9 secs : infill_ei
#
# Fri Jul 25 23:49:14 2025 AUC 0.931234633009578
#
# [mbo] 56: learning_rate=0.0131; feature_fraction=0.312; bagging_fraction=0.817; num_leaves=34; min_data_in_leaf=723; lambda_l2=0.0718 : y = 0.931 : 63.3 secs : infill_ei
#
# Fri Jul 25 23:50:19 2025 AUC 0.931130570843423
#
# [mbo] 57: learning_rate=0.012; feature_fraction=0.345; bagging_fraction=0.839; num_leaves=28; min_data_in_leaf=716; lambda_l2=2.51 : y = 0.931 : 64.0 secs : infill_ei
#
# Fri Jul 25 23:51:23 2025 AUC 0.931287991513018
#
# [mbo] 58: learning_rate=0.0118; feature_fraction=0.325; bagging_fraction=0.827; num_leaves=28; min_data_in_leaf=707; lambda_l2=2.56 : y = 0.931 : 62.9 secs : infill_ei
#
# Fri Jul 25 23:52:26 2025 AUC 0.930277998915775
#
# [mbo] 59: learning_rate=0.0117; feature_fraction=0.355; bagging_fraction=0.753; num_leaves=22; min_data_in_leaf=754; lambda_l2=3.24 : y = 0.93 : 61.8 secs : infill_ei
#
# Fri Jul 25 23:53:32 2025 AUC 0.931411173230554
#
# [mbo] 60: learning_rate=0.0137; feature_fraction=0.333; bagging_fraction=0.822; num_leaves=30; min_data_in_leaf=749; lambda_l2=4.87 : y = 0.931 : 64.9 secs : infill_ei
#
# Saved the current state after iteration 61 in the file bayesiana.RDATA.
#
# Fri Jul 25 23:54:42 2025 AUC 0.930858363384949
#
# [mbo] 61: learning_rate=0.0104; feature_fraction=0.302; bagging_fraction=0.831; num_leaves=35; min_data_in_leaf=713; lambda_l2=3.82 : y = 0.931 : 64.0 secs : infill_ei
#
# Fri Jul 25 23:55:48 2025 AUC 0.93093089678738
#
# [mbo] 62: learning_rate=0.0112; feature_fraction=0.35; bagging_fraction=0.781; num_leaves=29; min_data_in_leaf=749; lambda_l2=3.71 : y = 0.931 : 64.9 secs : infill_ei
#
# Fri Jul 25 23:56:52 2025 AUC 0.93028002178813
#
# [mbo] 63: learning_rate=0.0126; feature_fraction=0.333; bagging_fraction=0.848; num_leaves=27; min_data_in_leaf=706; lambda_l2=4.13 : y = 0.93 : 63.1 secs : infill_ei
#
# Fri Jul 25 23:57:56 2025 AUC 0.930904489980611
#
# [mbo] 64: learning_rate=0.0116; feature_fraction=0.337; bagging_fraction=0.751; num_leaves=24; min_data_in_leaf=751; lambda_l2=4.8 : y = 0.931 : 62.2 secs : infill_ei
#
# Fri Jul 25 23:59:05 2025 AUC 0.930914792918567
#
# [mbo] 65: learning_rate=0.0102; feature_fraction=0.37; bagging_fraction=0.782; num_leaves=33; min_data_in_leaf=738; lambda_l2=4.56 : y = 0.931 : 68.5 secs : infill_ei
#
# Sat Jul 26 00:00:08 2025 AUC 0.931591948682175
#
# [mbo] 66: learning_rate=0.0123; feature_fraction=0.322; bagging_fraction=0.845; num_leaves=25; min_data_in_leaf=701; lambda_l2=0.127 : y = 0.932 : 62.4 secs : infill_ei
#
# Sat Jul 26 00:01:11 2025 AUC 0.931364182558257
#
# [mbo] 67: learning_rate=0.0146; feature_fraction=0.367; bagging_fraction=0.839; num_leaves=20; min_data_in_leaf=744; lambda_l2=4.31 : y = 0.931 : 61.8 secs : infill_ei
#
# Sat Jul 26 00:02:11 2025 AUC 0.930557852453831
#
# [mbo] 68: learning_rate=0.0119; feature_fraction=0.309; bagging_fraction=0.759; num_leaves=20; min_data_in_leaf=708; lambda_l2=2.59 : y = 0.931 : 58.8 secs : infill_ei
#
# Sat Jul 26 00:03:10 2025 AUC 0.929773851544462
#
# [mbo] 69: learning_rate=0.0147; feature_fraction=0.325; bagging_fraction=0.784; num_leaves=20; min_data_in_leaf=742; lambda_l2=4.1 : y = 0.93 : 58.0 secs : infill_ei
#
# Sat Jul 26 00:04:12 2025 AUC 0.931218488726364
#
# [mbo] 70: learning_rate=0.0133; feature_fraction=0.332; bagging_fraction=0.78; num_leaves=23; min_data_in_leaf=710; lambda_l2=1.42 : y = 0.931 : 60.8 secs : infill_ei
#
# Saved the current state after iteration 71 in the file bayesiana.RDATA.
#
# Sat Jul 26 00:05:17 2025 AUC 0.931671460579376
#
# [mbo] 71: learning_rate=0.0138; feature_fraction=0.355; bagging_fraction=0.82; num_leaves=22; min_data_in_leaf=742; lambda_l2=1.31 : y = 0.932 : 61.1 secs : infill_ei
#
# Sat Jul 26 00:06:25 2025 AUC 0.931103610964204
#
# [mbo] 72: learning_rate=0.0141; feature_fraction=0.361; bagging_fraction=0.765; num_leaves=34; min_data_in_leaf=740; lambda_l2=1.39 : y = 0.931 : 66.8 secs : infill_ei
#
# Sat Jul 26 00:07:33 2025 AUC 0.930531122288709
#
# [mbo] 73: learning_rate=0.0144; feature_fraction=0.363; bagging_fraction=0.833; num_leaves=31; min_data_in_leaf=731; lambda_l2=2.48 : y = 0.931 : 66.6 secs : infill_ei
#
# Sat Jul 26 00:08:36 2025 AUC 0.930493322699829
#
# [mbo] 74: learning_rate=0.0123; feature_fraction=0.323; bagging_fraction=0.833; num_leaves=24; min_data_in_leaf=702; lambda_l2=1.39 : y = 0.93 : 61.5 secs : infill_ei
#
# Sat Jul 26 00:09:42 2025 AUC 0.930919554053566
#
# [mbo] 75: learning_rate=0.0138; feature_fraction=0.349; bagging_fraction=0.792; num_leaves=30; min_data_in_leaf=712; lambda_l2=1.02 : y = 0.931 : 65.5 secs : infill_ei
#
# Sat Jul 26 00:10:43 2025 AUC 0.931317987749313
#
# [mbo] 76: learning_rate=0.0128; feature_fraction=0.309; bagging_fraction=0.832; num_leaves=23; min_data_in_leaf=716; lambda_l2=1.54 : y = 0.931 : 59.8 secs : infill_ei
#
# Sat Jul 26 00:11:46 2025 AUC 0.930662859233584
#
# [mbo] 77: learning_rate=0.0141; feature_fraction=0.364; bagging_fraction=0.825; num_leaves=22; min_data_in_leaf=704; lambda_l2=1.18 : y = 0.931 : 61.9 secs : infill_ei
#
# Sat Jul 26 00:12:48 2025 AUC 0.930870843062311
#
# [mbo] 78: learning_rate=0.0142; feature_fraction=0.347; bagging_fraction=0.832; num_leaves=22; min_data_in_leaf=754; lambda_l2=0.047 : y = 0.931 : 60.4 secs : infill_ei
#
# Sat Jul 26 00:13:53 2025 AUC 0.930769755274591
#
# [mbo] 79: learning_rate=0.0102; feature_fraction=0.352; bagging_fraction=0.841; num_leaves=28; min_data_in_leaf=727; lambda_l2=0.357 : y = 0.931 : 63.9 secs : infill_ei
#
# Sat Jul 26 00:14:59 2025 AUC 0.931093902307352
#
# [mbo] 80: learning_rate=0.0106; feature_fraction=0.317; bagging_fraction=0.763; num_leaves=33; min_data_in_leaf=733; lambda_l2=1.69 : y = 0.931 : 65.1 secs : infill_ei
#
# Saved the current state after iteration 81 in the file bayesiana.RDATA.
#
# Sat Jul 26 00:16:05 2025 AUC 0.930583746071565
#
# [mbo] 81: learning_rate=0.0132; feature_fraction=0.355; bagging_fraction=0.826; num_leaves=23; min_data_in_leaf=755; lambda_l2=1.35 : y = 0.931 : 62.0 secs : infill_ei
#
# Sat Jul 26 00:17:09 2025 AUC 0.93080412987452
#
# [mbo] 82: learning_rate=0.0133; feature_fraction=0.334; bagging_fraction=0.759; num_leaves=28; min_data_in_leaf=735; lambda_l2=1.88 : y = 0.931 : 63.1 secs : infill_ei
#
# Sat Jul 26 00:18:13 2025 AUC 0.930678021792954
#
# [mbo] 83: learning_rate=0.0126; feature_fraction=0.33; bagging_fraction=0.791; num_leaves=30; min_data_in_leaf=756; lambda_l2=3.17 : y = 0.931 : 63.1 secs : infill_ei
#
# Sat Jul 26 00:19:16 2025 AUC 0.931260280292355
#
# [mbo] 84: learning_rate=0.0143; feature_fraction=0.322; bagging_fraction=0.793; num_leaves=25; min_data_in_leaf=738; lambda_l2=3.74 : y = 0.931 : 61.7 secs : infill_ei
#
# Sat Jul 26 00:20:17 2025 AUC 0.93107542029374
#
# [mbo] 85: learning_rate=0.0139; feature_fraction=0.308; bagging_fraction=0.804; num_leaves=22; min_data_in_leaf=711; lambda_l2=2.75 : y = 0.931 : 59.5 secs : infill_ei
#
# Sat Jul 26 00:21:23 2025 AUC 0.93050879906456
#
# [mbo] 86: learning_rate=0.0126; feature_fraction=0.332; bagging_fraction=0.775; num_leaves=31; min_data_in_leaf=715; lambda_l2=3.86 : y = 0.931 : 65.0 secs : infill_ei
#
# Sat Jul 26 00:22:30 2025 AUC 0.930291861659376
#
# [mbo] 87: learning_rate=0.0145; feature_fraction=0.334; bagging_fraction=0.811; num_leaves=35; min_data_in_leaf=726; lambda_l2=1.4 : y = 0.93 : 66.4 secs : infill_ei
#
# Sat Jul 26 00:23:36 2025 AUC 0.930986598579677
#
# [mbo] 88: learning_rate=0.0105; feature_fraction=0.322; bagging_fraction=0.767; num_leaves=32; min_data_in_leaf=720; lambda_l2=2.42 : y = 0.931 : 64.1 secs : infill_ei
#
# Sat Jul 26 00:24:38 2025 AUC 0.93043724685663
#
# [mbo] 89: learning_rate=0.0148; feature_fraction=0.357; bagging_fraction=0.786; num_leaves=22; min_data_in_leaf=711; lambda_l2=0.739 : y = 0.93 : 61.1 secs : infill_ei
#
# Sat Jul 26 00:25:39 2025 AUC 0.931294624876015
#
# [mbo] 90: learning_rate=0.0124; feature_fraction=0.308; bagging_fraction=0.833; num_leaves=20; min_data_in_leaf=714; lambda_l2=4.82 : y = 0.931 : 59.5 secs : infill_ei
#
# Saved the current state after iteration 91 in the file bayesiana.RDATA.
#
# Sat Jul 26 00:26:45 2025 AUC 0.931107383959773
#
# [mbo] 91: learning_rate=0.0145; feature_fraction=0.347; bagging_fraction=0.758; num_leaves=23; min_data_in_leaf=730; lambda_l2=1.56 : y = 0.931 : 61.8 secs : infill_ei
#
# Sat Jul 26 00:27:51 2025 AUC 0.931629356238672
#
# [mbo] 92: learning_rate=0.0106; feature_fraction=0.335; bagging_fraction=0.776; num_leaves=28; min_data_in_leaf=737; lambda_l2=4.75 : y = 0.932 : 64.3 secs : infill_ei
#
# Sat Jul 26 00:28:52 2025 AUC 0.930738670806864
#
# [mbo] 93: learning_rate=0.0121; feature_fraction=0.324; bagging_fraction=0.784; num_leaves=21; min_data_in_leaf=733; lambda_l2=2.69 : y = 0.931 : 60.3 secs : infill_ei
#
# Sat Jul 26 00:29:59 2025 AUC 0.930562621559539
#
# [mbo] 94: learning_rate=0.012; feature_fraction=0.347; bagging_fraction=0.772; num_leaves=28; min_data_in_leaf=730; lambda_l2=1.55 : y = 0.931 : 65.9 secs : infill_ei
#
# Sat Jul 26 00:31:04 2025 AUC 0.930783465615354
#
# [mbo] 95: learning_rate=0.0116; feature_fraction=0.324; bagging_fraction=0.774; num_leaves=27; min_data_in_leaf=703; lambda_l2=3.97 : y = 0.931 : 64.0 secs : infill_ei
#
# Sat Jul 26 00:32:10 2025 AUC 0.93110603713973
#
# [mbo] 96: learning_rate=0.011; feature_fraction=0.36; bagging_fraction=0.769; num_leaves=28; min_data_in_leaf=719; lambda_l2=2.8 : y = 0.931 : 64.6 secs : infill_ei
#
# Sat Jul 26 00:33:13 2025 AUC 0.930873980769545
#
# [mbo] 97: learning_rate=0.012; feature_fraction=0.366; bagging_fraction=0.803; num_leaves=24; min_data_in_leaf=756; lambda_l2=1.27 : y = 0.931 : 61.9 secs : infill_ei
#
# Sat Jul 26 00:34:15 2025 AUC 0.931103659816131
#
# [mbo] 98: learning_rate=0.0131; feature_fraction=0.314; bagging_fraction=0.755; num_leaves=25; min_data_in_leaf=754; lambda_l2=1.71 : y = 0.931 : 61.1 secs : infill_ei
#
# Sat Jul 26 00:35:20 2025 AUC 0.930390198959771
#
# [mbo] 99: learning_rate=0.011; feature_fraction=0.342; bagging_fraction=0.794; num_leaves=28; min_data_in_leaf=733; lambda_l2=0.41 : y = 0.93 : 63.7 secs : infill_ei
#
# Sat Jul 26 00:36:28 2025 AUC 0.930882277771473
#
# [mbo] 100: learning_rate=0.0112; feature_fraction=0.342; bagging_fraction=0.775; num_leaves=34; min_data_in_leaf=742; lambda_l2=2.76 : y = 0.931 : 66.9 secs : infill_ei
#
# Saved the current state after iteration 101 in the file bayesiana.RDATA.
#
# Sat Jul 26 00:37:37 2025 AUC 0.93039183002428
#
# [mbo] 101: learning_rate=0.0147; feature_fraction=0.319; bagging_fraction=0.793; num_leaves=29; min_data_in_leaf=703; lambda_l2=4.96 : y = 0.93 : 63.5 secs : infill_ei
#
# Sat Jul 26 00:38:40 2025 AUC 0.931597871357762
#
# [mbo] 102: learning_rate=0.0147; feature_fraction=0.359; bagging_fraction=0.76; num_leaves=24; min_data_in_leaf=751; lambda_l2=1.38 : y = 0.932 : 61.0 secs : infill_ei
#
# Sat Jul 26 00:39:42 2025 AUC 0.931009178452266
#
# [mbo] 103: learning_rate=0.0114; feature_fraction=0.343; bagging_fraction=0.775; num_leaves=22; min_data_in_leaf=736; lambda_l2=2.36 : y = 0.931 : 61.6 secs : infill_ei
#
# Sat Jul 26 00:40:45 2025 AUC 0.931514487002702
#
# [mbo] 104: learning_rate=0.0107; feature_fraction=0.337; bagging_fraction=0.783; num_leaves=23; min_data_in_leaf=711; lambda_l2=3.24 : y = 0.932 : 61.3 secs : infill_ei
#
# Sat Jul 26 00:41:47 2025 AUC 0.930844175077145
#
# [mbo] 105: learning_rate=0.0117; feature_fraction=0.346; bagging_fraction=0.848; num_leaves=22; min_data_in_leaf=735; lambda_l2=0.784 : y = 0.931 : 60.7 secs : infill_ei
#
# Sat Jul 26 00:42:54 2025 AUC 0.930279413730763
#
# [mbo] 106: learning_rate=0.0136; feature_fraction=0.365; bagging_fraction=0.801; num_leaves=31; min_data_in_leaf=749; lambda_l2=2.77 : y = 0.93 : 65.9 secs : infill_ei
#
# Sat Jul 26 00:43:54 2025 AUC 0.930753186576425
#
# [mbo] 107: learning_rate=0.0106; feature_fraction=0.307; bagging_fraction=0.799; num_leaves=21; min_data_in_leaf=744; lambda_l2=3.79 : y = 0.931 : 59.3 secs : infill_ei
#
# Sat Jul 26 00:44:58 2025 AUC 0.931211812886321
#
# [mbo] 108: learning_rate=0.0109; feature_fraction=0.317; bagging_fraction=0.786; num_leaves=28; min_data_in_leaf=723; lambda_l2=0.242 : y = 0.931 : 62.4 secs : infill_ei
#
# Sat Jul 26 00:46:02 2025 AUC 0.931677017745466
#
# [mbo] 109: learning_rate=0.0115; feature_fraction=0.354; bagging_fraction=0.776; num_leaves=25; min_data_in_leaf=757; lambda_l2=1.48 : y = 0.932 : 63.3 secs : infill_ei
#
# Sat Jul 26 00:47:04 2025 AUC 0.930935042267343
#
# [mbo] 110: learning_rate=0.0106; feature_fraction=0.314; bagging_fraction=0.774; num_leaves=26; min_data_in_leaf=736; lambda_l2=3.12 : y = 0.931 : 60.6 secs : infill_ei
#
# Saved the current state after iteration 111 in the file bayesiana.RDATA.
#
# Sat Jul 26 00:48:13 2025 AUC 0.930587648172755
#
# [mbo] 111: learning_rate=0.0116; feature_fraction=0.352; bagging_fraction=0.776; num_leaves=28; min_data_in_leaf=714; lambda_l2=1.67 : y = 0.931 : 63.8 secs : infill_ei
#
# Sat Jul 26 00:49:20 2025 AUC 0.930626260138392
#
# [mbo] 112: learning_rate=0.0143; feature_fraction=0.343; bagging_fraction=0.809; num_leaves=32; min_data_in_leaf=721; lambda_l2=2.37 : y = 0.931 : 65.3 secs : infill_ei
#
# Sat Jul 26 00:50:24 2025 AUC 0.931304212170308
#
# [mbo] 113: learning_rate=0.0121; feature_fraction=0.357; bagging_fraction=0.827; num_leaves=26; min_data_in_leaf=724; lambda_l2=2.7 : y = 0.931 : 63.4 secs : infill_ei
#
# Sat Jul 26 00:51:31 2025 AUC 0.931380040387904
#
# [mbo] 114: learning_rate=0.0113; feature_fraction=0.326; bagging_fraction=0.795; num_leaves=34; min_data_in_leaf=749; lambda_l2=3.54 : y = 0.931 : 65.2 secs : infill_ei
#
# Sat Jul 26 00:52:38 2025 AUC 0.930274101101267
#
# [mbo] 115: learning_rate=0.0129; feature_fraction=0.342; bagging_fraction=0.839; num_leaves=33; min_data_in_leaf=739; lambda_l2=3.27 : y = 0.93 : 66.2 secs : infill_ei
#
# Sat Jul 26 00:53:46 2025 AUC 0.931210815120487
#
# [mbo] 116: learning_rate=0.0134; feature_fraction=0.363; bagging_fraction=0.798; num_leaves=33; min_data_in_leaf=725; lambda_l2=3.72 : y = 0.931 : 66.1 secs : infill_ei
#
# Sat Jul 26 00:54:49 2025 AUC 0.931334347085298
#
# [mbo] 117: learning_rate=0.0133; feature_fraction=0.314; bagging_fraction=0.833; num_leaves=26; min_data_in_leaf=739; lambda_l2=4.37 : y = 0.931 : 62.1 secs : infill_ei
#
# Sat Jul 26 00:55:54 2025 AUC 0.930664985061533
#
# [mbo] 118: learning_rate=0.0104; feature_fraction=0.347; bagging_fraction=0.815; num_leaves=26; min_data_in_leaf=738; lambda_l2=4.83 : y = 0.931 : 63.4 secs : infill_ei
#
# Sat Jul 26 00:56:58 2025 AUC 0.930882050791997
#
# [mbo] 119: learning_rate=0.0148; feature_fraction=0.323; bagging_fraction=0.841; num_leaves=31; min_data_in_leaf=721; lambda_l2=0.376 : y = 0.931 : 62.8 secs : infill_ei
#
# Sat Jul 26 00:57:59 2025 AUC 0.931909352692012
#
# [mbo] 120: learning_rate=0.013; feature_fraction=0.335; bagging_fraction=0.829; num_leaves=20; min_data_in_leaf=732; lambda_l2=4.93 : y = 0.932 : 59.9 secs : infill_ei
#
# Saved the current state after iteration 121 in the file bayesiana.RDATA.
#
# Sat Jul 26 00:59:03 2025 AUC 0.931404260024903
#
# [mbo] 121: learning_rate=0.013; feature_fraction=0.309; bagging_fraction=0.828; num_leaves=21; min_data_in_leaf=730; lambda_l2=2.99 : y = 0.931 : 59.2 secs : infill_ei
#
# Sat Jul 26 01:00:09 2025 AUC 0.931208703009212
#
# [mbo] 122: learning_rate=0.0129; feature_fraction=0.343; bagging_fraction=0.763; num_leaves=28; min_data_in_leaf=718; lambda_l2=3.7 : y = 0.931 : 64.4 secs : infill_ei
#
# Sat Jul 26 01:01:10 2025 AUC 0.931153081270803
#
# [mbo] 123: learning_rate=0.0142; feature_fraction=0.344; bagging_fraction=0.812; num_leaves=20; min_data_in_leaf=731; lambda_l2=0.72 : y = 0.931 : 59.7 secs : infill_ei
#
# Sat Jul 26 01:02:12 2025 AUC 0.931765713773406
#
# [mbo] 124: learning_rate=0.0114; feature_fraction=0.311; bagging_fraction=0.766; num_leaves=24; min_data_in_leaf=749; lambda_l2=1.54 : y = 0.932 : 60.4 secs : infill_ei
#
# Sat Jul 26 01:03:16 2025 AUC 0.931118284964222
#
# [mbo] 125: learning_rate=0.0114; feature_fraction=0.325; bagging_fraction=0.818; num_leaves=30; min_data_in_leaf=728; lambda_l2=2.36 : y = 0.931 : 63.4 secs : infill_ei
#
# Sat Jul 26 01:04:19 2025 AUC 0.931369939564712
#
# [mbo] 126: learning_rate=0.0122; feature_fraction=0.307; bagging_fraction=0.848; num_leaves=26; min_data_in_leaf=755; lambda_l2=1.81 : y = 0.931 : 62.0 secs : infill_ei
#
# Sat Jul 26 01:05:21 2025 AUC 0.930163100769986
#
# [mbo] 127: learning_rate=0.0143; feature_fraction=0.323; bagging_fraction=0.752; num_leaves=22; min_data_in_leaf=736; lambda_l2=0.215 : y = 0.93 : 60.3 secs : infill_ei
#
# Sat Jul 26 01:06:27 2025 AUC 0.930363753380249
#
# [mbo] 128: learning_rate=0.0103; feature_fraction=0.359; bagging_fraction=0.773; num_leaves=27; min_data_in_leaf=760; lambda_l2=0.631 : y = 0.93 : 64.2 secs : infill_ei
#
# Sat Jul 26 01:07:35 2025 AUC 0.930413391928318
#
# [mbo] 129: learning_rate=0.0102; feature_fraction=0.338; bagging_fraction=0.84; num_leaves=34; min_data_in_leaf=742; lambda_l2=2.26 : y = 0.93 : 66.7 secs : infill_ei
#
# Sat Jul 26 01:08:39 2025 AUC 0.931037870656865
#
# [mbo] 130: learning_rate=0.0142; feature_fraction=0.348; bagging_fraction=0.784; num_leaves=25; min_data_in_leaf=704; lambda_l2=2.22 : y = 0.931 : 63.3 secs : infill_ei
#
# Saved the current state after iteration 131 in the file bayesiana.RDATA.
#
# Sat Jul 26 01:09:47 2025 AUC 0.931101265681758
#
# [mbo] 131: learning_rate=0.0118; feature_fraction=0.335; bagging_fraction=0.829; num_leaves=26; min_data_in_leaf=719; lambda_l2=2.81 : y = 0.931 : 63.2 secs : infill_ei
#
# Sat Jul 26 01:10:49 2025 AUC 0.931010927891386
#
# [mbo] 132: learning_rate=0.0111; feature_fraction=0.327; bagging_fraction=0.822; num_leaves=21; min_data_in_leaf=741; lambda_l2=4.98 : y = 0.931 : 60.8 secs : infill_ei
#
# Sat Jul 26 01:11:51 2025 AUC 0.931160382060131
#
# [mbo] 133: learning_rate=0.0143; feature_fraction=0.351; bagging_fraction=0.762; num_leaves=22; min_data_in_leaf=706; lambda_l2=3.59 : y = 0.931 : 60.6 secs : infill_ei
#
# Sat Jul 26 01:12:57 2025 AUC 0.932425852057618
#
# [mbo] 134: learning_rate=0.0135; feature_fraction=0.327; bagging_fraction=0.75; num_leaves=32; min_data_in_leaf=756; lambda_l2=0.229 : y = 0.932 : 64.6 secs : infill_ei
#
# Sat Jul 26 01:13:57 2025 AUC 0.931125525416821
#
# [mbo] 135: learning_rate=0.0108; feature_fraction=0.302; bagging_fraction=0.795; num_leaves=20; min_data_in_leaf=711; lambda_l2=0.191 : y = 0.931 : 58.1 secs : infill_ei
#
# Sat Jul 26 01:15:02 2025 AUC 0.930546486995016
#
# [mbo] 136: learning_rate=0.0115; feature_fraction=0.309; bagging_fraction=0.817; num_leaves=32; min_data_in_leaf=714; lambda_l2=2.26 : y = 0.931 : 64.2 secs : infill_ei
#
# Sat Jul 26 01:16:08 2025 AUC 0.931633817386973
#
# [mbo] 137: learning_rate=0.0136; feature_fraction=0.356; bagging_fraction=0.802; num_leaves=29; min_data_in_leaf=724; lambda_l2=1.99 : y = 0.932 : 65.0 secs : infill_ei
#
# Sat Jul 26 01:17:18 2025 AUC 0.930996833923848
#
# [mbo] 138: learning_rate=0.0147; feature_fraction=0.354; bagging_fraction=0.766; num_leaves=35; min_data_in_leaf=702; lambda_l2=3.91 : y = 0.931 : 68.0 secs : infill_ei
#
# Sat Jul 26 01:18:20 2025 AUC 0.930546792849087
#
# [mbo] 139: learning_rate=0.0126; feature_fraction=0.316; bagging_fraction=0.754; num_leaves=25; min_data_in_leaf=704; lambda_l2=0.746 : y = 0.931 : 61.0 secs : infill_ei
#
# Sat Jul 26 01:19:27 2025 AUC 0.93039686792095
#
# [mbo] 140: learning_rate=0.014; feature_fraction=0.345; bagging_fraction=0.765; num_leaves=32; min_data_in_leaf=752; lambda_l2=1.72 : y = 0.93 : 65.6 secs : infill_ei
#
# Saved the current state after iteration 141 in the file bayesiana.RDATA.
#
# Sat Jul 26 01:20:37 2025 AUC 0.930417984572982
#
# [mbo] 141: learning_rate=0.0108; feature_fraction=0.329; bagging_fraction=0.805; num_leaves=35; min_data_in_leaf=757; lambda_l2=0.151 : y = 0.93 : 64.9 secs : infill_ei
#
# Sat Jul 26 01:21:37 2025 AUC 0.931081524277983
#
# [mbo] 142: learning_rate=0.0118; feature_fraction=0.306; bagging_fraction=0.826; num_leaves=21; min_data_in_leaf=721; lambda_l2=0.173 : y = 0.931 : 58.7 secs : infill_ei
#
# Sat Jul 26 01:22:40 2025 AUC 0.930996192732421
#
# [mbo] 143: learning_rate=0.014; feature_fraction=0.308; bagging_fraction=0.826; num_leaves=28; min_data_in_leaf=739; lambda_l2=0.0333 : y = 0.931 : 61.6 secs : infill_ei
#
# Sat Jul 26 01:23:42 2025 AUC 0.930915465013769
#
# [mbo] 144: learning_rate=0.0125; feature_fraction=0.356; bagging_fraction=0.788; num_leaves=21; min_data_in_leaf=743; lambda_l2=0.442 : y = 0.931 : 60.5 secs : infill_ei
#
# Sat Jul 26 01:24:47 2025 AUC 0.931454046542534
#
# [mbo] 145: learning_rate=0.0107; feature_fraction=0.35; bagging_fraction=0.839; num_leaves=27; min_data_in_leaf=733; lambda_l2=4.78 : y = 0.931 : 63.9 secs : infill_ei
#
# Sat Jul 26 01:25:50 2025 AUC 0.930664929949689
#
# [mbo] 146: learning_rate=0.0134; feature_fraction=0.363; bagging_fraction=0.84; num_leaves=22; min_data_in_leaf=701; lambda_l2=4.41 : y = 0.931 : 61.7 secs : infill_ei
#
# Sat Jul 26 01:26:50 2025 AUC 0.9304681979859
#
# [mbo] 147: learning_rate=0.0128; feature_fraction=0.334; bagging_fraction=0.829; num_leaves=20; min_data_in_leaf=742; lambda_l2=2.01 : y = 0.93 : 57.9 secs : infill_ei
#
# Sat Jul 26 01:27:56 2025 AUC 0.930390915419364
#
# [mbo] 148: learning_rate=0.0112; feature_fraction=0.336; bagging_fraction=0.837; num_leaves=34; min_data_in_leaf=703; lambda_l2=0.575 : y = 0.93 : 65.4 secs : infill_ei
#
# Sat Jul 26 01:29:03 2025 AUC 0.930430353466335
#
# [mbo] 149: learning_rate=0.0111; feature_fraction=0.339; bagging_fraction=0.776; num_leaves=33; min_data_in_leaf=750; lambda_l2=0.504 : y = 0.93 : 65.5 secs : infill_ei
#
# Sat Jul 26 01:30:03 2025 AUC 0.930491581238672
#
# [mbo] 150: learning_rate=0.0148; feature_fraction=0.3; bagging_fraction=0.764; num_leaves=21; min_data_in_leaf=744; lambda_l2=1.2 : y = 0.93 : 58.4 secs : infill_ei
#
# Saved the current state after iteration 151 in the file bayesiana.RDATA.
#
# Sat Jul 26 01:31:11 2025 AUC 0.930942483795743
#
# [mbo] 151: learning_rate=0.0102; feature_fraction=0.336; bagging_fraction=0.751; num_leaves=22; min_data_in_leaf=700; lambda_l2=2.13 : y = 0.931 : 60.7 secs : infill_ei
#
# Sat Jul 26 01:32:13 2025 AUC 0.930271085641055
#
# [mbo] 152: learning_rate=0.0106; feature_fraction=0.301; bagging_fraction=0.803; num_leaves=28; min_data_in_leaf=708; lambda_l2=0.714 : y = 0.93 : 61.2 secs : infill_ei
#
# Sat Jul 26 01:33:17 2025 AUC 0.931524270669975
#
# [mbo] 153: learning_rate=0.0122; feature_fraction=0.301; bagging_fraction=0.841; num_leaves=31; min_data_in_leaf=723; lambda_l2=2.21 : y = 0.932 : 62.1 secs : infill_ei
#
# Sat Jul 26 01:34:16 2025 AUC 0.930638705356964
#
# [mbo] 154: learning_rate=0.0141; feature_fraction=0.302; bagging_fraction=0.822; num_leaves=20; min_data_in_leaf=750; lambda_l2=4.68 : y = 0.931 : 58.1 secs : infill_ei
#
# Sat Jul 26 01:35:20 2025 AUC 0.931040696066635
#
# [mbo] 155: learning_rate=0.0114; feature_fraction=0.31; bagging_fraction=0.836; num_leaves=29; min_data_in_leaf=738; lambda_l2=0.0739 : y = 0.931 : 62.8 secs : infill_ei
#
# Sat Jul 26 01:36:26 2025 AUC 0.931361199991781
#
# [mbo] 156: learning_rate=0.0136; feature_fraction=0.356; bagging_fraction=0.805; num_leaves=29; min_data_in_leaf=752; lambda_l2=0.542 : y = 0.931 : 64.5 secs : infill_ei
#
# Sat Jul 26 01:37:35 2025 AUC 0.930915554323833
#
# [mbo] 157: learning_rate=0.0129; feature_fraction=0.349; bagging_fraction=0.824; num_leaves=35; min_data_in_leaf=755; lambda_l2=3.13 : y = 0.931 : 67.6 secs : infill_ei
#
# Sat Jul 26 01:38:38 2025 AUC 0.931739650404368
#
# [mbo] 158: learning_rate=0.0135; feature_fraction=0.301; bagging_fraction=0.808; num_leaves=26; min_data_in_leaf=743; lambda_l2=1.84 : y = 0.932 : 61.1 secs : infill_ei
#
# Sat Jul 26 01:39:40 2025 AUC 0.931371253179572
#
# [mbo] 159: learning_rate=0.0117; feature_fraction=0.324; bagging_fraction=0.847; num_leaves=24; min_data_in_leaf=702; lambda_l2=4.17 : y = 0.931 : 60.8 secs : infill_ei
#
# Sat Jul 26 01:40:48 2025 AUC 0.930340962503
#
# [mbo] 160: learning_rate=0.0135; feature_fraction=0.366; bagging_fraction=0.845; num_leaves=32; min_data_in_leaf=727; lambda_l2=2.14 : y = 0.93 : 66.9 secs : infill_ei
#
# Saved the current state after iteration 161 in the file bayesiana.RDATA.
#
# Sat Jul 26 01:41:59 2025 AUC 0.931045769414804
#
# [mbo] 161: learning_rate=0.0106; feature_fraction=0.353; bagging_fraction=0.799; num_leaves=28; min_data_in_leaf=747; lambda_l2=3.75 : y = 0.931 : 64.3 secs : infill_ei
#
# Sat Jul 26 01:43:02 2025 AUC 0.930776825136566
#
# [mbo] 162: learning_rate=0.0119; feature_fraction=0.301; bagging_fraction=0.832; num_leaves=26; min_data_in_leaf=748; lambda_l2=4.19 : y = 0.931 : 61.3 secs : infill_ei
#
# Sat Jul 26 01:44:06 2025 AUC 0.931854025394535
#
# [mbo] 163: learning_rate=0.0136; feature_fraction=0.31; bagging_fraction=0.824; num_leaves=28; min_data_in_leaf=704; lambda_l2=2.18 : y = 0.932 : 62.2 secs : infill_ei
#
# Sat Jul 26 01:45:11 2025 AUC 0.930420543681046
#
# [mbo] 164: learning_rate=0.0139; feature_fraction=0.319; bagging_fraction=0.788; num_leaves=31; min_data_in_leaf=754; lambda_l2=2.04 : y = 0.93 : 64.3 secs : infill_ei
#
# Sat Jul 26 01:46:18 2025 AUC 0.931592745027882
#
# [mbo] 165: learning_rate=0.0114; feature_fraction=0.369; bagging_fraction=0.821; num_leaves=28; min_data_in_leaf=740; lambda_l2=1.61 : y = 0.932 : 65.1 secs : infill_ei
#
# Sat Jul 26 01:47:22 2025 AUC 0.930669542159258
#
# [mbo] 166: learning_rate=0.0138; feature_fraction=0.339; bagging_fraction=0.846; num_leaves=25; min_data_in_leaf=749; lambda_l2=1.48 : y = 0.931 : 62.1 secs : infill_ei
#
# Sat Jul 26 01:48:26 2025 AUC 0.930442397229004
#
# [mbo] 167: learning_rate=0.0145; feature_fraction=0.305; bagging_fraction=0.833; num_leaves=29; min_data_in_leaf=700; lambda_l2=3.19 : y = 0.93 : 62.6 secs : infill_ei
#
# Sat Jul 26 01:49:25 2025 AUC 0.930708931341998
#
# [mbo] 168: learning_rate=0.0141; feature_fraction=0.306; bagging_fraction=0.833; num_leaves=22; min_data_in_leaf=736; lambda_l2=0.779 : y = 0.931 : 57.8 secs : infill_ei
#
# Sat Jul 26 01:50:31 2025 AUC 0.930217475795479
#
# [mbo] 169: learning_rate=0.0135; feature_fraction=0.322; bagging_fraction=0.756; num_leaves=32; min_data_in_leaf=725; lambda_l2=0.703 : y = 0.93 : 64.8 secs : infill_ei
#
# Sat Jul 26 01:51:37 2025 AUC 0.930840227316234
#
# [mbo] 170: learning_rate=0.0135; feature_fraction=0.306; bagging_fraction=0.763; num_leaves=32; min_data_in_leaf=756; lambda_l2=1.1 : y = 0.931 : 64.2 secs : infill_ei
#
# Saved the current state after iteration 171 in the file bayesiana.RDATA.
#
# Sat Jul 26 01:52:48 2025 AUC 0.931845244945327
#
# [mbo] 171: learning_rate=0.01; feature_fraction=0.365; bagging_fraction=0.785; num_leaves=22; min_data_in_leaf=736; lambda_l2=4.71 : y = 0.932 : 62.6 secs : infill_ei
#
# Sat Jul 26 01:53:49 2025 AUC 0.93074291575915
#
# [mbo] 172: learning_rate=0.0134; feature_fraction=0.32; bagging_fraction=0.814; num_leaves=21; min_data_in_leaf=703; lambda_l2=2.41 : y = 0.931 : 59.2 secs : infill_ei
#
# Sat Jul 26 01:54:50 2025 AUC 0.930585883281499
#
# [mbo] 173: learning_rate=0.0144; feature_fraction=0.34; bagging_fraction=0.798; num_leaves=20; min_data_in_leaf=727; lambda_l2=4.27 : y = 0.931 : 59.6 secs : infill_ei
#
# Sat Jul 26 01:55:58 2025 AUC 0.930376408084355
#
# [mbo] 174: learning_rate=0.0143; feature_fraction=0.346; bagging_fraction=0.824; num_leaves=34; min_data_in_leaf=743; lambda_l2=3.37 : y = 0.93 : 66.7 secs : infill_ei
#
# Sat Jul 26 01:57:05 2025 AUC 0.929696812179693
#
# [mbo] 175: learning_rate=0.0134; feature_fraction=0.336; bagging_fraction=0.82; num_leaves=34; min_data_in_leaf=751; lambda_l2=3.79 : y = 0.93 : 64.9 secs : infill_ei
#
# Sat Jul 26 01:58:05 2025 AUC 0.930714903698078
#
# [mbo] 176: learning_rate=0.0143; feature_fraction=0.302; bagging_fraction=0.795; num_leaves=21; min_data_in_leaf=713; lambda_l2=3.62 : y = 0.931 : 58.8 secs : infill_ei
#
# Sat Jul 26 01:59:09 2025 AUC 0.931340109846496
#
# [mbo] 177: learning_rate=0.0127; feature_fraction=0.308; bagging_fraction=0.832; num_leaves=31; min_data_in_leaf=754; lambda_l2=3.12 : y = 0.931 : 63.0 secs : infill_ei
#
# Sat Jul 26 02:00:15 2025 AUC 0.931009025594318
#
# [mbo] 178: learning_rate=0.0107; feature_fraction=0.367; bagging_fraction=0.828; num_leaves=27; min_data_in_leaf=733; lambda_l2=4.02 : y = 0.931 : 64.4 secs : infill_ei
#
# Sat Jul 26 02:01:23 2025 AUC 0.930968207287934
#
# [mbo] 179: learning_rate=0.0133; feature_fraction=0.329; bagging_fraction=0.75; num_leaves=35; min_data_in_leaf=704; lambda_l2=2.77 : y = 0.931 : 66.0 secs : infill_ei
#
# Sat Jul 26 02:02:29 2025 AUC 0.930369406073323
#
# [mbo] 180: learning_rate=0.012; feature_fraction=0.339; bagging_fraction=0.762; num_leaves=33; min_data_in_leaf=732; lambda_l2=1.95 : y = 0.93 : 64.9 secs : infill_ei
#
# Saved the current state after iteration 181 in the file bayesiana.RDATA.
#
# Sat Jul 26 02:03:40 2025 AUC 0.930461558868731
#
# [mbo] 181: learning_rate=0.0135; feature_fraction=0.335; bagging_fraction=0.778; num_leaves=31; min_data_in_leaf=751; lambda_l2=0.809 : y = 0.93 : 63.7 secs : infill_ei
#
# Sat Jul 26 02:04:43 2025 AUC 0.93009441984813
#
# [mbo] 182: learning_rate=0.0106; feature_fraction=0.305; bagging_fraction=0.774; num_leaves=30; min_data_in_leaf=737; lambda_l2=0.694 : y = 0.93 : 62.0 secs : infill_ei
#
# Sat Jul 26 02:05:43 2025 AUC 0.930794769026177
#
# [mbo] 183: learning_rate=0.0149; feature_fraction=0.327; bagging_fraction=0.777; num_leaves=22; min_data_in_leaf=742; lambda_l2=4.54 : y = 0.931 : 58.6 secs : infill_ei
#
# Sat Jul 26 02:06:46 2025 AUC 0.930775104198043
#
# [mbo] 184: learning_rate=0.014; feature_fraction=0.34; bagging_fraction=0.825; num_leaves=24; min_data_in_leaf=748; lambda_l2=1.45 : y = 0.931 : 60.9 secs : infill_ei
#
# Sat Jul 26 02:07:48 2025 AUC 0.931534351335348
#
# [mbo] 185: learning_rate=0.0138; feature_fraction=0.333; bagging_fraction=0.787; num_leaves=25; min_data_in_leaf=731; lambda_l2=0.382 : y = 0.932 : 60.7 secs : infill_ei
#
# Sat Jul 26 02:08:50 2025 AUC 0.930888527178635
#
# [mbo] 186: learning_rate=0.0123; feature_fraction=0.368; bagging_fraction=0.841; num_leaves=21; min_data_in_leaf=733; lambda_l2=0.51 : y = 0.931 : 60.4 secs : infill_ei
#
# Sat Jul 26 02:09:56 2025 AUC 0.931112325636593
#
# [mbo] 187: learning_rate=0.014; feature_fraction=0.356; bagging_fraction=0.77; num_leaves=30; min_data_in_leaf=708; lambda_l2=1.49 : y = 0.931 : 64.2 secs : infill_ei
#
# Sat Jul 26 02:10:59 2025 AUC 0.931424578568828
#
# [mbo] 188: learning_rate=0.0131; feature_fraction=0.351; bagging_fraction=0.802; num_leaves=21; min_data_in_leaf=730; lambda_l2=4.83 : y = 0.931 : 61.2 secs : infill_ei
#
# Sat Jul 26 02:12:03 2025 AUC 0.930491266922585
#
# [mbo] 189: learning_rate=0.012; feature_fraction=0.356; bagging_fraction=0.835; num_leaves=24; min_data_in_leaf=754; lambda_l2=2.48 : y = 0.93 : 62.6 secs : infill_ei
#
# Sat Jul 26 02:13:06 2025 AUC 0.931054692930954
#
# [mbo] 190: learning_rate=0.0141; feature_fraction=0.312; bagging_fraction=0.813; num_leaves=27; min_data_in_leaf=721; lambda_l2=1.11 : y = 0.931 : 61.9 secs : infill_ei
#
# Saved the current state after iteration 191 in the file bayesiana.RDATA.
#
# Sat Jul 26 02:14:12 2025 AUC 0.931138238879519
#
# ...
#
# Saved the current state after iteration 231 in the file bayesiana.RDATA.
#
# Sat Jul 26 02:57:21 2025 AUC 0.93142894272226
#
# [mbo] 231: learning_rate=0.0146; feature_fraction=0.309; bagging_fraction=0.773; num_leaves=32; min_data_in_leaf=709; lambda_l2=1.4 : y = 0.931 : 63.3 secs : infill_ei
#
# Sat Jul 26 02:58:29 2025 AUC 0.932171378673011
#
# [mbo] 232: learning_rate=0.0103; feature_fraction=0.332; bagging_fraction=0.805; num_leaves=35; min_data_in_leaf=726; lambda_l2=2.02 : y = 0.932 : 65.3 secs : infill_ei
#
# Sat Jul 26 02:59:34 2025 AUC 0.931156553908313
#
# [mbo] 233: learning_rate=0.0142; feature_fraction=0.309; bagging_fraction=0.805; num_leaves=33; min_data_in_leaf=757; lambda_l2=4.34 : y = 0.931 : 63.9 secs : infill_ei
#
# Sat Jul 26 03:00:36 2025 AUC 0.93085282145598
#
# [mbo] 234: learning_rate=0.0125; feature_fraction=0.358; bagging_fraction=0.789; num_leaves=20; min_data_in_leaf=738; lambda_l2=0.831 : y = 0.931 : 60.0 secs : infill_ei
#
# Sat Jul 26 03:01:41 2025 AUC 0.931287203712495
#
# [mbo] 235: learning_rate=0.0104; feature_fraction=0.323; bagging_fraction=0.798; num_leaves=30; min_data_in_leaf=718; lambda_l2=4.35 : y = 0.931 : 62.8 secs : infill_ei
#
# Sat Jul 26 03:02:41 2025 AUC 0.931087854865242
#
# [mbo] 236: learning_rate=0.0129; feature_fraction=0.303; bagging_fraction=0.769; num_leaves=26; min_data_in_leaf=710; lambda_l2=3.95 : y = 0.931 : 59.1 secs : infill_ei
#
# Sat Jul 26 03:03:42 2025 AUC 0.931337790405635
#
# [mbo] 237: learning_rate=0.0133; feature_fraction=0.319; bagging_fraction=0.801; num_leaves=23; min_data_in_leaf=719; lambda_l2=1.71 : y = 0.931 : 59.0 secs : infill_ei
#
# Sat Jul 26 03:04:48 2025 AUC 0.932053476751658
#
# [mbo] 238: learning_rate=0.013; feature_fraction=0.319; bagging_fraction=0.765; num_leaves=34; min_data_in_leaf=737; lambda_l2=2.03 : y = 0.932 : 64.1 secs : infill_ei
#
# Sat Jul 26 03:05:55 2025 AUC 0.930768359022988
#
# [mbo] 239: learning_rate=0.0137; feature_fraction=0.344; bagging_fraction=0.831; num_leaves=33; min_data_in_leaf=721; lambda_l2=2.79 : y = 0.931 : 65.1 secs : infill_ei
#
# Sat Jul 26 03:07:00 2025 AUC 0.93068197829128
#
# [mbo] 240: learning_rate=0.0122; feature_fraction=0.32; bagging_fraction=0.813; num_leaves=32; min_data_in_leaf=702; lambda_l2=4.34 : y = 0.931 : 63.6 secs : infill_ei
#
# Saved the current state after iteration 241 in the file bayesiana.RDATA.
#
# Sat Jul 26 03:08:05 2025 AUC 0.931198871873258
#
# [mbo] 241: learning_rate=0.0133; feature_fraction=0.336; bagging_fraction=0.814; num_leaves=23; min_data_in_leaf=753; lambda_l2=1.58 : y = 0.931 : 58.9 secs : infill_ei
#
# Sat Jul 26 03:09:08 2025 AUC 0.929715969199221
#
# [mbo] 242: learning_rate=0.012; feature_fraction=0.326; bagging_fraction=0.799; num_leaves=29; min_data_in_leaf=713; lambda_l2=0.208 : y = 0.93 : 61.4 secs : infill_ei
#
# Sat Jul 26 03:10:08 2025 AUC 0.931029372565914
#
# [mbo] 243: learning_rate=0.0117; feature_fraction=0.309; bagging_fraction=0.756; num_leaves=21; min_data_in_leaf=718; lambda_l2=3.08 : y = 0.931 : 57.2 secs : infill_ei
#
# Sat Jul 26 03:11:13 2025 AUC 0.931357699652788
#
# [mbo] 244: learning_rate=0.0126; feature_fraction=0.352; bagging_fraction=0.835; num_leaves=27; min_data_in_leaf=732; lambda_l2=4.32 : y = 0.931 : 63.3 secs : infill_ei
#
# Sat Jul 26 03:12:18 2025 AUC 0.931031721172794
#
# [mbo] 245: learning_rate=0.0104; feature_fraction=0.33; bagging_fraction=0.801; num_leaves=32; min_data_in_leaf=721; lambda_l2=1.27 : y = 0.931 : 63.8 secs : infill_ei
#
# Sat Jul 26 03:13:19 2025 AUC 0.930372635779904
#
# [mbo] 246: learning_rate=0.0149; feature_fraction=0.318; bagging_fraction=0.813; num_leaves=25; min_data_in_leaf=721; lambda_l2=1.08 : y = 0.93 : 59.0 secs : infill_ei
#
# Sat Jul 26 03:14:27 2025 AUC 0.930557262990103
#
# [mbo] 247: learning_rate=0.0128; feature_fraction=0.358; bagging_fraction=0.849; num_leaves=34; min_data_in_leaf=754; lambda_l2=4.35 : y = 0.931 : 66.1 secs : infill_ei
#
# Sat Jul 26 03:15:35 2025 AUC 0.930739705147141
#
# [mbo] 248: learning_rate=0.0144; feature_fraction=0.351; bagging_fraction=0.84; num_leaves=35; min_data_in_leaf=733; lambda_l2=3.48 : y = 0.931 : 66.3 secs : infill_ei
#
# Sat Jul 26 03:16:41 2025 AUC 0.932218218440169
#
# [mbo] 249: learning_rate=0.0113; feature_fraction=0.358; bagging_fraction=0.769; num_leaves=27; min_data_in_leaf=710; lambda_l2=3.67 : y = 0.932 : 63.5 secs : infill_ei
#
# Sat Jul 26 03:17:44 2025 AUC 0.931387876414534
#
# [mbo] 250: learning_rate=0.0123; feature_fraction=0.304; bagging_fraction=0.773; num_leaves=26; min_data_in_leaf=741; lambda_l2=3.04 : y = 0.931 : 61.7 secs : infill_ei
#
# Saved the current state after iteration 251 in the file bayesiana.RDATA.
#
# Sat Jul 26 03:18:57 2025 AUC 0.930735803310084
#
# [mbo] 251: learning_rate=0.0113; feature_fraction=0.358; bagging_fraction=0.77; num_leaves=28; min_data_in_leaf=710; lambda_l2=2.4 : y = 0.931 : 63.5 secs : infill_ei
#
# Sat Jul 26 03:20:01 2025 AUC 0.93094234780538
#
# [mbo] 252: learning_rate=0.0148; feature_fraction=0.355; bagging_fraction=0.789; num_leaves=28; min_data_in_leaf=757; lambda_l2=2.3 : y = 0.931 : 63.0 secs : infill_ei
#
# Sat Jul 26 03:21:04 2025 AUC 0.930556787104478
#
# [mbo] 253: learning_rate=0.0143; feature_fraction=0.367; bagging_fraction=0.838; num_leaves=22; min_data_in_leaf=741; lambda_l2=3.8 : y = 0.931 : 60.7 secs : infill_ei
#
# Sat Jul 26 03:22:10 2025 AUC 0.931240214552948
#
# [mbo] 254: learning_rate=0.0104; feature_fraction=0.331; bagging_fraction=0.796; num_leaves=34; min_data_in_leaf=755; lambda_l2=1.93 : y = 0.931 : 64.3 secs : infill_ei
#
# Sat Jul 26 03:23:15 2025 AUC 0.930713332878338
#
# [mbo] 255: learning_rate=0.0121; feature_fraction=0.343; bagging_fraction=0.803; num_leaves=28; min_data_in_leaf=746; lambda_l2=4.58 : y = 0.931 : 62.6 secs : infill_ei
#
# Sat Jul 26 03:24:16 2025 AUC 0.931068613889238
#
# [mbo] 256: learning_rate=0.013; feature_fraction=0.331; bagging_fraction=0.836; num_leaves=25; min_data_in_leaf=718; lambda_l2=0.586 : y = 0.931 : 59.3 secs : infill_ei
#
# Sat Jul 26 03:25:23 2025 AUC 0.930577857461152
#
# [mbo] 257: learning_rate=0.0145; feature_fraction=0.367; bagging_fraction=0.805; num_leaves=29; min_data_in_leaf=700; lambda_l2=2.6 : y = 0.931 : 64.8 secs : infill_ei
#
# Sat Jul 26 03:26:23 2025 AUC 0.931192549358393
#
# [mbo] 258: learning_rate=0.0116; feature_fraction=0.302; bagging_fraction=0.8; num_leaves=22; min_data_in_leaf=752; lambda_l2=1.45 : y = 0.931 : 58.4 secs : infill_ei
#
# Sat Jul 26 03:27:28 2025 AUC 0.931440139112816
#
# [mbo] 259: learning_rate=0.0138; feature_fraction=0.356; bagging_fraction=0.821; num_leaves=27; min_data_in_leaf=741; lambda_l2=2.86 : y = 0.931 : 63.0 secs : infill_ei
#
# Sat Jul 26 03:28:29 2025 AUC 0.930405183016093
#
# [mbo] 260: learning_rate=0.0148; feature_fraction=0.317; bagging_fraction=0.784; num_leaves=22; min_data_in_leaf=715; lambda_l2=4 : y = 0.93 : 59.3 secs : infill_ei
#
# Saved the current state after iteration 261 in the file bayesiana.RDATA.
#
# Sat Jul 26 03:29:34 2025 AUC 0.930410449961587
#
# [mbo] 261: learning_rate=0.0123; feature_fraction=0.344; bagging_fraction=0.756; num_leaves=21; min_data_in_leaf=724; lambda_l2=1.99 : y = 0.93 : 58.5 secs : infill_ei
#
# Sat Jul 26 03:30:40 2025 AUC 0.931658963308563
#
# [mbo] 262: learning_rate=0.0135; feature_fraction=0.336; bagging_fraction=0.763; num_leaves=32; min_data_in_leaf=709; lambda_l2=0.638 : y = 0.932 : 64.2 secs : infill_ei
#
# Sat Jul 26 03:31:45 2025 AUC 0.930961001242206
#
# [mbo] 263: learning_rate=0.0142; feature_fraction=0.363; bagging_fraction=0.783; num_leaves=26; min_data_in_leaf=734; lambda_l2=3.37 : y = 0.931 : 62.8 secs : infill_ei
#
# Sat Jul 26 03:32:50 2025 AUC 0.931240058628027
#
# [mbo] 264: learning_rate=0.0114; feature_fraction=0.337; bagging_fraction=0.75; num_leaves=28; min_data_in_leaf=748; lambda_l2=1.58 : y = 0.931 : 62.8 secs : infill_ei
#
# Sat Jul 26 03:33:56 2025 AUC 0.930516322540533
#
# [mbo] 265: learning_rate=0.012; feature_fraction=0.354; bagging_fraction=0.764; num_leaves=29; min_data_in_leaf=740; lambda_l2=1.71 : y = 0.931 : 63.6 secs : infill_ei
#
# Sat Jul 26 03:34:59 2025 AUC 0.931107425505668
#
# [mbo] 266: learning_rate=0.0118; feature_fraction=0.364; bagging_fraction=0.766; num_leaves=23; min_data_in_leaf=712; lambda_l2=2.47 : y = 0.931 : 61.3 secs : infill_ei
#
# Sat Jul 26 03:36:01 2025 AUC 0.931895911569511
#
# [mbo] 267: learning_rate=0.014; feature_fraction=0.301; bagging_fraction=0.799; num_leaves=25; min_data_in_leaf=758; lambda_l2=2.39 : y = 0.932 : 59.7 secs : infill_ei
#
# Sat Jul 26 03:37:04 2025 AUC 0.930997115757044
#
# [mbo] 268: learning_rate=0.0149; feature_fraction=0.336; bagging_fraction=0.794; num_leaves=27; min_data_in_leaf=757; lambda_l2=4.38 : y = 0.931 : 61.4 secs : infill_ei
#
# Sat Jul 26 03:38:08 2025 AUC 0.931494093144294
#
# [mbo] 269: learning_rate=0.0143; feature_fraction=0.311; bagging_fraction=0.785; num_leaves=28; min_data_in_leaf=737; lambda_l2=3.29 : y = 0.931 : 61.7 secs : infill_ei
#
# Sat Jul 26 03:39:15 2025 AUC 0.930992162776244
#
# [mbo] 270: learning_rate=0.0145; feature_fraction=0.341; bagging_fraction=0.778; num_leaves=33; min_data_in_leaf=732; lambda_l2=0.34 : y = 0.931 : 64.8 secs : infill_ei
#
# Saved the current state after iteration 271 in the file bayesiana.RDATA.
#
# Sat Jul 26 03:40:24 2025 AUC 0.93079632767435
#
# [mbo] 271: learning_rate=0.0104; feature_fraction=0.334; bagging_fraction=0.767; num_leaves=29; min_data_in_leaf=715; lambda_l2=4.14 : y = 0.931 : 63.5 secs : infill_ei
#
# Sat Jul 26 03:41:29 2025 AUC 0.931113728514374
#
# [mbo] 272: learning_rate=0.0108; feature_fraction=0.331; bagging_fraction=0.814; num_leaves=30; min_data_in_leaf=736; lambda_l2=2.62 : y = 0.931 : 63.2 secs : infill_ei
#
# Sat Jul 26 03:42:31 2025 AUC 0.93076308046815
#
# [mbo] 273: learning_rate=0.0143; feature_fraction=0.305; bagging_fraction=0.766; num_leaves=24; min_data_in_leaf=720; lambda_l2=2.24 : y = 0.931 : 59.3 secs : infill_ei
#
# Sat Jul 26 03:43:33 2025 AUC 0.930892476143468
#
# [mbo] 274: learning_rate=0.0121; feature_fraction=0.311; bagging_fraction=0.801; num_leaves=23; min_data_in_leaf=744; lambda_l2=4.88 : y = 0.931 : 59.8 secs : infill_ei
#
# Sat Jul 26 03:44:34 2025 AUC 0.930918964111428
#
# [mbo] 275: learning_rate=0.0141; feature_fraction=0.354; bagging_fraction=0.756; num_leaves=22; min_data_in_leaf=700; lambda_l2=1.58 : y = 0.931 : 59.4 secs : infill_ei
#
# Sat Jul 26 03:45:40 2025 AUC 0.931700041668855
#
# [mbo] 276: learning_rate=0.0105; feature_fraction=0.33; bagging_fraction=0.811; num_leaves=30; min_data_in_leaf=734; lambda_l2=0.618 : y = 0.932 : 63.1 secs : infill_ei
#
# Sat Jul 26 03:46:42 2025 AUC 0.930492529940477
#
# [mbo] 277: learning_rate=0.0134; feature_fraction=0.312; bagging_fraction=0.805; num_leaves=26; min_data_in_leaf=736; lambda_l2=0.54 : y = 0.93 : 60.2 secs : infill_ei
#
# Sat Jul 26 03:47:44 2025 AUC 0.9319909844587
#
# [mbo] 278: learning_rate=0.0116; feature_fraction=0.329; bagging_fraction=0.754; num_leaves=23; min_data_in_leaf=732; lambda_l2=2.07 : y = 0.932 : 59.8 secs : infill_ei
#
# Sat Jul 26 03:48:48 2025 AUC 0.93120984598138
#
# [mbo] 279: learning_rate=0.0119; feature_fraction=0.367; bagging_fraction=0.81; num_leaves=23; min_data_in_leaf=743; lambda_l2=3.57 : y = 0.931 : 61.8 secs : infill_ei
#
# Sat Jul 26 03:49:48 2025 AUC 0.930978597762348
#
# [mbo] 280: learning_rate=0.0145; feature_fraction=0.318; bagging_fraction=0.827; num_leaves=23; min_data_in_leaf=747; lambda_l2=3.89 : y = 0.931 : 58.1 secs : infill_ei
#
# Saved the current state after iteration 281 in the file bayesiana.RDATA.
#
# Sat Jul 26 03:50:57 2025 AUC 0.930728507846003
#
# [mbo] 281: learning_rate=0.0132; feature_fraction=0.335; bagging_fraction=0.804; num_leaves=26; min_data_in_leaf=737; lambda_l2=3.43 : y = 0.931 : 62.7 secs : infill_ei
#
# Sat Jul 26 03:52:01 2025 AUC 0.930915996593435
#
# [mbo] 282: learning_rate=0.0142; feature_fraction=0.307; bagging_fraction=0.803; num_leaves=29; min_data_in_leaf=722; lambda_l2=4.87 : y = 0.931 : 62.0 secs : infill_ei
#
# Sat Jul 26 03:53:03 2025 AUC 0.930425618335675
#
# [mbo] 283: learning_rate=0.0139; feature_fraction=0.339; bagging_fraction=0.777; num_leaves=22; min_data_in_leaf=726; lambda_l2=3.23 : y = 0.93 : 59.6 secs : infill_ei
#
# Sat Jul 26 03:54:04 2025 AUC 0.930877845914052
#
# [mbo] 284: learning_rate=0.0124; feature_fraction=0.331; bagging_fraction=0.755; num_leaves=21; min_data_in_leaf=735; lambda_l2=0.685 : y = 0.931 : 58.9 secs : infill_ei
#
# Sat Jul 26 03:55:07 2025 AUC 0.930815267969345
#
# [mbo] 285: learning_rate=0.0128; feature_fraction=0.313; bagging_fraction=0.831; num_leaves=27; min_data_in_leaf=728; lambda_l2=3.36 : y = 0.931 : 61.2 secs : infill_ei
#
# Sat Jul 26 03:56:13 2025 AUC 0.930959662269923
#
# [mbo] 286: learning_rate=0.012; feature_fraction=0.304; bagging_fraction=0.777; num_leaves=35; min_data_in_leaf=739; lambda_l2=3.52 : y = 0.931 : 63.8 secs : infill_ei
#
# Sat Jul 26 03:57:19 2025 AUC 0.930719581730096
#
# [mbo] 287: learning_rate=0.0126; feature_fraction=0.31; bagging_fraction=0.783; num_leaves=34; min_data_in_leaf=752; lambda_l2=0.35 : y = 0.931 : 63.4 secs : infill_ei
#
# Sat Jul 26 03:58:18 2025 AUC 0.931067132244552
#
# [mbo] 288: learning_rate=0.0102; feature_fraction=0.309; bagging_fraction=0.756; num_leaves=21; min_data_in_leaf=727; lambda_l2=0.903 : y = 0.931 : 56.8 secs : infill_ei
#
# Sat Jul 26 03:59:20 2025 AUC 0.930295107138631
#
# [mbo] 289: learning_rate=0.0127; feature_fraction=0.329; bagging_fraction=0.839; num_leaves=24; min_data_in_leaf=729; lambda_l2=2.87 : y = 0.93 : 60.3 secs : infill_ei
#
# Sat Jul 26 04:00:25 2025 AUC 0.930450947401626
#
# [mbo] 290: learning_rate=0.0146; feature_fraction=0.336; bagging_fraction=0.83; num_leaves=29; min_data_in_leaf=739; lambda_l2=1.52 : y = 0.93 : 62.7 secs : infill_ei
#
# Saved the current state after iteration 291 in the file bayesiana.RDATA.
#
# Sat Jul 26 04:01:34 2025 AUC 0.931423363254943
#
# [mbo] 291: learning_rate=0.0106; feature_fraction=0.335; bagging_fraction=0.751; num_leaves=26; min_data_in_leaf=738; lambda_l2=0.733 : y = 0.931 : 61.4 secs : infill_ei
#
# Sat Jul 26 04:02:34 2025 AUC 0.930286158876854
#
# [mbo] 292: learning_rate=0.011; feature_fraction=0.309; bagging_fraction=0.765; num_leaves=21; min_data_in_leaf=748; lambda_l2=2.57 : y = 0.93 : 58.0 secs : infill_ei
#
# Sat Jul 26 04:03:40 2025 AUC 0.931349825309663
#
# [mbo] 293: learning_rate=0.0113; feature_fraction=0.331; bagging_fraction=0.824; num_leaves=30; min_data_in_leaf=714; lambda_l2=3.17 : y = 0.931 : 63.5 secs : infill_ei
#
# Sat Jul 26 04:04:40 2025 AUC 0.931081440252188
#
# [mbo] 294: learning_rate=0.0125; feature_fraction=0.317; bagging_fraction=0.765; num_leaves=23; min_data_in_leaf=736; lambda_l2=2.3 : y = 0.931 : 58.2 secs : infill_ei
#
# Sat Jul 26 04:05:45 2025 AUC 0.931001344427996
#
# [mbo] 295: learning_rate=0.0131; feature_fraction=0.314; bagging_fraction=0.801; num_leaves=32; min_data_in_leaf=724; lambda_l2=1.18 : y = 0.931 : 62.5 secs : infill_ei
#
# Sat Jul 26 04:06:47 2025 AUC 0.930751597620679
#
# [mbo] 296: learning_rate=0.0116; feature_fraction=0.368; bagging_fraction=0.765; num_leaves=20; min_data_in_leaf=705; lambda_l2=0.894 : y = 0.931 : 59.3 secs : infill_ei
#
# Sat Jul 26 04:07:52 2025 AUC 0.930373107723612
#
# [mbo] 297: learning_rate=0.0117; feature_fraction=0.342; bagging_fraction=0.85; num_leaves=28; min_data_in_leaf=741; lambda_l2=3.78 : y = 0.93 : 62.8 secs : infill_ei
#
# Sat Jul 26 04:08:54 2025 AUC 0.93009019628064
#
# [mbo] 298: learning_rate=0.0149; feature_fraction=0.341; bagging_fraction=0.768; num_leaves=23; min_data_in_leaf=727; lambda_l2=2.78 : y = 0.93 : 59.9 secs : infill_ei
#
# Sat Jul 26 04:09:56 2025 AUC 0.930954966175391
#
# [mbo] 299: learning_rate=0.0143; feature_fraction=0.369; bagging_fraction=0.807; num_leaves=22; min_data_in_leaf=718; lambda_l2=1.6 : y = 0.931 : 59.9 secs : infill_ei
#
# Sat Jul 26 04:10:58 2025 AUC 0.930761043759958
#
# [mbo] 300: learning_rate=0.0141; feature_fraction=0.319; bagging_fraction=0.837; num_leaves=25; min_data_in_leaf=713; lambda_l2=1.13 : y = 0.931 : 59.3 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "learning_rate"    "feature_fraction" "bagging_fraction" "num_leaves"
#  [5] "min_data_in_leaf" "lambda_l2"        "y"                "dob"
#  [9] "eol"              "error.message"    "exec.time"        "ei"
# [13] "error.model"      "train.time"       "prop.type"        "propose.time"
# [17] "se"               "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    learning_rate feature_fraction bagging_fraction num_leaves min_data_in_leaf
#            <num>            <num>            <num>      <int>            <int>
# 1:    0.01353456        0.3272251         0.750151         32              756
#    lambda_l2
#        <num>
# 1: 0.2290923
# [1] 0.9324259

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 100887
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 0.2290923
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 0.750151
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1200
#
# $learning_rate
# [1] 0.01353456
#
# $feature_fraction
# [1] 0.3272251
#
# $num_leaves
# [1] 32
#
# $min_data_in_leaf
# [1] 756

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sat Jul 26 04:17:35 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
