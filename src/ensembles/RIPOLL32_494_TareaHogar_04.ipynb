# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# Esta Tarea para el Hogar 02 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el viernes 01-agosto

# %% [markdown]
# ##  1. Cazatalentos

# %% [markdown]
# En la Clase 03 nos hemos enfrentado a  "La Maldicion del Ganandor",  elegir el modelo con el mejor puntaje simple no suele ser la mejor estrategia.
# <br> Lea y ejecute el notebook  **src/CazaTalentos/CazaTalentos.ipynb**
# <br> en caso de interesarle, participe del Desafío Ordenamiento  que vence el sábado 02 de agosto a las 19:00

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dm"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dm" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/itba2025-8d0a/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Fri Aug 01 06:41:29 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  656930 35.1 1439368    76.9 1431358  76.5
# Vcells 1224847  9.4 8388608    64.0 1924958  14.7

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 4971
PARAM$semilla_primigenia <- 888757

# %%
PARAM$kaggle$competencia <- "data-mining-analista-sr-2025-a"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 2000,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeNumericParam("learning_rate",       lower = 0.001,  upper = 0.3),
  makeIntegerParam("num_leaves",          lower = 20L,    upper = 2048L),
  makeIntegerParam("min_data_in_leaf",    lower = 10L,    upper = 8000L),
  makeNumericParam("feature_fraction",    lower = 0.1,    upper = 1.0),
  makeNumericParam("lambda_l2",           lower = 0.0,    upper = 15.0)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 250 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83544
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Fri Aug 01 06:43:37 2025 AUC 0.926150599685942
#
# Fri Aug 01 06:45:27 2025 AUC 0.925844307816425
#
# Fri Aug 01 06:46:55 2025 AUC 0.924339356065015
#
# Fri Aug 01 06:48:31 2025 AUC 0.9283944992928
#
# Fri Aug 01 06:49:57 2025 AUC 0.923975889148732
#
# Fri Aug 01 06:50:55 2025 AUC 0.926901265713042
#
# Fri Aug 01 06:52:10 2025 AUC 0.926458668428232
#
# Fri Aug 01 06:54:06 2025 AUC 0.928062168700944
#
# Fri Aug 01 06:54:54 2025 AUC 0.925502940131917
#
# Fri Aug 01 06:55:59 2025 AUC 0.923991993798989
#
# Fri Aug 01 06:57:23 2025 AUC 0.928027074766178
#
# Fri Aug 01 06:58:51 2025 AUC 0.925560815074851
#
# Fri Aug 01 07:00:28 2025 AUC 0.924316203607237
#
# Fri Aug 01 07:02:11 2025 AUC 0.927286917602554
#
# Fri Aug 01 07:03:03 2025 AUC 0.925220927975517
#
# Fri Aug 01 07:04:29 2025 AUC 0.92516128161161
#
# Fri Aug 01 07:06:21 2025 AUC 0.923583486856461
#
# Fri Aug 01 07:07:24 2025 AUC 0.926356903815263
#
# Fri Aug 01 07:09:38 2025 AUC 0.926004680701865
#
# Fri Aug 01 07:10:59 2025 AUC 0.924230912238062
#
# [mbo] 0: learning_rate=0.149; num_leaves=964; min_data_in_leaf=5190; feature_fraction=0.685; lambda_l2=6.18 : y = 0.926 : 56.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.168; num_leaves=1371; min_data_in_leaf=2527; feature_fraction=0.473; lambda_l2=8.4 : y = 0.926 : 110.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.194; num_leaves=509; min_data_in_leaf=5552; feature_fraction=0.332; lambda_l2=2.98 : y = 0.924 : 88.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0267; num_leaves=396; min_data_in_leaf=2337; feature_fraction=0.579; lambda_l2=11.3 : y = 0.928 : 95.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.276; num_leaves=579; min_data_in_leaf=4578; feature_fraction=0.266; lambda_l2=8.22 : y = 0.924 : 85.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0701; num_leaves=836; min_data_in_leaf=4123; feature_fraction=0.941; lambda_l2=5.24 : y = 0.927 : 57.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.295; num_leaves=257; min_data_in_leaf=3772; feature_fraction=0.601; lambda_l2=12.4 : y = 0.926 : 75.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.108; num_leaves=1787; min_data_in_leaf=1805; feature_fraction=0.442; lambda_l2=4.02 : y = 0.928 : 116.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0979; num_leaves=1885; min_data_in_leaf=7903; feature_fraction=0.879; lambda_l2=10 : y = 0.926 : 47.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.269; num_leaves=662; min_data_in_leaf=2998; feature_fraction=0.803; lambda_l2=6.83 : y = 0.924 : 64.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0371; num_leaves=1189; min_data_in_leaf=1534; feature_fraction=0.735; lambda_l2=1.78 : y = 0.928 : 84.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0532; num_leaves=178; min_data_in_leaf=7524; feature_fraction=0.388; lambda_l2=5.54 : y = 0.926 : 88.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.239; num_leaves=1476; min_data_in_leaf=6605; feature_fraction=0.516; lambda_l2=9.15 : y = 0.924 : 96.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0875; num_leaves=771; min_data_in_leaf=992; feature_fraction=0.178; lambda_l2=3.1 : y = 0.927 : 103.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.222; num_leaves=1704; min_data_in_leaf=6089; feature_fraction=0.999; lambda_l2=0.384 : y = 0.925 : 51.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.00986; num_leaves=1238; min_data_in_leaf=5652; feature_fraction=0.285; lambda_l2=13.1 : y = 0.925 : 86.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.249; num_leaves=1051; min_data_in_leaf=413; feature_fraction=0.142; lambda_l2=14.6 : y = 0.924 : 111.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.151; num_leaves=82; min_data_in_leaf=3445; feature_fraction=0.649; lambda_l2=11.1 : y = 0.926 : 63.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.206; num_leaves=2041; min_data_in_leaf=370; feature_fraction=0.823; lambda_l2=13.7 : y = 0.926 : 134.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.124; num_leaves=1621; min_data_in_leaf=6947; feature_fraction=0.207; lambda_l2=0.774 : y = 0.924 : 80.6 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Fri Aug 01 07:12:22 2025 AUC 0.928607117931221
#
# [mbo] 1: learning_rate=0.022; num_leaves=553; min_data_in_leaf=1568; feature_fraction=0.764; lambda_l2=6.64 : y = 0.929 : 79.7 secs : infill_ei
#
# Fri Aug 01 07:14:15 2025 AUC 0.92965392770318
#
# [mbo] 2: learning_rate=0.0324; num_leaves=68; min_data_in_leaf=20; feature_fraction=0.672; lambda_l2=9.43 : y = 0.93 : 111.9 secs : infill_ei
#
# Fri Aug 01 07:15:58 2025 AUC 0.929188635780403
#
# [mbo] 3: learning_rate=0.035; num_leaves=55; min_data_in_leaf=15; feature_fraction=1; lambda_l2=14.7 : y = 0.929 : 102.3 secs : infill_ei
#
# Fri Aug 01 07:16:54 2025 AUC 0.929688577631868
#
# [mbo] 4: learning_rate=0.0323; num_leaves=20; min_data_in_leaf=16; feature_fraction=0.773; lambda_l2=3.29 : y = 0.93 : 55.5 secs : infill_ei
#
# Fri Aug 01 07:18:37 2025 AUC 0.930514730874378
#
# [mbo] 5: learning_rate=0.0269; num_leaves=20; min_data_in_leaf=10; feature_fraction=0.487; lambda_l2=5.05 : y = 0.931 : 103.0 secs : infill_ei
#
# Fri Aug 01 07:20:14 2025 AUC 0.930626731036806
#
# [mbo] 6: learning_rate=0.0105; num_leaves=20; min_data_in_leaf=12; feature_fraction=0.389; lambda_l2=1.24 : y = 0.931 : 96.2 secs : infill_ei
#
# Fri Aug 01 07:21:41 2025 AUC 0.931062693320689
#
# [mbo] 7: learning_rate=0.018; num_leaves=21; min_data_in_leaf=15; feature_fraction=0.217; lambda_l2=4.42 : y = 0.931 : 86.4 secs : infill_ei
#
# Saved the current state after iteration 8 in the file bayesiana.RDATA.
#
# Fri Aug 01 07:23:00 2025 AUC 0.930194614436795
#
# [mbo] 8: learning_rate=0.0216; num_leaves=21; min_data_in_leaf=25; feature_fraction=0.105; lambda_l2=1.77 : y = 0.93 : 74.8 secs : infill_ei
#
# Fri Aug 01 07:24:32 2025 AUC 0.924310634821748
#
# [mbo] 9: learning_rate=0.00144; num_leaves=23; min_data_in_leaf=12; feature_fraction=0.234; lambda_l2=6.77 : y = 0.924 : 90.9 secs : infill_ei
#
# Fri Aug 01 07:31:26 2025 AUC 0.927399834386781
#
# [mbo] 10: learning_rate=0.0149; num_leaves=684; min_data_in_leaf=24; feature_fraction=0.917; lambda_l2=0.303 : y = 0.927 : 413.2 secs : infill_ei
#
# Fri Aug 01 07:35:36 2025 AUC 0.93037023444744
#
# [mbo] 11: learning_rate=0.0173; num_leaves=296; min_data_in_leaf=56; feature_fraction=0.365; lambda_l2=1.83 : y = 0.93 : 249.5 secs : infill_ei
#
# Saved the current state after iteration 12 in the file bayesiana.RDATA.
#
# Fri Aug 01 07:37:17 2025 AUC 0.932154693658199
#
# [mbo] 12: learning_rate=0.0146; num_leaves=22; min_data_in_leaf=463; feature_fraction=0.311; lambda_l2=3.54 : y = 0.932 : 95.1 secs : infill_ei
#
# Fri Aug 01 07:38:36 2025 AUC 0.926145828039611
#
# [mbo] 13: learning_rate=0.0143; num_leaves=33; min_data_in_leaf=4062; feature_fraction=0.158; lambda_l2=3.16 : y = 0.926 : 78.0 secs : infill_ei
#
# Fri Aug 01 07:40:21 2025 AUC 0.931995315825893
#
# [mbo] 14: learning_rate=0.014; num_leaves=20; min_data_in_leaf=537; feature_fraction=0.457; lambda_l2=12.3 : y = 0.932 : 104.1 secs : infill_ei
#
# Fri Aug 01 07:41:37 2025 AUC 0.924696067319015
#
# [mbo] 15: learning_rate=0.00146; num_leaves=26; min_data_in_leaf=17; feature_fraction=0.623; lambda_l2=12.6 : y = 0.925 : 75.9 secs : infill_ei
#
# Fri Aug 01 07:43:22 2025 AUC 0.929557412338986
#
# [mbo] 16: learning_rate=0.0146; num_leaves=22; min_data_in_leaf=74; feature_fraction=0.5; lambda_l2=2.51 : y = 0.93 : 104.2 secs : infill_ei
#
# Fri Aug 01 07:45:21 2025 AUC 0.931370344961886
#
# [mbo] 17: learning_rate=0.0137; num_leaves=203; min_data_in_leaf=634; feature_fraction=0.283; lambda_l2=11.6 : y = 0.931 : 118.2 secs : infill_ei
#
# Fri Aug 01 07:47:00 2025 AUC 0.931683349673364
#
# [mbo] 18: learning_rate=0.0149; num_leaves=24; min_data_in_leaf=305; feature_fraction=0.32; lambda_l2=8.46 : y = 0.932 : 98.3 secs : infill_ei
#
# Saved the current state after iteration 19 in the file bayesiana.RDATA.
#
# Fri Aug 01 07:48:41 2025 AUC 0.931612529728441
#
# [mbo] 19: learning_rate=0.0128; num_leaves=22; min_data_in_leaf=714; feature_fraction=0.317; lambda_l2=7.54 : y = 0.932 : 96.8 secs : infill_ei
#
# Fri Aug 01 07:50:03 2025 AUC 0.930789198496407
#
# [mbo] 20: learning_rate=0.0123; num_leaves=23; min_data_in_leaf=438; feature_fraction=0.132; lambda_l2=4.07 : y = 0.931 : 80.8 secs : infill_ei
#
# Fri Aug 01 07:52:09 2025 AUC 0.931103046408565
#
# [mbo] 21: learning_rate=0.0154; num_leaves=70; min_data_in_leaf=546; feature_fraction=0.319; lambda_l2=7.18 : y = 0.931 : 125.2 secs : infill_ei
#
# Fri Aug 01 07:54:33 2025 AUC 0.930455071089776
#
# [mbo] 22: learning_rate=0.0126; num_leaves=305; min_data_in_leaf=425; feature_fraction=0.394; lambda_l2=9.21 : y = 0.93 : 144.0 secs : infill_ei
#
# Fri Aug 01 07:56:16 2025 AUC 0.931549902814897
#
# [mbo] 23: learning_rate=0.0138; num_leaves=24; min_data_in_leaf=186; feature_fraction=0.351; lambda_l2=13.2 : y = 0.932 : 101.8 secs : infill_ei
#
# Fri Aug 01 07:58:07 2025 AUC 0.931871761751496
#
# [mbo] 24: learning_rate=0.0138; num_leaves=26; min_data_in_leaf=745; feature_fraction=0.485; lambda_l2=4.07 : y = 0.932 : 110.1 secs : infill_ei
#
# Saved the current state after iteration 25 in the file bayesiana.RDATA.
#
# Fri Aug 01 08:00:04 2025 AUC 0.930257519859673
#
# [mbo] 25: learning_rate=0.0139; num_leaves=35; min_data_in_leaf=975; feature_fraction=0.396; lambda_l2=1.76 : y = 0.93 : 112.1 secs : infill_ei
#
# Fri Aug 01 08:01:47 2025 AUC 0.931290683191868
#
# [mbo] 26: learning_rate=0.0141; num_leaves=21; min_data_in_leaf=446; feature_fraction=0.42; lambda_l2=4.6 : y = 0.931 : 102.3 secs : infill_ei
#
# Fri Aug 01 08:03:32 2025 AUC 0.928790123991281
#
# [mbo] 27: learning_rate=0.0127; num_leaves=23; min_data_in_leaf=2439; feature_fraction=0.436; lambda_l2=9.56 : y = 0.929 : 103.8 secs : infill_ei
#
# Fri Aug 01 08:06:25 2025 AUC 0.928749128222036
#
# [mbo] 28: learning_rate=0.0146; num_leaves=369; min_data_in_leaf=201; feature_fraction=0.199; lambda_l2=0.853 : y = 0.929 : 172.6 secs : infill_ei
#
# Fri Aug 01 08:08:42 2025 AUC 0.930518250875555
#
# [mbo] 29: learning_rate=0.0136; num_leaves=134; min_data_in_leaf=492; feature_fraction=0.299; lambda_l2=1.97 : y = 0.931 : 135.7 secs : infill_ei
#
# Saved the current state after iteration 30 in the file bayesiana.RDATA.
#
# Fri Aug 01 08:12:12 2025 AUC 0.929543993214901
#
# [mbo] 30: learning_rate=0.0122; num_leaves=201; min_data_in_leaf=25; feature_fraction=0.334; lambda_l2=3.98 : y = 0.93 : 206.1 secs : infill_ei
#
# Fri Aug 01 08:13:49 2025 AUC 0.931637896339286
#
# [mbo] 31: learning_rate=0.0142; num_leaves=21; min_data_in_leaf=504; feature_fraction=0.268; lambda_l2=13.6 : y = 0.932 : 95.6 secs : infill_ei
#
# Fri Aug 01 08:15:40 2025 AUC 0.930885378668325
#
# [mbo] 32: learning_rate=0.0135; num_leaves=41; min_data_in_leaf=925; feature_fraction=0.575; lambda_l2=8.76 : y = 0.931 : 110.9 secs : infill_ei
#
# Fri Aug 01 08:17:45 2025 AUC 0.930477171624428
#
# [mbo] 33: learning_rate=0.0145; num_leaves=761; min_data_in_leaf=709; feature_fraction=0.312; lambda_l2=5.39 : y = 0.93 : 124.4 secs : infill_ei
#
# Fri Aug 01 08:19:55 2025 AUC 0.93014688322965
#
# [mbo] 34: learning_rate=0.0161; num_leaves=84; min_data_in_leaf=68; feature_fraction=0.219; lambda_l2=12.4 : y = 0.93 : 128.9 secs : infill_ei
#
# Saved the current state after iteration 35 in the file bayesiana.RDATA.
#
# Fri Aug 01 08:21:38 2025 AUC 0.928566399108699
#
# [mbo] 35: learning_rate=0.0171; num_leaves=116; min_data_in_leaf=1659; feature_fraction=0.268; lambda_l2=6.72 : y = 0.929 : 98.4 secs : infill_ei
#
# Fri Aug 01 08:23:34 2025 AUC 0.930735347211472
#
# [mbo] 36: learning_rate=0.0151; num_leaves=121; min_data_in_leaf=837; feature_fraction=0.283; lambda_l2=3.74 : y = 0.931 : 115.0 secs : infill_ei
#
# Fri Aug 01 08:25:48 2025 AUC 0.930697060575171
#
# [mbo] 37: learning_rate=0.0145; num_leaves=271; min_data_in_leaf=731; feature_fraction=0.478; lambda_l2=14.5 : y = 0.931 : 133.1 secs : infill_ei
#
# Fri Aug 01 08:27:52 2025 AUC 0.930025299431759
#
# [mbo] 38: learning_rate=0.0185; num_leaves=1690; min_data_in_leaf=882; feature_fraction=0.323; lambda_l2=1.83 : y = 0.93 : 123.5 secs : infill_ei
#
# Fri Aug 01 08:30:31 2025 AUC 0.930261432114872
#
# [mbo] 39: learning_rate=0.0198; num_leaves=136; min_data_in_leaf=241; feature_fraction=0.317; lambda_l2=3.28 : y = 0.93 : 158.6 secs : infill_ei
#
# Saved the current state after iteration 40 in the file bayesiana.RDATA.
#
# Fri Aug 01 08:32:37 2025 AUC 0.931709435929134
#
# [mbo] 40: learning_rate=0.0107; num_leaves=33; min_data_in_leaf=691; feature_fraction=0.487; lambda_l2=6.27 : y = 0.932 : 118.8 secs : infill_ei
#
# Fri Aug 01 08:37:59 2025 AUC 0.928789014809847
#
# [mbo] 41: learning_rate=0.0105; num_leaves=980; min_data_in_leaf=49; feature_fraction=0.542; lambda_l2=3.9 : y = 0.929 : 321.1 secs : infill_ei
#
# Fri Aug 01 08:39:57 2025 AUC 0.929880609108831
#
# [mbo] 42: learning_rate=0.0137; num_leaves=457; min_data_in_leaf=1318; feature_fraction=0.473; lambda_l2=14 : y = 0.93 : 117.6 secs : infill_ei
#
# Fri Aug 01 08:42:00 2025 AUC 0.93194399956411
#
# [mbo] 43: learning_rate=0.011; num_leaves=393; min_data_in_leaf=780; feature_fraction=0.383; lambda_l2=10.4 : y = 0.932 : 122.0 secs : infill_ei
#
# Saved the current state after iteration 44 in the file bayesiana.RDATA.
#
# Fri Aug 01 08:44:00 2025 AUC 0.929994604107526
#
# [mbo] 44: learning_rate=0.0109; num_leaves=289; min_data_in_leaf=1273; feature_fraction=0.441; lambda_l2=13.3 : y = 0.93 : 115.7 secs : infill_ei
#
# Fri Aug 01 08:45:39 2025 AUC 0.931548353009033
#
# [mbo] 45: learning_rate=0.0107; num_leaves=23; min_data_in_leaf=543; feature_fraction=0.318; lambda_l2=8.37 : y = 0.932 : 98.1 secs : infill_ei
#
# Fri Aug 01 08:47:43 2025 AUC 0.931083213865
#
# [mbo] 46: learning_rate=0.011; num_leaves=49; min_data_in_leaf=172; feature_fraction=0.382; lambda_l2=6.92 : y = 0.931 : 122.9 secs : infill_ei
#
# Fri Aug 01 08:49:23 2025 AUC 0.930216947464655
#
# [mbo] 47: learning_rate=0.0112; num_leaves=564; min_data_in_leaf=721; feature_fraction=0.693; lambda_l2=12.8 : y = 0.93 : 99.5 secs : infill_ei
#
# Fri Aug 01 08:51:57 2025 AUC 0.930899424101351
#
# [mbo] 48: learning_rate=0.0105; num_leaves=469; min_data_in_leaf=330; feature_fraction=0.381; lambda_l2=7.98 : y = 0.931 : 153.3 secs : infill_ei
#
# Fri Aug 01 08:54:13 2025 AUC 0.931304069994754
#
# [mbo] 49: learning_rate=0.011; num_leaves=1083; min_data_in_leaf=828; feature_fraction=0.472; lambda_l2=3.51 : y = 0.931 : 134.7 secs : infill_ei
#
# Saved the current state after iteration 50 in the file bayesiana.RDATA.
#
# Fri Aug 01 08:56:28 2025 AUC 0.931177760132917
#
# [mbo] 50: learning_rate=0.0113; num_leaves=117; min_data_in_leaf=782; feature_fraction=0.55; lambda_l2=10.6 : y = 0.931 : 129.8 secs : infill_ei
#
# Fri Aug 01 08:57:58 2025 AUC 0.932077836297887
#
# [mbo] 51: learning_rate=0.0115; num_leaves=21; min_data_in_leaf=478; feature_fraction=0.21; lambda_l2=10.5 : y = 0.932 : 89.0 secs : infill_ei
#
# Fri Aug 01 08:59:36 2025 AUC 0.927021878960159
#
# [mbo] 52: learning_rate=0.0121; num_leaves=52; min_data_in_leaf=2963; feature_fraction=0.382; lambda_l2=14.1 : y = 0.927 : 97.0 secs : infill_ei
#
# Fri Aug 01 09:01:41 2025 AUC 0.929531490568552
#
# [mbo] 53: learning_rate=0.0166; num_leaves=128; min_data_in_leaf=437; feature_fraction=0.181; lambda_l2=3.44 : y = 0.93 : 124.3 secs : infill_ei
#
# Fri Aug 01 09:03:37 2025 AUC 0.930914056886728
#
# [mbo] 54: learning_rate=0.0115; num_leaves=477; min_data_in_leaf=800; feature_fraction=0.308; lambda_l2=12.3 : y = 0.931 : 115.1 secs : infill_ei
#
# Fri Aug 01 09:05:41 2025 AUC 0.929557427706816
#
# [mbo] 55: learning_rate=0.0143; num_leaves=1111; min_data_in_leaf=984; feature_fraction=0.383; lambda_l2=2.72 : y = 0.93 : 123.5 secs : infill_ei
#
# Saved the current state after iteration 56 in the file bayesiana.RDATA.
#
# Fri Aug 01 09:07:56 2025 AUC 0.930112339803244
#
# [mbo] 56: learning_rate=0.0113; num_leaves=150; min_data_in_leaf=748; feature_fraction=0.448; lambda_l2=7.71 : y = 0.93 : 129.6 secs : infill_ei
#
# Fri Aug 01 09:09:22 2025 AUC 0.927070317841269
#
# [mbo] 57: learning_rate=0.011; num_leaves=401; min_data_in_leaf=3092; feature_fraction=0.216; lambda_l2=6.96 : y = 0.927 : 85.3 secs : infill_ei
#
# Fri Aug 01 09:11:17 2025 AUC 0.930668235720695
#
# [mbo] 58: learning_rate=0.00927; num_leaves=31; min_data_in_leaf=971; feature_fraction=0.479; lambda_l2=3.35 : y = 0.931 : 114.0 secs : infill_ei
#
# Fri Aug 01 09:13:21 2025 AUC 0.929668177420383
#
# [mbo] 59: learning_rate=0.0107; num_leaves=294; min_data_in_leaf=1136; feature_fraction=0.543; lambda_l2=0.364 : y = 0.93 : 122.9 secs : infill_ei
#
# Fri Aug 01 09:15:03 2025 AUC 0.928379386797138
#
# [mbo] 60: learning_rate=0.0193; num_leaves=321; min_data_in_leaf=1152; feature_fraction=0.197; lambda_l2=0.514 : y = 0.928 : 101.6 secs : infill_ei
#
# Fri Aug 01 09:16:48 2025 AUC 0.931163596304087
#
# [mbo] 61: learning_rate=0.0113; num_leaves=30; min_data_in_leaf=358; feature_fraction=0.315; lambda_l2=11.3 : y = 0.931 : 103.8 secs : infill_ei
#
# Saved the current state after iteration 62 in the file bayesiana.RDATA.
#
# Fri Aug 01 09:20:42 2025 AUC 0.929057447019154
#
# [mbo] 62: learning_rate=0.0108; num_leaves=382; min_data_in_leaf=97; feature_fraction=0.611; lambda_l2=10.7 : y = 0.929 : 228.6 secs : infill_ei
#
# Fri Aug 01 09:24:04 2025 AUC 0.928932791619721
#
# [mbo] 63: learning_rate=0.0121; num_leaves=1390; min_data_in_leaf=52; feature_fraction=0.124; lambda_l2=10.7 : y = 0.929 : 200.8 secs : infill_ei
#
# Fri Aug 01 09:25:37 2025 AUC 0.930847984020356
#
# [mbo] 64: learning_rate=0.0136; num_leaves=21; min_data_in_leaf=405; feature_fraction=0.242; lambda_l2=8.88 : y = 0.931 : 92.3 secs : infill_ei
#
# Fri Aug 01 09:27:01 2025 AUC 0.930483037588709
#
# [mbo] 65: learning_rate=0.0107; num_leaves=21; min_data_in_leaf=430; feature_fraction=0.151; lambda_l2=10.9 : y = 0.93 : 83.6 secs : infill_ei
#
# Saved the current state after iteration 66 in the file bayesiana.RDATA.
#
# Fri Aug 01 09:29:02 2025 AUC 0.930900583787958
#
# [mbo] 66: learning_rate=0.0102; num_leaves=100; min_data_in_leaf=869; feature_fraction=0.321; lambda_l2=5.69 : y = 0.931 : 115.9 secs : infill_ei
#
# Fri Aug 01 09:31:09 2025 AUC 0.929995932211985
#
# [mbo] 67: learning_rate=0.0109; num_leaves=1781; min_data_in_leaf=934; feature_fraction=0.388; lambda_l2=3.8 : y = 0.93 : 125.7 secs : infill_ei
#
# Fri Aug 01 09:34:17 2025 AUC 0.928297077550279
#
# [mbo] 68: learning_rate=0.0293; num_leaves=136; min_data_in_leaf=111; feature_fraction=0.555; lambda_l2=3.45 : y = 0.928 : 186.5 secs : infill_ei
#
# Fri Aug 01 09:36:31 2025 AUC 0.930536692960738
#
# [mbo] 69: learning_rate=0.0108; num_leaves=1227; min_data_in_leaf=836; feature_fraction=0.501; lambda_l2=9.18 : y = 0.931 : 133.8 secs : infill_ei
#
# Fri Aug 01 09:38:35 2025 AUC 0.93053569182855
#
# [mbo] 70: learning_rate=0.0101; num_leaves=757; min_data_in_leaf=825; feature_fraction=0.398; lambda_l2=10.1 : y = 0.931 : 123.0 secs : infill_ei
#
# Saved the current state after iteration 71 in the file bayesiana.RDATA.
#
# Fri Aug 01 09:40:41 2025 AUC 0.929488788232563
#
# [mbo] 71: learning_rate=0.0143; num_leaves=192; min_data_in_leaf=1264; feature_fraction=0.505; lambda_l2=10.8 : y = 0.929 : 120.5 secs : infill_ei
#
# Fri Aug 01 09:42:44 2025 AUC 0.930883186309871
#
# [mbo] 72: learning_rate=0.0107; num_leaves=44; min_data_in_leaf=613; feature_fraction=0.567; lambda_l2=2.63 : y = 0.931 : 121.6 secs : infill_ei
#
# Fri Aug 01 09:45:08 2025 AUC 0.931484126812104
#
# [mbo] 73: learning_rate=0.0136; num_leaves=167; min_data_in_leaf=498; feature_fraction=0.401; lambda_l2=6.62 : y = 0.931 : 142.8 secs : infill_ei
#
# Fri Aug 01 09:49:38 2025 AUC 0.930055706769685
#
# [mbo] 74: learning_rate=0.011; num_leaves=894; min_data_in_leaf=53; feature_fraction=0.396; lambda_l2=9.04 : y = 0.93 : 269.7 secs : infill_ei
#
# Saved the current state after iteration 75 in the file bayesiana.RDATA.
#
# Fri Aug 01 09:51:38 2025 AUC 0.932445580677694
#
# [mbo] 75: learning_rate=0.0133; num_leaves=30; min_data_in_leaf=261; feature_fraction=0.481; lambda_l2=6.09 : y = 0.932 : 114.4 secs : infill_ei
#
# Fri Aug 01 09:53:27 2025 AUC 0.931053771608189
#
# [mbo] 76: learning_rate=0.0129; num_leaves=588; min_data_in_leaf=671; feature_fraction=0.677; lambda_l2=6.04 : y = 0.931 : 108.1 secs : infill_ei
#
# Fri Aug 01 09:56:34 2025 AUC 0.929520055955105
#
# [mbo] 77: learning_rate=0.0154; num_leaves=678; min_data_in_leaf=233; feature_fraction=0.477; lambda_l2=6.84 : y = 0.93 : 185.9 secs : infill_ei
#
# Fri Aug 01 09:59:28 2025 AUC 0.930850873344205
#
# [mbo] 78: learning_rate=0.0184; num_leaves=767; min_data_in_leaf=305; feature_fraction=0.44; lambda_l2=5.55 : y = 0.931 : 172.5 secs : infill_ei
#
# Fri Aug 01 10:01:50 2025 AUC 0.930388563253816
#
# [mbo] 79: learning_rate=0.0102; num_leaves=1369; min_data_in_leaf=535; feature_fraction=0.595; lambda_l2=2.01 : y = 0.93 : 141.6 secs : infill_ei
#
# Saved the current state after iteration 80 in the file bayesiana.RDATA.
#
# Fri Aug 01 10:03:34 2025 AUC 0.927809954017899
#
# [mbo] 80: learning_rate=0.0136; num_leaves=221; min_data_in_leaf=783; feature_fraction=0.115; lambda_l2=3.56 : y = 0.928 : 96.0 secs : infill_ei
#
# Fri Aug 01 10:05:03 2025 AUC 0.928146946646341
#
# [mbo] 81: learning_rate=0.012; num_leaves=189; min_data_in_leaf=2435; feature_fraction=0.589; lambda_l2=2.31 : y = 0.928 : 88.3 secs : infill_ei
#
# Fri Aug 01 10:07:28 2025 AUC 0.930711584474925
#
# [mbo] 82: learning_rate=0.0132; num_leaves=1063; min_data_in_leaf=633; feature_fraction=0.5; lambda_l2=7.4 : y = 0.931 : 144.1 secs : infill_ei
#
# Fri Aug 01 10:09:39 2025 AUC 0.930503212292557
#
# [mbo] 83: learning_rate=0.0118; num_leaves=1280; min_data_in_leaf=1000; feature_fraction=0.481; lambda_l2=5.91 : y = 0.931 : 129.5 secs : infill_ei
#
# Fri Aug 01 10:11:30 2025 AUC 0.930667478782637
#
# [mbo] 84: learning_rate=0.0117; num_leaves=1459; min_data_in_leaf=713; feature_fraction=0.682; lambda_l2=2.22 : y = 0.931 : 109.4 secs : infill_ei
#
# Fri Aug 01 10:12:43 2025 AUC 0.931448125322044
#
# [mbo] 85: learning_rate=0.0152; num_leaves=23; min_data_in_leaf=311; feature_fraction=0.633; lambda_l2=6.56 : y = 0.931 : 72.6 secs : infill_ei
#
# Saved the current state after iteration 86 in the file bayesiana.RDATA.
#
# Fri Aug 01 10:15:11 2025 AUC 0.930668237272505
#
# [mbo] 86: learning_rate=0.0146; num_leaves=77; min_data_in_leaf=628; feature_fraction=0.535; lambda_l2=3.48 : y = 0.931 : 142.4 secs : infill_ei
#
# Fri Aug 01 10:17:18 2025 AUC 0.929922418200223
#
# [mbo] 87: learning_rate=0.0143; num_leaves=100; min_data_in_leaf=465; feature_fraction=0.678; lambda_l2=4.11 : y = 0.93 : 125.3 secs : infill_ei
#
# Fri Aug 01 10:20:04 2025 AUC 0.931269593436129
#
# [mbo] 88: learning_rate=0.0181; num_leaves=1005; min_data_in_leaf=212; feature_fraction=0.288; lambda_l2=13.1 : y = 0.931 : 165.2 secs : infill_ei
#
# Fri Aug 01 10:21:51 2025 AUC 0.93105430956202
#
# [mbo] 89: learning_rate=0.0122; num_leaves=66; min_data_in_leaf=693; feature_fraction=0.213; lambda_l2=13.6 : y = 0.931 : 106.3 secs : infill_ei
#
# Fri Aug 01 10:25:43 2025 AUC 0.928748239641547
#
# [mbo] 90: learning_rate=0.0145; num_leaves=398; min_data_in_leaf=68; feature_fraction=0.354; lambda_l2=12.3 : y = 0.929 : 231.0 secs : infill_ei
#
# Saved the current state after iteration 91 in the file bayesiana.RDATA.
#
# Fri Aug 01 10:28:11 2025 AUC 0.930537819747374
#
# [mbo] 91: learning_rate=0.0132; num_leaves=69; min_data_in_leaf=450; feature_fraction=0.512; lambda_l2=12.4 : y = 0.931 : 142.4 secs : infill_ei
#
# Fri Aug 01 10:30:19 2025 AUC 0.93068440006839
#
# [mbo] 92: learning_rate=0.0127; num_leaves=45; min_data_in_leaf=481; feature_fraction=0.473; lambda_l2=5.12 : y = 0.931 : 127.1 secs : infill_ei
#
# Fri Aug 01 10:32:07 2025 AUC 0.930500562059878
#
# [mbo] 93: learning_rate=0.0195; num_leaves=1047; min_data_in_leaf=709; feature_fraction=0.679; lambda_l2=13.8 : y = 0.931 : 106.6 secs : infill_ei
#
# Fri Aug 01 10:34:19 2025 AUC 0.930948290753301
#
# [mbo] 94: learning_rate=0.0109; num_leaves=1456; min_data_in_leaf=940; feature_fraction=0.462; lambda_l2=3.18 : y = 0.931 : 130.9 secs : infill_ei
#
# Fri Aug 01 10:36:33 2025 AUC 0.930418861418551
#
# [mbo] 95: learning_rate=0.0168; num_leaves=378; min_data_in_leaf=639; feature_fraction=0.427; lambda_l2=13.1 : y = 0.93 : 133.0 secs : infill_ei
#
# Saved the current state after iteration 96 in the file bayesiana.RDATA.
#
# Fri Aug 01 10:38:36 2025 AUC 0.931298886513277
#
# [mbo] 96: learning_rate=0.0171; num_leaves=174; min_data_in_leaf=631; feature_fraction=0.613; lambda_l2=12.5 : y = 0.931 : 116.9 secs : infill_ei
#
# Fri Aug 01 10:40:41 2025 AUC 0.931890523563873
#
# [mbo] 97: learning_rate=0.0117; num_leaves=607; min_data_in_leaf=888; feature_fraction=0.424; lambda_l2=12.2 : y = 0.932 : 123.8 secs : infill_ei
#
# Fri Aug 01 10:42:56 2025 AUC 0.930780487637199
#
# [mbo] 98: learning_rate=0.018; num_leaves=1283; min_data_in_leaf=615; feature_fraction=0.366; lambda_l2=9.53 : y = 0.931 : 134.2 secs : infill_ei
#
# Fri Aug 01 10:44:31 2025 AUC 0.927885581773196
#
# [mbo] 99: learning_rate=0.0112; num_leaves=638; min_data_in_leaf=2248; feature_fraction=0.256; lambda_l2=11.8 : y = 0.928 : 93.9 secs : infill_ei
#
# Fri Aug 01 10:46:18 2025 AUC 0.931212346623454
#
# [mbo] 100: learning_rate=0.0118; num_leaves=632; min_data_in_leaf=778; feature_fraction=0.626; lambda_l2=14.2 : y = 0.931 : 105.2 secs : infill_ei
#
# Fri Aug 01 10:48:52 2025 AUC 0.9310304338509
#
# [mbo] 101: learning_rate=0.0136; num_leaves=101; min_data_in_leaf=294; feature_fraction=0.404; lambda_l2=4.71 : y = 0.931 : 152.9 secs : infill_ei
#
# Saved the current state after iteration 102 in the file bayesiana.RDATA.
#
# Fri Aug 01 10:50:57 2025 AUC 0.930549078391873
#
# [mbo] 102: learning_rate=0.0151; num_leaves=418; min_data_in_leaf=923; feature_fraction=0.576; lambda_l2=11.8 : y = 0.931 : 117.1 secs : infill_ei
#
# Fri Aug 01 10:52:58 2025 AUC 0.93122581933014
#
# [mbo] 103: learning_rate=0.0164; num_leaves=773; min_data_in_leaf=594; feature_fraction=0.638; lambda_l2=8.06 : y = 0.931 : 119.6 secs : infill_ei
#
# Fri Aug 01 10:54:50 2025 AUC 0.931213323822089
#
# [mbo] 104: learning_rate=0.0116; num_leaves=25; min_data_in_leaf=889; feature_fraction=0.464; lambda_l2=13.1 : y = 0.931 : 110.5 secs : infill_ei
#
# Fri Aug 01 10:57:03 2025 AUC 0.930734476803471
#
# [mbo] 105: learning_rate=0.0176; num_leaves=991; min_data_in_leaf=858; feature_fraction=0.535; lambda_l2=12.1 : y = 0.931 : 132.5 secs : infill_ei
#
# Fri Aug 01 10:58:28 2025 AUC 0.928654334397208
#
# [mbo] 106: learning_rate=0.0161; num_leaves=269; min_data_in_leaf=1541; feature_fraction=0.632; lambda_l2=13.7 : y = 0.929 : 83.4 secs : infill_ei
#
# Fri Aug 01 11:01:10 2025 AUC 0.930582545765822
#
# [mbo] 107: learning_rate=0.0133; num_leaves=262; min_data_in_leaf=310; feature_fraction=0.719; lambda_l2=0.813 : y = 0.931 : 160.8 secs : infill_ei
#
# Saved the current state after iteration 108 in the file bayesiana.RDATA.
#
# Fri Aug 01 11:03:02 2025 AUC 0.930903658387631
#
# [mbo] 108: learning_rate=0.0179; num_leaves=467; min_data_in_leaf=764; feature_fraction=0.654; lambda_l2=8.73 : y = 0.931 : 103.4 secs : infill_ei
#
# Fri Aug 01 11:05:20 2025 AUC 0.931568214685098
#
# [mbo] 109: learning_rate=0.0134; num_leaves=714; min_data_in_leaf=686; feature_fraction=0.58; lambda_l2=0.833 : y = 0.932 : 137.5 secs : infill_ei
#
# Fri Aug 01 11:07:01 2025 AUC 0.931073396106739
#
# [mbo] 110: learning_rate=0.0138; num_leaves=23; min_data_in_leaf=315; feature_fraction=0.363; lambda_l2=6.04 : y = 0.931 : 100.1 secs : infill_ei
#
# Fri Aug 01 11:09:30 2025 AUC 0.926840626103204
#
# [mbo] 111: learning_rate=0.201; num_leaves=984; min_data_in_leaf=486; feature_fraction=0.497; lambda_l2=13.4 : y = 0.927 : 147.6 secs : infill_ei
#
# Fri Aug 01 11:11:35 2025 AUC 0.931322770587353
#
# [mbo] 112: learning_rate=0.0114; num_leaves=576; min_data_in_leaf=721; feature_fraction=0.6; lambda_l2=1.78 : y = 0.931 : 123.4 secs : infill_ei
#
# Saved the current state after iteration 113 in the file bayesiana.RDATA.
#
# Fri Aug 01 11:13:35 2025 AUC 0.931094027709994
#
# [mbo] 113: learning_rate=0.0126; num_leaves=40; min_data_in_leaf=905; feature_fraction=0.381; lambda_l2=14.2 : y = 0.931 : 114.6 secs : infill_ei
#
# Fri Aug 01 11:14:50 2025 AUC 0.925606545356503
#
# [mbo] 114: learning_rate=0.215; num_leaves=396; min_data_in_leaf=2117; feature_fraction=0.833; lambda_l2=4.05 : y = 0.926 : 73.6 secs : infill_ei
#
# Fri Aug 01 11:17:08 2025 AUC 0.931229619952248
#
# [mbo] 115: learning_rate=0.0138; num_leaves=988; min_data_in_leaf=617; feature_fraction=0.417; lambda_l2=10.7 : y = 0.931 : 136.7 secs : infill_ei
#
# Fri Aug 01 11:19:18 2025 AUC 0.930682454002579
#
# [mbo] 116: learning_rate=0.0118; num_leaves=1046; min_data_in_leaf=724; feature_fraction=0.394; lambda_l2=13.5 : y = 0.931 : 128.3 secs : infill_ei
#
# Fri Aug 01 11:21:20 2025 AUC 0.930123787752563
#
# [mbo] 117: learning_rate=0.0108; num_leaves=477; min_data_in_leaf=876; feature_fraction=0.571; lambda_l2=5.82 : y = 0.93 : 121.3 secs : infill_ei
#
# Fri Aug 01 11:23:35 2025 AUC 0.93055458379672
#
# [mbo] 118: learning_rate=0.0123; num_leaves=752; min_data_in_leaf=774; feature_fraction=0.474; lambda_l2=9.41 : y = 0.931 : 132.9 secs : infill_ei
#
# Saved the current state after iteration 119 in the file bayesiana.RDATA.
#
# Fri Aug 01 11:28:49 2025 AUC 0.929158185890433
#
# [mbo] 119: learning_rate=0.0172; num_leaves=592; min_data_in_leaf=53; feature_fraction=0.599; lambda_l2=2.69 : y = 0.929 : 306.0 secs : infill_ei
#
# Fri Aug 01 11:29:57 2025 AUC 0.927571826521752
#
# [mbo] 120: learning_rate=0.0201; num_leaves=591; min_data_in_leaf=2596; feature_fraction=0.664; lambda_l2=7.43 : y = 0.928 : 67.7 secs : infill_ei
#
# Fri Aug 01 11:32:55 2025 AUC 0.930160179474538
#
# [mbo] 121: learning_rate=0.0133; num_leaves=133; min_data_in_leaf=220; feature_fraction=0.568; lambda_l2=6.69 : y = 0.93 : 176.5 secs : infill_ei
#
# Fri Aug 01 11:35:01 2025 AUC 0.932524229320027
#
# [mbo] 122: learning_rate=0.0129; num_leaves=93; min_data_in_leaf=693; feature_fraction=0.355; lambda_l2=10.8 : y = 0.933 : 124.2 secs : infill_ei
#
# Saved the current state after iteration 123 in the file bayesiana.RDATA.
#
# Fri Aug 01 11:36:56 2025 AUC 0.931395315322656
#
# [mbo] 123: learning_rate=0.0145; num_leaves=838; min_data_in_leaf=804; feature_fraction=0.626; lambda_l2=6.89 : y = 0.931 : 109.1 secs : infill_ei
#
# Fri Aug 01 11:39:01 2025 AUC 0.93074365673195
#
# [mbo] 124: learning_rate=0.0133; num_leaves=371; min_data_in_leaf=721; feature_fraction=0.35; lambda_l2=11.3 : y = 0.931 : 123.9 secs : infill_ei
#
# Fri Aug 01 11:40:00 2025 AUC 0.92726529068522
#
# [mbo] 125: learning_rate=0.0505; num_leaves=582; min_data_in_leaf=3864; feature_fraction=0.861; lambda_l2=5.32 : y = 0.927 : 58.2 secs : infill_ei
#
# Fri Aug 01 11:41:00 2025 AUC 0.927411639386449
#
# [mbo] 126: learning_rate=0.0834; num_leaves=1521; min_data_in_leaf=3908; feature_fraction=0.795; lambda_l2=13 : y = 0.927 : 59.3 secs : infill_ei
#
# Fri Aug 01 11:43:04 2025 AUC 0.931670329181791
#
# [mbo] 127: learning_rate=0.0121; num_leaves=262; min_data_in_leaf=598; feature_fraction=0.307; lambda_l2=10.4 : y = 0.932 : 122.4 secs : infill_ei
#
# Fri Aug 01 11:44:46 2025 AUC 0.930675038415799
#
# [mbo] 128: learning_rate=0.0143; num_leaves=1048; min_data_in_leaf=860; feature_fraction=0.675; lambda_l2=8.82 : y = 0.931 : 100.3 secs : infill_ei
#
# Fri Aug 01 11:48:32 2025 AUC 0.930082085138883
#
# [mbo] 129: learning_rate=0.0184; num_leaves=226; min_data_in_leaf=78; feature_fraction=0.44; lambda_l2=13.9 : y = 0.93 : 224.7 secs : infill_ei
#
# Saved the current state after iteration 130 in the file bayesiana.RDATA.
#
# Fri Aug 01 11:51:32 2025 AUC 0.931101078563088
#
# [mbo] 130: learning_rate=0.0191; num_leaves=918; min_data_in_leaf=212; feature_fraction=0.357; lambda_l2=11.4 : y = 0.931 : 173.3 secs : infill_ei
#
# Fri Aug 01 11:53:16 2025 AUC 0.931922427530884
#
# [mbo] 131: learning_rate=0.0178; num_leaves=22; min_data_in_leaf=680; feature_fraction=0.393; lambda_l2=12.6 : y = 0.932 : 103.6 secs : infill_ei
#
# Fri Aug 01 11:55:14 2025 AUC 0.931504973111988
#
# [mbo] 132: learning_rate=0.0181; num_leaves=44; min_data_in_leaf=328; feature_fraction=0.316; lambda_l2=9.71 : y = 0.932 : 115.5 secs : infill_ei
#
# Fri Aug 01 11:57:35 2025 AUC 0.93139986608059
#
# [mbo] 133: learning_rate=0.0205; num_leaves=356; min_data_in_leaf=478; feature_fraction=0.354; lambda_l2=10.7 : y = 0.931 : 140.4 secs : infill_ei
#
# Fri Aug 01 12:05:21 2025 AUC 0.927877032429519
#
# [mbo] 134: learning_rate=0.0174; num_leaves=1848; min_data_in_leaf=10; feature_fraction=0.64; lambda_l2=10.9 : y = 0.928 : 464.1 secs : infill_ei
#
# Saved the current state after iteration 135 in the file bayesiana.RDATA.
#
# Fri Aug 01 12:07:31 2025 AUC 0.931193784174469
#
# [mbo] 135: learning_rate=0.0128; num_leaves=53; min_data_in_leaf=552; feature_fraction=0.311; lambda_l2=4.07 : y = 0.931 : 122.7 secs : infill_ei
#
# Fri Aug 01 12:09:52 2025 AUC 0.930592191181386
#
# [mbo] 136: learning_rate=0.0115; num_leaves=54; min_data_in_leaf=268; feature_fraction=0.519; lambda_l2=9.15 : y = 0.931 : 139.7 secs : infill_ei
#
# Fri Aug 01 12:11:55 2025 AUC 0.931160847520024
#
# [mbo] 137: learning_rate=0.0185; num_leaves=1160; min_data_in_leaf=543; feature_fraction=0.692; lambda_l2=13.6 : y = 0.931 : 121.1 secs : infill_ei
#
# Fri Aug 01 12:16:25 2025 AUC 0.928720758270689
#
# [mbo] 138: learning_rate=0.0206; num_leaves=1158; min_data_in_leaf=34; feature_fraction=0.259; lambda_l2=9.05 : y = 0.929 : 269.0 secs : infill_ei
#
# Saved the current state after iteration 139 in the file bayesiana.RDATA.
#
# Fri Aug 01 12:18:31 2025 AUC 0.931248100331811
#
# [mbo] 139: learning_rate=0.0114; num_leaves=190; min_data_in_leaf=670; feature_fraction=0.353; lambda_l2=7.21 : y = 0.931 : 119.5 secs : infill_ei
#
# Fri Aug 01 12:20:03 2025 AUC 0.926299994476743
#
# [mbo] 140: learning_rate=0.189; num_leaves=606; min_data_in_leaf=4588; feature_fraction=0.392; lambda_l2=2.46 : y = 0.926 : 90.5 secs : infill_ei
#
# Fri Aug 01 12:22:20 2025 AUC 0.931204971769434
#
# [mbo] 141: learning_rate=0.0188; num_leaves=636; min_data_in_leaf=685; feature_fraction=0.459; lambda_l2=2.37 : y = 0.931 : 135.2 secs : infill_ei
#
# Fri Aug 01 12:24:22 2025 AUC 0.931356665297077
#
# [mbo] 142: learning_rate=0.0197; num_leaves=363; min_data_in_leaf=903; feature_fraction=0.441; lambda_l2=10.5 : y = 0.931 : 120.7 secs : infill_ei
#
# Fri Aug 01 12:26:18 2025 AUC 0.930529533336689
#
# [mbo] 143: learning_rate=0.0202; num_leaves=97; min_data_in_leaf=594; feature_fraction=0.613; lambda_l2=10.5 : y = 0.931 : 114.8 secs : infill_ei
#
# Fri Aug 01 12:28:38 2025 AUC 0.930104921074527
#
# [mbo] 144: learning_rate=0.019; num_leaves=467; min_data_in_leaf=485; feature_fraction=0.411; lambda_l2=5.64 : y = 0.93 : 138.0 secs : infill_ei
#
# Saved the current state after iteration 145 in the file bayesiana.RDATA.
#
# Fri Aug 01 12:30:28 2025 AUC 0.928721366386969
#
# [mbo] 145: learning_rate=0.0183; num_leaves=1056; min_data_in_leaf=1865; feature_fraction=0.393; lambda_l2=9.94 : y = 0.929 : 104.3 secs : infill_ei
#
# Fri Aug 01 12:32:34 2025 AUC 0.930744044921658
#
# [mbo] 146: learning_rate=0.021; num_leaves=131; min_data_in_leaf=941; feature_fraction=0.465; lambda_l2=4.01 : y = 0.931 : 124.4 secs : infill_ei
#
# Fri Aug 01 12:34:12 2025 AUC 0.930876401678673
#
# [mbo] 147: learning_rate=0.0197; num_leaves=31; min_data_in_leaf=190; feature_fraction=0.223; lambda_l2=11.7 : y = 0.931 : 95.6 secs : infill_ei
#
# Fri Aug 01 12:36:28 2025 AUC 0.930165950558397
#
# [mbo] 148: learning_rate=0.0181; num_leaves=1286; min_data_in_leaf=769; feature_fraction=0.559; lambda_l2=4.46 : y = 0.93 : 134.6 secs : infill_ei
#
# Fri Aug 01 12:38:34 2025 AUC 0.930958012546008
#
# [mbo] 149: learning_rate=0.0204; num_leaves=650; min_data_in_leaf=717; feature_fraction=0.411; lambda_l2=12 : y = 0.931 : 125.2 secs : infill_ei
#
# Fri Aug 01 12:40:33 2025 AUC 0.93040618129926
#
# [mbo] 150: learning_rate=0.0136; num_leaves=773; min_data_in_leaf=921; feature_fraction=0.579; lambda_l2=3.63 : y = 0.93 : 117.4 secs : infill_ei
#
# Saved the current state after iteration 151 in the file bayesiana.RDATA.
#
# Fri Aug 01 12:43:05 2025 AUC 0.93100534379296
#
# [mbo] 151: learning_rate=0.0119; num_leaves=960; min_data_in_leaf=342; feature_fraction=0.328; lambda_l2=9.07 : y = 0.931 : 142.6 secs : infill_ei
#
# Fri Aug 01 12:44:50 2025 AUC 0.93034115883363
#
# [mbo] 152: learning_rate=0.0145; num_leaves=27; min_data_in_leaf=783; feature_fraction=0.55; lambda_l2=1.08 : y = 0.93 : 103.9 secs : infill_ei
#
# Fri Aug 01 12:46:26 2025 AUC 0.932171690935493
#
# [mbo] 153: learning_rate=0.0174; num_leaves=22; min_data_in_leaf=656; feature_fraction=0.571; lambda_l2=7.12 : y = 0.932 : 94.7 secs : infill_ei
#
# Fri Aug 01 12:48:51 2025 AUC 0.930096455838804
#
# [mbo] 154: learning_rate=0.0187; num_leaves=883; min_data_in_leaf=660; feature_fraction=0.48; lambda_l2=1.1 : y = 0.93 : 143.7 secs : infill_ei
#
# Fri Aug 01 12:50:18 2025 AUC 0.923897454790004
#
# [mbo] 155: learning_rate=0.287; num_leaves=733; min_data_in_leaf=7501; feature_fraction=0.35; lambda_l2=9.53 : y = 0.924 : 85.1 secs : infill_ei
#
# Fri Aug 01 12:51:35 2025 AUC 0.931581853282599
#
# [mbo] 156: learning_rate=0.0174; num_leaves=21; min_data_in_leaf=739; feature_fraction=0.647; lambda_l2=6.44 : y = 0.932 : 75.8 secs : infill_ei
#
# Saved the current state after iteration 157 in the file bayesiana.RDATA.
#
# Fri Aug 01 12:53:34 2025 AUC 0.93164929641713
#
# [mbo] 157: learning_rate=0.0134; num_leaves=35; min_data_in_leaf=631; feature_fraction=0.444; lambda_l2=8.21 : y = 0.932 : 112.3 secs : infill_ei
#
# Fri Aug 01 12:55:27 2025 AUC 0.930365288488835
#
# [mbo] 158: learning_rate=0.0113; num_leaves=38; min_data_in_leaf=699; feature_fraction=0.389; lambda_l2=10.7 : y = 0.93 : 111.9 secs : infill_ei
#
# Fri Aug 01 12:56:35 2025 AUC 0.925274246954754
#
# [mbo] 159: learning_rate=0.193; num_leaves=1274; min_data_in_leaf=2454; feature_fraction=0.681; lambda_l2=14 : y = 0.925 : 66.5 secs : infill_ei
#
# Fri Aug 01 12:58:41 2025 AUC 0.930409826786737
#
# [mbo] 160: learning_rate=0.0148; num_leaves=1473; min_data_in_leaf=464; feature_fraction=0.227; lambda_l2=8.59 : y = 0.93 : 124.4 secs : infill_ei
#
# Fri Aug 01 13:00:41 2025 AUC 0.931603293822188
#
# [mbo] 161: learning_rate=0.0148; num_leaves=149; min_data_in_leaf=670; feature_fraction=0.328; lambda_l2=10.9 : y = 0.932 : 118.5 secs : infill_ei
#
# Fri Aug 01 13:02:44 2025 AUC 0.930200883563078
#
# [mbo] 162: learning_rate=0.0183; num_leaves=127; min_data_in_leaf=713; feature_fraction=0.577; lambda_l2=11.2 : y = 0.93 : 121.4 secs : infill_ei
#
# Saved the current state after iteration 163 in the file bayesiana.RDATA.
#
# Fri Aug 01 13:04:48 2025 AUC 0.931430081718888
#
# [mbo] 163: learning_rate=0.0111; num_leaves=951; min_data_in_leaf=703; feature_fraction=0.278; lambda_l2=3.96 : y = 0.931 : 116.8 secs : infill_ei
#
# Fri Aug 01 13:06:26 2025 AUC 0.930374915437863
#
# [mbo] 164: learning_rate=0.0129; num_leaves=666; min_data_in_leaf=895; feature_fraction=0.677; lambda_l2=0.697 : y = 0.93 : 96.8 secs : infill_ei
#
# Fri Aug 01 13:08:17 2025 AUC 0.929472267498351
#
# [mbo] 165: learning_rate=0.0106; num_leaves=511; min_data_in_leaf=1203; feature_fraction=0.405; lambda_l2=10.7 : y = 0.929 : 109.3 secs : infill_ei
#
# Fri Aug 01 13:10:19 2025 AUC 0.931948550052794
#
# [mbo] 166: learning_rate=0.0187; num_leaves=316; min_data_in_leaf=753; feature_fraction=0.37; lambda_l2=14.3 : y = 0.932 : 119.5 secs : infill_ei
#
# Fri Aug 01 13:12:38 2025 AUC 0.930619795781501
#
# [mbo] 167: learning_rate=0.0177; num_leaves=217; min_data_in_leaf=639; feature_fraction=0.489; lambda_l2=6.67 : y = 0.931 : 137.4 secs : infill_ei
#
# Fri Aug 01 13:15:14 2025 AUC 0.930205693081069
#
# [mbo] 168: learning_rate=0.0175; num_leaves=1040; min_data_in_leaf=286; feature_fraction=0.655; lambda_l2=7.62 : y = 0.93 : 154.3 secs : infill_ei
#
# Saved the current state after iteration 169 in the file bayesiana.RDATA.
#
# Fri Aug 01 13:17:25 2025 AUC 0.931041144686694
#
# [mbo] 169: learning_rate=0.0181; num_leaves=688; min_data_in_leaf=645; feature_fraction=0.354; lambda_l2=13.7 : y = 0.931 : 124.0 secs : infill_ei
#
# Fri Aug 01 13:19:30 2025 AUC 0.931121190913947
#
# [mbo] 170: learning_rate=0.0152; num_leaves=1061; min_data_in_leaf=539; feature_fraction=0.647; lambda_l2=2.73 : y = 0.931 : 122.9 secs : infill_ei
#
# Fri Aug 01 13:20:46 2025 AUC 0.926649646296999
#
# [mbo] 171: learning_rate=0.2; num_leaves=1456; min_data_in_leaf=2753; feature_fraction=0.615; lambda_l2=7.66 : y = 0.927 : 75.2 secs : infill_ei
#
# Fri Aug 01 13:22:36 2025 AUC 0.93054731628112
#
# [mbo] 172: learning_rate=0.0105; num_leaves=1260; min_data_in_leaf=781; feature_fraction=0.615; lambda_l2=6.7 : y = 0.931 : 108.1 secs : infill_ei
#
# Fri Aug 01 13:25:40 2025 AUC 0.930695441234214
#
# [mbo] 173: learning_rate=0.0111; num_leaves=787; min_data_in_leaf=161; feature_fraction=0.353; lambda_l2=10.9 : y = 0.931 : 180.9 secs : infill_ei
#
# Saved the current state after iteration 174 in the file bayesiana.RDATA.
#
# Fri Aug 01 13:27:52 2025 AUC 0.930888645469983
#
# [mbo] 174: learning_rate=0.0123; num_leaves=726; min_data_in_leaf=897; feature_fraction=0.469; lambda_l2=13 : y = 0.931 : 124.6 secs : infill_ei
#
# Fri Aug 01 13:30:20 2025 AUC 0.931915344765465
#
# [mbo] 175: learning_rate=0.0156; num_leaves=844; min_data_in_leaf=430; feature_fraction=0.357; lambda_l2=10.9 : y = 0.932 : 146.7 secs : infill_ei
#
# Fri Aug 01 13:32:47 2025 AUC 0.930769557387484
#
# [mbo] 176: learning_rate=0.0146; num_leaves=451; min_data_in_leaf=383; feature_fraction=0.358; lambda_l2=10.5 : y = 0.931 : 145.3 secs : infill_ei
#
# Fri Aug 01 13:34:58 2025 AUC 0.931176397732876
#
# [mbo] 177: learning_rate=0.0112; num_leaves=286; min_data_in_leaf=611; feature_fraction=0.325; lambda_l2=1.82 : y = 0.931 : 129.1 secs : infill_ei
#
# Fri Aug 01 13:37:10 2025 AUC 0.93113516059669
#
# [mbo] 178: learning_rate=0.0154; num_leaves=1457; min_data_in_leaf=629; feature_fraction=0.359; lambda_l2=8.45 : y = 0.931 : 129.6 secs : infill_ei
#
# Saved the current state after iteration 179 in the file bayesiana.RDATA.
#
# Fri Aug 01 13:38:54 2025 AUC 0.931926815745533
#
# [mbo] 179: learning_rate=0.0152; num_leaves=23; min_data_in_leaf=439; feature_fraction=0.31; lambda_l2=10.9 : y = 0.932 : 96.5 secs : infill_ei
#
# Fri Aug 01 13:40:26 2025 AUC 0.927703451328692
#
# [mbo] 180: learning_rate=0.0118; num_leaves=1536; min_data_in_leaf=4330; feature_fraction=0.357; lambda_l2=8.04 : y = 0.928 : 91.0 secs : infill_ei
#
# Fri Aug 01 13:42:20 2025 AUC 0.931549104067728
#
# [mbo] 181: learning_rate=0.0118; num_leaves=100; min_data_in_leaf=807; feature_fraction=0.293; lambda_l2=10.4 : y = 0.932 : 111.8 secs : infill_ei
#
# Fri Aug 01 13:44:06 2025 AUC 0.931244335258878
#
# [mbo] 182: learning_rate=0.0172; num_leaves=21; min_data_in_leaf=244; feature_fraction=0.469; lambda_l2=11 : y = 0.931 : 104.1 secs : infill_ei
#
# Fri Aug 01 13:45:39 2025 AUC 0.927125131055706
#
# [mbo] 183: learning_rate=0.0151; num_leaves=785; min_data_in_leaf=5136; feature_fraction=0.396; lambda_l2=10.2 : y = 0.927 : 91.8 secs : infill_ei
#
# Fri Aug 01 13:47:27 2025 AUC 0.930892181252929
#
# [mbo] 184: learning_rate=0.0196; num_leaves=33; min_data_in_leaf=850; feature_fraction=0.343; lambda_l2=13.4 : y = 0.931 : 105.8 secs : infill_ei
#
# Saved the current state after iteration 185 in the file bayesiana.RDATA.
#
# Fri Aug 01 13:50:51 2025 AUC 0.928850737816711
#
# [mbo] 185: learning_rate=0.0117; num_leaves=938; min_data_in_leaf=120; feature_fraction=0.22; lambda_l2=2.31 : y = 0.929 : 197.9 secs : infill_ei
#
# Fri Aug 01 13:53:03 2025 AUC 0.930448315195446
#
# [mbo] 186: learning_rate=0.0108; num_leaves=1082; min_data_in_leaf=651; feature_fraction=0.345; lambda_l2=1.92 : y = 0.93 : 129.5 secs : infill_ei
#
# Fri Aug 01 13:55:07 2025 AUC 0.929979929828212
#
# [mbo] 187: learning_rate=0.0119; num_leaves=645; min_data_in_leaf=1098; feature_fraction=0.472; lambda_l2=0.532 : y = 0.93 : 122.1 secs : infill_ei
#
# Fri Aug 01 13:58:02 2025 AUC 0.930598093987953
#
# [mbo] 188: learning_rate=0.0143; num_leaves=834; min_data_in_leaf=185; feature_fraction=0.627; lambda_l2=11.3 : y = 0.931 : 172.9 secs : infill_ei
#
# Saved the current state after iteration 189 in the file bayesiana.RDATA.
#
# Fri Aug 01 14:02:11 2025 AUC 0.930741793070965
#
# [mbo] 189: learning_rate=0.0188; num_leaves=1464; min_data_in_leaf=48; feature_fraction=0.289; lambda_l2=14.4 : y = 0.931 : 242.0 secs : infill_ei
#
# Fri Aug 01 14:04:07 2025 AUC 0.930004300984524
#
# [mbo] 190: learning_rate=0.0188; num_leaves=682; min_data_in_leaf=484; feature_fraction=0.697; lambda_l2=12.6 : y = 0.93 : 114.6 secs : infill_ei
#
# Fri Aug 01 14:08:14 2025 AUC 0.929505128438009
#
# [mbo] 191: learning_rate=0.011; num_leaves=366; min_data_in_leaf=46; feature_fraction=0.298; lambda_l2=6.39 : y = 0.93 : 243.9 secs : infill_ei
#
# Saved the current state after iteration 192 in the file bayesiana.RDATA.
#
# Fri Aug 01 14:10:24 2025 AUC 0.931087468974388
#
# [mbo] 192: learning_rate=0.0132; num_leaves=147; min_data_in_leaf=683; feature_fraction=0.364; lambda_l2=5.88 : y = 0.931 : 122.7 secs : infill_ei
#
# Fri Aug 01 14:12:40 2025 AUC 0.930573328408698
#
# [mbo] 193: learning_rate=0.0159; num_leaves=1120; min_data_in_leaf=443; feature_fraction=0.309; lambda_l2=10.2 : y = 0.931 : 133.9 secs : infill_ei
#
# Fri Aug 01 14:14:48 2025 AUC 0.93028129803148
#
# [mbo] 194: learning_rate=0.0111; num_leaves=386; min_data_in_leaf=774; feature_fraction=0.494; lambda_l2=13.5 : y = 0.93 : 126.6 secs : infill_ei
#
# Fri Aug 01 14:16:47 2025 AUC 0.93044618494897
#
# [mbo] 195: learning_rate=0.0129; num_leaves=63; min_data_in_leaf=415; feature_fraction=0.273; lambda_l2=12.3 : y = 0.93 : 116.2 secs : infill_ei
#
# Fri Aug 01 14:18:18 2025 AUC 0.927135085164195
#
# [mbo] 196: learning_rate=0.0776; num_leaves=931; min_data_in_leaf=1066; feature_fraction=0.952; lambda_l2=9.69 : y = 0.927 : 89.5 secs : infill_ei
#
# Fri Aug 01 14:19:59 2025 AUC 0.925770747863023
#
# [mbo] 197: learning_rate=0.144; num_leaves=344; min_data_in_leaf=3349; feature_fraction=0.484; lambda_l2=2.05 : y = 0.926 : 99.7 secs : infill_ei
#
# Saved the current state after iteration 198 in the file bayesiana.RDATA.
#
# Fri Aug 01 14:21:31 2025 AUC 0.929204954207734
#
# [mbo] 198: learning_rate=0.0143; num_leaves=1388; min_data_in_leaf=1098; feature_fraction=0.67; lambda_l2=5.95 : y = 0.929 : 86.0 secs : infill_ei
#
# Fri Aug 01 14:23:39 2025 AUC 0.930390106336529
#
# [mbo] 199: learning_rate=0.0178; num_leaves=607; min_data_in_leaf=747; feature_fraction=0.37; lambda_l2=1.42 : y = 0.93 : 125.7 secs : infill_ei
#
# Fri Aug 01 14:25:50 2025 AUC 0.930865725076443
#
# [mbo] 200: learning_rate=0.0137; num_leaves=52; min_data_in_leaf=278; feature_fraction=0.477; lambda_l2=6.44 : y = 0.931 : 127.5 secs : infill_ei
#
# Fri Aug 01 14:27:13 2025 AUC 0.926344183519669
#
# [mbo] 201: learning_rate=0.011; num_leaves=948; min_data_in_leaf=4057; feature_fraction=0.235; lambda_l2=4.45 : y = 0.926 : 80.8 secs : infill_ei
#
# Fri Aug 01 14:30:16 2025 AUC 0.929006587104371
#
# [mbo] 202: learning_rate=0.0114; num_leaves=817; min_data_in_leaf=229; feature_fraction=0.632; lambda_l2=1.02 : y = 0.929 : 181.1 secs : infill_ei
#
# Saved the current state after iteration 203 in the file bayesiana.RDATA.
#
# Fri Aug 01 14:32:05 2025 AUC 0.928792402867867
#
# [mbo] 203: learning_rate=0.0101; num_leaves=385; min_data_in_leaf=1771; feature_fraction=0.377; lambda_l2=2.34 : y = 0.929 : 101.3 secs : infill_ei
#
# Fri Aug 01 14:34:18 2025 AUC 0.930021405943157
#
# [mbo] 204: learning_rate=0.0188; num_leaves=153; min_data_in_leaf=548; feature_fraction=0.38; lambda_l2=5.45 : y = 0.93 : 131.4 secs : infill_ei
#
# Fri Aug 01 14:36:20 2025 AUC 0.930571233974751
#
# [mbo] 205: learning_rate=0.0128; num_leaves=397; min_data_in_leaf=733; feature_fraction=0.578; lambda_l2=10.3 : y = 0.931 : 119.7 secs : infill_ei
#
# Fri Aug 01 14:39:30 2025 AUC 0.929650683957094
#
# [mbo] 206: learning_rate=0.0124; num_leaves=1046; min_data_in_leaf=244; feature_fraction=0.403; lambda_l2=0.699 : y = 0.93 : 188.4 secs : infill_ei
#
# Fri Aug 01 14:41:49 2025 AUC 0.930578710795738
#
# [mbo] 207: learning_rate=0.0148; num_leaves=1203; min_data_in_leaf=619; feature_fraction=0.445; lambda_l2=8.41 : y = 0.931 : 136.1 secs : infill_ei
#
# Saved the current state after iteration 208 in the file bayesiana.RDATA.
#
# Fri Aug 01 14:43:13 2025 AUC 0.922225521238579
#
# [mbo] 208: learning_rate=0.27; num_leaves=1101; min_data_in_leaf=3844; feature_fraction=0.165; lambda_l2=3.39 : y = 0.922 : 77.7 secs : infill_ei
#
# Fri Aug 01 14:45:36 2025 AUC 0.930765275021807
#
# [mbo] 209: learning_rate=0.0172; num_leaves=801; min_data_in_leaf=290; feature_fraction=0.258; lambda_l2=10.9 : y = 0.931 : 141.1 secs : infill_ei
#
# Fri Aug 01 14:47:22 2025 AUC 0.930274462425436
#
# [mbo] 210: learning_rate=0.0174; num_leaves=1406; min_data_in_leaf=672; feature_fraction=0.697; lambda_l2=10.7 : y = 0.93 : 103.2 secs : infill_ei
#
# Fri Aug 01 14:49:24 2025 AUC 0.930284770987721
#
# [mbo] 211: learning_rate=0.0538; num_leaves=1054; min_data_in_leaf=718; feature_fraction=0.329; lambda_l2=12.4 : y = 0.93 : 120.9 secs : infill_ei
#
# Fri Aug 01 14:51:40 2025 AUC 0.930876921497489
#
# [mbo] 212: learning_rate=0.017; num_leaves=1437; min_data_in_leaf=714; feature_fraction=0.449; lambda_l2=3.51 : y = 0.931 : 133.3 secs : infill_ei
#
# Fri Aug 01 14:53:26 2025 AUC 0.925184580504718
#
# [mbo] 213: learning_rate=0.167; num_leaves=930; min_data_in_leaf=2676; feature_fraction=0.41; lambda_l2=3.07 : y = 0.925 : 104.7 secs : infill_ei
#
# Saved the current state after iteration 214 in the file bayesiana.RDATA.
#
# Fri Aug 01 14:55:33 2025 AUC 0.931182566973149
#
# [mbo] 214: learning_rate=0.0116; num_leaves=208; min_data_in_leaf=823; feature_fraction=0.356; lambda_l2=10.4 : y = 0.931 : 118.2 secs : infill_ei
#
# Fri Aug 01 14:57:31 2025 AUC 0.929102172936135
#
# [mbo] 215: learning_rate=0.0189; num_leaves=985; min_data_in_leaf=1651; feature_fraction=0.462; lambda_l2=13.5 : y = 0.929 : 115.9 secs : infill_ei
#
# Fri Aug 01 14:59:39 2025 AUC 0.931452248390727
#
# [mbo] 216: learning_rate=0.0107; num_leaves=398; min_data_in_leaf=668; feature_fraction=0.306; lambda_l2=7.62 : y = 0.931 : 125.1 secs : infill_ei
#
# Fri Aug 01 15:01:52 2025 AUC 0.930999662474427
#
# [mbo] 217: learning_rate=0.016; num_leaves=928; min_data_in_leaf=630; feature_fraction=0.333; lambda_l2=9.49 : y = 0.931 : 131.0 secs : infill_ei
#
# Fri Aug 01 15:03:36 2025 AUC 0.932526714126181
#
# [mbo] 218: learning_rate=0.0133; num_leaves=22; min_data_in_leaf=117; feature_fraction=0.371; lambda_l2=10.8 : y = 0.933 : 102.1 secs : infill_ei
#
# Saved the current state after iteration 219 in the file bayesiana.RDATA.
#
# Fri Aug 01 15:05:36 2025 AUC 0.931453442415197
#
# [mbo] 219: learning_rate=0.00775; num_leaves=702; min_data_in_leaf=648; feature_fraction=0.207; lambda_l2=10.4 : y = 0.931 : 112.6 secs : infill_ei
#
# Fri Aug 01 15:06:26 2025 AUC 0.924068236847046
#
# [mbo] 220: learning_rate=0.255; num_leaves=143; min_data_in_leaf=6676; feature_fraction=0.745; lambda_l2=9.91 : y = 0.924 : 48.7 secs : infill_ei
#
# Fri Aug 01 15:09:00 2025 AUC 0.931282777769281
#
# [mbo] 221: learning_rate=0.0112; num_leaves=782; min_data_in_leaf=439; feature_fraction=0.435; lambda_l2=12.1 : y = 0.931 : 152.1 secs : infill_ei
#
# Fri Aug 01 15:11:12 2025 AUC 0.92850788327705
#
# [mbo] 222: learning_rate=0.0144; num_leaves=701; min_data_in_leaf=1161; feature_fraction=0.531; lambda_l2=1.73 : y = 0.929 : 129.1 secs : infill_ei
#
# Fri Aug 01 15:12:35 2025 AUC 0.925193984520145
#
# [mbo] 223: learning_rate=0.0963; num_leaves=76; min_data_in_leaf=5991; feature_fraction=0.219; lambda_l2=5.92 : y = 0.925 : 81.7 secs : infill_ei
#
# Fri Aug 01 15:14:18 2025 AUC 0.929654814649538
#
# [mbo] 224: learning_rate=0.0165; num_leaves=62; min_data_in_leaf=775; feature_fraction=0.67; lambda_l2=7.56 : y = 0.93 : 100.9 secs : infill_ei
#
# Saved the current state after iteration 225 in the file bayesiana.RDATA.
#
# Fri Aug 01 15:15:55 2025 AUC 0.930087003600995
#
# [mbo] 225: learning_rate=0.0107; num_leaves=939; min_data_in_leaf=1198; feature_fraction=0.682; lambda_l2=2.79 : y = 0.93 : 89.3 secs : infill_ei
#
# Fri Aug 01 15:18:12 2025 AUC 0.930883842030567
#
# [mbo] 226: learning_rate=0.0316; num_leaves=1070; min_data_in_leaf=720; feature_fraction=0.378; lambda_l2=10.9 : y = 0.931 : 135.2 secs : infill_ei
#
# Fri Aug 01 15:20:18 2025 AUC 0.931063438958949
#
# [mbo] 227: learning_rate=0.017; num_leaves=1128; min_data_in_leaf=956; feature_fraction=0.37; lambda_l2=10.9 : y = 0.931 : 124.2 secs : infill_ei
#
# Fri Aug 01 15:22:08 2025 AUC 0.931016026090398
#
# [mbo] 228: learning_rate=0.0148; num_leaves=266; min_data_in_leaf=958; feature_fraction=0.233; lambda_l2=12.7 : y = 0.931 : 108.0 secs : infill_ei
#
# Fri Aug 01 15:25:00 2025 AUC 0.930128572482732
#
# [mbo] 229: learning_rate=0.0151; num_leaves=1129; min_data_in_leaf=358; feature_fraction=0.571; lambda_l2=11.8 : y = 0.93 : 168.9 secs : infill_ei
#
# Saved the current state after iteration 230 in the file bayesiana.RDATA.
#
# Fri Aug 01 15:27:06 2025 AUC 0.930459877613198
#
# [mbo] 230: learning_rate=0.018; num_leaves=249; min_data_in_leaf=704; feature_fraction=0.26; lambda_l2=14.4 : y = 0.93 : 117.9 secs : infill_ei
#
# Fri Aug 01 15:29:13 2025 AUC 0.929959896444871
#
# [mbo] 231: learning_rate=0.0176; num_leaves=133; min_data_in_leaf=852; feature_fraction=0.377; lambda_l2=12 : y = 0.93 : 125.0 secs : infill_ei
#
# Fri Aug 01 15:31:28 2025 AUC 0.931383748959211
#
# [mbo] 232: learning_rate=0.013; num_leaves=1529; min_data_in_leaf=691; feature_fraction=0.349; lambda_l2=14.2 : y = 0.931 : 131.9 secs : infill_ei
#
# Fri Aug 01 15:32:17 2025 AUC 0.924671809255409
#
# [mbo] 233: learning_rate=0.111; num_leaves=438; min_data_in_leaf=6662; feature_fraction=0.839; lambda_l2=4.23 : y = 0.925 : 47.7 secs : infill_ei
#
# Fri Aug 01 15:34:54 2025 AUC 0.929795584019529
#
# [mbo] 234: learning_rate=0.0165; num_leaves=923; min_data_in_leaf=331; feature_fraction=0.337; lambda_l2=3.69 : y = 0.93 : 155.1 secs : infill_ei
#
# Fri Aug 01 15:37:13 2025 AUC 0.930259342897054
#
# [mbo] 235: learning_rate=0.0164; num_leaves=1192; min_data_in_leaf=506; feature_fraction=0.368; lambda_l2=14.2 : y = 0.93 : 136.0 secs : infill_ei
#
# Saved the current state after iteration 236 in the file bayesiana.RDATA.
#
# Fri Aug 01 15:39:47 2025 AUC 0.930314647328082
#
# [mbo] 236: learning_rate=0.0133; num_leaves=112; min_data_in_leaf=309; feature_fraction=0.344; lambda_l2=10.6 : y = 0.93 : 146.2 secs : infill_ei
#
# Fri Aug 01 15:41:58 2025 AUC 0.930174445183961
#
# [mbo] 237: learning_rate=0.0147; num_leaves=632; min_data_in_leaf=962; feature_fraction=0.443; lambda_l2=11.7 : y = 0.93 : 128.8 secs : infill_ei
#
# Fri Aug 01 15:45:19 2025 AUC 0.930813974211106
#
# [mbo] 238: learning_rate=0.021; num_leaves=989; min_data_in_leaf=182; feature_fraction=0.412; lambda_l2=10.8 : y = 0.931 : 198.3 secs : infill_ei
#
# Fri Aug 01 15:46:14 2025 AUC 0.926198510757457
#
# [mbo] 239: learning_rate=0.0446; num_leaves=874; min_data_in_leaf=5737; feature_fraction=0.904; lambda_l2=4.83 : y = 0.926 : 54.0 secs : infill_ei
#
# Fri Aug 01 15:48:11 2025 AUC 0.931012075348549
#
# [mbo] 240: learning_rate=0.0167; num_leaves=28; min_data_in_leaf=988; feature_fraction=0.547; lambda_l2=8.52 : y = 0.931 : 114.5 secs : infill_ei
#
# Saved the current state after iteration 241 in the file bayesiana.RDATA.
#
# Fri Aug 01 15:50:11 2025 AUC 0.928125296539683
#
# [mbo] 241: learning_rate=0.157; num_leaves=1021; min_data_in_leaf=816; feature_fraction=0.797; lambda_l2=0.59 : y = 0.928 : 110.6 secs : infill_ei
#
# Fri Aug 01 15:52:02 2025 AUC 0.929812419248524
#
# [mbo] 242: learning_rate=0.0138; num_leaves=34; min_data_in_leaf=1408; feature_fraction=0.352; lambda_l2=10.6 : y = 0.93 : 108.4 secs : infill_ei
#
# Fri Aug 01 15:54:28 2025 AUC 0.930905196674968
#
# [mbo] 243: learning_rate=0.0184; num_leaves=847; min_data_in_leaf=719; feature_fraction=0.499; lambda_l2=9.94 : y = 0.931 : 141.7 secs : infill_ei
#
# Fri Aug 01 15:56:46 2025 AUC 0.930419312918959
#
# [mbo] 244: learning_rate=0.0143; num_leaves=685; min_data_in_leaf=469; feature_fraction=0.296; lambda_l2=10.7 : y = 0.93 : 134.6 secs : infill_ei
#
# Fri Aug 01 15:58:12 2025 AUC 0.924270274068152
#
# [mbo] 245: learning_rate=0.0411; num_leaves=1109; min_data_in_leaf=7159; feature_fraction=0.28; lambda_l2=12.8 : y = 0.924 : 84.5 secs : infill_ei
#
# Fri Aug 01 16:00:25 2025 AUC 0.931477834161527
#
# [mbo] 246: learning_rate=0.0141; num_leaves=186; min_data_in_leaf=666; feature_fraction=0.388; lambda_l2=14.2 : y = 0.931 : 131.3 secs : infill_ei
#
# Saved the current state after iteration 247 in the file bayesiana.RDATA.
#
# Fri Aug 01 16:03:20 2025 AUC 0.929945574321881
#
# [mbo] 247: learning_rate=0.0139; num_leaves=1479; min_data_in_leaf=398; feature_fraction=0.497; lambda_l2=12 : y = 0.93 : 166.4 secs : infill_ei
#
# Fri Aug 01 16:05:17 2025 AUC 0.931076012493759
#
# [mbo] 248: learning_rate=0.0147; num_leaves=292; min_data_in_leaf=706; feature_fraction=0.226; lambda_l2=10.2 : y = 0.931 : 113.7 secs : infill_ei
#
# Fri Aug 01 16:06:44 2025 AUC 0.923910471624787
#
# [mbo] 249: learning_rate=0.273; num_leaves=745; min_data_in_leaf=6682; feature_fraction=0.296; lambda_l2=6.79 : y = 0.924 : 85.5 secs : infill_ei
#
# Fri Aug 01 16:08:31 2025 AUC 0.92778502631957
#
# [mbo] 250: learning_rate=0.0169; num_leaves=60; min_data_in_leaf=2970; feature_fraction=0.476; lambda_l2=4.25 : y = 0.928 : 104.9 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "learning_rate"    "num_leaves"       "min_data_in_leaf" "feature_fraction"
#  [5] "lambda_l2"        "y"                "dob"              "eol"
#  [9] "error.message"    "exec.time"        "ei"               "error.model"
# [13] "train.time"       "prop.type"        "propose.time"     "se"
# [17] "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    learning_rate num_leaves min_data_in_leaf feature_fraction lambda_l2
#            <num>      <int>            <int>            <num>     <num>
# 1:    0.01332672         22              117          0.37095  10.78571
# [1] 0.9325267

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 888757
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 10.78571
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 1
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 2000
#
# $learning_rate
# [1] 0.01332672
#
# $feature_fraction
# [1] 0.37095
#
# $num_leaves
# [1] 22
#
# $min_data_in_leaf
# [1] 117

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Fri Aug 01 16:10:59 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
