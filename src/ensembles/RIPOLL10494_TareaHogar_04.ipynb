# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# Esta Tarea para el Hogar 02 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el viernes 01-agosto

# %% [markdown]
# ##  1. Cazatalentos

# %% [markdown]
# En la Clase 03 nos hemos enfrentado a  "La Maldicion del Ganandor",  elegir el modelo con el mejor puntaje simple no suele ser la mejor estrategia.
# <br> Lea y ejecute el notebook  **src/CazaTalentos/CazaTalentos.ipynb**
# <br> en caso de interesarle, participe del Desafío Ordenamiento  que vence el sábado 02 de agosto a las 19:00

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dm"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dm" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/itba2025-8d0a/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Jul 24 13:36:49 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  656930 35.1 1439380    76.9 1431363  76.5
# Vcells 1224847  9.4 8388608    64.0 1924958  14.7

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 4949
PARAM$semilla_primigenia <- 100887

# %%
PARAM$kaggle$competencia <- "data-mining-analista-sr-2025-a"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
makeNumericParam("learning_rate", lower = 0.01, upper = 0.015),
makeNumericParam("feature_fraction", lower = 0.30, upper = 0.37),
makeNumericParam("bagging_fraction", lower = 0.75, upper = 0.85),
makeIntegerParam("num_leaves", lower = 20L, upper = 35L),
makeIntegerParam("min_data_in_leaf", lower = 700L, upper = 760L)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 50 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83368
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Thu Jul 24 13:39:47 2025 AUC 0.930846208908838
#
# Thu Jul 24 13:40:53 2025 AUC 0.930926561705809
#
# Thu Jul 24 13:41:57 2025 AUC 0.931439799997353
#
# Thu Jul 24 13:43:01 2025 AUC 0.930211070215943
#
# Thu Jul 24 13:44:02 2025 AUC 0.931027915416772
#
# Thu Jul 24 13:44:59 2025 AUC 0.930955341619379
#
# Thu Jul 24 13:46:02 2025 AUC 0.93142676929712
#
# Thu Jul 24 13:47:01 2025 AUC 0.931086962697325
#
# Thu Jul 24 13:48:02 2025 AUC 0.931142186851886
#
# Thu Jul 24 13:49:01 2025 AUC 0.930969790940649
#
# Thu Jul 24 13:50:04 2025 AUC 0.931903182162981
#
# Thu Jul 24 13:51:10 2025 AUC 0.930221798601888
#
# Thu Jul 24 13:52:06 2025 AUC 0.930357576555877
#
# Thu Jul 24 13:53:06 2025 AUC 0.930374938708022
#
# Thu Jul 24 13:54:10 2025 AUC 0.931423352953327
#
# Thu Jul 24 13:55:13 2025 AUC 0.930056980269355
#
# Thu Jul 24 13:56:15 2025 AUC 0.931837348918687
#
# Thu Jul 24 13:57:16 2025 AUC 0.931002422999647
#
# Thu Jul 24 13:58:22 2025 AUC 0.931009559559793
#
# Thu Jul 24 13:59:25 2025 AUC 0.930913295863337
#
# [mbo] 0: learning_rate=0.0118; feature_fraction=0.35; bagging_fraction=0.817; num_leaves=26; min_data_in_leaf=752 : y = 0.931 : 62.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0136; feature_fraction=0.338; bagging_fraction=0.807; num_leaves=29; min_data_in_leaf=709 : y = 0.931 : 65.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.013; feature_fraction=0.327; bagging_fraction=0.787; num_leaves=30; min_data_in_leaf=713 : y = 0.931 : 64.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0112; feature_fraction=0.321; bagging_fraction=0.836; num_leaves=31; min_data_in_leaf=756 : y = 0.93 : 63.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0103; feature_fraction=0.342; bagging_fraction=0.784; num_leaves=22; min_data_in_leaf=731 : y = 0.931 : 61.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0127; feature_fraction=0.319; bagging_fraction=0.811; num_leaves=21; min_data_in_leaf=721 : y = 0.931 : 57.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.01; feature_fraction=0.305; bagging_fraction=0.774; num_leaves=34; min_data_in_leaf=737 : y = 0.931 : 62.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0144; feature_fraction=0.33; bagging_fraction=0.777; num_leaves=26; min_data_in_leaf=707 : y = 0.931 : 59.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0108; feature_fraction=0.354; bagging_fraction=0.831; num_leaves=24; min_data_in_leaf=727 : y = 0.931 : 60.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.014; feature_fraction=0.357; bagging_fraction=0.77; num_leaves=23; min_data_in_leaf=745 : y = 0.931 : 59.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0116; feature_fraction=0.362; bagging_fraction=0.797; num_leaves=28; min_data_in_leaf=746 : y = 0.932 : 63.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0135; feature_fraction=0.37; bagging_fraction=0.754; num_leaves=35; min_data_in_leaf=727 : y = 0.93 : 65.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0148; feature_fraction=0.316; bagging_fraction=0.756; num_leaves=20; min_data_in_leaf=734 : y = 0.93 : 56.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0106; feature_fraction=0.312; bagging_fraction=0.804; num_leaves=27; min_data_in_leaf=704 : y = 0.93 : 60.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.012; feature_fraction=0.346; bagging_fraction=0.849; num_leaves=32; min_data_in_leaf=721 : y = 0.931 : 63.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0131; feature_fraction=0.31; bagging_fraction=0.792; num_leaves=33; min_data_in_leaf=741 : y = 0.93 : 63.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0142; feature_fraction=0.303; bagging_fraction=0.825; num_leaves=25; min_data_in_leaf=701 : y = 0.932 : 62.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0124; feature_fraction=0.333; bagging_fraction=0.844; num_leaves=21; min_data_in_leaf=751 : y = 0.931 : 60.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0147; feature_fraction=0.366; bagging_fraction=0.821; num_leaves=34; min_data_in_leaf=759 : y = 0.931 : 66.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0114; feature_fraction=0.341; bagging_fraction=0.762; num_leaves=28; min_data_in_leaf=716 : y = 0.931 : 62.6 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Thu Jul 24 14:00:29 2025 AUC 0.931256695056926
#
# [mbo] 1: learning_rate=0.0101; feature_fraction=0.362; bagging_fraction=0.849; num_leaves=23; min_data_in_leaf=747 : y = 0.931 : 61.0 secs : infill_ei
#
# Thu Jul 24 14:01:34 2025 AUC 0.931272599161645
#
# [mbo] 2: learning_rate=0.0125; feature_fraction=0.362; bagging_fraction=0.785; num_leaves=32; min_data_in_leaf=747 : y = 0.931 : 64.0 secs : infill_ei
#
# Thu Jul 24 14:02:35 2025 AUC 0.93154329612711
#
# [mbo] 3: learning_rate=0.0135; feature_fraction=0.327; bagging_fraction=0.849; num_leaves=30; min_data_in_leaf=746 : y = 0.932 : 60.4 secs : infill_ei
#
# Thu Jul 24 14:03:38 2025 AUC 0.93045426789409
#
# [mbo] 4: learning_rate=0.0116; feature_fraction=0.362; bagging_fraction=0.757; num_leaves=27; min_data_in_leaf=731 : y = 0.93 : 62.0 secs : infill_ei
#
# Thu Jul 24 14:04:41 2025 AUC 0.931357616286746
#
# [mbo] 5: learning_rate=0.0101; feature_fraction=0.338; bagging_fraction=0.757; num_leaves=28; min_data_in_leaf=746 : y = 0.931 : 62.5 secs : infill_ei
#
# Thu Jul 24 14:05:45 2025 AUC 0.931099622840148
#
# [mbo] 6: learning_rate=0.0112; feature_fraction=0.363; bagging_fraction=0.795; num_leaves=28; min_data_in_leaf=726 : y = 0.931 : 63.8 secs : infill_ei
#
# Thu Jul 24 14:06:49 2025 AUC 0.930414752922975
#
# [mbo] 7: learning_rate=0.012; feature_fraction=0.363; bagging_fraction=0.804; num_leaves=28; min_data_in_leaf=758 : y = 0.93 : 63.2 secs : infill_ei
#
# Thu Jul 24 14:07:52 2025 AUC 0.931152470629467
#
# [mbo] 8: learning_rate=0.0119; feature_fraction=0.367; bagging_fraction=0.813; num_leaves=28; min_data_in_leaf=745 : y = 0.931 : 62.1 secs : infill_ei
#
# Thu Jul 24 14:08:53 2025 AUC 0.930444249509049
#
# [mbo] 9: learning_rate=0.0112; feature_fraction=0.36; bagging_fraction=0.798; num_leaves=24; min_data_in_leaf=753 : y = 0.93 : 60.5 secs : infill_ei
#
# Thu Jul 24 14:09:56 2025 AUC 0.930872000828147
#
# [mbo] 10: learning_rate=0.0104; feature_fraction=0.342; bagging_fraction=0.797; num_leaves=28; min_data_in_leaf=755 : y = 0.931 : 61.6 secs : infill_ei
#
# Saved the current state after iteration 11 in the file bayesiana.RDATA.
#
# Thu Jul 24 14:11:03 2025 AUC 0.931108958009525
#
# [mbo] 11: learning_rate=0.0136; feature_fraction=0.357; bagging_fraction=0.842; num_leaves=28; min_data_in_leaf=746 : y = 0.931 : 63.8 secs : infill_ei
#
# Thu Jul 24 14:12:05 2025 AUC 0.93067230431807
#
# [mbo] 12: learning_rate=0.0103; feature_fraction=0.363; bagging_fraction=0.786; num_leaves=24; min_data_in_leaf=743 : y = 0.931 : 61.0 secs : infill_ei
#
# Thu Jul 24 14:13:06 2025 AUC 0.929970333225022
#
# [mbo] 13: learning_rate=0.0116; feature_fraction=0.34; bagging_fraction=0.812; num_leaves=29; min_data_in_leaf=746 : y = 0.93 : 60.3 secs : infill_ei
#
# Thu Jul 24 14:14:09 2025 AUC 0.930977635571413
#
# [mbo] 14: learning_rate=0.0103; feature_fraction=0.32; bagging_fraction=0.756; num_leaves=31; min_data_in_leaf=719 : y = 0.931 : 62.3 secs : infill_ei
#
# Thu Jul 24 14:15:10 2025 AUC 0.930946509506389
#
# [mbo] 15: learning_rate=0.0125; feature_fraction=0.36; bagging_fraction=0.788; num_leaves=27; min_data_in_leaf=755 : y = 0.931 : 60.6 secs : infill_ei
#
# Thu Jul 24 14:16:08 2025 AUC 0.931480137289902
#
# [mbo] 16: learning_rate=0.0123; feature_fraction=0.305; bagging_fraction=0.849; num_leaves=24; min_data_in_leaf=710 : y = 0.931 : 57.7 secs : infill_ei
#
# Thu Jul 24 14:17:14 2025 AUC 0.931514086017325
#
# [mbo] 17: learning_rate=0.0118; feature_fraction=0.365; bagging_fraction=0.789; num_leaves=34; min_data_in_leaf=750 : y = 0.932 : 64.6 secs : infill_ei
#
# Thu Jul 24 14:18:15 2025 AUC 0.930439195406555
#
# [mbo] 18: learning_rate=0.0116; feature_fraction=0.328; bagging_fraction=0.775; num_leaves=29; min_data_in_leaf=744 : y = 0.93 : 61.2 secs : infill_ei
#
# Thu Jul 24 14:19:14 2025 AUC 0.930291931127789
#
# [mbo] 19: learning_rate=0.0146; feature_fraction=0.31; bagging_fraction=0.763; num_leaves=24; min_data_in_leaf=720 : y = 0.93 : 58.2 secs : infill_ei
#
# Thu Jul 24 14:20:17 2025 AUC 0.930015274863266
#
# [mbo] 20: learning_rate=0.0102; feature_fraction=0.334; bagging_fraction=0.764; num_leaves=28; min_data_in_leaf=711 : y = 0.93 : 62.2 secs : infill_ei
#
# Saved the current state after iteration 21 in the file bayesiana.RDATA.
#
# Thu Jul 24 14:21:25 2025 AUC 0.930739518397975
#
# [mbo] 21: learning_rate=0.0113; feature_fraction=0.314; bagging_fraction=0.77; num_leaves=33; min_data_in_leaf=709 : y = 0.931 : 62.8 secs : infill_ei
#
# Thu Jul 24 14:22:26 2025 AUC 0.93115260933308
#
# [mbo] 22: learning_rate=0.0129; feature_fraction=0.351; bagging_fraction=0.835; num_leaves=22; min_data_in_leaf=735 : y = 0.931 : 59.8 secs : infill_ei
#
# Thu Jul 24 14:23:26 2025 AUC 0.931234840131889
#
# [mbo] 23: learning_rate=0.0123; feature_fraction=0.335; bagging_fraction=0.784; num_leaves=20; min_data_in_leaf=740 : y = 0.931 : 59.0 secs : infill_ei
#
# Thu Jul 24 14:24:28 2025 AUC 0.931032360803153
#
# [mbo] 24: learning_rate=0.0105; feature_fraction=0.317; bagging_fraction=0.8; num_leaves=29; min_data_in_leaf=720 : y = 0.931 : 61.7 secs : infill_ei
#
# Thu Jul 24 14:25:26 2025 AUC 0.931392019410045
#
# [mbo] 25: learning_rate=0.011; feature_fraction=0.304; bagging_fraction=0.809; num_leaves=22; min_data_in_leaf=717 : y = 0.931 : 57.3 secs : infill_ei
#
# Thu Jul 24 14:26:30 2025 AUC 0.931589873725432
#
# [mbo] 26: learning_rate=0.0148; feature_fraction=0.364; bagging_fraction=0.827; num_leaves=32; min_data_in_leaf=744 : y = 0.932 : 63.7 secs : infill_ei
#
# Thu Jul 24 14:27:36 2025 AUC 0.930549968800335
#
# [mbo] 27: learning_rate=0.0121; feature_fraction=0.344; bagging_fraction=0.812; num_leaves=35; min_data_in_leaf=729 : y = 0.931 : 64.4 secs : infill_ei
#
# Thu Jul 24 14:28:36 2025 AUC 0.930743656890269
#
# [mbo] 28: learning_rate=0.0123; feature_fraction=0.343; bagging_fraction=0.756; num_leaves=24; min_data_in_leaf=750 : y = 0.931 : 59.5 secs : infill_ei
#
# Thu Jul 24 14:29:41 2025 AUC 0.931298725613448
#
# [mbo] 29: learning_rate=0.0128; feature_fraction=0.347; bagging_fraction=0.814; num_leaves=31; min_data_in_leaf=714 : y = 0.931 : 64.8 secs : infill_ei
#
# Thu Jul 24 14:30:46 2025 AUC 0.931699555400182
#
# [mbo] 30: learning_rate=0.0106; feature_fraction=0.365; bagging_fraction=0.848; num_leaves=32; min_data_in_leaf=726 : y = 0.932 : 64.0 secs : infill_ei
#
# Saved the current state after iteration 31 in the file bayesiana.RDATA.
#
# Thu Jul 24 14:31:51 2025 AUC 0.930599608080667
#
# [mbo] 31: learning_rate=0.0114; feature_fraction=0.322; bagging_fraction=0.832; num_leaves=31; min_data_in_leaf=710 : y = 0.931 : 61.4 secs : infill_ei
#
# Thu Jul 24 14:32:50 2025 AUC 0.930839035954751
#
# [mbo] 32: learning_rate=0.0122; feature_fraction=0.323; bagging_fraction=0.804; num_leaves=25; min_data_in_leaf=712 : y = 0.931 : 58.4 secs : infill_ei
#
# Thu Jul 24 14:33:51 2025 AUC 0.930793186678688
#
# [mbo] 33: learning_rate=0.014; feature_fraction=0.308; bagging_fraction=0.814; num_leaves=34; min_data_in_leaf=751 : y = 0.931 : 60.3 secs : infill_ei
#
# Thu Jul 24 14:34:53 2025 AUC 0.931046647218699
#
# [mbo] 34: learning_rate=0.0123; feature_fraction=0.342; bagging_fraction=0.776; num_leaves=27; min_data_in_leaf=745 : y = 0.931 : 60.6 secs : infill_ei
#
# Thu Jul 24 14:35:55 2025 AUC 0.930901711705729
#
# [mbo] 35: learning_rate=0.0107; feature_fraction=0.31; bagging_fraction=0.791; num_leaves=33; min_data_in_leaf=730 : y = 0.931 : 61.4 secs : infill_ei
#
# Thu Jul 24 14:36:51 2025 AUC 0.931811452035519
#
# [mbo] 36: learning_rate=0.0131; feature_fraction=0.322; bagging_fraction=0.832; num_leaves=20; min_data_in_leaf=745 : y = 0.932 : 55.8 secs : infill_ei
#
# Thu Jul 24 14:37:49 2025 AUC 0.930600488269887
#
# [mbo] 37: learning_rate=0.0139; feature_fraction=0.337; bagging_fraction=0.774; num_leaves=22; min_data_in_leaf=740 : y = 0.931 : 56.9 secs : infill_ei
#
# Thu Jul 24 14:38:52 2025 AUC 0.931609692275142
#
# [mbo] 38: learning_rate=0.0112; feature_fraction=0.339; bagging_fraction=0.81; num_leaves=33; min_data_in_leaf=708 : y = 0.932 : 62.5 secs : infill_ei
#
# Thu Jul 24 14:39:51 2025 AUC 0.931108861027973
#
# [mbo] 39: learning_rate=0.0113; feature_fraction=0.37; bagging_fraction=0.8; num_leaves=21; min_data_in_leaf=728 : y = 0.931 : 58.3 secs : infill_ei
#
# Thu Jul 24 14:40:48 2025 AUC 0.93091634737052
#
# [mbo] 40: learning_rate=0.0132; feature_fraction=0.328; bagging_fraction=0.823; num_leaves=20; min_data_in_leaf=746 : y = 0.931 : 56.4 secs : infill_ei
#
# Thu Jul 24 14:41:53 2025 AUC 0.93026680362198
#
# [mbo] 41: learning_rate=0.0133; feature_fraction=0.334; bagging_fraction=0.827; num_leaves=35; min_data_in_leaf=708 : y = 0.93 : 64.1 secs : infill_ei
#
# Saved the current state after iteration 42 in the file bayesiana.RDATA.
#
# Thu Jul 24 14:43:00 2025 AUC 0.931298284811145
#
# [mbo] 42: learning_rate=0.0104; feature_fraction=0.345; bagging_fraction=0.784; num_leaves=29; min_data_in_leaf=717 : y = 0.931 : 62.3 secs : infill_ei
#
# Thu Jul 24 14:44:01 2025 AUC 0.931098532520592
#
# [mbo] 43: learning_rate=0.0115; feature_fraction=0.365; bagging_fraction=0.776; num_leaves=23; min_data_in_leaf=760 : y = 0.931 : 59.8 secs : infill_ei
#
# Thu Jul 24 14:45:03 2025 AUC 0.930677652322295
#
# [mbo] 44: learning_rate=0.0129; feature_fraction=0.341; bagging_fraction=0.764; num_leaves=32; min_data_in_leaf=745 : y = 0.931 : 61.5 secs : infill_ei
#
# Thu Jul 24 14:46:08 2025 AUC 0.930617877395847
#
# [mbo] 45: learning_rate=0.011; feature_fraction=0.359; bagging_fraction=0.766; num_leaves=35; min_data_in_leaf=713 : y = 0.931 : 64.0 secs : infill_ei
#
# Thu Jul 24 14:47:05 2025 AUC 0.930229341677206
#
# [mbo] 46: learning_rate=0.0149; feature_fraction=0.302; bagging_fraction=0.818; num_leaves=23; min_data_in_leaf=739 : y = 0.93 : 56.4 secs : infill_ei
#
# Thu Jul 24 14:48:08 2025 AUC 0.931578524576436
#
# [mbo] 47: learning_rate=0.013; feature_fraction=0.337; bagging_fraction=0.818; num_leaves=30; min_data_in_leaf=725 : y = 0.932 : 62.1 secs : infill_ei
#
# Thu Jul 24 14:49:12 2025 AUC 0.931830575704824
#
# [mbo] 48: learning_rate=0.0118; feature_fraction=0.363; bagging_fraction=0.848; num_leaves=34; min_data_in_leaf=713 : y = 0.932 : 63.9 secs : infill_ei
#
# Thu Jul 24 14:50:12 2025 AUC 0.930560453091417
#
# [mbo] 49: learning_rate=0.0138; feature_fraction=0.303; bagging_fraction=0.791; num_leaves=22; min_data_in_leaf=701 : y = 0.931 : 58.6 secs : infill_ei
#
# Thu Jul 24 14:51:11 2025 AUC 0.930961295441848
#
# [mbo] 50: learning_rate=0.0114; feature_fraction=0.327; bagging_fraction=0.765; num_leaves=23; min_data_in_leaf=710 : y = 0.931 : 57.9 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "learning_rate"    "feature_fraction" "bagging_fraction" "num_leaves"
#  [5] "min_data_in_leaf" "y"                "dob"              "eol"
#  [9] "error.message"    "exec.time"        "ei"               "error.model"
# [13] "train.time"       "prop.type"        "propose.time"     "se"
# [17] "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    learning_rate feature_fraction bagging_fraction num_leaves min_data_in_leaf
#            <num>            <num>            <num>      <int>            <int>
# 1:    0.01162412        0.3617761        0.7973589         28              746
# [1] 0.9319032

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 100887
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 0
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 0.7973589
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1200
#
# $learning_rate
# [1] 0.01162412
#
# $feature_fraction
# [1] 0.3617761
#
# $num_leaves
# [1] 28
#
# $min_data_in_leaf
# [1] 746

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Jul 24 14:52:43 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
