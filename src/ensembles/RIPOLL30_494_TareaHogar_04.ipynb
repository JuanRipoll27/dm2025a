# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# Esta Tarea para el Hogar 02 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el viernes 01-agosto

# %% [markdown]
# ##  1. Cazatalentos

# %% [markdown]
# En la Clase 03 nos hemos enfrentado a  "La Maldicion del Ganandor",  elegir el modelo con el mejor puntaje simple no suele ser la mejor estrategia.
# <br> Lea y ejecute el notebook  **src/CazaTalentos/CazaTalentos.ipynb**
# <br> en caso de interesarle, participe del Desafío Ordenamiento  que vence el sábado 02 de agosto a las 19:00

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dm"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dm" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/itba2025-8d0a/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Jul 31 13:34:46 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  656930 35.1 1439374    76.9 1431358  76.5
# Vcells 1224847  9.4 8388608    64.0 1924958  14.7

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 4969
PARAM$semilla_primigenia <- 333757

# %%
PARAM$kaggle$competencia <- "data-mining-analista-sr-2025-a"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 2000,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeNumericParam("learning_rate",       lower = 0.008,  upper = 0.02),
  makeIntegerParam("num_leaves",          lower = 30L,    upper = 150L),
  makeIntegerParam("min_data_in_leaf",    lower = 20L,    upper = 300L),
  makeNumericParam("feature_fraction",    lower = 0.25,   upper = 0.55),
  makeNumericParam("lambda_l2",           lower = 5.0,    upper = 13.0)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 200 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83552
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Thu Jul 31 13:40:23 2025 AUC 0.92894102204473
#
# Thu Jul 31 13:42:58 2025 AUC 0.930173115250087
#
# Thu Jul 31 13:45:25 2025 AUC 0.931198521178968
#
# Thu Jul 31 13:47:52 2025 AUC 0.930026480386192
#
# Thu Jul 31 13:50:22 2025 AUC 0.930042096181226
#
# Thu Jul 31 13:52:51 2025 AUC 0.930996261428656
#
# Thu Jul 31 13:55:03 2025 AUC 0.930194200767327
#
# Thu Jul 31 13:57:31 2025 AUC 0.930168216382941
#
# Thu Jul 31 13:59:55 2025 AUC 0.931403629611297
#
# Thu Jul 31 14:02:48 2025 AUC 0.929405604389721
#
# Thu Jul 31 14:04:41 2025 AUC 0.931681179424663
#
# Thu Jul 31 14:07:38 2025 AUC 0.929433457192419
#
# Thu Jul 31 14:09:56 2025 AUC 0.931234325712338
#
# Thu Jul 31 14:12:07 2025 AUC 0.930566958104413
#
# Thu Jul 31 14:14:07 2025 AUC 0.930874701000773
#
# Thu Jul 31 14:16:40 2025 AUC 0.930249395571295
#
# Thu Jul 31 14:18:43 2025 AUC 0.931614697335285
#
# Thu Jul 31 14:21:17 2025 AUC 0.930341849667392
#
# Thu Jul 31 14:23:24 2025 AUC 0.930539746272552
#
# Thu Jul 31 14:26:11 2025 AUC 0.929749636636951
#
# [mbo] 0: learning_rate=0.0105; num_leaves=121; min_data_in_leaf=107; feature_fraction=0.295; lambda_l2=10.3 : y = 0.929 : 152.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0125; num_leaves=107; min_data_in_leaf=234; feature_fraction=0.412; lambda_l2=8.7 : y = 0.93 : 155.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0147; num_leaves=69; min_data_in_leaf=134; feature_fraction=0.494; lambda_l2=9.8 : y = 0.931 : 146.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0142; num_leaves=88; min_data_in_leaf=125; feature_fraction=0.395; lambda_l2=12.1 : y = 0.93 : 147.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0112; num_leaves=114; min_data_in_leaf=167; feature_fraction=0.28; lambda_l2=8.11 : y = 0.93 : 150.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.016; num_leaves=109; min_data_in_leaf=286; feature_fraction=0.376; lambda_l2=7.32 : y = 0.931 : 148.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0196; num_leaves=58; min_data_in_leaf=258; feature_fraction=0.445; lambda_l2=6.73 : y = 0.93 : 132.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0134; num_leaves=75; min_data_in_leaf=39; feature_fraction=0.424; lambda_l2=9.35 : y = 0.93 : 148.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0175; num_leaves=96; min_data_in_leaf=184; feature_fraction=0.316; lambda_l2=11.4 : y = 0.931 : 143.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.017; num_leaves=141; min_data_in_leaf=97; feature_fraction=0.343; lambda_l2=6.47 : y = 0.929 : 173.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.00907; num_leaves=32; min_data_in_leaf=21; feature_fraction=0.448; lambda_l2=5.4 : y = 0.932 : 112.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0155; num_leaves=127; min_data_in_leaf=157; feature_fraction=0.546; lambda_l2=9.44 : y = 0.929 : 177.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.00994; num_leaves=79; min_data_in_leaf=199; feature_fraction=0.362; lambda_l2=12.6 : y = 0.931 : 138.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0081; num_leaves=47; min_data_in_leaf=70; feature_fraction=0.516; lambda_l2=11.2 : y = 0.931 : 131.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0136; num_leaves=61; min_data_in_leaf=223; feature_fraction=0.251; lambda_l2=7.65 : y = 0.931 : 119.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0194; num_leaves=148; min_data_in_leaf=267; feature_fraction=0.276; lambda_l2=6.11 : y = 0.93 : 153.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0178; num_leaves=39; min_data_in_leaf=206; feature_fraction=0.523; lambda_l2=12.5 : y = 0.932 : 123.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.00971; num_leaves=94; min_data_in_leaf=299; feature_fraction=0.471; lambda_l2=8.49 : y = 0.93 : 153.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0184; num_leaves=48; min_data_in_leaf=80; feature_fraction=0.486; lambda_l2=5.02 : y = 0.931 : 126.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0121; num_leaves=138; min_data_in_leaf=53; feature_fraction=0.329; lambda_l2=10.8 : y = 0.93 : 167.6 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Thu Jul 31 14:28:17 2025 AUC 0.931382928222075
#
# [mbo] 1: learning_rate=0.02; num_leaves=38; min_data_in_leaf=193; feature_fraction=0.501; lambda_l2=11 : y = 0.931 : 122.5 secs : infill_ei
#
# Thu Jul 31 14:30:06 2025 AUC 0.931503663205745
#
# [mbo] 2: learning_rate=0.0191; num_leaves=38; min_data_in_leaf=205; feature_fraction=0.298; lambda_l2=8.4 : y = 0.932 : 108.4 secs : infill_ei
#
# Thu Jul 31 14:31:50 2025 AUC 0.93166546484764
#
# [mbo] 3: learning_rate=0.00837; num_leaves=38; min_data_in_leaf=20; feature_fraction=0.255; lambda_l2=5.31 : y = 0.932 : 103.4 secs : infill_ei
#
# Thu Jul 31 14:33:41 2025 AUC 0.929939193340488
#
# [mbo] 4: learning_rate=0.0127; num_leaves=36; min_data_in_leaf=117; feature_fraction=0.356; lambda_l2=7.71 : y = 0.93 : 110.5 secs : infill_ei
#
# Thu Jul 31 14:35:57 2025 AUC 0.930539223062134
#
# [mbo] 5: learning_rate=0.0192; num_leaves=69; min_data_in_leaf=179; feature_fraction=0.387; lambda_l2=11.4 : y = 0.931 : 134.4 secs : infill_ei
#
# Thu Jul 31 14:37:48 2025 AUC 0.930140178745759
#
# [mbo] 6: learning_rate=0.0172; num_leaves=40; min_data_in_leaf=20; feature_fraction=0.36; lambda_l2=5.01 : y = 0.93 : 110.4 secs : infill_ei
#
# Saved the current state after iteration 7 in the file bayesiana.RDATA.
#
# Thu Jul 31 14:40:12 2025 AUC 0.929943521190966
#
# [mbo] 7: learning_rate=0.017; num_leaves=85; min_data_in_leaf=197; feature_fraction=0.352; lambda_l2=11.7 : y = 0.93 : 140.3 secs : infill_ei
#
# Thu Jul 31 14:42:01 2025 AUC 0.9306107312462
#
# [mbo] 8: learning_rate=0.00813; num_leaves=34; min_data_in_leaf=20; feature_fraction=0.369; lambda_l2=5.1 : y = 0.931 : 109.2 secs : infill_ei
#
# Thu Jul 31 14:43:49 2025 AUC 0.930868322861985
#
# [mbo] 9: learning_rate=0.0154; num_leaves=38; min_data_in_leaf=145; feature_fraction=0.266; lambda_l2=6.29 : y = 0.931 : 106.5 secs : infill_ei
#
# Thu Jul 31 14:45:55 2025 AUC 0.930116686046799
#
# [mbo] 10: learning_rate=0.0178; num_leaves=41; min_data_in_leaf=218; feature_fraction=0.513; lambda_l2=12.5 : y = 0.93 : 126.1 secs : infill_ei
#
# Thu Jul 31 14:48:09 2025 AUC 0.930404262481697
#
# [mbo] 11: learning_rate=0.0137; num_leaves=55; min_data_in_leaf=208; feature_fraction=0.47; lambda_l2=6.09 : y = 0.93 : 133.1 secs : infill_ei
#
# Saved the current state after iteration 12 in the file bayesiana.RDATA.
#
# Thu Jul 31 14:50:10 2025 AUC 0.930725662422575
#
# [mbo] 12: learning_rate=0.0136; num_leaves=57; min_data_in_leaf=259; feature_fraction=0.256; lambda_l2=12.5 : y = 0.931 : 114.7 secs : infill_ei
#
# Thu Jul 31 14:52:08 2025 AUC 0.93063284351145
#
# [mbo] 13: learning_rate=0.00832; num_leaves=36; min_data_in_leaf=51; feature_fraction=0.45; lambda_l2=7.55 : y = 0.931 : 118.1 secs : infill_ei
#
# Thu Jul 31 14:55:01 2025 AUC 0.930119931928707
#
# [mbo] 14: learning_rate=0.00859; num_leaves=124; min_data_in_leaf=37; feature_fraction=0.419; lambda_l2=12 : y = 0.93 : 171.8 secs : infill_ei
#
# Thu Jul 31 14:57:04 2025 AUC 0.931223706484353
#
# [mbo] 15: learning_rate=0.00978; num_leaves=43; min_data_in_leaf=117; feature_fraction=0.436; lambda_l2=11.6 : y = 0.931 : 122.1 secs : infill_ei
#
# Thu Jul 31 14:58:57 2025 AUC 0.930555238216653
#
# [mbo] 16: learning_rate=0.00999; num_leaves=32; min_data_in_leaf=22; feature_fraction=0.424; lambda_l2=10.1 : y = 0.931 : 112.4 secs : infill_ei
#
# Saved the current state after iteration 17 in the file bayesiana.RDATA.
#
# Thu Jul 31 15:00:50 2025 AUC 0.930391321381161
#
# [mbo] 17: learning_rate=0.0135; num_leaves=39; min_data_in_leaf=249; feature_fraction=0.325; lambda_l2=7.29 : y = 0.93 : 109.8 secs : infill_ei
#
# Thu Jul 31 15:02:58 2025 AUC 0.930978156430887
#
# [mbo] 18: learning_rate=0.01; num_leaves=61; min_data_in_leaf=108; feature_fraction=0.335; lambda_l2=12.7 : y = 0.931 : 127.3 secs : infill_ei
#
# Thu Jul 31 15:05:37 2025 AUC 0.929917773725312
#
# [mbo] 19: learning_rate=0.0176; num_leaves=88; min_data_in_leaf=182; feature_fraction=0.519; lambda_l2=5.62 : y = 0.93 : 158.1 secs : infill_ei
#
# Thu Jul 31 15:07:43 2025 AUC 0.931374712985448
#
# [mbo] 20: learning_rate=0.00869; num_leaves=48; min_data_in_leaf=46; feature_fraction=0.448; lambda_l2=5.37 : y = 0.931 : 125.4 secs : infill_ei
#
# Thu Jul 31 15:10:21 2025 AUC 0.92919389751733
#
# [mbo] 21: learning_rate=0.019; num_leaves=140; min_data_in_leaf=201; feature_fraction=0.297; lambda_l2=7.02 : y = 0.929 : 157.7 secs : infill_ei
#
# Saved the current state after iteration 22 in the file bayesiana.RDATA.
#
# Thu Jul 31 15:12:12 2025 AUC 0.931831442156809
#
# [mbo] 22: learning_rate=0.00878; num_leaves=41; min_data_in_leaf=66; feature_fraction=0.276; lambda_l2=9.47 : y = 0.932 : 106.9 secs : infill_ei
#
# Thu Jul 31 15:14:22 2025 AUC 0.930806403119153
#
# [mbo] 23: learning_rate=0.0132; num_leaves=51; min_data_in_leaf=165; feature_fraction=0.463; lambda_l2=10.5 : y = 0.931 : 129.2 secs : infill_ei
#
# Thu Jul 31 15:16:35 2025 AUC 0.930506873501108
#
# [mbo] 24: learning_rate=0.00844; num_leaves=67; min_data_in_leaf=225; feature_fraction=0.358; lambda_l2=11.3 : y = 0.931 : 131.9 secs : infill_ei
#
# Thu Jul 31 15:18:51 2025 AUC 0.930418861417726
#
# [mbo] 25: learning_rate=0.0101; num_leaves=87; min_data_in_leaf=93; feature_fraction=0.277; lambda_l2=9.45 : y = 0.93 : 135.4 secs : infill_ei
#
# Thu Jul 31 15:21:01 2025 AUC 0.931137814611862
#
# [mbo] 26: learning_rate=0.0132; num_leaves=46; min_data_in_leaf=159; feature_fraction=0.51; lambda_l2=12.2 : y = 0.931 : 129.9 secs : infill_ei
#
# Saved the current state after iteration 27 in the file bayesiana.RDATA.
#
# Thu Jul 31 15:23:22 2025 AUC 0.93041232443289
#
# [mbo] 27: learning_rate=0.017; num_leaves=63; min_data_in_leaf=136; feature_fraction=0.422; lambda_l2=11.8 : y = 0.93 : 135.3 secs : infill_ei
#
# Thu Jul 31 15:25:48 2025 AUC 0.930992172579886
#
# [mbo] 28: learning_rate=0.0191; num_leaves=75; min_data_in_leaf=222; feature_fraction=0.505; lambda_l2=12.9 : y = 0.931 : 145.6 secs : infill_ei
#
# Thu Jul 31 15:28:18 2025 AUC 0.929808249996498
#
# [mbo] 29: learning_rate=0.0154; num_leaves=114; min_data_in_leaf=158; feature_fraction=0.297; lambda_l2=5.69 : y = 0.93 : 149.2 secs : infill_ei
#
# Thu Jul 31 15:30:31 2025 AUC 0.930648276585862
#
# [mbo] 30: learning_rate=0.0107; num_leaves=62; min_data_in_leaf=101; feature_fraction=0.395; lambda_l2=8.66 : y = 0.931 : 131.6 secs : infill_ei
#
# Thu Jul 31 15:32:23 2025 AUC 0.930615800015576
#
# [mbo] 31: learning_rate=0.00809; num_leaves=40; min_data_in_leaf=93; feature_fraction=0.332; lambda_l2=9.08 : y = 0.931 : 111.4 secs : infill_ei
#
# Saved the current state after iteration 32 in the file bayesiana.RDATA.
#
# Thu Jul 31 15:34:45 2025 AUC 0.930112097007566
#
# [mbo] 32: learning_rate=0.00825; num_leaves=77; min_data_in_leaf=192; feature_fraction=0.365; lambda_l2=9.37 : y = 0.93 : 137.3 secs : infill_ei
#
# Thu Jul 31 15:37:31 2025 AUC 0.92986676753525
#
# [mbo] 33: learning_rate=0.0166; num_leaves=144; min_data_in_leaf=150; feature_fraction=0.329; lambda_l2=11.7 : y = 0.93 : 165.2 secs : infill_ei
#
# Thu Jul 31 15:39:12 2025 AUC 0.930594272857006
#
# [mbo] 34: learning_rate=0.00885; num_leaves=31; min_data_in_leaf=201; feature_fraction=0.275; lambda_l2=8.37 : y = 0.931 : 100.3 secs : infill_ei
#
# Thu Jul 31 15:42:13 2025 AUC 0.929734798569583
#
# [mbo] 35: learning_rate=0.0141; num_leaves=139; min_data_in_leaf=41; feature_fraction=0.443; lambda_l2=5.87 : y = 0.93 : 180.4 secs : infill_ei
#
# Thu Jul 31 15:44:13 2025 AUC 0.931125556565119
#
# [mbo] 36: learning_rate=0.019; num_leaves=36; min_data_in_leaf=264; feature_fraction=0.525; lambda_l2=8.36 : y = 0.931 : 118.8 secs : infill_ei
#
# Saved the current state after iteration 37 in the file bayesiana.RDATA.
#
# Thu Jul 31 15:46:05 2025 AUC 0.930291970727177
#
# [mbo] 37: learning_rate=0.00862; num_leaves=43; min_data_in_leaf=52; feature_fraction=0.272; lambda_l2=8.45 : y = 0.93 : 107.3 secs : infill_ei
#
# Thu Jul 31 15:48:52 2025 AUC 0.929608038591965
#
# [mbo] 38: learning_rate=0.00828; num_leaves=138; min_data_in_leaf=54; feature_fraction=0.302; lambda_l2=6.81 : y = 0.93 : 166.3 secs : infill_ei
#
# Thu Jul 31 15:51:20 2025 AUC 0.929772049611066
#
# [mbo] 39: learning_rate=0.0136; num_leaves=113; min_data_in_leaf=202; feature_fraction=0.318; lambda_l2=10.9 : y = 0.93 : 147.8 secs : infill_ei
#
# Thu Jul 31 15:53:48 2025 AUC 0.929901367757298
#
# [mbo] 40: learning_rate=0.00822; num_leaves=84; min_data_in_leaf=275; feature_fraction=0.471; lambda_l2=9.8 : y = 0.93 : 146.8 secs : infill_ei
#
# Thu Jul 31 15:55:40 2025 AUC 0.930140013251146
#
# [mbo] 41: learning_rate=0.0168; num_leaves=37; min_data_in_leaf=116; feature_fraction=0.355; lambda_l2=12 : y = 0.93 : 111.3 secs : infill_ei
#
# Saved the current state after iteration 42 in the file bayesiana.RDATA.
#
# Thu Jul 31 15:57:29 2025 AUC 0.931000438646533
#
# [mbo] 42: learning_rate=0.00926; num_leaves=41; min_data_in_leaf=141; feature_fraction=0.264; lambda_l2=10.7 : y = 0.931 : 105.6 secs : infill_ei
#
# Thu Jul 31 16:00:01 2025 AUC 0.930937017173932
#
# [mbo] 43: learning_rate=0.0198; num_leaves=147; min_data_in_leaf=283; feature_fraction=0.324; lambda_l2=7.87 : y = 0.931 : 151.1 secs : infill_ei
#
# Thu Jul 31 16:01:50 2025 AUC 0.931430695206173
#
# [mbo] 44: learning_rate=0.0137; num_leaves=40; min_data_in_leaf=28; feature_fraction=0.28; lambda_l2=7.45 : y = 0.931 : 108.4 secs : infill_ei
#
# Thu Jul 31 16:04:33 2025 AUC 0.929805447359878
#
# [mbo] 45: learning_rate=0.0162; num_leaves=106; min_data_in_leaf=228; feature_fraction=0.521; lambda_l2=10.3 : y = 0.93 : 162.2 secs : infill_ei
#
# Thu Jul 31 16:06:38 2025 AUC 0.931650633014103
#
# [mbo] 46: learning_rate=0.0189; num_leaves=41; min_data_in_leaf=230; feature_fraction=0.479; lambda_l2=12.9 : y = 0.932 : 123.5 secs : infill_ei
#
# Saved the current state after iteration 47 in the file bayesiana.RDATA.
#
# Thu Jul 31 16:09:14 2025 AUC 0.929358923038564
#
# [mbo] 47: learning_rate=0.0168; num_leaves=92; min_data_in_leaf=65; feature_fraction=0.433; lambda_l2=10.6 : y = 0.929 : 152.5 secs : infill_ei
#
# Thu Jul 31 16:11:38 2025 AUC 0.93027192090543
#
# [mbo] 48: learning_rate=0.0145; num_leaves=86; min_data_in_leaf=34; feature_fraction=0.352; lambda_l2=11.4 : y = 0.93 : 142.4 secs : infill_ei
#
# Thu Jul 31 16:14:08 2025 AUC 0.930783987203429
#
# [mbo] 49: learning_rate=0.0105; num_leaves=127; min_data_in_leaf=288; feature_fraction=0.354; lambda_l2=8.03 : y = 0.931 : 149.4 secs : infill_ei
#
# Thu Jul 31 16:15:57 2025 AUC 0.930792375547877
#
# [mbo] 50: learning_rate=0.00841; num_leaves=41; min_data_in_leaf=228; feature_fraction=0.284; lambda_l2=11.4 : y = 0.931 : 108.6 secs : infill_ei
#
# Thu Jul 31 16:18:39 2025 AUC 0.928628225951256
#
# [mbo] 51: learning_rate=0.0179; num_leaves=110; min_data_in_leaf=129; feature_fraction=0.436; lambda_l2=10.4 : y = 0.929 : 161.1 secs : infill_ei
#
# Saved the current state after iteration 52 in the file bayesiana.RDATA.
#
# Thu Jul 31 16:20:50 2025 AUC 0.931132088153289
#
# [mbo] 52: learning_rate=0.0116; num_leaves=50; min_data_in_leaf=223; feature_fraction=0.413; lambda_l2=12 : y = 0.931 : 126.5 secs : infill_ei
#
# Thu Jul 31 16:23:22 2025 AUC 0.930572112634989
#
# [mbo] 53: learning_rate=0.0135; num_leaves=115; min_data_in_leaf=56; feature_fraction=0.315; lambda_l2=10.6 : y = 0.931 : 151.9 secs : infill_ei
#
# Thu Jul 31 16:25:12 2025 AUC 0.931615520393194
#
# [mbo] 54: learning_rate=0.0175; num_leaves=32; min_data_in_leaf=278; feature_fraction=0.385; lambda_l2=12.9 : y = 0.932 : 109.0 secs : infill_ei
#
# Thu Jul 31 16:27:31 2025 AUC 0.930233057632889
#
# [mbo] 55: learning_rate=0.013; num_leaves=84; min_data_in_leaf=165; feature_fraction=0.332; lambda_l2=6.65 : y = 0.93 : 138.0 secs : infill_ei
#
# Thu Jul 31 16:30:27 2025 AUC 0.92918914712567
#
# [mbo] 56: learning_rate=0.0151; num_leaves=118; min_data_in_leaf=90; feature_fraction=0.542; lambda_l2=11.5 : y = 0.929 : 175.0 secs : infill_ei
#
# Saved the current state after iteration 57 in the file bayesiana.RDATA.
#
# Thu Jul 31 16:32:26 2025 AUC 0.930401174930894
#
# [mbo] 57: learning_rate=0.00861; num_leaves=34; min_data_in_leaf=55; feature_fraction=0.429; lambda_l2=8.84 : y = 0.93 : 114.4 secs : infill_ei
#
# Thu Jul 31 16:34:28 2025 AUC 0.929816320866105
#
# [mbo] 58: learning_rate=0.00913; num_leaves=58; min_data_in_leaf=299; feature_fraction=0.312; lambda_l2=10.3 : y = 0.93 : 120.9 secs : infill_ei
#
# Thu Jul 31 16:36:32 2025 AUC 0.930703597147416
#
# [mbo] 59: learning_rate=0.00811; num_leaves=53; min_data_in_leaf=264; feature_fraction=0.373; lambda_l2=12.1 : y = 0.931 : 123.3 secs : infill_ei
#
# Thu Jul 31 16:38:57 2025 AUC 0.930597238147771
#
# [mbo] 60: learning_rate=0.00985; num_leaves=146; min_data_in_leaf=242; feature_fraction=0.264; lambda_l2=12.5 : y = 0.931 : 143.9 secs : infill_ei
#
# Thu Jul 31 16:40:49 2025 AUC 0.931060520737597
#
# [mbo] 61: learning_rate=0.0153; num_leaves=46; min_data_in_leaf=131; feature_fraction=0.276; lambda_l2=9.26 : y = 0.931 : 111.3 secs : infill_ei
#
# Saved the current state after iteration 62 in the file bayesiana.RDATA.
#
# Thu Jul 31 16:43:21 2025 AUC 0.93130428436018
#
# [mbo] 62: learning_rate=0.0103; num_leaves=89; min_data_in_leaf=109; feature_fraction=0.387; lambda_l2=8.95 : y = 0.931 : 147.7 secs : infill_ei
#
# Thu Jul 31 16:45:39 2025 AUC 0.930879756008558
#
# [mbo] 63: learning_rate=0.00853; num_leaves=56; min_data_in_leaf=21; feature_fraction=0.523; lambda_l2=7.72 : y = 0.931 : 137.3 secs : infill_ei
#
# Thu Jul 31 16:48:22 2025 AUC 0.929315267563846
#
# [mbo] 64: learning_rate=0.0158; num_leaves=139; min_data_in_leaf=67; feature_fraction=0.27; lambda_l2=12.7 : y = 0.929 : 162.6 secs : infill_ei
#
# Thu Jul 31 16:51:16 2025 AUC 0.93092589535259
#
# [mbo] 65: learning_rate=0.0128; num_leaves=118; min_data_in_leaf=56; feature_fraction=0.451; lambda_l2=5.1 : y = 0.931 : 172.7 secs : infill_ei
#
# Saved the current state after iteration 66 in the file bayesiana.RDATA.
#
# Thu Jul 31 16:53:39 2025 AUC 0.930036710862437
#
# [mbo] 66: learning_rate=0.0118; num_leaves=88; min_data_in_leaf=242; feature_fraction=0.337; lambda_l2=11 : y = 0.93 : 137.2 secs : infill_ei
#
# Thu Jul 31 16:56:01 2025 AUC 0.929724710745158
#
# [mbo] 67: learning_rate=0.0168; num_leaves=65; min_data_in_leaf=203; feature_fraction=0.489; lambda_l2=6.87 : y = 0.93 : 141.0 secs : infill_ei
#
# Thu Jul 31 16:58:08 2025 AUC 0.930062170877925
#
# [mbo] 68: learning_rate=0.0159; num_leaves=49; min_data_in_leaf=246; feature_fraction=0.445; lambda_l2=9.91 : y = 0.93 : 126.7 secs : infill_ei
#
# Thu Jul 31 17:00:05 2025 AUC 0.930541118153929
#
# [mbo] 69: learning_rate=0.0183; num_leaves=35; min_data_in_leaf=300; feature_fraction=0.455; lambda_l2=6.49 : y = 0.931 : 116.0 secs : infill_ei
#
# Thu Jul 31 17:03:12 2025 AUC 0.930240969235346
#
# [mbo] 70: learning_rate=0.0164; num_leaves=132; min_data_in_leaf=123; feature_fraction=0.528; lambda_l2=11.5 : y = 0.93 : 185.5 secs : infill_ei
#
# Saved the current state after iteration 71 in the file bayesiana.RDATA.
#
# Thu Jul 31 17:05:35 2025 AUC 0.930499214080069
#
# [mbo] 71: learning_rate=0.0188; num_leaves=65; min_data_in_leaf=248; feature_fraction=0.444; lambda_l2=6.84 : y = 0.93 : 137.7 secs : infill_ei
#
# Thu Jul 31 17:07:27 2025 AUC 0.930540796603786
#
# [mbo] 72: learning_rate=0.00885; num_leaves=34; min_data_in_leaf=33; feature_fraction=0.374; lambda_l2=5.35 : y = 0.931 : 110.5 secs : infill_ei
#
# Thu Jul 31 17:09:52 2025 AUC 0.930699532243172
#
# [mbo] 73: learning_rate=0.00992; num_leaves=82; min_data_in_leaf=250; feature_fraction=0.424; lambda_l2=10.4 : y = 0.931 : 144.2 secs : infill_ei
#
# Thu Jul 31 17:11:53 2025 AUC 0.930855453020992
#
# [mbo] 74: learning_rate=0.0146; num_leaves=55; min_data_in_leaf=194; feature_fraction=0.31; lambda_l2=12 : y = 0.931 : 120.3 secs : infill_ei
#
# Thu Jul 31 17:14:39 2025 AUC 0.930724296951063
#
# [mbo] 75: learning_rate=0.0107; num_leaves=101; min_data_in_leaf=127; feature_fraction=0.493; lambda_l2=6.88 : y = 0.931 : 165.8 secs : infill_ei
#
# Saved the current state after iteration 76 in the file bayesiana.RDATA.
#
# Thu Jul 31 17:16:55 2025 AUC 0.929396961699191
#
# [mbo] 76: learning_rate=0.0192; num_leaves=59; min_data_in_leaf=258; feature_fraction=0.396; lambda_l2=9.68 : y = 0.929 : 131.0 secs : infill_ei
#
# Thu Jul 31 17:19:50 2025 AUC 0.929818617854315
#
# [mbo] 77: learning_rate=0.0181; num_leaves=134; min_data_in_leaf=33; feature_fraction=0.396; lambda_l2=8.94 : y = 0.93 : 174.6 secs : infill_ei
#
# Thu Jul 31 17:22:06 2025 AUC 0.930307914223965
#
# [mbo] 78: learning_rate=0.0195; num_leaves=59; min_data_in_leaf=273; feature_fraction=0.469; lambda_l2=8.99 : y = 0.93 : 135.4 secs : infill_ei
#
# Thu Jul 31 17:24:20 2025 AUC 0.931005283955118
#
# [mbo] 79: learning_rate=0.00956; num_leaves=56; min_data_in_leaf=142; feature_fraction=0.417; lambda_l2=7.31 : y = 0.931 : 132.5 secs : infill_ei
#
# Thu Jul 31 17:26:22 2025 AUC 0.932211302724371
#
# [mbo] 80: learning_rate=0.00877; num_leaves=43; min_data_in_leaf=51; feature_fraction=0.435; lambda_l2=9.53 : y = 0.932 : 121.5 secs : infill_ei
#
# Saved the current state after iteration 81 in the file bayesiana.RDATA.
#
# Thu Jul 31 17:28:22 2025 AUC 0.931146537370758
#
# [mbo] 81: learning_rate=0.00877; num_leaves=36; min_data_in_leaf=103; feature_fraction=0.402; lambda_l2=9.01 : y = 0.931 : 114.8 secs : infill_ei
#
# Thu Jul 31 17:31:21 2025 AUC 0.929904423694944
#
# [mbo] 82: learning_rate=0.0105; num_leaves=131; min_data_in_leaf=26; feature_fraction=0.427; lambda_l2=11.8 : y = 0.93 : 178.8 secs : infill_ei
#
# Thu Jul 31 17:33:51 2025 AUC 0.931303529376308
#
# [mbo] 83: learning_rate=0.0163; num_leaves=105; min_data_in_leaf=235; feature_fraction=0.353; lambda_l2=9.27 : y = 0.931 : 148.3 secs : infill_ei
#
# Thu Jul 31 17:36:12 2025 AUC 0.930108562537452
#
# [mbo] 84: learning_rate=0.0192; num_leaves=76; min_data_in_leaf=246; feature_fraction=0.376; lambda_l2=5.01 : y = 0.93 : 140.2 secs : infill_ei
#
# Thu Jul 31 17:38:30 2025 AUC 0.93052582838149
#
# [mbo] 85: learning_rate=0.0158; num_leaves=76; min_data_in_leaf=38; feature_fraction=0.338; lambda_l2=12.8 : y = 0.931 : 137.4 secs : infill_ei
#
# Saved the current state after iteration 86 in the file bayesiana.RDATA.
#
# Thu Jul 31 17:40:36 2025 AUC 0.930423341525061
#
# [mbo] 86: learning_rate=0.0169; num_leaves=65; min_data_in_leaf=266; feature_fraction=0.253; lambda_l2=6.01 : y = 0.93 : 121.4 secs : infill_ei
#
# Thu Jul 31 17:43:30 2025 AUC 0.930173617390364
#
# [mbo] 87: learning_rate=0.00853; num_leaves=104; min_data_in_leaf=62; feature_fraction=0.506; lambda_l2=5.55 : y = 0.93 : 173.7 secs : infill_ei
#
# Thu Jul 31 17:45:30 2025 AUC 0.931192703742063
#
# [mbo] 88: learning_rate=0.0095; num_leaves=45; min_data_in_leaf=286; feature_fraction=0.311; lambda_l2=10.9 : y = 0.931 : 119.2 secs : infill_ei
#
# Thu Jul 31 17:47:49 2025 AUC 0.930142661760925
#
# [mbo] 89: learning_rate=0.0126; num_leaves=91; min_data_in_leaf=258; feature_fraction=0.251; lambda_l2=7.65 : y = 0.93 : 137.5 secs : infill_ei
#
# Thu Jul 31 17:50:29 2025 AUC 0.930051649642682
#
# [mbo] 90: learning_rate=0.0193; num_leaves=136; min_data_in_leaf=216; feature_fraction=0.307; lambda_l2=7.99 : y = 0.93 : 159.5 secs : infill_ei
#
# Saved the current state after iteration 91 in the file bayesiana.RDATA.
#
# Thu Jul 31 17:52:24 2025 AUC 0.931305892660553
#
# [mbo] 91: learning_rate=0.0102; num_leaves=35; min_data_in_leaf=177; feature_fraction=0.296; lambda_l2=9.12 : y = 0.931 : 108.6 secs : infill_ei
#
# Thu Jul 31 17:55:13 2025 AUC 0.930440583408087
#
# [mbo] 92: learning_rate=0.00983; num_leaves=104; min_data_in_leaf=57; feature_fraction=0.455; lambda_l2=10.5 : y = 0.93 : 168.0 secs : infill_ei
#
# Thu Jul 31 17:57:35 2025 AUC 0.929840594557687
#
# [mbo] 93: learning_rate=0.0097; num_leaves=64; min_data_in_leaf=262; feature_fraction=0.499; lambda_l2=12.8 : y = 0.93 : 141.7 secs : infill_ei
#
# Thu Jul 31 18:00:26 2025 AUC 0.929848597067357
#
# [mbo] 94: learning_rate=0.014; num_leaves=105; min_data_in_leaf=66; feature_fraction=0.545; lambda_l2=12.9 : y = 0.93 : 169.9 secs : infill_ei
#
# Thu Jul 31 18:02:21 2025 AUC 0.930287426705296
#
# [mbo] 95: learning_rate=0.0179; num_leaves=44; min_data_in_leaf=215; feature_fraction=0.275; lambda_l2=11.2 : y = 0.93 : 114.2 secs : infill_ei
#
# Saved the current state after iteration 96 in the file bayesiana.RDATA.
#
# Thu Jul 31 18:05:10 2025 AUC 0.92941850827299
#
# [mbo] 96: learning_rate=0.00973; num_leaves=118; min_data_in_leaf=195; feature_fraction=0.425; lambda_l2=9.59 : y = 0.929 : 164.4 secs : infill_ei
#
# Thu Jul 31 18:07:36 2025 AUC 0.929866372382717
#
# [mbo] 97: learning_rate=0.0142; num_leaves=104; min_data_in_leaf=222; feature_fraction=0.307; lambda_l2=9.78 : y = 0.93 : 144.8 secs : infill_ei
#
# Thu Jul 31 18:09:55 2025 AUC 0.930231996256493
#
# [mbo] 98: learning_rate=0.00957; num_leaves=62; min_data_in_leaf=53; feature_fraction=0.459; lambda_l2=9.52 : y = 0.93 : 138.1 secs : infill_ei
#
# Thu Jul 31 18:12:03 2025 AUC 0.93039600058043
#
# [mbo] 99: learning_rate=0.0112; num_leaves=57; min_data_in_leaf=57; feature_fraction=0.38; lambda_l2=6.93 : y = 0.93 : 126.8 secs : infill_ei
#
# Thu Jul 31 18:14:51 2025 AUC 0.931218228197443
#
# [mbo] 100: learning_rate=0.0145; num_leaves=110; min_data_in_leaf=169; feature_fraction=0.482; lambda_l2=10.1 : y = 0.931 : 167.8 secs : infill_ei
#
# Saved the current state after iteration 101 in the file bayesiana.RDATA.
#
# Thu Jul 31 18:17:26 2025 AUC 0.930126172602112
#
# [mbo] 101: learning_rate=0.0167; num_leaves=82; min_data_in_leaf=47; feature_fraction=0.41; lambda_l2=8.22 : y = 0.93 : 149.8 secs : infill_ei
#
# Thu Jul 31 18:20:24 2025 AUC 0.929519640211222
#
# [mbo] 102: learning_rate=0.0151; num_leaves=123; min_data_in_leaf=124; feature_fraction=0.512; lambda_l2=7.95 : y = 0.93 : 177.8 secs : infill_ei
#
# Thu Jul 31 18:22:48 2025 AUC 0.929680831137692
#
# [mbo] 103: learning_rate=0.012; num_leaves=106; min_data_in_leaf=274; feature_fraction=0.301; lambda_l2=5.29 : y = 0.93 : 142.5 secs : infill_ei
#
# Thu Jul 31 18:25:35 2025 AUC 0.930613188346147
#
# [mbo] 104: learning_rate=0.0163; num_leaves=133; min_data_in_leaf=36; feature_fraction=0.305; lambda_l2=13 : y = 0.931 : 165.8 secs : infill_ei
#
# Saved the current state after iteration 105 in the file bayesiana.RDATA.
#
# Thu Jul 31 18:28:13 2025 AUC 0.929534558123728
#
# [mbo] 105: learning_rate=0.0181; num_leaves=115; min_data_in_leaf=283; feature_fraction=0.389; lambda_l2=9.95 : y = 0.93 : 154.1 secs : infill_ei
#
# Thu Jul 31 18:31:02 2025 AUC 0.929732176112813
#
# [mbo] 106: learning_rate=0.0169; num_leaves=111; min_data_in_leaf=220; feature_fraction=0.471; lambda_l2=6.69 : y = 0.93 : 168.4 secs : infill_ei
#
# Thu Jul 31 18:33:25 2025 AUC 0.930455450630061
#
# [mbo] 107: learning_rate=0.0193; num_leaves=118; min_data_in_leaf=290; feature_fraction=0.258; lambda_l2=11.1 : y = 0.93 : 141.6 secs : infill_ei
#
# Thu Jul 31 18:35:36 2025 AUC 0.930101255536833
#
# [mbo] 108: learning_rate=0.0185; num_leaves=82; min_data_in_leaf=81; feature_fraction=0.252; lambda_l2=5.4 : y = 0.93 : 130.5 secs : infill_ei
#
# Thu Jul 31 18:37:57 2025 AUC 0.930872146425636
#
# [mbo] 109: learning_rate=0.0122; num_leaves=58; min_data_in_leaf=65; feature_fraction=0.507; lambda_l2=12.3 : y = 0.931 : 139.3 secs : infill_ei
#
# Saved the current state after iteration 110 in the file bayesiana.RDATA.
#
# Thu Jul 31 18:40:16 2025 AUC 0.930537157523725
#
# [mbo] 110: learning_rate=0.0115; num_leaves=78; min_data_in_leaf=184; feature_fraction=0.315; lambda_l2=9.46 : y = 0.931 : 134.7 secs : infill_ei
#
# Thu Jul 31 18:42:25 2025 AUC 0.93107621523568
#
# [mbo] 111: learning_rate=0.0141; num_leaves=55; min_data_in_leaf=136; feature_fraction=0.391; lambda_l2=5.06 : y = 0.931 : 127.8 secs : infill_ei
#
# Thu Jul 31 18:44:24 2025 AUC 0.930619258043452
#
# [mbo] 112: learning_rate=0.00901; num_leaves=47; min_data_in_leaf=79; feature_fraction=0.346; lambda_l2=5.24 : y = 0.931 : 118.3 secs : infill_ei
#
# Thu Jul 31 18:46:42 2025 AUC 0.930435892094477
#
# [mbo] 113: learning_rate=0.0151; num_leaves=91; min_data_in_leaf=230; feature_fraction=0.283; lambda_l2=11.8 : y = 0.93 : 136.6 secs : infill_ei
#
# Thu Jul 31 18:49:05 2025 AUC 0.929947815207369
#
# [mbo] 114: learning_rate=0.0171; num_leaves=106; min_data_in_leaf=187; feature_fraction=0.26; lambda_l2=6.82 : y = 0.93 : 142.5 secs : infill_ei
#
# Saved the current state after iteration 115 in the file bayesiana.RDATA.
#
# Thu Jul 31 18:51:30 2025 AUC 0.929843778515319
#
# [mbo] 115: learning_rate=0.0172; num_leaves=101; min_data_in_leaf=201; feature_fraction=0.258; lambda_l2=7.39 : y = 0.93 : 140.7 secs : infill_ei
#
# Thu Jul 31 18:54:34 2025 AUC 0.929414516579495
#
# [mbo] 116: learning_rate=0.01; num_leaves=129; min_data_in_leaf=118; feature_fraction=0.51; lambda_l2=12.4 : y = 0.929 : 182.2 secs : infill_ei
#
# Thu Jul 31 18:57:41 2025 AUC 0.92975832281273
#
# [mbo] 117: learning_rate=0.0179; num_leaves=139; min_data_in_leaf=156; feature_fraction=0.498; lambda_l2=5.08 : y = 0.93 : 186.1 secs : infill_ei
#
# Thu Jul 31 18:59:51 2025 AUC 0.930205003736012
#
# [mbo] 118: learning_rate=0.00903; num_leaves=46; min_data_in_leaf=159; feature_fraction=0.513; lambda_l2=10.4 : y = 0.93 : 129.4 secs : infill_ei
#
# Saved the current state after iteration 119 in the file bayesiana.RDATA.
#
# Thu Jul 31 19:02:02 2025 AUC 0.929874173298519
#
# [mbo] 119: learning_rate=0.0132; num_leaves=52; min_data_in_leaf=73; feature_fraction=0.392; lambda_l2=8.55 : y = 0.93 : 126.9 secs : infill_ei
#
# Thu Jul 31 19:05:18 2025 AUC 0.929669074040209
#
# [mbo] 120: learning_rate=0.012; num_leaves=145; min_data_in_leaf=50; feature_fraction=0.519; lambda_l2=10.2 : y = 0.93 : 194.7 secs : infill_ei
#
# Thu Jul 31 19:07:28 2025 AUC 0.930962348233986
#
# [mbo] 121: learning_rate=0.0151; num_leaves=80; min_data_in_leaf=216; feature_fraction=0.261; lambda_l2=7.37 : y = 0.931 : 129.2 secs : infill_ei
#
# Thu Jul 31 19:09:34 2025 AUC 0.930732179038609
#
# [mbo] 122: learning_rate=0.0176; num_leaves=43; min_data_in_leaf=83; feature_fraction=0.542; lambda_l2=10 : y = 0.931 : 125.1 secs : infill_ei
#
# Thu Jul 31 19:11:42 2025 AUC 0.930660538050663
#
# [mbo] 123: learning_rate=0.00876; num_leaves=44; min_data_in_leaf=50; feature_fraction=0.438; lambda_l2=11.8 : y = 0.931 : 125.6 secs : infill_ei
#
# Saved the current state after iteration 124 in the file bayesiana.RDATA.
#
# Thu Jul 31 19:14:12 2025 AUC 0.931310271957334
#
# [mbo] 124: learning_rate=0.00943; num_leaves=86; min_data_in_leaf=86; feature_fraction=0.351; lambda_l2=12.5 : y = 0.931 : 145.0 secs : infill_ei
#
# Thu Jul 31 19:16:49 2025 AUC 0.930334342027939
#
# [mbo] 125: learning_rate=0.0117; num_leaves=76; min_data_in_leaf=294; feature_fraction=0.492; lambda_l2=9.22 : y = 0.93 : 155.6 secs : infill_ei
#
# Thu Jul 31 19:19:01 2025 AUC 0.931140434876186
#
# [mbo] 126: learning_rate=0.00879; num_leaves=53; min_data_in_leaf=51; feature_fraction=0.428; lambda_l2=9.84 : y = 0.931 : 131.2 secs : infill_ei
#
# Thu Jul 31 19:21:21 2025 AUC 0.930429368813423
#
# [mbo] 127: learning_rate=0.0118; num_leaves=73; min_data_in_leaf=169; feature_fraction=0.346; lambda_l2=6.28 : y = 0.93 : 138.8 secs : infill_ei
#
# Thu Jul 31 19:23:15 2025 AUC 0.930623823771874
#
# [mbo] 128: learning_rate=0.0179; num_leaves=40; min_data_in_leaf=25; feature_fraction=0.352; lambda_l2=10.1 : y = 0.931 : 112.5 secs : infill_ei
#
# Saved the current state after iteration 129 in the file bayesiana.RDATA.
#
# Thu Jul 31 19:25:37 2025 AUC 0.930797572385186
#
# [mbo] 129: learning_rate=0.00973; num_leaves=55; min_data_in_leaf=42; feature_fraction=0.527; lambda_l2=11 : y = 0.931 : 137.3 secs : infill_ei
#
# Thu Jul 31 19:27:59 2025 AUC 0.930179153287044
#
# [mbo] 130: learning_rate=0.00967; num_leaves=62; min_data_in_leaf=180; feature_fraction=0.438; lambda_l2=6.63 : y = 0.93 : 141.0 secs : infill_ei
#
# Thu Jul 31 19:30:14 2025 AUC 0.92979982079965
#
# [mbo] 131: learning_rate=0.0141; num_leaves=52; min_data_in_leaf=31; feature_fraction=0.487; lambda_l2=9.24 : y = 0.93 : 134.3 secs : infill_ei
#
# Thu Jul 31 19:33:02 2025 AUC 0.929408055551741
#
# [mbo] 132: learning_rate=0.0191; num_leaves=102; min_data_in_leaf=216; feature_fraction=0.496; lambda_l2=7.83 : y = 0.929 : 166.5 secs : infill_ei
#
# Thu Jul 31 19:35:28 2025 AUC 0.92944694729987
#
# [mbo] 133: learning_rate=0.0185; num_leaves=97; min_data_in_leaf=180; feature_fraction=0.311; lambda_l2=10.7 : y = 0.929 : 144.7 secs : infill_ei
#
# Saved the current state after iteration 134 in the file bayesiana.RDATA.
#
# Thu Jul 31 19:37:45 2025 AUC 0.93069555479174
#
# [mbo] 134: learning_rate=0.00931; num_leaves=72; min_data_in_leaf=291; feature_fraction=0.329; lambda_l2=11.4 : y = 0.931 : 131.1 secs : infill_ei
#
# Thu Jul 31 19:39:49 2025 AUC 0.931435765935796
#
# [mbo] 135: learning_rate=0.0125; num_leaves=36; min_data_in_leaf=127; feature_fraction=0.493; lambda_l2=11.7 : y = 0.931 : 123.3 secs : infill_ei
#
# Thu Jul 31 19:42:38 2025 AUC 0.930468921431599
#
# [mbo] 136: learning_rate=0.0196; num_leaves=117; min_data_in_leaf=205; feature_fraction=0.456; lambda_l2=7.71 : y = 0.93 : 167.6 secs : infill_ei
#
# Thu Jul 31 19:44:31 2025 AUC 0.93093090111262
#
# [mbo] 137: learning_rate=0.0115; num_leaves=45; min_data_in_leaf=275; feature_fraction=0.302; lambda_l2=5.38 : y = 0.931 : 112.6 secs : infill_ei
#
# Thu Jul 31 19:46:45 2025 AUC 0.929780009316892
#
# [mbo] 138: learning_rate=0.0135; num_leaves=87; min_data_in_leaf=256; feature_fraction=0.25; lambda_l2=10.1 : y = 0.93 : 132.2 secs : infill_ei
#
# Saved the current state after iteration 139 in the file bayesiana.RDATA.
#
# Thu Jul 31 19:48:56 2025 AUC 0.931487236936208
#
# [mbo] 139: learning_rate=0.00995; num_leaves=74; min_data_in_leaf=271; feature_fraction=0.264; lambda_l2=8.6 : y = 0.931 : 126.1 secs : infill_ei
#
# Thu Jul 31 19:51:24 2025 AUC 0.930765713866545
#
# [mbo] 140: learning_rate=0.0137; num_leaves=55; min_data_in_leaf=82; feature_fraction=0.517; lambda_l2=8.9 : y = 0.931 : 147.8 secs : infill_ei
#
# Thu Jul 31 19:54:40 2025 AUC 0.92966681352689
#
# [mbo] 141: learning_rate=0.0115; num_leaves=146; min_data_in_leaf=109; feature_fraction=0.456; lambda_l2=5.32 : y = 0.93 : 194.1 secs : infill_ei
#
# Thu Jul 31 19:57:32 2025 AUC 0.930366646805752
#
# [mbo] 142: learning_rate=0.0146; num_leaves=128; min_data_in_leaf=200; feature_fraction=0.404; lambda_l2=8.26 : y = 0.93 : 170.8 secs : infill_ei
#
# Saved the current state after iteration 143 in the file bayesiana.RDATA.
#
# Thu Jul 31 20:00:22 2025 AUC 0.929976495646315
#
# [mbo] 143: learning_rate=0.0182; num_leaves=140; min_data_in_leaf=230; feature_fraction=0.351; lambda_l2=11.1 : y = 0.93 : 165.5 secs : infill_ei
#
# Thu Jul 31 20:02:57 2025 AUC 0.930114454333286
#
# [mbo] 144: learning_rate=0.012; num_leaves=125; min_data_in_leaf=205; feature_fraction=0.294; lambda_l2=7.96 : y = 0.93 : 153.7 secs : infill_ei
#
# Thu Jul 31 20:05:22 2025 AUC 0.930103041257336
#
# [mbo] 145: learning_rate=0.0108; num_leaves=61; min_data_in_leaf=251; feature_fraction=0.512; lambda_l2=9.52 : y = 0.93 : 144.0 secs : infill_ei
#
# Thu Jul 31 20:07:17 2025 AUC 0.931306938845487
#
# [mbo] 146: learning_rate=0.0111; num_leaves=33; min_data_in_leaf=87; feature_fraction=0.375; lambda_l2=11.6 : y = 0.931 : 113.2 secs : infill_ei
#
# Thu Jul 31 20:09:58 2025 AUC 0.929850239962268
#
# [mbo] 147: learning_rate=0.0155; num_leaves=129; min_data_in_leaf=271; feature_fraction=0.346; lambda_l2=7.16 : y = 0.93 : 160.5 secs : infill_ei
#
# Saved the current state after iteration 148 in the file bayesiana.RDATA.
#
# Thu Jul 31 20:12:53 2025 AUC 0.929987225418175
#
# [mbo] 148: learning_rate=0.0104; num_leaves=144; min_data_in_leaf=116; feature_fraction=0.299; lambda_l2=7.24 : y = 0.93 : 169.9 secs : infill_ei
#
# Thu Jul 31 20:15:51 2025 AUC 0.930069401019969
#
# [mbo] 149: learning_rate=0.0195; num_leaves=124; min_data_in_leaf=65; feature_fraction=0.438; lambda_l2=10.5 : y = 0.93 : 176.8 secs : infill_ei
#
# Thu Jul 31 20:18:01 2025 AUC 0.930737479050951
#
# [mbo] 150: learning_rate=0.0178; num_leaves=49; min_data_in_leaf=111; feature_fraction=0.433; lambda_l2=9.82 : y = 0.931 : 128.9 secs : infill_ei
#
# Thu Jul 31 20:20:30 2025 AUC 0.929407472377842
#
# [mbo] 151: learning_rate=0.0101; num_leaves=85; min_data_in_leaf=278; feature_fraction=0.422; lambda_l2=11.3 : y = 0.929 : 147.9 secs : infill_ei
#
# Saved the current state after iteration 152 in the file bayesiana.RDATA.
#
# Thu Jul 31 20:22:34 2025 AUC 0.930611164473622
#
# [mbo] 152: learning_rate=0.0107; num_leaves=53; min_data_in_leaf=252; feature_fraction=0.286; lambda_l2=6.43 : y = 0.931 : 118.9 secs : infill_ei
#
# Thu Jul 31 20:25:34 2025 AUC 0.929850542732963
#
# [mbo] 153: learning_rate=0.0105; num_leaves=125; min_data_in_leaf=152; feature_fraction=0.535; lambda_l2=12 : y = 0.93 : 179.1 secs : infill_ei
#
# Thu Jul 31 20:28:26 2025 AUC 0.930620256248633
#
# [mbo] 154: learning_rate=0.0192; num_leaves=136; min_data_in_leaf=25; feature_fraction=0.338; lambda_l2=10.8 : y = 0.931 : 170.9 secs : infill_ei
#
# Thu Jul 31 20:30:47 2025 AUC 0.930499301347654
#
# [mbo] 155: learning_rate=0.00832; num_leaves=96; min_data_in_leaf=216; feature_fraction=0.283; lambda_l2=9.63 : y = 0.93 : 139.5 secs : infill_ei
#
# Saved the current state after iteration 156 in the file bayesiana.RDATA.
#
# Thu Jul 31 20:33:33 2025 AUC 0.930479290616662
#
# [mbo] 156: learning_rate=0.0148; num_leaves=103; min_data_in_leaf=131; feature_fraction=0.438; lambda_l2=10.6 : y = 0.93 : 161.0 secs : infill_ei
#
# Thu Jul 31 20:35:48 2025 AUC 0.930761690899644
#
# [mbo] 157: learning_rate=0.0105; num_leaves=50; min_data_in_leaf=164; feature_fraction=0.498; lambda_l2=6.41 : y = 0.931 : 133.2 secs : infill_ei
#
# Thu Jul 31 20:38:31 2025 AUC 0.929474759528656
#
# [mbo] 158: learning_rate=0.0118; num_leaves=142; min_data_in_leaf=259; feature_fraction=0.388; lambda_l2=10.2 : y = 0.929 : 162.3 secs : infill_ei
#
# Thu Jul 31 20:40:16 2025 AUC 0.930367264321584
#
# [mbo] 159: learning_rate=0.0107; num_leaves=31; min_data_in_leaf=125; feature_fraction=0.299; lambda_l2=5.84 : y = 0.93 : 103.4 secs : infill_ei
#
# Thu Jul 31 20:42:40 2025 AUC 0.929811077646308
#
# [mbo] 160: learning_rate=0.0104; num_leaves=71; min_data_in_leaf=176; feature_fraction=0.432; lambda_l2=12.5 : y = 0.93 : 142.6 secs : infill_ei
#
# Saved the current state after iteration 161 in the file bayesiana.RDATA.
#
# Thu Jul 31 20:45:07 2025 AUC 0.930388518840219
#
# [mbo] 161: learning_rate=0.0115; num_leaves=65; min_data_in_leaf=216; feature_fraction=0.489; lambda_l2=10.9 : y = 0.93 : 142.7 secs : infill_ei
#
# Thu Jul 31 20:47:34 2025 AUC 0.930718163230009
#
# [mbo] 162: learning_rate=0.0119; num_leaves=109; min_data_in_leaf=181; feature_fraction=0.284; lambda_l2=10.6 : y = 0.931 : 145.9 secs : infill_ei
#
# Thu Jul 31 20:50:20 2025 AUC 0.929610470588999
#
# [mbo] 163: learning_rate=0.0143; num_leaves=110; min_data_in_leaf=182; feature_fraction=0.472; lambda_l2=12.6 : y = 0.93 : 164.9 secs : infill_ei
#
# Thu Jul 31 20:53:37 2025 AUC 0.929911664809794
#
# [mbo] 164: learning_rate=0.0132; num_leaves=135; min_data_in_leaf=62; feature_fraction=0.462; lambda_l2=11.7 : y = 0.93 : 195.7 secs : infill_ei
#
# Saved the current state after iteration 165 in the file bayesiana.RDATA.
#
# Thu Jul 31 20:55:46 2025 AUC 0.929878181020519
#
# [mbo] 165: learning_rate=0.00839; num_leaves=60; min_data_in_leaf=125; feature_fraction=0.32; lambda_l2=5.37 : y = 0.93 : 123.1 secs : infill_ei
#
# Thu Jul 31 20:58:05 2025 AUC 0.930998308652008
#
# [mbo] 166: learning_rate=0.0173; num_leaves=107; min_data_in_leaf=294; feature_fraction=0.256; lambda_l2=10.4 : y = 0.931 : 137.3 secs : infill_ei
#
# Thu Jul 31 21:00:37 2025 AUC 0.930331680415476
#
# [mbo] 167: learning_rate=0.00866; num_leaves=107; min_data_in_leaf=144; feature_fraction=0.327; lambda_l2=8.56 : y = 0.93 : 150.9 secs : infill_ei
#
# Thu Jul 31 21:03:23 2025 AUC 0.929475274146939
#
# [mbo] 168: learning_rate=0.009; num_leaves=107; min_data_in_leaf=51; feature_fraction=0.396; lambda_l2=11.6 : y = 0.929 : 164.8 secs : infill_ei
#
# Thu Jul 31 21:05:27 2025 AUC 0.931739902038834
#
# [mbo] 169: learning_rate=0.0109; num_leaves=41; min_data_in_leaf=30; feature_fraction=0.435; lambda_l2=12.8 : y = 0.932 : 121.6 secs : infill_ei
#
# Saved the current state after iteration 170 in the file bayesiana.RDATA.
#
# Thu Jul 31 21:07:34 2025 AUC 0.930814182134156
#
# [mbo] 170: learning_rate=0.0131; num_leaves=42; min_data_in_leaf=59; feature_fraction=0.378; lambda_l2=9.52 : y = 0.931 : 120.5 secs : infill_ei
#
# Thu Jul 31 21:10:03 2025 AUC 0.931352900337486
#
# [mbo] 171: learning_rate=0.00956; num_leaves=96; min_data_in_leaf=49; feature_fraction=0.323; lambda_l2=10.1 : y = 0.931 : 147.6 secs : infill_ei
#
# Thu Jul 31 21:13:12 2025 AUC 0.930848480630089
#
# [mbo] 172: learning_rate=0.0124; num_leaves=142; min_data_in_leaf=44; feature_fraction=0.443; lambda_l2=6.85 : y = 0.931 : 188.0 secs : infill_ei
#
# Thu Jul 31 21:15:25 2025 AUC 0.930914083432597
#
# [mbo] 173: learning_rate=0.0137; num_leaves=49; min_data_in_leaf=113; feature_fraction=0.483; lambda_l2=5.89 : y = 0.931 : 131.5 secs : infill_ei
#
# Thu Jul 31 21:18:02 2025 AUC 0.92990481048054
#
# [mbo] 174: learning_rate=0.0147; num_leaves=101; min_data_in_leaf=290; feature_fraction=0.462; lambda_l2=12.7 : y = 0.93 : 156.4 secs : infill_ei
#
# Saved the current state after iteration 175 in the file bayesiana.RDATA.
#
# Thu Jul 31 21:20:31 2025 AUC 0.930426615723258
#
# [mbo] 175: learning_rate=0.0138; num_leaves=88; min_data_in_leaf=39; feature_fraction=0.331; lambda_l2=7.85 : y = 0.93 : 142.6 secs : infill_ei
#
# Thu Jul 31 21:22:35 2025 AUC 0.931122855253265
#
# [mbo] 176: learning_rate=0.0177; num_leaves=51; min_data_in_leaf=59; feature_fraction=0.407; lambda_l2=7.33 : y = 0.931 : 123.3 secs : infill_ei
#
# Thu Jul 31 21:24:40 2025 AUC 0.930302752236154
#
# [mbo] 177: learning_rate=0.0134; num_leaves=55; min_data_in_leaf=33; feature_fraction=0.313; lambda_l2=11.6 : y = 0.93 : 123.6 secs : infill_ei
#
# Thu Jul 31 21:27:14 2025 AUC 0.92966525722195
#
# [mbo] 178: learning_rate=0.0199; num_leaves=100; min_data_in_leaf=94; feature_fraction=0.372; lambda_l2=8.37 : y = 0.93 : 152.2 secs : infill_ei
#
# Thu Jul 31 21:30:05 2025 AUC 0.929718129449396
#
# [mbo] 179: learning_rate=0.0171; num_leaves=93; min_data_in_leaf=152; feature_fraction=0.519; lambda_l2=5.85 : y = 0.93 : 169.7 secs : infill_ei
#
# Saved the current state after iteration 180 in the file bayesiana.RDATA.
#
# Thu Jul 31 21:32:41 2025 AUC 0.930788619862278
#
# [mbo] 180: learning_rate=0.0113; num_leaves=81; min_data_in_leaf=62; feature_fraction=0.458; lambda_l2=9.8 : y = 0.931 : 150.6 secs : infill_ei
#
# Thu Jul 31 21:34:22 2025 AUC 0.931805511546613
#
# [mbo] 181: learning_rate=0.0102; num_leaves=30; min_data_in_leaf=207; feature_fraction=0.271; lambda_l2=10.5 : y = 0.932 : 100.0 secs : infill_ei
#
# Thu Jul 31 21:36:32 2025 AUC 0.929718990647579
#
# [mbo] 182: learning_rate=0.016; num_leaves=77; min_data_in_leaf=202; feature_fraction=0.27; lambda_l2=5.63 : y = 0.93 : 128.5 secs : infill_ei
#
# Thu Jul 31 21:39:13 2025 AUC 0.929588000276228
#
# [mbo] 183: learning_rate=0.0196; num_leaves=108; min_data_in_leaf=190; feature_fraction=0.464; lambda_l2=8.52 : y = 0.93 : 159.7 secs : infill_ei
#
# Thu Jul 31 21:41:27 2025 AUC 0.930267704786488
#
# [mbo] 184: learning_rate=0.0119; num_leaves=54; min_data_in_leaf=68; feature_fraction=0.492; lambda_l2=6.55 : y = 0.93 : 133.2 secs : infill_ei
#
# Saved the current state after iteration 185 in the file bayesiana.RDATA.
#
# Thu Jul 31 21:43:58 2025 AUC 0.930331708899329
#
# [mbo] 185: learning_rate=0.0191; num_leaves=108; min_data_in_leaf=292; feature_fraction=0.344; lambda_l2=11.7 : y = 0.93 : 144.7 secs : infill_ei
#
# Thu Jul 31 21:46:36 2025 AUC 0.931249720289904
#
# [mbo] 186: learning_rate=0.0139; num_leaves=85; min_data_in_leaf=85; feature_fraction=0.526; lambda_l2=6.09 : y = 0.931 : 155.9 secs : infill_ei
#
# Thu Jul 31 21:48:59 2025 AUC 0.9302204403377
#
# [mbo] 187: learning_rate=0.0181; num_leaves=69; min_data_in_leaf=193; feature_fraction=0.472; lambda_l2=10.9 : y = 0.93 : 141.7 secs : infill_ei
#
# Thu Jul 31 21:51:44 2025 AUC 0.931138003424587
#
# [mbo] 188: learning_rate=0.0173; num_leaves=134; min_data_in_leaf=68; feature_fraction=0.331; lambda_l2=10.8 : y = 0.931 : 164.0 secs : infill_ei
#
# Saved the current state after iteration 189 in the file bayesiana.RDATA.
#
# Thu Jul 31 21:54:24 2025 AUC 0.93020707911902
#
# [mbo] 189: learning_rate=0.0109; num_leaves=132; min_data_in_leaf=108; feature_fraction=0.27; lambda_l2=12.1 : y = 0.93 : 154.0 secs : infill_ei
#
# Thu Jul 31 21:57:01 2025 AUC 0.930017209107341
#
# [mbo] 190: learning_rate=0.0191; num_leaves=92; min_data_in_leaf=181; feature_fraction=0.486; lambda_l2=10.5 : y = 0.93 : 155.6 secs : infill_ei
#
# Thu Jul 31 21:59:06 2025 AUC 0.930995726244134
#
# [mbo] 191: learning_rate=0.0175; num_leaves=74; min_data_in_leaf=89; feature_fraction=0.252; lambda_l2=6.27 : y = 0.931 : 123.6 secs : infill_ei
#
# Thu Jul 31 22:01:11 2025 AUC 0.93000093562007
#
# [mbo] 192: learning_rate=0.0157; num_leaves=58; min_data_in_leaf=73; feature_fraction=0.345; lambda_l2=7.78 : y = 0.93 : 123.7 secs : infill_ei
#
# Thu Jul 31 22:03:14 2025 AUC 0.929763501155633
#
# [mbo] 193: learning_rate=0.0108; num_leaves=50; min_data_in_leaf=40; feature_fraction=0.373; lambda_l2=9.77 : y = 0.93 : 122.0 secs : infill_ei
#
# Saved the current state after iteration 194 in the file bayesiana.RDATA.
#
# Thu Jul 31 22:06:05 2025 AUC 0.929836900542987
#
# [mbo] 194: learning_rate=0.0137; num_leaves=138; min_data_in_leaf=24; feature_fraction=0.262; lambda_l2=8.11 : y = 0.93 : 165.0 secs : infill_ei
#
# Thu Jul 31 22:08:44 2025 AUC 0.929658263933263
#
# [mbo] 195: learning_rate=0.0152; num_leaves=138; min_data_in_leaf=95; feature_fraction=0.278; lambda_l2=8.1 : y = 0.93 : 157.8 secs : infill_ei
#
# Thu Jul 31 22:11:04 2025 AUC 0.93004182066479
#
# [mbo] 196: learning_rate=0.0168; num_leaves=94; min_data_in_leaf=95; feature_fraction=0.301; lambda_l2=8.85 : y = 0.93 : 139.2 secs : infill_ei
#
# Thu Jul 31 22:13:37 2025 AUC 0.929990933106621
#
# [mbo] 197: learning_rate=0.0113; num_leaves=111; min_data_in_leaf=232; feature_fraction=0.379; lambda_l2=9.79 : y = 0.93 : 151.3 secs : infill_ei
#
# Saved the current state after iteration 198 in the file bayesiana.RDATA.
#
# Thu Jul 31 22:16:10 2025 AUC 0.930935528433667
#
# [mbo] 198: learning_rate=0.0102; num_leaves=76; min_data_in_leaf=233; feature_fraction=0.542; lambda_l2=5.99 : y = 0.931 : 148.6 secs : infill_ei
#
# Thu Jul 31 22:18:34 2025 AUC 0.930522084060162
#
# [mbo] 199: learning_rate=0.00846; num_leaves=91; min_data_in_leaf=136; feature_fraction=0.347; lambda_l2=12.4 : y = 0.931 : 142.4 secs : infill_ei
#
# Thu Jul 31 22:21:10 2025 AUC 0.930255331652075
#
# [mbo] 200: learning_rate=0.0183; num_leaves=92; min_data_in_leaf=116; feature_fraction=0.542; lambda_l2=7.13 : y = 0.93 : 154.7 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "learning_rate"    "num_leaves"       "min_data_in_leaf" "feature_fraction"
#  [5] "lambda_l2"        "y"                "dob"              "eol"
#  [9] "error.message"    "exec.time"        "ei"               "error.model"
# [13] "train.time"       "prop.type"        "propose.time"     "se"
# [17] "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    learning_rate num_leaves min_data_in_leaf feature_fraction lambda_l2
#            <num>      <int>            <int>            <num>     <num>
# 1:   0.008769788         43               51         0.434597  9.532736
# [1] 0.9322113

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 333757
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 9.532736
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 1
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 2000
#
# $learning_rate
# [1] 0.008769788
#
# $feature_fraction
# [1] 0.434597
#
# $num_leaves
# [1] 43
#
# $min_data_in_leaf
# [1] 51

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Jul 31 23:05:43 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
