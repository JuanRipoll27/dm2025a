# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# Esta Tarea para el Hogar 02 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el viernes 01-agosto

# %% [markdown]
# ##  1. Cazatalentos

# %% [markdown]
# En la Clase 03 nos hemos enfrentado a  "La Maldicion del Ganandor",  elegir el modelo con el mejor puntaje simple no suele ser la mejor estrategia.
# <br> Lea y ejecute el notebook  **src/CazaTalentos/CazaTalentos.ipynb**
# <br> en caso de interesarle, participe del Desafío Ordenamiento  que vence el sábado 02 de agosto a las 19:00

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dm"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dm" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/itba2025-8d0a/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Jul 22 02:41:47 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  656827 35.1 1439371    76.9 1439371  76.9
# Vcells 1224707  9.4 8388608    64.0 1924958  14.7

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 4943
PARAM$semilla_primigenia <- 100887

# %%
PARAM$kaggle$competencia <- "data-mining-analista-sr-2025-a"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "dart", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_iterations", lower = 1000L, upper = 2500L),
  makeNumericParam("learning_rate", lower = 0.008, upper = 0.05),
  makeNumericParam("feature_fraction", lower = 0.45, upper = 0.65),
  makeNumericParam("bagging_fraction", lower = 0.6, upper = 0.85),
  makeIntegerParam("num_leaves", lower = 25L, upper = 100L),
  makeIntegerParam("min_data_in_leaf", lower = 300L, upper = 700L),
  makeIntegerParam("max_depth", lower = 8L, upper = 14L),
  makeNumericParam("lambda_l1", lower = 1.0, upper = 5.0),
  makeNumericParam("lambda_l2", lower = 1.0, upper = 5.0),
  makeNumericParam("min_gain_to_split", lower = 0.001, upper = 0.3),
  makeNumericParam("drop_rate", lower = 0.2, upper = 0.5),
  makeNumericParam("skip_drop", lower = 0.2, upper = 0.6)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 90 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83368
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Tue Jul 22 02:46:55 2025 AUC 0.929623544160339
#
# Tue Jul 22 02:49:42 2025 AUC 0.929856894315559
#
# Tue Jul 22 02:53:21 2025 AUC 0.930368513719964
#
# Tue Jul 22 02:57:26 2025 AUC 0.927089336701001
#
# Tue Jul 22 03:00:29 2025 AUC 0.926920668397732
#
# Tue Jul 22 03:04:56 2025 AUC 0.92916826396741
#
# Tue Jul 22 03:07:41 2025 AUC 0.928741613263164
#
# Tue Jul 22 03:13:17 2025 AUC 0.929413534944525
#
# Tue Jul 22 03:18:09 2025 AUC 0.929811313386963
#
# Tue Jul 22 03:22:34 2025 AUC 0.92565959414275
#
# Tue Jul 22 03:27:22 2025 AUC 0.92950950570908
#
# Tue Jul 22 03:30:45 2025 AUC 0.93026160953509
#
# Tue Jul 22 03:37:23 2025 AUC 0.929624412053936
#
# Tue Jul 22 03:40:16 2025 AUC 0.92481129858403
#
# Tue Jul 22 03:42:58 2025 AUC 0.926881216231945
#
# Tue Jul 22 03:47:56 2025 AUC 0.929535951076787
#
# Tue Jul 22 03:53:11 2025 AUC 0.929161575370188
#
# Tue Jul 22 03:56:26 2025 AUC 0.927680360254526
#
# Tue Jul 22 04:00:32 2025 AUC 0.929688582348481
#
# Tue Jul 22 04:05:42 2025 AUC 0.92844801218754
#
# Tue Jul 22 04:11:24 2025 AUC 0.928490124585911
#
# Tue Jul 22 04:15:32 2025 AUC 0.920696698341464
#
# Tue Jul 22 04:20:37 2025 AUC 0.929724295589525
#
# Tue Jul 22 04:23:29 2025 AUC 0.929886351522426
#
# Tue Jul 22 04:28:59 2025 AUC 0.929015687799691
#
# Tue Jul 22 04:35:21 2025 AUC 0.928740727416062
#
# Tue Jul 22 04:41:13 2025 AUC 0.929234520178419
#
# Tue Jul 22 04:46:38 2025 AUC 0.926111079545751
#
# Tue Jul 22 04:54:56 2025 AUC 0.930846423792277
#
# Tue Jul 22 04:58:05 2025 AUC 0.930269162867727
#
# Tue Jul 22 05:03:30 2025 AUC 0.929835596824862
#
# Tue Jul 22 05:05:34 2025 AUC 0.921104003352862
#
# Tue Jul 22 05:08:49 2025 AUC 0.925618729508451
#
# Tue Jul 22 05:11:23 2025 AUC 0.928506543732899
#
# Tue Jul 22 05:16:07 2025 AUC 0.928338978980541
#
# Tue Jul 22 05:18:29 2025 AUC 0.912006163760282
#
# Tue Jul 22 05:25:08 2025 AUC 0.929828156045118
#
# Tue Jul 22 05:31:23 2025 AUC 0.929657894045935
#
# Tue Jul 22 05:35:10 2025 AUC 0.929723921902476
#
# Tue Jul 22 05:38:22 2025 AUC 0.925238814294534
#
# Tue Jul 22 05:44:20 2025 AUC 0.92911643704344
#
# Tue Jul 22 05:47:15 2025 AUC 0.909952102091058
#
# Tue Jul 22 05:51:09 2025 AUC 0.916278247947931
#
# Tue Jul 22 05:53:05 2025 AUC 0.910270906614144
#
# Tue Jul 22 06:00:46 2025 AUC 0.929908240526095
#
# Tue Jul 22 06:04:18 2025 AUC 0.930544010002129
#
# Tue Jul 22 06:09:32 2025 AUC 0.929491902365467
#
# Tue Jul 22 06:13:31 2025 AUC 0.92761976065819
#
# [mbo] 0: num_iterations=1567; learning_rate=0.0299; feature_fraction=0.507; bagging_fraction=0.693; num_leaves=67; min_data_in_leaf=415; max_depth=10; lambda_l1=1.61; lambda_l2=2.27; min_gain_to_split=0.125; drop_rate=0.278; skip_drop=0.505 : y = 0.93 : 265.7 secs : initdesign
#
# [mbo] 0: num_iterations=1226; learning_rate=0.0293; feature_fraction=0.536; bagging_fraction=0.637; num_leaves=57; min_data_in_leaf=483; max_depth=11; lambda_l1=2.52; lambda_l2=2.8; min_gain_to_split=0.0925; drop_rate=0.234; skip_drop=0.46 : y = 0.93 : 167.6 secs : initdesign
#
# [mbo] 0: num_iterations=1443; learning_rate=0.0433; feature_fraction=0.591; bagging_fraction=0.766; num_leaves=36; min_data_in_leaf=567; max_depth=11; lambda_l1=2.83; lambda_l2=3.21; min_gain_to_split=0.174; drop_rate=0.333; skip_drop=0.517 : y = 0.93 : 218.9 secs : initdesign
#
# [mbo] 0: num_iterations=1640; learning_rate=0.0329; feature_fraction=0.469; bagging_fraction=0.757; num_leaves=48; min_data_in_leaf=520; max_depth=12; lambda_l1=2.95; lambda_l2=3.09; min_gain_to_split=0.163; drop_rate=0.36; skip_drop=0.242 : y = 0.927 : 245.1 secs : initdesign
#
# [mbo] 0: num_iterations=1482; learning_rate=0.0196; feature_fraction=0.567; bagging_fraction=0.774; num_leaves=50; min_data_in_leaf=574; max_depth=12; lambda_l1=4.15; lambda_l2=2.66; min_gain_to_split=0.199; drop_rate=0.397; skip_drop=0.42 : y = 0.927 : 182.5 secs : initdesign
#
# [mbo] 0: num_iterations=1707; learning_rate=0.0368; feature_fraction=0.563; bagging_fraction=0.745; num_leaves=55; min_data_in_leaf=629; max_depth=11; lambda_l1=3.26; lambda_l2=2.18; min_gain_to_split=0.205; drop_rate=0.266; skip_drop=0.332 : y = 0.929 : 267.6 secs : initdesign
#
# [mbo] 0: num_iterations=1171; learning_rate=0.0347; feature_fraction=0.52; bagging_fraction=0.678; num_leaves=72; min_data_in_leaf=473; max_depth=12; lambda_l1=3.04; lambda_l2=3.49; min_gain_to_split=0.0741; drop_rate=0.413; skip_drop=0.401 : y = 0.929 : 164.4 secs : initdesign
#
# [mbo] 0: num_iterations=2320; learning_rate=0.0191; feature_fraction=0.544; bagging_fraction=0.72; num_leaves=80; min_data_in_leaf=485; max_depth=10; lambda_l1=2.33; lambda_l2=4.49; min_gain_to_split=0.26; drop_rate=0.443; skip_drop=0.381 : y = 0.929 : 335.7 secs : initdesign
#
# [mbo] 0: num_iterations=2139; learning_rate=0.0264; feature_fraction=0.553; bagging_fraction=0.787; num_leaves=91; min_data_in_leaf=642; max_depth=8; lambda_l1=4.98; lambda_l2=1.43; min_gain_to_split=0.23; drop_rate=0.455; skip_drop=0.429 : y = 0.93 : 292.4 secs : initdesign
#
# [mbo] 0: num_iterations=1769; learning_rate=0.0237; feature_fraction=0.601; bagging_fraction=0.672; num_leaves=63; min_data_in_leaf=403; max_depth=9; lambda_l1=1.94; lambda_l2=3.76; min_gain_to_split=0.106; drop_rate=0.259; skip_drop=0.263 : y = 0.926 : 264.8 secs : initdesign
#
# [mbo] 0: num_iterations=1721; learning_rate=0.0318; feature_fraction=0.495; bagging_fraction=0.75; num_leaves=60; min_data_in_leaf=555; max_depth=11; lambda_l1=1.48; lambda_l2=2.52; min_gain_to_split=0.0978; drop_rate=0.368; skip_drop=0.513 : y = 0.93 : 287.9 secs : initdesign
#
# [mbo] 0: num_iterations=1510; learning_rate=0.0271; feature_fraction=0.485; bagging_fraction=0.645; num_leaves=97; min_data_in_leaf=458; max_depth=12; lambda_l1=3.37; lambda_l2=1.63; min_gain_to_split=0.146; drop_rate=0.426; skip_drop=0.542 : y = 0.93 : 203.7 secs : initdesign
#
# [mbo] 0: num_iterations=2270; learning_rate=0.0359; feature_fraction=0.524; bagging_fraction=0.63; num_leaves=70; min_data_in_leaf=596; max_depth=14; lambda_l1=3.76; lambda_l2=1.02; min_gain_to_split=0.0381; drop_rate=0.302; skip_drop=0.305 : y = 0.93 : 398.1 secs : initdesign
#
# [mbo] 0: num_iterations=1297; learning_rate=0.0138; feature_fraction=0.547; bagging_fraction=0.718; num_leaves=58; min_data_in_leaf=374; max_depth=9; lambda_l1=1.84; lambda_l2=4.26; min_gain_to_split=0.242; drop_rate=0.421; skip_drop=0.437 : y = 0.925 : 172.2 secs : initdesign
#
# [mbo] 0: num_iterations=1279; learning_rate=0.0175; feature_fraction=0.582; bagging_fraction=0.729; num_leaves=43; min_data_in_leaf=445; max_depth=13; lambda_l1=2.78; lambda_l2=1.83; min_gain_to_split=0.112; drop_rate=0.247; skip_drop=0.497 : y = 0.927 : 162.6 secs : initdesign
#
# [mbo] 0: num_iterations=2161; learning_rate=0.0218; feature_fraction=0.481; bagging_fraction=0.633; num_leaves=33; min_data_in_leaf=679; max_depth=9; lambda_l1=4.54; lambda_l2=2.88; min_gain_to_split=0.0682; drop_rate=0.317; skip_drop=0.468 : y = 0.93 : 297.6 secs : initdesign
#
# [mbo] 0: num_iterations=2113; learning_rate=0.0335; feature_fraction=0.615; bagging_fraction=0.652; num_leaves=40; min_data_in_leaf=647; max_depth=10; lambda_l1=3.62; lambda_l2=4.95; min_gain_to_split=0.233; drop_rate=0.348; skip_drop=0.351 : y = 0.929 : 314.9 secs : initdesign
#
# [mbo] 0: num_iterations=1356; learning_rate=0.0379; feature_fraction=0.454; bagging_fraction=0.771; num_leaves=80; min_data_in_leaf=465; max_depth=9; lambda_l1=3.84; lambda_l2=2.94; min_gain_to_split=0.266; drop_rate=0.299; skip_drop=0.291 : y = 0.928 : 195.5 secs : initdesign
#
# [mbo] 0: num_iterations=1597; learning_rate=0.0443; feature_fraction=0.619; bagging_fraction=0.78; num_leaves=71; min_data_in_leaf=436; max_depth=8; lambda_l1=2.69; lambda_l2=4.09; min_gain_to_split=0.0564; drop_rate=0.385; skip_drop=0.568 : y = 0.93 : 246.1 secs : initdesign
#
# [mbo] 0: num_iterations=2206; learning_rate=0.0276; feature_fraction=0.629; bagging_fraction=0.839; num_leaves=92; min_data_in_leaf=500; max_depth=13; lambda_l1=3.71; lambda_l2=4.86; min_gain_to_split=0.295; drop_rate=0.351; skip_drop=0.276 : y = 0.928 : 309.9 secs : initdesign
#
# [mbo] 0: num_iterations=1978; learning_rate=0.0283; feature_fraction=0.632; bagging_fraction=0.618; num_leaves=68; min_data_in_leaf=344; max_depth=13; lambda_l1=1.57; lambda_l2=3.38; min_gain_to_split=0.0818; drop_rate=0.481; skip_drop=0.36 : y = 0.928 : 341.4 secs : initdesign
#
# [mbo] 0: num_iterations=1661; learning_rate=0.0127; feature_fraction=0.511; bagging_fraction=0.612; num_leaves=87; min_data_in_leaf=673; max_depth=12; lambda_l1=1.69; lambda_l2=2.01; min_gain_to_split=0.211; drop_rate=0.459; skip_drop=0.335 : y = 0.921 : 248.0 secs : initdesign
#
# [mbo] 0: num_iterations=2290; learning_rate=0.0148; feature_fraction=0.465; bagging_fraction=0.809; num_leaves=47; min_data_in_leaf=602; max_depth=13; lambda_l1=3.5; lambda_l2=1.1; min_gain_to_split=0.0859; drop_rate=0.31; skip_drop=0.475 : y = 0.93 : 305.7 secs : initdesign
#
# [mbo] 0: num_iterations=1209; learning_rate=0.0464; feature_fraction=0.587; bagging_fraction=0.843; num_leaves=38; min_data_in_leaf=657; max_depth=13; lambda_l1=2.02; lambda_l2=4.71; min_gain_to_split=0.16; drop_rate=0.326; skip_drop=0.58 : y = 0.93 : 171.9 secs : initdesign
#
# [mbo] 0: num_iterations=1828; learning_rate=0.0417; feature_fraction=0.562; bagging_fraction=0.816; num_leaves=89; min_data_in_leaf=515; max_depth=10; lambda_l1=1.81; lambda_l2=1.99; min_gain_to_split=0.139; drop_rate=0.321; skip_drop=0.228 : y = 0.929 : 329.7 secs : initdesign
#
# [mbo] 0: num_iterations=1934; learning_rate=0.045; feature_fraction=0.64; bagging_fraction=0.738; num_leaves=83; min_data_in_leaf=550; max_depth=14; lambda_l1=1.27; lambda_l2=4.55; min_gain_to_split=0.217; drop_rate=0.215; skip_drop=0.488 : y = 0.929 : 382.2 secs : initdesign
#
# [mbo] 0: num_iterations=2366; learning_rate=0.0209; feature_fraction=0.635; bagging_fraction=0.687; num_leaves=65; min_data_in_leaf=356; max_depth=12; lambda_l1=4.35; lambda_l2=1.23; min_gain_to_split=0.0186; drop_rate=0.256; skip_drop=0.323 : y = 0.929 : 352.2 secs : initdesign
#
# [mbo] 0: num_iterations=2234; learning_rate=0.0123; feature_fraction=0.451; bagging_fraction=0.792; num_leaves=53; min_data_in_leaf=535; max_depth=9; lambda_l1=1.09; lambda_l2=4.36; min_gain_to_split=0.00428; drop_rate=0.375; skip_drop=0.348 : y = 0.926 : 324.5 secs : initdesign
#
# [mbo] 0: num_iterations=2455; learning_rate=0.0377; feature_fraction=0.473; bagging_fraction=0.794; num_leaves=76; min_data_in_leaf=396; max_depth=9; lambda_l1=1.01; lambda_l2=3.26; min_gain_to_split=0.293; drop_rate=0.498; skip_drop=0.394 : y = 0.931 : 498.5 secs : initdesign
#
# [mbo] 0: num_iterations=1146; learning_rate=0.0426; feature_fraction=0.53; bagging_fraction=0.834; num_leaves=94; min_data_in_leaf=388; max_depth=14; lambda_l1=2.65; lambda_l2=1.71; min_gain_to_split=0.223; drop_rate=0.274; skip_drop=0.533 : y = 0.93 : 188.9 secs : initdesign
#
# [mbo] 0: num_iterations=1943; learning_rate=0.048; feature_fraction=0.499; bagging_fraction=0.606; num_leaves=29; min_data_in_leaf=366; max_depth=11; lambda_l1=4.66; lambda_l2=4.61; min_gain_to_split=0.252; drop_rate=0.292; skip_drop=0.535 : y = 0.93 : 324.6 secs : initdesign
#
# [mbo] 0: num_iterations=1076; learning_rate=0.0228; feature_fraction=0.61; bagging_fraction=0.701; num_leaves=47; min_data_in_leaf=426; max_depth=9; lambda_l1=4.84; lambda_l2=4.22; min_gain_to_split=0.135; drop_rate=0.464; skip_drop=0.372 : y = 0.921 : 124.6 secs : initdesign
#
# [mbo] 0: num_iterations=1324; learning_rate=0.04; feature_fraction=0.517; bagging_fraction=0.622; num_leaves=78; min_data_in_leaf=338; max_depth=14; lambda_l1=3.98; lambda_l2=2.73; min_gain_to_split=0.0247; drop_rate=0.281; skip_drop=0.217 : y = 0.926 : 195.0 secs : initdesign
#
# [mbo] 0: num_iterations=1056; learning_rate=0.024; feature_fraction=0.558; bagging_fraction=0.807; num_leaves=55; min_data_in_leaf=311; max_depth=10; lambda_l1=2.11; lambda_l2=1.4; min_gain_to_split=0.0289; drop_rate=0.447; skip_drop=0.446 : y = 0.929 : 154.0 secs : initdesign
#
# [mbo] 0: num_iterations=2024; learning_rate=0.0252; feature_fraction=0.594; bagging_fraction=0.82; num_leaves=26; min_data_in_leaf=533; max_depth=8; lambda_l1=4.28; lambda_l2=2.48; min_gain_to_split=0.0618; drop_rate=0.226; skip_drop=0.316 : y = 0.928 : 283.7 secs : initdesign
#
# [mbo] 0: num_iterations=1104; learning_rate=0.0181; feature_fraction=0.489; bagging_fraction=0.849; num_leaves=85; min_data_in_leaf=699; max_depth=11; lambda_l1=3.11; lambda_l2=3.68; min_gain_to_split=0.128; drop_rate=0.342; skip_drop=0.27 : y = 0.912 : 142.0 secs : initdesign
#
# [mbo] 0: num_iterations=2476; learning_rate=0.0395; feature_fraction=0.599; bagging_fraction=0.694; num_leaves=96; min_data_in_leaf=418; max_depth=8; lambda_l1=3.57; lambda_l2=4.8; min_gain_to_split=0.118; drop_rate=0.388; skip_drop=0.208 : y = 0.93 : 398.5 secs : initdesign
#
# [mbo] 0: num_iterations=2382; learning_rate=0.0164; feature_fraction=0.608; bagging_fraction=0.665; num_leaves=74; min_data_in_leaf=615; max_depth=8; lambda_l1=1.34; lambda_l2=1.27; min_gain_to_split=0.187; drop_rate=0.221; skip_drop=0.388 : y = 0.93 : 375.0 secs : initdesign
#
# [mbo] 0: num_iterations=2063; learning_rate=0.00982; feature_fraction=0.459; bagging_fraction=0.681; num_leaves=62; min_data_in_leaf=375; max_depth=8; lambda_l1=2.46; lambda_l2=3.66; min_gain_to_split=0.178; drop_rate=0.2; skip_drop=0.6 : y = 0.93 : 227.3 secs : initdesign
#
# [mbo] 0: num_iterations=1406; learning_rate=0.0406; feature_fraction=0.578; bagging_fraction=0.825; num_leaves=26; min_data_in_leaf=496; max_depth=14; lambda_l1=4.76; lambda_l2=4.07; min_gain_to_split=0.0506; drop_rate=0.403; skip_drop=0.224 : y = 0.925 : 191.8 secs : initdesign
#
# [mbo] 0: num_iterations=2063; learning_rate=0.0499; feature_fraction=0.526; bagging_fraction=0.751; num_leaves=85; min_data_in_leaf=688; max_depth=14; lambda_l1=2.17; lambda_l2=3.84; min_gain_to_split=0.244; drop_rate=0.488; skip_drop=0.552 : y = 0.929 : 358.2 secs : initdesign
#
# [mbo] 0: num_iterations=1533; learning_rate=0.00942; feature_fraction=0.646; bagging_fraction=0.603; num_leaves=34; min_data_in_leaf=325; max_depth=14; lambda_l1=4.05; lambda_l2=3.51; min_gain_to_split=0.152; drop_rate=0.212; skip_drop=0.242 : y = 0.91 : 175.4 secs : initdesign
#
# [mbo] 0: num_iterations=1848; learning_rate=0.0112; feature_fraction=0.622; bagging_fraction=0.709; num_leaves=93; min_data_in_leaf=307; max_depth=10; lambda_l1=4.42; lambda_l2=1.87; min_gain_to_split=0.286; drop_rate=0.407; skip_drop=0.292 : y = 0.916 : 233.6 secs : initdesign
#
# [mbo] 0: num_iterations=1018; learning_rate=0.00816; feature_fraction=0.573; bagging_fraction=0.704; num_leaves=40; min_data_in_leaf=662; max_depth=13; lambda_l1=4.73; lambda_l2=1.58; min_gain_to_split=0.275; drop_rate=0.47; skip_drop=0.452 : y = 0.91 : 116.3 secs : initdesign
#
# [mbo] 0: num_iterations=2410; learning_rate=0.047; feature_fraction=0.541; bagging_fraction=0.662; num_leaves=29; min_data_in_leaf=577; max_depth=8; lambda_l1=3.23; lambda_l2=2.12; min_gain_to_split=0.19; drop_rate=0.482; skip_drop=0.41 : y = 0.93 : 461.0 secs : initdesign
#
# [mbo] 0: num_iterations=1879; learning_rate=0.0152; feature_fraction=0.643; bagging_fraction=0.801; num_leaves=32; min_data_in_leaf=587; max_depth=11; lambda_l1=2.38; lambda_l2=3.97; min_gain_to_split=0.0116; drop_rate=0.432; skip_drop=0.589 : y = 0.931 : 211.9 secs : initdesign
#
# [mbo] 0: num_iterations=1785; learning_rate=0.0486; feature_fraction=0.501; bagging_fraction=0.648; num_leaves=100; min_data_in_leaf=618; max_depth=11; lambda_l1=4.21; lambda_l2=2.34; min_gain_to_split=0.0428; drop_rate=0.239; skip_drop=0.564 : y = 0.929 : 313.6 secs : initdesign
#
# [mbo] 0: num_iterations=1398; learning_rate=0.0315; feature_fraction=0.478; bagging_fraction=0.731; num_leaves=44; min_data_in_leaf=321; max_depth=13; lambda_l1=1.23; lambda_l2=3; min_gain_to_split=0.277; drop_rate=0.375; skip_drop=0.25 : y = 0.928 : 239.4 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Tue Jul 22 06:19:26 2025 AUC 0.930417814834719
#
# [mbo] 1: num_iterations=2247; learning_rate=0.0228; feature_fraction=0.56; bagging_fraction=0.781; num_leaves=50; min_data_in_leaf=460; max_depth=12; lambda_l1=2.82; lambda_l2=1.72; min_gain_to_split=0.172; drop_rate=0.362; skip_drop=0.465 : y = 0.93 : 351.0 secs : infill_ei
#
# Tue Jul 22 06:25:13 2025 AUC 0.930204879021148
#
# [mbo] 2: num_iterations=2459; learning_rate=0.0201; feature_fraction=0.54; bagging_fraction=0.67; num_leaves=45; min_data_in_leaf=566; max_depth=11; lambda_l1=3.33; lambda_l2=2.74; min_gain_to_split=0.0466; drop_rate=0.27; skip_drop=0.577 : y = 0.93 : 346.5 secs : infill_ei
#
# Saved the current state after iteration 3 in the file bayesiana.RDATA.
#
# Tue Jul 22 06:32:32 2025 AUC 0.928564715030287
#
# [mbo] 3: num_iterations=2299; learning_rate=0.0397; feature_fraction=0.544; bagging_fraction=0.733; num_leaves=92; min_data_in_leaf=422; max_depth=10; lambda_l1=2.97; lambda_l2=2.58; min_gain_to_split=0.246; drop_rate=0.369; skip_drop=0.376 : y = 0.929 : 433.9 secs : infill_ei
#
# Tue Jul 22 06:38:08 2025 AUC 0.930337833647704
#
# [mbo] 4: num_iterations=2424; learning_rate=0.016; feature_fraction=0.468; bagging_fraction=0.768; num_leaves=53; min_data_in_leaf=516; max_depth=8; lambda_l1=1.29; lambda_l2=3.15; min_gain_to_split=0.0353; drop_rate=0.429; skip_drop=0.543 : y = 0.93 : 335.2 secs : infill_ei
#
# Saved the current state after iteration 5 in the file bayesiana.RDATA.
#
# Tue Jul 22 06:42:15 2025 AUC 0.930298947698893
#
# [mbo] 5: num_iterations=1996; learning_rate=0.02; feature_fraction=0.565; bagging_fraction=0.802; num_leaves=56; min_data_in_leaf=548; max_depth=9; lambda_l1=3.14; lambda_l2=3.97; min_gain_to_split=0.16; drop_rate=0.321; skip_drop=0.594 : y = 0.93 : 242.4 secs : infill_ei
#
# Tue Jul 22 06:48:47 2025 AUC 0.929827319576221
#
# [mbo] 6: num_iterations=2490; learning_rate=0.0199; feature_fraction=0.647; bagging_fraction=0.793; num_leaves=64; min_data_in_leaf=556; max_depth=11; lambda_l1=1.45; lambda_l2=2.73; min_gain_to_split=0.011; drop_rate=0.345; skip_drop=0.432 : y = 0.93 : 390.9 secs : infill_ei
#
# Saved the current state after iteration 7 in the file bayesiana.RDATA.
#
# Tue Jul 22 06:55:23 2025 AUC 0.929598648024456
#
# [mbo] 7: num_iterations=2460; learning_rate=0.0255; feature_fraction=0.493; bagging_fraction=0.768; num_leaves=64; min_data_in_leaf=532; max_depth=12; lambda_l1=4.18; lambda_l2=1.01; min_gain_to_split=0.0267; drop_rate=0.23; skip_drop=0.407 : y = 0.93 : 390.0 secs : infill_ei
#
# Tue Jul 22 06:59:08 2025 AUC 0.930294991840621
#
# [mbo] 8: num_iterations=1358; learning_rate=0.0465; feature_fraction=0.472; bagging_fraction=0.785; num_leaves=58; min_data_in_leaf=451; max_depth=12; lambda_l1=1.89; lambda_l2=2.71; min_gain_to_split=0.264; drop_rate=0.472; skip_drop=0.506 : y = 0.93 : 224.4 secs : infill_ei
#
# Saved the current state after iteration 9 in the file bayesiana.RDATA.
#
# Tue Jul 22 07:05:17 2025 AUC 0.929292354307886
#
# [mbo] 9: num_iterations=2143; learning_rate=0.0272; feature_fraction=0.541; bagging_fraction=0.623; num_leaves=67; min_data_in_leaf=517; max_depth=8; lambda_l1=2.11; lambda_l2=1.09; min_gain_to_split=0.288; drop_rate=0.345; skip_drop=0.412 : y = 0.929 : 363.2 secs : infill_ei
#
# Tue Jul 22 07:09:52 2025 AUC 0.930520532959874
#
# [mbo] 10: num_iterations=2199; learning_rate=0.0149; feature_fraction=0.486; bagging_fraction=0.81; num_leaves=34; min_data_in_leaf=399; max_depth=10; lambda_l1=2.21; lambda_l2=4.12; min_gain_to_split=0.0698; drop_rate=0.251; skip_drop=0.598 : y = 0.931 : 273.4 secs : infill_ei
#
# Saved the current state after iteration 11 in the file bayesiana.RDATA.
#
# Tue Jul 22 07:13:26 2025 AUC 0.929563038602512
#
# [mbo] 11: num_iterations=1566; learning_rate=0.0361; feature_fraction=0.542; bagging_fraction=0.808; num_leaves=66; min_data_in_leaf=531; max_depth=13; lambda_l1=3.62; lambda_l2=3.6; min_gain_to_split=0.289; drop_rate=0.493; skip_drop=0.581 : y = 0.93 : 209.4 secs : infill_ei
#
# Tue Jul 22 07:16:28 2025 AUC 0.930078697865939
#
# [mbo] 12: num_iterations=1151; learning_rate=0.0451; feature_fraction=0.501; bagging_fraction=0.621; num_leaves=52; min_data_in_leaf=547; max_depth=13; lambda_l1=2.85; lambda_l2=1.21; min_gain_to_split=0.138; drop_rate=0.29; skip_drop=0.581 : y = 0.93 : 181.5 secs : infill_ei
#
# Tue Jul 22 07:24:14 2025 AUC 0.930791152769094
#
# [mbo] 13: num_iterations=2497; learning_rate=0.0382; feature_fraction=0.485; bagging_fraction=0.752; num_leaves=63; min_data_in_leaf=475; max_depth=8; lambda_l1=1.2; lambda_l2=4.69; min_gain_to_split=0.156; drop_rate=0.468; skip_drop=0.28 : y = 0.931 : 464.3 secs : infill_ei
#
# Saved the current state after iteration 14 in the file bayesiana.RDATA.
#
# Tue Jul 22 07:29:01 2025 AUC 0.930382556407043
#
# [mbo] 14: num_iterations=2134; learning_rate=0.0161; feature_fraction=0.502; bagging_fraction=0.666; num_leaves=89; min_data_in_leaf=380; max_depth=11; lambda_l1=1.75; lambda_l2=3.88; min_gain_to_split=0.19; drop_rate=0.424; skip_drop=0.594 : y = 0.93 : 282.1 secs : infill_ei
#
# Tue Jul 22 07:33:21 2025 AUC 0.929413464662583
#
# [mbo] 15: num_iterations=2127; learning_rate=0.0146; feature_fraction=0.563; bagging_fraction=0.683; num_leaves=59; min_data_in_leaf=550; max_depth=8; lambda_l1=1.5; lambda_l2=4.64; min_gain_to_split=0.0548; drop_rate=0.257; skip_drop=0.582 : y = 0.929 : 258.7 secs : infill_ei
#
# Tue Jul 22 07:36:25 2025 AUC 0.930156590707547
#
# [mbo] 16: num_iterations=1347; learning_rate=0.0274; feature_fraction=0.572; bagging_fraction=0.774; num_leaves=57; min_data_in_leaf=373; max_depth=11; lambda_l1=2.41; lambda_l2=2.36; min_gain_to_split=0.0665; drop_rate=0.45; skip_drop=0.575 : y = 0.93 : 183.7 secs : infill_ei
#
# Saved the current state after iteration 17 in the file bayesiana.RDATA.
#
# Tue Jul 22 07:40:40 2025 AUC 0.930765154556441
#
# [mbo] 17: num_iterations=1793; learning_rate=0.0188; feature_fraction=0.491; bagging_fraction=0.778; num_leaves=42; min_data_in_leaf=349; max_depth=10; lambda_l1=2.01; lambda_l2=2.17; min_gain_to_split=0.043; drop_rate=0.427; skip_drop=0.562 : y = 0.931 : 250.1 secs : infill_ei
#
# Tue Jul 22 07:48:01 2025 AUC 0.929793340083085
#
# [mbo] 18: num_iterations=2494; learning_rate=0.0243; feature_fraction=0.521; bagging_fraction=0.79; num_leaves=70; min_data_in_leaf=356; max_depth=12; lambda_l1=1.89; lambda_l2=2.01; min_gain_to_split=0.0117; drop_rate=0.399; skip_drop=0.512 : y = 0.93 : 439.4 secs : infill_ei
#
# Saved the current state after iteration 19 in the file bayesiana.RDATA.
#
# Tue Jul 22 07:52:40 2025 AUC 0.9298139521556
#
# [mbo] 19: num_iterations=2069; learning_rate=0.0214; feature_fraction=0.467; bagging_fraction=0.7; num_leaves=39; min_data_in_leaf=376; max_depth=8; lambda_l1=1.92; lambda_l2=4.13; min_gain_to_split=0.0929; drop_rate=0.454; skip_drop=0.6 : y = 0.93 : 272.8 secs : infill_ei
#
# Tue Jul 22 07:57:19 2025 AUC 0.931008441421782
#
# [mbo] 20: num_iterations=2158; learning_rate=0.0226; feature_fraction=0.613; bagging_fraction=0.731; num_leaves=59; min_data_in_leaf=583; max_depth=12; lambda_l1=4.02; lambda_l2=2.25; min_gain_to_split=0.0929; drop_rate=0.447; skip_drop=0.5 : y = 0.931 : 278.8 secs : infill_ei
#
# Tue Jul 22 08:02:45 2025 AUC 0.929292368983429
#
# [mbo] 21: num_iterations=2175; learning_rate=0.029; feature_fraction=0.638; bagging_fraction=0.623; num_leaves=48; min_data_in_leaf=611; max_depth=10; lambda_l1=4.54; lambda_l2=1.03; min_gain_to_split=0.0388; drop_rate=0.258; skip_drop=0.446 : y = 0.929 : 324.7 secs : infill_ei
#
# Saved the current state after iteration 22 in the file bayesiana.RDATA.
#
# Tue Jul 22 08:06:35 2025 AUC 0.929974574792512
#
# [mbo] 22: num_iterations=1306; learning_rate=0.0387; feature_fraction=0.466; bagging_fraction=0.782; num_leaves=56; min_data_in_leaf=339; max_depth=12; lambda_l1=1.02; lambda_l2=2.48; min_gain_to_split=0.192; drop_rate=0.425; skip_drop=0.578 : y = 0.93 : 224.6 secs : infill_ei
#
# Tue Jul 22 08:11:12 2025 AUC 0.930451972592586
#
# [mbo] 23: num_iterations=2225; learning_rate=0.0196; feature_fraction=0.487; bagging_fraction=0.799; num_leaves=25; min_data_in_leaf=573; max_depth=12; lambda_l1=3.3; lambda_l2=2.83; min_gain_to_split=0.193; drop_rate=0.45; skip_drop=0.544 : y = 0.93 : 275.7 secs : infill_ei
#
# Tue Jul 22 08:14:50 2025 AUC 0.930010080554766
#
# [mbo] 24: num_iterations=1817; learning_rate=0.0186; feature_fraction=0.481; bagging_fraction=0.801; num_leaves=49; min_data_in_leaf=486; max_depth=12; lambda_l1=2.39; lambda_l2=2.02; min_gain_to_split=0.00572; drop_rate=0.424; skip_drop=0.599 : y = 0.93 : 217.4 secs : infill_ei
#
# Saved the current state after iteration 25 in the file bayesiana.RDATA.
#
# Tue Jul 22 08:20:58 2025 AUC 0.929728603703778
#
# [mbo] 25: num_iterations=2429; learning_rate=0.0191; feature_fraction=0.523; bagging_fraction=0.703; num_leaves=81; min_data_in_leaf=323; max_depth=8; lambda_l1=3.62; lambda_l2=1.29; min_gain_to_split=0.119; drop_rate=0.221; skip_drop=0.515 : y = 0.93 : 361.7 secs : infill_ei
#
# Tue Jul 22 08:29:47 2025 AUC 0.929461998419476
#
# [mbo] 26: num_iterations=2491; learning_rate=0.0355; feature_fraction=0.588; bagging_fraction=0.81; num_leaves=55; min_data_in_leaf=393; max_depth=8; lambda_l1=1.12; lambda_l2=1.64; min_gain_to_split=0.208; drop_rate=0.473; skip_drop=0.252 : y = 0.929 : 527.4 secs : infill_ei
#
# Saved the current state after iteration 27 in the file bayesiana.RDATA.
#
# Tue Jul 22 08:35:42 2025 AUC 0.930150656066249
#
# [mbo] 27: num_iterations=2370; learning_rate=0.0293; feature_fraction=0.603; bagging_fraction=0.654; num_leaves=94; min_data_in_leaf=587; max_depth=11; lambda_l1=3.42; lambda_l2=3.9; min_gain_to_split=0.174; drop_rate=0.481; skip_drop=0.479 : y = 0.93 : 349.5 secs : infill_ei
#
# Tue Jul 22 08:42:34 2025 AUC 0.930087798243302
#
# [mbo] 28: num_iterations=2123; learning_rate=0.0431; feature_fraction=0.454; bagging_fraction=0.78; num_leaves=50; min_data_in_leaf=589; max_depth=8; lambda_l1=1.05; lambda_l2=4.63; min_gain_to_split=0.268; drop_rate=0.48; skip_drop=0.409 : y = 0.93 : 411.3 secs : infill_ei
#
# Saved the current state after iteration 29 in the file bayesiana.RDATA.
#
# Tue Jul 22 08:47:54 2025 AUC 0.929731352808554
#
# [mbo] 29: num_iterations=2500; learning_rate=0.0202; feature_fraction=0.581; bagging_fraction=0.775; num_leaves=67; min_data_in_leaf=552; max_depth=11; lambda_l1=3.6; lambda_l2=3.32; min_gain_to_split=0.267; drop_rate=0.443; skip_drop=0.55 : y = 0.93 : 312.8 secs : infill_ei
#
# Tue Jul 22 08:51:23 2025 AUC 0.929607703442076
#
# [mbo] 30: num_iterations=1260; learning_rate=0.047; feature_fraction=0.529; bagging_fraction=0.704; num_leaves=69; min_data_in_leaf=446; max_depth=12; lambda_l1=2.53; lambda_l2=4.38; min_gain_to_split=0.194; drop_rate=0.272; skip_drop=0.554 : y = 0.93 : 207.7 secs : infill_ei
#
# Tue Jul 22 08:55:59 2025 AUC 0.930035709859329
#
# [mbo] 31: num_iterations=1843; learning_rate=0.0474; feature_fraction=0.486; bagging_fraction=0.845; num_leaves=29; min_data_in_leaf=587; max_depth=9; lambda_l1=4.54; lambda_l2=2.96; min_gain_to_split=0.119; drop_rate=0.42; skip_drop=0.565 : y = 0.93 : 274.8 secs : infill_ei
#
# Saved the current state after iteration 32 in the file bayesiana.RDATA.
#
# Tue Jul 22 09:01:10 2025 AUC 0.928961288516518
#
# [mbo] 32: num_iterations=2202; learning_rate=0.0197; feature_fraction=0.573; bagging_fraction=0.755; num_leaves=32; min_data_in_leaf=592; max_depth=8; lambda_l1=2.19; lambda_l2=2.61; min_gain_to_split=0.102; drop_rate=0.448; skip_drop=0.489 : y = 0.929 : 303.7 secs : infill_ei
#
# Tue Jul 22 09:07:07 2025 AUC 0.929138882789683
#
# [mbo] 33: num_iterations=2409; learning_rate=0.022; feature_fraction=0.453; bagging_fraction=0.601; num_leaves=88; min_data_in_leaf=576; max_depth=13; lambda_l1=3.31; lambda_l2=2.13; min_gain_to_split=0.168; drop_rate=0.375; skip_drop=0.455 : y = 0.929 : 355.7 secs : infill_ei
#
# Saved the current state after iteration 34 in the file bayesiana.RDATA.
#
# Tue Jul 22 09:12:32 2025 AUC 0.93069778678581
#
# [mbo] 34: num_iterations=2302; learning_rate=0.016; feature_fraction=0.45; bagging_fraction=0.8; num_leaves=64; min_data_in_leaf=321; max_depth=9; lambda_l1=1.22; lambda_l2=4.24; min_gain_to_split=0.225; drop_rate=0.434; skip_drop=0.556 : y = 0.931 : 320.5 secs : infill_ei
#
# Tue Jul 22 09:16:37 2025 AUC 0.930539897024268
#
# [mbo] 35: num_iterations=1974; learning_rate=0.0241; feature_fraction=0.632; bagging_fraction=0.84; num_leaves=40; min_data_in_leaf=601; max_depth=13; lambda_l1=4.54; lambda_l2=2.54; min_gain_to_split=0.056; drop_rate=0.33; skip_drop=0.554 : y = 0.931 : 243.6 secs : infill_ei
#
# Tue Jul 22 09:20:51 2025 AUC 0.928684312187685
#
# [mbo] 36: num_iterations=1951; learning_rate=0.0209; feature_fraction=0.577; bagging_fraction=0.798; num_leaves=61; min_data_in_leaf=404; max_depth=12; lambda_l1=3.99; lambda_l2=3.31; min_gain_to_split=0.0442; drop_rate=0.408; skip_drop=0.537 : y = 0.929 : 253.4 secs : infill_ei
#
# Saved the current state after iteration 37 in the file bayesiana.RDATA.
#
# Tue Jul 22 09:24:37 2025 AUC 0.929741120022224
#
# [mbo] 37: num_iterations=1655; learning_rate=0.0251; feature_fraction=0.615; bagging_fraction=0.754; num_leaves=48; min_data_in_leaf=573; max_depth=13; lambda_l1=2.26; lambda_l2=1.97; min_gain_to_split=0.222; drop_rate=0.438; skip_drop=0.535 : y = 0.93 : 220.5 secs : infill_ei
#
# Tue Jul 22 09:30:09 2025 AUC 0.930522688682379
#
# [mbo] 38: num_iterations=2278; learning_rate=0.0156; feature_fraction=0.488; bagging_fraction=0.682; num_leaves=51; min_data_in_leaf=363; max_depth=10; lambda_l1=1.01; lambda_l2=1.25; min_gain_to_split=0.197; drop_rate=0.43; skip_drop=0.593 : y = 0.931 : 330.6 secs : infill_ei
#
# Tue Jul 22 09:36:06 2025 AUC 0.929996101157145
#
# [mbo] 39: num_iterations=2348; learning_rate=0.0267; feature_fraction=0.472; bagging_fraction=0.761; num_leaves=88; min_data_in_leaf=414; max_depth=8; lambda_l1=1.22; lambda_l2=3.92; min_gain_to_split=0.154; drop_rate=0.49; skip_drop=0.575 : y = 0.93 : 355.4 secs : infill_ei
#
# Saved the current state after iteration 40 in the file bayesiana.RDATA.
#
# Tue Jul 22 09:39:37 2025 AUC 0.929867449862469
#
# [mbo] 40: num_iterations=1301; learning_rate=0.0379; feature_fraction=0.528; bagging_fraction=0.698; num_leaves=81; min_data_in_leaf=474; max_depth=12; lambda_l1=2.06; lambda_l2=1.07; min_gain_to_split=0.0518; drop_rate=0.41; skip_drop=0.578 : y = 0.93 : 203.6 secs : infill_ei
#
# Tue Jul 22 09:48:29 2025 AUC 0.929280323208323
#
# [mbo] 41: num_iterations=2498; learning_rate=0.047; feature_fraction=0.491; bagging_fraction=0.654; num_leaves=59; min_data_in_leaf=433; max_depth=9; lambda_l1=1.23; lambda_l2=4.51; min_gain_to_split=0.236; drop_rate=0.488; skip_drop=0.239 : y = 0.929 : 530.5 secs : infill_ei
#
# Saved the current state after iteration 42 in the file bayesiana.RDATA.
#
# Tue Jul 22 09:54:57 2025 AUC 0.929664583651274
#
# [mbo] 42: num_iterations=2417; learning_rate=0.0399; feature_fraction=0.484; bagging_fraction=0.645; num_leaves=43; min_data_in_leaf=655; max_depth=9; lambda_l1=3.99; lambda_l2=4.14; min_gain_to_split=0.146; drop_rate=0.341; skip_drop=0.541 : y = 0.93 : 381.3 secs : infill_ei
#
# Tue Jul 22 10:00:33 2025 AUC 0.929881995560858
#
# [mbo] 43: num_iterations=1971; learning_rate=0.0457; feature_fraction=0.565; bagging_fraction=0.608; num_leaves=54; min_data_in_leaf=613; max_depth=11; lambda_l1=4.16; lambda_l2=4.41; min_gain_to_split=0.0785; drop_rate=0.491; skip_drop=0.497 : y = 0.93 : 333.9 secs : infill_ei
#
# Saved the current state after iteration 44 in the file bayesiana.RDATA.
#
# Tue Jul 22 10:04:13 2025 AUC 0.929696497521004
#
# [mbo] 44: num_iterations=1370; learning_rate=0.0459; feature_fraction=0.584; bagging_fraction=0.848; num_leaves=74; min_data_in_leaf=608; max_depth=12; lambda_l1=4; lambda_l2=1.39; min_gain_to_split=0.15; drop_rate=0.327; skip_drop=0.541 : y = 0.93 : 214.8 secs : infill_ei
#
# Tue Jul 22 10:09:14 2025 AUC 0.930272545319097
#
# [mbo] 45: num_iterations=2113; learning_rate=0.016; feature_fraction=0.45; bagging_fraction=0.812; num_leaves=69; min_data_in_leaf=384; max_depth=8; lambda_l1=1.3; lambda_l2=1.97; min_gain_to_split=0.219; drop_rate=0.291; skip_drop=0.585 : y = 0.93 : 300.1 secs : infill_ei
#
# Tue Jul 22 10:12:50 2025 AUC 0.931353860787968
#
# [mbo] 46: num_iterations=1419; learning_rate=0.0245; feature_fraction=0.46; bagging_fraction=0.801; num_leaves=31; min_data_in_leaf=347; max_depth=10; lambda_l1=1.78; lambda_l2=1.37; min_gain_to_split=0.186; drop_rate=0.408; skip_drop=0.517 : y = 0.931 : 214.5 secs : infill_ei
#
# Saved the current state after iteration 47 in the file bayesiana.RDATA.
#
# Tue Jul 22 10:16:34 2025 AUC 0.930103893868231
#
# [mbo] 47: num_iterations=1286; learning_rate=0.0333; feature_fraction=0.482; bagging_fraction=0.797; num_leaves=41; min_data_in_leaf=368; max_depth=13; lambda_l1=1.95; lambda_l2=1.08; min_gain_to_split=0.143; drop_rate=0.315; skip_drop=0.463 : y = 0.93 : 218.1 secs : infill_ei
#
# Tue Jul 22 10:19:50 2025 AUC 0.930594341038302
#
# [mbo] 48: num_iterations=1439; learning_rate=0.0194; feature_fraction=0.477; bagging_fraction=0.734; num_leaves=33; min_data_in_leaf=310; max_depth=9; lambda_l1=1.22; lambda_l2=2.04; min_gain_to_split=0.0716; drop_rate=0.383; skip_drop=0.591 : y = 0.931 : 194.9 secs : infill_ei
#
# Tue Jul 22 10:27:14 2025 AUC 0.930544972240484
#
# [mbo] 49: num_iterations=2431; learning_rate=0.0289; feature_fraction=0.461; bagging_fraction=0.682; num_leaves=35; min_data_in_leaf=351; max_depth=11; lambda_l1=1.77; lambda_l2=4.83; min_gain_to_split=0.253; drop_rate=0.317; skip_drop=0.48 : y = 0.931 : 442.3 secs : infill_ei
#
# Saved the current state after iteration 50 in the file bayesiana.RDATA.
#
# Tue Jul 22 10:34:04 2025 AUC 0.929941498231178
#
# [mbo] 50: num_iterations=2091; learning_rate=0.043; feature_fraction=0.459; bagging_fraction=0.846; num_leaves=37; min_data_in_leaf=326; max_depth=8; lambda_l1=1.56; lambda_l2=4.4; min_gain_to_split=0.236; drop_rate=0.436; skip_drop=0.433 : y = 0.93 : 403.7 secs : infill_ei
#
# Tue Jul 22 10:37:42 2025 AUC 0.930171186915757
#
# [mbo] 51: num_iterations=1423; learning_rate=0.0268; feature_fraction=0.459; bagging_fraction=0.653; num_leaves=54; min_data_in_leaf=323; max_depth=9; lambda_l1=2.16; lambda_l2=1.34; min_gain_to_split=0.174; drop_rate=0.492; skip_drop=0.468 : y = 0.93 : 216.4 secs : infill_ei
#
# Saved the current state after iteration 52 in the file bayesiana.RDATA.
#
# Tue Jul 22 10:41:16 2025 AUC 0.931360839711461
#
# [mbo] 52: num_iterations=1539; learning_rate=0.0261; feature_fraction=0.455; bagging_fraction=0.781; num_leaves=25; min_data_in_leaf=302; max_depth=10; lambda_l1=2.44; lambda_l2=2.67; min_gain_to_split=0.228; drop_rate=0.303; skip_drop=0.569 : y = 0.931 : 207.2 secs : infill_ei
#
# Tue Jul 22 10:47:03 2025 AUC 0.92979584827335
#
# [mbo] 53: num_iterations=2106; learning_rate=0.0276; feature_fraction=0.456; bagging_fraction=0.823; num_leaves=49; min_data_in_leaf=471; max_depth=11; lambda_l1=1.52; lambda_l2=4.77; min_gain_to_split=0.243; drop_rate=0.455; skip_drop=0.482 : y = 0.93 : 345.9 secs : infill_ei
#
# Tue Jul 22 10:51:14 2025 AUC 0.930103071416568
#
# [mbo] 54: num_iterations=1468; learning_rate=0.0453; feature_fraction=0.499; bagging_fraction=0.827; num_leaves=100; min_data_in_leaf=519; max_depth=8; lambda_l1=1.49; lambda_l2=2.98; min_gain_to_split=0.162; drop_rate=0.481; skip_drop=0.53 : y = 0.93 : 248.7 secs : infill_ei
#
# Saved the current state after iteration 55 in the file bayesiana.RDATA.
#
# Tue Jul 22 10:57:01 2025 AUC 0.930356966603078
#
# [mbo] 55: num_iterations=2079; learning_rate=0.0195; feature_fraction=0.452; bagging_fraction=0.745; num_leaves=29; min_data_in_leaf=335; max_depth=10; lambda_l1=1.6; lambda_l2=1.14; min_gain_to_split=0.175; drop_rate=0.218; skip_drop=0.45 : y = 0.93 : 339.6 secs : infill_ei
#
# Tue Jul 22 11:00:37 2025 AUC 0.930812560194782
#
# [mbo] 56: num_iterations=1769; learning_rate=0.0173; feature_fraction=0.459; bagging_fraction=0.735; num_leaves=28; min_data_in_leaf=349; max_depth=10; lambda_l1=1.83; lambda_l2=4.4; min_gain_to_split=0.28; drop_rate=0.271; skip_drop=0.596 : y = 0.931 : 213.8 secs : infill_ei
#
# Tue Jul 22 11:08:27 2025 AUC 0.930754466762781
#
# [mbo] 57: num_iterations=2499; learning_rate=0.0322; feature_fraction=0.466; bagging_fraction=0.76; num_leaves=94; min_data_in_leaf=322; max_depth=8; lambda_l1=1.24; lambda_l2=4.79; min_gain_to_split=0.252; drop_rate=0.49; skip_drop=0.335 : y = 0.931 : 469.0 secs : infill_ei
#
# Saved the current state after iteration 58 in the file bayesiana.RDATA.
#
# Tue Jul 22 11:14:15 2025 AUC 0.930287957824974
#
# [mbo] 58: num_iterations=2416; learning_rate=0.0251; feature_fraction=0.626; bagging_fraction=0.724; num_leaves=39; min_data_in_leaf=626; max_depth=13; lambda_l1=4.86; lambda_l2=2.53; min_gain_to_split=0.0839; drop_rate=0.381; skip_drop=0.413 : y = 0.93 : 340.5 secs : infill_ei
#
# Tue Jul 22 11:21:21 2025 AUC 0.931259782858116
#
# [mbo] 59: num_iterations=2457; learning_rate=0.0468; feature_fraction=0.459; bagging_fraction=0.653; num_leaves=27; min_data_in_leaf=410; max_depth=11; lambda_l1=1.71; lambda_l2=2.81; min_gain_to_split=0.0497; drop_rate=0.478; skip_drop=0.54 : y = 0.931 : 424.9 secs : infill_ei
#
# Saved the current state after iteration 60 in the file bayesiana.RDATA.
#
# Tue Jul 22 11:29:50 2025 AUC 0.930479526537011
#
# [mbo] 60: num_iterations=2490; learning_rate=0.0431; feature_fraction=0.452; bagging_fraction=0.836; num_leaves=40; min_data_in_leaf=370; max_depth=9; lambda_l1=1.16; lambda_l2=4.04; min_gain_to_split=0.107; drop_rate=0.498; skip_drop=0.494 : y = 0.93 : 503.4 secs : infill_ei
#
# Tue Jul 22 11:37:38 2025 AUC 0.93052351312277
#
# [mbo] 61: num_iterations=2454; learning_rate=0.0368; feature_fraction=0.49; bagging_fraction=0.702; num_leaves=27; min_data_in_leaf=348; max_depth=13; lambda_l1=1.25; lambda_l2=3.42; min_gain_to_split=0.0583; drop_rate=0.455; skip_drop=0.389 : y = 0.931 : 466.3 secs : infill_ei
#
# Saved the current state after iteration 62 in the file bayesiana.RDATA.
#
# Tue Jul 22 11:43:53 2025 AUC 0.930153498323507
#
# [mbo] 62: num_iterations=2389; learning_rate=0.0166; feature_fraction=0.496; bagging_fraction=0.711; num_leaves=53; min_data_in_leaf=412; max_depth=11; lambda_l1=1.27; lambda_l2=3.58; min_gain_to_split=0.181; drop_rate=0.243; skip_drop=0.576 : y = 0.93 : 368.3 secs : infill_ei
#
# Tue Jul 22 11:48:59 2025 AUC 0.931230711504392
#
# [mbo] 63: num_iterations=1893; learning_rate=0.0494; feature_fraction=0.489; bagging_fraction=0.644; num_leaves=25; min_data_in_leaf=515; max_depth=12; lambda_l1=1.44; lambda_l2=3.45; min_gain_to_split=0.0755; drop_rate=0.43; skip_drop=0.548 : y = 0.931 : 304.4 secs : infill_ei
#
# Saved the current state after iteration 64 in the file bayesiana.RDATA.
#
# Tue Jul 22 11:53:43 2025 AUC 0.930419683689182
#
# [mbo] 64: num_iterations=2288; learning_rate=0.0165; feature_fraction=0.471; bagging_fraction=0.776; num_leaves=28; min_data_in_leaf=603; max_depth=10; lambda_l1=4.58; lambda_l2=1.29; min_gain_to_split=0.0997; drop_rate=0.286; skip_drop=0.596 : y = 0.93 : 277.8 secs : infill_ei
#
# Tue Jul 22 11:59:19 2025 AUC 0.931070312526498
#
# [mbo] 65: num_iterations=1895; learning_rate=0.0498; feature_fraction=0.462; bagging_fraction=0.667; num_leaves=25; min_data_in_leaf=360; max_depth=12; lambda_l1=1.83; lambda_l2=1.44; min_gain_to_split=0.0554; drop_rate=0.367; skip_drop=0.53 : y = 0.931 : 334.6 secs : infill_ei
#
# Saved the current state after iteration 66 in the file bayesiana.RDATA.
#
# Tue Jul 22 12:04:54 2025 AUC 0.93055546702367
#
# [mbo] 66: num_iterations=1823; learning_rate=0.0463; feature_fraction=0.483; bagging_fraction=0.693; num_leaves=25; min_data_in_leaf=535; max_depth=14; lambda_l1=2.7; lambda_l2=2.25; min_gain_to_split=0.0397; drop_rate=0.416; skip_drop=0.523 : y = 0.931 : 328.0 secs : infill_ei
#
# Tue Jul 22 12:11:45 2025 AUC 0.93108894988122
#
# [mbo] 67: num_iterations=2028; learning_rate=0.0486; feature_fraction=0.455; bagging_fraction=0.631; num_leaves=25; min_data_in_leaf=432; max_depth=9; lambda_l1=1.26; lambda_l2=2.97; min_gain_to_split=0.0268; drop_rate=0.336; skip_drop=0.426 : y = 0.931 : 410.4 secs : infill_ei
#
# Saved the current state after iteration 68 in the file bayesiana.RDATA.
#
# Tue Jul 22 12:17:19 2025 AUC 0.931577221119704
#
# [mbo] 68: num_iterations=1886; learning_rate=0.0491; feature_fraction=0.455; bagging_fraction=0.652; num_leaves=25; min_data_in_leaf=448; max_depth=8; lambda_l1=2.24; lambda_l2=2.74; min_gain_to_split=0.0577; drop_rate=0.466; skip_drop=0.544 : y = 0.932 : 327.5 secs : infill_ei
#
# Tue Jul 22 12:21:49 2025 AUC 0.930121151454288
#
# [mbo] 69: num_iterations=1806; learning_rate=0.0229; feature_fraction=0.493; bagging_fraction=0.784; num_leaves=25; min_data_in_leaf=436; max_depth=9; lambda_l1=2.12; lambda_l2=2.26; min_gain_to_split=0.0945; drop_rate=0.231; skip_drop=0.59 : y = 0.93 : 268.8 secs : infill_ei
#
# Tue Jul 22 12:25:37 2025 AUC 0.929468564103368
#
# [mbo] 70: num_iterations=1466; learning_rate=0.0247; feature_fraction=0.485; bagging_fraction=0.781; num_leaves=31; min_data_in_leaf=333; max_depth=10; lambda_l1=2.66; lambda_l2=3.23; min_gain_to_split=0.284; drop_rate=0.332; skip_drop=0.498 : y = 0.929 : 225.7 secs : infill_ei
#
# Saved the current state after iteration 71 in the file bayesiana.RDATA.
#
# Tue Jul 22 12:31:04 2025 AUC 0.931003409000845
#
# [mbo] 71: num_iterations=1840; learning_rate=0.047; feature_fraction=0.452; bagging_fraction=0.608; num_leaves=26; min_data_in_leaf=382; max_depth=9; lambda_l1=2.12; lambda_l2=3.69; min_gain_to_split=0.0421; drop_rate=0.311; skip_drop=0.574 : y = 0.931 : 320.7 secs : infill_ei
#
# Tue Jul 22 12:35:50 2025 AUC 0.930955559041083
#
# [mbo] 72: num_iterations=1808; learning_rate=0.0243; feature_fraction=0.451; bagging_fraction=0.821; num_leaves=26; min_data_in_leaf=303; max_depth=11; lambda_l1=1.3; lambda_l2=1.78; min_gain_to_split=0.2; drop_rate=0.373; skip_drop=0.584 : y = 0.931 : 283.4 secs : infill_ei
#
# Saved the current state after iteration 73 in the file bayesiana.RDATA.
#
# Tue Jul 22 12:39:15 2025 AUC 0.930447573093138
#
# [mbo] 73: num_iterations=1465; learning_rate=0.0293; feature_fraction=0.451; bagging_fraction=0.634; num_leaves=25; min_data_in_leaf=553; max_depth=12; lambda_l1=3.54; lambda_l2=4.16; min_gain_to_split=0.197; drop_rate=0.207; skip_drop=0.594 : y = 0.93 : 200.1 secs : infill_ei
#
# Tue Jul 22 12:42:56 2025 AUC 0.930005086534329
#
# [mbo] 74: num_iterations=1489; learning_rate=0.0276; feature_fraction=0.45; bagging_fraction=0.796; num_leaves=26; min_data_in_leaf=303; max_depth=9; lambda_l1=4.2; lambda_l2=1.02; min_gain_to_split=0.175; drop_rate=0.348; skip_drop=0.581 : y = 0.93 : 219.4 secs : infill_ei
#
# Tue Jul 22 12:50:18 2025 AUC 0.930410782066107
#
# [mbo] 75: num_iterations=2318; learning_rate=0.05; feature_fraction=0.451; bagging_fraction=0.64; num_leaves=25; min_data_in_leaf=496; max_depth=9; lambda_l1=2.23; lambda_l2=4.02; min_gain_to_split=0.0643; drop_rate=0.354; skip_drop=0.52 : y = 0.93 : 439.9 secs : infill_ei
#
# Saved the current state after iteration 76 in the file bayesiana.RDATA.
#
# Tue Jul 22 12:57:02 2025 AUC 0.93127195730999
#
# [mbo] 76: num_iterations=2027; learning_rate=0.0476; feature_fraction=0.461; bagging_fraction=0.615; num_leaves=31; min_data_in_leaf=384; max_depth=10; lambda_l1=1.52; lambda_l2=3.41; min_gain_to_split=0.124; drop_rate=0.498; skip_drop=0.532 : y = 0.931 : 397.5 secs : infill_ei
#
# Tue Jul 22 13:00:45 2025 AUC 0.930971050842795
#
# [mbo] 77: num_iterations=1336; learning_rate=0.0467; feature_fraction=0.502; bagging_fraction=0.759; num_leaves=25; min_data_in_leaf=390; max_depth=10; lambda_l1=1.42; lambda_l2=2.25; min_gain_to_split=0.0684; drop_rate=0.46; skip_drop=0.552 : y = 0.931 : 221.6 secs : infill_ei
#
# Saved the current state after iteration 78 in the file bayesiana.RDATA.
#
# Tue Jul 22 13:07:04 2025 AUC 0.929713664412275
#
# [mbo] 78: num_iterations=1694; learning_rate=0.049; feature_fraction=0.518; bagging_fraction=0.776; num_leaves=31; min_data_in_leaf=444; max_depth=9; lambda_l1=1.03; lambda_l2=1.58; min_gain_to_split=0.0736; drop_rate=0.493; skip_drop=0.42 : y = 0.93 : 373.0 secs : infill_ei
#
# Tue Jul 22 13:12:00 2025 AUC 0.930967587873977
#
# [mbo] 79: num_iterations=1613; learning_rate=0.0457; feature_fraction=0.451; bagging_fraction=0.628; num_leaves=27; min_data_in_leaf=603; max_depth=9; lambda_l1=1.9; lambda_l2=1.97; min_gain_to_split=0.0438; drop_rate=0.412; skip_drop=0.505 : y = 0.931 : 294.0 secs : infill_ei
#
# Saved the current state after iteration 80 in the file bayesiana.RDATA.
#
# Tue Jul 22 13:20:27 2025 AUC 0.929719743724455
#
# [mbo] 80: num_iterations=2500; learning_rate=0.0359; feature_fraction=0.592; bagging_fraction=0.643; num_leaves=99; min_data_in_leaf=527; max_depth=8; lambda_l1=1.32; lambda_l2=4.61; min_gain_to_split=0.3; drop_rate=0.484; skip_drop=0.236 : y = 0.93 : 500.0 secs : infill_ei
#
# Tue Jul 22 13:26:11 2025 AUC 0.930568975513276
#
# [mbo] 81: num_iterations=1963; learning_rate=0.0465; feature_fraction=0.45; bagging_fraction=0.643; num_leaves=25; min_data_in_leaf=518; max_depth=11; lambda_l1=2.97; lambda_l2=1.92; min_gain_to_split=0.251; drop_rate=0.447; skip_drop=0.562 : y = 0.931 : 341.9 secs : infill_ei
#
# Saved the current state after iteration 82 in the file bayesiana.RDATA.
#
# Tue Jul 22 13:35:19 2025 AUC 0.929706275286691
#
# [mbo] 82: num_iterations=2498; learning_rate=0.0344; feature_fraction=0.454; bagging_fraction=0.631; num_leaves=61; min_data_in_leaf=354; max_depth=8; lambda_l1=1.76; lambda_l2=2.97; min_gain_to_split=0.00675; drop_rate=0.315; skip_drop=0.299 : y = 0.93 : 541.2 secs : infill_ei
#
# Tue Jul 22 13:39:23 2025 AUC 0.930906603016351
#
# [mbo] 83: num_iterations=1502; learning_rate=0.0483; feature_fraction=0.459; bagging_fraction=0.608; num_leaves=25; min_data_in_leaf=475; max_depth=10; lambda_l1=3.13; lambda_l2=2.65; min_gain_to_split=0.0243; drop_rate=0.424; skip_drop=0.553 : y = 0.931 : 241.7 secs : infill_ei
#
# Saved the current state after iteration 84 in the file bayesiana.RDATA.
#
# Tue Jul 22 13:43:44 2025 AUC 0.931310627814767
#
# [mbo] 84: num_iterations=1678; learning_rate=0.0275; feature_fraction=0.45; bagging_fraction=0.676; num_leaves=25; min_data_in_leaf=345; max_depth=11; lambda_l1=1.98; lambda_l2=2.3; min_gain_to_split=0.172; drop_rate=0.402; skip_drop=0.56 : y = 0.931 : 254.4 secs : infill_ei
#
# Tue Jul 22 13:50:25 2025 AUC 0.929562169845442
#
# [mbo] 85: num_iterations=1966; learning_rate=0.0479; feature_fraction=0.493; bagging_fraction=0.63; num_leaves=38; min_data_in_leaf=481; max_depth=10; lambda_l1=1.45; lambda_l2=2.27; min_gain_to_split=0.0139; drop_rate=0.447; skip_drop=0.56 : y = 0.93 : 398.8 secs : infill_ei
#
# Saved the current state after iteration 86 in the file bayesiana.RDATA.
#
# Tue Jul 22 13:56:14 2025 AUC 0.93073951342138
#
# [mbo] 86: num_iterations=1784; learning_rate=0.0488; feature_fraction=0.45; bagging_fraction=0.636; num_leaves=26; min_data_in_leaf=548; max_depth=12; lambda_l1=2.09; lambda_l2=3.65; min_gain_to_split=0.116; drop_rate=0.418; skip_drop=0.449 : y = 0.931 : 342.1 secs : infill_ei
#
# Tue Jul 22 13:59:31 2025 AUC 0.930495141731868
#
# [mbo] 87: num_iterations=1144; learning_rate=0.0453; feature_fraction=0.451; bagging_fraction=0.619; num_leaves=25; min_data_in_leaf=415; max_depth=8; lambda_l1=1.4; lambda_l2=2.94; min_gain_to_split=0.209; drop_rate=0.258; skip_drop=0.515 : y = 0.93 : 195.4 secs : infill_ei
#
# Tue Jul 22 14:04:04 2025 AUC 0.930109374123466
#
# [mbo] 88: num_iterations=1615; learning_rate=0.0478; feature_fraction=0.476; bagging_fraction=0.631; num_leaves=25; min_data_in_leaf=632; max_depth=8; lambda_l1=2.67; lambda_l2=3.74; min_gain_to_split=0.207; drop_rate=0.346; skip_drop=0.576 : y = 0.93 : 270.9 secs : infill_ei
#
# Saved the current state after iteration 89 in the file bayesiana.RDATA.
#
# Tue Jul 22 14:07:30 2025 AUC 0.931210263192814
#
# [mbo] 89: num_iterations=1334; learning_rate=0.0264; feature_fraction=0.464; bagging_fraction=0.703; num_leaves=25; min_data_in_leaf=323; max_depth=11; lambda_l1=1.96; lambda_l2=1.23; min_gain_to_split=0.142; drop_rate=0.218; skip_drop=0.577 : y = 0.931 : 199.0 secs : infill_ei
#
# Tue Jul 22 14:14:14 2025 AUC 0.93133857609445
#
# [mbo] 90: num_iterations=2049; learning_rate=0.0495; feature_fraction=0.451; bagging_fraction=0.715; num_leaves=25; min_data_in_leaf=306; max_depth=13; lambda_l1=1.72; lambda_l2=3.01; min_gain_to_split=0.189; drop_rate=0.233; skip_drop=0.463 : y = 0.931 : 402.0 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "num_iterations"    "learning_rate"     "feature_fraction"
#  [4] "bagging_fraction"  "num_leaves"        "min_data_in_leaf"
#  [7] "max_depth"         "lambda_l1"         "lambda_l2"
# [10] "min_gain_to_split" "drop_rate"         "skip_drop"
# [13] "y"                 "dob"               "eol"
# [16] "error.message"     "exec.time"         "ei"
# [19] "error.model"       "train.time"        "prop.type"
# [22] "propose.time"      "se"                "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    num_iterations learning_rate feature_fraction bagging_fraction num_leaves
#             <int>         <num>            <num>            <num>      <int>
# 1:           1886    0.04906325         0.454579        0.6515288         25
#    min_data_in_leaf max_depth lambda_l1 lambda_l2 min_gain_to_split drop_rate
#               <int>     <int>     <num>     <num>             <num>     <num>
# 1:              448         8  2.240967  2.740605        0.05767594 0.4662577
#    skip_drop
#        <num>
# 1: 0.5439883
# [1] 0.9315772

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "dart"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 100887
#
# $max_depth
# [1] 8
#
# $min_gain_to_split
# [1] 0.05767594
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 2.240967
#
# $lambda_l2
# [1] 2.740605
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 0.6515288
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.4662577
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5439883
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1886
#
# $learning_rate
# [1] 0.04906325
#
# $feature_fraction
# [1] 0.454579
#
# $num_leaves
# [1] 25
#
# $min_data_in_leaf
# [1] 448

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Jul 22 14:23:57 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
