# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# Esta Tarea para el Hogar 02 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el viernes 01-agosto

# %% [markdown]
# ##  1. Cazatalentos

# %% [markdown]
# En la Clase 03 nos hemos enfrentado a  "La Maldicion del Ganandor",  elegir el modelo con el mejor puntaje simple no suele ser la mejor estrategia.
# <br> Lea y ejecute el notebook  **src/CazaTalentos/CazaTalentos.ipynb**
# <br> en caso de interesarle, participe del Desafío Ordenamiento  que vence el sábado 02 de agosto a las 19:00

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dm"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dm" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/itba2025-8d0a/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sat Jul 26 14:06:30 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  656930 35.1 1439377    76.9 1431357  76.5
# Vcells 1224847  9.4 8388608    64.0 1924958  14.7

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 4961
PARAM$semilla_primigenia <- 100887

# %%
PARAM$kaggle$competencia <- "data-mining-analista-sr-2025-a"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeNumericParam("learning_rate", lower = 0.0134, upper = 0.0154),
  makeNumericParam("feature_fraction", lower = 0.347, upper = 0.367),
  makeNumericParam("bagging_fraction", lower = 0.8222, upper = 0.8422),
  makeNumericParam("lambda_l2", lower = 0.729, upper = 0.749),
  makeIntegerParam("num_leaves", lower = 27L, upper = 29L),
  makeIntegerParam("min_data_in_leaf", lower = 744L, upper = 748L)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 50 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83368
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Sat Jul 26 14:08:58 2025 AUC 0.931024670439245
#
# Sat Jul 26 14:09:44 2025 AUC 0.930357381269769
#
# Sat Jul 26 14:10:30 2025 AUC 0.931284181519166
#
# Sat Jul 26 14:11:18 2025 AUC 0.93109978446018
#
# Sat Jul 26 14:12:06 2025 AUC 0.929988357439195
#
# Sat Jul 26 14:12:50 2025 AUC 0.93085978302891
#
# Sat Jul 26 14:13:35 2025 AUC 0.931507346277306
#
# Sat Jul 26 14:14:19 2025 AUC 0.931077227466467
#
# Sat Jul 26 14:15:05 2025 AUC 0.930688790541155
#
# Sat Jul 26 14:15:51 2025 AUC 0.930193262907591
#
# Sat Jul 26 14:16:35 2025 AUC 0.931148845152321
#
# Sat Jul 26 14:17:21 2025 AUC 0.930244514598834
#
# Sat Jul 26 14:18:07 2025 AUC 0.930462681239423
#
# Sat Jul 26 14:18:54 2025 AUC 0.930099375105477
#
# Sat Jul 26 14:19:39 2025 AUC 0.930273619531543
#
# Sat Jul 26 14:20:28 2025 AUC 0.930862897465453
#
# Sat Jul 26 14:21:13 2025 AUC 0.931528176906556
#
# Sat Jul 26 14:21:57 2025 AUC 0.930776082805432
#
# Sat Jul 26 14:22:44 2025 AUC 0.930246313310749
#
# Sat Jul 26 14:23:28 2025 AUC 0.931067280432218
#
# Sat Jul 26 14:24:13 2025 AUC 0.930436826305409
#
# Sat Jul 26 14:24:58 2025 AUC 0.930272199042276
#
# Sat Jul 26 14:25:44 2025 AUC 0.930219158224796
#
# Sat Jul 26 14:26:28 2025 AUC 0.930602068932171
#
# [mbo] 0: learning_rate=0.0147; feature_fraction=0.359; bagging_fraction=0.834; lambda_l2=0.734; num_leaves=27; min_data_in_leaf=745 : y = 0.931 : 46.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0143; feature_fraction=0.361; bagging_fraction=0.84; lambda_l2=0.737; num_leaves=29; min_data_in_leaf=746 : y = 0.93 : 46.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.014; feature_fraction=0.36; bagging_fraction=0.831; lambda_l2=0.729; num_leaves=28; min_data_in_leaf=744 : y = 0.931 : 46.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0136; feature_fraction=0.351; bagging_fraction=0.83; lambda_l2=0.745; num_leaves=29; min_data_in_leaf=747 : y = 0.931 : 47.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.015; feature_fraction=0.358; bagging_fraction=0.827; lambda_l2=0.74; num_leaves=28; min_data_in_leaf=748 : y = 0.93 : 47.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0148; feature_fraction=0.353; bagging_fraction=0.836; lambda_l2=0.746; num_leaves=28; min_data_in_leaf=746 : y = 0.931 : 44.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0143; feature_fraction=0.349; bagging_fraction=0.832; lambda_l2=0.748; num_leaves=28; min_data_in_leaf=744 : y = 0.932 : 44.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0146; feature_fraction=0.365; bagging_fraction=0.828; lambda_l2=0.733; num_leaves=28; min_data_in_leaf=747 : y = 0.931 : 44.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0151; feature_fraction=0.353; bagging_fraction=0.826; lambda_l2=0.736; num_leaves=27; min_data_in_leaf=744 : y = 0.931 : 45.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0147; feature_fraction=0.35; bagging_fraction=0.831; lambda_l2=0.742; num_leaves=29; min_data_in_leaf=747 : y = 0.93 : 46.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0134; feature_fraction=0.354; bagging_fraction=0.835; lambda_l2=0.735; num_leaves=27; min_data_in_leaf=745 : y = 0.931 : 44.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0137; feature_fraction=0.363; bagging_fraction=0.822; lambda_l2=0.746; num_leaves=28; min_data_in_leaf=747 : y = 0.93 : 45.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0141; feature_fraction=0.367; bagging_fraction=0.837; lambda_l2=0.73; num_leaves=27; min_data_in_leaf=747 : y = 0.93 : 45.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0144; feature_fraction=0.366; bagging_fraction=0.833; lambda_l2=0.739; num_leaves=29; min_data_in_leaf=746 : y = 0.93 : 46.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0139; feature_fraction=0.347; bagging_fraction=0.823; lambda_l2=0.733; num_leaves=27; min_data_in_leaf=748 : y = 0.93 : 45.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0138; feature_fraction=0.355; bagging_fraction=0.839; lambda_l2=0.738; num_leaves=29; min_data_in_leaf=744 : y = 0.931 : 48.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0153; feature_fraction=0.364; bagging_fraction=0.825; lambda_l2=0.749; num_leaves=28; min_data_in_leaf=745 : y = 0.932 : 44.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0146; feature_fraction=0.348; bagging_fraction=0.833; lambda_l2=0.742; num_leaves=27; min_data_in_leaf=745 : y = 0.931 : 44.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0152; feature_fraction=0.363; bagging_fraction=0.841; lambda_l2=0.744; num_leaves=29; min_data_in_leaf=748 : y = 0.93 : 46.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.015; feature_fraction=0.362; bagging_fraction=0.842; lambda_l2=0.741; num_leaves=27; min_data_in_leaf=746 : y = 0.931 : 44.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0153; feature_fraction=0.355; bagging_fraction=0.828; lambda_l2=0.731; num_leaves=29; min_data_in_leaf=746 : y = 0.93 : 45.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0135; feature_fraction=0.352; bagging_fraction=0.838; lambda_l2=0.747; num_leaves=28; min_data_in_leaf=748 : y = 0.93 : 45.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0142; feature_fraction=0.357; bagging_fraction=0.838; lambda_l2=0.732; num_leaves=29; min_data_in_leaf=748 : y = 0.93 : 45.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.014; feature_fraction=0.358; bagging_fraction=0.825; lambda_l2=0.74; num_leaves=27; min_data_in_leaf=744 : y = 0.931 : 44.1 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Sat Jul 26 14:27:16 2025 AUC 0.931236530972233
#
# [mbo] 1: learning_rate=0.0144; feature_fraction=0.359; bagging_fraction=0.836; lambda_l2=0.733; num_leaves=28; min_data_in_leaf=744 : y = 0.931 : 43.9 secs : infill_ei
#
# Sat Jul 26 14:28:02 2025 AUC 0.930556476255195
#
# [mbo] 2: learning_rate=0.0153; feature_fraction=0.361; bagging_fraction=0.828; lambda_l2=0.749; num_leaves=28; min_data_in_leaf=744 : y = 0.931 : 44.9 secs : infill_ei
#
# Sat Jul 26 14:28:47 2025 AUC 0.931106449936821
#
# [mbo] 3: learning_rate=0.0152; feature_fraction=0.365; bagging_fraction=0.826; lambda_l2=0.743; num_leaves=28; min_data_in_leaf=745 : y = 0.931 : 44.7 secs : infill_ei
#
# Sat Jul 26 14:29:30 2025 AUC 0.93081728681611
#
# [mbo] 4: learning_rate=0.0142; feature_fraction=0.354; bagging_fraction=0.832; lambda_l2=0.739; num_leaves=28; min_data_in_leaf=744 : y = 0.931 : 43.0 secs : infill_ei
#
# Sat Jul 26 14:30:16 2025 AUC 0.930974692340289
#
# [mbo] 5: learning_rate=0.0154; feature_fraction=0.352; bagging_fraction=0.825; lambda_l2=0.747; num_leaves=28; min_data_in_leaf=745 : y = 0.931 : 45.1 secs : infill_ei
#
# Sat Jul 26 14:30:59 2025 AUC 0.929781857878786
#
# [mbo] 6: learning_rate=0.0147; feature_fraction=0.349; bagging_fraction=0.833; lambda_l2=0.745; num_leaves=28; min_data_in_leaf=744 : y = 0.93 : 42.6 secs : infill_ei
#
# Sat Jul 26 14:31:44 2025 AUC 0.930343784385353
#
# [mbo] 7: learning_rate=0.0136; feature_fraction=0.348; bagging_fraction=0.834; lambda_l2=0.732; num_leaves=28; min_data_in_leaf=745 : y = 0.93 : 44.5 secs : infill_ei
#
# Sat Jul 26 14:32:29 2025 AUC 0.931149464890325
#
# [mbo] 8: learning_rate=0.0146; feature_fraction=0.359; bagging_fraction=0.834; lambda_l2=0.739; num_leaves=28; min_data_in_leaf=748 : y = 0.931 : 44.7 secs : infill_ei
#
# Sat Jul 26 14:33:13 2025 AUC 0.930992308579425
#
# [mbo] 9: learning_rate=0.0141; feature_fraction=0.348; bagging_fraction=0.827; lambda_l2=0.732; num_leaves=28; min_data_in_leaf=745 : y = 0.931 : 43.7 secs : infill_ei
#
# Sat Jul 26 14:33:57 2025 AUC 0.931010132776211
#
# [mbo] 10: learning_rate=0.0143; feature_fraction=0.352; bagging_fraction=0.831; lambda_l2=0.74; num_leaves=28; min_data_in_leaf=744 : y = 0.931 : 43.5 secs : infill_ei
#
# Sat Jul 26 14:34:42 2025 AUC 0.930633758844206
#
# [mbo] 11: learning_rate=0.0148; feature_fraction=0.365; bagging_fraction=0.823; lambda_l2=0.736; num_leaves=29; min_data_in_leaf=745 : y = 0.931 : 45.1 secs : infill_ei
#
# Sat Jul 26 14:35:27 2025 AUC 0.93029493854118
#
# [mbo] 12: learning_rate=0.0144; feature_fraction=0.36; bagging_fraction=0.827; lambda_l2=0.738; num_leaves=29; min_data_in_leaf=747 : y = 0.93 : 44.5 secs : infill_ei
#
# Sat Jul 26 14:36:14 2025 AUC 0.931110307273604
#
# [mbo] 13: learning_rate=0.015; feature_fraction=0.355; bagging_fraction=0.826; lambda_l2=0.748; num_leaves=29; min_data_in_leaf=747 : y = 0.931 : 45.8 secs : infill_ei
#
# Sat Jul 26 14:36:57 2025 AUC 0.930284391020287
#
# [mbo] 14: learning_rate=0.0144; feature_fraction=0.351; bagging_fraction=0.832; lambda_l2=0.742; num_leaves=28; min_data_in_leaf=744 : y = 0.93 : 43.3 secs : infill_ei
#
# Saved the current state after iteration 15 in the file bayesiana.RDATA.
#
# Sat Jul 26 14:37:47 2025 AUC 0.930846482718287
#
# [mbo] 15: learning_rate=0.0135; feature_fraction=0.365; bagging_fraction=0.824; lambda_l2=0.731; num_leaves=28; min_data_in_leaf=744 : y = 0.931 : 44.0 secs : infill_ei
#
# Sat Jul 26 14:38:32 2025 AUC 0.930326914787477
#
# [mbo] 16: learning_rate=0.0138; feature_fraction=0.356; bagging_fraction=0.827; lambda_l2=0.729; num_leaves=28; min_data_in_leaf=746 : y = 0.93 : 44.8 secs : infill_ei
#
# Sat Jul 26 14:39:17 2025 AUC 0.930893497292826
#
# [mbo] 17: learning_rate=0.0143; feature_fraction=0.352; bagging_fraction=0.831; lambda_l2=0.737; num_leaves=28; min_data_in_leaf=744 : y = 0.931 : 43.6 secs : infill_ei
#
# Sat Jul 26 14:40:00 2025 AUC 0.930523540179918
#
# [mbo] 18: learning_rate=0.0151; feature_fraction=0.353; bagging_fraction=0.832; lambda_l2=0.734; num_leaves=28; min_data_in_leaf=744 : y = 0.931 : 43.4 secs : infill_ei
#
# Sat Jul 26 14:40:43 2025 AUC 0.931293854789662
#
# [mbo] 19: learning_rate=0.0149; feature_fraction=0.349; bagging_fraction=0.831; lambda_l2=0.744; num_leaves=27; min_data_in_leaf=746 : y = 0.931 : 42.5 secs : infill_ei
#
# Sat Jul 26 14:41:27 2025 AUC 0.931113949717893
#
# [mbo] 20: learning_rate=0.0138; feature_fraction=0.356; bagging_fraction=0.827; lambda_l2=0.747; num_leaves=27; min_data_in_leaf=745 : y = 0.931 : 43.5 secs : infill_ei
#
# Sat Jul 26 14:42:12 2025 AUC 0.930667762604804
#
# [mbo] 21: learning_rate=0.0151; feature_fraction=0.354; bagging_fraction=0.835; lambda_l2=0.74; num_leaves=27; min_data_in_leaf=745 : y = 0.931 : 43.7 secs : infill_ei
#
# Sat Jul 26 14:42:57 2025 AUC 0.931042683396631
#
# [mbo] 22: learning_rate=0.0135; feature_fraction=0.366; bagging_fraction=0.84; lambda_l2=0.742; num_leaves=29; min_data_in_leaf=746 : y = 0.931 : 45.2 secs : infill_ei
#
# Sat Jul 26 14:43:42 2025 AUC 0.931538562265288
#
# [mbo] 23: learning_rate=0.0141; feature_fraction=0.359; bagging_fraction=0.829; lambda_l2=0.735; num_leaves=28; min_data_in_leaf=744 : y = 0.932 : 44.0 secs : infill_ei
#
# Sat Jul 26 14:44:26 2025 AUC 0.931409629761073
#
# [mbo] 24: learning_rate=0.0141; feature_fraction=0.355; bagging_fraction=0.832; lambda_l2=0.733; num_leaves=28; min_data_in_leaf=744 : y = 0.931 : 43.8 secs : infill_ei
#
# Sat Jul 26 14:45:12 2025 AUC 0.930694627295633
#
# [mbo] 25: learning_rate=0.0149; feature_fraction=0.353; bagging_fraction=0.824; lambda_l2=0.73; num_leaves=28; min_data_in_leaf=745 : y = 0.931 : 45.2 secs : infill_ei
#
# Sat Jul 26 14:45:56 2025 AUC 0.930831482504433
#
# [mbo] 26: learning_rate=0.0152; feature_fraction=0.351; bagging_fraction=0.837; lambda_l2=0.745; num_leaves=27; min_data_in_leaf=745 : y = 0.931 : 43.3 secs : infill_ei
#
# Sat Jul 26 14:46:41 2025 AUC 0.931041356687104
#
# [mbo] 27: learning_rate=0.014; feature_fraction=0.352; bagging_fraction=0.835; lambda_l2=0.743; num_leaves=29; min_data_in_leaf=746 : y = 0.931 : 44.9 secs : infill_ei
#
# Sat Jul 26 14:47:25 2025 AUC 0.930710966544981
#
# [mbo] 28: learning_rate=0.0143; feature_fraction=0.348; bagging_fraction=0.829; lambda_l2=0.748; num_leaves=28; min_data_in_leaf=744 : y = 0.931 : 43.9 secs : infill_ei
#
# Saved the current state after iteration 29 in the file bayesiana.RDATA.
#
# Sat Jul 26 14:48:15 2025 AUC 0.931077295673023
#
# [mbo] 29: learning_rate=0.0152; feature_fraction=0.365; bagging_fraction=0.842; lambda_l2=0.749; num_leaves=29; min_data_in_leaf=745 : y = 0.931 : 45.3 secs : infill_ei
#
# Sat Jul 26 14:49:00 2025 AUC 0.930165710439553
#
# [mbo] 30: learning_rate=0.0144; feature_fraction=0.354; bagging_fraction=0.824; lambda_l2=0.738; num_leaves=29; min_data_in_leaf=748 : y = 0.93 : 45.1 secs : infill_ei
#
# Sat Jul 26 14:49:46 2025 AUC 0.931808288727286
#
# [mbo] 31: learning_rate=0.0151; feature_fraction=0.351; bagging_fraction=0.829; lambda_l2=0.74; num_leaves=29; min_data_in_leaf=748 : y = 0.932 : 45.4 secs : infill_ei
#
# Sat Jul 26 14:50:33 2025 AUC 0.931391031082583
#
# [mbo] 32: learning_rate=0.0148; feature_fraction=0.357; bagging_fraction=0.837; lambda_l2=0.746; num_leaves=27; min_data_in_leaf=744 : y = 0.931 : 46.1 secs : infill_ei
#
# Sat Jul 26 14:51:17 2025 AUC 0.930919810087216
#
# [mbo] 33: learning_rate=0.0147; feature_fraction=0.355; bagging_fraction=0.823; lambda_l2=0.729; num_leaves=27; min_data_in_leaf=746 : y = 0.931 : 43.6 secs : infill_ei
#
# Sat Jul 26 14:52:02 2025 AUC 0.931098025927526
#
# [mbo] 34: learning_rate=0.0135; feature_fraction=0.356; bagging_fraction=0.831; lambda_l2=0.734; num_leaves=27; min_data_in_leaf=745 : y = 0.931 : 44.4 secs : infill_ei
#
# Sat Jul 26 14:52:47 2025 AUC 0.931425944650417
#
# [mbo] 35: learning_rate=0.0136; feature_fraction=0.365; bagging_fraction=0.831; lambda_l2=0.733; num_leaves=28; min_data_in_leaf=747 : y = 0.931 : 44.4 secs : infill_ei
#
# Sat Jul 26 14:53:32 2025 AUC 0.929984142755221
#
# [mbo] 36: learning_rate=0.0151; feature_fraction=0.349; bagging_fraction=0.824; lambda_l2=0.741; num_leaves=29; min_data_in_leaf=748 : y = 0.93 : 44.7 secs : infill_ei
#
# Sat Jul 26 14:54:18 2025 AUC 0.930990961599186
#
# [mbo] 37: learning_rate=0.0138; feature_fraction=0.348; bagging_fraction=0.832; lambda_l2=0.749; num_leaves=29; min_data_in_leaf=748 : y = 0.931 : 45.2 secs : infill_ei
#
# Sat Jul 26 14:55:03 2025 AUC 0.930595144588408
#
# [mbo] 38: learning_rate=0.0154; feature_fraction=0.358; bagging_fraction=0.829; lambda_l2=0.745; num_leaves=29; min_data_in_leaf=745 : y = 0.931 : 44.8 secs : infill_ei
#
# Sat Jul 26 14:55:48 2025 AUC 0.930625251928201
#
# [mbo] 39: learning_rate=0.0143; feature_fraction=0.362; bagging_fraction=0.822; lambda_l2=0.745; num_leaves=29; min_data_in_leaf=745 : y = 0.931 : 44.2 secs : infill_ei
#
# Sat Jul 26 14:56:34 2025 AUC 0.930200889371733
#
# [mbo] 40: learning_rate=0.0149; feature_fraction=0.359; bagging_fraction=0.84; lambda_l2=0.737; num_leaves=29; min_data_in_leaf=746 : y = 0.93 : 45.5 secs : infill_ei
#
# Sat Jul 26 14:57:20 2025 AUC 0.929117110216995
#
# [mbo] 41: learning_rate=0.0145; feature_fraction=0.348; bagging_fraction=0.842; lambda_l2=0.742; num_leaves=28; min_data_in_leaf=747 : y = 0.929 : 45.2 secs : infill_ei
#
# Sat Jul 26 14:58:05 2025 AUC 0.930621697389565
#
# [mbo] 42: learning_rate=0.014; feature_fraction=0.365; bagging_fraction=0.83; lambda_l2=0.742; num_leaves=29; min_data_in_leaf=747 : y = 0.931 : 45.0 secs : infill_ei
#
# Saved the current state after iteration 43 in the file bayesiana.RDATA.
#
# Sat Jul 26 14:58:54 2025 AUC 0.930810871171746
#
# [mbo] 43: learning_rate=0.0142; feature_fraction=0.364; bagging_fraction=0.827; lambda_l2=0.746; num_leaves=27; min_data_in_leaf=747 : y = 0.931 : 44.4 secs : infill_ei
#
# Sat Jul 26 14:59:38 2025 AUC 0.931413438917456
#
# [mbo] 44: learning_rate=0.0147; feature_fraction=0.36; bagging_fraction=0.833; lambda_l2=0.743; num_leaves=27; min_data_in_leaf=745 : y = 0.931 : 43.7 secs : infill_ei
#
# Sat Jul 26 15:00:25 2025 AUC 0.931470933261402
#
# [mbo] 45: learning_rate=0.015; feature_fraction=0.358; bagging_fraction=0.831; lambda_l2=0.738; num_leaves=29; min_data_in_leaf=746 : y = 0.931 : 47.0 secs : infill_ei
#
# Sat Jul 26 15:01:10 2025 AUC 0.930874256988624
#
# [mbo] 46: learning_rate=0.0147; feature_fraction=0.347; bagging_fraction=0.836; lambda_l2=0.733; num_leaves=29; min_data_in_leaf=747 : y = 0.931 : 44.4 secs : infill_ei
#
# Sat Jul 26 15:01:55 2025 AUC 0.930587238095585
#
# [mbo] 47: learning_rate=0.0135; feature_fraction=0.348; bagging_fraction=0.824; lambda_l2=0.746; num_leaves=28; min_data_in_leaf=747 : y = 0.931 : 44.3 secs : infill_ei
#
# Sat Jul 26 15:02:40 2025 AUC 0.93073797239911
#
# [mbo] 48: learning_rate=0.0152; feature_fraction=0.348; bagging_fraction=0.825; lambda_l2=0.736; num_leaves=27; min_data_in_leaf=748 : y = 0.931 : 43.8 secs : infill_ei
#
# Sat Jul 26 15:03:25 2025 AUC 0.930381037184051
#
# [mbo] 49: learning_rate=0.0139; feature_fraction=0.355; bagging_fraction=0.837; lambda_l2=0.742; num_leaves=28; min_data_in_leaf=744 : y = 0.93 : 45.0 secs : infill_ei
#
# Sat Jul 26 15:04:10 2025 AUC 0.931180646380587
#
# [mbo] 50: learning_rate=0.0153; feature_fraction=0.36; bagging_fraction=0.835; lambda_l2=0.736; num_leaves=27; min_data_in_leaf=747 : y = 0.931 : 44.2 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "learning_rate"    "feature_fraction" "bagging_fraction" "lambda_l2"
#  [5] "num_leaves"       "min_data_in_leaf" "y"                "dob"
#  [9] "eol"              "error.message"    "exec.time"        "ei"
# [13] "error.model"      "train.time"       "prop.type"        "propose.time"
# [17] "se"               "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    learning_rate feature_fraction bagging_fraction lambda_l2 num_leaves
#            <num>            <num>            <num>     <num>      <int>
# 1:    0.01508273        0.3506115        0.8293256 0.7396931         29
#    min_data_in_leaf
#               <int>
# 1:              748
# [1] 0.9318083

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 100887
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 0.7396931
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 0.8293256
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1200
#
# $learning_rate
# [1] 0.01508273
#
# $feature_fraction
# [1] 0.3506115
#
# $num_leaves
# [1] 29
#
# $min_data_in_leaf
# [1] 748

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sat Jul 26 15:05:10 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
