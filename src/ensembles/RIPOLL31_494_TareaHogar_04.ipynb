# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# Esta Tarea para el Hogar 02 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el viernes 01-agosto

# %% [markdown]
# ##  1. Cazatalentos

# %% [markdown]
# En la Clase 03 nos hemos enfrentado a  "La Maldicion del Ganandor",  elegir el modelo con el mejor puntaje simple no suele ser la mejor estrategia.
# <br> Lea y ejecute el notebook  **src/CazaTalentos/CazaTalentos.ipynb**
# <br> en caso de interesarle, participe del Desafío Ordenamiento  que vence el sábado 02 de agosto a las 19:00

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dm"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dm" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/itba2025-8d0a/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Jul 31 23:16:59 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  656930 35.1 1439368    76.9 1431360  76.5
# Vcells 1224847  9.4 8388608    64.0 1924958  14.7

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 4970
PARAM$semilla_primigenia <- 333757

# %%
PARAM$kaggle$competencia <- "data-mining-analista-sr-2025-a"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 2000,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeNumericParam("learning_rate",       lower = 0.005,  upper = 0.025),
  makeIntegerParam("num_leaves",          lower = 30L,    upper = 300L),
  makeIntegerParam("min_data_in_leaf",    lower = 10L,    upper = 200L),
  makeNumericParam("feature_fraction",    lower = 0.3,    upper = 0.7),
  makeNumericParam("lambda_l2",           lower = 5.0,    upper = 15.0)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 150 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83552
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Thu Jul 31 23:21:08 2025 AUC 0.928507209984633
#
# Thu Jul 31 23:24:25 2025 AUC 0.929918742470263
#
# Thu Jul 31 23:26:55 2025 AUC 0.930519382220144
#
# Thu Jul 31 23:30:07 2025 AUC 0.929483696595285
#
# Thu Jul 31 23:33:17 2025 AUC 0.930033437113613
#
# Thu Jul 31 23:36:23 2025 AUC 0.930284684079667
#
# Thu Jul 31 23:38:56 2025 AUC 0.928954605903625
#
# Thu Jul 31 23:41:59 2025 AUC 0.930064968825782
#
# Thu Jul 31 23:45:02 2025 AUC 0.930788669934252
#
# Thu Jul 31 23:49:00 2025 AUC 0.92835875675978
#
# Thu Jul 31 23:50:50 2025 AUC 0.93136702947409
#
# Thu Jul 31 23:54:16 2025 AUC 0.929098833407094
#
# Thu Jul 31 23:57:07 2025 AUC 0.931083603104467
#
# Thu Jul 31 23:58:56 2025 AUC 0.930089078548736
#
# Fri Aug 01 00:01:14 2025 AUC 0.930627809787446
#
# Fri Aug 01 00:04:07 2025 AUC 0.930554928177113
#
# Fri Aug 01 00:05:41 2025 AUC 0.931381417014908
#
# Fri Aug 01 00:08:28 2025 AUC 0.929904690997789
#
# Fri Aug 01 00:10:23 2025 AUC 0.930225482820451
#
# Fri Aug 01 00:14:17 2025 AUC 0.929272590294651
#
# [mbo] 0: learning_rate=0.00921; num_leaves=233; min_data_in_leaf=69; feature_fraction=0.361; lambda_l2=11.7 : y = 0.929 : 203.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0125; num_leaves=203; min_data_in_leaf=155; feature_fraction=0.516; lambda_l2=9.63 : y = 0.93 : 197.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0162; num_leaves=119; min_data_in_leaf=87; feature_fraction=0.625; lambda_l2=11 : y = 0.931 : 150.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0153; num_leaves=161; min_data_in_leaf=81; feature_fraction=0.493; lambda_l2=13.8 : y = 0.929 : 192.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0104; num_leaves=220; min_data_in_leaf=110; feature_fraction=0.341; lambda_l2=8.89 : y = 0.93 : 189.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0183; num_leaves=208; min_data_in_leaf=191; feature_fraction=0.468; lambda_l2=7.9 : y = 0.93 : 186.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0243; num_leaves=93; min_data_in_leaf=171; feature_fraction=0.559; lambda_l2=7.16 : y = 0.929 : 152.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.014; num_leaves=132; min_data_in_leaf=23; feature_fraction=0.533; lambda_l2=10.4 : y = 0.93 : 183.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0208; num_leaves=179; min_data_in_leaf=121; feature_fraction=0.388; lambda_l2=13 : y = 0.931 : 183.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0199; num_leaves=279; min_data_in_leaf=62; feature_fraction=0.425; lambda_l2=6.84 : y = 0.928 : 238.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.00678; num_leaves=36; min_data_in_leaf=11; feature_fraction=0.564; lambda_l2=5.5 : y = 0.931 : 109.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0176; num_leaves=247; min_data_in_leaf=103; feature_fraction=0.694; lambda_l2=10.5 : y = 0.929 : 206.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.00823; num_leaves=141; min_data_in_leaf=132; feature_fraction=0.45; lambda_l2=14.5 : y = 0.931 : 171.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.00517; num_leaves=68; min_data_in_leaf=44; feature_fraction=0.655; lambda_l2=12.7 : y = 0.93 : 108.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0143; num_leaves=99; min_data_in_leaf=148; feature_fraction=0.301; lambda_l2=8.31 : y = 0.931 : 138.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0239; num_leaves=296; min_data_in_leaf=178; feature_fraction=0.335; lambda_l2=6.39 : y = 0.931 : 173.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0213; num_leaves=51; min_data_in_leaf=137; feature_fraction=0.664; lambda_l2=14.4 : y = 0.931 : 94.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.00785; num_leaves=174; min_data_in_leaf=199; feature_fraction=0.595; lambda_l2=9.36 : y = 0.93 : 166.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0223; num_leaves=71; min_data_in_leaf=51; feature_fraction=0.614; lambda_l2=5.03 : y = 0.93 : 114.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0119; num_leaves=271; min_data_in_leaf=32; feature_fraction=0.405; lambda_l2=12.3 : y = 0.929 : 234.6 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Fri Aug 01 00:16:25 2025 AUC 0.93117649906919
#
# [mbo] 1: learning_rate=0.0161; num_leaves=51; min_data_in_leaf=122; feature_fraction=0.443; lambda_l2=12.9 : y = 0.931 : 124.4 secs : infill_ei
#
# Fri Aug 01 00:18:25 2025 AUC 0.93039726148868
#
# [mbo] 2: learning_rate=0.0201; num_leaves=85; min_data_in_leaf=128; feature_fraction=0.688; lambda_l2=14.1 : y = 0.93 : 119.6 secs : infill_ei
#
# Fri Aug 01 00:20:17 2025 AUC 0.931616410441396
#
# [mbo] 3: learning_rate=0.0138; num_leaves=37; min_data_in_leaf=138; feature_fraction=0.402; lambda_l2=14.5 : y = 0.932 : 111.4 secs : infill_ei
#
# Fri Aug 01 00:22:08 2025 AUC 0.929941044484084
#
# [mbo] 4: learning_rate=0.0234; num_leaves=30; min_data_in_leaf=137; feature_fraction=0.482; lambda_l2=14.4 : y = 0.93 : 110.3 secs : infill_ei
#
# Fri Aug 01 00:23:52 2025 AUC 0.930667805579933
#
# [mbo] 5: learning_rate=0.0214; num_leaves=36; min_data_in_leaf=144; feature_fraction=0.576; lambda_l2=14.5 : y = 0.931 : 103.3 secs : infill_ei
#
# Fri Aug 01 00:25:56 2025 AUC 0.930395928112495
#
# [mbo] 6: learning_rate=0.00786; num_leaves=53; min_data_in_leaf=134; feature_fraction=0.411; lambda_l2=9.29 : y = 0.93 : 123.4 secs : infill_ei
#
# Saved the current state after iteration 7 in the file bayesiana.RDATA.
#
# Fri Aug 01 00:27:32 2025 AUC 0.930242018712722
#
# [mbo] 7: learning_rate=0.015; num_leaves=47; min_data_in_leaf=141; feature_fraction=0.642; lambda_l2=13.9 : y = 0.93 : 92.5 secs : infill_ei
#
# Fri Aug 01 00:29:41 2025 AUC 0.930590062502058
#
# [mbo] 8: learning_rate=0.0158; num_leaves=58; min_data_in_leaf=143; feature_fraction=0.418; lambda_l2=14.8 : y = 0.931 : 127.4 secs : infill_ei
#
# Fri Aug 01 00:31:33 2025 AUC 0.930693719151606
#
# [mbo] 9: learning_rate=0.0138; num_leaves=36; min_data_in_leaf=125; feature_fraction=0.397; lambda_l2=13.1 : y = 0.931 : 111.3 secs : infill_ei
#
# Fri Aug 01 00:35:00 2025 AUC 0.928906166544536
#
# [mbo] 10: learning_rate=0.00574; num_leaves=224; min_data_in_leaf=51; feature_fraction=0.625; lambda_l2=12.3 : y = 0.929 : 206.4 secs : infill_ei
#
# Fri Aug 01 00:37:38 2025 AUC 0.930747075774219
#
# [mbo] 11: learning_rate=0.0128; num_leaves=127; min_data_in_leaf=136; feature_fraction=0.403; lambda_l2=14.9 : y = 0.931 : 157.4 secs : infill_ei
#
# Saved the current state after iteration 12 in the file bayesiana.RDATA.
#
# Fri Aug 01 00:40:25 2025 AUC 0.929914310242557
#
# [mbo] 12: learning_rate=0.0102; num_leaves=158; min_data_in_leaf=172; feature_fraction=0.374; lambda_l2=11.1 : y = 0.93 : 164.0 secs : infill_ei
#
# Fri Aug 01 00:42:19 2025 AUC 0.931326526121519
#
# [mbo] 13: learning_rate=0.00922; num_leaves=37; min_data_in_leaf=46; feature_fraction=0.55; lambda_l2=8.4 : y = 0.931 : 112.5 secs : infill_ei
#
# Fri Aug 01 00:44:33 2025 AUC 0.930038964331139
#
# [mbo] 14: learning_rate=0.0189; num_leaves=85; min_data_in_leaf=150; feature_fraction=0.345; lambda_l2=11.9 : y = 0.93 : 133.5 secs : infill_ei
#
# Fri Aug 01 00:46:37 2025 AUC 0.930709481591807
#
# [mbo] 15: learning_rate=0.00753; num_leaves=61; min_data_in_leaf=124; feature_fraction=0.362; lambda_l2=14.5 : y = 0.931 : 123.4 secs : infill_ei
#
# Fri Aug 01 00:49:10 2025 AUC 0.931010439098943
#
# [mbo] 16: learning_rate=0.0123; num_leaves=117; min_data_in_leaf=159; feature_fraction=0.395; lambda_l2=11.8 : y = 0.931 : 152.7 secs : infill_ei
#
# Saved the current state after iteration 17 in the file bayesiana.RDATA.
#
# Fri Aug 01 00:51:20 2025 AUC 0.930828982165999
#
# [mbo] 17: learning_rate=0.0173; num_leaves=62; min_data_in_leaf=139; feature_fraction=0.385; lambda_l2=13.9 : y = 0.931 : 126.2 secs : infill_ei
#
# Fri Aug 01 00:54:18 2025 AUC 0.92975132234244
#
# [mbo] 18: learning_rate=0.0172; num_leaves=171; min_data_in_leaf=149; feature_fraction=0.413; lambda_l2=14.8 : y = 0.93 : 176.8 secs : infill_ei
#
# Fri Aug 01 00:56:10 2025 AUC 0.931677629383673
#
# [mbo] 19: learning_rate=0.0123; num_leaves=33; min_data_in_leaf=143; feature_fraction=0.446; lambda_l2=14.5 : y = 0.932 : 111.5 secs : infill_ei
#
# Fri Aug 01 00:57:56 2025 AUC 0.931826413536286
#
# [mbo] 20: learning_rate=0.0124; num_leaves=35; min_data_in_leaf=148; feature_fraction=0.347; lambda_l2=15 : y = 0.932 : 105.3 secs : infill_ei
#
# Fri Aug 01 01:00:07 2025 AUC 0.93163520796854
#
# [mbo] 21: learning_rate=0.0205; num_leaves=54; min_data_in_leaf=117; feature_fraction=0.519; lambda_l2=14.3 : y = 0.932 : 130.7 secs : infill_ei
#
# Saved the current state after iteration 22 in the file bayesiana.RDATA.
#
# Fri Aug 01 01:01:58 2025 AUC 0.931256364160206
#
# [mbo] 22: learning_rate=0.00947; num_leaves=33; min_data_in_leaf=26; feature_fraction=0.556; lambda_l2=6.55 : y = 0.931 : 106.7 secs : infill_ei
#
# Fri Aug 01 01:03:44 2025 AUC 0.931674367943451
#
# [mbo] 23: learning_rate=0.00959; num_leaves=36; min_data_in_leaf=140; feature_fraction=0.334; lambda_l2=14.9 : y = 0.932 : 105.7 secs : infill_ei
#
# Fri Aug 01 01:05:31 2025 AUC 0.930605119035381
#
# [mbo] 24: learning_rate=0.0116; num_leaves=30; min_data_in_leaf=143; feature_fraction=0.375; lambda_l2=14.2 : y = 0.931 : 106.0 secs : infill_ei
#
# Fri Aug 01 01:08:24 2025 AUC 0.930039860760011
#
# [mbo] 25: learning_rate=0.0114; num_leaves=145; min_data_in_leaf=134; feature_fraction=0.453; lambda_l2=14.6 : y = 0.93 : 172.4 secs : infill_ei
#
# Fri Aug 01 01:10:18 2025 AUC 0.93159624380165
#
# [mbo] 26: learning_rate=0.011; num_leaves=35; min_data_in_leaf=29; feature_fraction=0.439; lambda_l2=15 : y = 0.932 : 112.7 secs : infill_ei
#
# Saved the current state after iteration 27 in the file bayesiana.RDATA.
#
# Fri Aug 01 01:12:11 2025 AUC 0.931020303760381
#
# [mbo] 27: learning_rate=0.0132; num_leaves=34; min_data_in_leaf=167; feature_fraction=0.404; lambda_l2=14.6 : y = 0.931 : 108.2 secs : infill_ei
#
# Fri Aug 01 01:14:00 2025 AUC 0.929986858219463
#
# [mbo] 28: learning_rate=0.0209; num_leaves=70; min_data_in_leaf=47; feature_fraction=0.667; lambda_l2=14.4 : y = 0.93 : 108.2 secs : infill_ei
#
# Fri Aug 01 01:15:50 2025 AUC 0.930951669697024
#
# [mbo] 29: learning_rate=0.0123; num_leaves=35; min_data_in_leaf=115; feature_fraction=0.408; lambda_l2=15 : y = 0.931 : 109.6 secs : infill_ei
#
# Fri Aug 01 01:17:51 2025 AUC 0.930836057335243
#
# [mbo] 30: learning_rate=0.013; num_leaves=39; min_data_in_leaf=146; feature_fraction=0.511; lambda_l2=14.8 : y = 0.931 : 120.3 secs : infill_ei
#
# Fri Aug 01 01:19:50 2025 AUC 0.931857708414675
#
# [mbo] 31: learning_rate=0.00847; num_leaves=36; min_data_in_leaf=22; feature_fraction=0.509; lambda_l2=11.1 : y = 0.932 : 117.3 secs : infill_ei
#
# Fri Aug 01 01:22:42 2025 AUC 0.92955492126893
#
# [mbo] 32: learning_rate=0.00657; num_leaves=145; min_data_in_leaf=168; feature_fraction=0.48; lambda_l2=5.8 : y = 0.93 : 172.2 secs : infill_ei
#
# Saved the current state after iteration 33 in the file bayesiana.RDATA.
#
# Fri Aug 01 01:24:29 2025 AUC 0.930115532455991
#
# [mbo] 33: learning_rate=0.00526; num_leaves=36; min_data_in_leaf=27; feature_fraction=0.584; lambda_l2=12.7 : y = 0.93 : 101.8 secs : infill_ei
#
# Fri Aug 01 01:26:57 2025 AUC 0.931340191935666
#
# [mbo] 34: learning_rate=0.0209; num_leaves=93; min_data_in_leaf=184; feature_fraction=0.571; lambda_l2=5.58 : y = 0.931 : 147.7 secs : infill_ei
#
# Fri Aug 01 01:28:53 2025 AUC 0.931576044436177
#
# [mbo] 35: learning_rate=0.0139; num_leaves=38; min_data_in_leaf=65; feature_fraction=0.446; lambda_l2=14.6 : y = 0.932 : 115.4 secs : infill_ei
#
# Fri Aug 01 01:30:51 2025 AUC 0.931472364728514
#
# [mbo] 36: learning_rate=0.00941; num_leaves=36; min_data_in_leaf=55; feature_fraction=0.498; lambda_l2=11.7 : y = 0.931 : 116.9 secs : infill_ei
#
# Fri Aug 01 01:33:45 2025 AUC 0.929749747615047
#
# [mbo] 37: learning_rate=0.0183; num_leaves=244; min_data_in_leaf=152; feature_fraction=0.683; lambda_l2=12.8 : y = 0.93 : 173.8 secs : infill_ei
#
# Saved the current state after iteration 38 in the file bayesiana.RDATA.
#
# Fri Aug 01 01:36:50 2025 AUC 0.930067815985007
#
# [mbo] 38: learning_rate=0.00517; num_leaves=272; min_data_in_leaf=170; feature_fraction=0.48; lambda_l2=7.3 : y = 0.93 : 180.6 secs : infill_ei
#
# Fri Aug 01 01:39:02 2025 AUC 0.930431992515229
#
# [mbo] 39: learning_rate=0.021; num_leaves=60; min_data_in_leaf=122; feature_fraction=0.48; lambda_l2=7.43 : y = 0.93 : 131.7 secs : infill_ei
#
# Fri Aug 01 01:40:58 2025 AUC 0.930635752140871
#
# [mbo] 40: learning_rate=0.00877; num_leaves=36; min_data_in_leaf=27; feature_fraction=0.494; lambda_l2=11.4 : y = 0.931 : 115.3 secs : infill_ei
#
# Fri Aug 01 01:43:42 2025 AUC 0.930082129742838
#
# [mbo] 41: learning_rate=0.0183; num_leaves=117; min_data_in_leaf=32; feature_fraction=0.439; lambda_l2=13.2 : y = 0.93 : 162.6 secs : infill_ei
#
# Fri Aug 01 01:45:44 2025 AUC 0.930201799277902
#
# [mbo] 42: learning_rate=0.0139; num_leaves=48; min_data_in_leaf=137; feature_fraction=0.43; lambda_l2=12.2 : y = 0.93 : 121.2 secs : infill_ei
#
# Saved the current state after iteration 43 in the file bayesiana.RDATA.
#
# Fri Aug 01 01:47:53 2025 AUC 0.93154950681442
#
# [mbo] 43: learning_rate=0.00662; num_leaves=52; min_data_in_leaf=120; feature_fraction=0.443; lambda_l2=14.4 : y = 0.932 : 124.4 secs : infill_ei
#
# Fri Aug 01 01:50:11 2025 AUC 0.930658601929106
#
# [mbo] 44: learning_rate=0.00925; num_leaves=61; min_data_in_leaf=32; feature_fraction=0.506; lambda_l2=11.6 : y = 0.931 : 137.8 secs : infill_ei
#
# Fri Aug 01 01:54:41 2025 AUC 0.929845317031647
#
# [mbo] 45: learning_rate=0.0192; num_leaves=284; min_data_in_leaf=22; feature_fraction=0.588; lambda_l2=8.49 : y = 0.93 : 269.4 secs : infill_ei
#
# Fri Aug 01 01:56:39 2025 AUC 0.931782679611187
#
# [mbo] 46: learning_rate=0.00832; num_leaves=36; min_data_in_leaf=17; feature_fraction=0.554; lambda_l2=10.6 : y = 0.932 : 117.3 secs : infill_ei
#
# Saved the current state after iteration 47 in the file bayesiana.RDATA.
#
# Fri Aug 01 01:59:34 2025 AUC 0.929265479149592
#
# [mbo] 47: learning_rate=0.00637; num_leaves=111; min_data_in_leaf=147; feature_fraction=0.475; lambda_l2=5.04 : y = 0.929 : 170.7 secs : infill_ei
#
# Fri Aug 01 02:02:43 2025 AUC 0.929487516369906
#
# [mbo] 48: learning_rate=0.021; num_leaves=152; min_data_in_leaf=188; feature_fraction=0.574; lambda_l2=7.76 : y = 0.929 : 188.0 secs : infill_ei
#
# Fri Aug 01 02:05:03 2025 AUC 0.93139566654889
#
# [mbo] 49: learning_rate=0.00922; num_leaves=80; min_data_in_leaf=71; feature_fraction=0.332; lambda_l2=5.59 : y = 0.931 : 139.0 secs : infill_ei
#
# Fri Aug 01 02:07:04 2025 AUC 0.931145332780386
#
# [mbo] 50: learning_rate=0.00657; num_leaves=35; min_data_in_leaf=32; feature_fraction=0.505; lambda_l2=10.2 : y = 0.931 : 120.4 secs : infill_ei
#
# Saved the current state after iteration 51 in the file bayesiana.RDATA.
#
# Fri Aug 01 02:09:59 2025 AUC 0.930626270719132
#
# [mbo] 51: learning_rate=0.0172; num_leaves=104; min_data_in_leaf=43; feature_fraction=0.51; lambda_l2=10.8 : y = 0.931 : 169.5 secs : infill_ei
#
# Fri Aug 01 02:13:29 2025 AUC 0.929128989201488
#
# [mbo] 52: learning_rate=0.00847; num_leaves=188; min_data_in_leaf=26; feature_fraction=0.423; lambda_l2=9.14 : y = 0.929 : 209.9 secs : infill_ei
#
# Fri Aug 01 02:15:20 2025 AUC 0.932088996671251
#
# [mbo] 53: learning_rate=0.0107; num_leaves=34; min_data_in_leaf=140; feature_fraction=0.342; lambda_l2=12.4 : y = 0.932 : 109.8 secs : infill_ei
#
# Fri Aug 01 02:18:50 2025 AUC 0.929302277708476
#
# [mbo] 54: learning_rate=0.0135; num_leaves=241; min_data_in_leaf=117; feature_fraction=0.396; lambda_l2=8.21 : y = 0.929 : 208.9 secs : infill_ei
#
# Saved the current state after iteration 55 in the file bayesiana.RDATA.
#
# Fri Aug 01 02:20:46 2025 AUC 0.931729924212316
#
# [mbo] 55: learning_rate=0.00896; num_leaves=38; min_data_in_leaf=125; feature_fraction=0.344; lambda_l2=13.4 : y = 0.932 : 112.0 secs : infill_ei
#
# Fri Aug 01 02:23:12 2025 AUC 0.930121762145491
#
# [mbo] 56: learning_rate=0.01; num_leaves=93; min_data_in_leaf=137; feature_fraction=0.338; lambda_l2=13.1 : y = 0.93 : 145.5 secs : infill_ei
#
# Fri Aug 01 02:26:32 2025 AUC 0.929970475610157
#
# [mbo] 57: learning_rate=0.0142; num_leaves=167; min_data_in_leaf=153; feature_fraction=0.501; lambda_l2=9.41 : y = 0.93 : 198.4 secs : infill_ei
#
# Fri Aug 01 02:28:19 2025 AUC 0.931147292525507
#
# [mbo] 58: learning_rate=0.012; num_leaves=30; min_data_in_leaf=53; feature_fraction=0.342; lambda_l2=14.2 : y = 0.931 : 106.7 secs : infill_ei
#
# Fri Aug 01 02:30:14 2025 AUC 0.931047132243915
#
# [mbo] 59: learning_rate=0.0107; num_leaves=30; min_data_in_leaf=109; feature_fraction=0.455; lambda_l2=12.4 : y = 0.931 : 113.9 secs : infill_ei
#
# Saved the current state after iteration 60 in the file bayesiana.RDATA.
#
# Fri Aug 01 02:32:07 2025 AUC 0.930436578547084
#
# [mbo] 60: learning_rate=0.0079; num_leaves=30; min_data_in_leaf=163; feature_fraction=0.342; lambda_l2=12.7 : y = 0.93 : 108.2 secs : infill_ei
#
# Fri Aug 01 02:34:56 2025 AUC 0.929914261741959
#
# [mbo] 61: learning_rate=0.018; num_leaves=244; min_data_in_leaf=196; feature_fraction=0.318; lambda_l2=10.7 : y = 0.93 : 167.8 secs : infill_ei
#
# Fri Aug 01 02:37:23 2025 AUC 0.929398510668568
#
# [mbo] 62: learning_rate=0.0122; num_leaves=115; min_data_in_leaf=152; feature_fraction=0.669; lambda_l2=8.98 : y = 0.929 : 146.5 secs : infill_ei
#
# Fri Aug 01 02:39:44 2025 AUC 0.930161666508404
#
# [mbo] 63: learning_rate=0.00943; num_leaves=73; min_data_in_leaf=152; feature_fraction=0.583; lambda_l2=8.9 : y = 0.93 : 139.8 secs : infill_ei
#
# Fri Aug 01 02:42:38 2025 AUC 0.929203459919274
#
# [mbo] 64: learning_rate=0.017; num_leaves=146; min_data_in_leaf=63; feature_fraction=0.335; lambda_l2=5.13 : y = 0.929 : 173.8 secs : infill_ei
#
# Saved the current state after iteration 65 in the file bayesiana.RDATA.
#
# Fri Aug 01 02:45:50 2025 AUC 0.929376274833767
#
# [mbo] 65: learning_rate=0.0181; num_leaves=149; min_data_in_leaf=45; feature_fraction=0.433; lambda_l2=5.16 : y = 0.929 : 187.5 secs : infill_ei
#
# Fri Aug 01 02:49:29 2025 AUC 0.929249246014007
#
# [mbo] 66: learning_rate=0.0107; num_leaves=237; min_data_in_leaf=19; feature_fraction=0.31; lambda_l2=5.37 : y = 0.929 : 218.3 secs : infill_ei
#
# Fri Aug 01 02:52:06 2025 AUC 0.930531090420905
#
# [mbo] 67: learning_rate=0.0188; num_leaves=100; min_data_in_leaf=103; feature_fraction=0.408; lambda_l2=10.2 : y = 0.931 : 156.5 secs : infill_ei
#
# Fri Aug 01 02:55:41 2025 AUC 0.928940261126312
#
# [mbo] 68: learning_rate=0.0197; num_leaves=215; min_data_in_leaf=32; feature_fraction=0.648; lambda_l2=12.5 : y = 0.929 : 214.0 secs : infill_ei
#
# Saved the current state after iteration 69 in the file bayesiana.RDATA.
#
# Fri Aug 01 02:58:40 2025 AUC 0.928716923857581
#
# [mbo] 69: learning_rate=0.00654; num_leaves=232; min_data_in_leaf=144; feature_fraction=0.693; lambda_l2=12.4 : y = 0.929 : 175.1 secs : infill_ei
#
# Fri Aug 01 03:01:38 2025 AUC 0.930343287222592
#
# [mbo] 70: learning_rate=0.00886; num_leaves=199; min_data_in_leaf=168; feature_fraction=0.34; lambda_l2=8.66 : y = 0.93 : 176.5 secs : infill_ei
#
# Fri Aug 01 03:04:47 2025 AUC 0.928798731747035
#
# [mbo] 71: learning_rate=0.0208; num_leaves=265; min_data_in_leaf=190; feature_fraction=0.603; lambda_l2=5.11 : y = 0.929 : 188.7 secs : infill_ei
#
# Fri Aug 01 03:07:25 2025 AUC 0.929908084363312
#
# [mbo] 72: learning_rate=0.011; num_leaves=98; min_data_in_leaf=23; feature_fraction=0.388; lambda_l2=14.5 : y = 0.93 : 157.0 secs : infill_ei
#
# Saved the current state after iteration 73 in the file bayesiana.RDATA.
#
# Fri Aug 01 03:10:07 2025 AUC 0.930347316880441
#
# [mbo] 73: learning_rate=0.0243; num_leaves=95; min_data_in_leaf=74; feature_fraction=0.449; lambda_l2=13.9 : y = 0.93 : 157.7 secs : infill_ei
#
# Fri Aug 01 03:13:21 2025 AUC 0.929447310510799
#
# [mbo] 74: learning_rate=0.00895; num_leaves=178; min_data_in_leaf=191; feature_fraction=0.539; lambda_l2=6.74 : y = 0.929 : 193.7 secs : infill_ei
#
# Fri Aug 01 03:15:29 2025 AUC 0.931085300328386
#
# [mbo] 75: learning_rate=0.0124; num_leaves=47; min_data_in_leaf=120; feature_fraction=0.565; lambda_l2=14.4 : y = 0.931 : 125.9 secs : infill_ei
#
# Fri Aug 01 03:19:00 2025 AUC 0.930338726100812
#
# [mbo] 76: learning_rate=0.0128; num_leaves=205; min_data_in_leaf=24; feature_fraction=0.382; lambda_l2=9.67 : y = 0.93 : 210.4 secs : infill_ei
#
# Saved the current state after iteration 77 in the file bayesiana.RDATA.
#
# Fri Aug 01 03:22:02 2025 AUC 0.928555359360962
#
# [mbo] 77: learning_rate=0.014; num_leaves=121; min_data_in_leaf=26; feature_fraction=0.49; lambda_l2=7.62 : y = 0.929 : 178.8 secs : infill_ei
#
# Fri Aug 01 03:23:50 2025 AUC 0.930807006624514
#
# [mbo] 78: learning_rate=0.0118; num_leaves=30; min_data_in_leaf=119; feature_fraction=0.341; lambda_l2=9.07 : y = 0.931 : 106.6 secs : infill_ei
#
# Fri Aug 01 03:25:47 2025 AUC 0.932367146849082
#
# [mbo] 79: learning_rate=0.0161; num_leaves=34; min_data_in_leaf=21; feature_fraction=0.44; lambda_l2=14.6 : y = 0.932 : 115.8 secs : infill_ei
#
# Fri Aug 01 03:27:47 2025 AUC 0.931782864068411
#
# [mbo] 80: learning_rate=0.0129; num_leaves=37; min_data_in_leaf=23; feature_fraction=0.437; lambda_l2=14.7 : y = 0.932 : 118.8 secs : infill_ei
#
# Fri Aug 01 03:29:37 2025 AUC 0.930934103948397
#
# [mbo] 81: learning_rate=0.0137; num_leaves=31; min_data_in_leaf=148; feature_fraction=0.372; lambda_l2=12.4 : y = 0.931 : 109.2 secs : infill_ei
#
# Saved the current state after iteration 82 in the file bayesiana.RDATA.
#
# Fri Aug 01 03:31:46 2025 AUC 0.930151947929706
#
# [mbo] 82: learning_rate=0.00607; num_leaves=81; min_data_in_leaf=50; feature_fraction=0.663; lambda_l2=9.76 : y = 0.93 : 124.9 secs : infill_ei
#
# Fri Aug 01 03:35:19 2025 AUC 0.92896827567516
#
# [mbo] 83: learning_rate=0.0242; num_leaves=267; min_data_in_leaf=119; feature_fraction=0.385; lambda_l2=5.28 : y = 0.929 : 211.8 secs : infill_ei
#
# Fri Aug 01 03:37:07 2025 AUC 0.930087529474229
#
# [mbo] 84: learning_rate=0.0158; num_leaves=61; min_data_in_leaf=109; feature_fraction=0.691; lambda_l2=8.46 : y = 0.93 : 107.2 secs : infill_ei
#
# Fri Aug 01 03:39:02 2025 AUC 0.931603705224565
#
# [mbo] 85: learning_rate=0.0163; num_leaves=34; min_data_in_leaf=12; feature_fraction=0.429; lambda_l2=14.5 : y = 0.932 : 114.2 secs : infill_ei
#
# Fri Aug 01 03:41:01 2025 AUC 0.930646568239561
#
# [mbo] 86: learning_rate=0.00836; num_leaves=30; min_data_in_leaf=66; feature_fraction=0.512; lambda_l2=14.3 : y = 0.931 : 118.1 secs : infill_ei
#
# Saved the current state after iteration 87 in the file bayesiana.RDATA.
#
# Fri Aug 01 03:44:49 2025 AUC 0.929597460086455
#
# [mbo] 87: learning_rate=0.0184; num_leaves=268; min_data_in_leaf=68; feature_fraction=0.349; lambda_l2=13.9 : y = 0.93 : 222.8 secs : infill_ei
#
# Fri Aug 01 03:46:36 2025 AUC 0.93202593549614
#
# [mbo] 88: learning_rate=0.0124; num_leaves=33; min_data_in_leaf=159; feature_fraction=0.315; lambda_l2=13.1 : y = 0.932 : 106.1 secs : infill_ei
#
# Fri Aug 01 03:48:29 2025 AUC 0.931830595162643
#
# [mbo] 89: learning_rate=0.0125; num_leaves=38; min_data_in_leaf=134; feature_fraction=0.333; lambda_l2=13.1 : y = 0.932 : 111.5 secs : infill_ei
#
# Fri Aug 01 03:52:04 2025 AUC 0.929185160027195
#
# [mbo] 90: learning_rate=0.0122; num_leaves=249; min_data_in_leaf=111; feature_fraction=0.437; lambda_l2=11.6 : y = 0.929 : 214.0 secs : infill_ei
#
# Saved the current state after iteration 91 in the file bayesiana.RDATA.
#
# Fri Aug 01 03:54:04 2025 AUC 0.931826369056692
#
# [mbo] 91: learning_rate=0.0161; num_leaves=30; min_data_in_leaf=24; feature_fraction=0.446; lambda_l2=14.8 : y = 0.932 : 113.5 secs : infill_ei
#
# Fri Aug 01 03:57:44 2025 AUC 0.930174408375457
#
# [mbo] 92: learning_rate=0.0149; num_leaves=192; min_data_in_leaf=18; feature_fraction=0.441; lambda_l2=15 : y = 0.93 : 218.4 secs : infill_ei
#
# Fri Aug 01 03:59:41 2025 AUC 0.931330497620411
#
# [mbo] 93: learning_rate=0.0154; num_leaves=33; min_data_in_leaf=51; feature_fraction=0.44; lambda_l2=12.3 : y = 0.931 : 115.8 secs : infill_ei
#
# Fri Aug 01 04:01:39 2025 AUC 0.931319140935458
#
# [mbo] 94: learning_rate=0.0105; num_leaves=30; min_data_in_leaf=85; feature_fraction=0.51; lambda_l2=10.8 : y = 0.931 : 117.5 secs : infill_ei
#
# Fri Aug 01 04:05:23 2025 AUC 0.930189997384096
#
# [mbo] 95: learning_rate=0.0154; num_leaves=253; min_data_in_leaf=74; feature_fraction=0.372; lambda_l2=8.92 : y = 0.93 : 223.4 secs : infill_ei
#
# Saved the current state after iteration 96 in the file bayesiana.RDATA.
#
# Fri Aug 01 04:07:28 2025 AUC 0.931438192966759
#
# [mbo] 96: learning_rate=0.0171; num_leaves=37; min_data_in_leaf=29; feature_fraction=0.44; lambda_l2=14.8 : y = 0.931 : 118.4 secs : infill_ei
#
# Fri Aug 01 04:09:30 2025 AUC 0.930135355176279
#
# [mbo] 97: learning_rate=0.0121; num_leaves=34; min_data_in_leaf=21; feature_fraction=0.503; lambda_l2=11.6 : y = 0.93 : 120.6 secs : infill_ei
#
# Fri Aug 01 04:11:24 2025 AUC 0.931101457435827
#
# [mbo] 98: learning_rate=0.0128; num_leaves=42; min_data_in_leaf=141; feature_fraction=0.308; lambda_l2=13.3 : y = 0.931 : 112.8 secs : infill_ei
#
# Fri Aug 01 04:13:28 2025 AUC 0.931306870355137
#
# [mbo] 99: learning_rate=0.00963; num_leaves=36; min_data_in_leaf=52; feature_fraction=0.53; lambda_l2=10.9 : y = 0.931 : 121.9 secs : infill_ei
#
# Fri Aug 01 04:15:56 2025 AUC 0.92978671632166
#
# [mbo] 100: learning_rate=0.0107; num_leaves=86; min_data_in_leaf=128; feature_fraction=0.592; lambda_l2=5.59 : y = 0.93 : 146.8 secs : infill_ei
#
# Saved the current state after iteration 101 in the file bayesiana.RDATA.
#
# Fri Aug 01 04:18:02 2025 AUC 0.9309986504813
#
# [mbo] 101: learning_rate=0.016; num_leaves=44; min_data_in_leaf=19; feature_fraction=0.377; lambda_l2=14.3 : y = 0.931 : 120.3 secs : infill_ei
#
# Fri Aug 01 04:20:33 2025 AUC 0.930603088789444
#
# [mbo] 102: learning_rate=0.00828; num_leaves=68; min_data_in_leaf=19; feature_fraction=0.513; lambda_l2=10.8 : y = 0.931 : 149.3 secs : infill_ei
#
# Fri Aug 01 04:22:21 2025 AUC 0.930804795233469
#
# [mbo] 103: learning_rate=0.0074; num_leaves=35; min_data_in_leaf=141; feature_fraction=0.314; lambda_l2=13.4 : y = 0.931 : 107.3 secs : infill_ei
#
# Fri Aug 01 04:25:16 2025 AUC 0.930294175978266
#
# [mbo] 104: learning_rate=0.0177; num_leaves=120; min_data_in_leaf=66; feature_fraction=0.452; lambda_l2=14.1 : y = 0.93 : 174.1 secs : infill_ei
#
# Fri Aug 01 04:28:06 2025 AUC 0.930400140215185
#
# [mbo] 105: learning_rate=0.0155; num_leaves=144; min_data_in_leaf=75; feature_fraction=0.656; lambda_l2=13 : y = 0.93 : 168.2 secs : infill_ei
#
# Saved the current state after iteration 106 in the file bayesiana.RDATA.
#
# Fri Aug 01 04:30:04 2025 AUC 0.929526132359277
#
# [mbo] 106: learning_rate=0.0161; num_leaves=30; min_data_in_leaf=80; feature_fraction=0.457; lambda_l2=14.7 : y = 0.93 : 113.6 secs : infill_ei
#
# Fri Aug 01 04:33:03 2025 AUC 0.930040281292896
#
# [mbo] 107: learning_rate=0.0143; num_leaves=155; min_data_in_leaf=146; feature_fraction=0.363; lambda_l2=6.24 : y = 0.93 : 178.1 secs : infill_ei
#
# Fri Aug 01 04:35:30 2025 AUC 0.929312837990366
#
# [mbo] 108: learning_rate=0.0193; num_leaves=91; min_data_in_leaf=199; feature_fraction=0.594; lambda_l2=6.06 : y = 0.929 : 146.1 secs : infill_ei
#
# Fri Aug 01 04:39:26 2025 AUC 0.928146668728085
#
# [mbo] 109: learning_rate=0.025; num_leaves=250; min_data_in_leaf=21; feature_fraction=0.693; lambda_l2=8.76 : y = 0.928 : 235.2 secs : infill_ei
#
# Saved the current state after iteration 110 in the file bayesiana.RDATA.
#
# Fri Aug 01 04:42:19 2025 AUC 0.930051159230342
#
# [mbo] 110: learning_rate=0.0235; num_leaves=129; min_data_in_leaf=42; feature_fraction=0.602; lambda_l2=5.35 : y = 0.93 : 168.0 secs : infill_ei
#
# Fri Aug 01 04:44:06 2025 AUC 0.931711512016364
#
# [mbo] 111: learning_rate=0.0122; num_leaves=30; min_data_in_leaf=152; feature_fraction=0.327; lambda_l2=13.1 : y = 0.932 : 105.4 secs : infill_ei
#
# Fri Aug 01 04:45:54 2025 AUC 0.932084056593249
#
# [mbo] 112: learning_rate=0.0117; num_leaves=30; min_data_in_leaf=136; feature_fraction=0.344; lambda_l2=13 : y = 0.932 : 106.7 secs : infill_ei
#
# Fri Aug 01 04:47:39 2025 AUC 0.930464141250849
#
# [mbo] 113: learning_rate=0.0125; num_leaves=30; min_data_in_leaf=132; feature_fraction=0.313; lambda_l2=12.9 : y = 0.93 : 103.3 secs : infill_ei
#
# Fri Aug 01 04:50:16 2025 AUC 0.929306944825142
#
# [mbo] 114: learning_rate=0.014; num_leaves=129; min_data_in_leaf=92; feature_fraction=0.69; lambda_l2=12.6 : y = 0.929 : 156.7 secs : infill_ei
#
# Saved the current state after iteration 115 in the file bayesiana.RDATA.
#
# Fri Aug 01 04:52:19 2025 AUC 0.93171354657542
#
# [mbo] 115: learning_rate=0.0114; num_leaves=46; min_data_in_leaf=136; feature_fraction=0.344; lambda_l2=13.9 : y = 0.932 : 118.0 secs : infill_ei
#
# Fri Aug 01 04:55:56 2025 AUC 0.929350109749219
#
# [mbo] 116: learning_rate=0.0149; num_leaves=209; min_data_in_leaf=45; feature_fraction=0.662; lambda_l2=7.84 : y = 0.929 : 216.1 secs : infill_ei
#
# Fri Aug 01 04:57:57 2025 AUC 0.930183336336679
#
# [mbo] 117: learning_rate=0.0209; num_leaves=39; min_data_in_leaf=35; feature_fraction=0.443; lambda_l2=14.6 : y = 0.93 : 119.2 secs : infill_ei
#
# Fri Aug 01 05:00:31 2025 AUC 0.930113788228073
#
# [mbo] 118: learning_rate=0.0233; num_leaves=103; min_data_in_leaf=47; feature_fraction=0.348; lambda_l2=12.2 : y = 0.93 : 153.8 secs : infill_ei
#
# Saved the current state after iteration 119 in the file bayesiana.RDATA.
#
# Fri Aug 01 05:02:47 2025 AUC 0.929621732389808
#
# [mbo] 119: learning_rate=0.022; num_leaves=87; min_data_in_leaf=41; feature_fraction=0.655; lambda_l2=13.8 : y = 0.93 : 130.8 secs : infill_ei
#
# Fri Aug 01 05:07:16 2025 AUC 0.930051360052117
#
# [mbo] 120: learning_rate=0.013; num_leaves=300; min_data_in_leaf=15; feature_fraction=0.648; lambda_l2=10.1 : y = 0.93 : 268.1 secs : infill_ei
#
# Fri Aug 01 05:09:03 2025 AUC 0.931358256370767
#
# [mbo] 121: learning_rate=0.0133; num_leaves=31; min_data_in_leaf=142; feature_fraction=0.336; lambda_l2=14.7 : y = 0.931 : 106.6 secs : infill_ei
#
# Fri Aug 01 05:11:28 2025 AUC 0.930937319443036
#
# [mbo] 122: learning_rate=0.0234; num_leaves=84; min_data_in_leaf=38; feature_fraction=0.352; lambda_l2=12.1 : y = 0.931 : 143.1 secs : infill_ei
#
# Saved the current state after iteration 123 in the file bayesiana.RDATA.
#
# Fri Aug 01 05:13:30 2025 AUC 0.93147484309503
#
# [mbo] 123: learning_rate=0.0152; num_leaves=35; min_data_in_leaf=21; feature_fraction=0.441; lambda_l2=14.4 : y = 0.931 : 116.6 secs : infill_ei
#
# Fri Aug 01 05:15:30 2025 AUC 0.93078414212667
#
# [mbo] 124: learning_rate=0.0125; num_leaves=37; min_data_in_leaf=50; feature_fraction=0.439; lambda_l2=8.65 : y = 0.931 : 118.6 secs : infill_ei
#
# Fri Aug 01 05:17:17 2025 AUC 0.931471993744017
#
# [mbo] 125: learning_rate=0.0118; num_leaves=30; min_data_in_leaf=141; feature_fraction=0.341; lambda_l2=10.2 : y = 0.931 : 105.9 secs : infill_ei
#
# Fri Aug 01 05:20:35 2025 AUC 0.928769258440686
#
# [mbo] 126: learning_rate=0.0164; num_leaves=179; min_data_in_leaf=23; feature_fraction=0.626; lambda_l2=10.9 : y = 0.929 : 196.8 secs : infill_ei
#
# Fri Aug 01 05:24:10 2025 AUC 0.929327472629396
#
# [mbo] 127: learning_rate=0.0113; num_leaves=263; min_data_in_leaf=150; feature_fraction=0.526; lambda_l2=7.4 : y = 0.929 : 213.8 secs : infill_ei
#
# Saved the current state after iteration 128 in the file bayesiana.RDATA.
#
# Fri Aug 01 05:26:28 2025 AUC 0.93051918767005
#
# [mbo] 128: learning_rate=0.00815; num_leaves=71; min_data_in_leaf=127; feature_fraction=0.347; lambda_l2=11.9 : y = 0.931 : 133.4 secs : infill_ei
#
# Fri Aug 01 05:28:21 2025 AUC 0.931253530013996
#
# [mbo] 129: learning_rate=0.0125; num_leaves=41; min_data_in_leaf=173; feature_fraction=0.318; lambda_l2=13.3 : y = 0.931 : 112.0 secs : infill_ei
#
# Fri Aug 01 05:30:15 2025 AUC 0.929206456708086
#
# [mbo] 130: learning_rate=0.0178; num_leaves=68; min_data_in_leaf=38; feature_fraction=0.694; lambda_l2=12.5 : y = 0.929 : 113.4 secs : infill_ei
#
# Fri Aug 01 05:32:12 2025 AUC 0.931087138286617
#
# [mbo] 131: learning_rate=0.0127; num_leaves=33; min_data_in_leaf=48; feature_fraction=0.437; lambda_l2=14.6 : y = 0.931 : 114.9 secs : infill_ei
#
# Fri Aug 01 05:35:31 2025 AUC 0.92943271159367
#
# [mbo] 132: learning_rate=0.00653; num_leaves=283; min_data_in_leaf=123; feature_fraction=0.427; lambda_l2=14.3 : y = 0.929 : 197.6 secs : infill_ei
#
# Saved the current state after iteration 133 in the file bayesiana.RDATA.
#
# Fri Aug 01 05:39:38 2025 AUC 0.928520990463449
#
# [mbo] 133: learning_rate=0.0149; num_leaves=266; min_data_in_leaf=86; feature_fraction=0.611; lambda_l2=6.43 : y = 0.929 : 242.8 secs : infill_ei
#
# Fri Aug 01 05:42:42 2025 AUC 0.930355647134269
#
# [mbo] 134: learning_rate=0.00735; num_leaves=153; min_data_in_leaf=68; feature_fraction=0.631; lambda_l2=7.81 : y = 0.93 : 183.1 secs : infill_ei
#
# Fri Aug 01 05:44:45 2025 AUC 0.929754893005244
#
# [mbo] 135: learning_rate=0.0164; num_leaves=40; min_data_in_leaf=21; feature_fraction=0.434; lambda_l2=13.7 : y = 0.93 : 121.4 secs : infill_ei
#
# Fri Aug 01 05:48:08 2025 AUC 0.930155776821466
#
# [mbo] 136: learning_rate=0.0202; num_leaves=261; min_data_in_leaf=181; feature_fraction=0.539; lambda_l2=8.78 : y = 0.93 : 201.5 secs : infill_ei
#
# Saved the current state after iteration 137 in the file bayesiana.RDATA.
#
# Fri Aug 01 05:51:21 2025 AUC 0.929511958591448
#
# [mbo] 137: learning_rate=0.0157; num_leaves=146; min_data_in_leaf=26; feature_fraction=0.436; lambda_l2=14.6 : y = 0.93 : 188.6 secs : infill_ei
#
# Fri Aug 01 05:53:22 2025 AUC 0.930583759897117
#
# [mbo] 138: learning_rate=0.00704; num_leaves=31; min_data_in_leaf=51; feature_fraction=0.508; lambda_l2=11.1 : y = 0.931 : 118.4 secs : infill_ei
#
# Fri Aug 01 05:56:56 2025 AUC 0.929489360701692
#
# [mbo] 139: learning_rate=0.0089; num_leaves=253; min_data_in_leaf=114; feature_fraction=0.439; lambda_l2=8.51 : y = 0.929 : 213.5 secs : infill_ei
#
# Fri Aug 01 06:00:33 2025 AUC 0.928727338404672
#
# [mbo] 140: learning_rate=0.0204; num_leaves=215; min_data_in_leaf=46; feature_fraction=0.682; lambda_l2=12.9 : y = 0.929 : 215.8 secs : infill_ei
#
# Saved the current state after iteration 141 in the file bayesiana.RDATA.
#
# Fri Aug 01 06:04:29 2025 AUC 0.929279795322089
#
# [mbo] 141: learning_rate=0.00922; num_leaves=253; min_data_in_leaf=35; feature_fraction=0.365; lambda_l2=11 : y = 0.929 : 231.8 secs : infill_ei
#
# Fri Aug 01 06:07:19 2025 AUC 0.929805988263011
#
# [mbo] 142: learning_rate=0.00551; num_leaves=112; min_data_in_leaf=95; feature_fraction=0.444; lambda_l2=7.94 : y = 0.93 : 168.7 secs : infill_ei
#
# Fri Aug 01 06:09:15 2025 AUC 0.930472957918023
#
# [mbo] 143: learning_rate=0.0164; num_leaves=31; min_data_in_leaf=18; feature_fraction=0.438; lambda_l2=14.7 : y = 0.93 : 113.8 secs : infill_ei
#
# Fri Aug 01 06:11:16 2025 AUC 0.930957813804161
#
# [mbo] 144: learning_rate=0.0122; num_leaves=38; min_data_in_leaf=195; feature_fraction=0.435; lambda_l2=7 : y = 0.931 : 119.6 secs : infill_ei
#
# Saved the current state after iteration 145 in the file bayesiana.RDATA.
#
# Fri Aug 01 06:14:11 2025 AUC 0.929612091041025
#
# [mbo] 145: learning_rate=0.0154; num_leaves=125; min_data_in_leaf=62; feature_fraction=0.392; lambda_l2=5.28 : y = 0.93 : 170.3 secs : infill_ei
#
# Fri Aug 01 06:18:42 2025 AUC 0.929899072849126
#
# [mbo] 146: learning_rate=0.0223; num_leaves=275; min_data_in_leaf=34; feature_fraction=0.552; lambda_l2=11.7 : y = 0.93 : 270.5 secs : infill_ei
#
# Fri Aug 01 06:21:54 2025 AUC 0.930290774488317
#
# [mbo] 147: learning_rate=0.0102; num_leaves=164; min_data_in_leaf=183; feature_fraction=0.535; lambda_l2=12.7 : y = 0.93 : 190.7 secs : infill_ei
#
# Saved the current state after iteration 148 in the file bayesiana.RDATA.
#
# Fri Aug 01 06:25:19 2025 AUC 0.92973024086558
#
# [mbo] 148: learning_rate=0.0108; num_leaves=201; min_data_in_leaf=124; feature_fraction=0.378; lambda_l2=6.67 : y = 0.93 : 200.2 secs : infill_ei
#
# Fri Aug 01 06:28:34 2025 AUC 0.930117040282247
#
# [mbo] 149: learning_rate=0.0197; num_leaves=273; min_data_in_leaf=130; feature_fraction=0.364; lambda_l2=12.9 : y = 0.93 : 193.8 secs : infill_ei
#
# Fri Aug 01 06:30:27 2025 AUC 0.930048028055671
#
# [mbo] 150: learning_rate=0.0246; num_leaves=39; min_data_in_leaf=192; feature_fraction=0.572; lambda_l2=6.72 : y = 0.93 : 111.8 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "learning_rate"    "num_leaves"       "min_data_in_leaf" "feature_fraction"
#  [5] "lambda_l2"        "y"                "dob"              "eol"
#  [9] "error.message"    "exec.time"        "ei"               "error.model"
# [13] "train.time"       "prop.type"        "propose.time"     "se"
# [17] "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    learning_rate num_leaves min_data_in_leaf feature_fraction lambda_l2
#            <num>      <int>            <int>            <num>     <num>
# 1:    0.01610396         34               21         0.439731  14.64511
# [1] 0.9323671

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 333757
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 14.64511
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 1
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 2000
#
# $learning_rate
# [1] 0.01610396
#
# $feature_fraction
# [1] 0.439731
#
# $num_leaves
# [1] 34
#
# $min_data_in_leaf
# [1] 21

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Fri Aug 01 06:41:03 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
