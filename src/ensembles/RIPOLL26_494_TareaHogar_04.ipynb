# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# Esta Tarea para el Hogar 02 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el viernes 01-agosto

# %% [markdown]
# ##  1. Cazatalentos

# %% [markdown]
# En la Clase 03 nos hemos enfrentado a  "La Maldicion del Ganandor",  elegir el modelo con el mejor puntaje simple no suele ser la mejor estrategia.
# <br> Lea y ejecute el notebook  **src/CazaTalentos/CazaTalentos.ipynb**
# <br> en caso de interesarle, participe del Desafío Ordenamiento  que vence el sábado 02 de agosto a las 19:00

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dm"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dm" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/itba2025-8d0a/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Jul 29 13:57:50 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  658291 35.2 1439374    76.9 1439374  76.9
# Vcells 1227501  9.4 8388608    64.0 1964337  15.0

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 4965
PARAM$semilla_primigenia <- 333757

# %%
PARAM$kaggle$competencia <- "data-mining-analista-sr-2025-a"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1500,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
makeNumericParam("learning_rate", lower = 0.02, upper = 0.035),
makeIntegerParam("num_leaves", lower = 1300L, upper = 1600L),
makeIntegerParam("min_data_in_leaf", lower = 400L, upper = 600L),
makeNumericParam("bagging_fraction", lower = 0.30, upper = 0.50),   # <- subirlo un poco
makeNumericParam("feature_fraction", lower = 0.48, upper = 0.55),
makeNumericParam("lambda_l2", lower = 8.0, upper = 10.0),
makeNumericParam("lambda_l1", lower = 1.0, upper = 2.5),
makeNumericParam("min_gain_to_split", lower = 0.8, upper = 1.2),
makeNumericParam("min_sum_hessian_in_leaf", lower = 40.0, upper = 60.0),
makeNumericParam("scale_pos_weight", lower = 7.5, upper = 9.5),
makeNumericParam("path_smooth", lower = 80, upper = 95),
makeIntegerParam("top_k", lower = 14L, upper = 20L)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 200 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83552
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Tue Jul 29 13:59:03 2025 AUC 0.929366000929258
#
# Tue Jul 29 13:59:58 2025 AUC 0.92995502406866
#
# Tue Jul 29 14:01:05 2025 AUC 0.929325155297383
#
# Tue Jul 29 14:01:59 2025 AUC 0.930100327265448
#
# Tue Jul 29 14:02:57 2025 AUC 0.929149026770443
#
# Tue Jul 29 14:03:53 2025 AUC 0.930366728408053
#
# Tue Jul 29 14:04:45 2025 AUC 0.929413547822538
#
# Tue Jul 29 14:05:40 2025 AUC 0.929926318562328
#
# Tue Jul 29 14:06:36 2025 AUC 0.930071621073703
#
# Tue Jul 29 14:07:34 2025 AUC 0.9302783362208
#
# Tue Jul 29 14:08:28 2025 AUC 0.930065293765328
#
# Tue Jul 29 14:09:27 2025 AUC 0.930181075091478
#
# Tue Jul 29 14:10:24 2025 AUC 0.93082284159967
#
# Tue Jul 29 14:11:23 2025 AUC 0.930308906169764
#
# Tue Jul 29 14:12:22 2025 AUC 0.931109798381772
#
# Tue Jul 29 14:13:14 2025 AUC 0.930195659077932
#
# Tue Jul 29 14:14:06 2025 AUC 0.929541990283275
#
# Tue Jul 29 14:15:02 2025 AUC 0.929601878036614
#
# Tue Jul 29 14:15:55 2025 AUC 0.930718714195947
#
# Tue Jul 29 14:16:52 2025 AUC 0.930827991850103
#
# Tue Jul 29 14:17:52 2025 AUC 0.929938350098351
#
# Tue Jul 29 14:18:51 2025 AUC 0.929273501900663
#
# Tue Jul 29 14:19:50 2025 AUC 0.929684303889503
#
# Tue Jul 29 14:20:46 2025 AUC 0.930291976811121
#
# Tue Jul 29 14:21:40 2025 AUC 0.930940779745744
#
# Tue Jul 29 14:22:33 2025 AUC 0.929709675702927
#
# Tue Jul 29 14:23:25 2025 AUC 0.930480048940847
#
# Tue Jul 29 14:24:20 2025 AUC 0.929293313243341
#
# Tue Jul 29 14:25:20 2025 AUC 0.929696868753319
#
# Tue Jul 29 14:26:19 2025 AUC 0.929894513928037
#
# Tue Jul 29 14:27:10 2025 AUC 0.930233180063982
#
# Tue Jul 29 14:28:12 2025 AUC 0.930349917120527
#
# Tue Jul 29 14:29:04 2025 AUC 0.930253273361277
#
# Tue Jul 29 14:29:58 2025 AUC 0.930498151115186
#
# Tue Jul 29 14:31:01 2025 AUC 0.9301445969801
#
# Tue Jul 29 14:31:52 2025 AUC 0.930491987631334
#
# Tue Jul 29 14:32:52 2025 AUC 0.930487574960793
#
# Tue Jul 29 14:33:49 2025 AUC 0.929773414353614
#
# Tue Jul 29 14:34:40 2025 AUC 0.930088188130304
#
# Tue Jul 29 14:35:35 2025 AUC 0.931095827185794
#
# Tue Jul 29 14:36:25 2025 AUC 0.930861889111208
#
# Tue Jul 29 14:37:23 2025 AUC 0.930135167745376
#
# Tue Jul 29 14:38:15 2025 AUC 0.929929714529889
#
# Tue Jul 29 14:39:06 2025 AUC 0.930464963355593
#
# Tue Jul 29 14:40:04 2025 AUC 0.93004858757104
#
# Tue Jul 29 14:41:07 2025 AUC 0.929086897993457
#
# Tue Jul 29 14:41:58 2025 AUC 0.930867629701291
#
# Tue Jul 29 14:42:58 2025 AUC 0.92979261277704
#
# [mbo] 0: learning_rate=0.0289; num_leaves=1480; min_data_in_leaf=516; bagging_fraction=0.411; feature_fraction=0.492; lambda_l2=8.86; lambda_l1=1.73; min_gain_to_split=0.945; min_sum_hessian_in_leaf=49; scale_pos_weight=8.68; path_smooth=84.2; top_k=16 : y = 0.929 : 54.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0295; num_leaves=1552; min_data_in_leaf=494; bagging_fraction=0.322; feature_fraction=0.491; lambda_l2=9.49; lambda_l1=1.7; min_gain_to_split=0.924; min_sum_hessian_in_leaf=46; scale_pos_weight=8.66; path_smooth=87.2; top_k=19 : y = 0.93 : 54.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0233; num_leaves=1449; min_data_in_leaf=591; bagging_fraction=0.439; feature_fraction=0.515; lambda_l2=9.16; lambda_l1=1.44; min_gain_to_split=0.903; min_sum_hessian_in_leaf=49.6; scale_pos_weight=8.21; path_smooth=82.9; top_k=17 : y = 0.929 : 67.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0319; num_leaves=1453; min_data_in_leaf=415; bagging_fraction=0.381; feature_fraction=0.536; lambda_l2=8.3; lambda_l1=2.12; min_gain_to_split=0.808; min_sum_hessian_in_leaf=47.1; scale_pos_weight=8.96; path_smooth=84.9; top_k=17 : y = 0.93 : 53.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0242; num_leaves=1497; min_data_in_leaf=460; bagging_fraction=0.373; feature_fraction=0.522; lambda_l2=8.82; lambda_l1=2.06; min_gain_to_split=1.04; min_sum_hessian_in_leaf=56.7; scale_pos_weight=8.34; path_smooth=85.8; top_k=17 : y = 0.929 : 58.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0265; num_leaves=1548; min_data_in_leaf=447; bagging_fraction=0.331; feature_fraction=0.519; lambda_l2=9.61; lambda_l1=1.39; min_gain_to_split=1.08; min_sum_hessian_in_leaf=52.1; scale_pos_weight=8.12; path_smooth=87.1; top_k=19 : y = 0.93 : 56.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0332; num_leaves=1489; min_data_in_leaf=451; bagging_fraction=0.414; feature_fraction=0.515; lambda_l2=8.55; lambda_l1=1.01; min_gain_to_split=1.09; min_sum_hessian_in_leaf=51.6; scale_pos_weight=8.29; path_smooth=89.7; top_k=20 : y = 0.929 : 51.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0291; num_leaves=1422; min_data_in_leaf=484; bagging_fraction=0.408; feature_fraction=0.53; lambda_l2=9.17; lambda_l1=2.23; min_gain_to_split=1.11; min_sum_hessian_in_leaf=43.3; scale_pos_weight=8.51; path_smooth=81.9; top_k=16 : y = 0.93 : 54.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0276; num_leaves=1366; min_data_in_leaf=504; bagging_fraction=0.397; feature_fraction=0.508; lambda_l2=9.04; lambda_l1=1.58; min_gain_to_split=0.939; min_sum_hessian_in_leaf=44.6; scale_pos_weight=9.18; path_smooth=84.7; top_k=18 : y = 0.93 : 56.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.022; num_leaves=1458; min_data_in_leaf=570; bagging_fraction=0.433; feature_fraction=0.535; lambda_l2=8.71; lambda_l1=2.16; min_gain_to_split=1.2; min_sum_hessian_in_leaf=48.1; scale_pos_weight=8.2; path_smooth=86.9; top_k=15 : y = 0.93 : 57.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0259; num_leaves=1385; min_data_in_leaf=483; bagging_fraction=0.376; feature_fraction=0.537; lambda_l2=8.98; lambda_l1=1.36; min_gain_to_split=1.09; min_sum_hessian_in_leaf=51.2; scale_pos_weight=9.21; path_smooth=91; top_k=16 : y = 0.93 : 54.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0251; num_leaves=1517; min_data_in_leaf=553; bagging_fraction=0.355; feature_fraction=0.504; lambda_l2=9.09; lambda_l1=2.31; min_gain_to_split=0.813; min_sum_hessian_in_leaf=53.4; scale_pos_weight=8.07; path_smooth=90.3; top_k=14 : y = 0.93 : 58.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.024; num_leaves=1397; min_data_in_leaf=457; bagging_fraction=0.346; feature_fraction=0.532; lambda_l2=9.79; lambda_l1=1.94; min_gain_to_split=1.02; min_sum_hessian_in_leaf=44.5; scale_pos_weight=8.16; path_smooth=90.6; top_k=19 : y = 0.931 : 57.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0274; num_leaves=1437; min_data_in_leaf=426; bagging_fraction=0.359; feature_fraction=0.518; lambda_l2=9.88; lambda_l1=1.77; min_gain_to_split=0.846; min_sum_hessian_in_leaf=55.8; scale_pos_weight=8.44; path_smooth=80.6; top_k=17 : y = 0.93 : 58.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0226; num_leaves=1527; min_data_in_leaf=581; bagging_fraction=0.394; feature_fraction=0.511; lambda_l2=8.95; lambda_l1=1.48; min_gain_to_split=0.953; min_sum_hessian_in_leaf=54.4; scale_pos_weight=8.47; path_smooth=92; top_k=18 : y = 0.931 : 59.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0314; num_leaves=1507; min_data_in_leaf=475; bagging_fraction=0.497; feature_fraction=0.487; lambda_l2=8.11; lambda_l1=1.93; min_gain_to_split=0.973; min_sum_hessian_in_leaf=58; scale_pos_weight=9.12; path_smooth=83.3; top_k=18 : y = 0.93 : 51.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0336; num_leaves=1343; min_data_in_leaf=517; bagging_fraction=0.329; feature_fraction=0.507; lambda_l2=8.89; lambda_l1=2.08; min_gain_to_split=0.958; min_sum_hessian_in_leaf=49.5; scale_pos_weight=8.41; path_smooth=91.8; top_k=15 : y = 0.93 : 52.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0269; num_leaves=1503; min_data_in_leaf=430; bagging_fraction=0.4; feature_fraction=0.503; lambda_l2=8.46; lambda_l1=2; min_gain_to_split=1.07; min_sum_hessian_in_leaf=47.1; scale_pos_weight=9.04; path_smooth=93.6; top_k=20 : y = 0.93 : 56.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0299; num_leaves=1533; min_data_in_leaf=530; bagging_fraction=0.425; feature_fraction=0.51; lambda_l2=8.25; lambda_l1=1.8; min_gain_to_split=1.01; min_sum_hessian_in_leaf=46.6; scale_pos_weight=7.88; path_smooth=83.8; top_k=15 : y = 0.931 : 53.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0256; num_leaves=1486; min_data_in_leaf=544; bagging_fraction=0.304; feature_fraction=0.487; lambda_l2=9.38; lambda_l1=1.68; min_gain_to_split=1.05; min_sum_hessian_in_leaf=45.5; scale_pos_weight=9.45; path_smooth=86.2; top_k=17 : y = 0.931 : 56.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0213; num_leaves=1468; min_data_in_leaf=408; bagging_fraction=0.444; feature_fraction=0.506; lambda_l2=8.72; lambda_l1=1.21; min_gain_to_split=1.06; min_sum_hessian_in_leaf=59.8; scale_pos_weight=7.71; path_smooth=90.4; top_k=19 : y = 0.93 : 60.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0231; num_leaves=1403; min_data_in_leaf=536; bagging_fraction=0.484; feature_fraction=0.542; lambda_l2=9.37; lambda_l1=1.27; min_gain_to_split=0.996; min_sum_hessian_in_leaf=40.1; scale_pos_weight=8.83; path_smooth=83.6; top_k=20 : y = 0.929 : 59.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0205; num_leaves=1427; min_data_in_leaf=500; bagging_fraction=0.321; feature_fraction=0.541; lambda_l2=8.02; lambda_l1=1.64; min_gain_to_split=1.14; min_sum_hessian_in_leaf=50.1; scale_pos_weight=8.04; path_smooth=94.1; top_k=15 : y = 0.93 : 58.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0279; num_leaves=1574; min_data_in_leaf=463; bagging_fraction=0.344; feature_fraction=0.539; lambda_l2=9.56; lambda_l1=1.98; min_gain_to_split=1.19; min_sum_hessian_in_leaf=47.8; scale_pos_weight=9.5; path_smooth=87.9; top_k=15 : y = 0.93 : 56.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0348; num_leaves=1600; min_data_in_leaf=439; bagging_fraction=0.488; feature_fraction=0.524; lambda_l2=9.21; lambda_l1=1.41; min_gain_to_split=1.03; min_sum_hessian_in_leaf=50.5; scale_pos_weight=8.87; path_smooth=89; top_k=14 : y = 0.931 : 53.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.03; num_leaves=1359; min_data_in_leaf=472; bagging_fraction=0.462; feature_fraction=0.484; lambda_l2=8.16; lambda_l1=1.17; min_gain_to_split=0.978; min_sum_hessian_in_leaf=48.7; scale_pos_weight=7.94; path_smooth=92.6; top_k=18 : y = 0.93 : 53.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0286; num_leaves=1390; min_data_in_leaf=433; bagging_fraction=0.304; feature_fraction=0.495; lambda_l2=8.36; lambda_l1=1.85; min_gain_to_split=1.15; min_sum_hessian_in_leaf=57.7; scale_pos_weight=7.85; path_smooth=81.8; top_k=17 : y = 0.93 : 51.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0261; num_leaves=1347; min_data_in_leaf=510; bagging_fraction=0.313; feature_fraction=0.5; lambda_l2=8.78; lambda_l1=2.4; min_gain_to_split=1.18; min_sum_hessian_in_leaf=58.5; scale_pos_weight=9.32; path_smooth=88.7; top_k=14 : y = 0.929 : 54.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0219; num_leaves=1318; min_data_in_leaf=558; bagging_fraction=0.366; feature_fraction=0.498; lambda_l2=9.27; lambda_l1=1.34; min_gain_to_split=0.991; min_sum_hessian_in_leaf=57.5; scale_pos_weight=8.95; path_smooth=81.1; top_k=18 : y = 0.93 : 60.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.025; num_leaves=1581; min_data_in_leaf=491; bagging_fraction=0.478; feature_fraction=0.489; lambda_l2=9.87; lambda_l1=1.83; min_gain_to_split=0.916; min_sum_hessian_in_leaf=52.9; scale_pos_weight=7.68; path_smooth=81.6; top_k=15 : y = 0.93 : 58.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0338; num_leaves=1443; min_data_in_leaf=546; bagging_fraction=0.31; feature_fraction=0.533; lambda_l2=8.61; lambda_l1=2.16; min_gain_to_split=1; min_sum_hessian_in_leaf=52.6; scale_pos_weight=9.03; path_smooth=80.7; top_k=17 : y = 0.93 : 51.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0209; num_leaves=1373; min_data_in_leaf=564; bagging_fraction=0.426; feature_fraction=0.496; lambda_l2=8.22; lambda_l1=1.89; min_gain_to_split=0.863; min_sum_hessian_in_leaf=43.6; scale_pos_weight=8.76; path_smooth=87.6; top_k=14 : y = 0.93 : 61.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0344; num_leaves=1568; min_data_in_leaf=469; bagging_fraction=0.391; feature_fraction=0.484; lambda_l2=9.8; lambda_l1=1.6; min_gain_to_split=0.874; min_sum_hessian_in_leaf=51.9; scale_pos_weight=8.62; path_smooth=89.9; top_k=19 : y = 0.93 : 51.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0282; num_leaves=1320; min_data_in_leaf=595; bagging_fraction=0.474; feature_fraction=0.513; lambda_l2=9.53; lambda_l1=2.35; min_gain_to_split=0.837; min_sum_hessian_in_leaf=55.3; scale_pos_weight=7.79; path_smooth=85; top_k=14 : y = 0.93 : 54.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0224; num_leaves=1524; min_data_in_leaf=575; bagging_fraction=0.463; feature_fraction=0.543; lambda_l2=8.44; lambda_l1=1.13; min_gain_to_split=0.926; min_sum_hessian_in_leaf=41.4; scale_pos_weight=7.55; path_smooth=94.4; top_k=16 : y = 0.93 : 62.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0316; num_leaves=1352; min_data_in_leaf=524; bagging_fraction=0.338; feature_fraction=0.494; lambda_l2=9.68; lambda_l1=2.48; min_gain_to_split=1.1; min_sum_hessian_in_leaf=54.8; scale_pos_weight=8.25; path_smooth=93.8; top_k=20 : y = 0.93 : 51.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0201; num_leaves=1376; min_data_in_leaf=444; bagging_fraction=0.451; feature_fraction=0.546; lambda_l2=8.65; lambda_l1=2.34; min_gain_to_split=1.04; min_sum_hessian_in_leaf=59.3; scale_pos_weight=9.4; path_smooth=92.4; top_k=17 : y = 0.93 : 60.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0303; num_leaves=1540; min_data_in_leaf=562; bagging_fraction=0.384; feature_fraction=0.482; lambda_l2=8.19; lambda_l1=1.07; min_gain_to_split=0.85; min_sum_hessian_in_leaf=40.6; scale_pos_weight=9.26; path_smooth=89.1; top_k=20 : y = 0.93 : 56.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0342; num_leaves=1407; min_data_in_leaf=587; bagging_fraction=0.482; feature_fraction=0.544; lambda_l2=8.08; lambda_l1=2.21; min_gain_to_split=0.831; min_sum_hessian_in_leaf=41.7; scale_pos_weight=7.62; path_smooth=80.2; top_k=19 : y = 0.93 : 51.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.033; num_leaves=1331; min_data_in_leaf=527; bagging_fraction=0.418; feature_fraction=0.528; lambda_l2=9.06; lambda_l1=1.1; min_gain_to_split=0.891; min_sum_hessian_in_leaf=56.1; scale_pos_weight=8.89; path_smooth=94.7; top_k=16 : y = 0.931 : 54.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0312; num_leaves=1303; min_data_in_leaf=418; bagging_fraction=0.458; feature_fraction=0.55; lambda_l2=9.73; lambda_l1=2.47; min_gain_to_split=1.16; min_sum_hessian_in_leaf=41; scale_pos_weight=7.99; path_smooth=93.3; top_k=19 : y = 0.931 : 50.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0235; num_leaves=1582; min_data_in_leaf=599; bagging_fraction=0.369; feature_fraction=0.527; lambda_l2=10; lambda_l1=1.23; min_gain_to_split=1.12; min_sum_hessian_in_leaf=42.1; scale_pos_weight=8.55; path_smooth=85.4; top_k=15 : y = 0.93 : 57.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0326; num_leaves=1328; min_data_in_leaf=541; bagging_fraction=0.334; feature_fraction=0.501; lambda_l2=9.95; lambda_l1=1.52; min_gain_to_split=0.881; min_sum_hessian_in_leaf=42.7; scale_pos_weight=7.8; path_smooth=82.7; top_k=18 : y = 0.93 : 51.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0309; num_leaves=1590; min_data_in_leaf=499; bagging_fraction=0.496; feature_fraction=0.548; lambda_l2=9.66; lambda_l1=1.05; min_gain_to_split=1.15; min_sum_hessian_in_leaf=56.3; scale_pos_weight=7.52; path_smooth=86.6; top_k=20 : y = 0.93 : 50.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.027; num_leaves=1474; min_data_in_leaf=404; bagging_fraction=0.448; feature_fraction=0.481; lambda_l2=9.45; lambda_l1=2.42; min_gain_to_split=0.818; min_sum_hessian_in_leaf=59.1; scale_pos_weight=9.37; path_smooth=93; top_k=14 : y = 0.93 : 57.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0209; num_leaves=1312; min_data_in_leaf=406; bagging_fraction=0.434; feature_fraction=0.523; lambda_l2=9.33; lambda_l1=1.3; min_gain_to_split=1.13; min_sum_hessian_in_leaf=45.1; scale_pos_weight=7.63; path_smooth=88.4; top_k=14 : y = 0.929 : 63.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0324; num_leaves=1414; min_data_in_leaf=576; bagging_fraction=0.469; feature_fraction=0.52; lambda_l2=8.41; lambda_l1=2.28; min_gain_to_split=1.17; min_sum_hessian_in_leaf=44.1; scale_pos_weight=9.13; path_smooth=91.3; top_k=16 : y = 0.931 : 51.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0245; num_leaves=1561; min_data_in_leaf=425; bagging_fraction=0.354; feature_fraction=0.529; lambda_l2=8.52; lambda_l1=1.56; min_gain_to_split=0.898; min_sum_hessian_in_leaf=54; scale_pos_weight=8.74; path_smooth=82.2; top_k=20 : y = 0.93 : 60.1 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Tue Jul 29 14:44:04 2025 AUC 0.930194709877168
#
# [mbo] 1: learning_rate=0.0269; num_leaves=1517; min_data_in_leaf=581; bagging_fraction=0.411; feature_fraction=0.516; lambda_l2=8.99; lambda_l1=1.92; min_gain_to_split=0.833; min_sum_hessian_in_leaf=56.4; scale_pos_weight=9.25; path_smooth=93.9; top_k=18 : y = 0.93 : 59.2 secs : infill_ei
#
# Tue Jul 29 14:45:00 2025 AUC 0.930517301044146
#
# [mbo] 2: learning_rate=0.0291; num_leaves=1337; min_data_in_leaf=532; bagging_fraction=0.419; feature_fraction=0.528; lambda_l2=8.19; lambda_l1=1.06; min_gain_to_split=0.893; min_sum_hessian_in_leaf=56.9; scale_pos_weight=8.57; path_smooth=89.4; top_k=16 : y = 0.931 : 55.4 secs : infill_ei
#
# Tue Jul 29 14:46:03 2025 AUC 0.930641519470837
#
# [mbo] 3: learning_rate=0.0234; num_leaves=1525; min_data_in_leaf=556; bagging_fraction=0.421; feature_fraction=0.51; lambda_l2=8.78; lambda_l1=1.91; min_gain_to_split=0.814; min_sum_hessian_in_leaf=51.3; scale_pos_weight=8.32; path_smooth=89.5; top_k=17 : y = 0.931 : 61.5 secs : infill_ei
#
# Tue Jul 29 14:47:02 2025 AUC 0.929224711150424
#
# [mbo] 4: learning_rate=0.0247; num_leaves=1534; min_data_in_leaf=505; bagging_fraction=0.447; feature_fraction=0.511; lambda_l2=8.9; lambda_l1=1.74; min_gain_to_split=0.972; min_sum_hessian_in_leaf=54.7; scale_pos_weight=8.69; path_smooth=93.1; top_k=17 : y = 0.929 : 58.7 secs : infill_ei
#
# Tue Jul 29 14:47:58 2025 AUC 0.930213645349942
#
# [mbo] 5: learning_rate=0.0258; num_leaves=1534; min_data_in_leaf=571; bagging_fraction=0.406; feature_fraction=0.535; lambda_l2=9.52; lambda_l1=1.48; min_gain_to_split=0.996; min_sum_hessian_in_leaf=56.2; scale_pos_weight=8.49; path_smooth=92.9; top_k=17 : y = 0.93 : 54.6 secs : infill_ei
#
# Tue Jul 29 14:48:50 2025 AUC 0.929612012190139
#
# [mbo] 6: learning_rate=0.0318; num_leaves=1398; min_data_in_leaf=463; bagging_fraction=0.463; feature_fraction=0.518; lambda_l2=9.13; lambda_l1=2.3; min_gain_to_split=1.17; min_sum_hessian_in_leaf=42.6; scale_pos_weight=8.85; path_smooth=90.8; top_k=17 : y = 0.93 : 51.9 secs : infill_ei
#
# Tue Jul 29 14:49:46 2025 AUC 0.930624782684589
#
# [mbo] 7: learning_rate=0.0261; num_leaves=1527; min_data_in_leaf=579; bagging_fraction=0.364; feature_fraction=0.511; lambda_l2=8.6; lambda_l1=1.27; min_gain_to_split=1.13; min_sum_hessian_in_leaf=54.8; scale_pos_weight=8.01; path_smooth=91.7; top_k=15 : y = 0.931 : 54.2 secs : infill_ei
#
# Tue Jul 29 14:50:47 2025 AUC 0.929447167670461
#
# [mbo] 8: learning_rate=0.0225; num_leaves=1523; min_data_in_leaf=582; bagging_fraction=0.452; feature_fraction=0.546; lambda_l2=8.99; lambda_l1=1.28; min_gain_to_split=1.02; min_sum_hessian_in_leaf=54.4; scale_pos_weight=8.06; path_smooth=86.1; top_k=18 : y = 0.929 : 60.1 secs : infill_ei
#
# Tue Jul 29 14:51:47 2025 AUC 0.92856730416518
#
# [mbo] 9: learning_rate=0.021; num_leaves=1350; min_data_in_leaf=565; bagging_fraction=0.395; feature_fraction=0.511; lambda_l2=8.71; lambda_l1=1.95; min_gain_to_split=1.09; min_sum_hessian_in_leaf=59.2; scale_pos_weight=8.26; path_smooth=84.5; top_k=17 : y = 0.929 : 59.4 secs : infill_ei
#
# Tue Jul 29 14:52:50 2025 AUC 0.929404357485766
#
# [mbo] 10: learning_rate=0.0228; num_leaves=1467; min_data_in_leaf=574; bagging_fraction=0.375; feature_fraction=0.516; lambda_l2=9.05; lambda_l1=1.41; min_gain_to_split=0.821; min_sum_hessian_in_leaf=53.3; scale_pos_weight=8.43; path_smooth=91.4; top_k=18 : y = 0.929 : 61.7 secs : infill_ei
#
# Tue Jul 29 14:53:46 2025 AUC 0.929917289459438
#
# [mbo] 11: learning_rate=0.0282; num_leaves=1523; min_data_in_leaf=509; bagging_fraction=0.394; feature_fraction=0.483; lambda_l2=8.52; lambda_l1=1.49; min_gain_to_split=0.851; min_sum_hessian_in_leaf=47.9; scale_pos_weight=9.02; path_smooth=89.5; top_k=18 : y = 0.93 : 55.4 secs : infill_ei
#
# Saved the current state after iteration 12 in the file bayesiana.RDATA.
#
# Tue Jul 29 14:54:48 2025 AUC 0.929490576570979
#
# [mbo] 12: learning_rate=0.0216; num_leaves=1537; min_data_in_leaf=582; bagging_fraction=0.404; feature_fraction=0.546; lambda_l2=9.02; lambda_l1=1.49; min_gain_to_split=0.952; min_sum_hessian_in_leaf=56.3; scale_pos_weight=7.93; path_smooth=93.8; top_k=18 : y = 0.929 : 57.4 secs : infill_ei
#
# Tue Jul 29 14:55:48 2025 AUC 0.929878316722888
#
# [mbo] 13: learning_rate=0.0231; num_leaves=1527; min_data_in_leaf=539; bagging_fraction=0.358; feature_fraction=0.511; lambda_l2=8.59; lambda_l1=2.3; min_gain_to_split=0.815; min_sum_hessian_in_leaf=46; scale_pos_weight=8.21; path_smooth=86.2; top_k=19 : y = 0.93 : 59.4 secs : infill_ei
#
# Tue Jul 29 14:56:45 2025 AUC 0.930111556941934
#
# [mbo] 14: learning_rate=0.0242; num_leaves=1449; min_data_in_leaf=478; bagging_fraction=0.438; feature_fraction=0.511; lambda_l2=9.01; lambda_l1=1.71; min_gain_to_split=0.975; min_sum_hessian_in_leaf=54.5; scale_pos_weight=9.06; path_smooth=91.9; top_k=18 : y = 0.93 : 55.9 secs : infill_ei
#
# Tue Jul 29 14:57:43 2025 AUC 0.93092386520189
#
# [mbo] 15: learning_rate=0.0221; num_leaves=1552; min_data_in_leaf=572; bagging_fraction=0.488; feature_fraction=0.53; lambda_l2=8.85; lambda_l1=1.47; min_gain_to_split=1.1; min_sum_hessian_in_leaf=48.9; scale_pos_weight=8.96; path_smooth=94; top_k=17 : y = 0.931 : 57.0 secs : infill_ei
#
# Tue Jul 29 14:58:41 2025 AUC 0.929869318037144
#
# [mbo] 16: learning_rate=0.0238; num_leaves=1469; min_data_in_leaf=473; bagging_fraction=0.32; feature_fraction=0.511; lambda_l2=8.27; lambda_l1=1.4; min_gain_to_split=0.94; min_sum_hessian_in_leaf=58.3; scale_pos_weight=7.68; path_smooth=81.3; top_k=19 : y = 0.93 : 57.8 secs : infill_ei
#
# Tue Jul 29 14:59:36 2025 AUC 0.930131904245287
#
# [mbo] 17: learning_rate=0.0315; num_leaves=1555; min_data_in_leaf=506; bagging_fraction=0.419; feature_fraction=0.5; lambda_l2=8.78; lambda_l1=2.32; min_gain_to_split=0.809; min_sum_hessian_in_leaf=54.5; scale_pos_weight=8.48; path_smooth=84.5; top_k=18 : y = 0.93 : 53.8 secs : infill_ei
#
# Tue Jul 29 15:00:43 2025 AUC 0.930276439074874
#
# [mbo] 18: learning_rate=0.0205; num_leaves=1478; min_data_in_leaf=434; bagging_fraction=0.43; feature_fraction=0.535; lambda_l2=8.39; lambda_l1=2.23; min_gain_to_split=0.939; min_sum_hessian_in_leaf=47; scale_pos_weight=8.4; path_smooth=88; top_k=18 : y = 0.93 : 66.6 secs : infill_ei
#
# Tue Jul 29 15:01:45 2025 AUC 0.92969581958018
#
# [mbo] 19: learning_rate=0.0219; num_leaves=1529; min_data_in_leaf=482; bagging_fraction=0.483; feature_fraction=0.504; lambda_l2=8.81; lambda_l1=1.94; min_gain_to_split=0.95; min_sum_hessian_in_leaf=49.9; scale_pos_weight=8.47; path_smooth=92.1; top_k=18 : y = 0.93 : 61.2 secs : infill_ei
#
# Tue Jul 29 15:02:42 2025 AUC 0.930411702493574
#
# [mbo] 20: learning_rate=0.0264; num_leaves=1492; min_data_in_leaf=452; bagging_fraction=0.334; feature_fraction=0.548; lambda_l2=9.68; lambda_l1=1.51; min_gain_to_split=0.971; min_sum_hessian_in_leaf=46; scale_pos_weight=8.11; path_smooth=92.3; top_k=20 : y = 0.93 : 55.9 secs : infill_ei
#
# Tue Jul 29 15:03:37 2025 AUC 0.930127535090618
#
# [mbo] 21: learning_rate=0.0281; num_leaves=1307; min_data_in_leaf=427; bagging_fraction=0.417; feature_fraction=0.531; lambda_l2=9.71; lambda_l1=2.47; min_gain_to_split=1.15; min_sum_hessian_in_leaf=54.1; scale_pos_weight=8.1; path_smooth=86.9; top_k=19 : y = 0.93 : 53.5 secs : infill_ei
#
# Tue Jul 29 15:04:35 2025 AUC 0.930218623111141
#
# [mbo] 22: learning_rate=0.0252; num_leaves=1573; min_data_in_leaf=586; bagging_fraction=0.388; feature_fraction=0.487; lambda_l2=9.07; lambda_l1=1.97; min_gain_to_split=0.856; min_sum_hessian_in_leaf=51.3; scale_pos_weight=8.24; path_smooth=93.7; top_k=15 : y = 0.93 : 58.0 secs : infill_ei
#
# Saved the current state after iteration 23 in the file bayesiana.RDATA.
#
# Tue Jul 29 15:05:35 2025 AUC 0.930705827627313
#
# [mbo] 23: learning_rate=0.0335; num_leaves=1528; min_data_in_leaf=560; bagging_fraction=0.405; feature_fraction=0.528; lambda_l2=9.62; lambda_l1=1.03; min_gain_to_split=0.898; min_sum_hessian_in_leaf=46.7; scale_pos_weight=8.88; path_smooth=94.7; top_k=16 : y = 0.931 : 55.8 secs : infill_ei
#
# Tue Jul 29 15:06:30 2025 AUC 0.930191610672471
#
# [mbo] 24: learning_rate=0.0284; num_leaves=1400; min_data_in_leaf=587; bagging_fraction=0.388; feature_fraction=0.549; lambda_l2=9.5; lambda_l1=2.38; min_gain_to_split=0.836; min_sum_hessian_in_leaf=46.9; scale_pos_weight=7.97; path_smooth=87; top_k=16 : y = 0.93 : 53.4 secs : infill_ei
#
# Tue Jul 29 15:07:23 2025 AUC 0.930483253288095
#
# [mbo] 25: learning_rate=0.0324; num_leaves=1550; min_data_in_leaf=546; bagging_fraction=0.48; feature_fraction=0.54; lambda_l2=9.06; lambda_l1=1.26; min_gain_to_split=0.89; min_sum_hessian_in_leaf=50.5; scale_pos_weight=8.95; path_smooth=85.3; top_k=17 : y = 0.93 : 52.6 secs : infill_ei
#
# Tue Jul 29 15:08:25 2025 AUC 0.929747163617393
#
# [mbo] 26: learning_rate=0.0221; num_leaves=1308; min_data_in_leaf=482; bagging_fraction=0.483; feature_fraction=0.501; lambda_l2=9.08; lambda_l1=1.18; min_gain_to_split=0.902; min_sum_hessian_in_leaf=44.2; scale_pos_weight=8.67; path_smooth=81.9; top_k=20 : y = 0.93 : 61.2 secs : infill_ei
#
# Tue Jul 29 15:09:20 2025 AUC 0.930194255825515
#
# [mbo] 27: learning_rate=0.0329; num_leaves=1486; min_data_in_leaf=492; bagging_fraction=0.45; feature_fraction=0.506; lambda_l2=8.4; lambda_l1=1.12; min_gain_to_split=0.886; min_sum_hessian_in_leaf=58; scale_pos_weight=8.89; path_smooth=92.5; top_k=16 : y = 0.93 : 53.7 secs : infill_ei
#
# Tue Jul 29 15:10:19 2025 AUC 0.930130494902697
#
# [mbo] 28: learning_rate=0.0232; num_leaves=1563; min_data_in_leaf=462; bagging_fraction=0.483; feature_fraction=0.55; lambda_l2=8.21; lambda_l1=2.38; min_gain_to_split=0.947; min_sum_hessian_in_leaf=54.7; scale_pos_weight=8.7; path_smooth=83.8; top_k=17 : y = 0.93 : 57.8 secs : infill_ei
#
# Tue Jul 29 15:11:19 2025 AUC 0.929987914480554
#
# [mbo] 29: learning_rate=0.0266; num_leaves=1390; min_data_in_leaf=468; bagging_fraction=0.468; feature_fraction=0.494; lambda_l2=9.42; lambda_l1=2.39; min_gain_to_split=0.868; min_sum_hessian_in_leaf=57.3; scale_pos_weight=8.15; path_smooth=86.7; top_k=14 : y = 0.93 : 59.2 secs : infill_ei
#
# Tue Jul 29 15:12:13 2025 AUC 0.93070500370589
#
# [mbo] 30: learning_rate=0.0278; num_leaves=1431; min_data_in_leaf=564; bagging_fraction=0.418; feature_fraction=0.527; lambda_l2=8.6; lambda_l1=1.1; min_gain_to_split=1.14; min_sum_hessian_in_leaf=57.8; scale_pos_weight=8.61; path_smooth=93.6; top_k=15 : y = 0.931 : 52.8 secs : infill_ei
#
# Tue Jul 29 15:13:02 2025 AUC 0.929700549862684
#
# [mbo] 31: learning_rate=0.0331; num_leaves=1443; min_data_in_leaf=441; bagging_fraction=0.364; feature_fraction=0.538; lambda_l2=9.47; lambda_l1=1.47; min_gain_to_split=1.12; min_sum_hessian_in_leaf=57.7; scale_pos_weight=8.89; path_smooth=91.5; top_k=16 : y = 0.93 : 48.9 secs : infill_ei
#
# Tue Jul 29 15:14:03 2025 AUC 0.929418892314712
#
# [mbo] 32: learning_rate=0.022; num_leaves=1465; min_data_in_leaf=566; bagging_fraction=0.472; feature_fraction=0.516; lambda_l2=8.74; lambda_l1=1.26; min_gain_to_split=0.933; min_sum_hessian_in_leaf=53.3; scale_pos_weight=8.52; path_smooth=83.2; top_k=20 : y = 0.929 : 59.7 secs : infill_ei
#
# Tue Jul 29 15:14:59 2025 AUC 0.929646670981956
#
# [mbo] 33: learning_rate=0.0235; num_leaves=1552; min_data_in_leaf=562; bagging_fraction=0.394; feature_fraction=0.498; lambda_l2=8.73; lambda_l1=2.32; min_gain_to_split=1.02; min_sum_hessian_in_leaf=56.6; scale_pos_weight=8.5; path_smooth=91.8; top_k=17 : y = 0.93 : 54.9 secs : infill_ei
#
# Saved the current state after iteration 34 in the file bayesiana.RDATA.
#
# Tue Jul 29 15:15:54 2025 AUC 0.929258727613114
#
# [mbo] 34: learning_rate=0.0333; num_leaves=1516; min_data_in_leaf=584; bagging_fraction=0.396; feature_fraction=0.511; lambda_l2=9.47; lambda_l1=2.28; min_gain_to_split=0.955; min_sum_hessian_in_leaf=56.7; scale_pos_weight=7.74; path_smooth=93.3; top_k=18 : y = 0.929 : 50.1 secs : infill_ei
#
# Tue Jul 29 15:16:53 2025 AUC 0.930337970306139
#
# [mbo] 35: learning_rate=0.0229; num_leaves=1510; min_data_in_leaf=568; bagging_fraction=0.499; feature_fraction=0.529; lambda_l2=8.82; lambda_l1=1.34; min_gain_to_split=0.939; min_sum_hessian_in_leaf=48.5; scale_pos_weight=7.59; path_smooth=92; top_k=18 : y = 0.93 : 57.7 secs : infill_ei
#
# Tue Jul 29 15:17:44 2025 AUC 0.929590244167372
#
# [mbo] 36: learning_rate=0.0345; num_leaves=1302; min_data_in_leaf=567; bagging_fraction=0.349; feature_fraction=0.491; lambda_l2=9.95; lambda_l1=2.48; min_gain_to_split=0.985; min_sum_hessian_in_leaf=46.5; scale_pos_weight=7.62; path_smooth=88.7; top_k=14 : y = 0.93 : 50.0 secs : infill_ei
#
# Tue Jul 29 15:18:36 2025 AUC 0.929891555707317
#
# [mbo] 37: learning_rate=0.0328; num_leaves=1389; min_data_in_leaf=513; bagging_fraction=0.373; feature_fraction=0.528; lambda_l2=9.81; lambda_l1=2.13; min_gain_to_split=0.953; min_sum_hessian_in_leaf=47.4; scale_pos_weight=8.99; path_smooth=94.7; top_k=17 : y = 0.93 : 50.7 secs : infill_ei
#
# Tue Jul 29 15:19:29 2025 AUC 0.930401363575499
#
# [mbo] 38: learning_rate=0.0324; num_leaves=1343; min_data_in_leaf=535; bagging_fraction=0.416; feature_fraction=0.49; lambda_l2=9.44; lambda_l1=1.2; min_gain_to_split=1.07; min_sum_hessian_in_leaf=56.2; scale_pos_weight=8.96; path_smooth=94.1; top_k=16 : y = 0.93 : 52.4 secs : infill_ei
#
# Tue Jul 29 15:20:28 2025 AUC 0.929868751431203
#
# [mbo] 39: learning_rate=0.0233; num_leaves=1303; min_data_in_leaf=451; bagging_fraction=0.307; feature_fraction=0.528; lambda_l2=8.87; lambda_l1=2.1; min_gain_to_split=1.18; min_sum_hessian_in_leaf=44.4; scale_pos_weight=7.75; path_smooth=84.1; top_k=15 : y = 0.93 : 57.5 secs : infill_ei
#
# Tue Jul 29 15:21:24 2025 AUC 0.929687535869264
#
# [mbo] 40: learning_rate=0.0332; num_leaves=1344; min_data_in_leaf=527; bagging_fraction=0.339; feature_fraction=0.527; lambda_l2=9.66; lambda_l1=1.38; min_gain_to_split=1.06; min_sum_hessian_in_leaf=51.9; scale_pos_weight=9.33; path_smooth=90.5; top_k=16 : y = 0.93 : 54.8 secs : infill_ei
#
# Tue Jul 29 15:22:27 2025 AUC 0.930214336364649
#
# [mbo] 41: learning_rate=0.0207; num_leaves=1581; min_data_in_leaf=495; bagging_fraction=0.488; feature_fraction=0.527; lambda_l2=8.64; lambda_l1=1.44; min_gain_to_split=0.887; min_sum_hessian_in_leaf=42; scale_pos_weight=9.07; path_smooth=91.9; top_k=17 : y = 0.93 : 62.5 secs : infill_ei
#
# Tue Jul 29 15:23:23 2025 AUC 0.931620458603575
#
# [mbo] 42: learning_rate=0.0235; num_leaves=1486; min_data_in_leaf=403; bagging_fraction=0.312; feature_fraction=0.528; lambda_l2=8.3; lambda_l1=2.41; min_gain_to_split=1.12; min_sum_hessian_in_leaf=55.3; scale_pos_weight=7.78; path_smooth=81.5; top_k=19 : y = 0.932 : 54.4 secs : infill_ei
#
# Tue Jul 29 15:24:21 2025 AUC 0.931228768661106
#
# [mbo] 43: learning_rate=0.0229; num_leaves=1388; min_data_in_leaf=401; bagging_fraction=0.356; feature_fraction=0.521; lambda_l2=8.3; lambda_l1=2.09; min_gain_to_split=1.05; min_sum_hessian_in_leaf=46; scale_pos_weight=7.64; path_smooth=84.3; top_k=19 : y = 0.931 : 57.1 secs : infill_ei
#
# Tue Jul 29 15:25:17 2025 AUC 0.930712837937314
#
# [mbo] 44: learning_rate=0.0287; num_leaves=1394; min_data_in_leaf=474; bagging_fraction=0.32; feature_fraction=0.518; lambda_l2=9.93; lambda_l1=1.36; min_gain_to_split=0.909; min_sum_hessian_in_leaf=41; scale_pos_weight=9.12; path_smooth=91.3; top_k=17 : y = 0.931 : 55.5 secs : infill_ei
#
# Saved the current state after iteration 45 in the file bayesiana.RDATA.
#
# Tue Jul 29 15:26:16 2025 AUC 0.930472920484052
#
# [mbo] 45: learning_rate=0.0271; num_leaves=1472; min_data_in_leaf=553; bagging_fraction=0.314; feature_fraction=0.525; lambda_l2=8.24; lambda_l1=1.73; min_gain_to_split=1.12; min_sum_hessian_in_leaf=54.2; scale_pos_weight=7.75; path_smooth=82.8; top_k=19 : y = 0.93 : 52.9 secs : infill_ei
#
# Tue Jul 29 15:27:08 2025 AUC 0.930148205032689
#
# [mbo] 46: learning_rate=0.0316; num_leaves=1431; min_data_in_leaf=446; bagging_fraction=0.352; feature_fraction=0.51; lambda_l2=8.3; lambda_l1=1.68; min_gain_to_split=1.03; min_sum_hessian_in_leaf=57.7; scale_pos_weight=8.18; path_smooth=90.1; top_k=19 : y = 0.93 : 51.1 secs : infill_ei
#
# Tue Jul 29 15:28:00 2025 AUC 0.929125679445277
#
# [mbo] 47: learning_rate=0.0311; num_leaves=1431; min_data_in_leaf=524; bagging_fraction=0.309; feature_fraction=0.547; lambda_l2=8.77; lambda_l1=1.69; min_gain_to_split=0.828; min_sum_hessian_in_leaf=52.3; scale_pos_weight=7.99; path_smooth=81.9; top_k=15 : y = 0.929 : 51.0 secs : infill_ei
#
# Tue Jul 29 15:28:51 2025 AUC 0.929117904916267
#
# [mbo] 48: learning_rate=0.031; num_leaves=1548; min_data_in_leaf=513; bagging_fraction=0.307; feature_fraction=0.534; lambda_l2=8.2; lambda_l1=1.46; min_gain_to_split=1.02; min_sum_hessian_in_leaf=56.6; scale_pos_weight=8.04; path_smooth=90.5; top_k=20 : y = 0.929 : 50.3 secs : infill_ei
#
# Tue Jul 29 15:29:47 2025 AUC 0.929946448850768
#
# [mbo] 49: learning_rate=0.0235; num_leaves=1501; min_data_in_leaf=445; bagging_fraction=0.379; feature_fraction=0.541; lambda_l2=9.08; lambda_l1=2.41; min_gain_to_split=1.13; min_sum_hessian_in_leaf=50.2; scale_pos_weight=9.17; path_smooth=81.8; top_k=19 : y = 0.93 : 55.2 secs : infill_ei
#
# Tue Jul 29 15:30:45 2025 AUC 0.929610332973528
#
# [mbo] 50: learning_rate=0.0242; num_leaves=1446; min_data_in_leaf=401; bagging_fraction=0.401; feature_fraction=0.524; lambda_l2=8.36; lambda_l1=2.31; min_gain_to_split=1.11; min_sum_hessian_in_leaf=56.2; scale_pos_weight=7.74; path_smooth=81.7; top_k=19 : y = 0.93 : 56.2 secs : infill_ei
#
# Tue Jul 29 15:31:44 2025 AUC 0.930853830466872
#
# [mbo] 51: learning_rate=0.0234; num_leaves=1403; min_data_in_leaf=404; bagging_fraction=0.337; feature_fraction=0.531; lambda_l2=9.45; lambda_l1=1.65; min_gain_to_split=1.11; min_sum_hessian_in_leaf=50.2; scale_pos_weight=7.89; path_smooth=81.5; top_k=16 : y = 0.931 : 57.9 secs : infill_ei
#
# Tue Jul 29 15:32:47 2025 AUC 0.930777025219955
#
# [mbo] 52: learning_rate=0.0239; num_leaves=1458; min_data_in_leaf=402; bagging_fraction=0.481; feature_fraction=0.522; lambda_l2=8.3; lambda_l1=2.17; min_gain_to_split=1.16; min_sum_hessian_in_leaf=46.8; scale_pos_weight=8.35; path_smooth=83.6; top_k=19 : y = 0.931 : 61.9 secs : infill_ei
#
# Tue Jul 29 15:33:48 2025 AUC 0.92954572849073
#
# [mbo] 53: learning_rate=0.0219; num_leaves=1525; min_data_in_leaf=447; bagging_fraction=0.339; feature_fraction=0.528; lambda_l2=8.32; lambda_l1=2.32; min_gain_to_split=1.1; min_sum_hessian_in_leaf=43.5; scale_pos_weight=7.6; path_smooth=81.5; top_k=18 : y = 0.93 : 59.3 secs : infill_ei
#
# Tue Jul 29 15:34:49 2025 AUC 0.9305331005684
#
# [mbo] 54: learning_rate=0.0218; num_leaves=1482; min_data_in_leaf=420; bagging_fraction=0.356; feature_fraction=0.484; lambda_l2=9.47; lambda_l1=1.92; min_gain_to_split=1.12; min_sum_hessian_in_leaf=46.2; scale_pos_weight=7.67; path_smooth=84.3; top_k=19 : y = 0.931 : 59.2 secs : infill_ei
#
# Tue Jul 29 15:35:54 2025 AUC 0.929887597821654
#
# [mbo] 55: learning_rate=0.0224; num_leaves=1526; min_data_in_leaf=591; bagging_fraction=0.381; feature_fraction=0.531; lambda_l2=8.99; lambda_l1=1.45; min_gain_to_split=0.903; min_sum_hessian_in_leaf=57.1; scale_pos_weight=8.49; path_smooth=91.9; top_k=18 : y = 0.93 : 64.4 secs : infill_ei
#
# Saved the current state after iteration 56 in the file bayesiana.RDATA.
#
# Tue Jul 29 15:36:59 2025 AUC 0.930082551689955
#
# [mbo] 56: learning_rate=0.0224; num_leaves=1456; min_data_in_leaf=405; bagging_fraction=0.313; feature_fraction=0.491; lambda_l2=8.95; lambda_l1=2.4; min_gain_to_split=1.13; min_sum_hessian_in_leaf=50.4; scale_pos_weight=7.76; path_smooth=82; top_k=19 : y = 0.93 : 59.0 secs : infill_ei
#
# Tue Jul 29 15:37:54 2025 AUC 0.930256860866419
#
# [mbo] 57: learning_rate=0.0288; num_leaves=1563; min_data_in_leaf=486; bagging_fraction=0.401; feature_fraction=0.515; lambda_l2=9.99; lambda_l1=1.24; min_gain_to_split=1.07; min_sum_hessian_in_leaf=57.5; scale_pos_weight=8.19; path_smooth=80.7; top_k=18 : y = 0.93 : 54.0 secs : infill_ei
#
# Tue Jul 29 15:38:51 2025 AUC 0.930216039690006
#
# [mbo] 58: learning_rate=0.0274; num_leaves=1556; min_data_in_leaf=481; bagging_fraction=0.313; feature_fraction=0.496; lambda_l2=8.48; lambda_l1=2.41; min_gain_to_split=0.874; min_sum_hessian_in_leaf=55.3; scale_pos_weight=8.31; path_smooth=83.7; top_k=19 : y = 0.93 : 55.2 secs : infill_ei
#
# Tue Jul 29 15:39:48 2025 AUC 0.930713510279842
#
# [mbo] 59: learning_rate=0.0257; num_leaves=1470; min_data_in_leaf=431; bagging_fraction=0.343; feature_fraction=0.507; lambda_l2=9.3; lambda_l1=2.3; min_gain_to_split=0.907; min_sum_hessian_in_leaf=51.1; scale_pos_weight=8.11; path_smooth=83.1; top_k=16 : y = 0.931 : 56.4 secs : infill_ei
#
# Tue Jul 29 15:40:45 2025 AUC 0.929675483046663
#
# [mbo] 60: learning_rate=0.0248; num_leaves=1485; min_data_in_leaf=422; bagging_fraction=0.392; feature_fraction=0.489; lambda_l2=9.93; lambda_l1=1.1; min_gain_to_split=1.19; min_sum_hessian_in_leaf=55.3; scale_pos_weight=7.58; path_smooth=81.3; top_k=16 : y = 0.93 : 56.0 secs : infill_ei
#
# Tue Jul 29 15:41:44 2025 AUC 0.930726328034009
#
# [mbo] 61: learning_rate=0.0224; num_leaves=1324; min_data_in_leaf=437; bagging_fraction=0.369; feature_fraction=0.481; lambda_l2=9.23; lambda_l1=1.99; min_gain_to_split=1.15; min_sum_hessian_in_leaf=57.1; scale_pos_weight=8.26; path_smooth=85.7; top_k=14 : y = 0.931 : 57.2 secs : infill_ei
#
# Tue Jul 29 15:42:44 2025 AUC 0.928964404855286
#
# [mbo] 62: learning_rate=0.0217; num_leaves=1576; min_data_in_leaf=496; bagging_fraction=0.496; feature_fraction=0.537; lambda_l2=8.33; lambda_l1=1.29; min_gain_to_split=0.992; min_sum_hessian_in_leaf=52; scale_pos_weight=7.66; path_smooth=90.9; top_k=18 : y = 0.929 : 59.2 secs : infill_ei
#
# Tue Jul 29 15:43:35 2025 AUC 0.930116605826284
#
# [mbo] 63: learning_rate=0.0313; num_leaves=1522; min_data_in_leaf=473; bagging_fraction=0.351; feature_fraction=0.524; lambda_l2=8.03; lambda_l1=2.41; min_gain_to_split=1.06; min_sum_hessian_in_leaf=55.3; scale_pos_weight=7.79; path_smooth=84.5; top_k=16 : y = 0.93 : 49.9 secs : infill_ei
#
# Tue Jul 29 15:44:28 2025 AUC 0.929759292886918
#
# [mbo] 64: learning_rate=0.0295; num_leaves=1468; min_data_in_leaf=587; bagging_fraction=0.366; feature_fraction=0.523; lambda_l2=9.44; lambda_l1=1.08; min_gain_to_split=1.14; min_sum_hessian_in_leaf=51; scale_pos_weight=8.55; path_smooth=93.3; top_k=20 : y = 0.93 : 51.7 secs : infill_ei
#
# Tue Jul 29 15:45:26 2025 AUC 0.92975131939229
#
# [mbo] 65: learning_rate=0.0229; num_leaves=1387; min_data_in_leaf=448; bagging_fraction=0.428; feature_fraction=0.539; lambda_l2=8.03; lambda_l1=1.66; min_gain_to_split=1.03; min_sum_hessian_in_leaf=47.9; scale_pos_weight=7.61; path_smooth=82.1; top_k=16 : y = 0.93 : 57.2 secs : infill_ei
#
# Tue Jul 29 15:46:26 2025 AUC 0.930278423684477
#
# [mbo] 66: learning_rate=0.0235; num_leaves=1540; min_data_in_leaf=429; bagging_fraction=0.392; feature_fraction=0.515; lambda_l2=9.61; lambda_l1=1.52; min_gain_to_split=1.15; min_sum_hessian_in_leaf=41.2; scale_pos_weight=9.48; path_smooth=83.3; top_k=14 : y = 0.93 : 58.2 secs : infill_ei
#
# Saved the current state after iteration 67 in the file bayesiana.RDATA.
#
# Tue Jul 29 15:47:25 2025 AUC 0.930068857572756
#
# [mbo] 67: learning_rate=0.0248; num_leaves=1487; min_data_in_leaf=542; bagging_fraction=0.313; feature_fraction=0.524; lambda_l2=8.31; lambda_l1=2.13; min_gain_to_split=1.13; min_sum_hessian_in_leaf=52.1; scale_pos_weight=8.24; path_smooth=81.7; top_k=19 : y = 0.93 : 53.8 secs : infill_ei
#
# Tue Jul 29 15:48:24 2025 AUC 0.929666011719133
#
# [mbo] 68: learning_rate=0.0215; num_leaves=1341; min_data_in_leaf=461; bagging_fraction=0.313; feature_fraction=0.529; lambda_l2=8.88; lambda_l1=2.41; min_gain_to_split=1.07; min_sum_hessian_in_leaf=49.4; scale_pos_weight=8.87; path_smooth=82.4; top_k=19 : y = 0.93 : 58.0 secs : infill_ei
#
# Tue Jul 29 15:49:23 2025 AUC 0.92885719705589
#
# [mbo] 69: learning_rate=0.0226; num_leaves=1426; min_data_in_leaf=597; bagging_fraction=0.432; feature_fraction=0.482; lambda_l2=9.01; lambda_l1=2.41; min_gain_to_split=0.972; min_sum_hessian_in_leaf=56.8; scale_pos_weight=8.71; path_smooth=85.8; top_k=14 : y = 0.929 : 57.7 secs : infill_ei
#
# Tue Jul 29 15:50:19 2025 AUC 0.930654447511196
#
# [mbo] 70: learning_rate=0.0273; num_leaves=1371; min_data_in_leaf=492; bagging_fraction=0.397; feature_fraction=0.513; lambda_l2=9.93; lambda_l1=1.6; min_gain_to_split=1.05; min_sum_hessian_in_leaf=52.4; scale_pos_weight=8.39; path_smooth=90.3; top_k=18 : y = 0.931 : 54.6 secs : infill_ei
#
# Tue Jul 29 15:51:20 2025 AUC 0.930472910537651
#
# [mbo] 71: learning_rate=0.0235; num_leaves=1345; min_data_in_leaf=407; bagging_fraction=0.313; feature_fraction=0.512; lambda_l2=8.49; lambda_l1=2.41; min_gain_to_split=0.916; min_sum_hessian_in_leaf=54.9; scale_pos_weight=7.62; path_smooth=80.3; top_k=17 : y = 0.93 : 59.9 secs : infill_ei
#
# Tue Jul 29 15:52:19 2025 AUC 0.930887075652906
#
# [mbo] 72: learning_rate=0.0218; num_leaves=1481; min_data_in_leaf=434; bagging_fraction=0.312; feature_fraction=0.482; lambda_l2=8.5; lambda_l1=1.61; min_gain_to_split=1.12; min_sum_hessian_in_leaf=55.3; scale_pos_weight=8.78; path_smooth=83.5; top_k=19 : y = 0.931 : 57.5 secs : infill_ei
#
# Tue Jul 29 15:53:12 2025 AUC 0.930028738845424
#
# [mbo] 73: learning_rate=0.0251; num_leaves=1383; min_data_in_leaf=450; bagging_fraction=0.329; feature_fraction=0.55; lambda_l2=9.89; lambda_l1=2.01; min_gain_to_split=1.12; min_sum_hessian_in_leaf=43.8; scale_pos_weight=7.53; path_smooth=90; top_k=18 : y = 0.93 : 51.6 secs : infill_ei
#
# Tue Jul 29 15:54:11 2025 AUC 0.93034786173424
#
# [mbo] 74: learning_rate=0.0221; num_leaves=1500; min_data_in_leaf=514; bagging_fraction=0.453; feature_fraction=0.513; lambda_l2=8.16; lambda_l1=1.14; min_gain_to_split=1.16; min_sum_hessian_in_leaf=40.5; scale_pos_weight=8.88; path_smooth=90.5; top_k=14 : y = 0.93 : 58.1 secs : infill_ei
#
# Tue Jul 29 15:55:10 2025 AUC 0.929696172838204
#
# [mbo] 75: learning_rate=0.0218; num_leaves=1456; min_data_in_leaf=454; bagging_fraction=0.452; feature_fraction=0.538; lambda_l2=8.5; lambda_l1=1.86; min_gain_to_split=1.04; min_sum_hessian_in_leaf=51.6; scale_pos_weight=7.86; path_smooth=85.8; top_k=19 : y = 0.93 : 57.7 secs : infill_ei
#
# Tue Jul 29 15:56:08 2025 AUC 0.930352946327514
#
# [mbo] 76: learning_rate=0.0226; num_leaves=1493; min_data_in_leaf=403; bagging_fraction=0.303; feature_fraction=0.546; lambda_l2=8.04; lambda_l1=2.07; min_gain_to_split=1.06; min_sum_hessian_in_leaf=58.5; scale_pos_weight=7.54; path_smooth=82.1; top_k=18 : y = 0.93 : 57.5 secs : infill_ei
#
# Tue Jul 29 15:57:05 2025 AUC 0.929392048649197
#
# [mbo] 77: learning_rate=0.0252; num_leaves=1471; min_data_in_leaf=404; bagging_fraction=0.313; feature_fraction=0.509; lambda_l2=9.44; lambda_l1=1.89; min_gain_to_split=1.1; min_sum_hessian_in_leaf=56.2; scale_pos_weight=7.78; path_smooth=80.4; top_k=19 : y = 0.929 : 55.5 secs : infill_ei
#
# Saved the current state after iteration 78 in the file bayesiana.RDATA.
#
# Tue Jul 29 15:58:03 2025 AUC 0.929964737416096
#
# [mbo] 78: learning_rate=0.0312; num_leaves=1329; min_data_in_leaf=590; bagging_fraction=0.341; feature_fraction=0.546; lambda_l2=8.89; lambda_l1=1.61; min_gain_to_split=0.845; min_sum_hessian_in_leaf=53.2; scale_pos_weight=8.39; path_smooth=91.3; top_k=16 : y = 0.93 : 51.1 secs : infill_ei
#
# Tue Jul 29 15:58:58 2025 AUC 0.930207131235912
#
# [mbo] 79: learning_rate=0.0234; num_leaves=1398; min_data_in_leaf=464; bagging_fraction=0.311; feature_fraction=0.546; lambda_l2=8.67; lambda_l1=2.32; min_gain_to_split=1.12; min_sum_hessian_in_leaf=54.5; scale_pos_weight=7.8; path_smooth=80.6; top_k=20 : y = 0.93 : 53.4 secs : infill_ei
#
# Tue Jul 29 15:59:57 2025 AUC 0.928949813841224
#
# [mbo] 80: learning_rate=0.0224; num_leaves=1528; min_data_in_leaf=475; bagging_fraction=0.335; feature_fraction=0.507; lambda_l2=8.95; lambda_l1=1.53; min_gain_to_split=0.939; min_sum_hessian_in_leaf=57.4; scale_pos_weight=8.11; path_smooth=88; top_k=18 : y = 0.929 : 57.1 secs : infill_ei
#
# Tue Jul 29 16:00:59 2025 AUC 0.930229195345405
#
# [mbo] 81: learning_rate=0.0237; num_leaves=1499; min_data_in_leaf=403; bagging_fraction=0.362; feature_fraction=0.528; lambda_l2=8.39; lambda_l1=2.43; min_gain_to_split=1.07; min_sum_hessian_in_leaf=55.5; scale_pos_weight=8.88; path_smooth=81.4; top_k=17 : y = 0.93 : 61.3 secs : infill_ei
#
# Tue Jul 29 16:01:57 2025 AUC 0.930352041302154
#
# [mbo] 82: learning_rate=0.0245; num_leaves=1314; min_data_in_leaf=449; bagging_fraction=0.415; feature_fraction=0.487; lambda_l2=9.69; lambda_l1=1.89; min_gain_to_split=0.992; min_sum_hessian_in_leaf=57.8; scale_pos_weight=8.09; path_smooth=88.3; top_k=19 : y = 0.93 : 56.8 secs : infill_ei
#
# Tue Jul 29 16:02:56 2025 AUC 0.930651232996282
#
# [mbo] 83: learning_rate=0.0235; num_leaves=1487; min_data_in_leaf=403; bagging_fraction=0.436; feature_fraction=0.494; lambda_l2=8.46; lambda_l1=2.41; min_gain_to_split=0.945; min_sum_hessian_in_leaf=55.6; scale_pos_weight=8.88; path_smooth=85.3; top_k=19 : y = 0.931 : 58.2 secs : infill_ei
#
# Tue Jul 29 16:03:50 2025 AUC 0.930475803556952
#
# [mbo] 84: learning_rate=0.0317; num_leaves=1437; min_data_in_leaf=438; bagging_fraction=0.488; feature_fraction=0.523; lambda_l2=9.47; lambda_l1=1.41; min_gain_to_split=1.08; min_sum_hessian_in_leaf=50.5; scale_pos_weight=7.77; path_smooth=90.9; top_k=15 : y = 0.93 : 52.1 secs : infill_ei
#
# Tue Jul 29 16:04:51 2025 AUC 0.929645424337081
#
# [mbo] 85: learning_rate=0.0208; num_leaves=1578; min_data_in_leaf=517; bagging_fraction=0.346; feature_fraction=0.514; lambda_l2=8.83; lambda_l1=1.52; min_gain_to_split=1.09; min_sum_hessian_in_leaf=56; scale_pos_weight=7.83; path_smooth=86.5; top_k=18 : y = 0.93 : 59.5 secs : infill_ei
#
# Tue Jul 29 16:05:44 2025 AUC 0.930469488604626
#
# [mbo] 86: learning_rate=0.0317; num_leaves=1493; min_data_in_leaf=419; bagging_fraction=0.313; feature_fraction=0.515; lambda_l2=9.91; lambda_l1=2.05; min_gain_to_split=1.14; min_sum_hessian_in_leaf=55.2; scale_pos_weight=7.71; path_smooth=84.2; top_k=19 : y = 0.93 : 51.4 secs : infill_ei
#
# Tue Jul 29 16:06:45 2025 AUC 0.929968812682415
#
# [mbo] 87: learning_rate=0.0233; num_leaves=1388; min_data_in_leaf=400; bagging_fraction=0.339; feature_fraction=0.522; lambda_l2=8.63; lambda_l1=2.32; min_gain_to_split=0.906; min_sum_hessian_in_leaf=41.2; scale_pos_weight=8.19; path_smooth=80.6; top_k=18 : y = 0.93 : 58.8 secs : infill_ei
#
# Tue Jul 29 16:07:46 2025 AUC 0.929187868347272
#
# [mbo] 88: learning_rate=0.0202; num_leaves=1419; min_data_in_leaf=424; bagging_fraction=0.324; feature_fraction=0.542; lambda_l2=8.27; lambda_l1=1.78; min_gain_to_split=1.13; min_sum_hessian_in_leaf=59.3; scale_pos_weight=8.04; path_smooth=85.6; top_k=17 : y = 0.929 : 59.6 secs : infill_ei
#
# Saved the current state after iteration 89 in the file bayesiana.RDATA.
#
# Tue Jul 29 16:08:43 2025 AUC 0.930622036513059
#
# [mbo] 89: learning_rate=0.0313; num_leaves=1484; min_data_in_leaf=401; bagging_fraction=0.351; feature_fraction=0.528; lambda_l2=8.27; lambda_l1=1.44; min_gain_to_split=1.12; min_sum_hessian_in_leaf=53.7; scale_pos_weight=7.92; path_smooth=82.2; top_k=19 : y = 0.931 : 52.0 secs : infill_ei
#
# Tue Jul 29 16:09:43 2025 AUC 0.930171116403881
#
# [mbo] 90: learning_rate=0.0253; num_leaves=1325; min_data_in_leaf=405; bagging_fraction=0.337; feature_fraction=0.494; lambda_l2=9.94; lambda_l1=1.09; min_gain_to_split=0.877; min_sum_hessian_in_leaf=50.3; scale_pos_weight=9; path_smooth=86.4; top_k=17 : y = 0.93 : 58.3 secs : infill_ei
#
# Tue Jul 29 16:10:47 2025 AUC 0.929935466983251
#
# [mbo] 91: learning_rate=0.022; num_leaves=1444; min_data_in_leaf=407; bagging_fraction=0.461; feature_fraction=0.521; lambda_l2=9.08; lambda_l1=1.03; min_gain_to_split=1.04; min_sum_hessian_in_leaf=44.9; scale_pos_weight=8.46; path_smooth=90.6; top_k=19 : y = 0.93 : 62.9 secs : infill_ei
#
# Tue Jul 29 16:11:44 2025 AUC 0.929656023938637
#
# ...
#
# Tue Jul 29 17:12:44 2025 AUC 0.931726671645633
#
# [mbo] 155: learning_rate=0.0215; num_leaves=1466; min_data_in_leaf=515; bagging_fraction=0.418; feature_fraction=0.543; lambda_l2=9.85; lambda_l1=1.5; min_gain_to_split=0.899; min_sum_hessian_in_leaf=56.1; scale_pos_weight=8.96; path_smooth=80.2; top_k=16 : y = 0.932 : 60.2 secs : infill_ei
#
# Tue Jul 29 17:13:40 2025 AUC 0.930291976568583
#
# [mbo] 156: learning_rate=0.0292; num_leaves=1463; min_data_in_leaf=548; bagging_fraction=0.475; feature_fraction=0.537; lambda_l2=9.61; lambda_l1=1.26; min_gain_to_split=0.898; min_sum_hessian_in_leaf=56.1; scale_pos_weight=8.36; path_smooth=80.1; top_k=19 : y = 0.93 : 53.3 secs : infill_ei
#
# Tue Jul 29 17:14:32 2025 AUC 0.930489843534884
#
# [mbo] 157: learning_rate=0.0322; num_leaves=1530; min_data_in_leaf=481; bagging_fraction=0.308; feature_fraction=0.507; lambda_l2=8.85; lambda_l1=2.25; min_gain_to_split=1.12; min_sum_hessian_in_leaf=55.3; scale_pos_weight=7.75; path_smooth=82.7; top_k=16 : y = 0.93 : 49.4 secs : infill_ei
#
# Tue Jul 29 17:15:30 2025 AUC 0.930021145693582
#
# [mbo] 158: learning_rate=0.0282; num_leaves=1397; min_data_in_leaf=496; bagging_fraction=0.394; feature_fraction=0.518; lambda_l2=9.85; lambda_l1=1.25; min_gain_to_split=0.884; min_sum_hessian_in_leaf=56.2; scale_pos_weight=7.89; path_smooth=91; top_k=16 : y = 0.93 : 55.4 secs : infill_ei
#
# Tue Jul 29 17:16:22 2025 AUC 0.929352980554473
#
# [mbo] 159: learning_rate=0.0349; num_leaves=1547; min_data_in_leaf=453; bagging_fraction=0.462; feature_fraction=0.492; lambda_l2=9.21; lambda_l1=2.26; min_gain_to_split=0.904; min_sum_hessian_in_leaf=48.5; scale_pos_weight=7.86; path_smooth=90.8; top_k=19 : y = 0.929 : 50.4 secs : infill_ei
#
# Tue Jul 29 17:17:14 2025 AUC 0.928578912049389
#
# [mbo] 160: learning_rate=0.0329; num_leaves=1557; min_data_in_leaf=567; bagging_fraction=0.348; feature_fraction=0.483; lambda_l2=9.36; lambda_l1=1.01; min_gain_to_split=1.02; min_sum_hessian_in_leaf=58.1; scale_pos_weight=8.09; path_smooth=80.7; top_k=15 : y = 0.929 : 51.3 secs : infill_ei
#
# Tue Jul 29 17:18:02 2025 AUC 0.929727925243194
#
# [mbo] 161: learning_rate=0.0348; num_leaves=1512; min_data_in_leaf=560; bagging_fraction=0.313; feature_fraction=0.545; lambda_l2=9.8; lambda_l1=2.21; min_gain_to_split=1.16; min_sum_hessian_in_leaf=52.2; scale_pos_weight=7.68; path_smooth=85.6; top_k=19 : y = 0.93 : 46.3 secs : infill_ei
#
# Tue Jul 29 17:18:53 2025 AUC 0.929296396612167
#
# [mbo] 162: learning_rate=0.033; num_leaves=1484; min_data_in_leaf=512; bagging_fraction=0.306; feature_fraction=0.5; lambda_l2=9.59; lambda_l1=1.86; min_gain_to_split=1.1; min_sum_hessian_in_leaf=59; scale_pos_weight=8.6; path_smooth=80.4; top_k=19 : y = 0.929 : 49.8 secs : infill_ei
#
# Tue Jul 29 17:19:55 2025 AUC 0.929405013187077
#
# [mbo] 163: learning_rate=0.0215; num_leaves=1311; min_data_in_leaf=515; bagging_fraction=0.457; feature_fraction=0.534; lambda_l2=9.2; lambda_l1=1.52; min_gain_to_split=0.831; min_sum_hessian_in_leaf=53; scale_pos_weight=8.95; path_smooth=84.2; top_k=16 : y = 0.929 : 59.7 secs : infill_ei
#
# Tue Jul 29 17:20:59 2025 AUC 0.930216662011083
#
# [mbo] 164: learning_rate=0.0214; num_leaves=1359; min_data_in_leaf=462; bagging_fraction=0.32; feature_fraction=0.484; lambda_l2=9.82; lambda_l1=2.48; min_gain_to_split=1.03; min_sum_hessian_in_leaf=55.9; scale_pos_weight=8.47; path_smooth=91.2; top_k=18 : y = 0.93 : 61.9 secs : infill_ei
#
# Tue Jul 29 17:21:59 2025 AUC 0.929336246160247
#
# [mbo] 165: learning_rate=0.0228; num_leaves=1442; min_data_in_leaf=429; bagging_fraction=0.35; feature_fraction=0.522; lambda_l2=9.43; lambda_l1=1.88; min_gain_to_split=1.15; min_sum_hessian_in_leaf=46.6; scale_pos_weight=8.88; path_smooth=84.3; top_k=18 : y = 0.929 : 57.8 secs : infill_ei
#
# Saved the current state after iteration 166 in the file bayesiana.RDATA.
#
# Tue Jul 29 17:23:02 2025 AUC 0.929964551221413
#
# [mbo] 166: learning_rate=0.0252; num_leaves=1596; min_data_in_leaf=407; bagging_fraction=0.387; feature_fraction=0.545; lambda_l2=8.75; lambda_l1=1.98; min_gain_to_split=0.882; min_sum_hessian_in_leaf=43.7; scale_pos_weight=9.46; path_smooth=86.2; top_k=14 : y = 0.93 : 56.8 secs : infill_ei
#
# Tue Jul 29 17:23:55 2025 AUC 0.930809064890639
#
# [mbo] 167: learning_rate=0.0316; num_leaves=1414; min_data_in_leaf=529; bagging_fraction=0.461; feature_fraction=0.518; lambda_l2=8.54; lambda_l1=1.36; min_gain_to_split=0.991; min_sum_hessian_in_leaf=58; scale_pos_weight=8.99; path_smooth=86; top_k=16 : y = 0.931 : 51.6 secs : infill_ei
#
# Tue Jul 29 17:24:50 2025 AUC 0.93088714630626
#
# [mbo] 168: learning_rate=0.0283; num_leaves=1317; min_data_in_leaf=518; bagging_fraction=0.358; feature_fraction=0.5; lambda_l2=9.96; lambda_l1=1.46; min_gain_to_split=0.967; min_sum_hessian_in_leaf=56.5; scale_pos_weight=8.63; path_smooth=89.8; top_k=20 : y = 0.931 : 53.8 secs : infill_ei
#
# Tue Jul 29 17:25:48 2025 AUC 0.929549574265606
#
# [mbo] 169: learning_rate=0.0279; num_leaves=1504; min_data_in_leaf=506; bagging_fraction=0.381; feature_fraction=0.509; lambda_l2=9; lambda_l1=2.07; min_gain_to_split=0.834; min_sum_hessian_in_leaf=57.1; scale_pos_weight=9.45; path_smooth=94.1; top_k=15 : y = 0.93 : 56.5 secs : infill_ei
#
# Tue Jul 29 17:26:40 2025 AUC 0.929593976901681
#
# [mbo] 170: learning_rate=0.0329; num_leaves=1513; min_data_in_leaf=525; bagging_fraction=0.35; feature_fraction=0.534; lambda_l2=8.38; lambda_l1=1.45; min_gain_to_split=1.04; min_sum_hessian_in_leaf=47.9; scale_pos_weight=8.88; path_smooth=86.3; top_k=15 : y = 0.93 : 50.6 secs : infill_ei
#
# Tue Jul 29 17:27:43 2025 AUC 0.930050959741135
#
# [mbo] 171: learning_rate=0.022; num_leaves=1539; min_data_in_leaf=403; bagging_fraction=0.5; feature_fraction=0.546; lambda_l2=9.38; lambda_l1=1.15; min_gain_to_split=0.833; min_sum_hessian_in_leaf=58.9; scale_pos_weight=9.05; path_smooth=93.4; top_k=19 : y = 0.93 : 61.7 secs : infill_ei
#
# Tue Jul 29 17:28:47 2025 AUC 0.929471675679695
#
# [mbo] 172: learning_rate=0.0218; num_leaves=1406; min_data_in_leaf=525; bagging_fraction=0.416; feature_fraction=0.543; lambda_l2=9.95; lambda_l1=1.5; min_gain_to_split=0.876; min_sum_hessian_in_leaf=50.6; scale_pos_weight=9.49; path_smooth=81.5; top_k=17 : y = 0.929 : 60.2 secs : infill_ei
#
# Tue Jul 29 17:29:36 2025 AUC 0.930767569689716
#
# [mbo] 173: learning_rate=0.0318; num_leaves=1463; min_data_in_leaf=545; bagging_fraction=0.398; feature_fraction=0.534; lambda_l2=9.99; lambda_l1=2.48; min_gain_to_split=1.08; min_sum_hessian_in_leaf=56.3; scale_pos_weight=7.54; path_smooth=85.9; top_k=14 : y = 0.931 : 47.9 secs : infill_ei
#
# Tue Jul 29 17:30:37 2025 AUC 0.930436083421877
#
# [mbo] 174: learning_rate=0.0206; num_leaves=1372; min_data_in_leaf=591; bagging_fraction=0.319; feature_fraction=0.542; lambda_l2=8.74; lambda_l1=2.38; min_gain_to_split=0.926; min_sum_hessian_in_leaf=47.1; scale_pos_weight=7.62; path_smooth=81.1; top_k=19 : y = 0.93 : 59.2 secs : infill_ei
#
# Tue Jul 29 17:31:37 2025 AUC 0.93076970298729
#
# [mbo] 175: learning_rate=0.0225; num_leaves=1336; min_data_in_leaf=436; bagging_fraction=0.447; feature_fraction=0.515; lambda_l2=9.72; lambda_l1=1.76; min_gain_to_split=0.945; min_sum_hessian_in_leaf=46.5; scale_pos_weight=7.54; path_smooth=89.1; top_k=16 : y = 0.931 : 59.2 secs : infill_ei
#
# Tue Jul 29 17:32:31 2025 AUC 0.930425268194535
#
# [mbo] 176: learning_rate=0.03; num_leaves=1410; min_data_in_leaf=511; bagging_fraction=0.463; feature_fraction=0.494; lambda_l2=9.03; lambda_l1=2.14; min_gain_to_split=0.883; min_sum_hessian_in_leaf=59.5; scale_pos_weight=8.1; path_smooth=85.8; top_k=16 : y = 0.93 : 52.3 secs : infill_ei
#
# Saved the current state after iteration 177 in the file bayesiana.RDATA.
#
# Tue Jul 29 17:33:35 2025 AUC 0.93023930221667
#
# [mbo] 177: learning_rate=0.0276; num_leaves=1575; min_data_in_leaf=519; bagging_fraction=0.399; feature_fraction=0.547; lambda_l2=8.05; lambda_l1=1.95; min_gain_to_split=0.944; min_sum_hessian_in_leaf=56.1; scale_pos_weight=8.94; path_smooth=92.8; top_k=16 : y = 0.93 : 53.2 secs : infill_ei
#
# Tue Jul 29 17:34:28 2025 AUC 0.930884779198154
#
# [mbo] 178: learning_rate=0.0317; num_leaves=1377; min_data_in_leaf=562; bagging_fraction=0.411; feature_fraction=0.491; lambda_l2=9.92; lambda_l1=1.07; min_gain_to_split=1.14; min_sum_hessian_in_leaf=58.5; scale_pos_weight=8.66; path_smooth=92.5; top_k=19 : y = 0.931 : 50.8 secs : infill_ei
#
# Tue Jul 29 17:35:28 2025 AUC 0.929987678253794
#
# [mbo] 179: learning_rate=0.0232; num_leaves=1532; min_data_in_leaf=403; bagging_fraction=0.316; feature_fraction=0.529; lambda_l2=8.3; lambda_l1=1.84; min_gain_to_split=1.09; min_sum_hessian_in_leaf=54.5; scale_pos_weight=8.1; path_smooth=81.6; top_k=17 : y = 0.93 : 57.1 secs : infill_ei
#
# Tue Jul 29 17:36:28 2025 AUC 0.931336705982851
#
# [mbo] 180: learning_rate=0.0237; num_leaves=1509; min_data_in_leaf=409; bagging_fraction=0.367; feature_fraction=0.526; lambda_l2=8.64; lambda_l1=1.41; min_gain_to_split=0.916; min_sum_hessian_in_leaf=57.8; scale_pos_weight=8.78; path_smooth=92.4; top_k=14 : y = 0.931 : 58.7 secs : infill_ei
#
# Tue Jul 29 17:37:33 2025 AUC 0.930148361146687
#
# [mbo] 181: learning_rate=0.0217; num_leaves=1389; min_data_in_leaf=533; bagging_fraction=0.414; feature_fraction=0.522; lambda_l2=9.85; lambda_l1=1.43; min_gain_to_split=0.899; min_sum_hessian_in_leaf=47.4; scale_pos_weight=8.96; path_smooth=86.8; top_k=17 : y = 0.93 : 61.4 secs : infill_ei
#
# Tue Jul 29 17:38:33 2025 AUC 0.930628206470954
#
# [mbo] 182: learning_rate=0.0208; num_leaves=1464; min_data_in_leaf=429; bagging_fraction=0.32; feature_fraction=0.527; lambda_l2=8.17; lambda_l1=2.09; min_gain_to_split=1.15; min_sum_hessian_in_leaf=46.9; scale_pos_weight=8.7; path_smooth=93.4; top_k=15 : y = 0.931 : 58.5 secs : infill_ei
#
# Tue Jul 29 17:39:35 2025 AUC 0.930218278612806
#
# [mbo] 183: learning_rate=0.0249; num_leaves=1464; min_data_in_leaf=486; bagging_fraction=0.447; feature_fraction=0.522; lambda_l2=9.59; lambda_l1=1.39; min_gain_to_split=0.899; min_sum_hessian_in_leaf=56.2; scale_pos_weight=7.69; path_smooth=82; top_k=16 : y = 0.93 : 56.1 secs : infill_ei
#
# Tue Jul 29 17:40:34 2025 AUC 0.929783700077952
#
# [mbo] 184: learning_rate=0.0241; num_leaves=1556; min_data_in_leaf=554; bagging_fraction=0.416; feature_fraction=0.518; lambda_l2=8.27; lambda_l1=2.15; min_gain_to_split=0.997; min_sum_hessian_in_leaf=54.8; scale_pos_weight=9.09; path_smooth=81.8; top_k=17 : y = 0.93 : 57.5 secs : infill_ei
#
# Tue Jul 29 17:41:27 2025 AUC 0.92930680014052
#
# [mbo] 185: learning_rate=0.0343; num_leaves=1514; min_data_in_leaf=518; bagging_fraction=0.327; feature_fraction=0.497; lambda_l2=9.47; lambda_l1=2.07; min_gain_to_split=0.862; min_sum_hessian_in_leaf=42.8; scale_pos_weight=7.74; path_smooth=81.6; top_k=18 : y = 0.929 : 51.9 secs : infill_ei
#
# Tue Jul 29 17:42:21 2025 AUC 0.930328792368996
#
# [mbo] 186: learning_rate=0.0251; num_leaves=1354; min_data_in_leaf=574; bagging_fraction=0.497; feature_fraction=0.482; lambda_l2=8.2; lambda_l1=1.67; min_gain_to_split=1.14; min_sum_hessian_in_leaf=52.8; scale_pos_weight=7.74; path_smooth=92.1; top_k=19 : y = 0.93 : 52.6 secs : infill_ei
#
# Tue Jul 29 17:43:23 2025 AUC 0.929189833504321
#
# [mbo] 187: learning_rate=0.0216; num_leaves=1594; min_data_in_leaf=424; bagging_fraction=0.315; feature_fraction=0.513; lambda_l2=8.4; lambda_l1=1.49; min_gain_to_split=1.17; min_sum_hessian_in_leaf=55.3; scale_pos_weight=8.67; path_smooth=81; top_k=19 : y = 0.929 : 56.7 secs : infill_ei
#
# Saved the current state after iteration 188 in the file bayesiana.RDATA.
#
# Tue Jul 29 17:44:18 2025 AUC 0.929379637529504
#
# [mbo] 188: learning_rate=0.0345; num_leaves=1409; min_data_in_leaf=480; bagging_fraction=0.398; feature_fraction=0.527; lambda_l2=9.03; lambda_l1=2.11; min_gain_to_split=0.976; min_sum_hessian_in_leaf=45.5; scale_pos_weight=8.33; path_smooth=84.6; top_k=18 : y = 0.929 : 49.7 secs : infill_ei
#
# Tue Jul 29 17:45:17 2025 AUC 0.929114975990765
#
# [mbo] 189: learning_rate=0.0268; num_leaves=1394; min_data_in_leaf=438; bagging_fraction=0.376; feature_fraction=0.541; lambda_l2=8.76; lambda_l1=1.19; min_gain_to_split=0.817; min_sum_hessian_in_leaf=44; scale_pos_weight=9.1; path_smooth=94.8; top_k=15 : y = 0.929 : 57.5 secs : infill_ei
#
# Tue Jul 29 17:46:23 2025 AUC 0.930866954749432
#
# [mbo] 190: learning_rate=0.0205; num_leaves=1370; min_data_in_leaf=500; bagging_fraction=0.345; feature_fraction=0.53; lambda_l2=9.77; lambda_l1=2.18; min_gain_to_split=0.875; min_sum_hessian_in_leaf=49.7; scale_pos_weight=9.08; path_smooth=83.8; top_k=14 : y = 0.931 : 64.1 secs : infill_ei
#
# Tue Jul 29 17:47:21 2025 AUC 0.930227807124943
#
# [mbo] 191: learning_rate=0.0215; num_leaves=1491; min_data_in_leaf=464; bagging_fraction=0.474; feature_fraction=0.502; lambda_l2=9.52; lambda_l1=1.28; min_gain_to_split=1.14; min_sum_hessian_in_leaf=57.8; scale_pos_weight=8.19; path_smooth=84; top_k=17 : y = 0.93 : 56.2 secs : infill_ei
#
# Tue Jul 29 17:48:19 2025 AUC 0.930008417390063
#
# [mbo] 192: learning_rate=0.0231; num_leaves=1563; min_data_in_leaf=431; bagging_fraction=0.472; feature_fraction=0.503; lambda_l2=9.25; lambda_l1=1.45; min_gain_to_split=1.12; min_sum_hessian_in_leaf=40.2; scale_pos_weight=8.46; path_smooth=87.1; top_k=16 : y = 0.93 : 56.2 secs : infill_ei
#
# Tue Jul 29 17:49:11 2025 AUC 0.930327700955511
#
# [mbo] 193: learning_rate=0.0326; num_leaves=1486; min_data_in_leaf=511; bagging_fraction=0.499; feature_fraction=0.514; lambda_l2=9.83; lambda_l1=2.29; min_gain_to_split=0.853; min_sum_hessian_in_leaf=56.8; scale_pos_weight=7.99; path_smooth=87; top_k=15 : y = 0.93 : 50.8 secs : infill_ei
#
# Tue Jul 29 17:50:09 2025 AUC 0.930916978061317
#
# [mbo] 194: learning_rate=0.0219; num_leaves=1427; min_data_in_leaf=416; bagging_fraction=0.369; feature_fraction=0.505; lambda_l2=9.58; lambda_l1=1.89; min_gain_to_split=1.2; min_sum_hessian_in_leaf=43.2; scale_pos_weight=8.78; path_smooth=92.9; top_k=14 : y = 0.931 : 56.8 secs : infill_ei
#
# Tue Jul 29 17:51:09 2025 AUC 0.930389871868837
#
# [mbo] 195: learning_rate=0.022; num_leaves=1580; min_data_in_leaf=563; bagging_fraction=0.404; feature_fraction=0.491; lambda_l2=8.71; lambda_l1=2.02; min_gain_to_split=1.09; min_sum_hessian_in_leaf=43.3; scale_pos_weight=7.76; path_smooth=82.6; top_k=14 : y = 0.93 : 58.3 secs : infill_ei
#
# Tue Jul 29 17:52:07 2025 AUC 0.928746358605696
#
# [mbo] 196: learning_rate=0.0288; num_leaves=1505; min_data_in_leaf=502; bagging_fraction=0.417; feature_fraction=0.497; lambda_l2=9.13; lambda_l1=2.26; min_gain_to_split=0.898; min_sum_hessian_in_leaf=56.1; scale_pos_weight=9.23; path_smooth=87.7; top_k=16 : y = 0.929 : 53.5 secs : infill_ei
#
# Tue Jul 29 17:52:59 2025 AUC 0.930741494514123
#
# [mbo] 197: learning_rate=0.0298; num_leaves=1599; min_data_in_leaf=446; bagging_fraction=0.354; feature_fraction=0.516; lambda_l2=8.95; lambda_l1=1.79; min_gain_to_split=1.19; min_sum_hessian_in_leaf=41.2; scale_pos_weight=7.61; path_smooth=85.2; top_k=18 : y = 0.931 : 50.1 secs : infill_ei
#
# Tue Jul 29 17:53:51 2025 AUC 0.930852005849526
#
# [mbo] 198: learning_rate=0.033; num_leaves=1430; min_data_in_leaf=591; bagging_fraction=0.382; feature_fraction=0.511; lambda_l2=8.98; lambda_l1=1.38; min_gain_to_split=1.02; min_sum_hessian_in_leaf=43.5; scale_pos_weight=8.66; path_smooth=90.5; top_k=16 : y = 0.931 : 50.8 secs : infill_ei
#
# Saved the current state after iteration 199 in the file bayesiana.RDATA.
#
# Tue Jul 29 17:54:54 2025 AUC 0.929037343086217
#
# [mbo] 199: learning_rate=0.0221; num_leaves=1493; min_data_in_leaf=428; bagging_fraction=0.413; feature_fraction=0.484; lambda_l2=9.12; lambda_l1=2.24; min_gain_to_split=1.03; min_sum_hessian_in_leaf=58.1; scale_pos_weight=9.25; path_smooth=91.8; top_k=20 : y = 0.929 : 57.5 secs : infill_ei
#
# Tue Jul 29 17:55:55 2025 AUC 0.931098393206675
#
# [mbo] 200: learning_rate=0.0209; num_leaves=1501; min_data_in_leaf=507; bagging_fraction=0.44; feature_fraction=0.529; lambda_l2=9.81; lambda_l1=1.98; min_gain_to_split=1.01; min_sum_hessian_in_leaf=44.6; scale_pos_weight=8.9; path_smooth=87.9; top_k=20 : y = 0.931 : 59.3 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "learning_rate"           "num_leaves"
#  [3] "min_data_in_leaf"        "bagging_fraction"
#  [5] "feature_fraction"        "lambda_l2"
#  [7] "lambda_l1"               "min_gain_to_split"
#  [9] "min_sum_hessian_in_leaf" "scale_pos_weight"
# [11] "path_smooth"             "top_k"
# [13] "y"                       "dob"
# [15] "eol"                     "error.message"
# [17] "exec.time"               "ei"
# [19] "error.model"             "train.time"
# [21] "prop.type"               "propose.time"
# [23] "se"                      "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    learning_rate num_leaves min_data_in_leaf bagging_fraction feature_fraction
#            <num>      <int>            <int>            <num>            <num>
# 1:    0.02150983       1466              515        0.4176058        0.5433709
#    lambda_l2 lambda_l1 min_gain_to_split min_sum_hessian_in_leaf
#        <num>     <num>             <num>                   <num>
# 1:  9.847839   1.50213         0.8990293                56.10836
#    scale_pos_weight path_smooth top_k
#               <num>       <num> <int>
# 1:         8.956218    80.18257    16
# [1] 0.9317267

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 333757
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0.8990293
#
# $min_sum_hessian_in_leaf
# [1] 56.10836
#
# $lambda_l1
# [1] 1.50213
#
# $lambda_l2
# [1] 9.847839
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 0.4176058
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 8.956218
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1500
#
# $learning_rate
# [1] 0.02150983
#
# $feature_fraction
# [1] 0.5433709
#
# $num_leaves
# [1] 1466
#
# $min_data_in_leaf
# [1] 515
#
# $path_smooth
# [1] 80.18257
#
# $top_k
# [1] 16

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Jul 29 18:04:26 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
