# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# Esta Tarea para el Hogar 02 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el viernes 01-agosto

# %% [markdown]
# ##  1. Cazatalentos

# %% [markdown]
# En la Clase 03 nos hemos enfrentado a  "La Maldicion del Ganandor",  elegir el modelo con el mejor puntaje simple no suele ser la mejor estrategia.
# <br> Lea y ejecute el notebook  **src/CazaTalentos/CazaTalentos.ipynb**
# <br> en caso de interesarle, participe del Desafío Ordenamiento  que vence el sábado 02 de agosto a las 19:00

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dm"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dm" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/itba2025-8d0a/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Wed Aug 06 14:00:55 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  656846 35.1 1439368    76.9 1439368  76.9
# Vcells 1224707  9.4 8388608    64.0 1924958  14.7

# %%
notificar <- function(mensaje) {
  system(sprintf('curl -d "%s" https://ntfy.sh/juani_canal_cloud', mensaje))
}

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 4975
PARAM$semilla_primigenia <- 888757

# %%
PARAM$kaggle$competencia <- "data-mining-analista-sr-2025-a"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 2000,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_iterations", lower = 200L, upper = 1500L),
  makeNumericParam("learning_rate", lower = 0.05, upper = 0.5),
  makeNumericParam("feature_fraction", lower = 0.2, upper = 0.8),
  makeIntegerParam("num_leaves", lower = 8L, upper = 28L),
  makeIntegerParam("min_data_in_leaf", lower = 10L, upper = 500L)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 350 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]
dataset_train <- rbindlist(list(dataset_train, dataset_train[clase01 == 1L][, clase01 := 0L]))

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 85929
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimización bayesiana, retomando si ya existe
# es la celda más lenta de todo el notebook

notificar("🚀 Arranca la ferrari de la optimización bayesianaaa")
start_time <- Sys.time()
hora_ultima_notificacion <- start_time

tryCatch({

  if (!file.exists(kbayesiana)) {
    bayesiana_salida <- mbo(obj.fun, learner = surr.km, control = ctrl)
  } else {
    bayesiana_salida <- mboContinue(kbayesiana)
  }

  # Calcular duración y mandar mensaje final
  end_time <- Sys.time()
  duracion <- difftime(end_time, start_time, units = "mins")
  horas <- floor(as.numeric(duracion) / 60)
  minutos <- round(as.numeric(duracion) %% 60)

  mensaje_final <- paste0(
    "✅ Sos un genio, la Optimización Bayesiana finalizo bien CAMPEON.\n",
    "⏱️ Una locura, Duración total: ", horas, "h ", minutos, "m.\n",
    "⚠️ MOVETE PIBE, Tenés 30 minutos antes de que se apague la VM. Dalee daleee."
  )

  notificar(mensaje_final)

}, error = function(e) {
  notificar(paste0("❌ PERO LA CONCHA DE LA LORA, Error en optimización bayesiana, a laburar negrito: ", e$message))
})
# Out:
# Computing y column(s) for design. Not provided.
#
# Wed Aug 06 14:01:50 2025 AUC 0.906859440338769
#
# Wed Aug 06 14:02:34 2025 AUC 0.905975033784754
#
# Wed Aug 06 14:03:03 2025 AUC 0.910188557048061
#
# Wed Aug 06 14:03:19 2025 AUC 0.91159576366344
#
# Wed Aug 06 14:04:19 2025 AUC 0.911457134149872
#
# Wed Aug 06 14:04:47 2025 AUC 0.907009038516815
#
# Wed Aug 06 14:06:02 2025 AUC 0.912029979293681
#
# Wed Aug 06 14:06:31 2025 AUC 0.903708356669642
#
# Wed Aug 06 14:06:53 2025 AUC 0.899083226940705
#
# Wed Aug 06 14:08:02 2025 AUC 0.908713609363883
#
# Wed Aug 06 14:08:19 2025 AUC 0.901572574041069
#
# Wed Aug 06 14:08:30 2025 AUC 0.911402717217338
#
# Wed Aug 06 14:09:03 2025 AUC 0.90598681762776
#
# Wed Aug 06 14:09:26 2025 AUC 0.908307845882366
#
# Wed Aug 06 14:09:54 2025 AUC 0.890660707188963
#
# Wed Aug 06 14:10:01 2025 AUC 0.908172067024203
#
# Wed Aug 06 14:10:51 2025 AUC 0.910000156320712
#
# Wed Aug 06 14:11:35 2025 AUC 0.913630939577753
#
# Wed Aug 06 14:12:25 2025 AUC 0.89786650953754
#
# Wed Aug 06 14:12:42 2025 AUC 0.898928380659235
#
# [mbo] 0: num_iterations=842; learning_rate=0.259; feature_fraction=0.589; num_leaves=21; min_data_in_leaf=212 : y = 0.907 : 33.8 secs : initdesign
#
# [mbo] 0: num_iterations=925; learning_rate=0.35; feature_fraction=0.389; num_leaves=16; min_data_in_leaf=284 : y = 0.906 : 43.8 secs : initdesign
#
# [mbo] 0: num_iterations=1040; learning_rate=0.159; feature_fraction=0.616; num_leaves=13; min_data_in_leaf=107 : y = 0.91 : 29.1 secs : initdesign
#
# [mbo] 0: num_iterations=311; learning_rate=0.133; feature_fraction=0.375; num_leaves=19; min_data_in_leaf=380 : y = 0.912 : 16.2 secs : initdesign
#
# [mbo] 0: num_iterations=1397; learning_rate=0.174; feature_fraction=0.543; num_leaves=11; min_data_in_leaf=279 : y = 0.911 : 59.5 secs : initdesign
#
# [mbo] 0: num_iterations=500; learning_rate=0.231; feature_fraction=0.509; num_leaves=27; min_data_in_leaf=181 : y = 0.907 : 27.7 secs : initdesign
#
# [mbo] 0: num_iterations=1479; learning_rate=0.103; feature_fraction=0.483; num_leaves=19; min_data_in_leaf=414 : y = 0.912 : 75.1 secs : initdesign
#
# [mbo] 0: num_iterations=666; learning_rate=0.442; feature_fraction=0.335; num_leaves=15; min_data_in_leaf=141 : y = 0.904 : 29.3 secs : initdesign
#
# [mbo] 0: num_iterations=621; learning_rate=0.464; feature_fraction=0.793; num_leaves=26; min_data_in_leaf=338 : y = 0.899 : 21.6 secs : initdesign
#
# [mbo] 0: num_iterations=1368; learning_rate=0.193; feature_fraction=0.424; num_leaves=24; min_data_in_leaf=233 : y = 0.909 : 69.6 secs : initdesign
#
# [mbo] 0: num_iterations=357; learning_rate=0.309; feature_fraction=0.314; num_leaves=22; min_data_in_leaf=68 : y = 0.902 : 16.7 secs : initdesign
#
# [mbo] 0: num_iterations=427; learning_rate=0.0852; feature_fraction=0.764; num_leaves=14; min_data_in_leaf=191 : y = 0.911 : 11.0 secs : initdesign
#
# [mbo] 0: num_iterations=1236; learning_rate=0.373; feature_fraction=0.695; num_leaves=17; min_data_in_leaf=309 : y = 0.906 : 33.4 secs : initdesign
#
# [mbo] 0: num_iterations=576; learning_rate=0.217; feature_fraction=0.274; num_leaves=9; min_data_in_leaf=111 : y = 0.908 : 22.9 secs : initdesign
#
# [mbo] 0: num_iterations=1162; learning_rate=0.424; feature_fraction=0.657; num_leaves=28; min_data_in_leaf=22 : y = 0.891 : 27.7 secs : initdesign
#
# [mbo] 0: num_iterations=238; learning_rate=0.32; feature_fraction=0.624; num_leaves=12; min_data_in_leaf=437 : y = 0.908 : 7.1 secs : initdesign
#
# [mbo] 0: num_iterations=1277; learning_rate=0.279; feature_fraction=0.23; num_leaves=8; min_data_in_leaf=486 : y = 0.91 : 49.5 secs : initdesign
#
# [mbo] 0: num_iterations=854; learning_rate=0.0639; feature_fraction=0.458; num_leaves=20; min_data_in_leaf=373 : y = 0.914 : 44.8 secs : initdesign
#
# [mbo] 0: num_iterations=1089; learning_rate=0.498; feature_fraction=0.227; num_leaves=24; min_data_in_leaf=457 : y = 0.898 : 49.8 secs : initdesign
#
# [mbo] 0: num_iterations=734; learning_rate=0.405; feature_fraction=0.721; num_leaves=10; min_data_in_leaf=35 : y = 0.899 : 17.2 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Wed Aug 06 14:13:16 2025 AUC 0.914280272676647
#
# [mbo] 1: num_iterations=888; learning_rate=0.0501; feature_fraction=0.59; num_leaves=10; min_data_in_leaf=487 : y = 0.914 : 30.5 secs : infill_ei
#
# Wed Aug 06 14:13:43 2025 AUC 0.912303506989091
#
# [mbo] 2: num_iterations=996; learning_rate=0.0995; feature_fraction=0.8; num_leaves=15; min_data_in_leaf=500 : y = 0.912 : 26.2 secs : infill_ei
#
# Wed Aug 06 14:14:28 2025 AUC 0.913900584283469
#
# [mbo] 3: num_iterations=975; learning_rate=0.05; feature_fraction=0.475; num_leaves=8; min_data_in_leaf=392 : y = 0.914 : 44.1 secs : infill_ei
#
# Wed Aug 06 14:15:01 2025 AUC 0.914407609976394
#
# [mbo] 4: num_iterations=816; learning_rate=0.05; feature_fraction=0.206; num_leaves=12; min_data_in_leaf=500 : y = 0.914 : 32.5 secs : infill_ei
#
# Wed Aug 06 14:15:43 2025 AUC 0.912012235803527
#
# [mbo] 5: num_iterations=976; learning_rate=0.05; feature_fraction=0.233; num_leaves=16; min_data_in_leaf=188 : y = 0.912 : 41.4 secs : infill_ei
#
# Wed Aug 06 14:16:18 2025 AUC 0.914539414557553
#
# [mbo] 6: num_iterations=719; learning_rate=0.05; feature_fraction=0.424; num_leaves=13; min_data_in_leaf=474 : y = 0.915 : 33.8 secs : infill_ei
#
# Wed Aug 06 14:16:58 2025 AUC 0.914586852638883
#
# [mbo] 7: num_iterations=890; learning_rate=0.0501; feature_fraction=0.359; num_leaves=8; min_data_in_leaf=500 : y = 0.915 : 39.3 secs : infill_ei
#
# Wed Aug 06 14:17:17 2025 AUC 0.91215164785266
#
# [mbo] 8: num_iterations=386; learning_rate=0.0501; feature_fraction=0.596; num_leaves=28; min_data_in_leaf=500 : y = 0.912 : 18.0 secs : infill_ei
#
# Wed Aug 06 14:18:05 2025 AUC 0.913434526405116
#
# [mbo] 9: num_iterations=1038; learning_rate=0.05; feature_fraction=0.382; num_leaves=13; min_data_in_leaf=500 : y = 0.913 : 47.9 secs : infill_ei
#
# Wed Aug 06 14:18:30 2025 AUC 0.914380861286825
#
# [mbo] 10: num_iterations=582; learning_rate=0.0501; feature_fraction=0.238; num_leaves=8; min_data_in_leaf=485 : y = 0.914 : 24.3 secs : infill_ei
#
# Wed Aug 06 14:19:07 2025 AUC 0.914055193795049
#
# [mbo] 11: num_iterations=754; learning_rate=0.086; feature_fraction=0.479; num_leaves=8; min_data_in_leaf=481 : y = 0.914 : 35.8 secs : infill_ei
#
# Wed Aug 06 14:19:42 2025 AUC 0.915012842845586
#
# [mbo] 12: num_iterations=800; learning_rate=0.0501; feature_fraction=0.305; num_leaves=8; min_data_in_leaf=462 : y = 0.915 : 34.1 secs : infill_ei
#
# Wed Aug 06 14:20:19 2025 AUC 0.912254619935183
#
# [mbo] 13: num_iterations=724; learning_rate=0.0501; feature_fraction=0.201; num_leaves=27; min_data_in_leaf=432 : y = 0.912 : 36.7 secs : infill_ei
#
# Wed Aug 06 14:21:03 2025 AUC 0.910904380409772
#
# [mbo] 14: num_iterations=1500; learning_rate=0.0501; feature_fraction=0.797; num_leaves=19; min_data_in_leaf=202 : y = 0.911 : 43.6 secs : infill_ei
#
# Wed Aug 06 14:21:23 2025 AUC 0.913240955095531
#
# [mbo] 15: num_iterations=633; learning_rate=0.0501; feature_fraction=0.693; num_leaves=17; min_data_in_leaf=425 : y = 0.913 : 19.2 secs : infill_ei
#
# Wed Aug 06 14:21:36 2025 AUC 0.910614054454645
#
# [mbo] 16: num_iterations=200; learning_rate=0.0502; feature_fraction=0.489; num_leaves=28; min_data_in_leaf=125 : y = 0.911 : 11.9 secs : infill_ei
#
# Wed Aug 06 14:22:11 2025 AUC 0.914287476501469
#
# [mbo] 17: num_iterations=766; learning_rate=0.0501; feature_fraction=0.329; num_leaves=10; min_data_in_leaf=432 : y = 0.914 : 34.3 secs : infill_ei
#
# Wed Aug 06 14:22:43 2025 AUC 0.911859952656144
#
# [mbo] 18: num_iterations=1499; learning_rate=0.203; feature_fraction=0.8; num_leaves=8; min_data_in_leaf=462 : y = 0.912 : 31.5 secs : infill_ei
#
# Wed Aug 06 14:23:20 2025 AUC 0.913728232215407
#
# [mbo] 19: num_iterations=788; learning_rate=0.0501; feature_fraction=0.526; num_leaves=8; min_data_in_leaf=307 : y = 0.914 : 36.5 secs : infill_ei
#
# Saved the current state after iteration 20 in the file bayesiana.RDATA.
#
# Wed Aug 06 14:24:31 2025 AUC 0.912827881262795
#
# [mbo] 20: num_iterations=1500; learning_rate=0.0502; feature_fraction=0.438; num_leaves=8; min_data_in_leaf=121 : y = 0.913 : 66.4 secs : infill_ei
#
# Wed Aug 06 14:25:28 2025 AUC 0.914819812622664
#
# [mbo] 21: num_iterations=1495; learning_rate=0.0502; feature_fraction=0.202; num_leaves=8; min_data_in_leaf=348 : y = 0.915 : 55.9 secs : infill_ei
#
# Wed Aug 06 14:26:24 2025 AUC 0.915595891303218
#
# [mbo] 22: num_iterations=1450; learning_rate=0.05; feature_fraction=0.2; num_leaves=8; min_data_in_leaf=465 : y = 0.916 : 55.4 secs : infill_ei
#
# Wed Aug 06 14:26:30 2025 AUC 0.914790963024152
#
# [mbo] 23: num_iterations=214; learning_rate=0.0505; feature_fraction=0.797; num_leaves=8; min_data_in_leaf=488 : y = 0.915 : 5.5 secs : infill_ei
#
# Wed Aug 06 14:26:42 2025 AUC 0.913136463020642
#
# [mbo] 24: num_iterations=200; learning_rate=0.05; feature_fraction=0.502; num_leaves=16; min_data_in_leaf=338 : y = 0.913 : 10.8 secs : infill_ei
#
# Wed Aug 06 14:27:40 2025 AUC 0.91407811247428
#
# [mbo] 25: num_iterations=1499; learning_rate=0.0506; feature_fraction=0.2; num_leaves=8; min_data_in_leaf=466 : y = 0.914 : 57.2 secs : infill_ei
#
# Wed Aug 06 14:28:32 2025 AUC 0.913870714451218
#
# [mbo] 26: num_iterations=1347; learning_rate=0.0501; feature_fraction=0.201; num_leaves=8; min_data_in_leaf=358 : y = 0.914 : 51.6 secs : infill_ei
#
# Wed Aug 06 14:29:32 2025 AUC 0.914206676888825
#
# [mbo] 27: num_iterations=1439; learning_rate=0.0502; feature_fraction=0.201; num_leaves=16; min_data_in_leaf=328 : y = 0.914 : 59.8 secs : infill_ei
#
# Wed Aug 06 14:29:48 2025 AUC 0.914604633703517
#
# [mbo] 28: num_iterations=302; learning_rate=0.0501; feature_fraction=0.465; num_leaves=8; min_data_in_leaf=500 : y = 0.915 : 14.3 secs : infill_ei
#
# Wed Aug 06 14:29:53 2025 AUC 0.913207476863031
#
# [mbo] 29: num_iterations=200; learning_rate=0.119; feature_fraction=0.666; num_leaves=8; min_data_in_leaf=493 : y = 0.913 : 5.0 secs : infill_ei
#
# Wed Aug 06 14:30:25 2025 AUC 0.914325751963725
#
# [mbo] 30: num_iterations=1429; learning_rate=0.05; feature_fraction=0.685; num_leaves=8; min_data_in_leaf=448 : y = 0.914 : 31.4 secs : infill_ei
#
# Wed Aug 06 14:30:49 2025 AUC 0.914275131435763
#
# [mbo] 31: num_iterations=485; learning_rate=0.0503; feature_fraction=0.537; num_leaves=9; min_data_in_leaf=500 : y = 0.914 : 22.9 secs : infill_ei
#
# Wed Aug 06 14:30:57 2025 AUC 0.913783178824277
#
# [mbo] 32: num_iterations=310; learning_rate=0.05; feature_fraction=0.761; num_leaves=8; min_data_in_leaf=420 : y = 0.914 : 7.5 secs : infill_ei
#
# Wed Aug 06 14:31:55 2025 AUC 0.909117050161353
#
# [mbo] 33: num_iterations=1463; learning_rate=0.356; feature_fraction=0.566; num_leaves=8; min_data_in_leaf=500 : y = 0.909 : 56.5 secs : infill_ei
#
# Wed Aug 06 14:32:21 2025 AUC 0.913623922936653
#
# [mbo] 34: num_iterations=1174; learning_rate=0.0506; feature_fraction=0.799; num_leaves=8; min_data_in_leaf=480 : y = 0.914 : 25.5 secs : infill_ei
#
# Wed Aug 06 14:32:42 2025 AUC 0.912117289567896
#
# [mbo] 35: num_iterations=819; learning_rate=0.0501; feature_fraction=0.653; num_leaves=12; min_data_in_leaf=122 : y = 0.912 : 20.4 secs : infill_ei
#
# Wed Aug 06 14:33:41 2025 AUC 0.914217583493837
#
# [mbo] 36: num_iterations=1442; learning_rate=0.0506; feature_fraction=0.275; num_leaves=8; min_data_in_leaf=385 : y = 0.914 : 58.2 secs : infill_ei
#
# Saved the current state after iteration 37 in the file bayesiana.RDATA.
#
# Wed Aug 06 14:34:37 2025 AUC 0.911590739872044
#
# [mbo] 37: num_iterations=1415; learning_rate=0.0504; feature_fraction=0.764; num_leaves=28; min_data_in_leaf=500 : y = 0.912 : 51.4 secs : infill_ei
#
# Wed Aug 06 14:35:31 2025 AUC 0.913966048699951
#
# [mbo] 38: num_iterations=1382; learning_rate=0.0521; feature_fraction=0.205; num_leaves=8; min_data_in_leaf=480 : y = 0.914 : 53.1 secs : infill_ei
#
# Wed Aug 06 14:36:26 2025 AUC 0.913500462442075
#
# [mbo] 39: num_iterations=1455; learning_rate=0.0506; feature_fraction=0.2; num_leaves=8; min_data_in_leaf=254 : y = 0.914 : 54.7 secs : infill_ei
#
# Wed Aug 06 14:36:54 2025 AUC 0.913025982677434
#
# [mbo] 40: num_iterations=1091; learning_rate=0.0502; feature_fraction=0.784; num_leaves=10; min_data_in_leaf=315 : y = 0.913 : 26.3 secs : infill_ei
#
# Wed Aug 06 14:37:03 2025 AUC 0.914217290028815
#
# [mbo] 41: num_iterations=201; learning_rate=0.0501; feature_fraction=0.201; num_leaves=12; min_data_in_leaf=463 : y = 0.914 : 8.9 secs : infill_ei
#
# Wed Aug 06 14:37:59 2025 AUC 0.911684801406468
#
# [mbo] 42: num_iterations=1439; learning_rate=0.174; feature_fraction=0.204; num_leaves=8; min_data_in_leaf=444 : y = 0.912 : 55.0 secs : infill_ei
#
# Wed Aug 06 14:38:34 2025 AUC 0.914304374048535
#
# [mbo] 43: num_iterations=911; learning_rate=0.103; feature_fraction=0.202; num_leaves=8; min_data_in_leaf=331 : y = 0.914 : 34.4 secs : infill_ei
#
# Wed Aug 06 14:38:56 2025 AUC 0.913273028186047
#
# [mbo] 44: num_iterations=514; learning_rate=0.05; feature_fraction=0.2; num_leaves=12; min_data_in_leaf=288 : y = 0.913 : 20.7 secs : infill_ei
#
# Wed Aug 06 14:39:05 2025 AUC 0.912936246821064
#
# [mbo] 45: num_iterations=201; learning_rate=0.0502; feature_fraction=0.66; num_leaves=17; min_data_in_leaf=469 : y = 0.913 : 7.9 secs : infill_ei
#
# Wed Aug 06 14:39:14 2025 AUC 0.914022083612728
#
# [mbo] 46: num_iterations=201; learning_rate=0.0502; feature_fraction=0.22; num_leaves=8; min_data_in_leaf=250 : y = 0.914 : 8.4 secs : infill_ei
#
# Wed Aug 06 14:39:58 2025 AUC 0.914451520763348
#
# [mbo] 47: num_iterations=1148; learning_rate=0.0715; feature_fraction=0.2; num_leaves=8; min_data_in_leaf=333 : y = 0.914 : 43.1 secs : infill_ei
#
# Wed Aug 06 14:40:09 2025 AUC 0.914714684686127
#
# [mbo] 48: num_iterations=245; learning_rate=0.05; feature_fraction=0.238; num_leaves=8; min_data_in_leaf=364 : y = 0.915 : 10.2 secs : infill_ei
#
# Wed Aug 06 14:40:48 2025 AUC 0.913299674454383
#
# [mbo] 49: num_iterations=919; learning_rate=0.0512; feature_fraction=0.201; num_leaves=13; min_data_in_leaf=457 : y = 0.913 : 37.4 secs : infill_ei
#
# Wed Aug 06 14:41:38 2025 AUC 0.911604759640466
#
# [mbo] 50: num_iterations=1071; learning_rate=0.156; feature_fraction=0.516; num_leaves=8; min_data_in_leaf=341 : y = 0.912 : 49.9 secs : infill_ei
#
# Wed Aug 06 14:42:24 2025 AUC 0.913268699651531
#
# [mbo] 51: num_iterations=1156; learning_rate=0.0511; feature_fraction=0.226; num_leaves=8; min_data_in_leaf=89 : y = 0.913 : 44.2 secs : infill_ei
#
# Wed Aug 06 14:42:53 2025 AUC 0.911050011646208
#
# [mbo] 52: num_iterations=1309; learning_rate=0.0518; feature_fraction=0.798; num_leaves=8; min_data_in_leaf=18 : y = 0.911 : 28.1 secs : infill_ei
#
# Wed Aug 06 14:43:03 2025 AUC 0.914988737315652
#
# [mbo] 53: num_iterations=200; learning_rate=0.0501; feature_fraction=0.423; num_leaves=8; min_data_in_leaf=436 : y = 0.915 : 9.8 secs : infill_ei
#
# Wed Aug 06 14:43:53 2025 AUC 0.914682020609079
#
# [mbo] 54: num_iterations=1237; learning_rate=0.0502; feature_fraction=0.202; num_leaves=8; min_data_in_leaf=340 : y = 0.915 : 48.6 secs : infill_ei
#
# Saved the current state after iteration 55 in the file bayesiana.RDATA.
#
# Wed Aug 06 14:44:54 2025 AUC 0.909641847428701
#
# [mbo] 55: num_iterations=1500; learning_rate=0.108; feature_fraction=0.2; num_leaves=8; min_data_in_leaf=10 : y = 0.91 : 55.9 secs : infill_ei
#
# Wed Aug 06 14:45:12 2025 AUC 0.915430037375655
#
# [mbo] 56: num_iterations=397; learning_rate=0.05; feature_fraction=0.239; num_leaves=8; min_data_in_leaf=461 : y = 0.915 : 17.0 secs : infill_ei
#
# Wed Aug 06 14:45:31 2025 AUC 0.91409076525182
#
# [mbo] 57: num_iterations=418; learning_rate=0.0502; feature_fraction=0.341; num_leaves=8; min_data_in_leaf=370 : y = 0.914 : 18.2 secs : infill_ei
#
# Wed Aug 06 14:45:48 2025 AUC 0.914428167197392
#
# [mbo] 58: num_iterations=416; learning_rate=0.0648; feature_fraction=0.2; num_leaves=8; min_data_in_leaf=500 : y = 0.914 : 16.3 secs : infill_ei
#
# Wed Aug 06 14:46:04 2025 AUC 0.914515182014822
#
# [mbo] 59: num_iterations=349; learning_rate=0.05; feature_fraction=0.31; num_leaves=8; min_data_in_leaf=460 : y = 0.915 : 15.1 secs : infill_ei
#
# Wed Aug 06 14:46:36 2025 AUC 0.912572711377936
#
# [mbo] 60: num_iterations=830; learning_rate=0.0982; feature_fraction=0.201; num_leaves=8; min_data_in_leaf=221 : y = 0.913 : 31.2 secs : infill_ei
#
# Wed Aug 06 14:46:56 2025 AUC 0.914265584024043
#
# [mbo] 61: num_iterations=451; learning_rate=0.05; feature_fraction=0.201; num_leaves=8; min_data_in_leaf=445 : y = 0.914 : 18.1 secs : infill_ei
#
# Wed Aug 06 14:47:25 2025 AUC 0.912317300876852
#
# [mbo] 62: num_iterations=622; learning_rate=0.0501; feature_fraction=0.219; num_leaves=25; min_data_in_leaf=124 : y = 0.912 : 28.2 secs : infill_ei
#
# Wed Aug 06 14:48:24 2025 AUC 0.914386425946914
#
# [mbo] 63: num_iterations=1452; learning_rate=0.0501; feature_fraction=0.201; num_leaves=11; min_data_in_leaf=498 : y = 0.914 : 57.8 secs : infill_ei
#
# Wed Aug 06 14:48:30 2025 AUC 0.912251772581809
#
# [mbo] 64: num_iterations=200; learning_rate=0.05; feature_fraction=0.8; num_leaves=8; min_data_in_leaf=128 : y = 0.912 : 5.1 secs : infill_ei
#
# Wed Aug 06 14:49:17 2025 AUC 0.912697152751679
#
# [mbo] 65: num_iterations=1209; learning_rate=0.0502; feature_fraction=0.596; num_leaves=18; min_data_in_leaf=342 : y = 0.913 : 46.2 secs : infill_ei
#
# Wed Aug 06 14:49:50 2025 AUC 0.910816910628596
#
# [mbo] 66: num_iterations=837; learning_rate=0.188; feature_fraction=0.218; num_leaves=9; min_data_in_leaf=500 : y = 0.911 : 32.7 secs : infill_ei
#
# Wed Aug 06 14:50:26 2025 AUC 0.914372266551178
#
# [mbo] 67: num_iterations=848; learning_rate=0.0504; feature_fraction=0.201; num_leaves=11; min_data_in_leaf=339 : y = 0.914 : 34.7 secs : infill_ei
#
# Wed Aug 06 14:50:43 2025 AUC 0.914048703590577
#
# [mbo] 68: num_iterations=694; learning_rate=0.0503; feature_fraction=0.798; num_leaves=8; min_data_in_leaf=500 : y = 0.914 : 15.6 secs : infill_ei
#
# Wed Aug 06 14:50:59 2025 AUC 0.912061221822851
#
# [mbo] 69: num_iterations=386; learning_rate=0.0504; feature_fraction=0.201; num_leaves=8; min_data_in_leaf=11 : y = 0.912 : 15.0 secs : infill_ei
#
# Wed Aug 06 14:51:37 2025 AUC 0.911992345884273
#
# [mbo] 70: num_iterations=922; learning_rate=0.0501; feature_fraction=0.247; num_leaves=8; min_data_in_leaf=10 : y = 0.912 : 36.7 secs : infill_ei
#
# Wed Aug 06 14:52:06 2025 AUC 0.912119141271224
#
# [mbo] 71: num_iterations=609; learning_rate=0.0502; feature_fraction=0.475; num_leaves=8; min_data_in_leaf=10 : y = 0.912 : 27.6 secs : infill_ei
#
# Wed Aug 06 14:52:15 2025 AUC 0.914435600102964
#
# [mbo] 72: num_iterations=200; learning_rate=0.161; feature_fraction=0.2; num_leaves=8; min_data_in_leaf=324 : y = 0.914 : 8.1 secs : infill_ei
#
# Wed Aug 06 14:52:24 2025 AUC 0.912233776111753
#
# [mbo] 73: num_iterations=200; learning_rate=0.13; feature_fraction=0.568; num_leaves=8; min_data_in_leaf=287 : y = 0.912 : 8.3 secs : infill_ei
#
# Wed Aug 06 14:52:45 2025 AUC 0.911517893066802
#
# [mbo] 74: num_iterations=398; learning_rate=0.0501; feature_fraction=0.202; num_leaves=27; min_data_in_leaf=286 : y = 0.912 : 19.2 secs : infill_ei
#
# Wed Aug 06 14:53:16 2025 AUC 0.90826092216808
#
# [mbo] 75: num_iterations=1498; learning_rate=0.281; feature_fraction=0.793; num_leaves=8; min_data_in_leaf=296 : y = 0.908 : 30.8 secs : infill_ei
#
# Wed Aug 06 14:53:55 2025 AUC 0.912810713900442
#
# [mbo] 76: num_iterations=1234; learning_rate=0.089; feature_fraction=0.599; num_leaves=8; min_data_in_leaf=161 : y = 0.913 : 37.4 secs : infill_ei
#
# Wed Aug 06 14:54:05 2025 AUC 0.912638364779744
#
# [mbo] 77: num_iterations=200; learning_rate=0.194; feature_fraction=0.257; num_leaves=8; min_data_in_leaf=458 : y = 0.913 : 8.4 secs : infill_ei
#
# Saved the current state after iteration 78 in the file bayesiana.RDATA.
#
# Wed Aug 06 14:54:20 2025 AUC 0.914235514002028
#
# [mbo] 78: num_iterations=396; learning_rate=0.0501; feature_fraction=0.704; num_leaves=8; min_data_in_leaf=488 : y = 0.914 : 10.2 secs : infill_ei
#
# Wed Aug 06 14:54:43 2025 AUC 0.913817261961633
#
# [mbo] 79: num_iterations=521; learning_rate=0.0501; feature_fraction=0.36; num_leaves=8; min_data_in_leaf=136 : y = 0.914 : 22.1 secs : infill_ei
#
# Wed Aug 06 14:55:11 2025 AUC 0.912407635477861
#
# [mbo] 80: num_iterations=1278; learning_rate=0.114; feature_fraction=0.799; num_leaves=8; min_data_in_leaf=335 : y = 0.912 : 26.8 secs : infill_ei
#
# Wed Aug 06 14:55:42 2025 AUC 0.912141311782798
#
# [mbo] 81: num_iterations=792; learning_rate=0.0502; feature_fraction=0.788; num_leaves=28; min_data_in_leaf=500 : y = 0.912 : 30.4 secs : infill_ei
#
# Wed Aug 06 14:56:02 2025 AUC 0.909982350590678
#
# [mbo] 82: num_iterations=542; learning_rate=0.0502; feature_fraction=0.794; num_leaves=24; min_data_in_leaf=118 : y = 0.91 : 18.5 secs : infill_ei
#
# Wed Aug 06 14:56:19 2025 AUC 0.914052050458525
#
# [mbo] 83: num_iterations=392; learning_rate=0.0502; feature_fraction=0.203; num_leaves=10; min_data_in_leaf=172 : y = 0.914 : 16.1 secs : infill_ei
#
# Wed Aug 06 14:57:08 2025 AUC 0.913599613520171
#
# [mbo] 84: num_iterations=1174; learning_rate=0.0502; feature_fraction=0.201; num_leaves=8; min_data_in_leaf=463 : y = 0.914 : 47.5 secs : infill_ei
#
# Wed Aug 06 14:57:18 2025 AUC 0.912216626513221
#
# [mbo] 85: num_iterations=200; learning_rate=0.0933; feature_fraction=0.201; num_leaves=8; min_data_in_leaf=138 : y = 0.912 : 8.1 secs : infill_ei
#
# Wed Aug 06 14:57:50 2025 AUC 0.914584562607989
#
# [mbo] 86: num_iterations=655; learning_rate=0.0502; feature_fraction=0.472; num_leaves=8; min_data_in_leaf=500 : y = 0.915 : 31.2 secs : infill_ei
#
# Wed Aug 06 14:58:19 2025 AUC 0.911457407805081
#
# [mbo] 87: num_iterations=680; learning_rate=0.132; feature_fraction=0.212; num_leaves=16; min_data_in_leaf=324 : y = 0.911 : 28.1 secs : infill_ei
#
# Wed Aug 06 14:58:54 2025 AUC 0.910646825953737
#
# [mbo] 88: num_iterations=1290; learning_rate=0.238; feature_fraction=0.798; num_leaves=14; min_data_in_leaf=500 : y = 0.911 : 33.6 secs : infill_ei
#
# Wed Aug 06 14:59:21 2025 AUC 0.912588874296284
#
# [mbo] 89: num_iterations=649; learning_rate=0.0501; feature_fraction=0.233; num_leaves=9; min_data_in_leaf=161 : y = 0.913 : 25.7 secs : infill_ei
#
# Wed Aug 06 15:00:03 2025 AUC 0.914206982746567
#
# [mbo] 90: num_iterations=1037; learning_rate=0.0501; feature_fraction=0.202; num_leaves=8; min_data_in_leaf=312 : y = 0.914 : 40.7 secs : infill_ei
#
# Wed Aug 06 15:01:00 2025 AUC 0.910348869398117
#
# [mbo] 91: num_iterations=1248; learning_rate=0.0501; feature_fraction=0.203; num_leaves=28; min_data_in_leaf=91 : y = 0.91 : 55.6 secs : infill_ei
#
# Wed Aug 06 15:01:57 2025 AUC 0.915257536571956
#
# [mbo] 92: num_iterations=1450; learning_rate=0.0502; feature_fraction=0.202; num_leaves=9; min_data_in_leaf=447 : y = 0.915 : 56.1 secs : infill_ei
#
# Wed Aug 06 15:03:05 2025 AUC 0.914492312202477
#
# [mbo] 93: num_iterations=1461; learning_rate=0.0531; feature_fraction=0.451; num_leaves=8; min_data_in_leaf=325 : y = 0.914 : 66.1 secs : infill_ei
#
# Wed Aug 06 15:04:03 2025 AUC 0.913269680078694
#
# [mbo] 94: num_iterations=1454; learning_rate=0.0749; feature_fraction=0.218; num_leaves=8; min_data_in_leaf=331 : y = 0.913 : 56.5 secs : infill_ei
#
# Wed Aug 06 15:04:13 2025 AUC 0.899111950778565
#
# [mbo] 95: num_iterations=200; learning_rate=0.499; feature_fraction=0.239; num_leaves=17; min_data_in_leaf=454 : y = 0.899 : 9.2 secs : infill_ei
#
# Saved the current state after iteration 96 in the file bayesiana.RDATA.
#
# Wed Aug 06 15:04:35 2025 AUC 0.912155448460076
#
# [mbo] 96: num_iterations=395; learning_rate=0.17; feature_fraction=0.2; num_leaves=8; min_data_in_leaf=337 : y = 0.912 : 16.2 secs : infill_ei
#
# Wed Aug 06 15:04:44 2025 AUC 0.909066132486046
#
# [mbo] 97: num_iterations=200; learning_rate=0.179; feature_fraction=0.799; num_leaves=28; min_data_in_leaf=452 : y = 0.909 : 7.7 secs : infill_ei
#
# Wed Aug 06 15:05:03 2025 AUC 0.912445882583755
#
# [mbo] 98: num_iterations=819; learning_rate=0.0502; feature_fraction=0.712; num_leaves=8; min_data_in_leaf=500 : y = 0.912 : 18.1 secs : infill_ei
#
# Wed Aug 06 15:05:17 2025 AUC 0.914406168655574
#
# [mbo] 99: num_iterations=551; learning_rate=0.0506; feature_fraction=0.799; num_leaves=8; min_data_in_leaf=500 : y = 0.914 : 12.6 secs : infill_ei
#
# Wed Aug 06 15:05:27 2025 AUC 0.913421313353809
#
# [mbo] 100: num_iterations=200; learning_rate=0.113; feature_fraction=0.229; num_leaves=8; min_data_in_leaf=449 : y = 0.913 : 8.4 secs : infill_ei
#
# Wed Aug 06 15:05:43 2025 AUC 0.912758130658971
#
# [mbo] 101: num_iterations=573; learning_rate=0.143; feature_fraction=0.799; num_leaves=10; min_data_in_leaf=500 : y = 0.913 : 14.2 secs : infill_ei
#
# Wed Aug 06 15:06:24 2025 AUC 0.91407549927328
#
# [mbo] 102: num_iterations=897; learning_rate=0.0686; feature_fraction=0.453; num_leaves=8; min_data_in_leaf=310 : y = 0.914 : 40.6 secs : infill_ei
#
# Wed Aug 06 15:07:16 2025 AUC 0.911050732322315
#
# [mbo] 103: num_iterations=1117; learning_rate=0.0503; feature_fraction=0.531; num_leaves=8; min_data_in_leaf=10 : y = 0.911 : 50.2 secs : infill_ei
#
# Wed Aug 06 15:07:56 2025 AUC 0.910991945374643
#
# [mbo] 104: num_iterations=687; learning_rate=0.0863; feature_fraction=0.555; num_leaves=28; min_data_in_leaf=500 : y = 0.911 : 38.8 secs : infill_ei
#
# Wed Aug 06 15:08:43 2025 AUC 0.911837765347979
#
# [mbo] 105: num_iterations=1191; learning_rate=0.178; feature_fraction=0.2; num_leaves=8; min_data_in_leaf=126 : y = 0.912 : 45.4 secs : infill_ei
#
# Wed Aug 06 15:09:27 2025 AUC 0.908783366468825
#
# [mbo] 106: num_iterations=806; learning_rate=0.0501; feature_fraction=0.407; num_leaves=28; min_data_in_leaf=32 : y = 0.909 : 43.1 secs : infill_ei
#
# Wed Aug 06 15:09:49 2025 AUC 0.913958544132206
#
# [mbo] 107: num_iterations=400; learning_rate=0.0501; feature_fraction=0.415; num_leaves=13; min_data_in_leaf=494 : y = 0.914 : 19.8 secs : infill_ei
#
# Wed Aug 06 15:10:21 2025 AUC 0.914078455058132
#
# [mbo] 108: num_iterations=735; learning_rate=0.0505; feature_fraction=0.254; num_leaves=8; min_data_in_leaf=500 : y = 0.914 : 30.7 secs : infill_ei
#
# Wed Aug 06 15:10:36 2025 AUC 0.913923866262959
#
# [mbo] 109: num_iterations=602; learning_rate=0.05; feature_fraction=0.799; num_leaves=8; min_data_in_leaf=323 : y = 0.914 : 13.9 secs : infill_ei
#
# Wed Aug 06 15:11:09 2025 AUC 0.908630602420953
#
# [mbo] 110: num_iterations=1500; learning_rate=0.143; feature_fraction=0.682; num_leaves=8; min_data_in_leaf=14 : y = 0.909 : 31.0 secs : infill_ei
#
# Wed Aug 06 15:12:11 2025 AUC 0.913334866532216
#
# [mbo] 111: num_iterations=1462; learning_rate=0.05; feature_fraction=0.558; num_leaves=8; min_data_in_leaf=365 : y = 0.913 : 60.4 secs : infill_ei
#
# Wed Aug 06 15:12:53 2025 AUC 0.913880459003444
#
# [mbo] 112: num_iterations=829; learning_rate=0.0502; feature_fraction=0.455; num_leaves=11; min_data_in_leaf=476 : y = 0.914 : 40.3 secs : infill_ei
#
# Wed Aug 06 15:13:16 2025 AUC 0.914265783165236
#
# [mbo] 113: num_iterations=582; learning_rate=0.0544; feature_fraction=0.584; num_leaves=8; min_data_in_leaf=359 : y = 0.914 : 21.7 secs : infill_ei
#
# Wed Aug 06 15:13:49 2025 AUC 0.9144060823107
#
# [mbo] 114: num_iterations=1057; learning_rate=0.0503; feature_fraction=0.628; num_leaves=8; min_data_in_leaf=495 : y = 0.914 : 31.2 secs : infill_ei
#
# Wed Aug 06 15:14:23 2025 AUC 0.913559862490089
#
# [mbo] 115: num_iterations=1258; learning_rate=0.0844; feature_fraction=0.646; num_leaves=8; min_data_in_leaf=500 : y = 0.914 : 33.2 secs : infill_ei
#
# Saved the current state after iteration 116 in the file bayesiana.RDATA.
#
# Wed Aug 06 15:14:50 2025 AUC 0.913880343334156
#
# [mbo] 116: num_iterations=602; learning_rate=0.0506; feature_fraction=0.6; num_leaves=8; min_data_in_leaf=469 : y = 0.914 : 20.5 secs : infill_ei
#
# Wed Aug 06 15:15:45 2025 AUC 0.914471865972279
#
# [mbo] 117: num_iterations=1190; learning_rate=0.0502; feature_fraction=0.373; num_leaves=8; min_data_in_leaf=283 : y = 0.914 : 53.4 secs : infill_ei
#
# Wed Aug 06 15:16:16 2025 AUC 0.913551396177305
#
# [mbo] 118: num_iterations=599; learning_rate=0.0503; feature_fraction=0.43; num_leaves=16; min_data_in_leaf=304 : y = 0.914 : 29.8 secs : infill_ei
#
# Wed Aug 06 15:16:52 2025 AUC 0.913243751229241
#
# [mbo] 119: num_iterations=801; learning_rate=0.0861; feature_fraction=0.29; num_leaves=8; min_data_in_leaf=376 : y = 0.913 : 33.8 secs : infill_ei
#
# Wed Aug 06 15:17:22 2025 AUC 0.912846428185844
#
# [mbo] 120: num_iterations=924; learning_rate=0.0505; feature_fraction=0.642; num_leaves=19; min_data_in_leaf=326 : y = 0.913 : 28.9 secs : infill_ei
#
# Wed Aug 06 15:18:19 2025 AUC 0.913580621859272
#
# [mbo] 121: num_iterations=1289; learning_rate=0.05; feature_fraction=0.329; num_leaves=8; min_data_in_leaf=299 : y = 0.914 : 55.0 secs : infill_ei
#
# Wed Aug 06 15:19:00 2025 AUC 0.914409955617259
#
# [mbo] 122: num_iterations=796; learning_rate=0.0503; feature_fraction=0.307; num_leaves=19; min_data_in_leaf=500 : y = 0.914 : 38.9 secs : infill_ei
#
# Wed Aug 06 15:20:00 2025 AUC 0.913820614842908
#
# [mbo] 123: num_iterations=1253; learning_rate=0.0501; feature_fraction=0.442; num_leaves=8; min_data_in_leaf=463 : y = 0.914 : 58.5 secs : infill_ei
#
# Wed Aug 06 15:20:28 2025 AUC 0.914333968739088
#
# [mbo] 124: num_iterations=547; learning_rate=0.0501; feature_fraction=0.541; num_leaves=8; min_data_in_leaf=225 : y = 0.914 : 26.0 secs : infill_ei
#
# Wed Aug 06 15:20:59 2025 AUC 0.913554102014708
#
# [mbo] 125: num_iterations=895; learning_rate=0.115; feature_fraction=0.59; num_leaves=8; min_data_in_leaf=376 : y = 0.914 : 29.7 secs : infill_ei
#
# Wed Aug 06 15:21:13 2025 AUC 0.912549230495877
#
# [mbo] 126: num_iterations=495; learning_rate=0.0767; feature_fraction=0.8; num_leaves=8; min_data_in_leaf=434 : y = 0.913 : 11.2 secs : infill_ei
#
# Wed Aug 06 15:21:47 2025 AUC 0.914462096581474
#
# [mbo] 127: num_iterations=1426; learning_rate=0.0945; feature_fraction=0.798; num_leaves=8; min_data_in_leaf=500 : y = 0.914 : 31.9 secs : infill_ei
#
# Wed Aug 06 15:22:06 2025 AUC 0.913572713350336
#
# [mbo] 128: num_iterations=383; learning_rate=0.0502; feature_fraction=0.525; num_leaves=8; min_data_in_leaf=166 : y = 0.914 : 17.8 secs : infill_ei
#
# Wed Aug 06 15:22:48 2025 AUC 0.9108902673044
#
# [mbo] 129: num_iterations=885; learning_rate=0.133; feature_fraction=0.2; num_leaves=24; min_data_in_leaf=322 : y = 0.911 : 39.6 secs : infill_ei
#
# Wed Aug 06 15:23:27 2025 AUC 0.912054150954067
#
# [mbo] 130: num_iterations=1428; learning_rate=0.149; feature_fraction=0.723; num_leaves=16; min_data_in_leaf=500 : y = 0.912 : 37.3 secs : infill_ei
#
# Wed Aug 06 15:23:55 2025 AUC 0.912566102584349
#
# [mbo] 131: num_iterations=556; learning_rate=0.142; feature_fraction=0.473; num_leaves=10; min_data_in_leaf=499 : y = 0.913 : 25.9 secs : infill_ei
#
# Wed Aug 06 15:24:12 2025 AUC 0.911550372797645
#
# [mbo] 132: num_iterations=693; learning_rate=0.119; feature_fraction=0.797; num_leaves=9; min_data_in_leaf=187 : y = 0.912 : 16.0 secs : infill_ei
#
# Wed Aug 06 15:24:35 2025 AUC 0.912412829435623
#
# [mbo] 133: num_iterations=707; learning_rate=0.0503; feature_fraction=0.784; num_leaves=19; min_data_in_leaf=345 : y = 0.912 : 21.2 secs : infill_ei
#
# Saved the current state after iteration 134 in the file bayesiana.RDATA.
#
# Wed Aug 06 15:24:53 2025 AUC 0.914259904154542
#
# [mbo] 134: num_iterations=302; learning_rate=0.05; feature_fraction=0.202; num_leaves=8; min_data_in_leaf=498 : y = 0.914 : 12.0 secs : infill_ei
#
# Wed Aug 06 15:26:15 2025 AUC 0.910841036961309
#
# [mbo] 135: num_iterations=1500; learning_rate=0.05; feature_fraction=0.431; num_leaves=28; min_data_in_leaf=177 : y = 0.911 : 80.0 secs : infill_ei
#
# Wed Aug 06 15:26:54 2025 AUC 0.913221416318528
#
# [mbo] 136: num_iterations=1354; learning_rate=0.0502; feature_fraction=0.8; num_leaves=13; min_data_in_leaf=479 : y = 0.913 : 36.1 secs : infill_ei
#
# Wed Aug 06 15:27:05 2025 AUC 0.913578459030112
#
# [mbo] 137: num_iterations=207; learning_rate=0.0501; feature_fraction=0.551; num_leaves=8; min_data_in_leaf=500 : y = 0.914 : 9.2 secs : infill_ei
#
# Wed Aug 06 15:27:16 2025 AUC 0.91217846324576
#
# [mbo] 138: num_iterations=200; learning_rate=0.163; feature_fraction=0.416; num_leaves=8; min_data_in_leaf=354 : y = 0.912 : 9.3 secs : infill_ei
#
# Wed Aug 06 15:27:49 2025 AUC 0.913180104168116
#
# [mbo] 139: num_iterations=1492; learning_rate=0.05; feature_fraction=0.794; num_leaves=8; min_data_in_leaf=485 : y = 0.913 : 32.1 secs : infill_ei
#
# Wed Aug 06 15:28:01 2025 AUC 0.910423585765694
#
# [mbo] 140: num_iterations=200; learning_rate=0.164; feature_fraction=0.2; num_leaves=20; min_data_in_leaf=332 : y = 0.91 : 9.5 secs : infill_ei
#
# Wed Aug 06 15:28:51 2025 AUC 0.913095889055004
#
# [mbo] 141: num_iterations=1033; learning_rate=0.05; feature_fraction=0.582; num_leaves=26; min_data_in_leaf=499 : y = 0.913 : 47.9 secs : infill_ei
#
# Wed Aug 06 15:28:59 2025 AUC 0.913079505246565
#
# [mbo] 142: num_iterations=271; learning_rate=0.142; feature_fraction=0.8; num_leaves=8; min_data_in_leaf=500 : y = 0.913 : 6.4 secs : infill_ei
#
# Wed Aug 06 15:29:47 2025 AUC 0.914477826481486
#
# [mbo] 143: num_iterations=1099; learning_rate=0.0612; feature_fraction=0.336; num_leaves=8; min_data_in_leaf=342 : y = 0.914 : 46.5 secs : infill_ei
#
# Wed Aug 06 15:30:26 2025 AUC 0.914167795185602
#
# [mbo] 144: num_iterations=1000; learning_rate=0.0805; feature_fraction=0.577; num_leaves=8; min_data_in_leaf=500 : y = 0.914 : 36.5 secs : infill_ei
#
# Wed Aug 06 15:30:46 2025 AUC 0.912331476276352
#
# [mbo] 145: num_iterations=540; learning_rate=0.127; feature_fraction=0.597; num_leaves=8; min_data_in_leaf=127 : y = 0.912 : 17.6 secs : infill_ei
#
# Wed Aug 06 15:31:22 2025 AUC 0.914459628390453
#
# [mbo] 146: num_iterations=864; learning_rate=0.0501; feature_fraction=0.244; num_leaves=8; min_data_in_leaf=451 : y = 0.914 : 34.1 secs : infill_ei
#
# Wed Aug 06 15:32:18 2025 AUC 0.913318892074448
#
# [mbo] 147: num_iterations=1222; learning_rate=0.119; feature_fraction=0.392; num_leaves=8; min_data_in_leaf=336 : y = 0.913 : 54.0 secs : infill_ei
#
# Wed Aug 06 15:32:47 2025 AUC 0.913708884151606
#
# [mbo] 148: num_iterations=547; learning_rate=0.0502; feature_fraction=0.285; num_leaves=20; min_data_in_leaf=496 : y = 0.914 : 26.7 secs : infill_ei
#
# Wed Aug 06 15:33:52 2025 AUC 0.911550511069093
#
# [mbo] 149: num_iterations=1435; learning_rate=0.215; feature_fraction=0.462; num_leaves=8; min_data_in_leaf=490 : y = 0.912 : 63.5 secs : infill_ei
#
# Wed Aug 06 15:35:01 2025 AUC 0.913020730436446
#
# [mbo] 150: num_iterations=1455; learning_rate=0.05; feature_fraction=0.2; num_leaves=28; min_data_in_leaf=402 : y = 0.913 : 66.5 secs : infill_ei
#
# Saved the current state after iteration 151 in the file bayesiana.RDATA.
#
# Wed Aug 06 15:35:35 2025 AUC 0.914817857045072
#
# [mbo] 151: num_iterations=547; learning_rate=0.0502; feature_fraction=0.452; num_leaves=8; min_data_in_leaf=468 : y = 0.915 : 25.1 secs : infill_ei
#
# Wed Aug 06 15:35:48 2025 AUC 0.913889150388514
#
# [mbo] 152: num_iterations=261; learning_rate=0.05; feature_fraction=0.428; num_leaves=8; min_data_in_leaf=285 : y = 0.914 : 12.2 secs : infill_ei
#
# Wed Aug 06 15:36:01 2025 AUC 0.912746166479499
#
# [mbo] 153: num_iterations=373; learning_rate=0.0506; feature_fraction=0.8; num_leaves=18; min_data_in_leaf=500 : y = 0.913 : 11.7 secs : infill_ei
#
# Wed Aug 06 15:36:42 2025 AUC 0.910218710633646
#
# [mbo] 154: num_iterations=995; learning_rate=0.233; feature_fraction=0.2; num_leaves=8; min_data_in_leaf=284 : y = 0.91 : 38.7 secs : infill_ei
#
# Wed Aug 06 15:37:40 2025 AUC 0.913315460973411
#
# [mbo] 155: num_iterations=1142; learning_rate=0.05; feature_fraction=0.377; num_leaves=22; min_data_in_leaf=348 : y = 0.913 : 56.4 secs : infill_ei
#
# Wed Aug 06 15:37:55 2025 AUC 0.912991810184427
#
# [mbo] 156: num_iterations=201; learning_rate=0.0504; feature_fraction=0.4; num_leaves=27; min_data_in_leaf=496 : y = 0.913 : 12.3 secs : infill_ei
#
# Wed Aug 06 15:38:52 2025 AUC 0.908295899328646
#
# [mbo] 157: num_iterations=1499; learning_rate=0.364; feature_fraction=0.2; num_leaves=8; min_data_in_leaf=327 : y = 0.908 : 55.4 secs : infill_ei
#
# Wed Aug 06 15:39:07 2025 AUC 0.912516395754474
#
# [mbo] 158: num_iterations=589; learning_rate=0.0501; feature_fraction=0.68; num_leaves=8; min_data_in_leaf=155 : y = 0.913 : 13.0 secs : infill_ei
#
# Wed Aug 06 15:39:14 2025 AUC 0.91130726902702
#
# [mbo] 159: num_iterations=200; learning_rate=0.222; feature_fraction=0.789; num_leaves=8; min_data_in_leaf=227 : y = 0.911 : 4.8 secs : infill_ei
#
# Wed Aug 06 15:39:36 2025 AUC 0.914322620481555
#
# [mbo] 160: num_iterations=387; learning_rate=0.05; feature_fraction=0.493; num_leaves=8; min_data_in_leaf=426 : y = 0.914 : 19.0 secs : infill_ei
#
# Wed Aug 06 15:40:22 2025 AUC 0.912250900586517
#
# [mbo] 161: num_iterations=903; learning_rate=0.098; feature_fraction=0.538; num_leaves=18; min_data_in_leaf=499 : y = 0.912 : 44.1 secs : infill_ei
#
# Wed Aug 06 15:40:34 2025 AUC 0.914206265242536
#
# [mbo] 162: num_iterations=200; learning_rate=0.0501; feature_fraction=0.357; num_leaves=8; min_data_in_leaf=492 : y = 0.914 : 10.2 secs : infill_ei
#
# Wed Aug 06 15:40:56 2025 AUC 0.913212264930166
#
# [mbo] 163: num_iterations=954; learning_rate=0.056; feature_fraction=0.8; num_leaves=8; min_data_in_leaf=104 : y = 0.913 : 20.1 secs : infill_ei
#
# Wed Aug 06 15:41:27 2025 AUC 0.914347621892105
#
# [mbo] 164: num_iterations=999; learning_rate=0.0535; feature_fraction=0.601; num_leaves=8; min_data_in_leaf=218 : y = 0.914 : 29.0 secs : infill_ei
#
# Wed Aug 06 15:42:01 2025 AUC 0.913397707912139
#
# [mbo] 165: num_iterations=1415; learning_rate=0.0502; feature_fraction=0.774; num_leaves=8; min_data_in_leaf=339 : y = 0.913 : 31.2 secs : infill_ei
#
# Wed Aug 06 15:42:48 2025 AUC 0.912320676347854
#
# [mbo] 166: num_iterations=1034; learning_rate=0.0971; feature_fraction=0.378; num_leaves=8; min_data_in_leaf=146 : y = 0.912 : 44.3 secs : infill_ei
#
# Wed Aug 06 15:43:22 2025 AUC 0.912501671899501
#
# [mbo] 167: num_iterations=910; learning_rate=0.0637; feature_fraction=0.577; num_leaves=8; min_data_in_leaf=185 : y = 0.913 : 32.7 secs : infill_ei
#
# Wed Aug 06 15:43:48 2025 AUC 0.912995761367218
#
# [mbo] 168: num_iterations=502; learning_rate=0.0771; feature_fraction=0.481; num_leaves=8; min_data_in_leaf=290 : y = 0.913 : 24.1 secs : infill_ei
#
# Wed Aug 06 15:44:13 2025 AUC 0.91224820940264
#
# [mbo] 169: num_iterations=714; learning_rate=0.22; feature_fraction=0.597; num_leaves=8; min_data_in_leaf=500 : y = 0.912 : 22.3 secs : infill_ei
#
# Wed Aug 06 15:45:25 2025 AUC 0.914462054925276
#
# [mbo] 170: num_iterations=1430; learning_rate=0.0503; feature_fraction=0.422; num_leaves=17; min_data_in_leaf=467 : y = 0.914 : 70.6 secs : infill_ei
#
# Saved the current state after iteration 171 in the file bayesiana.RDATA.
#
# Wed Aug 06 15:46:02 2025 AUC 0.904675136630519
#
# [mbo] 171: num_iterations=1389; learning_rate=0.5; feature_fraction=0.798; num_leaves=8; min_data_in_leaf=480 : y = 0.905 : 29.5 secs : infill_ei
#
# Wed Aug 06 15:46:16 2025 AUC 0.911966054162912
#
# [mbo] 172: num_iterations=291; learning_rate=0.153; feature_fraction=0.2; num_leaves=8; min_data_in_leaf=224 : y = 0.912 : 11.4 secs : infill_ei
#
# Wed Aug 06 15:46:34 2025 AUC 0.914629071817857
#
# [mbo] 173: num_iterations=377; learning_rate=0.05; feature_fraction=0.206; num_leaves=9; min_data_in_leaf=395 : y = 0.915 : 15.0 secs : infill_ei
#
# Wed Aug 06 15:46:58 2025 AUC 0.911585332463947
#
# [mbo] 174: num_iterations=961; learning_rate=0.263; feature_fraction=0.8; num_leaves=8; min_data_in_leaf=500 : y = 0.912 : 21.3 secs : infill_ei
#
# Wed Aug 06 15:47:23 2025 AUC 0.913992772570819
#
# [mbo] 175: num_iterations=1012; learning_rate=0.0556; feature_fraction=0.651; num_leaves=8; min_data_in_leaf=334 : y = 0.914 : 23.1 secs : infill_ei
#
# Wed Aug 06 15:47:52 2025 AUC 0.911883407118312
#
# [mbo] 176: num_iterations=1124; learning_rate=0.0502; feature_fraction=0.726; num_leaves=11; min_data_in_leaf=135 : y = 0.912 : 26.2 secs : infill_ei
#
# Wed Aug 06 15:48:00 2025 AUC 0.908738184269777
#
# [mbo] 177: num_iterations=200; learning_rate=0.146; feature_fraction=0.698; num_leaves=8; min_data_in_leaf=10 : y = 0.909 : 4.8 secs : infill_ei
#
# Wed Aug 06 15:48:36 2025 AUC 0.90985049028878
#
# [mbo] 178: num_iterations=1191; learning_rate=0.274; feature_fraction=0.609; num_leaves=8; min_data_in_leaf=499 : y = 0.91 : 33.6 secs : infill_ei
#
# Wed Aug 06 15:49:25 2025 AUC 0.914033963168252
#
# [mbo] 179: num_iterations=1157; learning_rate=0.0502; feature_fraction=0.273; num_leaves=8; min_data_in_leaf=225 : y = 0.914 : 45.5 secs : infill_ei
#
# Wed Aug 06 15:49:38 2025 AUC 0.912256910774047
#
# [mbo] 180: num_iterations=387; learning_rate=0.202; feature_fraction=0.649; num_leaves=8; min_data_in_leaf=500 : y = 0.912 : 9.7 secs : infill_ei
#
# Wed Aug 06 15:50:19 2025 AUC 0.914304599828076
#
# [mbo] 181: num_iterations=946; learning_rate=0.05; feature_fraction=0.327; num_leaves=8; min_data_in_leaf=320 : y = 0.914 : 38.7 secs : infill_ei
#
# Wed Aug 06 15:50:26 2025 AUC 0.914096415040457
#
# [mbo] 182: num_iterations=200; learning_rate=0.0501; feature_fraction=0.717; num_leaves=8; min_data_in_leaf=350 : y = 0.914 : 5.1 secs : infill_ei
#
# Wed Aug 06 15:50:37 2025 AUC 0.910737940141719
#
# [mbo] 183: num_iterations=200; learning_rate=0.234; feature_fraction=0.201; num_leaves=8; min_data_in_leaf=301 : y = 0.911 : 8.3 secs : infill_ei
#
# Wed Aug 06 15:50:58 2025 AUC 0.9119461007124
#
# [mbo] 184: num_iterations=888; learning_rate=0.188; feature_fraction=0.8; num_leaves=8; min_data_in_leaf=295 : y = 0.912 : 18.6 secs : infill_ei
#
# Wed Aug 06 15:51:18 2025 AUC 0.913464668782569
#
# [mbo] 185: num_iterations=392; learning_rate=0.0501; feature_fraction=0.237; num_leaves=15; min_data_in_leaf=482 : y = 0.913 : 17.1 secs : infill_ei
#
# Wed Aug 06 15:51:48 2025 AUC 0.911859988239816
#
# [mbo] 186: num_iterations=683; learning_rate=0.153; feature_fraction=0.569; num_leaves=8; min_data_in_leaf=330 : y = 0.912 : 26.6 secs : infill_ei
#
# Wed Aug 06 15:52:03 2025 AUC 0.908975284273617
#
# [mbo] 187: num_iterations=532; learning_rate=0.274; feature_fraction=0.798; num_leaves=8; min_data_in_leaf=500 : y = 0.909 : 11.7 secs : infill_ei
#
# Wed Aug 06 15:52:57 2025 AUC 0.913584867316683
#
# [mbo] 188: num_iterations=1083; learning_rate=0.0502; feature_fraction=0.438; num_leaves=13; min_data_in_leaf=285 : y = 0.914 : 51.0 secs : infill_ei
#
# Wed Aug 06 15:53:21 2025 AUC 0.911791513408551
#
# [mbo] 189: num_iterations=557; learning_rate=0.0895; feature_fraction=0.2; num_leaves=11; min_data_in_leaf=71 : y = 0.912 : 21.6 secs : infill_ei
#
# Wed Aug 06 15:54:36 2025 AUC 0.91187308367424
#
# [mbo] 190: num_iterations=1418; learning_rate=0.0501; feature_fraction=0.447; num_leaves=21; min_data_in_leaf=348 : y = 0.912 : 72.7 secs : infill_ei
#
# Wed Aug 06 15:54:50 2025 AUC 0.913805731392569
#
# [mbo] 191: num_iterations=398; learning_rate=0.0501; feature_fraction=0.616; num_leaves=11; min_data_in_leaf=329 : y = 0.914 : 12.2 secs : infill_ei
#
# Wed Aug 06 15:55:59 2025 AUC 0.913059138959459
#
# [mbo] 192: num_iterations=1204; learning_rate=0.0503; feature_fraction=0.382; num_leaves=28; min_data_in_leaf=491 : y = 0.913 : 64.3 secs : infill_ei
#
# Saved the current state after iteration 193 in the file bayesiana.RDATA.
#
# Wed Aug 06 15:56:36 2025 AUC 0.912108982828514
#
# [mbo] 193: num_iterations=975; learning_rate=0.112; feature_fraction=0.607; num_leaves=8; min_data_in_leaf=255 : y = 0.912 : 27.3 secs : infill_ei
#
# Wed Aug 06 15:57:31 2025 AUC 0.913235426650083
#
# [mbo] 194: num_iterations=1346; learning_rate=0.05; feature_fraction=0.2; num_leaves=8; min_data_in_leaf=115 : y = 0.913 : 51.3 secs : infill_ei
#
# Wed Aug 06 15:58:48 2025 AUC 0.906655176061062
#
# [mbo] 195: num_iterations=1500; learning_rate=0.266; feature_fraction=0.292; num_leaves=28; min_data_in_leaf=465 : y = 0.907 : 74.0 secs : infill_ei
#
# Wed Aug 06 15:59:41 2025 AUC 0.913376377423993
#
# [mbo] 196: num_iterations=1123; learning_rate=0.0979; feature_fraction=0.53; num_leaves=8; min_data_in_leaf=477 : y = 0.913 : 50.2 secs : infill_ei
#
# Wed Aug 06 16:00:04 2025 AUC 0.912252195540843
#
# [mbo] 197: num_iterations=913; learning_rate=0.171; feature_fraction=0.8; num_leaves=8; min_data_in_leaf=477 : y = 0.912 : 20.0 secs : infill_ei
#
# Wed Aug 06 16:00:55 2025 AUC 0.912042512183126
#
# [mbo] 198: num_iterations=1243; learning_rate=0.119; feature_fraction=0.201; num_leaves=8; min_data_in_leaf=57 : y = 0.912 : 47.4 secs : infill_ei
#
# Wed Aug 06 16:01:39 2025 AUC 0.912099745772678
#
# [mbo] 199: num_iterations=1141; learning_rate=0.0521; feature_fraction=0.794; num_leaves=28; min_data_in_leaf=500 : y = 0.912 : 41.0 secs : infill_ei
#
# Wed Aug 06 16:02:11 2025 AUC 0.911090815185814
#
# [mbo] 200: num_iterations=1318; learning_rate=0.199; feature_fraction=0.729; num_leaves=8; min_data_in_leaf=156 : y = 0.911 : 28.6 secs : infill_ei
#
# Wed Aug 06 16:02:23 2025 AUC 0.913736183245725
#
# [mbo] 201: num_iterations=200; learning_rate=0.0505; feature_fraction=0.237; num_leaves=8; min_data_in_leaf=324 : y = 0.914 : 8.5 secs : infill_ei
#
# Wed Aug 06 16:02:37 2025 AUC 0.914280479640589
#
# [mbo] 202: num_iterations=203; learning_rate=0.05; feature_fraction=0.448; num_leaves=10; min_data_in_leaf=398 : y = 0.914 : 10.1 secs : infill_ei
#
# Wed Aug 06 16:02:51 2025 AUC 0.913393091641837
#
# [mbo] 203: num_iterations=254; learning_rate=0.05; feature_fraction=0.362; num_leaves=8; min_data_in_leaf=450 : y = 0.913 : 11.5 secs : infill_ei
#
# Wed Aug 06 16:03:04 2025 AUC 0.913430425376715
#
# [mbo] 204: num_iterations=313; learning_rate=0.0507; feature_fraction=0.756; num_leaves=8; min_data_in_leaf=242 : y = 0.913 : 8.8 secs : infill_ei
#
# Wed Aug 06 16:04:11 2025 AUC 0.914142042729638
#
# [mbo] 205: num_iterations=1448; learning_rate=0.0502; feature_fraction=0.405; num_leaves=8; min_data_in_leaf=485 : y = 0.914 : 63.5 secs : infill_ei
#
# Wed Aug 06 16:04:27 2025 AUC 0.913629539270482
#
# [mbo] 206: num_iterations=334; learning_rate=0.0501; feature_fraction=0.203; num_leaves=8; min_data_in_leaf=346 : y = 0.914 : 13.3 secs : infill_ei
#
# Wed Aug 06 16:04:58 2025 AUC 0.912467213982963
#
# [mbo] 207: num_iterations=525; learning_rate=0.0503; feature_fraction=0.434; num_leaves=27; min_data_in_leaf=372 : y = 0.912 : 29.1 secs : infill_ei
#
# Wed Aug 06 16:05:25 2025 AUC 0.912939870823161
#
# [mbo] 208: num_iterations=495; learning_rate=0.0501; feature_fraction=0.295; num_leaves=18; min_data_in_leaf=202 : y = 0.913 : 22.7 secs : infill_ei
#
# Wed Aug 06 16:05:52 2025 AUC 0.91441887235295
#
# [mbo] 209: num_iterations=535; learning_rate=0.0501; feature_fraction=0.308; num_leaves=9; min_data_in_leaf=499 : y = 0.914 : 23.9 secs : infill_ei
#
# Wed Aug 06 16:06:35 2025 AUC 0.913396540888162
#
# [mbo] 210: num_iterations=1433; learning_rate=0.109; feature_fraction=0.617; num_leaves=8; min_data_in_leaf=466 : y = 0.913 : 38.6 secs : infill_ei
#
# Saved the current state after iteration 211 in the file bayesiana.RDATA.
#
# Wed Aug 06 16:06:52 2025 AUC 0.913858622557142
#
# [mbo] 211: num_iterations=202; learning_rate=0.0502; feature_fraction=0.29; num_leaves=12; min_data_in_leaf=206 : y = 0.914 : 9.3 secs : infill_ei
#
# Wed Aug 06 16:07:02 2025 AUC 0.91188045827786
#
# [mbo] 212: num_iterations=200; learning_rate=0.0501; feature_fraction=0.8; num_leaves=20; min_data_in_leaf=276 : y = 0.912 : 7.0 secs : infill_ei
#
# Wed Aug 06 16:07:30 2025 AUC 0.912870974234189
#
# [mbo] 213: num_iterations=545; learning_rate=0.0503; feature_fraction=0.581; num_leaves=19; min_data_in_leaf=496 : y = 0.913 : 24.6 secs : infill_ei
#
# Wed Aug 06 16:08:02 2025 AUC 0.91293104830541
#
# [mbo] 214: num_iterations=1229; learning_rate=0.05; feature_fraction=0.671; num_leaves=8; min_data_in_leaf=232 : y = 0.913 : 28.0 secs : infill_ei
#
# Wed Aug 06 16:09:01 2025 AUC 0.913845591291479
#
# [mbo] 215: num_iterations=1221; learning_rate=0.05; feature_fraction=0.332; num_leaves=16; min_data_in_leaf=388 : y = 0.914 : 56.8 secs : infill_ei
#
# Wed Aug 06 16:09:18 2025 AUC 0.913328908094087
#
# [mbo] 216: num_iterations=300; learning_rate=0.0501; feature_fraction=0.244; num_leaves=11; min_data_in_leaf=107 : y = 0.913 : 13.0 secs : infill_ei
#
# Wed Aug 06 16:09:54 2025 AUC 0.908682416464635
#
# [mbo] 217: num_iterations=999; learning_rate=0.0501; feature_fraction=0.8; num_leaves=27; min_data_in_leaf=106 : y = 0.909 : 33.8 secs : infill_ei
#
# Wed Aug 06 16:10:39 2025 AUC 0.913773295873266
#
# [mbo] 218: num_iterations=886; learning_rate=0.0503; feature_fraction=0.214; num_leaves=24; min_data_in_leaf=494 : y = 0.914 : 41.2 secs : infill_ei
#
# Wed Aug 06 16:11:39 2025 AUC 0.910465274674346
#
# [mbo] 219: num_iterations=1311; learning_rate=0.222; feature_fraction=0.416; num_leaves=8; min_data_in_leaf=112 : y = 0.91 : 57.3 secs : infill_ei
#
# Wed Aug 06 16:12:43 2025 AUC 0.914445754371806
#
# [mbo] 220: num_iterations=1499; learning_rate=0.0502; feature_fraction=0.226; num_leaves=10; min_data_in_leaf=287 : y = 0.914 : 60.5 secs : infill_ei
#
# ...
#
# Wed Aug 06 16:44:03 2025 AUC 0.91326797981208
#
# [mbo] 272: num_iterations=565; learning_rate=0.0503; feature_fraction=0.311; num_leaves=8; min_data_in_leaf=374 : y = 0.913 : 24.5 secs : infill_ei
#
# Wed Aug 06 16:44:30 2025 AUC 0.91293035347735
#
# [mbo] 273: num_iterations=588; learning_rate=0.0502; feature_fraction=0.2; num_leaves=19; min_data_in_leaf=378 : y = 0.913 : 25.3 secs : infill_ei
#
# Wed Aug 06 16:45:13 2025 AUC 0.913282583998829
#
# [mbo] 274: num_iterations=1055; learning_rate=0.0501; feature_fraction=0.585; num_leaves=8; min_data_in_leaf=404 : y = 0.913 : 37.7 secs : infill_ei
#
# Wed Aug 06 16:45:38 2025 AUC 0.913640813791336
#
# [mbo] 275: num_iterations=987; learning_rate=0.0504; feature_fraction=0.794; num_leaves=8; min_data_in_leaf=223 : y = 0.914 : 21.7 secs : infill_ei
#
# Wed Aug 06 16:45:58 2025 AUC 0.912310214699714
#
# [mbo] 276: num_iterations=575; learning_rate=0.05; feature_fraction=0.638; num_leaves=12; min_data_in_leaf=268 : y = 0.912 : 16.0 secs : infill_ei
#
# Wed Aug 06 16:46:15 2025 AUC 0.912902760934539
#
# [mbo] 277: num_iterations=276; learning_rate=0.05; feature_fraction=0.42; num_leaves=13; min_data_in_leaf=238 : y = 0.913 : 13.7 secs : infill_ei
#
# Wed Aug 06 16:47:17 2025 AUC 0.912435799308531
#
# [mbo] 278: num_iterations=1182; learning_rate=0.0823; feature_fraction=0.434; num_leaves=18; min_data_in_leaf=500 : y = 0.912 : 59.5 secs : infill_ei
#
# Wed Aug 06 16:47:49 2025 AUC 0.91421187954857
#
# [mbo] 279: num_iterations=528; learning_rate=0.05; feature_fraction=0.494; num_leaves=13; min_data_in_leaf=378 : y = 0.914 : 27.2 secs : infill_ei
#
# Wed Aug 06 16:48:52 2025 AUC 0.914961777952192
#
# [mbo] 280: num_iterations=1434; learning_rate=0.05; feature_fraction=0.301; num_leaves=8; min_data_in_leaf=459 : y = 0.915 : 58.0 secs : infill_ei
#
# Saved the current state after iteration 281 in the file bayesiana.RDATA.
#
# Wed Aug 06 16:50:09 2025 AUC 0.913914305737545
#
# [mbo] 281: num_iterations=1496; learning_rate=0.0501; feature_fraction=0.347; num_leaves=15; min_data_in_leaf=390 : y = 0.914 : 68.8 secs : infill_ei
#
# Wed Aug 06 16:51:06 2025 AUC 0.913336037602126
#
# [mbo] 282: num_iterations=1107; learning_rate=0.0501; feature_fraction=0.48; num_leaves=8; min_data_in_leaf=208 : y = 0.913 : 53.1 secs : infill_ei
#
# Wed Aug 06 16:51:23 2025 AUC 0.911409318999662
#
# [mbo] 283: num_iterations=200; learning_rate=0.0502; feature_fraction=0.408; num_leaves=28; min_data_in_leaf=277 : y = 0.911 : 12.2 secs : infill_ei
#
# Wed Aug 06 16:52:01 2025 AUC 0.913139710346536
#
# [mbo] 284: num_iterations=1000; learning_rate=0.0502; feature_fraction=0.597; num_leaves=8; min_data_in_leaf=99 : y = 0.913 : 32.6 secs : infill_ei
#
# Wed Aug 06 16:53:00 2025 AUC 0.912995753026695
#
# [mbo] 285: num_iterations=1177; learning_rate=0.0504; feature_fraction=0.461; num_leaves=8; min_data_in_leaf=330 : y = 0.913 : 54.0 secs : infill_ei
#
# Wed Aug 06 16:53:40 2025 AUC 0.912384619696065
#
# [mbo] 286: num_iterations=687; learning_rate=0.0501; feature_fraction=0.445; num_leaves=16; min_data_in_leaf=140 : y = 0.912 : 34.1 secs : infill_ei
#
# Wed Aug 06 16:54:42 2025 AUC 0.912514617597284
#
# [mbo] 287: num_iterations=1360; learning_rate=0.05; feature_fraction=0.345; num_leaves=8; min_data_in_leaf=60 : y = 0.913 : 57.8 secs : infill_ei
#
# Wed Aug 06 16:55:22 2025 AUC 0.913982740886016
#
# [mbo] 288: num_iterations=874; learning_rate=0.0534; feature_fraction=0.2; num_leaves=8; min_data_in_leaf=395 : y = 0.914 : 33.9 secs : infill_ei
#
# Wed Aug 06 16:56:10 2025 AUC 0.913715788251738
#
# [mbo] 289: num_iterations=989; learning_rate=0.0996; feature_fraction=0.335; num_leaves=8; min_data_in_leaf=464 : y = 0.914 : 42.8 secs : infill_ei
#
# Wed Aug 06 16:56:40 2025 AUC 0.910349847312977
#
# [mbo] 290: num_iterations=405; learning_rate=0.165; feature_fraction=0.403; num_leaves=28; min_data_in_leaf=500 : y = 0.91 : 23.6 secs : infill_ei
#
# Wed Aug 06 16:58:13 2025 AUC 0.91311581020906
#
# [mbo] 291: num_iterations=1462; learning_rate=0.05; feature_fraction=0.443; num_leaves=28; min_data_in_leaf=500 : y = 0.913 : 85.6 secs : infill_ei
#
# Wed Aug 06 16:58:39 2025 AUC 0.914470525178929
#
# [mbo] 292: num_iterations=959; learning_rate=0.0503; feature_fraction=0.65; num_leaves=8; min_data_in_leaf=462 : y = 0.914 : 22.7 secs : infill_ei
#
# Wed Aug 06 16:59:20 2025 AUC 0.912798253134578
#
# [mbo] 293: num_iterations=681; learning_rate=0.0502; feature_fraction=0.49; num_leaves=15; min_data_in_leaf=451 : y = 0.913 : 35.7 secs : infill_ei
#
# Saved the current state after iteration 294 in the file bayesiana.RDATA.
#
# Wed Aug 06 17:00:36 2025 AUC 0.914405307287478
#
# [mbo] 294: num_iterations=1433; learning_rate=0.05; feature_fraction=0.513; num_leaves=8; min_data_in_leaf=465 : y = 0.914 : 66.0 secs : infill_ei
#
# Wed Aug 06 17:00:56 2025 AUC 0.913690530641404
#
# [mbo] 295: num_iterations=298; learning_rate=0.05; feature_fraction=0.518; num_leaves=8; min_data_in_leaf=351 : y = 0.914 : 14.4 secs : infill_ei
#
# Wed Aug 06 17:01:37 2025 AUC 0.913700474434275
#
# [mbo] 296: num_iterations=1500; learning_rate=0.0502; feature_fraction=0.64; num_leaves=9; min_data_in_leaf=316 : y = 0.914 : 37.0 secs : infill_ei
#
# Wed Aug 06 17:02:25 2025 AUC 0.912886710478116
#
# [mbo] 297: num_iterations=1001; learning_rate=0.0504; feature_fraction=0.412; num_leaves=8; min_data_in_leaf=243 : y = 0.913 : 43.7 secs : infill_ei
#
# Wed Aug 06 17:03:33 2025 AUC 0.913471018108069
#
# [mbo] 298: num_iterations=1500; learning_rate=0.0625; feature_fraction=0.374; num_leaves=8; min_data_in_leaf=302 : y = 0.913 : 64.4 secs : infill_ei
#
# Wed Aug 06 17:04:27 2025 AUC 0.913824672730744
#
# [mbo] 299: num_iterations=1137; learning_rate=0.135; feature_fraction=0.316; num_leaves=8; min_data_in_leaf=268 : y = 0.914 : 47.3 secs : infill_ei
#
# Wed Aug 06 17:04:53 2025 AUC 0.913414882192741
#
# [mbo] 300: num_iterations=749; learning_rate=0.0618; feature_fraction=0.632; num_leaves=8; min_data_in_leaf=398 : y = 0.913 : 19.0 secs : infill_ei
#
# Wed Aug 06 17:05:33 2025 AUC 0.912893085218647
#
# [mbo] 301: num_iterations=838; learning_rate=0.0504; feature_fraction=0.2; num_leaves=11; min_data_in_leaf=107 : y = 0.913 : 33.4 secs : infill_ei
#
# Wed Aug 06 17:06:27 2025 AUC 0.912670056113406
#
# [mbo] 302: num_iterations=1225; learning_rate=0.13; feature_fraction=0.345; num_leaves=8; min_data_in_leaf=210 : y = 0.913 : 50.4 secs : infill_ei
#
# Wed Aug 06 17:07:24 2025 AUC 0.910729373701702
#
# [mbo] 303: num_iterations=1342; learning_rate=0.0502; feature_fraction=0.587; num_leaves=19; min_data_in_leaf=88 : y = 0.911 : 54.4 secs : infill_ei
#
# Wed Aug 06 17:07:47 2025 AUC 0.912019404233588
#
# [mbo] 304: num_iterations=489; learning_rate=0.0502; feature_fraction=0.708; num_leaves=28; min_data_in_leaf=500 : y = 0.912 : 19.9 secs : infill_ei
#
# Wed Aug 06 17:08:44 2025 AUC 0.913663363837355
#
# [mbo] 305: num_iterations=1159; learning_rate=0.0503; feature_fraction=0.299; num_leaves=11; min_data_in_leaf=310 : y = 0.914 : 50.1 secs : infill_ei
#
# Wed Aug 06 17:09:50 2025 AUC 0.913491893250839
#
# [mbo] 306: num_iterations=1498; learning_rate=0.0501; feature_fraction=0.201; num_leaves=14; min_data_in_leaf=217 : y = 0.913 : 62.3 secs : infill_ei
#
# Saved the current state after iteration 307 in the file bayesiana.RDATA.
#
# Wed Aug 06 17:10:35 2025 AUC 0.914619670888327
#
# [mbo] 307: num_iterations=708; learning_rate=0.0501; feature_fraction=0.382; num_leaves=8; min_data_in_leaf=499 : y = 0.915 : 32.3 secs : infill_ei
#
# Wed Aug 06 17:11:25 2025 AUC 0.913418832916843
#
# [mbo] 308: num_iterations=1093; learning_rate=0.0503; feature_fraction=0.2; num_leaves=10; min_data_in_leaf=364 : y = 0.913 : 43.6 secs : infill_ei
#
# Wed Aug 06 17:12:23 2025 AUC 0.912082637084578
#
# [mbo] 309: num_iterations=1082; learning_rate=0.05; feature_fraction=0.579; num_leaves=28; min_data_in_leaf=281 : y = 0.912 : 55.4 secs : infill_ei
#
# Wed Aug 06 17:12:44 2025 AUC 0.913172867918308
#
# [mbo] 310: num_iterations=622; learning_rate=0.0521; feature_fraction=0.8; num_leaves=15; min_data_in_leaf=496 : y = 0.913 : 17.9 secs : infill_ei
#
# Wed Aug 06 17:13:38 2025 AUC 0.914282402944974
#
# [mbo] 311: num_iterations=1136; learning_rate=0.0503; feature_fraction=0.352; num_leaves=8; min_data_in_leaf=465 : y = 0.914 : 48.5 secs : infill_ei
#
# Wed Aug 06 17:14:12 2025 AUC 0.912834033757588
#
# [mbo] 312: num_iterations=554; learning_rate=0.0501; feature_fraction=0.457; num_leaves=17; min_data_in_leaf=408 : y = 0.913 : 29.5 secs : infill_ei
#
# Wed Aug 06 17:14:48 2025 AUC 0.913595251668326
#
# [mbo] 313: num_iterations=1374; learning_rate=0.0504; feature_fraction=0.732; num_leaves=8; min_data_in_leaf=500 : y = 0.914 : 30.0 secs : infill_ei
#
# Wed Aug 06 17:15:00 2025 AUC 0.911896493226585
#
# [mbo] 314: num_iterations=200; learning_rate=0.0502; feature_fraction=0.667; num_leaves=19; min_data_in_leaf=182 : y = 0.912 : 6.7 secs : infill_ei
#
# Wed Aug 06 17:15:18 2025 AUC 0.913039267179428
#
# [mbo] 315: num_iterations=648; learning_rate=0.0504; feature_fraction=0.745; num_leaves=8; min_data_in_leaf=380 : y = 0.913 : 15.6 secs : infill_ei
#
# Wed Aug 06 17:16:22 2025 AUC 0.912444922908616
#
# [mbo] 316: num_iterations=1499; learning_rate=0.0507; feature_fraction=0.64; num_leaves=27; min_data_in_leaf=500 : y = 0.912 : 59.7 secs : infill_ei
#
# Wed Aug 06 17:16:33 2025 AUC 0.914894270690839
#
# [mbo] 317: num_iterations=200; learning_rate=0.0506; feature_fraction=0.727; num_leaves=8; min_data_in_leaf=432 : y = 0.915 : 5.3 secs : infill_ei
#
# Wed Aug 06 17:17:14 2025 AUC 0.911209815779877
#
# [mbo] 318: num_iterations=1080; learning_rate=0.0504; feature_fraction=0.697; num_leaves=23; min_data_in_leaf=381 : y = 0.911 : 36.9 secs : infill_ei
#
# Wed Aug 06 17:17:43 2025 AUC 0.911048949587305
#
# [mbo] 319: num_iterations=701; learning_rate=0.0517; feature_fraction=0.7; num_leaves=28; min_data_in_leaf=499 : y = 0.911 : 26.2 secs : infill_ei
#
# Wed Aug 06 17:18:43 2025 AUC 0.914439593174516
#
# [mbo] 320: num_iterations=1424; learning_rate=0.0501; feature_fraction=0.219; num_leaves=8; min_data_in_leaf=420 : y = 0.914 : 55.7 secs : infill_ei
#
# Wed Aug 06 17:19:02 2025 AUC 0.912923015531671
#
# [mbo] 321: num_iterations=423; learning_rate=0.0503; feature_fraction=0.685; num_leaves=21; min_data_in_leaf=380 : y = 0.913 : 14.3 secs : infill_ei
#
# Wed Aug 06 17:19:32 2025 AUC 0.913609956969161
#
# [mbo] 322: num_iterations=699; learning_rate=0.05; feature_fraction=0.605; num_leaves=8; min_data_in_leaf=218 : y = 0.914 : 21.7 secs : infill_ei
#
# Wed Aug 06 17:20:55 2025 AUC 0.909724056841147
#
# [mbo] 323: num_iterations=1446; learning_rate=0.152; feature_fraction=0.558; num_leaves=28; min_data_in_leaf=500 : y = 0.91 : 75.4 secs : infill_ei
#
# Saved the current state after iteration 324 in the file bayesiana.RDATA.
#
# Wed Aug 06 17:21:22 2025 AUC 0.911878877799732
#
# [mbo] 324: num_iterations=377; learning_rate=0.0505; feature_fraction=0.211; num_leaves=23; min_data_in_leaf=145 : y = 0.912 : 17.6 secs : infill_ei
#
# Wed Aug 06 17:22:11 2025 AUC 0.910822471661701
#
# [mbo] 325: num_iterations=794; learning_rate=0.0587; feature_fraction=0.567; num_leaves=28; min_data_in_leaf=361 : y = 0.911 : 41.6 secs : infill_ei
#
# Wed Aug 06 17:22:34 2025 AUC 0.913618381017513
#
# [mbo] 326: num_iterations=442; learning_rate=0.0502; feature_fraction=0.201; num_leaves=8; min_data_in_leaf=121 : y = 0.914 : 17.2 secs : infill_ei
#
# Wed Aug 06 17:23:43 2025 AUC 0.913034411255922
#
# [mbo] 327: num_iterations=1218; learning_rate=0.0517; feature_fraction=0.33; num_leaves=28; min_data_in_leaf=273 : y = 0.913 : 61.0 secs : infill_ei
#
# Wed Aug 06 17:24:20 2025 AUC 0.91370151047397
#
# [mbo] 328: num_iterations=913; learning_rate=0.05; feature_fraction=0.574; num_leaves=8; min_data_in_leaf=428 : y = 0.914 : 34.1 secs : infill_ei
#
# Wed Aug 06 17:24:30 2025 AUC 0.91378336555701
#
# [mbo] 329: num_iterations=244; learning_rate=0.0523; feature_fraction=0.741; num_leaves=8; min_data_in_leaf=493 : y = 0.914 : 6.9 secs : infill_ei
#
# Wed Aug 06 17:24:55 2025 AUC 0.912284326317098
#
# [mbo] 330: num_iterations=887; learning_rate=0.195; feature_fraction=0.623; num_leaves=8; min_data_in_leaf=500 : y = 0.912 : 22.6 secs : infill_ei
#
# Wed Aug 06 17:25:28 2025 AUC 0.913652875582549
#
# [mbo] 331: num_iterations=750; learning_rate=0.0508; feature_fraction=0.201; num_leaves=8; min_data_in_leaf=297 : y = 0.914 : 28.3 secs : infill_ei
#
# Wed Aug 06 17:25:43 2025 AUC 0.914151095846322
#
# [mbo] 332: num_iterations=200; learning_rate=0.0503; feature_fraction=0.264; num_leaves=8; min_data_in_leaf=466 : y = 0.914 : 8.6 secs : infill_ei
#
# Wed Aug 06 17:25:58 2025 AUC 0.911674659595118
#
# [mbo] 333: num_iterations=201; learning_rate=0.147; feature_fraction=0.306; num_leaves=8; min_data_in_leaf=365 : y = 0.912 : 8.6 secs : infill_ei
#
# Wed Aug 06 17:26:23 2025 AUC 0.912820844018169
#
# [mbo] 334: num_iterations=412; learning_rate=0.0501; feature_fraction=0.332; num_leaves=26; min_data_in_leaf=500 : y = 0.913 : 21.1 secs : infill_ei
#
# Wed Aug 06 17:26:44 2025 AUC 0.91324093848982
#
# [mbo] 335: num_iterations=432; learning_rate=0.05; feature_fraction=0.593; num_leaves=9; min_data_in_leaf=115 : y = 0.913 : 15.8 secs : infill_ei
#
# Wed Aug 06 17:27:23 2025 AUC 0.913667431683823
#
# [mbo] 336: num_iterations=732; learning_rate=0.05; feature_fraction=0.439; num_leaves=8; min_data_in_leaf=357 : y = 0.914 : 32.7 secs : infill_ei
#
# Wed Aug 06 17:27:47 2025 AUC 0.912824587655592
#
# [mbo] 337: num_iterations=427; learning_rate=0.05; feature_fraction=0.312; num_leaves=8; min_data_in_leaf=66 : y = 0.913 : 19.0 secs : infill_ei
#
# Wed Aug 06 17:28:42 2025 AUC 0.896547474662386
#
# [mbo] 338: num_iterations=1496; learning_rate=0.5; feature_fraction=0.2; num_leaves=8; min_data_in_leaf=33 : y = 0.897 : 50.9 secs : infill_ei
#
# Wed Aug 06 17:29:25 2025 AUC 0.913280546887012
#
# [mbo] 339: num_iterations=812; learning_rate=0.0634; feature_fraction=0.326; num_leaves=11; min_data_in_leaf=495 : y = 0.913 : 35.8 secs : infill_ei
#
# Wed Aug 06 17:30:43 2025 AUC 0.912479003386914
#
# [mbo] 340: num_iterations=1500; learning_rate=0.0502; feature_fraction=0.291; num_leaves=28; min_data_in_leaf=302 : y = 0.912 : 73.7 secs : infill_ei
#
# Wed Aug 06 17:31:28 2025 AUC 0.914408718222654
#
# [mbo] 341: num_iterations=937; learning_rate=0.0504; feature_fraction=0.3; num_leaves=8; min_data_in_leaf=275 : y = 0.914 : 39.3 secs : infill_ei
#
# Saved the current state after iteration 342 in the file bayesiana.RDATA.
#
# Wed Aug 06 17:31:52 2025 AUC 0.91216173126523
#
# [mbo] 342: num_iterations=597; learning_rate=0.05; feature_fraction=0.705; num_leaves=8; min_data_in_leaf=69 : y = 0.912 : 13.0 secs : infill_ei
#
# Wed Aug 06 17:32:09 2025 AUC 0.913038411762373
#
# [mbo] 343: num_iterations=541; learning_rate=0.124; feature_fraction=0.661; num_leaves=10; min_data_in_leaf=495 : y = 0.913 : 13.3 secs : infill_ei
#
# Wed Aug 06 17:32:32 2025 AUC 0.913074118196792
#
# [mbo] 344: num_iterations=871; learning_rate=0.0504; feature_fraction=0.8; num_leaves=8; min_data_in_leaf=302 : y = 0.913 : 19.2 secs : infill_ei
#
# Wed Aug 06 17:32:41 2025 AUC 0.911904732037979
#
# [mbo] 345: num_iterations=200; learning_rate=0.0813; feature_fraction=0.781; num_leaves=8; min_data_in_leaf=320 : y = 0.912 : 5.0 secs : infill_ei
#
# Wed Aug 06 17:33:04 2025 AUC 0.913793325462475
#
# [mbo] 346: num_iterations=270; learning_rate=0.0512; feature_fraction=0.416; num_leaves=8; min_data_in_leaf=375 : y = 0.914 : 13.3 secs : infill_ei
#
# Wed Aug 06 17:33:52 2025 AUC 0.913755009564545
#
# [mbo] 347: num_iterations=910; learning_rate=0.116; feature_fraction=0.46; num_leaves=8; min_data_in_leaf=476 : y = 0.914 : 43.1 secs : infill_ei
#
# Wed Aug 06 17:34:10 2025 AUC 0.913091592140145
#
# [mbo] 348: num_iterations=201; learning_rate=0.107; feature_fraction=0.324; num_leaves=8; min_data_in_leaf=270 : y = 0.913 : 9.1 secs : infill_ei
#
# Wed Aug 06 17:35:04 2025 AUC 0.913070437923852
#
# [mbo] 349: num_iterations=1117; learning_rate=0.0649; feature_fraction=0.2; num_leaves=16; min_data_in_leaf=339 : y = 0.913 : 46.3 secs : infill_ei
#
# Wed Aug 06 17:35:35 2025 AUC 0.913727556490515
#
# [mbo] 350: num_iterations=554; learning_rate=0.0511; feature_fraction=0.538; num_leaves=11; min_data_in_leaf=336 : y = 0.914 : 26.3 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "num_iterations"   "learning_rate"    "feature_fraction" "num_leaves"
#  [5] "min_data_in_leaf" "y"                "dob"              "eol"
#  [9] "error.message"    "exec.time"        "ei"               "error.model"
# [13] "train.time"       "prop.type"        "propose.time"     "se"
# [17] "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    num_iterations learning_rate feature_fraction num_leaves min_data_in_leaf
#             <int>         <num>            <num>      <int>            <int>
# 1:           1450     0.0500089        0.2002222          8              465
# [1] 0.9155959

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]
dataset_train <- rbindlist(list(dataset_train, dataset_train[clase01 == 1L][, clase01 := 0L]))

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 888757
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 0
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 1
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1450
#
# $learning_rate
# [1] 0.0500089
#
# $feature_fraction
# [1] 0.2002222
#
# $num_leaves
# [1] 8
#
# $min_data_in_leaf
# [1] 465

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Wed Aug 06 17:38:56 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
