# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# Esta Tarea para el Hogar 02 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el viernes 01-agosto

# %% [markdown]
# ##  1. Cazatalentos

# %% [markdown]
# En la Clase 03 nos hemos enfrentado a  "La Maldicion del Ganandor",  elegir el modelo con el mejor puntaje simple no suele ser la mejor estrategia.
# <br> Lea y ejecute el notebook  **src/CazaTalentos/CazaTalentos.ipynb**
# <br> en caso de interesarle, participe del Desafío Ordenamiento  que vence el sábado 02 de agosto a las 19:00

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dm"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dm" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/itba2025-8d0a/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Wed Jul 30 03:15:51 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  656930 35.1 1439371    76.9 1431351  76.5
# Vcells 1224847  9.4 8388608    64.0 1924958  14.7

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 4967
PARAM$semilla_primigenia <- 333757

# %%
PARAM$kaggle$competencia <- "data-mining-analista-sr-2025-a"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 2000,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeNumericParam("learning_rate",       lower = 0.001,  upper = 0.3),
  makeIntegerParam("num_leaves",          lower = 20L,    upper = 2048L),
  makeIntegerParam("min_data_in_leaf",    lower = 10L,    upper = 8000L),
  makeNumericParam("feature_fraction",    lower = 0.1,    upper = 1.0),
  makeNumericParam("lambda_l2",           lower = 0.0,    upper = 15.0)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 600 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83552
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Wed Jul 30 03:18:48 2025 AUC 0.92542960499435
#
# Wed Jul 30 03:20:06 2025 AUC 0.925576910313022
#
# Wed Jul 30 03:21:07 2025 AUC 0.926039466347214
#
# Wed Jul 30 03:22:48 2025 AUC 0.925176786601903
#
# Wed Jul 30 03:24:08 2025 AUC 0.925974407829675
#
# Wed Jul 30 03:25:38 2025 AUC 0.923575132801374
#
# Wed Jul 30 03:26:24 2025 AUC 0.923182327846666
#
# Wed Jul 30 03:28:18 2025 AUC 0.928365267894321
#
# Wed Jul 30 03:29:44 2025 AUC 0.926035380361946
#
# Wed Jul 30 03:31:28 2025 AUC 0.92421450775192
#
# Wed Jul 30 03:33:01 2025 AUC 0.929698641003163
#
# Wed Jul 30 03:33:58 2025 AUC 0.925324032247262
#
# Wed Jul 30 03:35:34 2025 AUC 0.926929724720129
#
# Wed Jul 30 03:36:41 2025 AUC 0.92631227937884
#
# Wed Jul 30 03:37:47 2025 AUC 0.923291768508322
#
# Wed Jul 30 03:39:02 2025 AUC 0.923617720895456
#
# Wed Jul 30 03:39:52 2025 AUC 0.924951497628002
#
# Wed Jul 30 03:40:38 2025 AUC 0.924395096790715
#
# Wed Jul 30 03:41:54 2025 AUC 0.924247331219626
#
# Wed Jul 30 03:43:49 2025 AUC 0.928330099917876
#
# [mbo] 0: learning_rate=0.0639; num_leaves=1546; min_data_in_leaf=2507; feature_fraction=0.236; lambda_l2=9.99 : y = 0.925 : 93.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.113; num_leaves=1318; min_data_in_leaf=6104; feature_fraction=0.587; lambda_l2=6.94 : y = 0.926 : 77.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.169; num_leaves=690; min_data_in_leaf=3269; feature_fraction=0.831; lambda_l2=9.01 : y = 0.926 : 60.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.155; num_leaves=1001; min_data_in_leaf=2996; feature_fraction=0.534; lambda_l2=13.2 : y = 0.925 : 100.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0819; num_leaves=1444; min_data_in_leaf=4209; feature_fraction=0.191; lambda_l2=5.84 : y = 0.926 : 80.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.2; num_leaves=1357; min_data_in_leaf=7582; feature_fraction=0.478; lambda_l2=4.34 : y = 0.924 : 90.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.29; num_leaves=495; min_data_in_leaf=6785; feature_fraction=0.684; lambda_l2=3.24 : y = 0.923 : 46.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.135; num_leaves=784; min_data_in_leaf=574; feature_fraction=0.623; lambda_l2=8.16 : y = 0.928 : 114.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.237; num_leaves=1136; min_data_in_leaf=4685; feature_fraction=0.299; lambda_l2=12 : y = 0.926 : 85.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.224; num_leaves=1887; min_data_in_leaf=2222; feature_fraction=0.38; lambda_l2=2.76 : y = 0.924 : 104.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0276; num_leaves=66; min_data_in_leaf=54; feature_fraction=0.695; lambda_l2=0.751 : y = 0.93 : 92.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.189; num_leaves=1649; min_data_in_leaf=3926; feature_fraction=0.987; lambda_l2=8.32 : y = 0.925 : 57.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0493; num_leaves=854; min_data_in_leaf=5123; feature_fraction=0.437; lambda_l2=14.3 : y = 0.927 : 96.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.00347; num_leaves=306; min_data_in_leaf=1448; feature_fraction=0.899; lambda_l2=11.6 : y = 0.926 : 67.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.14; num_leaves=540; min_data_in_leaf=5788; feature_fraction=0.102; lambda_l2=4.96 : y = 0.923 : 65.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.284; num_leaves=2014; min_data_in_leaf=7060; feature_fraction=0.179; lambda_l2=2.09 : y = 0.924 : 74.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.245; num_leaves=182; min_data_in_leaf=5327; feature_fraction=0.919; lambda_l2=14.1 : y = 0.925 : 50.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0436; num_leaves=1104; min_data_in_leaf=7949; feature_fraction=0.764; lambda_l2=6.54 : y = 0.924 : 45.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.259; num_leaves=330; min_data_in_leaf=1725; feature_fraction=0.808; lambda_l2=0.0416 : y = 0.924 : 76.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.103; num_leaves=1831; min_data_in_leaf=963; feature_fraction=0.337; lambda_l2=10.9 : y = 0.928 : 115.3 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Wed Jul 30 03:49:41 2025 AUC 0.926091279302081
#
# [mbo] 1: learning_rate=0.0012; num_leaves=1329; min_data_in_leaf=10; feature_fraction=0.329; lambda_l2=4.08 : y = 0.926 : 347.3 secs : infill_ei
#
# Wed Jul 30 03:50:36 2025 AUC 0.929059725108697
#
# [mbo] 2: learning_rate=0.0521; num_leaves=20; min_data_in_leaf=202; feature_fraction=0.867; lambda_l2=5.11 : y = 0.929 : 54.8 secs : infill_ei
#
# Wed Jul 30 03:52:14 2025 AUC 0.929818883088645
#
# [mbo] 3: learning_rate=0.0635; num_leaves=22; min_data_in_leaf=301; feature_fraction=0.505; lambda_l2=0.0122 : y = 0.93 : 96.9 secs : infill_ei
#
# Wed Jul 30 03:53:04 2025 AUC 0.927289832336381
#
# [mbo] 4: learning_rate=0.0531; num_leaves=20; min_data_in_leaf=17; feature_fraction=0.925; lambda_l2=0.32 : y = 0.927 : 49.9 secs : infill_ei
#
# Wed Jul 30 03:54:58 2025 AUC 0.92879331816677
#
# [mbo] 5: learning_rate=0.0562; num_leaves=71; min_data_in_leaf=190; feature_fraction=0.623; lambda_l2=4.2 : y = 0.929 : 113.0 secs : infill_ei
#
# Saved the current state after iteration 6 in the file bayesiana.RDATA.
#
# Wed Jul 30 03:57:44 2025 AUC 0.928435276973268
#
# [mbo] 6: learning_rate=0.0295; num_leaves=289; min_data_in_leaf=304; feature_fraction=0.627; lambda_l2=0.346 : y = 0.928 : 161.2 secs : infill_ei
#
# Wed Jul 30 03:59:19 2025 AUC 0.928394389474465
#
# [mbo] 7: learning_rate=0.0718; num_leaves=20; min_data_in_leaf=13; feature_fraction=0.494; lambda_l2=0.742 : y = 0.928 : 94.0 secs : infill_ei
#
# Wed Jul 30 04:01:31 2025 AUC 0.928194146403744
#
# [mbo] 8: learning_rate=0.0374; num_leaves=105; min_data_in_leaf=121; feature_fraction=0.757; lambda_l2=4.01 : y = 0.928 : 131.2 secs : infill_ei
#
# Wed Jul 30 04:03:24 2025 AUC 0.929443137694052
#
# [mbo] 9: learning_rate=0.0455; num_leaves=41; min_data_in_leaf=550; feature_fraction=0.547; lambda_l2=0.0271 : y = 0.929 : 112.5 secs : infill_ei
#
# Wed Jul 30 04:04:42 2025 AUC 0.927041702252488
#
# [mbo] 10: learning_rate=0.0586; num_leaves=22; min_data_in_leaf=1606; feature_fraction=0.602; lambda_l2=0.0626 : y = 0.927 : 77.2 secs : infill_ei
#
# Wed Jul 30 04:06:11 2025 AUC 0.929308197066434
#
# [mbo] 11: learning_rate=0.0544; num_leaves=56; min_data_in_leaf=14; feature_fraction=0.651; lambda_l2=5.37 : y = 0.929 : 89.3 secs : infill_ei
#
# Saved the current state after iteration 12 in the file bayesiana.RDATA.
#
# Wed Jul 30 04:08:00 2025 AUC 0.93018077924092
#
# [mbo] 12: learning_rate=0.0522; num_leaves=23; min_data_in_leaf=367; feature_fraction=0.509; lambda_l2=3.58 : y = 0.93 : 102.3 secs : infill_ei
#
# Wed Jul 30 04:10:22 2025 AUC 0.927358670657877
#
# [mbo] 13: learning_rate=0.145; num_leaves=207; min_data_in_leaf=467; feature_fraction=0.499; lambda_l2=6.94 : y = 0.927 : 141.7 secs : infill_ei
#
# Wed Jul 30 04:13:09 2025 AUC 0.929439218622432
#
# [mbo] 14: learning_rate=0.055; num_leaves=1272; min_data_in_leaf=386; feature_fraction=0.513; lambda_l2=1.39 : y = 0.929 : 166.5 secs : infill_ei
#
# Wed Jul 30 04:17:11 2025 AUC 0.926896688332953
#
# [mbo] 15: learning_rate=0.0539; num_leaves=447; min_data_in_leaf=85; feature_fraction=0.512; lambda_l2=0.0806 : y = 0.927 : 241.1 secs : infill_ei
#
# Saved the current state after iteration 16 in the file bayesiana.RDATA.
#
# Wed Jul 30 04:19:38 2025 AUC 0.928253565830431
#
# [mbo] 16: learning_rate=0.0701; num_leaves=278; min_data_in_leaf=413; feature_fraction=0.591; lambda_l2=1.97 : y = 0.928 : 142.8 secs : infill_ei
#
# Wed Jul 30 04:21:55 2025 AUC 0.929268732770053
#
# [mbo] 17: learning_rate=0.0478; num_leaves=307; min_data_in_leaf=515; feature_fraction=0.393; lambda_l2=2.62 : y = 0.929 : 136.2 secs : infill_ei
#
# Wed Jul 30 04:24:07 2025 AUC 0.929658653942766
#
# [mbo] 18: learning_rate=0.0649; num_leaves=61; min_data_in_leaf=483; feature_fraction=0.485; lambda_l2=9.04 : y = 0.93 : 131.2 secs : infill_ei
#
# Wed Jul 30 04:25:23 2025 AUC 0.929718010750925
#
# [mbo] 19: learning_rate=0.0534; num_leaves=22; min_data_in_leaf=502; feature_fraction=0.127; lambda_l2=6.05 : y = 0.93 : 76.1 secs : infill_ei
#
# Wed Jul 30 04:27:24 2025 AUC 0.928633352862124
#
# [mbo] 20: learning_rate=0.0549; num_leaves=91; min_data_in_leaf=380; feature_fraction=0.694; lambda_l2=8.51 : y = 0.929 : 120.0 secs : infill_ei
#
# Saved the current state after iteration 21 in the file bayesiana.RDATA.
#
# Wed Jul 30 04:29:05 2025 AUC 0.931527705043068
#
# [mbo] 21: learning_rate=0.0157; num_leaves=20; min_data_in_leaf=398; feature_fraction=0.442; lambda_l2=1.82 : y = 0.932 : 96.5 secs : infill_ei
#
# Wed Jul 30 04:31:19 2025 AUC 0.930110057150347
#
# [mbo] 22: learning_rate=0.0304; num_leaves=1188; min_data_in_leaf=769; feature_fraction=0.48; lambda_l2=6.94 : y = 0.93 : 133.1 secs : infill_ei
#
# Wed Jul 30 04:32:52 2025 AUC 0.930975828252027
#
# [mbo] 23: learning_rate=0.0189; num_leaves=20; min_data_in_leaf=450; feature_fraction=0.374; lambda_l2=1.73 : y = 0.931 : 92.7 secs : infill_ei
#
# Wed Jul 30 04:34:56 2025 AUC 0.929949643255158
#
# [mbo] 24: learning_rate=0.0492; num_leaves=2048; min_data_in_leaf=781; feature_fraction=0.587; lambda_l2=6.68 : y = 0.93 : 122.8 secs : infill_ei
#
# Wed Jul 30 04:37:05 2025 AUC 0.931043680560647
#
# [mbo] 25: learning_rate=0.00454; num_leaves=315; min_data_in_leaf=385; feature_fraction=0.341; lambda_l2=6.88 : y = 0.931 : 128.2 secs : infill_ei
#
# Wed Jul 30 04:39:00 2025 AUC 0.92519530105538
#
# [mbo] 26: learning_rate=0.00159; num_leaves=1607; min_data_in_leaf=582; feature_fraction=0.497; lambda_l2=12.1 : y = 0.925 : 114.8 secs : infill_ei
#
# Saved the current state after iteration 27 in the file bayesiana.RDATA.
#
# Wed Jul 30 04:40:54 2025 AUC 0.93062916255074
#
# [mbo] 27: learning_rate=0.0135; num_leaves=27; min_data_in_leaf=83; feature_fraction=0.511; lambda_l2=10.8 : y = 0.931 : 109.0 secs : infill_ei
#
# Wed Jul 30 04:42:35 2025 AUC 0.921365653280641
#
# [mbo] 28: learning_rate=0.00108; num_leaves=46; min_data_in_leaf=350; feature_fraction=0.283; lambda_l2=11 : y = 0.921 : 100.5 secs : infill_ei
#
# Wed Jul 30 04:44:35 2025 AUC 0.93109057097382
#
# [mbo] 29: learning_rate=0.00796; num_leaves=45; min_data_in_leaf=546; feature_fraction=0.412; lambda_l2=3.26 : y = 0.931 : 118.9 secs : infill_ei
#
# Wed Jul 30 04:46:51 2025 AUC 0.929953188055956
#
# [mbo] 30: learning_rate=0.0108; num_leaves=367; min_data_in_leaf=608; feature_fraction=0.518; lambda_l2=6.64 : y = 0.93 : 135.3 secs : infill_ei
#
# Wed Jul 30 04:49:05 2025 AUC 0.929432827440608
#
# [mbo] 31: learning_rate=0.00464; num_leaves=363; min_data_in_leaf=383; feature_fraction=0.352; lambda_l2=5.07 : y = 0.929 : 133.1 secs : infill_ei
#
# Saved the current state after iteration 32 in the file bayesiana.RDATA.
#
# Wed Jul 30 04:51:06 2025 AUC 0.930437265551882
#
# [mbo] 32: learning_rate=0.0232; num_leaves=36; min_data_in_leaf=176; feature_fraction=0.481; lambda_l2=7.49 : y = 0.93 : 115.0 secs : infill_ei
#
# Wed Jul 30 04:52:45 2025 AUC 0.930049582292997
#
# [mbo] 33: learning_rate=0.0189; num_leaves=22; min_data_in_leaf=659; feature_fraction=0.434; lambda_l2=0.00551 : y = 0.93 : 98.7 secs : infill_ei
#
# Wed Jul 30 04:54:43 2025 AUC 0.930953431210352
#
# [mbo] 34: learning_rate=0.00979; num_leaves=39; min_data_in_leaf=557; feature_fraction=0.452; lambda_l2=5.37 : y = 0.931 : 117.4 secs : infill_ei
#
# Wed Jul 30 04:56:47 2025 AUC 0.929836013238874
#
# [mbo] 35: learning_rate=0.0381; num_leaves=296; min_data_in_leaf=587; feature_fraction=0.338; lambda_l2=11.1 : y = 0.93 : 123.1 secs : infill_ei
#
# Wed Jul 30 04:58:52 2025 AUC 0.929933332925336
#
# [mbo] 36: learning_rate=0.0249; num_leaves=286; min_data_in_leaf=695; feature_fraction=0.374; lambda_l2=7.07 : y = 0.93 : 123.6 secs : infill_ei
#
# Wed Jul 30 05:00:32 2025 AUC 0.928321008242554
#
# [mbo] 37: learning_rate=0.0177; num_leaves=21; min_data_in_leaf=2949; feature_fraction=0.452; lambda_l2=3.04 : y = 0.928 : 99.9 secs : infill_ei
#
# Saved the current state after iteration 38 in the file bayesiana.RDATA.
#
# Wed Jul 30 05:02:00 2025 AUC 0.918232463868964
#
# [mbo] 38: learning_rate=0.0021; num_leaves=81; min_data_in_leaf=4807; feature_fraction=0.341; lambda_l2=10.4 : y = 0.918 : 82.2 secs : infill_ei
#
# Wed Jul 30 05:04:10 2025 AUC 0.929245101619193
#
# [mbo] 39: learning_rate=0.0232; num_leaves=742; min_data_in_leaf=451; feature_fraction=0.619; lambda_l2=6.87 : y = 0.929 : 128.5 secs : infill_ei
#
# Wed Jul 30 05:05:36 2025 AUC 0.931555113055106
#
# [mbo] 40: learning_rate=0.00899; num_leaves=20; min_data_in_leaf=37; feature_fraction=0.244; lambda_l2=6.9 : y = 0.932 : 86.1 secs : infill_ei
#
# Wed Jul 30 05:08:09 2025 AUC 0.92861703436563
#
# [mbo] 41: learning_rate=0.0135; num_leaves=151; min_data_in_leaf=15; feature_fraction=0.207; lambda_l2=7.3 : y = 0.929 : 151.3 secs : infill_ei
#
# Wed Jul 30 05:10:45 2025 AUC 0.929940507714871
#
# [mbo] 42: learning_rate=0.0108; num_leaves=94; min_data_in_leaf=269; feature_fraction=0.509; lambda_l2=1.74 : y = 0.93 : 155.6 secs : infill_ei
#
# Saved the current state after iteration 43 in the file bayesiana.RDATA.
#
# Wed Jul 30 05:13:21 2025 AUC 0.928721808633434
#
# [mbo] 43: learning_rate=0.0168; num_leaves=121; min_data_in_leaf=16; feature_fraction=0.892; lambda_l2=11.5 : y = 0.929 : 151.5 secs : infill_ei
#
# Wed Jul 30 05:15:54 2025 AUC 0.929639049106902
#
# [mbo] 44: learning_rate=0.0503; num_leaves=1146; min_data_in_leaf=560; feature_fraction=0.517; lambda_l2=5.49 : y = 0.93 : 152.4 secs : infill_ei
#
# Wed Jul 30 05:19:46 2025 AUC 0.930094066340609
#
# [mbo] 45: learning_rate=0.0127; num_leaves=315; min_data_in_leaf=42; feature_fraction=0.279; lambda_l2=11 : y = 0.93 : 231.4 secs : infill_ei
#
# Wed Jul 30 05:21:01 2025 AUC 0.930177838996256
#
# [mbo] 46: learning_rate=0.0166; num_leaves=34; min_data_in_leaf=323; feature_fraction=0.836; lambda_l2=1.38 : y = 0.93 : 74.2 secs : infill_ei
#
# Saved the current state after iteration 47 in the file bayesiana.RDATA.
#
# Wed Jul 30 05:23:38 2025 AUC 0.929117032480341
#
# [mbo] 47: learning_rate=0.00779; num_leaves=173; min_data_in_leaf=300; feature_fraction=0.575; lambda_l2=6.87 : y = 0.929 : 152.2 secs : infill_ei
#
# Wed Jul 30 05:25:30 2025 AUC 0.930617009235931
#
# [mbo] 48: learning_rate=0.00785; num_leaves=184; min_data_in_leaf=661; feature_fraction=0.286; lambda_l2=6.6 : y = 0.931 : 111.1 secs : infill_ei
#
# Wed Jul 30 05:27:15 2025 AUC 0.930557744034802
#
# [mbo] 49: learning_rate=0.00982; num_leaves=66; min_data_in_leaf=152; feature_fraction=0.147; lambda_l2=3.93 : y = 0.931 : 103.8 secs : infill_ei
#
# Wed Jul 30 05:28:49 2025 AUC 0.928863984204132
#
# [mbo] 50: learning_rate=0.00783; num_leaves=293; min_data_in_leaf=1518; feature_fraction=0.257; lambda_l2=7.79 : y = 0.929 : 92.9 secs : infill_ei
#
# Wed Jul 30 05:33:31 2025 AUC 0.930233541735239
#
# [mbo] 51: learning_rate=0.021; num_leaves=341; min_data_in_leaf=20; feature_fraction=0.501; lambda_l2=10.8 : y = 0.93 : 281.1 secs : infill_ei
#
# Saved the current state after iteration 52 in the file bayesiana.RDATA.
#
# Wed Jul 30 05:35:12 2025 AUC 0.931109346875372
#
# [mbo] 52: learning_rate=0.0461; num_leaves=21; min_data_in_leaf=389; feature_fraction=0.405; lambda_l2=6.3 : y = 0.931 : 95.4 secs : infill_ei
#
# Wed Jul 30 05:36:38 2025 AUC 0.930749264860356
#
# [mbo] 53: learning_rate=0.0266; num_leaves=20; min_data_in_leaf=166; feature_fraction=0.268; lambda_l2=5.61 : y = 0.931 : 85.9 secs : infill_ei
#
# Wed Jul 30 05:38:45 2025 AUC 0.930232806673804
#
# [mbo] 54: learning_rate=0.0148; num_leaves=179; min_data_in_leaf=629; feature_fraction=0.36; lambda_l2=3.07 : y = 0.93 : 125.6 secs : infill_ei
#
# Wed Jul 30 05:42:20 2025 AUC 0.92853392597957
#
# [mbo] 55: learning_rate=0.00423; num_leaves=332; min_data_in_leaf=80; feature_fraction=0.807; lambda_l2=6.5 : y = 0.929 : 214.0 secs : infill_ei
#
# Wed Jul 30 05:44:28 2025 AUC 0.928987749016733
#
# [mbo] 56: learning_rate=0.00522; num_leaves=121; min_data_in_leaf=188; feature_fraction=0.194; lambda_l2=8.26 : y = 0.929 : 127.1 secs : infill_ei
#
# Saved the current state after iteration 57 in the file bayesiana.RDATA.
#
# Wed Jul 30 05:47:49 2025 AUC 0.928648539393168
#
# [mbo] 57: learning_rate=0.0423; num_leaves=331; min_data_in_leaf=128; feature_fraction=0.386; lambda_l2=6.56 : y = 0.929 : 196.9 secs : infill_ei
#
# Wed Jul 30 05:49:27 2025 AUC 0.930410357672507
#
# [mbo] 58: learning_rate=0.0108; num_leaves=20; min_data_in_leaf=30; feature_fraction=0.402; lambda_l2=2.72 : y = 0.93 : 96.0 secs : infill_ei
#
# Wed Jul 30 05:51:31 2025 AUC 0.930426896622088
#
# [mbo] 59: learning_rate=0.0286; num_leaves=48; min_data_in_leaf=55; feature_fraction=0.518; lambda_l2=8.69 : y = 0.93 : 123.3 secs : infill_ei
#
# Wed Jul 30 05:53:48 2025 AUC 0.929186200748057
#
# [mbo] 60: learning_rate=0.0653; num_leaves=1562; min_data_in_leaf=786; feature_fraction=0.52; lambda_l2=5.83 : y = 0.929 : 136.1 secs : infill_ei
#
# Wed Jul 30 05:56:09 2025 AUC 0.930423915519515
#
# [mbo] 61: learning_rate=0.0276; num_leaves=457; min_data_in_leaf=544; feature_fraction=0.542; lambda_l2=11.4 : y = 0.93 : 139.4 secs : infill_ei
#
# Saved the current state after iteration 62 in the file bayesiana.RDATA.
#
# Wed Jul 30 05:58:17 2025 AUC 0.930888873680415
#
# [mbo] 62: learning_rate=0.00637; num_leaves=866; min_data_in_leaf=509; feature_fraction=0.274; lambda_l2=6.21 : y = 0.931 : 121.5 secs : infill_ei
#
# Wed Jul 30 06:00:15 2025 AUC 0.929067725895941
#
# [mbo] 63: learning_rate=0.0026; num_leaves=277; min_data_in_leaf=510; feature_fraction=0.395; lambda_l2=7.58 : y = 0.929 : 117.4 secs : infill_ei
#
# Wed Jul 30 06:02:29 2025 AUC 0.931394290062713
#
# [mbo] 64: learning_rate=0.018; num_leaves=472; min_data_in_leaf=403; feature_fraction=0.315; lambda_l2=10.3 : y = 0.931 : 132.9 secs : infill_ei
#
# Wed Jul 30 06:04:07 2025 AUC 0.921692473984068
#
# [mbo] 65: learning_rate=0.00114; num_leaves=409; min_data_in_leaf=618; feature_fraction=0.276; lambda_l2=6.89 : y = 0.922 : 97.2 secs : infill_ei
#
# Wed Jul 30 06:08:57 2025 AUC 0.929584914838211
#
# [mbo] 66: learning_rate=0.00435; num_leaves=1345; min_data_in_leaf=34; feature_fraction=0.41; lambda_l2=7.87 : y = 0.93 : 289.2 secs : infill_ei
#
# Saved the current state after iteration 67 in the file bayesiana.RDATA.
#
# Wed Jul 30 06:11:02 2025 AUC 0.929376860396346
#
# [mbo] 67: learning_rate=0.0179; num_leaves=969; min_data_in_leaf=397; feature_fraction=0.186; lambda_l2=12.3 : y = 0.929 : 117.7 secs : infill_ei
#
# Wed Jul 30 06:11:57 2025 AUC 0.924154765550052
#
# [mbo] 68: learning_rate=0.204; num_leaves=1326; min_data_in_leaf=4611; feature_fraction=0.966; lambda_l2=12.1 : y = 0.924 : 54.5 secs : infill_ei
#
# Wed Jul 30 06:13:46 2025 AUC 0.929542476923923
#
# [mbo] 69: learning_rate=0.00415; num_leaves=829; min_data_in_leaf=584; feature_fraction=0.273; lambda_l2=14.4 : y = 0.93 : 108.4 secs : infill_ei
#
# Wed Jul 30 06:15:33 2025 AUC 0.929551994840486
#
# [mbo] 70: learning_rate=0.0154; num_leaves=713; min_data_in_leaf=1049; feature_fraction=0.243; lambda_l2=1.31 : y = 0.93 : 105.9 secs : infill_ei
#
# Wed Jul 30 06:17:02 2025 AUC 0.924628475464814
#
# [mbo] 71: learning_rate=0.184; num_leaves=787; min_data_in_leaf=7374; feature_fraction=0.407; lambda_l2=3.99 : y = 0.925 : 88.0 secs : infill_ei
#
# Wed Jul 30 06:19:08 2025 AUC 0.928915880374623
#
# [mbo] 72: learning_rate=0.037; num_leaves=617; min_data_in_leaf=527; feature_fraction=0.785; lambda_l2=2.04 : y = 0.929 : 125.5 secs : infill_ei
#
# Saved the current state after iteration 73 in the file bayesiana.RDATA.
#
# Wed Jul 30 06:22:57 2025 AUC 0.929290403556092
#
# [mbo] 73: learning_rate=0.0154; num_leaves=471; min_data_in_leaf=106; feature_fraction=0.464; lambda_l2=11.7 : y = 0.929 : 224.3 secs : infill_ei
#
# Wed Jul 30 06:24:57 2025 AUC 0.930660954198262
#
# [mbo] 74: learning_rate=0.018; num_leaves=380; min_data_in_leaf=716; feature_fraction=0.275; lambda_l2=3.09 : y = 0.931 : 118.5 secs : infill_ei
#
# Wed Jul 30 06:26:29 2025 AUC 0.927433301232023
#
# [mbo] 75: learning_rate=0.165; num_leaves=128; min_data_in_leaf=992; feature_fraction=0.753; lambda_l2=14.9 : y = 0.927 : 91.5 secs : infill_ei
#
# Wed Jul 30 06:28:01 2025 AUC 0.931375509515424
#
# [mbo] 76: learning_rate=0.0165; num_leaves=20; min_data_in_leaf=268; feature_fraction=0.282; lambda_l2=9.53 : y = 0.931 : 90.9 secs : infill_ei
#
# Wed Jul 30 06:29:42 2025 AUC 0.931044368283979
#
# [mbo] 77: learning_rate=0.0175; num_leaves=27; min_data_in_leaf=59; feature_fraction=0.401; lambda_l2=6.53 : y = 0.931 : 100.3 secs : infill_ei
#
# Saved the current state after iteration 78 in the file bayesiana.RDATA.
#
# Wed Jul 30 06:33:43 2025 AUC 0.929338265822164
#
# [mbo] 78: learning_rate=0.00887; num_leaves=565; min_data_in_leaf=75; feature_fraction=0.328; lambda_l2=3.22 : y = 0.929 : 234.4 secs : infill_ei
#
# Wed Jul 30 06:35:57 2025 AUC 0.930893520981119
#
# [mbo] 79: learning_rate=0.00869; num_leaves=947; min_data_in_leaf=353; feature_fraction=0.298; lambda_l2=12 : y = 0.931 : 133.0 secs : infill_ei
#
# Wed Jul 30 06:40:02 2025 AUC 0.929855570285822
#
# [mbo] 80: learning_rate=0.0201; num_leaves=522; min_data_in_leaf=38; feature_fraction=0.262; lambda_l2=7.3 : y = 0.93 : 243.6 secs : infill_ei
#
# Saved the current state after iteration 81 in the file bayesiana.RDATA.
#
# Wed Jul 30 06:41:45 2025 AUC 0.922706998629395
#
# [mbo] 81: learning_rate=0.248; num_leaves=494; min_data_in_leaf=912; feature_fraction=0.172; lambda_l2=5.98 : y = 0.923 : 96.5 secs : infill_ei
#
# Wed Jul 30 06:43:59 2025 AUC 0.92976898881767
#
# [mbo] 82: learning_rate=0.0178; num_leaves=257; min_data_in_leaf=408; feature_fraction=0.344; lambda_l2=8.67 : y = 0.93 : 133.2 secs : infill_ei
#
# Wed Jul 30 06:47:43 2025 AUC 0.929712056283435
#
# [mbo] 83: learning_rate=0.00497; num_leaves=290; min_data_in_leaf=71; feature_fraction=0.414; lambda_l2=8.37 : y = 0.93 : 222.7 secs : infill_ei
#
# Wed Jul 30 06:51:56 2025 AUC 0.928754670062751
#
# [mbo] 84: learning_rate=0.0164; num_leaves=450; min_data_in_leaf=61; feature_fraction=0.41; lambda_l2=4.95 : y = 0.929 : 251.4 secs : infill_ei
#
# Saved the current state after iteration 85 in the file bayesiana.RDATA.
#
# Wed Jul 30 06:53:07 2025 AUC 0.926221228972184
#
# [mbo] 85: learning_rate=0.023; num_leaves=1892; min_data_in_leaf=5363; feature_fraction=0.614; lambda_l2=1.31 : y = 0.926 : 66.2 secs : infill_ei
#
# Wed Jul 30 06:54:36 2025 AUC 0.924387353569199
#
# [mbo] 86: learning_rate=0.221; num_leaves=1698; min_data_in_leaf=2359; feature_fraction=0.23; lambda_l2=13.9 : y = 0.924 : 88.3 secs : infill_ei
#
# Wed Jul 30 06:56:07 2025 AUC 0.927909770642609
#
# [mbo] 87: learning_rate=0.00547; num_leaves=125; min_data_in_leaf=2256; feature_fraction=0.31; lambda_l2=12.7 : y = 0.928 : 90.1 secs : infill_ei
#
# Wed Jul 30 06:57:33 2025 AUC 0.930855191347949
#
# [mbo] 88: learning_rate=0.0171; num_leaves=20; min_data_in_leaf=633; feature_fraction=0.226; lambda_l2=10.5 : y = 0.931 : 84.9 secs : infill_ei
#
# Wed Jul 30 06:59:40 2025 AUC 0.93001845803872
#
# [mbo] 89: learning_rate=0.0482; num_leaves=76; min_data_in_leaf=298; feature_fraction=0.294; lambda_l2=6.63 : y = 0.93 : 125.6 secs : infill_ei
#
# Wed Jul 30 07:01:40 2025 AUC 0.931418630586829
#
# [mbo] 90: learning_rate=0.00906; num_leaves=722; min_data_in_leaf=823; feature_fraction=0.391; lambda_l2=13.8 : y = 0.931 : 118.6 secs : infill_ei
#
# Wed Jul 30 07:03:15 2025 AUC 0.929383218989949
#
# [mbo] 91: learning_rate=0.00823; num_leaves=1075; min_data_in_leaf=628; feature_fraction=0.124; lambda_l2=14.1 : y = 0.929 : 94.1 secs : infill_ei
#
# Saved the current state after iteration 92 in the file bayesiana.RDATA.
#
# Wed Jul 30 07:04:56 2025 AUC 0.926107524218931
#
# [mbo] 92: learning_rate=0.172; num_leaves=574; min_data_in_leaf=3187; feature_fraction=0.376; lambda_l2=12.1 : y = 0.926 : 95.8 secs : infill_ei
#
# Wed Jul 30 07:06:16 2025 AUC 0.924828160263162
#
# [mbo] 93: learning_rate=0.183; num_leaves=246; min_data_in_leaf=4707; feature_fraction=0.222; lambda_l2=4.13 : y = 0.925 : 79.2 secs : infill_ei
#
# Wed Jul 30 07:08:26 2025 AUC 0.929687290157153
#
# [mbo] 94: learning_rate=0.00544; num_leaves=474; min_data_in_leaf=496; feature_fraction=0.57; lambda_l2=9.6 : y = 0.93 : 128.9 secs : infill_ei
#
# Wed Jul 30 07:10:29 2025 AUC 0.926487182124533
#
# [mbo] 95: learning_rate=0.186; num_leaves=1339; min_data_in_leaf=384; feature_fraction=0.676; lambda_l2=13.4 : y = 0.926 : 121.7 secs : infill_ei
#
# Wed Jul 30 07:11:57 2025 AUC 0.923059385327645
#
# [mbo] 96: learning_rate=0.288; num_leaves=1310; min_data_in_leaf=5122; feature_fraction=0.349; lambda_l2=5.05 : y = 0.923 : 87.3 secs : infill_ei
#
# Wed Jul 30 07:13:25 2025 AUC 0.924615800432654
#
# [mbo] 97: learning_rate=0.157; num_leaves=1485; min_data_in_leaf=2243; feature_fraction=0.21; lambda_l2=8.73 : y = 0.925 : 87.5 secs : infill_ei
#
# Saved the current state after iteration 98 in the file bayesiana.RDATA.
#
# Wed Jul 30 07:15:22 2025 AUC 0.928127585085154
#
# [mbo] 98: learning_rate=0.00767; num_leaves=800; min_data_in_leaf=1512; feature_fraction=0.505; lambda_l2=12.3 : y = 0.928 : 111.3 secs : infill_ei
#
# Wed Jul 30 07:17:25 2025 AUC 0.930054259013937
#
# [mbo] 99: learning_rate=0.00581; num_leaves=281; min_data_in_leaf=487; feature_fraction=0.353; lambda_l2=10.5 : y = 0.93 : 122.4 secs : infill_ei
#
# Wed Jul 30 07:19:30 2025 AUC 0.930395891801025
#
# [mbo] 100: learning_rate=0.00996; num_leaves=233; min_data_in_leaf=448; feature_fraction=0.308; lambda_l2=12 : y = 0.93 : 123.5 secs : infill_ei
#
# Wed Jul 30 07:20:22 2025 AUC 0.925374308412395
#
# [mbo] 101: learning_rate=0.0405; num_leaves=996; min_data_in_leaf=5196; feature_fraction=0.673; lambda_l2=11.7 : y = 0.925 : 51.3 secs : infill_ei
#
# Wed Jul 30 07:21:30 2025 AUC 0.926329853183957
#
# [mbo] 102: learning_rate=0.133; num_leaves=144; min_data_in_leaf=2419; feature_fraction=0.692; lambda_l2=0.205 : y = 0.926 : 66.8 secs : infill_ei
#
# Wed Jul 30 07:23:06 2025 AUC 0.928558613272251
#
# [mbo] 103: learning_rate=0.0268; num_leaves=769; min_data_in_leaf=1100; feature_fraction=0.191; lambda_l2=7.53 : y = 0.929 : 95.6 secs : infill_ei
#
# Wed Jul 30 07:25:34 2025 AUC 0.930040672031839
#
# [mbo] 104: learning_rate=0.016; num_leaves=488; min_data_in_leaf=472; feature_fraction=0.512; lambda_l2=10.7 : y = 0.93 : 146.9 secs : infill_ei
#
# Saved the current state after iteration 105 in the file bayesiana.RDATA.
#
# Wed Jul 30 07:29:57 2025 AUC 0.927214310862972
#
# [mbo] 105: learning_rate=0.0183; num_leaves=998; min_data_in_leaf=16; feature_fraction=0.129; lambda_l2=6.08 : y = 0.927 : 256.6 secs : infill_ei
#
# Wed Jul 30 07:31:44 2025 AUC 0.930241714852129
#
# [mbo] 106: learning_rate=0.0104; num_leaves=717; min_data_in_leaf=679; feature_fraction=0.225; lambda_l2=14.1 : y = 0.93 : 105.8 secs : infill_ei
#
# Wed Jul 30 07:33:52 2025 AUC 0.929341063065721
#
# [mbo] 107: learning_rate=0.0642; num_leaves=1092; min_data_in_leaf=578; feature_fraction=0.596; lambda_l2=10.7 : y = 0.929 : 126.9 secs : infill_ei
#
# Wed Jul 30 07:35:18 2025 AUC 0.927836590174771
#
# [mbo] 108: learning_rate=0.0181; num_leaves=576; min_data_in_leaf=1278; feature_fraction=0.128; lambda_l2=13.1 : y = 0.928 : 85.0 secs : infill_ei
#
# Wed Jul 30 07:37:35 2025 AUC 0.927689944652899
#
# [mbo] 109: learning_rate=0.0479; num_leaves=442; min_data_in_leaf=401; feature_fraction=0.75; lambda_l2=1.18 : y = 0.928 : 135.8 secs : infill_ei
#
# Saved the current state after iteration 110 in the file bayesiana.RDATA.
#
# Wed Jul 30 07:41:45 2025 AUC 0.930313585154361
#
# [mbo] 110: learning_rate=0.00383; num_leaves=693; min_data_in_leaf=47; feature_fraction=0.357; lambda_l2=7.27 : y = 0.93 : 244.9 secs : infill_ei
#
# Wed Jul 30 07:43:58 2025 AUC 0.93030539275017
#
# [mbo] 111: learning_rate=0.00967; num_leaves=602; min_data_in_leaf=398; feature_fraction=0.297; lambda_l2=8.58 : y = 0.93 : 131.5 secs : infill_ei
#
# Wed Jul 30 07:45:40 2025 AUC 0.930155911897699
#
# [mbo] 112: learning_rate=0.00864; num_leaves=817; min_data_in_leaf=712; feature_fraction=0.656; lambda_l2=4.87 : y = 0.93 : 100.9 secs : infill_ei
#
# Wed Jul 30 07:47:41 2025 AUC 0.928425157392369
#
# [mbo] 113: learning_rate=0.153; num_leaves=1294; min_data_in_leaf=472; feature_fraction=0.228; lambda_l2=13.8 : y = 0.928 : 120.3 secs : infill_ei
#
# Saved the current state after iteration 114 in the file bayesiana.RDATA.
#
# Wed Jul 30 07:50:38 2025 AUC 0.930554108449927
#
# [mbo] 114: learning_rate=0.0179; num_leaves=706; min_data_in_leaf=168; feature_fraction=0.305; lambda_l2=11.6 : y = 0.931 : 171.2 secs : infill_ei
#
# Wed Jul 30 07:52:50 2025 AUC 0.930085781583402
#
# [mbo] 115: learning_rate=0.0221; num_leaves=432; min_data_in_leaf=387; feature_fraction=0.232; lambda_l2=8.87 : y = 0.93 : 130.9 secs : infill_ei
#
# Wed Jul 30 07:54:53 2025 AUC 0.930887124845428
#
# [mbo] 116: learning_rate=0.00831; num_leaves=693; min_data_in_leaf=395; feature_fraction=0.65; lambda_l2=11.1 : y = 0.931 : 121.4 secs : infill_ei
#
# Wed Jul 30 07:56:53 2025 AUC 0.928886592676798
#
# [mbo] 117: learning_rate=0.0193; num_leaves=474; min_data_in_leaf=993; feature_fraction=0.552; lambda_l2=9.91 : y = 0.929 : 118.5 secs : infill_ei
#
# Wed Jul 30 07:59:06 2025 AUC 0.927087234391704
#
# [mbo] 118: learning_rate=0.172; num_leaves=946; min_data_in_leaf=727; feature_fraction=0.49; lambda_l2=8.28 : y = 0.927 : 131.5 secs : infill_ei
#
# Saved the current state after iteration 119 in the file bayesiana.RDATA.
#
# Wed Jul 30 08:00:05 2025 AUC 0.925812034707228
#
# [mbo] 119: learning_rate=0.128; num_leaves=1342; min_data_in_leaf=4576; feature_fraction=0.934; lambda_l2=13.1 : y = 0.926 : 53.9 secs : infill_ei
#
# Wed Jul 30 08:01:46 2025 AUC 0.928140205471255
#
# [mbo] 120: learning_rate=0.015; num_leaves=1441; min_data_in_leaf=1330; feature_fraction=0.259; lambda_l2=14 : y = 0.928 : 99.1 secs : infill_ei
#
# Wed Jul 30 08:03:10 2025 AUC 0.925891317631169
#
# [mbo] 121: learning_rate=0.124; num_leaves=1176; min_data_in_leaf=6200; feature_fraction=0.319; lambda_l2=13.8 : y = 0.926 : 83.7 secs : infill_ei
#
# Wed Jul 30 08:06:36 2025 AUC 0.929895809325784
#
# [mbo] 122: learning_rate=0.00916; num_leaves=709; min_data_in_leaf=144; feature_fraction=0.435; lambda_l2=4.76 : y = 0.93 : 203.9 secs : infill_ei
#
# Wed Jul 30 08:08:13 2025 AUC 0.923553030099673
#
# [mbo] 123: learning_rate=0.286; num_leaves=1040; min_data_in_leaf=5448; feature_fraction=0.505; lambda_l2=6.14 : y = 0.924 : 95.8 secs : infill_ei
#
# Wed Jul 30 08:09:47 2025 AUC 0.930214755484844
#
# [mbo] 124: learning_rate=0.0125; num_leaves=552; min_data_in_leaf=758; feature_fraction=0.76; lambda_l2=13.2 : y = 0.93 : 93.1 secs : infill_ei
#
# Saved the current state after iteration 125 in the file bayesiana.RDATA.
#
# Wed Jul 30 08:11:15 2025 AUC 0.930523232678636
#
# [mbo] 125: learning_rate=0.01; num_leaves=21; min_data_in_leaf=28; feature_fraction=0.6; lambda_l2=11.1 : y = 0.931 : 80.6 secs : infill_ei
#
# Wed Jul 30 08:16:44 2025 AUC 0.929822091268989
#
# [mbo] 126: learning_rate=0.00927; num_leaves=1293; min_data_in_leaf=29; feature_fraction=0.501; lambda_l2=10.7 : y = 0.93 : 327.8 secs : infill_ei
#
# Wed Jul 30 08:18:27 2025 AUC 0.931294500705747
#
# [mbo] 127: learning_rate=0.00889; num_leaves=35; min_data_in_leaf=649; feature_fraction=0.307; lambda_l2=1.03 : y = 0.931 : 101.1 secs : infill_ei
#
# Wed Jul 30 08:19:14 2025 AUC 0.925060282614871
#
# [mbo] 128: learning_rate=0.239; num_leaves=1480; min_data_in_leaf=7423; feature_fraction=0.87; lambda_l2=4.17 : y = 0.925 : 45.8 secs : infill_ei
#
# Wed Jul 30 08:24:42 2025 AUC 0.926913390075072
#
# [mbo] 129: learning_rate=0.00945; num_leaves=720; min_data_in_leaf=28; feature_fraction=0.874; lambda_l2=11.6 : y = 0.927 : 326.3 secs : infill_ei
#
# Saved the current state after iteration 130 in the file bayesiana.RDATA.
#
# Wed Jul 30 08:26:04 2025 AUC 0.926661144706192
#
# [mbo] 130: learning_rate=0.01; num_leaves=560; min_data_in_leaf=2593; feature_fraction=0.604; lambda_l2=11.4 : y = 0.927 : 76.9 secs : infill_ei
#
# Wed Jul 30 08:27:47 2025 AUC 0.929660619545051
#
# [mbo] 131: learning_rate=0.00555; num_leaves=673; min_data_in_leaf=559; feature_fraction=0.672; lambda_l2=8.08 : y = 0.93 : 102.1 secs : infill_ei
#
# Wed Jul 30 08:31:07 2025 AUC 0.929718688802666
#
# [mbo] 132: learning_rate=0.00871; num_leaves=1280; min_data_in_leaf=103; feature_fraction=0.341; lambda_l2=13.8 : y = 0.93 : 198.2 secs : infill_ei
#
# Wed Jul 30 08:32:59 2025 AUC 0.929088188320175
#
# [mbo] 133: learning_rate=0.00864; num_leaves=108; min_data_in_leaf=1047; feature_fraction=0.42; lambda_l2=12.5 : y = 0.929 : 111.1 secs : infill_ei
#
# Wed Jul 30 08:33:55 2025 AUC 0.92500289761288
#
# [mbo] 134: learning_rate=0.0312; num_leaves=383; min_data_in_leaf=5588; feature_fraction=0.975; lambda_l2=4.77 : y = 0.925 : 55.4 secs : infill_ei
#
# Wed Jul 30 08:38:20 2025 AUC 0.928918479379991
#
# [mbo] 135: learning_rate=0.00879; num_leaves=725; min_data_in_leaf=38; feature_fraction=0.328; lambda_l2=13.8 : y = 0.929 : 261.9 secs : infill_ei
#
# Saved the current state after iteration 136 in the file bayesiana.RDATA.
#
# Wed Jul 30 08:43:54 2025 AUC 0.929174128993622
#
# [mbo] 136: learning_rate=0.0052; num_leaves=1614; min_data_in_leaf=17; feature_fraction=0.309; lambda_l2=10.2 : y = 0.929 : 327.9 secs : infill_ei
#
# Wed Jul 30 08:45:25 2025 AUC 0.926008575927737
#
# [mbo] 137: learning_rate=0.0742; num_leaves=2036; min_data_in_leaf=5303; feature_fraction=0.557; lambda_l2=10.2 : y = 0.926 : 90.3 secs : infill_ei
#
# Wed Jul 30 08:47:15 2025 AUC 0.930133807386932
#
# [mbo] 138: learning_rate=0.0098; num_leaves=1592; min_data_in_leaf=894; feature_fraction=0.248; lambda_l2=11.4 : y = 0.93 : 108.0 secs : infill_ei
#
# Wed Jul 30 08:49:18 2025 AUC 0.930630979190133
#
# [mbo] 139: learning_rate=0.00824; num_leaves=689; min_data_in_leaf=827; feature_fraction=0.428; lambda_l2=8.6 : y = 0.931 : 121.5 secs : infill_ei
#
# Saved the current state after iteration 140 in the file bayesiana.RDATA.
#
# Wed Jul 30 08:51:47 2025 AUC 0.929018468133124
#
# [mbo] 140: learning_rate=0.0284; num_leaves=1394; min_data_in_leaf=358; feature_fraction=0.64; lambda_l2=5.95 : y = 0.929 : 143.2 secs : infill_ei
#
# Wed Jul 30 08:53:13 2025 AUC 0.923090026380945
#
# [mbo] 141: learning_rate=0.28; num_leaves=1819; min_data_in_leaf=7467; feature_fraction=0.567; lambda_l2=12.4 : y = 0.923 : 84.3 secs : infill_ei
#
# Wed Jul 30 08:54:53 2025 AUC 0.931771829038614
#
# [mbo] 142: learning_rate=0.017; num_leaves=20; min_data_in_leaf=528; feature_fraction=0.349; lambda_l2=2.45 : y = 0.932 : 98.7 secs : infill_ei
#
# Wed Jul 30 08:56:46 2025 AUC 0.92861771044757
#
# [mbo] 143: learning_rate=0.0119; num_leaves=713; min_data_in_leaf=1602; feature_fraction=0.429; lambda_l2=11.9 : y = 0.929 : 110.3 secs : infill_ei
#
# Wed Jul 30 08:57:54 2025 AUC 0.926448889676305
#
# [mbo] 144: learning_rate=0.128; num_leaves=1964; min_data_in_leaf=2500; feature_fraction=0.683; lambda_l2=10.6 : y = 0.926 : 67.4 secs : infill_ei
#
# Wed Jul 30 09:01:11 2025 AUC 0.929695944789026
#
# [mbo] 145: learning_rate=0.00516; num_leaves=967; min_data_in_leaf=175; feature_fraction=0.432; lambda_l2=2.53 : y = 0.93 : 195.0 secs : infill_ei
#
# Saved the current state after iteration 146 in the file bayesiana.RDATA.
#
# Wed Jul 30 09:06:29 2025 AUC 0.930109664657811
#
# [mbo] 146: learning_rate=0.00944; num_leaves=1078; min_data_in_leaf=25; feature_fraction=0.378; lambda_l2=9.9 : y = 0.93 : 309.9 secs : infill_ei
#
# Wed Jul 30 09:08:32 2025 AUC 0.929833941875699
#
# [mbo] 147: learning_rate=0.00924; num_leaves=1082; min_data_in_leaf=666; feature_fraction=0.591; lambda_l2=13.8 : y = 0.93 : 121.5 secs : infill_ei
#
# Wed Jul 30 09:09:51 2025 AUC 0.926149542748808
#
# [mbo] 148: learning_rate=0.0091; num_leaves=1223; min_data_in_leaf=4527; feature_fraction=0.187; lambda_l2=13.2 : y = 0.926 : 77.8 secs : infill_ei
#
# Wed Jul 30 09:11:12 2025 AUC 0.929017994855877
#
# [mbo] 149: learning_rate=0.0143; num_leaves=141; min_data_in_leaf=1235; feature_fraction=0.689; lambda_l2=6.02 : y = 0.929 : 80.2 secs : infill_ei
#
# Wed Jul 30 09:12:04 2025 AUC 0.925931760247254
#
# [mbo] 150: learning_rate=0.0812; num_leaves=396; min_data_in_leaf=5830; feature_fraction=0.984; lambda_l2=4.44 : y = 0.926 : 50.5 secs : infill_ei
#
# Saved the current state after iteration 151 in the file bayesiana.RDATA.
#
# Wed Jul 30 09:14:10 2025 AUC 0.929748230380902
#
# [mbo] 151: learning_rate=0.00406; num_leaves=712; min_data_in_leaf=838; feature_fraction=0.491; lambda_l2=13.2 : y = 0.93 : 119.0 secs : infill_ei
#
# Wed Jul 30 09:16:34 2025 AUC 0.930674579590636
#
# [mbo] 152: learning_rate=0.0139; num_leaves=83; min_data_in_leaf=508; feature_fraction=0.485; lambda_l2=0.837 : y = 0.931 : 142.7 secs : infill_ei
#
# Wed Jul 30 09:18:58 2025 AUC 0.930755549485277
#
# [mbo] 153: learning_rate=0.00636; num_leaves=1122; min_data_in_leaf=356; feature_fraction=0.42; lambda_l2=14.7 : y = 0.931 : 142.4 secs : infill_ei
#
# Wed Jul 30 09:20:50 2025 AUC 0.929023111819658
#
# [mbo] 154: learning_rate=0.00512; num_leaves=938; min_data_in_leaf=983; feature_fraction=0.381; lambda_l2=11.4 : y = 0.929 : 110.3 secs : infill_ei
#
# Wed Jul 30 09:23:15 2025 AUC 0.93052869302765
#
# [mbo] 155: learning_rate=0.0184; num_leaves=644; min_data_in_leaf=455; feature_fraction=0.445; lambda_l2=14.2 : y = 0.931 : 144.0 secs : infill_ei
#
# Saved the current state after iteration 156 in the file bayesiana.RDATA.
#
# Wed Jul 30 09:25:36 2025 AUC 0.930531870491936
#
# [mbo] 156: learning_rate=0.00817; num_leaves=317; min_data_in_leaf=390; feature_fraction=0.281; lambda_l2=3.09 : y = 0.931 : 134.6 secs : infill_ei
#
# Wed Jul 30 09:27:41 2025 AUC 0.9301403136848
#
# [mbo] 157: learning_rate=0.0159; num_leaves=855; min_data_in_leaf=663; feature_fraction=0.378; lambda_l2=14 : y = 0.93 : 123.7 secs : infill_ei
#
# Wed Jul 30 09:28:58 2025 AUC 0.926743778790652
#
# [mbo] 158: learning_rate=0.219; num_leaves=219; min_data_in_leaf=1450; feature_fraction=0.851; lambda_l2=10.1 : y = 0.927 : 75.8 secs : infill_ei
#
# Wed Jul 30 09:30:43 2025 AUC 0.929940489527854
#
# [mbo] 159: learning_rate=0.00908; num_leaves=1452; min_data_in_leaf=956; feature_fraction=0.24; lambda_l2=11 : y = 0.93 : 103.2 secs : infill_ei
#
# Wed Jul 30 09:33:21 2025 AUC 0.930324817225658
#
# [mbo] 160: learning_rate=0.0191; num_leaves=219; min_data_in_leaf=280; feature_fraction=0.413; lambda_l2=10.3 : y = 0.93 : 156.4 secs : infill_ei
#
# Saved the current state after iteration 161 in the file bayesiana.RDATA.
#
# Wed Jul 30 09:35:00 2025 AUC 0.930673317136021
#
# [mbo] 161: learning_rate=0.015; num_leaves=44; min_data_in_leaf=30; feature_fraction=0.608; lambda_l2=5.58 : y = 0.931 : 92.2 secs : infill_ei
#
# Wed Jul 30 09:35:49 2025 AUC 0.925437014778479
#
# [mbo] 162: learning_rate=0.17; num_leaves=818; min_data_in_leaf=6509; feature_fraction=0.859; lambda_l2=11.8 : y = 0.925 : 48.0 secs : infill_ei
#
# Wed Jul 30 09:37:43 2025 AUC 0.929213818547172
#
# [mbo] 163: learning_rate=0.0269; num_leaves=222; min_data_in_leaf=869; feature_fraction=0.319; lambda_l2=10.5 : y = 0.929 : 112.1 secs : infill_ei
#
# Wed Jul 30 09:40:34 2025 AUC 0.928864151099367
#
# [mbo] 164: learning_rate=0.0325; num_leaves=739; min_data_in_leaf=277; feature_fraction=0.498; lambda_l2=10.6 : y = 0.929 : 168.9 secs : infill_ei
#
# Wed Jul 30 09:42:07 2025 AUC 0.92257473821261
#
# [mbo] 165: learning_rate=0.288; num_leaves=1155; min_data_in_leaf=1478; feature_fraction=0.603; lambda_l2=1.27 : y = 0.923 : 92.5 secs : infill_ei
#
# Wed Jul 30 09:43:05 2025 AUC 0.925855693817168
#
# [mbo] 166: learning_rate=0.113; num_leaves=2003; min_data_in_leaf=6360; feature_fraction=0.63; lambda_l2=9.25 : y = 0.926 : 56.4 secs : infill_ei
#
# Wed Jul 30 09:44:28 2025 AUC 0.924316684523643
#
# [mbo] 167: learning_rate=0.282; num_leaves=122; min_data_in_leaf=1075; feature_fraction=0.742; lambda_l2=6.88 : y = 0.924 : 81.8 secs : infill_ei
#
# Saved the current state after iteration 168 in the file bayesiana.RDATA.
#
# Wed Jul 30 09:45:21 2025 AUC 0.924855679050741
#
# [mbo] 168: learning_rate=0.0778; num_leaves=42; min_data_in_leaf=5862; feature_fraction=0.884; lambda_l2=11.6 : y = 0.925 : 47.8 secs : infill_ei
#
# Wed Jul 30 09:47:10 2025 AUC 0.923891599515776
#
# [mbo] 169: learning_rate=0.264; num_leaves=593; min_data_in_leaf=1399; feature_fraction=0.384; lambda_l2=3.08 : y = 0.924 : 107.9 secs : infill_ei
#
# Wed Jul 30 09:49:29 2025 AUC 0.929931114168039
#
# [mbo] 170: learning_rate=0.0443; num_leaves=381; min_data_in_leaf=590; feature_fraction=0.474; lambda_l2=6.73 : y = 0.93 : 137.0 secs : infill_ei
#
# Wed Jul 30 09:50:36 2025 AUC 0.925621918349505
#
# [mbo] 171: learning_rate=0.218; num_leaves=1889; min_data_in_leaf=2557; feature_fraction=0.907; lambda_l2=12.8 : y = 0.926 : 66.3 secs : infill_ei
#
# Wed Jul 30 09:52:10 2025 AUC 0.93045119824401
#
# [mbo] 172: learning_rate=0.017; num_leaves=28; min_data_in_leaf=450; feature_fraction=0.282; lambda_l2=1.42 : y = 0.93 : 92.4 secs : infill_ei
#
# Wed Jul 30 09:54:31 2025 AUC 0.931024571786305
#
# [mbo] 173: learning_rate=0.00757; num_leaves=849; min_data_in_leaf=435; feature_fraction=0.425; lambda_l2=10.7 : y = 0.931 : 137.1 secs : infill_ei
#
# Wed Jul 30 09:57:00 2025 AUC 0.930173028135321
#
# [mbo] 174: learning_rate=0.0099; num_leaves=877; min_data_in_leaf=356; feature_fraction=0.389; lambda_l2=6.98 : y = 0.93 : 147.1 secs : infill_ei
#
# Saved the current state after iteration 175 in the file bayesiana.RDATA.
#
# Wed Jul 30 09:58:50 2025 AUC 0.929167580412864
#
# [mbo] 175: learning_rate=0.00788; num_leaves=29; min_data_in_leaf=1320; feature_fraction=0.412; lambda_l2=0.732 : y = 0.929 : 103.8 secs : infill_ei
#
# Wed Jul 30 10:00:41 2025 AUC 0.929000990819825
#
# [mbo] 176: learning_rate=0.0106; num_leaves=1600; min_data_in_leaf=1456; feature_fraction=0.414; lambda_l2=14.3 : y = 0.929 : 108.6 secs : infill_ei
#
# Wed Jul 30 10:03:04 2025 AUC 0.930454731953395
#
# [mbo] 177: learning_rate=0.0171; num_leaves=149; min_data_in_leaf=599; feature_fraction=0.583; lambda_l2=2.35 : y = 0.93 : 140.8 secs : infill_ei
#
# Wed Jul 30 10:04:48 2025 AUC 0.930135644908302
#
# [mbo] 178: learning_rate=0.0168; num_leaves=33; min_data_in_leaf=1024; feature_fraction=0.313; lambda_l2=13.2 : y = 0.93 : 102.8 secs : infill_ei
#
# Wed Jul 30 10:06:00 2025 AUC 0.926820918820842
#
# [mbo] 179: learning_rate=0.099; num_leaves=1361; min_data_in_leaf=2273; feature_fraction=0.668; lambda_l2=4.71 : y = 0.927 : 71.1 secs : infill_ei
#
# Wed Jul 30 10:07:55 2025 AUC 0.927207072906097
#
# [mbo] 180: learning_rate=0.0756; num_leaves=455; min_data_in_leaf=1385; feature_fraction=0.452; lambda_l2=9.44 : y = 0.927 : 113.8 secs : infill_ei
#
# Saved the current state after iteration 181 in the file bayesiana.RDATA.
#
# Wed Jul 30 10:10:28 2025 AUC 0.930205806361292
#
# [mbo] 181: learning_rate=0.00678; num_leaves=1160; min_data_in_leaf=275; feature_fraction=0.284; lambda_l2=6.84 : y = 0.93 : 145.1 secs : infill_ei
#
# Wed Jul 30 10:11:35 2025 AUC 0.923527409237243
#
# [mbo] 182: learning_rate=0.287; num_leaves=1979; min_data_in_leaf=2591; feature_fraction=0.729; lambda_l2=8.81 : y = 0.924 : 65.7 secs : infill_ei
#
# Wed Jul 30 10:13:08 2025 AUC 0.930224097302378
#
# [mbo] 183: learning_rate=0.0162; num_leaves=21; min_data_in_leaf=781; feature_fraction=0.272; lambda_l2=5.95 : y = 0.93 : 89.6 secs : infill_ei
#
# Wed Jul 30 10:15:29 2025 AUC 0.930283563300566
#
# [mbo] 184: learning_rate=0.0274; num_leaves=940; min_data_in_leaf=620; feature_fraction=0.52; lambda_l2=10.9 : y = 0.93 : 137.8 secs : infill_ei
#
# Wed Jul 30 10:18:55 2025 AUC 0.929710110890663
#
# [mbo] 185: learning_rate=0.00616; num_leaves=195; min_data_in_leaf=14; feature_fraction=0.39; lambda_l2=6.61 : y = 0.93 : 203.6 secs : infill_ei
#
# Saved the current state after iteration 186 in the file bayesiana.RDATA.
#
# Wed Jul 30 10:19:48 2025 AUC 0.926267965632504
#
# [mbo] 186: learning_rate=0.0778; num_leaves=350; min_data_in_leaf=6974; feature_fraction=0.951; lambda_l2=6.66 : y = 0.926 : 46.7 secs : infill_ei
#
# Wed Jul 30 10:20:50 2025 AUC 0.926689221969368
#
# [mbo] 187: learning_rate=0.0694; num_leaves=686; min_data_in_leaf=3193; feature_fraction=0.669; lambda_l2=11.7 : y = 0.927 : 60.5 secs : infill_ei
#
# Wed Jul 30 10:23:02 2025 AUC 0.930018734393856
#
# [mbo] 188: learning_rate=0.0135; num_leaves=718; min_data_in_leaf=747; feature_fraction=0.507; lambda_l2=13.8 : y = 0.93 : 128.8 secs : infill_ei
#
# Wed Jul 30 10:24:32 2025 AUC 0.929757962909416
#
# [mbo] 189: learning_rate=0.00928; num_leaves=23; min_data_in_leaf=886; feature_fraction=0.223; lambda_l2=1.7 : y = 0.93 : 87.5 secs : infill_ei
#
# Wed Jul 30 10:26:10 2025 AUC 0.930487228689571
#
# [mbo] 190: learning_rate=0.017; num_leaves=21; min_data_in_leaf=458; feature_fraction=0.359; lambda_l2=10.8 : y = 0.93 : 94.8 secs : infill_ei
#
# Wed Jul 30 10:28:08 2025 AUC 0.930123639397654
#
# [mbo] 191: learning_rate=0.0104; num_leaves=178; min_data_in_leaf=681; feature_fraction=0.597; lambda_l2=2.78 : y = 0.93 : 116.9 secs : infill_ei
#
# Wed Jul 30 10:29:12 2025 AUC 0.927024408538828
#
# [mbo] 192: learning_rate=0.0455; num_leaves=377; min_data_in_leaf=2580; feature_fraction=0.861; lambda_l2=7.94 : y = 0.927 : 62.5 secs : infill_ei
#
# Saved the current state after iteration 193 in the file bayesiana.RDATA.
#
# Wed Jul 30 10:30:19 2025 AUC 0.927053462280497
#
# [mbo] 193: learning_rate=0.124; num_leaves=1853; min_data_in_leaf=3168; feature_fraction=0.749; lambda_l2=4.99 : y = 0.927 : 60.9 secs : infill_ei
#
# Wed Jul 30 10:32:19 2025 AUC 0.930438985320401
#
# [mbo] 194: learning_rate=0.0124; num_leaves=271; min_data_in_leaf=412; feature_fraction=0.66; lambda_l2=10.5 : y = 0.93 : 118.5 secs : infill_ei
#
# Wed Jul 30 10:34:37 2025 AUC 0.929927801870743
#
# [mbo] 195: learning_rate=0.00765; num_leaves=1124; min_data_in_leaf=648; feature_fraction=0.413; lambda_l2=0.612 : y = 0.93 : 134.9 secs : infill_ei
#
# Wed Jul 30 10:36:44 2025 AUC 0.931601464739116
#
# [mbo] 196: learning_rate=0.0062; num_leaves=140; min_data_in_leaf=390; feature_fraction=0.317; lambda_l2=10.5 : y = 0.932 : 124.8 secs : infill_ei
#
# Wed Jul 30 10:38:19 2025 AUC 0.928441004185834
#
# [mbo] 197: learning_rate=0.0702; num_leaves=95; min_data_in_leaf=969; feature_fraction=0.161; lambda_l2=5.06 : y = 0.928 : 93.6 secs : infill_ei
#
# Wed Jul 30 10:40:44 2025 AUC 0.930894446597454
#
# [mbo] 198: learning_rate=0.0206; num_leaves=1032; min_data_in_leaf=324; feature_fraction=0.312; lambda_l2=10.5 : y = 0.931 : 143.3 secs : infill_ei
#
# Saved the current state after iteration 199 in the file bayesiana.RDATA.
#
# Wed Jul 30 10:42:35 2025 AUC 0.930525658061068
#
# [mbo] 199: learning_rate=0.00667; num_leaves=40; min_data_in_leaf=339; feature_fraction=0.309; lambda_l2=7.96 : y = 0.931 : 105.8 secs : infill_ei
#
# Wed Jul 30 10:44:02 2025 AUC 0.923888492330204
#
# [mbo] 200: learning_rate=0.278; num_leaves=606; min_data_in_leaf=2372; feature_fraction=0.595; lambda_l2=2.51 : y = 0.924 : 85.9 secs : infill_ei
#
# Wed Jul 30 10:45:25 2025 AUC 0.922144291697807
#
# [mbo] 201: learning_rate=0.249; num_leaves=2027; min_data_in_leaf=7557; feature_fraction=0.29; lambda_l2=2.84 : y = 0.922 : 81.1 secs : infill_ei
#
# Wed Jul 30 10:46:15 2025 AUC 0.92381858053246
#
# [mbo] 202: learning_rate=0.00878; num_leaves=2015; min_data_in_leaf=7403; feature_fraction=0.978; lambda_l2=3.65 : y = 0.924 : 49.0 secs : infill_ei
#
# Wed Jul 30 10:47:08 2025 AUC 0.924899159378828
#
# [mbo] 203: learning_rate=0.122; num_leaves=26; min_data_in_leaf=5113; feature_fraction=0.862; lambda_l2=12.6 : y = 0.925 : 51.7 secs : infill_ei
#
# Wed Jul 30 10:47:59 2025 AUC 0.92581358108466
#
# [mbo] 204: learning_rate=0.0142; num_leaves=200; min_data_in_leaf=5903; feature_fraction=0.698; lambda_l2=9.74 : y = 0.926 : 49.9 secs : infill_ei
#
# Wed Jul 30 10:49:59 2025 AUC 0.930008415626198
#
# [mbo] 205: learning_rate=0.00967; num_leaves=76; min_data_in_leaf=238; feature_fraction=0.218; lambda_l2=5.96 : y = 0.93 : 117.8 secs : infill_ei
#
# Wed Jul 30 10:51:31 2025 AUC 0.924222442732666
#
# [mbo] 206: learning_rate=0.104; num_leaves=1897; min_data_in_leaf=6796; feature_fraction=0.415; lambda_l2=0.32 : y = 0.924 : 90.1 secs : infill_ei
#
# Saved the current state after iteration 207 in the file bayesiana.RDATA.
#
# Wed Jul 30 10:53:03 2025 AUC 0.92499005169277
#
# [mbo] 207: learning_rate=0.136; num_leaves=732; min_data_in_leaf=2972; feature_fraction=0.224; lambda_l2=0.553 : y = 0.925 : 86.8 secs : infill_ei
#
# Wed Jul 30 10:55:52 2025 AUC 0.929812339056062
#
# [mbo] 208: learning_rate=0.00853; num_leaves=146; min_data_in_leaf=53; feature_fraction=0.318; lambda_l2=8.56 : y = 0.93 : 166.6 secs : infill_ei
#
# Wed Jul 30 10:58:21 2025 AUC 0.930111683022346
#
# [mbo] 209: learning_rate=0.0199; num_leaves=614; min_data_in_leaf=321; feature_fraction=0.338; lambda_l2=10.6 : y = 0.93 : 146.2 secs : infill_ei
#
# Wed Jul 30 11:00:15 2025 AUC 0.925578764551677
#
# [mbo] 210: learning_rate=0.243; num_leaves=1753; min_data_in_leaf=2478; feature_fraction=0.486; lambda_l2=11.4 : y = 0.926 : 112.6 secs : infill_ei
#
# Wed Jul 30 11:01:04 2025 AUC 0.924280949565403
#
# [mbo] 211: learning_rate=0.243; num_leaves=334; min_data_in_leaf=7815; feature_fraction=0.666; lambda_l2=11.6 : y = 0.924 : 47.7 secs : infill_ei
#
# Wed Jul 30 11:03:21 2025 AUC 0.930205401009064
#
# ...
#
# Wed Jul 30 21:57:51 2025 AUC 0.930253222861834
#
# [mbo] 525: learning_rate=0.0064; num_leaves=2027; min_data_in_leaf=778; feature_fraction=0.342; lambda_l2=12.3 : y = 0.93 : 116.4 secs : infill_ei
#
# Wed Jul 30 22:00:25 2025 AUC 0.92881710450097
#
# [mbo] 526: learning_rate=0.0277; num_leaves=806; min_data_in_leaf=318; feature_fraction=0.657; lambda_l2=12 : y = 0.929 : 138.2 secs : infill_ei
#
# Wed Jul 30 22:01:44 2025 AUC 0.924829384364063
#
# [mbo] 527: learning_rate=0.155; num_leaves=283; min_data_in_leaf=4358; feature_fraction=0.163; lambda_l2=4.84 : y = 0.925 : 76.2 secs : infill_ei
#
# Wed Jul 30 22:04:26 2025 AUC 0.929323744568024
#
# [mbo] 528: learning_rate=0.0214; num_leaves=1775; min_data_in_leaf=462; feature_fraction=0.382; lambda_l2=2.39 : y = 0.929 : 151.9 secs : infill_ei
#
# Saved the current state after iteration 529 in the file bayesiana.RDATA.
#
# Wed Jul 30 22:07:04 2025 AUC 0.930989371942883
#
# [mbo] 529: learning_rate=0.0267; num_leaves=889; min_data_in_leaf=365; feature_fraction=0.276; lambda_l2=13.6 : y = 0.931 : 144.8 secs : infill_ei
#
# Wed Jul 30 22:08:35 2025 AUC 0.926911420769674
#
# [mbo] 530: learning_rate=0.00542; num_leaves=790; min_data_in_leaf=2427; feature_fraction=0.249; lambda_l2=13.8 : y = 0.927 : 87.8 secs : infill_ei
#
# Wed Jul 30 22:09:32 2025 AUC 0.924899806915669
#
# [mbo] 531: learning_rate=0.26; num_leaves=138; min_data_in_leaf=5518; feature_fraction=0.924; lambda_l2=12.2 : y = 0.925 : 53.8 secs : infill_ei
#
# Wed Jul 30 22:11:00 2025 AUC 0.924009785457893
#
# [mbo] 532: learning_rate=0.00671; num_leaves=1041; min_data_in_leaf=5996; feature_fraction=0.568; lambda_l2=10 : y = 0.924 : 84.2 secs : infill_ei
#
# Wed Jul 30 22:12:46 2025 AUC 0.925723302175787
#
# [mbo] 533: learning_rate=0.215; num_leaves=1083; min_data_in_leaf=2677; feature_fraction=0.425; lambda_l2=1.91 : y = 0.926 : 103.5 secs : infill_ei
#
# Wed Jul 30 22:14:59 2025 AUC 0.930711205431138
#
# [mbo] 534: learning_rate=0.0223; num_leaves=510; min_data_in_leaf=446; feature_fraction=0.283; lambda_l2=14.9 : y = 0.931 : 124.9 secs : infill_ei
#
# Saved the current state after iteration 535 in the file bayesiana.RDATA.
#
# Wed Jul 30 22:16:11 2025 AUC 0.924612841890523
#
# [mbo] 535: learning_rate=0.175; num_leaves=1699; min_data_in_leaf=3154; feature_fraction=0.87; lambda_l2=9.4 : y = 0.925 : 62.4 secs : infill_ei
#
# Wed Jul 30 22:17:08 2025 AUC 0.924405153444647
#
# [mbo] 536: learning_rate=0.268; num_leaves=1916; min_data_in_leaf=5228; feature_fraction=0.721; lambda_l2=11.2 : y = 0.924 : 53.5 secs : infill_ei
#
# Wed Jul 30 22:21:56 2025 AUC 0.929117850110727
#
# [mbo] 537: learning_rate=0.0165; num_leaves=1037; min_data_in_leaf=48; feature_fraction=0.597; lambda_l2=13.9 : y = 0.929 : 280.5 secs : infill_ei
#
# Wed Jul 30 22:24:08 2025 AUC 0.931127970824408
#
# [mbo] 538: learning_rate=0.0102; num_leaves=1950; min_data_in_leaf=836; feature_fraction=0.318; lambda_l2=8.53 : y = 0.931 : 116.6 secs : infill_ei
#
# Wed Jul 30 22:26:22 2025 AUC 0.930432144675354
#
# [mbo] 539: learning_rate=0.0281; num_leaves=955; min_data_in_leaf=706; feature_fraction=0.328; lambda_l2=14.4 : y = 0.93 : 120.1 secs : infill_ei
#
# Saved the current state after iteration 540 in the file bayesiana.RDATA.
#
# Wed Jul 30 22:28:18 2025 AUC 0.931000421604104
#
# [mbo] 540: learning_rate=0.0176; num_leaves=20; min_data_in_leaf=105; feature_fraction=0.442; lambda_l2=9.94 : y = 0.931 : 101.1 secs : infill_ei
#
# Wed Jul 30 22:29:52 2025 AUC 0.923335212457524
#
# [mbo] 541: learning_rate=0.258; num_leaves=48; min_data_in_leaf=7488; feature_fraction=0.525; lambda_l2=12.5 : y = 0.923 : 90.9 secs : infill_ei
#
# Wed Jul 30 22:32:00 2025 AUC 0.930602496647366
#
# [mbo] 542: learning_rate=0.00896; num_leaves=1985; min_data_in_leaf=808; feature_fraction=0.376; lambda_l2=13.1 : y = 0.931 : 118.2 secs : infill_ei
#
# Wed Jul 30 22:33:47 2025 AUC 0.928680653731481
#
# [mbo] 543: learning_rate=0.0139; num_leaves=22; min_data_in_leaf=1083; feature_fraction=0.414; lambda_l2=1.67 : y = 0.929 : 99.5 secs : infill_ei
#
# Wed Jul 30 22:35:49 2025 AUC 0.929758282031138
#
# [mbo] 544: learning_rate=0.00766; num_leaves=2014; min_data_in_leaf=752; feature_fraction=0.236; lambda_l2=10.1 : y = 0.93 : 108.5 secs : infill_ei
#
# Wed Jul 30 22:36:54 2025 AUC 0.929752347088513
#
# [mbo] 545: learning_rate=0.0149; num_leaves=21; min_data_in_leaf=605; feature_fraction=0.71; lambda_l2=0.175 : y = 0.93 : 56.9 secs : infill_ei
#
# Saved the current state after iteration 546 in the file bayesiana.RDATA.
#
# Wed Jul 30 22:39:28 2025 AUC 0.929655742795256
#
# [mbo] 546: learning_rate=0.029; num_leaves=100; min_data_in_leaf=278; feature_fraction=0.383; lambda_l2=8.08 : y = 0.93 : 144.4 secs : infill_ei
#
# Wed Jul 30 22:40:34 2025 AUC 0.926190042268805
#
# [mbo] 547: learning_rate=0.243; num_leaves=722; min_data_in_leaf=2883; feature_fraction=0.93; lambda_l2=6.66 : y = 0.926 : 63.1 secs : infill_ei
#
# Wed Jul 30 22:42:35 2025 AUC 0.928323481871949
#
# [mbo] 548: learning_rate=0.0151; num_leaves=86; min_data_in_leaf=996; feature_fraction=0.422; lambda_l2=11.8 : y = 0.928 : 115.3 secs : infill_ei
#
# Wed Jul 30 22:43:30 2025 AUC 0.92495873183266
#
# [mbo] 549: learning_rate=0.194; num_leaves=1886; min_data_in_leaf=5469; feature_fraction=0.791; lambda_l2=9.98 : y = 0.925 : 51.7 secs : infill_ei
#
# Wed Jul 30 22:45:34 2025 AUC 0.930375647349825
#
# [mbo] 550: learning_rate=0.0222; num_leaves=960; min_data_in_leaf=838; feature_fraction=0.29; lambda_l2=13.5 : y = 0.93 : 113.9 secs : infill_ei
#
# Wed Jul 30 22:47:39 2025 AUC 0.930516621915768
#
# [mbo] 551: learning_rate=0.013; num_leaves=1754; min_data_in_leaf=723; feature_fraction=0.626; lambda_l2=9.07 : y = 0.931 : 112.5 secs : infill_ei
#
# Saved the current state after iteration 552 in the file bayesiana.RDATA.
#
# Wed Jul 30 22:50:35 2025 AUC 0.929287255868574
#
# [mbo] 552: learning_rate=0.0157; num_leaves=516; min_data_in_leaf=414; feature_fraction=0.431; lambda_l2=0.234 : y = 0.929 : 160.5 secs : infill_ei
#
# Wed Jul 30 22:52:09 2025 AUC 0.923457591282377
#
# [mbo] 553: learning_rate=0.251; num_leaves=1988; min_data_in_leaf=6832; feature_fraction=0.538; lambda_l2=7.43 : y = 0.923 : 91.1 secs : infill_ei
#
# Wed Jul 30 22:54:24 2025 AUC 0.930358419215351
#
# [mbo] 554: learning_rate=0.0109; num_leaves=1927; min_data_in_leaf=423; feature_fraction=0.25; lambda_l2=13.8 : y = 0.93 : 125.4 secs : infill_ei
#
# Wed Jul 30 22:55:14 2025 AUC 0.924344984537492
#
# [mbo] 555: learning_rate=0.246; num_leaves=1007; min_data_in_leaf=7146; feature_fraction=0.966; lambda_l2=9.29 : y = 0.924 : 46.6 secs : infill_ei
#
# Wed Jul 30 22:56:58 2025 AUC 0.930558926733098
#
# [mbo] 556: learning_rate=0.0105; num_leaves=1877; min_data_in_leaf=826; feature_fraction=0.649; lambda_l2=10.3 : y = 0.931 : 96.7 secs : infill_ei
#
# Wed Jul 30 23:00:40 2025 AUC 0.930994826751603
#
# [mbo] 557: learning_rate=0.0176; num_leaves=547; min_data_in_leaf=75; feature_fraction=0.338; lambda_l2=11 : y = 0.931 : 217.0 secs : infill_ei
#
# Saved the current state after iteration 558 in the file bayesiana.RDATA.
#
# Wed Jul 30 23:03:10 2025 AUC 0.929958766227569
#
# [mbo] 558: learning_rate=0.0106; num_leaves=533; min_data_in_leaf=602; feature_fraction=0.256; lambda_l2=1.95 : y = 0.93 : 119.1 secs : infill_ei
#
# Wed Jul 30 23:05:50 2025 AUC 0.930158320238793
#
# [mbo] 559: learning_rate=0.0303; num_leaves=679; min_data_in_leaf=505; feature_fraction=0.512; lambda_l2=6.38 : y = 0.93 : 149.0 secs : infill_ei
#
# Wed Jul 30 23:07:15 2025 AUC 0.930744847992757
#
# [mbo] 560: learning_rate=0.00631; num_leaves=27; min_data_in_leaf=127; feature_fraction=0.644; lambda_l2=10.9 : y = 0.931 : 73.6 secs : infill_ei
#
# Wed Jul 30 23:08:50 2025 AUC 0.929167780681528
#
# [mbo] 561: learning_rate=0.0178; num_leaves=1771; min_data_in_leaf=1221; feature_fraction=0.64; lambda_l2=12.7 : y = 0.929 : 86.0 secs : infill_ei
#
# Wed Jul 30 23:10:25 2025 AUC 0.925040032398541
#
# [mbo] 562: learning_rate=0.149; num_leaves=458; min_data_in_leaf=2412; feature_fraction=0.591; lambda_l2=1.03 : y = 0.925 : 89.5 secs : infill_ei
#
# Wed Jul 30 23:11:20 2025 AUC 0.927027633154922
#
# [mbo] 563: learning_rate=0.0882; num_leaves=134; min_data_in_leaf=5084; feature_fraction=0.671; lambda_l2=14.2 : y = 0.927 : 51.2 secs : infill_ei
#
# Saved the current state after iteration 564 in the file bayesiana.RDATA.
#
# Wed Jul 30 23:12:47 2025 AUC 0.922881693565195
#
# [mbo] 564: learning_rate=0.204; num_leaves=581; min_data_in_leaf=6285; feature_fraction=0.221; lambda_l2=3.67 : y = 0.923 : 78.5 secs : infill_ei
#
# Wed Jul 30 23:14:59 2025 AUC 0.930208949791633
#
# [mbo] 565: learning_rate=0.00549; num_leaves=159; min_data_in_leaf=498; feature_fraction=0.348; lambda_l2=12.7 : y = 0.93 : 123.4 secs : infill_ei
#
# Wed Jul 30 23:17:28 2025 AUC 0.931868780891598
#
# [mbo] 566: learning_rate=0.0114; num_leaves=1131; min_data_in_leaf=486; feature_fraction=0.32; lambda_l2=11 : y = 0.932 : 131.9 secs : infill_ei
#
# Wed Jul 30 23:21:20 2025 AUC 0.930561982652777
#
# [mbo] 567: learning_rate=0.00994; num_leaves=1748; min_data_in_leaf=111; feature_fraction=0.581; lambda_l2=13.9 : y = 0.931 : 219.8 secs : infill_ei
#
# Wed Jul 30 23:23:39 2025 AUC 0.930619258696835
#
# [mbo] 568: learning_rate=0.0149; num_leaves=1228; min_data_in_leaf=608; feature_fraction=0.321; lambda_l2=13.7 : y = 0.931 : 125.0 secs : infill_ei
#
# Saved the current state after iteration 569 in the file bayesiana.RDATA.
#
# Wed Jul 30 23:25:11 2025 AUC 0.922793128390629
#
# [mbo] 569: learning_rate=0.245; num_leaves=1393; min_data_in_leaf=5970; feature_fraction=0.252; lambda_l2=3.94 : y = 0.923 : 81.7 secs : infill_ei
#
# Wed Jul 30 23:27:54 2025 AUC 0.930495649207464
#
# [mbo] 570: learning_rate=0.00753; num_leaves=690; min_data_in_leaf=281; feature_fraction=0.39; lambda_l2=12.5 : y = 0.93 : 152.9 secs : infill_ei
#
# Wed Jul 30 23:30:32 2025 AUC 0.930530564725319
#
# [mbo] 571: learning_rate=0.0502; num_leaves=1205; min_data_in_leaf=395; feature_fraction=0.347; lambda_l2=6.85 : y = 0.931 : 145.4 secs : infill_ei
#
# Wed Jul 30 23:32:40 2025 AUC 0.93041616051251
#
# [mbo] 572: learning_rate=0.0121; num_leaves=1639; min_data_in_leaf=490; feature_fraction=0.64; lambda_l2=13.1 : y = 0.93 : 117.1 secs : infill_ei
#
# Wed Jul 30 23:34:46 2025 AUC 0.930535397689652
#
# [mbo] 573: learning_rate=0.00722; num_leaves=1080; min_data_in_leaf=520; feature_fraction=0.251; lambda_l2=12.3 : y = 0.931 : 116.9 secs : infill_ei
#
# Saved the current state after iteration 574 in the file bayesiana.RDATA.
#
# Wed Jul 30 23:36:48 2025 AUC 0.926515534245277
#
# [mbo] 574: learning_rate=0.155; num_leaves=1565; min_data_in_leaf=1704; feature_fraction=0.468; lambda_l2=10.4 : y = 0.927 : 111.8 secs : infill_ei
#
# Wed Jul 30 23:38:38 2025 AUC 0.930066743624537
#
# [mbo] 575: learning_rate=0.00904; num_leaves=351; min_data_in_leaf=686; feature_fraction=0.631; lambda_l2=9.96 : y = 0.93 : 102.0 secs : infill_ei
#
# Wed Jul 30 23:40:58 2025 AUC 0.930183011991983
#
# [mbo] 576: learning_rate=0.0489; num_leaves=63; min_data_in_leaf=400; feature_fraction=0.414; lambda_l2=6.57 : y = 0.93 : 129.5 secs : infill_ei
#
# Wed Jul 30 23:43:27 2025 AUC 0.929253794187411
#
# [mbo] 577: learning_rate=0.0266; num_leaves=603; min_data_in_leaf=575; feature_fraction=0.437; lambda_l2=11.9 : y = 0.929 : 135.3 secs : infill_ei
#
# Wed Jul 30 23:45:04 2025 AUC 0.926951712908776
#
# [mbo] 578: learning_rate=0.152; num_leaves=951; min_data_in_leaf=1269; feature_fraction=0.617; lambda_l2=6.8 : y = 0.927 : 93.1 secs : infill_ei
#
# Saved the current state after iteration 579 in the file bayesiana.RDATA.
#
# Wed Jul 30 23:47:59 2025 AUC 0.928931213079493
#
# [mbo] 579: learning_rate=0.0512; num_leaves=1324; min_data_in_leaf=335; feature_fraction=0.432; lambda_l2=8.47 : y = 0.929 : 160.8 secs : infill_ei
#
# Wed Jul 30 23:50:24 2025 AUC 0.930750917705662
#
# [mbo] 580: learning_rate=0.0237; num_leaves=1745; min_data_in_leaf=502; feature_fraction=0.587; lambda_l2=12.5 : y = 0.931 : 139.2 secs : infill_ei
#
# Wed Jul 30 23:53:02 2025 AUC 0.929340545523385
#
# [mbo] 581: learning_rate=0.0461; num_leaves=205; min_data_in_leaf=497; feature_fraction=0.419; lambda_l2=11.3 : y = 0.929 : 142.5 secs : infill_ei
#
# Wed Jul 30 23:55:25 2025 AUC 0.929144976256637
#
# [mbo] 582: learning_rate=0.0491; num_leaves=1451; min_data_in_leaf=805; feature_fraction=0.449; lambda_l2=6.51 : y = 0.929 : 132.5 secs : infill_ei
#
# Saved the current state after iteration 583 in the file bayesiana.RDATA.
#
# Wed Jul 30 23:58:12 2025 AUC 0.92957552720976
#
# [mbo] 583: learning_rate=0.0269; num_leaves=810; min_data_in_leaf=383; feature_fraction=0.293; lambda_l2=4.73 : y = 0.93 : 146.4 secs : infill_ei
#
# Wed Jul 30 23:59:40 2025 AUC 0.927158819220972
#
# [mbo] 584: learning_rate=0.0213; num_leaves=1061; min_data_in_leaf=2461; feature_fraction=0.141; lambda_l2=12.6 : y = 0.927 : 84.4 secs : infill_ei
#
# Thu Jul 31 00:02:31 2025 AUC 0.930230728220488
#
# [mbo] 585: learning_rate=0.0229; num_leaves=1478; min_data_in_leaf=418; feature_fraction=0.562; lambda_l2=12.8 : y = 0.93 : 164.0 secs : infill_ei
#
# Thu Jul 31 00:05:05 2025 AUC 0.930743648731719
#
# [mbo] 586: learning_rate=0.0126; num_leaves=902; min_data_in_leaf=418; feature_fraction=0.315; lambda_l2=11.5 : y = 0.931 : 144.0 secs : infill_ei
#
# Thu Jul 31 00:07:19 2025 AUC 0.930904140879633
#
# [mbo] 587: learning_rate=0.0215; num_leaves=1974; min_data_in_leaf=822; feature_fraction=0.278; lambda_l2=5.65 : y = 0.931 : 124.0 secs : infill_ei
#
# Saved the current state after iteration 588 in the file bayesiana.RDATA.
#
# Thu Jul 31 00:08:46 2025 AUC 0.926829494619124
#
# [mbo] 588: learning_rate=0.151; num_leaves=1876; min_data_in_leaf=2179; feature_fraction=0.72; lambda_l2=8.86 : y = 0.927 : 76.1 secs : infill_ei
#
# Thu Jul 31 00:11:04 2025 AUC 0.930323412712908
#
# [mbo] 589: learning_rate=0.0145; num_leaves=132; min_data_in_leaf=832; feature_fraction=0.575; lambda_l2=1.55 : y = 0.93 : 128.6 secs : infill_ei
#
# Thu Jul 31 00:13:22 2025 AUC 0.930288932410895
#
# [mbo] 590: learning_rate=0.0117; num_leaves=37; min_data_in_leaf=863; feature_fraction=0.485; lambda_l2=4.48 : y = 0.93 : 122.6 secs : infill_ei
#
# Thu Jul 31 00:15:37 2025 AUC 0.929559013385313
#
# [mbo] 591: learning_rate=0.0296; num_leaves=941; min_data_in_leaf=675; feature_fraction=0.276; lambda_l2=13.6 : y = 0.93 : 123.6 secs : infill_ei
#
# Thu Jul 31 00:18:37 2025 AUC 0.929731101552973
#
# [mbo] 592: learning_rate=0.0248; num_leaves=93; min_data_in_leaf=230; feature_fraction=0.482; lambda_l2=5.77 : y = 0.93 : 168.3 secs : infill_ei
#
# Saved the current state after iteration 593 in the file bayesiana.RDATA.
#
# Thu Jul 31 00:21:36 2025 AUC 0.930183356984293
#
# [mbo] 593: learning_rate=0.0108; num_leaves=837; min_data_in_leaf=329; feature_fraction=0.387; lambda_l2=13.5 : y = 0.93 : 160.6 secs : infill_ei
#
# Thu Jul 31 00:24:21 2025 AUC 0.9315988508219
#
# [mbo] 594: learning_rate=0.00704; num_leaves=1795; min_data_in_leaf=509; feature_fraction=0.443; lambda_l2=14.8 : y = 0.932 : 149.2 secs : infill_ei
#
# Thu Jul 31 00:28:20 2025 AUC 0.929213649733119
#
# [mbo] 595: learning_rate=0.0113; num_leaves=1178; min_data_in_leaf=77; feature_fraction=0.292; lambda_l2=11.6 : y = 0.929 : 231.3 secs : infill_ei
#
# Thu Jul 31 00:31:04 2025 AUC 0.93060218848971
#
# [mbo] 596: learning_rate=0.00958; num_leaves=595; min_data_in_leaf=521; feature_fraction=0.47; lambda_l2=14.2 : y = 0.931 : 144.5 secs : infill_ei
#
# Saved the current state after iteration 597 in the file bayesiana.RDATA.
#
# Thu Jul 31 00:33:09 2025 AUC 0.928179897348944
#
# [mbo] 597: learning_rate=0.013; num_leaves=1828; min_data_in_leaf=2585; feature_fraction=0.369; lambda_l2=10.8 : y = 0.928 : 104.7 secs : infill_ei
#
# Thu Jul 31 00:36:00 2025 AUC 0.929968027672655
#
# [mbo] 598: learning_rate=0.053; num_leaves=967; min_data_in_leaf=485; feature_fraction=0.338; lambda_l2=4.16 : y = 0.93 : 149.3 secs : infill_ei
#
# Thu Jul 31 00:38:38 2025 AUC 0.929618543801416
#
# [mbo] 599: learning_rate=0.0157; num_leaves=119; min_data_in_leaf=610; feature_fraction=0.43; lambda_l2=0.543 : y = 0.93 : 149.8 secs : infill_ei
#
# Thu Jul 31 00:41:42 2025 AUC 0.930086937125629
#
# [mbo] 600: learning_rate=0.0221; num_leaves=381; min_data_in_leaf=397; feature_fraction=0.515; lambda_l2=1.87 : y = 0.93 : 175.2 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "learning_rate"    "num_leaves"       "min_data_in_leaf" "feature_fraction"
#  [5] "lambda_l2"        "y"                "dob"              "eol"
#  [9] "error.message"    "exec.time"        "ei"               "error.model"
# [13] "train.time"       "prop.type"        "propose.time"     "se"
# [17] "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    learning_rate num_leaves min_data_in_leaf feature_fraction lambda_l2
#            <num>      <int>            <int>            <num>     <num>
# 1:   0.009810641         45               19        0.2853453  11.28039
# [1] 0.9320599

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 333757
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 11.28039
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 1
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 2000
#
# $learning_rate
# [1] 0.009810641
#
# $feature_fraction
# [1] 0.2853453
#
# $num_leaves
# [1] 45
#
# $min_data_in_leaf
# [1] 19

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Jul 31 00:44:33 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
