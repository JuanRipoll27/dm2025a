# %% [markdown]
# # 3 Optimización de Hiperpárametros

# %% [markdown]
# ## 3.01 Introduccion
# En general los algoritmos que generan modelos predictivos poseen hiperparámetros que *dado un dataset* deben ser optimizados.
# <br> La invocación de uno de esos algoritmos sin hiperparámetros no es más que
# invocarlos con hiperparámetros por default definidos por el fabricante. Por ejemplo en el caso de la librería **rpart** es cp=0.01, maxdepth=30, minsplit=20, minbucket=6,  lo que en nuestro dataset genera un arbol de un solo nodo (decimos "no se abre el arbol"); la razon de esto es la proporcion de "BAJA+1" y "BAJA+2"

# %% [markdown]
# En el primer notebook de la asignatura usted probó optimizar manualmente los hiperparámetros entrenando en un mes completo y viendo los resultados directamente en el Public Leaderboard, que es una porción de los datos de futuro.
# <br> En el mundo real no se dispone jamás de la clase del futuro, con lo cual lo anterior es meramente un artifical divertimento.
# <br> La solución es estimar la bondad de un set de hiperparámetros en alguna combinación de:
#   * Una sola partición de  <training, testing>
#   * Multiples particiones de <training, testing>
#   * El método de  k-fold Cross Validation , generalmente con n>=5
#   * Utilizar   n-repated  k-fold Cross Validation
#   * Leave One Out  si la cardinalidad del dataset y el poder de cómputo se lo permiten

# %% [markdown]
# Luego de comenzar a trabajar con el método de  "Multiples particiones de <training, testing>  se le invitó a extender un esqueleto de código del método de **Optimización de Hiperparámetros por Grid Search**

# %% [markdown]
# ## 3.02 Conceptos
#
# En esta entrega veremos los siguiente conceptos:
# * El origen del overfitting en un arbol de decisión
# * *La maldición del ganador*, overfitting en los hiperparámetros ganadores, Selective Inference
# * Data Drifting
# * Alterntivas de búsqueda
#   * Grid Search, la fuerza bruta
#   * Bayesian Optimization, la heurística

# %% [markdown]
# ## 3.03  Corrida notebook inicial
#
# En el repositorio oficial de la asignatura se encuentra el notebook ./src/rpart/z102_FinalTrain.ipynb  que automaticamente hace el submit a la Competencia Analista Sr  de Kaggle.
# <br>  Ingrese a un nuevo Google Colab  y pruebe algunas corridas del notebook cambiando los hiperparámetros de rpart

# %% [markdown]
# ## 3.04 Origen del Overfitting en un arbol de decisión
# ¿Qué combinacion de hiperparámetros overfitea un árbol de decisión, para nuestro dataset?
# <br>¿Cómo se ve el overfitting desde el punto de vista de las curvas de ganancia?

# %% [markdown]
# El objetivo de este capítulo es que usted juegue manualmente con los hiperparámetros de un rpart, observe las curvas de ganancia generadas en una particion <training=50%, testing=50%>  y obtengla conclusiones sobre el fenómeno observado.

# %% [markdown]
# Introducimos el concepto de **Curva de Ganancia**
# <br> Al aplicar un modelo a un dataset se le asigna a cada registro una probabilidad, a su vez cada registro contribuye con una ganancia la que puede ser una pérdida o una ganancia.
# <br>Ordenamos el dataset por probabilidad *descendente* y computamos la ganancia acumulada, generando de esta forma la curva de ganancia
# <br> Para visualizar el efecto del under/over  fitting adecuadamente, realizamos una particion  <training= 50%, testing= 50%>

# %% [markdown]
# tener presente:
# <br> Overfitting  **NO**  es la diferencia entre las curvas
# <br> Lo que divide el underfitting del overfitting al aumentar la complejidad del modelo es la complejidad donde se alcanza la métrica máxima.

# %% [markdown]
# ### ¿Qué debe hacer usted?
# Probar al menos estas combinaciones:
# * **Arbol crecimiento descontrolado**
#    * cp= -1
#    * maxdepth= 30
#    * minsplit= 2
#    * minbucket= 1
# * Arbol talla reducida
#    * cp= -1
#    * maxdepth= 3
#    * minsplit= 20000
#    * minbucket= 10000

# %% [markdown]
# #### Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dm"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dm" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/itba2025-8d0a/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection

# %%
# cargo las librerias que necesito
require("data.table")
require("rpart")
require("ggplot2")

# %%
# carpeta de trabajo
setwd("/content/buckets/b1/exp")
experimento <- "exp304"
dir.create(experimento, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# ### Acción :  Jugar con  minsplit, minbucket y maxdepth

# %%
# cambiar aqui los parametros
PARAM <- list()
PARAM$semilla_primigenia <- 102191


PARAM$minsplit <- 300
PARAM$minbucket <- 20
PARAM$maxdepth <- 11

# %%
# particionar agrega una columna llamada fold a un dataset
#   que consiste en una particion estratificada segun agrupa
# particionar( data=dataset, division=c(70,30),
#  agrupa=clase_ternaria, seed=semilla)   crea una particion 70, 30

particionar <- function(data, division, agrupa= "", campo= "fold", start= 1, seed= NA) {
  if (!is.na(seed)) set.seed(seed)

  bloque <- unlist(mapply(
    function(x, y) {rep(y, x)},division, seq(from= start, length.out= length(division))))

  data[, (campo) := sample(rep(bloque,ceiling(.N / length(bloque))))[1:.N],by= agrupa]
}

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
# a partir de ahora solo trabajo con 202107, el mes que tiene clase

dataset <- dataset[foto_mes == 202107] # defino donde voy a entrenar

# %%
# La division training/testing es 50%, 50%
#  que sea 50/50 se indica con el c(1,1)

particionar(dataset,
  division= c(1, 1),
  agrupa= "clase_ternaria",
  seed= PARAM$semilla_primigenia
)

# %%
# Entreno el modelo
# los datos donde voy a entrenar
# aqui es donde se deben probar distintos hiperparametros

modelo <- rpart(
  formula= "clase_ternaria ~ . -fold",
  data= dataset[fold == 1, ],
  xval= 0,
  cp= -1,
  minsplit= PARAM$minsplit,
  minbucket= PARAM$minbucket,
  maxdepth= PARAM$maxdepth
)

# %%
# aplico el modelo a TODOS los datos, inclusive los de training
prediccion <- predict(modelo, dataset, type= "prob")

# %%
# Pego la probabilidad de  BAJA+2
tb_prediccion <- dataset[, list(fold,clase_ternaria)]
tb_prediccion[, prob_baja2 := prediccion[, "BAJA+2"]]

# %%
# Dibujo la curva de ganancia acumulada
setorder(tb_prediccion, fold, -prob_baja2)

# %%
# agrego una columna que es la de las ganancias
# la multiplico por 2 para que ya este normalizada
#  es 2 porque cada fold es el 50%

tb_prediccion[, gan := 2 *ifelse(clase_ternaria == "BAJA+2", 117000, -3000)]
tb_prediccion[, ganancia_acumulada := cumsum(gan), by= fold]
tb_prediccion[, pos := sequence(.N), by= fold]

# %%
tb_prediccion

# %%
# agrego una columna que es la de las ganancias
# la multiplico por 2 para que ya este normalizada
#  es 2 porque cada fold es el 50%

tb_prediccion[, gan := 2 *ifelse(clase_ternaria == "BAJA+2", 117000, -3000)]
tb_prediccion[, ganancia_acumulada := cumsum(gan), by= fold]
tb_prediccion[, pos := sequence(.N), by= fold]

# %%
# defino hasta donde muestra el grafico
amostrar <- 20000

# %%
# Esta hermosa curva muestra como en el mentiroso training
#   la ganancia es siempre mejor que en el real testing

options( repr.plot.width=10, repr.plot.height=10)

gra <- ggplot(
           data= tb_prediccion[pos <= amostrar],
           aes( x= pos, y= ganancia_acumulada,
                color= ifelse(fold == 1, "train", "test") )
             ) + geom_line()

print( gra )

# %%
# veo los resultados

print(PARAM)
cat( "Train gan max: ", tb_prediccion[fold==1, max(ganancia_acumulada)], "\n" )
cat( "Test  gan max: ", tb_prediccion[fold==2, max(ganancia_acumulada)], "\n" )

# %% [markdown]
# ## 3.05 Análisis de la salida de Grid Search
#
# En clase utilizando un enfoque constructivista de educacion cada una de las mesas del aula analizará las salidas de las corridas de Grid Search de la Tarea para el Hogar.
# <br>Se espera que quienes ya trabajan como Data Analyst se luzcan en el análisis de esos datos
# <br>Finalmente se utilizara un *arma conceptual secreta*, iluminando elegantemente donde están las mayores ganancias.
#
# <br><br>Si usted no tuvo la oportunidad de hacer sus propias corridas esta generosa cátedra pone a su diposición esta salida https://storage.googleapis.com/open-courses/itba2025-8d0a/gridsearch.txt

# %% [markdown]
# ## 3.06 La Maldición del Ganador

# %% [markdown]
# ¿Los hiperparámetros ganadores de toda la cohorte, estan overfiteando?
# <br> Trabajaremos con la hoja **C3-GS Overfitting** de la Google Sheet Colaborativa
# <br> Determinar de toda la cohorte quien obtuvo la mayor ganancia y con qué hiperparámetros
# <br> copiarlos  a la hoja **C3-GS Overfitting**
# <br> Quien obtuvo esa ganancia no debe hacer nada
# <br> El resto de la cohorte, modifica su script de Grid Search para calcular la ganancia de dichos hiperparámetros ganadores  utilizando su Semilla Primigenia y registra la ganancia en la linea correspondiente a su nombre en la hoja C3-GS Overfitting

# %% [markdown]
# ¿ Como compara la ganancia del ganador versus el resto de las ganancias recién calculadas ?

# %% [markdown]
# #### Bibliografia

# %% [markdown]
# * Selective Inference - the silent killer of replicability   https://www.youtube.com/watch?v=6ZxIzVjV1DE
# * Ioannidis, J. P. A. Why most published research findings are false. PLoS Med. 2, e124 (2005). https://journals.plos.org/plosmedicine/article/file?id=10.1371/journal.pmed.0020124&type=printable

# %% [markdown]
# ---

# %% [markdown]
# ## 3.07 Data Drifting  sospechas

# %% [markdown]
# Ordenar la salida del Grid Search en forma descendente por ganancia (en testing obviamente)
# <br> De esta forma la posición 1 corresponde a la mayor ganancia, la 2 a la segunda mejor, etc
# <br> En la Google Sheet Colaborativa,  hoja  **C3- GridSEarch** cargue las posiciones  1, 2, 5, 10, 50 y 100 de la salida del Grid Search, dejando la columna Public Leaderboard sin cargar
# <br> La columna ganancia_mean tiene valores en orden descendente

# %% [markdown]
# El objetivo de hacer Grid Search  es utilizando particiones <training, testing>  encontrar los mejores hiperparámetros
# <br> Esto tiene sentido en la medida que los hiperparámetros que resultan mejores de la búsqueda Grid Search son también los mejores cuando se hace el Final Training

# %% [markdown]
# Utilizando el notebook de la primiera clase,  **z102_FinalTrain.ipynb**   calcule para cada uno de los sets de hiperparámetros de las posiciones 1, 2, 5, 10, 50 y 100  cual es la ganancia en el Public Leaderboard de Kaggle
# <br> Deberá hacer una corrida para cada conjunto de hiperparámetros

# %% [markdown]
#  ¿ Se cumple que los hiperparámetros de la posición  1 del Grid Search son los que mejor funcionan para predecir los datos del futuro ?

# %% [markdown]
# ¿ Si esto no fuera así, estamos en una sitacion de **Game Over** ?

# %% [markdown]
# ---

# %% [markdown]
# ## 3.08 Data Drifting, breve intuicion

# %% [markdown]
# Se mostrará un posible origen de las discrepancias observadas en el capítulo anterior
# <br> La solución al Data Drifting es otro precio ...

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection

# %% [markdown]
# * Instalacion de la libreria  rpart.plot  para dibujar el arbol
# * invocacion de las librerias  **data.table** y  **rpart**

# %%
# cargo las librerias que necesito
require("data.table")
require("rpart")

# %%
# carpeta de trabajo
setwd("/content/buckets/b1/exp")
experimento <- "exp308"
dir.create(experimento, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %%
PARAM <- list()
PARAM$mes0 <- 202107
PARAM$mes1 <- 202109

# %%
graficar_campo <- function(campo, param) {
  # quito de grafico las colas del 5% de las densidades
  qA <- quantile(dataset[foto_mes == param$mes0, get(campo)],
    prob= c(0.05, 0.95), na.rm= TRUE
  )

  qB <- quantile(dataset[foto_mes == param$mes1, get(campo)],
    prob= c(0.05, 0.95), na.rm= TRUE
  )

  xxmin <- pmin(qA[[1]], qB[[1]])
  xxmax <- pmax(qA[[2]], qB[[2]])

  densidad_A <- density(dataset[foto_mes == param$mes0, get(campo)],
    kernel= "gaussian", na.rm= TRUE
  )

  densidad_B <- density(dataset[foto_mes == param$mes1, get(campo)],
    kernel= "gaussian", na.rm= TRUE
  )

  plot(densidad_A,
    col= "blue",
    xlim= c(xxmin, xxmax),
    ylim= c(0, pmax(max(densidad_A$y), max(densidad_B$y))),
    main= campo
  )

  lines(densidad_B, col= "red", lty= 2)

  legend("topright",
    legend= c( param$mes0, param$mes1),
    col= c("blue", "red"), lty= c(1, 2)
  )
}

# %%
# lectura del dataset
dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
# Entreno el modelo
# utilizo los mejores hiperparametros encontrados

modelo <- rpart(
  formula= "clase_ternaria ~ . ",
  data= dataset[foto_mes == PARAM$mes0], # los datos donde voy a entrenar
  xval= 0,
  cp= -1,
  minsplit= 1144,
  minbucket= 539,
  maxdepth= 8
)

# %%
campos_modelo <- names(modelo$variable.importance)
campos_buenos <- c(campos_modelo, setdiff(colnames(dataset), campos_modelo))
campos_buenos <- setdiff(
  campos_buenos,
  c("foto_mes", "clase_ternaria")
)

campos_buenos

# %%
# para fines didacticos,  cliente_antiguedad primero
campos_buenos <- c("cliente_antiguedad", campos_buenos)

# %%
# grafico las densidades de cada variable para los dos mses

options( repr.plot.width=15, repr.plot.height=15)

for (campo in campos_buenos) {
  cat(campo, "  ")
  graficar_campo(campo, PARAM)
}

# %% [markdown]
# ---

# %% [markdown]
# ## 3.09 Bayesian Optimization

# %% [markdown]
# Se explicará en clase como a partir del Grid Search se deriva el algoritmo de Bayesian Optimization

# %% [markdown]
# ---

# %% [markdown]
# ## 3.10 Bayesian Optimization código

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  653308 34.9 1439377    76.9 1117753  59.7
# Vcells 1216578  9.3 8388608    64.0 1924958  14.7

# %% [markdown]
# * Instalacion de la libreria  rpart.plot  para dibujar el arbol
# * invocacion de las librerias  **data.table** y  **rpart**

# %%
# cargo las librerias que necesito
require("data.table")
require("rpart")
require("parallel")
# Out:
# Loading required package: data.table
#
# Loading required package: rpart
#
# Loading required package: parallel

# %%
if( ! require("rlist") ) install.packages("rlist")
require("rlist")
# Out:
# Loading required package: rlist

# %%
# paquete necesarios para la Bayesian Optimization
if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")
# Out:
# Loading required package: DiceKriging

# %%
# paquete necesarios para la Bayesian Optimization
if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# Accion a realizar : cambiar por su semilla primigenia

# %%
# Defino la  Optimizacion Bayesiana

# cantidad de iteraciones de la Optimizacion Bayesiana
PARAM <- list()

PARAM$semilla_primigenia <- 100887
PARAM$experimento <- "HT310"

PARAM$BO_iter <- 70 #cantidad de iteraciones de la Bayesian Optimization

# la letra L al final de 1L significa ENTERO
PARAM$hs <- makeParamSet(
    makeNumericParam("cp", lower= -1, upper= 0.1),
    makeIntegerParam("minsplit", lower= 1L, upper= 8000L),
    makeIntegerParam("minbucket", lower= 1L, upper= 4000L),
    makeIntegerParam("maxdepth", lower= 3L, upper= 20L),
    forbidden= quote(minbucket > 0.5 * minsplit)
)
# minbuket NO PUEDE ser mayor que la mitad de minsplit

# %%
# carpeta de trabajo
setwd("/content/buckets/b1/exp")
dir.create(PARAM$experimento, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", PARAM$experimento ))

# %%
particionar <- function(data, division, agrupa = "", campo = "fold",
                        start = 1, seed = NA) {
  if (!is.na(seed)) set.seed(seed)

  bloque <- unlist(mapply(
    function(x, y) {
      rep(y, x)
    }, division,
    seq(from= start, length.out= length(division))
  ))

  data[, (campo) := sample(rep(bloque, ceiling(.N / length(bloque))))[1:.N],
    by= agrupa
  ]
}

# %%
# fold_test  tiene el numero de fold que voy a usar para testear,
#  entreno en el resto de los folds
# param tiene los hiperparametros del arbol

ArbolSimple <- function(fold_test, param_rpart) {
  # genero el modelo
  # entreno en todo MENOS el fold_test que uso para testing
  modelo <- rpart("clase_ternaria ~ .",
    data= dataset[fold != fold_test, ],
    xval= 0,
    control= param_rpart
  )

  # aplico el modelo a los datos de testing
  # aplico el modelo sobre los datos de testing
  # quiero que me devuelva probabilidades
  prediccion <- predict(modelo,
    dataset[fold == fold_test, ],
    type= "prob"
  )

  # esta es la probabilidad de baja
  prob_baja2 <- prediccion[, "BAJA+2"]

  # calculo la ganancia
  ganancia_testing <- dataset[fold == fold_test][
    prob_baja2 > 1 / 40,
    sum(ifelse(clase_ternaria == "BAJA+2",
      117000, -3000
    ))
  ]

  # esta es la ganancia sobre el fold de testing, NO esta normalizada
  return(ganancia_testing)
}

# %%
ArbolesCrossValidation <- function(param_rpart, qfolds, pagrupa, semilla) {
  # generalmente  c(1, 1, 1, 1, 1 )  cinco unos
  divi <- rep(1, qfolds)

  # particiono en dataset en folds
  particionar(dataset, divi, seed= semilla, agrupa= pagrupa)

  ganancias <- mcmapply(ArbolSimple,
    seq(qfolds), # 1 2 3 4 5
    MoreArgs= list(param_rpart),
    SIMPLIFY= FALSE,
    mc.cores= detectCores()
  )

  dataset[, fold := NULL]

  # devuelvo la primer ganancia y el promedio
  # promedio las ganancias
  ganancia_promedio <- mean(unlist(ganancias))
  # aqui normalizo la ganancia
  ganancia_promedio_normalizada <- ganancia_promedio * qfolds

  return(ganancia_promedio_normalizada)
}

# %%
# esta funcion solo puede recibir los parametros que se estan optimizando
# el resto de los parametros, lamentablemente se pasan como variables globales

EstimarGanancia <- function(x) {
  message(format(Sys.time(), "%a %b %d %X %Y"))
  GLOBAL_iteracion <<- GLOBAL_iteracion + 1

  xval_folds <- 5
  # param= x los hiperparametros del arbol
  # qfolds= xval_folds  la cantidad de folds
  ganancia <- ArbolesCrossValidation(
    param_rpart= x,
    qfolds= xval_folds,
    pagrupa= "clase_ternaria",
    semilla= PARAM$semilla_primigenia
  )

  return(ganancia)
}

# %%
# lectura del dataset
dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
archivo_log <- "BO_log.txt"
archivo_BO <- "bayesian.RDATA"

# leo si ya existe el log
#  para retomar en caso que se se corte el programa
GLOBAL_iteracion <- 0
GLOBAL_mejor <- -Inf

if (file.exists(archivo_log)) {
  tabla_log <- fread(archivo_log)
  GLOBAL_iteracion <- nrow(tabla_log)
  GLOBAL_mejor <- tabla_log[, max(ganancia)]
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

funcion_optimizar <- EstimarGanancia

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,
#  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
# minimize= FALSE estoy Maximizando la ganancia
obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar,
  minimize= FALSE,
  noisy= TRUE,
  par.set= PARAM$hs,
  has.simple.signature= FALSE
)

ctrl <- makeMBOControl(
  save.on.disk.at.time= 600,
  save.file.path= archivo_BO
)

ctrl <- setMBOControlTermination(ctrl, iters= PARAM$BO_iter)
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

surr.km <- makeLearner("regr.km",
  predict.type= "se",
  covtype= "matern3_2", control= list(trace= TRUE)
)

# %%
# inicio la optimizacion bayesiana
if (!file.exists(archivo_BO)) {
  bayesiana_salida <- mbo(
    fun= obj.fun,
    learner= surr.km,
    control= ctrl
  )
} else {
  bayesiana_salida <- mboContinue(archivo_BO)
}
# retomo en caso que ya exista
# Out:
# Computing y column(s) for design. Not provided.
#
# Mon Jul 21 04:27:36 2025
#
# Mon Jul 21 04:29:38 2025
#
# Mon Jul 21 04:31:06 2025
#
# Mon Jul 21 04:32:35 2025
#
# Mon Jul 21 04:33:22 2025
#
# Mon Jul 21 04:35:00 2025
#
# Mon Jul 21 04:35:39 2025
#
# Mon Jul 21 04:38:08 2025
#
# Mon Jul 21 04:41:05 2025
#
# Mon Jul 21 04:43:25 2025
#
# Mon Jul 21 04:44:03 2025
#
# Mon Jul 21 04:45:57 2025
#
# Mon Jul 21 04:48:39 2025
#
# Mon Jul 21 04:51:15 2025
#
# Mon Jul 21 04:51:54 2025
#
# Mon Jul 21 04:54:52 2025
#
# [mbo] 0: cp=-0.501; minsplit=3380; minbucket=291; maxdepth=18 : y = 4.57e+07 : 121.8 secs : initdesign
#
# [mbo] 0: cp=-0.569; minsplit=6926; minbucket=2817; maxdepth=13 : y = 4.69e+07 : 88.0 secs : initdesign
#
# [mbo] 0: cp=-0.446; minsplit=7249; minbucket=1591; maxdepth=12 : y = 4.75e+07 : 88.9 secs : initdesign
#
# [mbo] 0: cp=-0.856; minsplit=6500; minbucket=676; maxdepth=4 : y = 4.69e+07 : 47.7 secs : initdesign
#
# [mbo] 0: cp=-0.0141; minsplit=7601; minbucket=2550; maxdepth=7 : y = 4.68e+07 : 97.6 secs : initdesign
#
# [mbo] 0: cp=0.0869; minsplit=4788; minbucket=223; maxdepth=19 : y = 0 : 39.0 secs : initdesign
#
# [mbo] 0: cp=-0.768; minsplit=5874; minbucket=2063; maxdepth=18 : y = 4.7e+07 : 149.2 secs : initdesign
#
# [mbo] 0: cp=-0.701; minsplit=5065; minbucket=380; maxdepth=16 : y = 4.74e+07 : 176.6 secs : initdesign
#
# [mbo] 0: cp=-0.384; minsplit=5430; minbucket=935; maxdepth=10 : y = 4.77e+07 : 140.4 secs : initdesign
#
# [mbo] 0: cp=0.0507; minsplit=7932; minbucket=3436; maxdepth=11 : y = 0 : 38.4 secs : initdesign
#
# [mbo] 0: cp=-0.589; minsplit=3479; minbucket=516; maxdepth=7 : y = 4.5e+07 : 113.8 secs : initdesign
#
# [mbo] 0: cp=-0.433; minsplit=3678; minbucket=1374; maxdepth=14 : y = 4.61e+07 : 162.2 secs : initdesign
#
# [mbo] 0: cp=-0.847; minsplit=4519; minbucket=1581; maxdepth=17 : y = 4.57e+07 : 155.8 secs : initdesign
#
# [mbo] 0: cp=0.0346; minsplit=7021; minbucket=358; maxdepth=15 : y = 0 : 38.8 secs : initdesign
#
# [mbo] 0: cp=-0.264; minsplit=4887; minbucket=170; maxdepth=13 : y = 4.72e+07 : 177.5 secs : initdesign
#
# [mbo] 0: cp=-0.652; minsplit=1671; minbucket=468; maxdepth=5 : y = 4.88e+07 : 100.2 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesian.RDATA.
#
# Mon Jul 21 04:56:38 2025
#
# [mbo] 1: cp=-0.228; minsplit=6232; minbucket=2273; maxdepth=3 : y = 3.79e+07 : 71.4 secs : infill_ei
#
# Mon Jul 21 04:57:53 2025
#
# [mbo] 2: cp=-0.0652; minsplit=7534; minbucket=2396; maxdepth=3 : y = 3.78e+07 : 69.7 secs : infill_ei
#
# Mon Jul 21 04:59:05 2025
#
# [mbo] 3: cp=-0.203; minsplit=6963; minbucket=416; maxdepth=7 : y = 4.76e+07 : 117.1 secs : infill_ei
#
# Mon Jul 21 05:01:05 2025
#
# [mbo] 4: cp=-0.519; minsplit=5559; minbucket=2; maxdepth=13 : y = 4.71e+07 : 185.8 secs : infill_ei
#
# Mon Jul 21 05:04:13 2025
#
# [mbo] 5: cp=-0.188; minsplit=4490; minbucket=2074; maxdepth=7 : y = 4.53e+07 : 117.8 secs : infill_ei
#
# Mon Jul 21 05:06:14 2025
#
# [mbo] 6: cp=-0.683; minsplit=6983; minbucket=2200; maxdepth=5 : y = 4.69e+07 : 94.5 secs : infill_ei
#
# Saved the current state after iteration 7 in the file bayesian.RDATA.
#
# Mon Jul 21 05:07:59 2025
#
# [mbo] 7: cp=-0.742; minsplit=5925; minbucket=1742; maxdepth=12 : y = 4.73e+07 : 154.0 secs : infill_ei
#
# Mon Jul 21 05:10:36 2025
#
# [mbo] 8: cp=-0.344; minsplit=1275; minbucket=2; maxdepth=12 : y = 4.84e+07 : 198.6 secs : infill_ei
#
# Mon Jul 21 05:13:57 2025
#
# [mbo] 9: cp=-0.627; minsplit=7538; minbucket=1802; maxdepth=16 : y = 4.72e+07 : 151.0 secs : infill_ei
#
# Mon Jul 21 05:16:31 2025
#
# [mbo] 10: cp=-0.67; minsplit=7380; minbucket=1; maxdepth=4 : y = 4.66e+07 : 81.4 secs : infill_ei
#
# Mon Jul 21 05:17:55 2025
#
# [mbo] 11: cp=-0.326; minsplit=7997; minbucket=1761; maxdepth=7 : y = 4.72e+07 : 108.8 secs : infill_ei
#
# Saved the current state after iteration 12 in the file bayesian.RDATA.
#
# Mon Jul 21 05:19:50 2025
#
# [mbo] 12: cp=-0.737; minsplit=2176; minbucket=1086; maxdepth=3 : y = 3.72e+07 : 68.8 secs : infill_ei
#
# Mon Jul 21 05:21:02 2025
#
# [mbo] 13: cp=-0.807; minsplit=7233; minbucket=284; maxdepth=6 : y = 4.75e+07 : 104.6 secs : infill_ei
#
# Mon Jul 21 05:22:49 2025
#
# [mbo] 14: cp=-0.359; minsplit=5209; minbucket=216; maxdepth=12 : y = 4.73e+07 : 164.5 secs : infill_ei
#
# Mon Jul 21 05:25:36 2025
#
# [mbo] 15: cp=-0.412; minsplit=2; minbucket=1; maxdepth=5 : y = 4.8e+07 : 95.4 secs : infill_ei
#
# Mon Jul 21 05:27:14 2025
#
# [mbo] 16: cp=-0.0351; minsplit=8000; minbucket=1214; maxdepth=6 : y = 4.75e+07 : 103.6 secs : infill_ei
#
# Mon Jul 21 05:29:00 2025
#
# [mbo] 17: cp=-1; minsplit=5950; minbucket=10; maxdepth=5 : y = 4.72e+07 : 93.0 secs : infill_ei
#
# Saved the current state after iteration 18 in the file bayesian.RDATA.
#
# Mon Jul 21 05:30:40 2025
#
# [mbo] 18: cp=-0.486; minsplit=6537; minbucket=1; maxdepth=5 : y = 4.68e+07 : 94.4 secs : infill_ei
#
# Mon Jul 21 05:32:17 2025
#
# [mbo] 19: cp=-0.65; minsplit=8000; minbucket=1262; maxdepth=10 : y = 4.75e+07 : 139.9 secs : infill_ei
#
# Mon Jul 21 05:34:41 2025
#
# [mbo] 20: cp=-0.671; minsplit=1775; minbucket=884; maxdepth=18 : y = 4.78e+07 : 187.8 secs : infill_ei
#
# Mon Jul 21 05:37:51 2025
#
# [mbo] 21: cp=-0.263; minsplit=140; minbucket=1; maxdepth=9 : y = 4.75e+07 : 152.5 secs : infill_ei
#
# Mon Jul 21 05:40:27 2025
#
# [mbo] 22: cp=-0.922; minsplit=8000; minbucket=2708; maxdepth=8 : y = 4.68e+07 : 121.5 secs : infill_ei
#
# Saved the current state after iteration 23 in the file bayesian.RDATA.
#
# Mon Jul 21 05:42:37 2025
#
# [mbo] 23: cp=-0.562; minsplit=7984; minbucket=2490; maxdepth=9 : y = 4.68e+07 : 126.4 secs : infill_ei
#
# Mon Jul 21 05:44:46 2025
#
# [mbo] 24: cp=-0.732; minsplit=7995; minbucket=582; maxdepth=20 : y = 4.75e+07 : 175.7 secs : infill_ei
#
# Mon Jul 21 05:47:44 2025
#
# [mbo] 25: cp=-0.661; minsplit=7995; minbucket=1940; maxdepth=13 : y = 4.71e+07 : 146.5 secs : infill_ei
#
# Mon Jul 21 05:50:15 2025
#
# [mbo] 26: cp=-0.893; minsplit=14; minbucket=5; maxdepth=10 : y = 4.34e+07 : 166.4 secs : infill_ei
#
# Saved the current state after iteration 27 in the file bayesian.RDATA.
#
# Mon Jul 21 05:53:11 2025
#
# [mbo] 27: cp=-1; minsplit=7932; minbucket=3709; maxdepth=12 : y = 4.7e+07 : 140.3 secs : infill_ei
#
# Mon Jul 21 05:55:34 2025
#
# [mbo] 28: cp=-0.999; minsplit=7999; minbucket=1137; maxdepth=11 : y = 4.75e+07 : 145.0 secs : infill_ei
#
# Mon Jul 21 05:58:02 2025
#
# [mbo] 29: cp=-0.999; minsplit=8000; minbucket=3660; maxdepth=5 : y = 4.7e+07 : 94.3 secs : infill_ei
#
# Mon Jul 21 05:59:40 2025
#
# [mbo] 30: cp=-0.301; minsplit=7; minbucket=1; maxdepth=13 : y = 3.87e+07 : 211.1 secs : infill_ei
#
# Saved the current state after iteration 31 in the file bayesian.RDATA.
#
# Mon Jul 21 06:03:20 2025
#
# [mbo] 31: cp=-0.491; minsplit=1862; minbucket=923; maxdepth=11 : y = 4.67e+07 : 160.0 secs : infill_ei
#
# Mon Jul 21 06:06:03 2025
#
# [mbo] 32: cp=-0.321; minsplit=1731; minbucket=4; maxdepth=9 : y = 4.89e+07 : 151.8 secs : infill_ei
#
# Mon Jul 21 06:08:38 2025
#
# [mbo] 33: cp=-0.262; minsplit=2730; minbucket=3; maxdepth=10 : y = 4.71e+07 : 159.8 secs : infill_ei
#
# Mon Jul 21 06:11:21 2025
#
# [mbo] 34: cp=-0.66; minsplit=6930; minbucket=1; maxdepth=18 : y = 4.67e+07 : 226.0 secs : infill_ei
#
# Saved the current state after iteration 35 in the file bayesian.RDATA.
#
# Mon Jul 21 06:15:16 2025
#
# [mbo] 35: cp=-0.333; minsplit=3039; minbucket=10; maxdepth=3 : y = 3.72e+07 : 73.3 secs : infill_ei
#
# Mon Jul 21 06:16:32 2025
#
# [mbo] 36: cp=-0.628; minsplit=4087; minbucket=1551; maxdepth=20 : y = 4.66e+07 : 163.8 secs : infill_ei
#
# Warning message in generateDesign(control$infill.opt.focussearch.points, ps.local, :
# “generateDesign could only produce 999 points instead of 1000!”
# Mon Jul 21 06:19:19 2025
#
# [mbo] 37: cp=-0.793; minsplit=2400; minbucket=1; maxdepth=20 : y = 4.87e+07 : 292.4 secs : infill_ei
#
# Mon Jul 21 06:24:14 2025
#
# [mbo] 38: cp=-1; minsplit=5410; minbucket=576; maxdepth=20 : y = 4.74e+07 : 179.2 secs : infill_ei
#
# Saved the current state after iteration 39 in the file bayesian.RDATA.
#
# Mon Jul 21 06:27:20 2025
#
# [mbo] 39: cp=-1; minsplit=6219; minbucket=2745; maxdepth=10 : y = 4.69e+07 : 136.1 secs : infill_ei
#
# Mon Jul 21 06:29:39 2025
#
# [mbo] 40: cp=-0.753; minsplit=4011; minbucket=636; maxdepth=19 : y = 4.65e+07 : 184.8 secs : infill_ei
#
# Mon Jul 21 06:32:47 2025
#
# [mbo] 41: cp=-0.94; minsplit=7999; minbucket=3941; maxdepth=20 : y = 4.75e+07 : 137.4 secs : infill_ei
#
# Mon Jul 21 06:35:07 2025
#
# [mbo] 42: cp=-0.401; minsplit=1211; minbucket=1; maxdepth=10 : y = 4.84e+07 : 169.3 secs : infill_ei
#
# Saved the current state after iteration 43 in the file bayesian.RDATA.
#
# Mon Jul 21 06:38:04 2025
#
# [mbo] 43: cp=-1; minsplit=7992; minbucket=2689; maxdepth=15 : y = 4.68e+07 : 142.3 secs : infill_ei
#
# Mon Jul 21 06:40:29 2025
#
# [mbo] 44: cp=-0.916; minsplit=8000; minbucket=2073; maxdepth=20 : y = 4.7e+07 : 148.8 secs : infill_ei
#
# Mon Jul 21 06:43:01 2025
#
# [mbo] 45: cp=-0.66; minsplit=7993; minbucket=3996; maxdepth=18 : y = 4.76e+07 : 138.9 secs : infill_ei
#
# Mon Jul 21 06:45:23 2025
#
# [mbo] 46: cp=-1; minsplit=5960; minbucket=4; maxdepth=14 : y = 4.72e+07 : 188.3 secs : infill_ei
#
# Saved the current state after iteration 47 in the file bayesian.RDATA.
#
# Mon Jul 21 06:48:40 2025
#
# [mbo] 47: cp=-0.999; minsplit=7; minbucket=2; maxdepth=20 : y = 1.86e+07 : 319.1 secs : infill_ei
#
# Mon Jul 21 06:54:03 2025
#
# [mbo] 48: cp=-0.642; minsplit=712; minbucket=1; maxdepth=7 : y = 4.68e+07 : 126.6 secs : infill_ei
#
# Mon Jul 21 06:56:13 2025
#
# [mbo] 49: cp=-0.657; minsplit=2544; minbucket=2; maxdepth=20 : y = 4.63e+07 : 284.6 secs : infill_ei
#
# Saved the current state after iteration 50 in the file bayesian.RDATA.
#
# Mon Jul 21 07:01:06 2025
#
# [mbo] 50: cp=-0.781; minsplit=2257; minbucket=9; maxdepth=15 : y = 4.77e+07 : 225.0 secs : infill_ei
#
# Mon Jul 21 07:04:55 2025
#
# [mbo] 51: cp=-0.254; minsplit=965; minbucket=456; maxdepth=6 : y = 4.84e+07 : 112.0 secs : infill_ei
#
# Mon Jul 21 07:06:51 2025
#
# [mbo] 52: cp=-0.694; minsplit=6901; minbucket=3449; maxdepth=20 : y = 4.78e+07 : 138.7 secs : infill_ei
#
# Mon Jul 21 07:09:13 2025
#
# [mbo] 53: cp=-0.449; minsplit=6763; minbucket=1575; maxdepth=8 : y = 4.75e+07 : 128.1 secs : infill_ei
#
# Saved the current state after iteration 54 in the file bayesian.RDATA.
#
# Mon Jul 21 07:11:28 2025
#
# [mbo] 54: cp=-0.0599; minsplit=6558; minbucket=2340; maxdepth=6 : y = 4.69e+07 : 104.1 secs : infill_ei
#
# Mon Jul 21 07:13:16 2025
#
# [mbo] 55: cp=-0.832; minsplit=5753; minbucket=25; maxdepth=20 : y = 4.61e+07 : 240.2 secs : infill_ei
#
# Mon Jul 21 07:17:20 2025
#
# [mbo] 56: cp=-0.546; minsplit=1212; minbucket=3; maxdepth=5 : y = 4.76e+07 : 95.2 secs : infill_ei
#
# Mon Jul 21 07:18:58 2025
#
# [mbo] 57: cp=-0.805; minsplit=2007; minbucket=5; maxdepth=10 : y = 4.87e+07 : 160.4 secs : infill_ei
#
# Saved the current state after iteration 58 in the file bayesian.RDATA.
#
# Mon Jul 21 07:21:47 2025
#
# [mbo] 58: cp=-0.762; minsplit=2566; minbucket=1266; maxdepth=18 : y = 4.65e+07 : 174.1 secs : infill_ei
#
# Mon Jul 21 07:24:45 2025
#
# [mbo] 59: cp=-0.693; minsplit=1681; minbucket=3; maxdepth=12 : y = 4.83e+07 : 196.2 secs : infill_ei
#
# Mon Jul 21 07:28:05 2025
#
# [mbo] 60: cp=-0.893; minsplit=1669; minbucket=4; maxdepth=6 : y = 4.79e+07 : 108.9 secs : infill_ei
#
# Mon Jul 21 07:29:57 2025
#
# [mbo] 61: cp=-0.904; minsplit=4845; minbucket=6; maxdepth=10 : y = 4.74e+07 : 153.7 secs : infill_ei
#
# Saved the current state after iteration 62 in the file bayesian.RDATA.
#
# Mon Jul 21 07:32:38 2025
#
# [mbo] 62: cp=-0.535; minsplit=7999; minbucket=2229; maxdepth=20 : y = 4.68e+07 : 141.5 secs : infill_ei
#
# Mon Jul 21 07:35:03 2025
#
# [mbo] 63: cp=-0.67; minsplit=5357; minbucket=3; maxdepth=5 : y = 4.68e+07 : 95.0 secs : infill_ei
#
# Mon Jul 21 07:36:41 2025
#
# [mbo] 64: cp=-0.884; minsplit=7119; minbucket=799; maxdepth=12 : y = 4.76e+07 : 153.4 secs : infill_ei
#
# Mon Jul 21 07:39:17 2025
#
# [mbo] 65: cp=-0.941; minsplit=8000; minbucket=594; maxdepth=5 : y = 4.75e+07 : 95.6 secs : infill_ei
#
# Mon Jul 21 07:40:57 2025
#
# [mbo] 66: cp=-0.0182; minsplit=20; minbucket=2; maxdepth=6 : y = 4.79e+07 : 109.9 secs : infill_ei
#
# Saved the current state after iteration 67 in the file bayesian.RDATA.
#
# Mon Jul 21 07:42:56 2025
#
# [mbo] 67: cp=-0.147; minsplit=1109; minbucket=2; maxdepth=8 : y = 4.79e+07 : 138.5 secs : infill_ei
#
# Mon Jul 21 07:45:18 2025
#
# [mbo] 68: cp=-1; minsplit=2011; minbucket=32; maxdepth=9 : y = 4.67e+07 : 143.9 secs : infill_ei
#
# Mon Jul 21 07:47:45 2025
#
# [mbo] 69: cp=-0.592; minsplit=1905; minbucket=11; maxdepth=16 : y = 4.54e+07 : 235.8 secs : infill_ei
#
# Mon Jul 21 07:51:45 2025
#
# [mbo] 70: cp=-0.855; minsplit=1873; minbucket=12; maxdepth=12 : y = 4.64e+07 : 192.3 secs : infill_ei
#
# Saved the final state in the file bayesian.RDATA
#
# Saved the final state in the file bayesian.RDATA

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  list(cp, minsplit, minbucket, maxdepth)
]

print(PARAM$out$lgbm$mejores_hiperparametros)

# %%
format(Sys.time(), "%a %b %d %X %Y")

# %% [markdown]
# ---
